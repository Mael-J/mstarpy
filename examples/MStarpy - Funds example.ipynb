# %% [markdown]
# # Fund Analysis
#
# In this example, we will explore all the key methods used to perform an in-depth analysis of a fund.

# %%
import mstarpy as ms

# %% [markdown]
# Initialize Funds to start you analysis

# %%
funds = ms.Funds("VTSAX")

# %% [markdown]
# Find the fund name

# %%
funds.name
# Out:
# 'Vanguard Total Stock Mkt Idx Adm'

# %% [markdown]
# Find the fund isin

# %%
funds.isin
# Out:
# 'US9229087286'

# %% [markdown]
# Asset allocation split of the fund, index and category
#
# Asset Allocation
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.allocationMap()
# Out:
# {'assetType': 'EQUITY',
#  'portfolioDate': '2025-05-31T05:00:00.000',
#  'portfolioDateCategory': '2025-06-30T05:00:00.000',
#  'portfolioDateIndex': None,
#  'portfolioDateGlobal': '2025-05-31T05:00:00.000',
#  'portfolioDateCategoryGlobal': '2025-06-30T05:00:00.000',
#  'portfolioDateIndexGlobal': None,
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryName': 'Large Blend',
#  'indexName': None,
#  'allocationMap': {'AssetAllocCash': {'netAllocation': '0.42386',
#    'shortAllocation': '0.00139',
#    'longAllocation': '0.42525',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '1.63730',
#    'targetAllocation': None},
#   'AssetAllocNotClassified': {'netAllocation': '0.0',
#    'shortAllocation': '0.0',
#    'longAllocation': '0.0',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '0.02182',
#    'targetAllocation': None},
#   'AssetAllocNonUSEquity': {'netAllocation': '0.54227',
#    'shortAllocation': '0.00000',
#    'longAllocation': '0.54227',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '2.15734',
#    'targetAllocation': None},
#   'AssetAllocOther': {'netAllocation': '0.00000',
#    'shortAllocation': '0.00000',
#    'longAllocation': '0.00000',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '1.10571',
#    'targetAllocation': None},
#   'AssetAllocUSEquity': {'netAllocation': '99.03387',
#    'shortAllocation': '0.00000',
#    'longAllocation': '99.03387',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '96.43916',
#    'targetAllocation': None},
#   'AssetAllocBond': {'netAllocation': '0.00000',
#    'shortAllocation': '0.00000',
#    'longAllocation': '0.00000',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '0.54330',
#    'targetAllocation': None}},
#  'japanAssetAllocation': None,
#  'countryCode': 'USA',
#  'securityType': None,
#  'dualViewData': None,
#  'targetDate': None,
#  'hasRegionalAssetAlloc': True,
#  'globalAllocationMap': {'assetAllocPreferred': {'netAllocation': '0.00000',
#    'shortAllocation': '0.00000',
#    'longAllocation': '0.00000',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '0.02182',
#    'targetAllocation': None},
#   'assetAllocOther': {'netAllocation': '0.00000',
#    'shortAllocation': '0.00000',
#    'longAllocation': '0.00000',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '1.10571',
#    'targetAllocation': None},
#   'assetAllocEquity': {'netAllocation': '99.57614',
#    'shortAllocation': '0.00000',
#    'longAllocation': '99.57614',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '98.59650',
#    'targetAllocation': None},
#   'assetAllocCash': {'netAllocation': '0.42386',
#    'shortAllocation': '0.00139',
#    'longAllocation': '0.42525',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '1.63730',
#    'targetAllocation': None},
#   'assetAllocConvertible': {'netAllocation': '0.00000',
#    'shortAllocation': '0.00000',
#    'longAllocation': '0.00000',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '0.00000',
#    'targetAllocation': None},
#   'assetAllocFixedIncome': {'netAllocation': '0.00000',
#    'shortAllocation': '0.00000',
#    'longAllocation': '0.00000',
#    'longAllocationIndex': None,
#    'longAllocationCategory': '0.54330',
#    'targetAllocation': None}}}

# %% [markdown]
# Fund allocation by Market Capitalization and Style
#
# Stock Style - Weight
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.allocationWeighting()
# Out:
# {'portfolioDate': '2025-05-31T05:00:00.000',
#  'masterPortfolioId': '3506',
#  'largeValue': '20.19900',
#  'largeBlend': '34.96900',
#  'largeGrowth': '16.77800',
#  'middleValue': '5.65400',
#  'middleBlend': '8.71200',
#  'middleGrowth': '5.20500',
#  'smallValue': '2.91600',
#  'smallBlend': '3.33700',
#  'smallGrowth': '2.22800'}

# %% [markdown]
# Ratings of the asset manager funds

# %%
funds.analystRating()
# Out:
# [{'rating': '7',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.739884216,
#   'noPremiumChinaFund': False},
#  {'rating': '6',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.1317143869,
#   'noPremiumChinaFund': False},
#  {'rating': '5',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.1149306194,
#   'noPremiumChinaFund': False},
#  {'rating': '4',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.005442902,
#   'noPremiumChinaFund': False},
#  {'rating': '3',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': '2',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0002498594,
#   'noPremiumChinaFund': False},
#  {'rating': '1',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': '0',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0077780163,
#   'noPremiumChinaFund': False}]

# %% [markdown]
# Rating and Performance of the best funds of the asset manager

# %%
funds.analystRatingTopFunds()
# Out:
# {'userType': 'Free',
#  'analystRatingFundList': [{'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'calendarYearFlow': 9415656518.0,
#    'netAsset': 786337258753.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 19.04603,
#    'trailing3YearReturnRank': 39.0,
#    'fundShareClassId': 'F00000VE7X',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA002PT',
#    'secId': 'F00000VE7X',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'calendarYearFlow': -15928247136.0,
#    'netAsset': 586598496648.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 19.65995,
#    'trailing3YearReturnRank': 23.0,
#    'fundShareClassId': 'FOUSA00L8W',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA002QH',
#    'secId': 'FOUSA00L8W',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'calendarYearFlow': 1380413493.0,
#    'netAsset': 234254459616.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 13.73202,
#    'trailing3YearReturnRank': 77.0,
#    'fundShareClassId': 'FOUSA00KIR',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA004JJ',
#    'secId': 'FOUSA00KIR',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'calendarYearFlow': -3932520588.0,
#    'netAsset': 196378179138.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 19.68529,
#    'trailing3YearReturnRank': 22.0,
#    'fundShareClassId': 'FOUSA00GPG',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA002Q0',
#    'secId': 'FOUSA00GPG',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'calendarYearFlow': 7985822603.0,
#    'netAsset': 166807538024.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 2.6004,
#    'trailing3YearReturnRank': 52.0,
#    'fundShareClassId': 'FOUSA08OZU',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA09PA2',
#    'secId': 'FOUSA08OZU',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2025-06-30T05:00:00.000',
#  'footerReturnDate': '2025-06-30T05:00:00.000',
#  'currency': 'USD',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Recent change in ratings for asset manager funds

# %%
funds.analystRatingTopFundsUpDown()
# Out:
# {'topAnalystRatingUpDownList': [],
#  'userType': 'Free',
#  'currency': 'USD',
#  'securityType': 'FO',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'secId': 'FOUSA00L83',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Carbon metrics
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.carbonMetrics()
# Out:
# {'carbonPortfolioCoveragePct': None,
#  'carbonRiskScore': None,
#  'carbonRiskScoreCategoryAverage': '7.40205',
#  'carbonRiskScoreCategoryHigh': '28.40655',
#  'carbonRiskScoreCategoryLow': '0.00000',
#  'carbonRiskScoreCategoryAverageDate': '2022-12-31T06:00:00.000',
#  'carbonRiskScoreCategoryRankPct': None,
#  'carbonRiskScoreDate': '2025-05-31T05:00:00.000',
#  'categoryDate': '2022-12-31T06:00:00.000',
#  'categoryName': 'Large Blend',
#  'fossilFuelInvolvementPctCategoryAverage': '8.78908',
#  'fossilFuelInvolvementPct': '8.32994',
#  'fossilFuelInvolvementPctCategoryHigh': '100.00000',
#  'fossilFuelInvolvementPctCategoryLow': '0.00000',
#  'isLowCarbon': None,
#  'fossilFuelPercentageOfPortfolioCovered': '97.17163',
#  'portfolioCarbonRiskScore': '7.24337',
#  'carbonRiskPercentageOfPortfolioCovered': '98.05256',
#  'isDesignatedLowCarbon': 'false'}

# %% [markdown]
# Cost Illustration
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.costIllustration()
# Out:
# {'prospectusDate': '2025-04-29T05:00:00.000',
#  'expectedReturn': 5.0,
#  'initial': 10000.0,
#  'mer': None,
#  'priceTemplate': 'USA_OE',
#  'baseCurrencyId': 'USD',
#  'costItems': [{'year': 1,
#    'endNetAsset': 10499.90772386964,
#    'purchase': 0.0,
#    'ongoing': 4.0984318959,
#    'redemption': 0.0,
#    'total': 4.0984318959,
#    'purchasePer': 0.0,
#    'ongoingPer': 0.0003903303,
#    'redemptionPer': 0.0,
#    'totalPer': 0.0003903303},
#   {'year': 5,
#    'endNetAsset': 12759.994261123229,
#    'purchase': 0.0,
#    'ongoing': 22.6274729756,
#    'redemption': 0.0,
#    'total': 22.6274729756,
#    'purchasePer': 0.0,
#    'ongoingPer': 0.0017733137,
#    'redemptionPer': 0.0,
#    'totalPer': 0.0017733137},
#   {'year': 10,
#    'endNetAsset': 16275.500184834224,
#    'purchase': 0.0,
#    'ongoing': 51.4489152536,
#    'redemption': 0.0,
#    'total': 51.4489152536,
#    'purchasePer': 0.0,
#    'ongoingPer': 0.0031611265,
#    'redemptionPer': 0.0,
#    'totalPer': 0.0031611265}]}

# %% [markdown]
# Performance including and excluding fees

# %%
funds.costProjection()
# Out:
# {'initialInvestment': 10000.0,
#  'yearsToCalculate': 5,
#  'growthRatePercent': 5.0,
#  'returnExcludingFeeAmount': 12762.81563,
#  'returnIncludingFeeAmount': 12762.81563,
#  'returnFeeReductionAmount': 0.0,
#  'reducedRateOfReturn': 5.0,
#  'currency': 'USD'}

# %% [markdown]
# Coupon distributed by the fund, category and benchmark
#
# Bond Breakdown - Coupon Range
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
ms.Funds("IE00B04GQT48").couponRange()
# Out:
# {'fundCouponRange': {'portfolioDate': '2025-06-30T05:00:00.000',
#   'name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'coupon0': 0.0117,
#   'coupon0To2': 5.61603,
#   'coupon2To4': 31.78255,
#   'coupon4To6': 53.10869,
#   'coupon6To8': 8.86669,
#   'coupon8To10': 0.59446,
#   'couponMoreThan10': 0.0},
#  'categoryCouponRange': {'portfolioDate': '2025-06-30T05:00:00.000',
#   'name': 'USD Corporate Bond',
#   'coupon0': 0.3194,
#   'coupon0To2': 0.78432,
#   'coupon2To4': 22.42147,
#   'coupon4To6': 37.13462,
#   'coupon6To8': 33.94334,
#   'coupon8To10': 0.69753,
#   'couponMoreThan10': 0.05399},
#  'benchmarkCouponRange': None,
#  'morningstarIndexCouponRange': {'portfolioDate': '2025-06-30T05:00:00.000',
#   'name': 'Morningstar US Corp Bd TR USD',
#   'coupon0': 0.0,
#   'coupon0To2': 5.06109,
#   'coupon2To4': 31.74389,
#   'coupon4To6': 54.30446,
#   'coupon6To8': 8.42628,
#   'coupon8To10': 0.4647,
#   'couponMoreThan10': 0.0}}

# %% [markdown]
# Credit rating split of the fund, catory and benchmark
#
# Bond Breakdown - Credit quality
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
ms.Funds("IE00B04GQT48").creditQuality()
# Out:
# {'fundName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'categoryName': 'USD Corporate Bond',
#  'indexName': 'Morningstar US Corp Bd TR USD',
#  'fund': {'creditQualityDate': '2025-06-30T05:00:00.000',
#   'creditQualityAAA': '7.45108',
#   'creditQualityAA': '12.87290',
#   'creditQualityA': '38.98468',
#   'creditQualityBBB': '40.41491',
#   'creditQualityBB': '0.00000',
#   'creditQualityB': '0.00000',
#   'creditQualityBelowB': '0.00000',
#   'creditQualityNotRated': '0.27640'},
#  'category': {'creditQualityDate': '2025-06-30T05:00:00.000',
#   'creditQualityAAA': '2.17247',
#   'creditQualityAA': '11.28163',
#   'creditQualityA': '38.54982',
#   'creditQualityBBB': '44.96795',
#   'creditQualityBB': '1.22378',
#   'creditQualityB': '0.11418',
#   'creditQualityBelowB': '0.82229',
#   'creditQualityNotRated': '0.86707'},
#  'index': {'creditQualityDate': None,
#   'creditQualityAAA': None,
#   'creditQualityAA': None,
#   'creditQualityA': None,
#   'creditQualityBBB': None,
#   'creditQualityBB': None,
#   'creditQualityB': None,
#   'creditQualityBelowB': None,
#   'creditQualityNotRated': None}}

# %% [markdown]
# Information of the fund

# %%
funds.dataPoint(field=["name", "alpha", "fundSize"])
# Out:
# [{'meta': {'securityID': 'FOUSA00L83',
#    'performanceID': '0P00002YGZ',
#    'fundID': 'FSUSA002PT',
#    'masterPortfolioID': '3506',
#    'universe': 'FO',
#    'exchange': 'XNAS',
#    'ticker': 'VTSAX'},
#   'fields': {'name': {'value': 'Vanguard Total Stock Mkt Idx Adm'},
#    'alpha': {'value': -0.892},
#    'fundSize': {'value': 1912236548176,
#     'properties': {'currency': {'value': 'USD'},
#      'date': {'value': '2025-06-30'}}}}}]

# %% [markdown]
# Coupon distributed by the fund
#
# Performance - Distributions
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.distribution("annual")
# Out:
# {'distribution': [{'distributionDate': '2025-06-30T05:00:00.000',
#    'distributionNav': 148.01,
#    'income': 0.9169,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 0.9169,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2024-12-23T06:00:00.000',
#    'distributionNav': 143.11,
#    'income': 1.7759,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.7759,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2023-12-20T06:00:00.000',
#    'distributionNav': 113.64,
#    'income': 1.651,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.651,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2022-12-21T06:00:00.000',
#    'distributionNav': 94.0,
#    'income': 1.5396999999999998,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.5396999999999998,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2021-12-23T06:00:00.000',
#    'distributionNav': 116.71,
#    'income': 1.4152,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.4152,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None}],
#  'baseCurrencyId': 'USD',
#  'template': 'OE_USA_EQUITY'}

# %% [markdown]
# Download a PDF file
#
# https://global.morningstar.com/fr/investissements/fonds/0P0000GFVM/documents

# %%
ms.Funds("IE00B04GQT48").downloadDocument("fr","PRIIP KID","en")
# Out:
# {'page': {'name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc', 'performanceID': '0P0000GFVM', 'securityID': 'F0000022KV', 'masterPortfolioID': '107906', 'fundID': 'FSGBR065UB', 'ticker': None, 'exchange': None, 'exchangeCountry': None, 'investmentType': 'FO', 'cusip': None, 'isin': 'IE00B04GQT48', 'universe': 'FO', 'fundStarRating': 3, 'medalistRating': 'Gold', 'countriesOfSale': ['AUT', 'CHE', 'DEU', 'DNK', 'ESP', 'FIN', 'FRA', 'GBR', 'IRL', 'ITA', 'LIE', 'LUX', 'NLD', 'NOR', 'PRT', 'SWE'], 'allowedMarketIds': ['at', 'bnl', 'eu', 'dk', 'fi', 'fr', 'de', 'ie', 'it', 'lu', 'nl', 'nord', 'no', 'pt', 'es', 'se', 'ch', 'gb']}, 'components': {'ads': {'status': 200, 'payload': {'fundcat': 'USDCorporateBond', 'familyid': '0C000022HA', 'brandingNameId': 'BN00000AAL', 'sustainabilityRating': 3}}, 'documents': {'status': 200, 'payload': [{'id': '4', 'name': 'Annual Report', 'documents': [{'effectiveDate': '2024-12-31', 'postedDate': '2025-05-08', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-12-31', 'postedDate': '2013-05-08', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en', 'fr'], 'effectiveDate': '2024-12-31', 'postedDate': '2025-05-08', 'categoryId': 'shareholder'}, {'id': '52', 'name': 'Factsheet', 'documents': [{'effectiveDate': '2025-06-30', 'postedDate': '2025-07-18', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2025-06-30', 'postedDate': '2025-07-18', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en', 'fr', 'nl'], 'effectiveDate': '2025-06-30', 'postedDate': '2025-07-18', 'categoryId': 'other'}, {'id': '109', 'name': 'Information Memorandum', 'documents': [{'effectiveDate': '2020-06-19', 'postedDate': '2020-07-09', 'mimeType': 'application/pdf', 'languages': ['en']}], 'mimeType': 'application/pdf', 'languages': ['en'], 'effectiveDate': '2020-06-19', 'postedDate': '2020-07-09', 'categoryId': 'other'}, {'id': '299', 'name': 'PRIIP KID', 'documents': [{'effectiveDate': '2025-03-19', 'postedDate': '2025-03-21', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2025-03-19', 'postedDate': '2025-03-21', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'no', 'sv', 'fi', 'pt', 'en', 'it', 'fr', 'da', 'nl', 'es'], 'effectiveDate': '2025-03-19', 'postedDate': '2025-03-21', 'categoryId': 'offering'}, {'id': '1', 'name': 'Prospectus', 'documents': [{'effectiveDate': '2025-05-08', 'postedDate': '2025-06-23', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2016-05-02', 'postedDate': '2017-11-28', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en', 'fr', 'nl'], 'effectiveDate': '2025-05-08', 'postedDate': '2025-06-23', 'categoryId': 'offering'}, {'id': '51', 'name': 'Rulebook', 'documents': [{'effectiveDate': '2013-09-23', 'postedDate': '2025-07-01', 'mimeType': 'application/pdf', 'languages': ['en']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en'], 'effectiveDate': '2017-10-02', 'postedDate': '2017-12-02', 'categoryId': 'other'}, {'id': '5', 'name': 'Semi-Annual Report', 'documents': [{'effectiveDate': '2024-06-30', 'postedDate': '2024-11-13', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-06-30', 'postedDate': '2013-04-21', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en', 'fr'], 'effectiveDate': '2024-06-30', 'postedDate': '2024-11-13', 'categoryId': 'shareholder'}, {'id': '2', 'name': 'Supplement to Prospectus', 'documents': [{'effectiveDate': '2012-04-03', 'postedDate': '2012-04-28', 'mimeType': 'application/pdf', 'languages': ['en']}], 'mimeType': 'application/pdf', 'languages': ['en', 'nl'], 'effectiveDate': '2012-04-03', 'postedDate': '2012-04-28', 'categoryId': 'offering'}]}}}
# {'status': 200,
#  'mesage': 'File downloaded',
#  'filename': 'PRIIP KID-F0000022KV-2025-03-19-20250718151738.pdf',
#  'folder': '.'}

# %% [markdown]
# Yield and growth forecast for the Equity fund, category and benchmark
#
# Style Measures - Measures
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.equityStyle()
# Out:
# {'portfolioDate': '2025-05-31T05:00:00.000',
#  'assetType': 'EQUITY',
#  'fund': {'prospectiveEarningsYield': 21.7341,
#   'prospectiveBookValueYield': 3.79912,
#   'prospectiveRevenueYield': 2.54526,
#   'prospectiveCashFlowYield': 13.39386,
#   'prospectiveDividendYield': 1.46533,
#   'forecasted5YearEarningsGrowth': 9.30035,
#   'forecastedEarningsGrowth': 7.85485,
#   'forecastedBookValueGrowth': 7.06073,
#   'forecastedRevenueGrowth': 6.89831,
#   'forecastedCashFlowGrowth': 6.25046,
#   'portfolioDate': '2025-05-31T05:00:00.000',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'secId': 'FOUSA00L83',
#   'currencyId': 'USD'},
#  'categoryAverage': {'prospectiveEarningsYield': 23.9956,
#   'prospectiveBookValueYield': 4.81279,
#   'prospectiveRevenueYield': 2.75717,
#   'prospectiveCashFlowYield': 15.41436,
#   'prospectiveDividendYield': 1.30523,
#   'forecasted5YearEarningsGrowth': 8.65896,
#   'forecastedEarningsGrowth': 13.12778,
#   'forecastedBookValueGrowth': 9.62229,
#   'forecastedRevenueGrowth': 8.45043,
#   'forecastedCashFlowGrowth': 11.11817,
#   'portfolioDate': '2025-06-30T05:00:00.000',
#   'name': 'Large Blend',
#   'secId': '$FOCA$LB$$',
#   'currencyId': ''},
#  'indexAverage': {'prospectiveEarningsYield': 23.56842,
#   'prospectiveBookValueYield': 4.46804,
#   'prospectiveRevenueYield': 3.05913,
#   'prospectiveCashFlowYield': 15.01953,
#   'prospectiveDividendYield': 1.36093,
#   'forecasted5YearEarningsGrowth': 9.43963,
#   'forecastedEarningsGrowth': 9.67751,
#   'forecastedBookValueGrowth': 8.84745,
#   'forecastedRevenueGrowth': 8.1357,
#   'forecastedCashFlowGrowth': 7.53645,
#   'portfolioDate': '2025-06-30T05:00:00.000',
#   'name': 'Morningstar US Large-Mid TR USD',
#   'secId': 'F00000GWXD',
#   'currencyId': ''}}

# %% [markdown]
# Historical equity exposure and style
# 1 = Large Value, 2 = Large Blend, 3 = Large Growth,
# 4 = Mid Value, 5 = Mid Blend, 6 = Mid Growth
# 7 = Small Value, 8 = Small Blend, 9 = Small Growth
#
# Stock Style - historical
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.equityStyleBoxHistory()
# Out:
# {'history': [{'year': 2025,
#    'portfolioDate': '2025-05-31T05:00:00.000',
#    'style': 2,
#    'percentage': 99.57476,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2024,
#    'portfolioDate': '2024-12-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.61408,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2023,
#    'portfolioDate': '2023-12-31T06:00:00.000',
#    'style': 3,
#    'percentage': 99.54633,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2022,
#    'portfolioDate': '2022-12-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.02589,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2021,
#    'portfolioDate': '2021-12-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.37405,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'}],
#  'secId': 'FOUSA00L83',
#  'masterPortfolioId': '3506',
#  'asOfDate': '2025-05-31T05:00:00.000'}

# %% [markdown]
# Environment, Social and Governance data

# %%
funds.esgData()
# Out:
# {'userType': 'Free',
#  'esgData': {'sociallyResponsibleFund': None,
#   'ethicalIssueStrategyFocus': None,
#   'portfolioDate': '2025-05-31T00:00:00.000',
#   'portfolioDateSustainabilityRating': '2025-05-31T05:00:00.000',
#   'fundESGScore': None,
#   'percentAUMCoveredESG': 99.38205,
#   'fundSustainabilityScore': 21.18,
#   'percentAUMCoveredControversy': 99.78497,
#   'categoryRankDate': '2025-04-30T05:00:00.000',
#   'sustainabilityFundQuintile': 3,
#   'sustainabilityPercentCategoryRank': 69.0,
#   'sustainabilityMandate': 'No',
#   'secId': 'FOUSA00L83',
#   'performanceId': '0P00002YGZ',
#   'tradingSymbol': None,
#   'iSIN': None,
#   'fundId': 'FSUSA002PT',
#   'masterPortfolioId': '3506',
#   'categoryId': '$FOCA$LB$$',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'controversyDeduction': None,
#   'categoryName': 'Large Blend',
#   'globalCategoryName': 'US Equity Large Cap Blend',
#   'fundHistoryAvgSustainabilityScore': 20.95822,
#   'historicalSustainabilityScoreGlobalCategoryAverage': None,
#   'currentSustainabilityScoreGlobalCategoryAverage': None,
#   'numberofFundsAnalyzedinCategorySustainability': None,
#   'HistoryAvgSustainabilityPercentCategoryRank': None,
#   'sustainabilityRatingCorporateContributionPercent': 100.0,
#   'sustainabilityRatingSovereignContributionPercent': 0.0,
#   'portfolioSovereignsustainabilityscore': None,
#   'historicalSovereignSustainabilityScore': None,
#   'historicalSovereignSustainabilityCategoryAverage': 13.32153,
#   'sovereignSustainabilityRatingPercentOfEligiblePortfolioCovered': None,
#   'sustainabilityMandateSurveyed': None},
#  'esgScoreCalculation': {'basedPercentAUM': 99.38205,
#   'portfolioESGScore': None,
#   'portfolioESGScoreCategory': None,
#   'controversyScore': None,
#   'controversyScoreCategory': None,
#   'sustainabilityScore': 21.18,
#   'sustainabilityScoreCategory': None,
#   'environmentalScore': 4.66,
#   'environmentalScoreCategory': None,
#   'socialScore': 9.2,
#   'socialScoreCategory': None,
#   'governanceScore': 6.12,
#   'governanceScoreCategory': None,
#   'portfolioDate': '2025-05-31T05:00:00.000',
#   'portfolioSustainabilityScore': 21.18,
#   'portfolioEnvironmentalRiskScore': 4.66,
#   'portfolioSocialRiskScore': 9.2,
#   'portfolioGovernanceRiskScore': 6.12,
#   'portfolioUnallocatedEsgRiskScore': 1.2,
#   'percentAUMCoveredControversy': 99.78497,
#   'esgFundQuintile': None,
#   'esgPercentCategoryRank': None,
#   'controversyFundQuintile': None,
#   'controversyPercentCategoryRank': None,
#   'ePercentCategoryRank': None,
#   'sPercentCategoryRank': None,
#   'gPercentCategoryRank': None,
#   'categoryRankDate': '2025-04-30T05:00:00.000',
#   'historicalSustainabilityScoreGlobalCategoryAverage': None,
#   'currentSustainabilityScoreGlobalCategoryAverage': None,
#   'HistoryAvgSustainabilityPercentCategoryRank': 69.0,
#   'numberofFundsAnalyzedinCategorySustainability': None},
#  'esgHoldingsAnalyst': '_PO_',
#  'esgScoreDistribution': '_PO_',
#  'esgLevelDistribution': '_PO_',
#  'sustainabilityIntentionality': {'investmentId': 'FSUSA002PT',
#   'eSGIncorporation': False,
#   'eSGEngagement': False,
#   'genderDiversity': False,
#   'lowCarbonFossilFuelFree': False,
#   'communityDevelopment': False,
#   'environmental': False,
#   'otherImpactThemes': False,
#   'renewableEnergy': False,
#   'waterFocused': False,
#   'generalEnvironmentalSector': False,
#   'sustainableInvestmentOverall': False,
#   'eSGFundOverall': False,
#   'impactFundOverall': False,
#   'environmentalSectorOverall': False,
#   'createdOn': '2019-05-01 04:01:00.0',
#   'lastUpdateDate': '2025-06-03 04:04:00.0',
#   'usesNormsBasedScreening': None,
#   'excludesAbortionStemCells': None,
#   'excludesAdultEntertainment': None,
#   'excludesAlcohol': None,
#   'excludesAnimalTesting': None,
#   'excludesControversialWeapons': None,
#   'excludesFurSpecialtyLeather': None,
#   'excludesGambling': None,
#   'excludesGMOs': None,
#   'excludesMilitaryContracting': None,
#   'excludesNuclear': None,
#   'excludesPalmOil': None,
#   'excludesPesticides': None,
#   'excludesSmallArms': None,
#   'excludesThermalCoal': None,
#   'excludesTobacco': None,
#   'excludesOther': None,
#   'employsExclusionsOverall': None}}

# %% [markdown]
# Environment, Social and Governance risk
#
# Sustainability - Risk
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.esgRisk()
# Out:
# {'sustainabilityFundQuintile': 3,
#  'fundHistoryAvgSustainabilityScore': 20.95822,
#  'fundSustainabilityScore': 21.18,
#  'historicalSustainabilityScoreGlobalCategoryAverage': None,
#  'historicalSovereignSustainabilityScore': None,
#  'portfolioSovereignSustainabilityScore': None,
#  'historicalSovereignSustainabilityCategoryAverage': 13.32153,
#  'percentAUMCoveredESG': 99.38205,
#  'sovereignSustainabilityRatingPercentOfEligiblePortfolioCovered': None,
#  'globalCategoryName': 'US Equity Large Cap Blend',
#  'categoryRankDate': '2025-04-30T00:00:00.000',
#  'portfolioDateSustainabilityRating': '2025-05-31T05:00:00.000',
#  'categoryId': '$FOCA$LB$$',
#  'portfolioDate': '2025-05-31T00:00:00.000',
#  'carbon': {'carbonPortfolioCoveragePct': None,
#   'carbonRiskScore': None,
#   'carbonRiskScoreCategoryAverage': '7.40205',
#   'carbonRiskScoreCategoryHigh': '28.40655',
#   'carbonRiskScoreCategoryLow': '0.00000',
#   'carbonRiskScoreCategoryAverageDate': '2022-12-31T06:00:00.000',
#   'carbonRiskScoreCategoryRankPct': None,
#   'carbonRiskScoreDate': '2025-05-31T05:00:00.000',
#   'categoryDate': '2022-12-31T06:00:00.000',
#   'categoryName': 'Large Blend',
#   'fossilFuelInvolvementPctCategoryAverage': '8.78908',
#   'fossilFuelInvolvementPct': '8.32994',
#   'fossilFuelInvolvementPctCategoryHigh': '100.00000',
#   'fossilFuelInvolvementPctCategoryLow': '0.00000',
#   'isLowCarbon': None,
#   'fossilFuelPercentageOfPortfolioCovered': '97.17163',
#   'portfolioCarbonRiskScore': '7.24337',
#   'carbonRiskPercentageOfPortfolioCovered': '98.05256',
#   'isDesignatedLowCarbon': 'false'}}

# %% [markdown]
# Factor Style, Yield, Momemtum, Quality, Volatility, Liquidity and Size
# of the fund, category and benchmark
#
# Factor Profile
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.factorProfile()
# Out:
# {'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryId': '$FOCA$LB$$',
#  'categoryName': 'Large Blend',
#  'indexId': 'F00000GWXD',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'indexEffectiveDate': '2025-05-31',
#  'categoryEffectiveDate': '2025-05-31',
#  'ticker': 'VTSAX',
#  'id': '0P00002YGZ',
#  'effectiveDate': '2025-05-31',
#  'factors': {'style': {'categoryAvg': 55.066489,
#    'indexAvg': 48.426103,
#    'percentile': 55.319119,
#    'historicRange': [{'year': '1', 'min': 47.602372, 'max': 55.319119},
#     {'year': '3', 'min': 45.830953, 'max': 55.319119},
#     {'year': '5', 'min': 42.202135, 'max': 55.319119}]},
#   'yield': {'categoryAvg': 61.516488,
#    'indexAvg': 59.544265,
#    'percentile': 54.289072,
#    'historicRange': [{'year': '1', 'min': 54.289072, 'max': 57.726217},
#     {'year': '3', 'min': 50.244824, 'max': 57.726217},
#     {'year': '5', 'min': 47.466716, 'max': 57.726217}]},
#   'quality': {'categoryAvg': 19.578681,
#    'indexAvg': 33.152359,
#    'percentile': 45.963265,
#    'historicRange': [{'year': '1', 'min': 40.065672, 'max': 45.963265},
#     {'year': '3', 'min': 39.075409, 'max': 45.963265},
#     {'year': '5', 'min': 39.075409, 'max': 49.795959}]},
#   'momentum': {'categoryAvg': 58.929166,
#    'indexAvg': 38.915253,
#    'percentile': 46.922527,
#    'historicRange': [{'year': '1', 'min': 40.175431, 'max': 47.764934},
#     {'year': '3', 'min': 34.52498, 'max': 60.363224},
#     {'year': '5', 'min': 34.52498, 'max': 60.363224}]},
#   'volatility': {'categoryAvg': 64.120896,
#    'indexAvg': 51.551637,
#    'percentile': 49.923576,
#    'historicRange': [{'year': '1', 'min': 42.729427, 'max': 49.987509},
#     {'year': '3', 'min': 42.729427, 'max': 52.434263},
#     {'year': '5', 'min': 42.729427, 'max': 55.93316}]},
#   'liquidity': {'categoryAvg': 78.781981,
#    'indexAvg': 68.335058,
#    'percentile': 58.844956,
#    'historicRange': [{'year': '1', 'min': 55.748166, 'max': 62.325967},
#     {'year': '3', 'min': 53.11791, 'max': 63.463423},
#     {'year': '5', 'min': 51.07554, 'max': 63.463423}]},
#   'size': {'categoryAvg': 86.308404,
#    'indexAvg': 76.815861,
#    'percentile': 59.207425,
#    'historicRange': [{'year': '1', 'min': 59.207425, 'max': 60.712472},
#     {'year': '3', 'min': 56.561866, 'max': 62.14024},
#     {'year': '5', 'min': 54.800434, 'max': 62.14024}]}}}

# %% [markdown]
# Ongoing Fee Level
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.feeLevel()
# Out:
# {'morningstarFeeLevelRankDate': '2025-06-30T05:00:00.000',
#  'morningstarFeeLevelGroup': 'IC00000272',
#  'name': 'Large Cap Institutional',
#  'morningstarFeeLevel': 1,
#  'morningstarFeeLevelPercentileRank': 3.0,
#  'morningstarFeeLevelGroupSize': 938.0,
#  'median': 0.69,
#  'morningstarFeeLevelGroupStartingDistribution': 0.0,
#  'morningstarFeeLevelGroup1stBreakpointDistribution': 0.48,
#  'morningstarFeeLevelGroup2ndBreakpointDistribution': 0.65,
#  'morningstarFeeLevelGroup3rdBreakpointDistribution': 0.73,
#  'morningstarFeeLevelGroup4thBreakpointDistribution': 0.85,
#  'morningstarFeeLevelGroupEndBreakpointDistribution': 1.5,
#  'fundFee': None,
#  'reportDate': '2024-12-31T06:00:00.000',
#  'peerMedian': None,
#  'fundIndex': None,
#  'prospectusExpenseRatio': 0.04,
#  'adjustedProspectusExpenseRatio': 0.04,
#  'icrFund': None,
#  'priceTemplate': 'USA_OE',
#  'morningstarTotalCostRatioPDS': None}

# %% [markdown]
# MiFID fees
#
# Price
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/quote

# %%
#ms.Funds("IE00B04GQT48").feeMifid()

# %% [markdown]
# Financial metrics of fund, category and benchmark

# %%
ms.Funds("IE00B04GQT48").financialMetrics()
# Out:
# {'userType': 'Free',
#  'fund': {'masterPortfolioId': '107906',
#   'portfolioDate': '2025-06-30T05:00:00.000',
#   'wideMoatPercentage': '_PO_',
#   'narrowMoatPercentage': '_PO_',
#   'noMoatPercentage': '_PO_',
#   'financialHealthGradeType': '_PO_',
#   'profitabilityGradeType': '_PO_',
#   'growthGradeType': '_PO_',
#   'roic': '_PO_',
#   'cashReturn': '_PO_',
#   'freeCashFlowYield': '_PO_',
#   'debtToCapital': '_PO_',
#   'securityName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc'},
#  'category': {'masterPortfolioId': '211369',
#   'portfolioDate': '2025-06-30T05:00:00.000',
#   'wideMoatPercentage': '_PO_',
#   'narrowMoatPercentage': '_PO_',
#   'noMoatPercentage': '_PO_',
#   'financialHealthGradeType': '_PO_',
#   'profitabilityGradeType': '_PO_',
#   'growthGradeType': '_PO_',
#   'roic': '_PO_',
#   'cashReturn': '_PO_',
#   'freeCashFlowYield': '_PO_',
#   'debtToCapital': '_PO_',
#   'securityName': 'USD Corporate Bond'},
#  'index': {'masterPortfolioId': '1861103',
#   'portfolioDate': '2025-06-30T05:00:00.000',
#   'wideMoatPercentage': '_PO_',
#   'narrowMoatPercentage': '_PO_',
#   'noMoatPercentage': '_PO_',
#   'financialHealthGradeType': '_PO_',
#   'profitabilityGradeType': '_PO_',
#   'growthGradeType': '_PO_',
#   'roic': '_PO_',
#   'cashReturn': '_PO_',
#   'freeCashFlowYield': '_PO_',
#   'debtToCapital': '_PO_',
#   'securityName': 'Morningstar US Corp Bd TR USD'}}

# %% [markdown]
# Fixed Income metrics for the fund, category and benchmark
#
# Fixed Income style - Current
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
ms.Funds("IE00B04GQT48").fixedIncomeStyle()
# Out:
# {'isCan': False,
#  'portfolioDate': '2025-06-30T05:00:00.000',
#  'assetType': 'FIXEDINCOME',
#  'fixedIncStyleBox': 6,
#  'fund': {'secId': 'F0000022KV',
#   'secName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'portfolioDate': '2025-06-30T05:00:00.000',
#   'avgEffectiveDuration': 6.113,
#   'modifiedDuration': 6.2017,
#   'avgEffectiveMaturity': 9.3482,
#   'avgCreditQualityName': 'A-',
#   'surveyedAverageSurveyedCreditRating': 'A-',
#   'calculatedAverageCreditRating': 'A-',
#   'avgCreditQualityDate': '2025-06-30T05:00:00.000',
#   'avgCoupon': 4.39836,
#   'avgPrice': 95.80448,
#   'yieldToMaturity': 4.9532},
#  'categoryAverage': {'secId': 'EUCA000691',
#   'secName': 'USD Corporate Bond',
#   'portfolioDate': '2025-06-30T05:00:00.000',
#   'avgEffectiveDuration': 5.96736,
#   'modifiedDuration': 5.57272,
#   'avgEffectiveMaturity': 8.76374,
#   'avgCreditQualityName': 'A-',
#   'surveyedAverageSurveyedCreditRating': 'A-',
#   'calculatedAverageCreditRating': 'A-',
#   'avgCreditQualityDate': '2025-06-30T05:00:00.000',
#   'avgCoupon': 5.26549,
#   'avgPrice': 98.96648,
#   'yieldToMaturity': 5.14106}}

# %% [markdown]
# Historical Fixed Income Style
#
# Fixed Income Style - Historical
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
ms.Funds("IE00B04GQT48").fixedincomeStyleBoxHistory()
# Out:
# {'history': [{'year': 2025,
#    'portfolioDate': '2025-06-30T05:00:00.000',
#    'style': 6,
#    'percentage': 99.94675,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2024,
#    'portfolioDate': '2024-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.95603,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2023,
#    'portfolioDate': '2023-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.89898,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2022,
#    'portfolioDate': '2022-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.86471,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2021,
#    'portfolioDate': '2021-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 96.70474,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'}],
#  'secId': 'F0000022KV',
#  'masterPortfolioId': '107906',
#  'asOfDate': '2025-06-30T05:00:00.000'}

# %% [markdown]
# Available documents and their countries
#
# https://global.morningstar.com/fr/investissements/fonds/0P0000GFVM/documents

# %%
ms.Funds("IE00B04GQT48").getDocumentInformation("fr")
# Out:
# {'page': {'name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc', 'performanceID': '0P0000GFVM', 'securityID': 'F0000022KV', 'masterPortfolioID': '107906', 'fundID': 'FSGBR065UB', 'ticker': None, 'exchange': None, 'exchangeCountry': None, 'investmentType': 'FO', 'cusip': None, 'isin': 'IE00B04GQT48', 'universe': 'FO', 'fundStarRating': 3, 'medalistRating': 'Gold', 'countriesOfSale': ['AUT', 'CHE', 'DEU', 'DNK', 'ESP', 'FIN', 'FRA', 'GBR', 'IRL', 'ITA', 'LIE', 'LUX', 'NLD', 'NOR', 'PRT', 'SWE'], 'allowedMarketIds': ['at', 'bnl', 'eu', 'dk', 'fi', 'fr', 'de', 'ie', 'it', 'lu', 'nl', 'nord', 'no', 'pt', 'es', 'se', 'ch', 'gb']}, 'components': {'ads': {'status': 200, 'payload': {'fundcat': 'USDCorporateBond', 'familyid': '0C000022HA', 'brandingNameId': 'BN00000AAL', 'sustainabilityRating': 3}}, 'documents': {'status': 200, 'payload': [{'id': '4', 'name': 'Annual Report', 'documents': [{'effectiveDate': '2024-12-31', 'postedDate': '2025-05-08', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-12-31', 'postedDate': '2013-05-08', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en', 'fr'], 'effectiveDate': '2024-12-31', 'postedDate': '2025-05-08', 'categoryId': 'shareholder'}, {'id': '52', 'name': 'Factsheet', 'documents': [{'effectiveDate': '2025-06-30', 'postedDate': '2025-07-18', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2025-06-30', 'postedDate': '2025-07-18', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en', 'fr', 'nl'], 'effectiveDate': '2025-06-30', 'postedDate': '2025-07-18', 'categoryId': 'other'}, {'id': '109', 'name': 'Information Memorandum', 'documents': [{'effectiveDate': '2020-06-19', 'postedDate': '2020-07-09', 'mimeType': 'application/pdf', 'languages': ['en']}], 'mimeType': 'application/pdf', 'languages': ['en'], 'effectiveDate': '2020-06-19', 'postedDate': '2020-07-09', 'categoryId': 'other'}, {'id': '299', 'name': 'PRIIP KID', 'documents': [{'effectiveDate': '2025-03-19', 'postedDate': '2025-03-21', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2025-03-19', 'postedDate': '2025-03-21', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'no', 'sv', 'fi', 'pt', 'en', 'it', 'fr', 'da', 'nl', 'es'], 'effectiveDate': '2025-03-19', 'postedDate': '2025-03-21', 'categoryId': 'offering'}, {'id': '1', 'name': 'Prospectus', 'documents': [{'effectiveDate': '2025-05-08', 'postedDate': '2025-06-23', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2016-05-02', 'postedDate': '2017-11-28', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en', 'fr', 'nl'], 'effectiveDate': '2025-05-08', 'postedDate': '2025-06-23', 'categoryId': 'offering'}, {'id': '51', 'name': 'Rulebook', 'documents': [{'effectiveDate': '2013-09-23', 'postedDate': '2025-07-01', 'mimeType': 'application/pdf', 'languages': ['en']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en'], 'effectiveDate': '2017-10-02', 'postedDate': '2017-12-02', 'categoryId': 'other'}, {'id': '5', 'name': 'Semi-Annual Report', 'documents': [{'effectiveDate': '2024-06-30', 'postedDate': '2024-11-13', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-06-30', 'postedDate': '2013-04-21', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf', 'languages': ['de', 'en', 'fr'], 'effectiveDate': '2024-06-30', 'postedDate': '2024-11-13', 'categoryId': 'shareholder'}, {'id': '2', 'name': 'Supplement to Prospectus', 'documents': [{'effectiveDate': '2012-04-03', 'postedDate': '2012-04-28', 'mimeType': 'application/pdf', 'languages': ['en']}], 'mimeType': 'application/pdf', 'languages': ['en', 'nl'], 'effectiveDate': '2012-04-03', 'postedDate': '2012-04-28', 'categoryId': 'offering'}]}}}
# {'page': {'name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'performanceID': '0P0000GFVM',
#   'securityID': 'F0000022KV',
#   'masterPortfolioID': '107906',
#   'fundID': 'FSGBR065UB',
#   'ticker': None,
#   'exchange': None,
#   'exchangeCountry': None,
#   'investmentType': 'FO',
#   'cusip': None,
#   'isin': 'IE00B04GQT48',
#   'universe': 'FO',
#   'fundStarRating': 3,
#   'medalistRating': 'Gold',
#   'countriesOfSale': ['AUT',
#    'CHE',
#    'DEU',
#    'DNK',
#    'ESP',
#    'FIN',
#    'FRA',
#    'GBR',
#    'IRL',
#    'ITA',
#    'LIE',
#    'LUX',
#    'NLD',
#    'NOR',
#    'PRT',
#    'SWE'],
#   'allowedMarketIds': ['at',
#    'bnl',
#    'eu',
#    'dk',
#    'fi',
#    'fr',
#    'de',
#    'ie',
#    'it',
#    'lu',
#    'nl',
#    'nord',
#    'no',
#    'pt',
#    'es',
#    'se',
#    'ch',
#    'gb']},
#  'components': {'ads': {'status': 200,
#    'payload': {'fundcat': 'USDCorporateBond',
#     'familyid': '0C000022HA',
#     'brandingNameId': 'BN00000AAL',
#     'sustainabilityRating': 3}},
#   'documents': {'status': 200,
#    'payload': [{'id': '4',
#      'name': 'Annual Report',
#      'documents': [{'effectiveDate': '2024-12-31',
#        'postedDate': '2025-05-08',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2012-12-31',
#        'postedDate': '2013-05-08',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf',
#      'languages': ['de', 'en', 'fr'],
#      'effectiveDate': '2024-12-31',
#      'postedDate': '2025-05-08',
#      'categoryId': 'shareholder'},
#     {'id': '52',
#      'name': 'Factsheet',
#      'documents': [{'effectiveDate': '2025-06-30',
#        'postedDate': '2025-07-18',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2025-06-30',
#        'postedDate': '2025-07-18',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf',
#      'languages': ['de', 'en', 'fr', 'nl'],
#      'effectiveDate': '2025-06-30',
#      'postedDate': '2025-07-18',
#      'categoryId': 'other'},
#     {'id': '109',
#      'name': 'Information Memorandum',
#      'documents': [{'effectiveDate': '2020-06-19',
#        'postedDate': '2020-07-09',
#        'mimeType': 'application/pdf',
#        'languages': ['en']}],
#      'mimeType': 'application/pdf',
#      'languages': ['en'],
#      'effectiveDate': '2020-06-19',
#      'postedDate': '2020-07-09',
#      'categoryId': 'other'},
#     {'id': '299',
#      'name': 'PRIIP KID',
#      'documents': [{'effectiveDate': '2025-03-19',
#        'postedDate': '2025-03-21',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2025-03-19',
#        'postedDate': '2025-03-21',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf',
#      'languages': ['de',
#       'no',
#       'sv',
#       'fi',
#       'pt',
#       'en',
#       'it',
#       'fr',
#       'da',
#       'nl',
#       'es'],
#      'effectiveDate': '2025-03-19',
#      'postedDate': '2025-03-21',
#      'categoryId': 'offering'},
#     {'id': '1',
#      'name': 'Prospectus',
#      'documents': [{'effectiveDate': '2025-05-08',
#        'postedDate': '2025-06-23',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2016-05-02',
#        'postedDate': '2017-11-28',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf',
#      'languages': ['de', 'en', 'fr', 'nl'],
#      'effectiveDate': '2025-05-08',
#      'postedDate': '2025-06-23',
#      'categoryId': 'offering'},
#     {'id': '51',
#      'name': 'Rulebook',
#      'documents': [{'effectiveDate': '2013-09-23',
#        'postedDate': '2025-07-01',
#        'mimeType': 'application/pdf',
#        'languages': ['en']}],
#      'mimeType': 'application/pdf',
#      'languages': ['de', 'en'],
#      'effectiveDate': '2017-10-02',
#      'postedDate': '2017-12-02',
#      'categoryId': 'other'},
#     {'id': '5',
#      'name': 'Semi-Annual Report',
#      'documents': [{'effectiveDate': '2024-06-30',
#        'postedDate': '2024-11-13',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2012-06-30',
#        'postedDate': '2013-04-21',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf',
#      'languages': ['de', 'en', 'fr'],
#      'effectiveDate': '2024-06-30',
#      'postedDate': '2024-11-13',
#      'categoryId': 'shareholder'},
#     {'id': '2',
#      'name': 'Supplement to Prospectus',
#      'documents': [{'effectiveDate': '2012-04-03',
#        'postedDate': '2012-04-28',
#        'mimeType': 'application/pdf',
#        'languages': ['en']}],
#      'mimeType': 'application/pdf',
#      'languages': ['en', 'nl'],
#      'effectiveDate': '2012-04-03',
#      'postedDate': '2012-04-28',
#      'categoryId': 'offering'}]}}}

# %% [markdown]
# Historical Total Assets and Net flow
#
# chart Fund flows
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.graphData()
# Out:
# {'startYear': 2015,
#  'latestDate': '2025-06-30T05:00:00.000',
#  'endYear': 2025,
#  'secId': 'FOUSA00L83',
#  'currency': 'USD',
#  'data': [{'yr': 2015,
#    'naQ1': 2.3561537711,
#    'naQ2': 2.4007285133,
#    'naQ3': 2.2925798402,
#    'naQ4': 2.4099261165,
#    'naYr': 2.4099261165,
#    'nfQ1': 60.902337337,
#    'nfQ2': 37.395808427,
#    'nfQ3': 23.699594815,
#    'nfQ4': 31.712889239,
#    'nfYr': 153.710629912,
#    'numFund': 133,
#    'industryMarketShare': 19.61607874,
#    'growthRate': 6.84018472,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2016,
#    'naQ1': 2.4945725779,
#    'naQ2': 2.5996820759,
#    'naQ3': 2.7346545656,
#    'naQ4': 2.7925682151,
#    'naYr': 2.7925682151,
#    'nfQ1': 55.2679087,
#    'nfQ2': 47.781899606,
#    'nfQ3': 46.422851327,
#    'nfQ4': 33.477700948,
#    'nfYr': 182.950360656,
#    'numFund': 137,
#    'industryMarketShare': 22.55791388,
#    'growthRate': 7.59153401,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2017,
#    'naQ1': 2.9992043692,
#    'naQ2': 3.1367856448,
#    'naQ3': 3.2933485512,
#    'naQ4': 3.4662529642,
#    'naYr': 3.4662529642,
#    'nfQ1': 76.544077209,
#    'nfQ2': 49.740152883,
#    'nfQ3': 45.596475009,
#    'nfQ4': 35.127845853,
#    'nfYr': 207.008551027,
#    'numFund': 141,
#    'industryMarketShare': 23.80576336,
#    'growthRate': 7.41283776,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2018,
#    'naQ1': 3.4775429338,
#    'naQ2': 3.5487050769,
#    'naQ3': 3.7130380885,
#    'naQ4': 3.3519682965,
#    'naYr': 3.3519682965,
#    'nfQ1': 39.248219558,
#    'nfQ2': 13.009449995,
#    'nfQ3': 17.920404999,
#    'nfQ4': 5.66131066,
#    'nfYr': 75.83938518,
#    'numFund': 141,
#    'industryMarketShare': 24.93654446,
#    'growthRate': 2.18793567,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2019,
#    'naQ1': 3.7386327959,
#    'naQ2': 3.8794341613,
#    'naQ3': 3.9250090712,
#    'naQ4': 4.1801009687,
#    'naYr': 4.1801009687,
#    'nfQ1': 45.451464525,
#    'nfQ2': 15.283373037,
#    'nfQ3': 5.873646387,
#    'nfQ4': 10.649513687,
#    'nfYr': 77.257997677,
#    'numFund': 145,
#    'industryMarketShare': 25.73961721,
#    'growthRate': 2.30485467,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2020,
#    'naQ1': 3.5116894508,
#    'naQ2': 4.0330797614,
#    'naQ3': 4.2458626145,
#    'naQ4': 4.6431199711,
#    'naYr': 4.6431199711,
#    'nfQ1': -21.871656289,
#    'nfQ2': -12.506920755,
#    'nfQ3': -13.738040151,
#    'nfQ4': -11.537860333,
#    'nfYr': -59.654477566,
#    'numFund': 143,
#    'industryMarketShare': 25.69265786,
#    'growthRate': -1.42710614,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2021,
#    'naQ1': 4.7898002858,
#    'naQ2': 5.0998775849,
#    'naQ3': 5.0752681636,
#    'naQ4': 5.3260283229,
#    'naYr': 5.3260283229,
#    'nfQ1': 30.984857242,
#    'nfQ2': 23.482260306,
#    'nfQ3': 0.43701705,
#    'nfQ4': -20.833309666,
#    'nfYr': 34.070824927,
#    'numFund': 148,
#    'industryMarketShare': 25.83594065,
#    'growthRate': 0.73379161,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2022,
#    'naQ1': 5.0096266344,
#    'naQ2': 4.3528344385,
#    'naQ3': 4.1135320631,
#    'naQ4': 4.3508557423,
#    'naYr': 4.3508557423,
#    'nfQ1': -24.924057561,
#    'nfQ2': -25.609908708,
#    'nfQ3': -19.028184639,
#    'nfQ4': -36.838683651,
#    'nfYr': -106.400834657,
#    'numFund': 148,
#    'industryMarketShare': 26.91862258,
#    'growthRate': -1.99775195,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2023,
#    'naQ1': 4.5911608054,
#    'naQ2': 4.7857922788,
#    'naQ3': 4.605537003,
#    'naQ4': 5.0312120502,
#    'naYr': 5.0312120502,
#    'nfQ1': 6.347599815,
#    'nfQ2': -25.736576458,
#    'nfQ3': -22.906856568,
#    'nfQ4': -38.386126797,
#    'nfYr': -80.681960095,
#    'numFund': 149,
#    'industryMarketShare': 27.47761159,
#    'growthRate': -1.8543929,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2024,
#    'naQ1': 5.3558837273,
#    'naQ2': 5.4308621783,
#    'naQ3': 5.7172046904,
#    'naQ4': 5.6735103501,
#    'naYr': 5.6735103501,
#    'nfQ1': 4.694823732,
#    'nfQ2': -22.445750849,
#    'nfQ3': -35.720628276,
#    'nfQ4': -30.512048781,
#    'nfYr': -83.983604278,
#    'numFund': 148,
#    'industryMarketShare': 27.95184283,
#    'growthRate': -1.66925193,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2025,
#    'naQ1': 5.5306047054,
#    'naQ2': 5.952615842,
#    'naQ3': None,
#    'naQ4': None,
#    'naYr': 5.952615842,
#    'nfQ1': -34.103414022,
#    'nfQ2': -29.338252349,
#    'nfQ3': None,
#    'nfQ4': None,
#    'nfYr': -63.441666406,
#    'numFund': 149,
#    'industryMarketShare': None,
#    'growthRate': -1.11820835,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'}]}

# %% [markdown]
# Historical performance
#
# Performance - Returns
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.historicalData()
# Out:
# {'userType': 'Free',
#  'baseCurrency': 'USD',
#  'domicileCountryId': 'USA',
#  'asOfDate': '2025-07-17T00:00:00.000',
#  'startDate': '2015-01-01T00:00:00.000',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'graphData': {'fund': [{'date': '2015-01-31', 'value': 9722.867907967722},
#    {'date': '2015-02-28', 'value': 10282.946626904615},
#    {'date': '2015-03-31', 'value': 10179.189316322805},
#    {'date': '2015-04-30', 'value': 10222.024053041712},
#    {'date': '2015-05-31', 'value': 10364.158788519986},
#    {'date': '2015-06-30', 'value': 10187.715307816843},
#    {'date': '2015-07-31', 'value': 10355.880923706878},
#    {'date': '2015-08-31', 'value': 9734.059019173168},
#    {'date': '2015-09-30', 'value': 9447.49362904852},
#    {'date': '2015-10-31', 'value': 10190.401353874837},
#    {'date': '2015-11-30', 'value': 10247.395753536068},
#    {'date': '2015-12-31', 'value': 10038.764562308274},
#    {'date': '2016-01-31', 'value': 9471.502127536814},
#    {'date': '2016-02-29', 'value': 9467.548542771436},
#    {'date': '2016-03-31', 'value': 10133.460764819105},
#    {'date': '2016-04-30', 'value': 10198.991619147668},
#    {'date': '2016-05-31', 'value': 10379.69809559783},
#    {'date': '2016-06-30', 'value': 10405.554091541706},
#    {'date': '2016-07-31', 'value': 10816.430948811018},
#    {'date': '2016-08-31', 'value': 10846.349645470322},
#    {'date': '2016-09-30', 'value': 10863.033922654133},
#    {'date': '2016-10-31', 'value': 10622.524431883323},
#    {'date': '2016-11-30', 'value': 11095.527127944131},
#    {'date': '2016-12-31', 'value': 11310.093927906644},
#    {'date': '2017-01-31', 'value': 11527.907301067797},
#    {'date': '2017-02-28', 'value': 11955.463951303795},
#    {'date': '2017-03-31', 'value': 11964.847923007786},
#    {'date': '2017-04-30', 'value': 12090.452339423548},
#    {'date': '2017-05-31', 'value': 12214.029889698722},
#    {'date': '2017-06-30', 'value': 12327.293740585947},
#    {'date': '2017-07-31', 'value': 12557.272794807754},
#    {'date': '2017-08-31', 'value': 12577.625161599977},
#    {'date': '2017-09-30', 'value': 12887.326122612549},
#    {'date': '2017-10-31', 'value': 13167.352029429618},
#    {'date': '2017-11-30', 'value': 13567.973482133608},
#    {'date': '2017-12-31', 'value': 13704.359451257382},
#    {'date': '2018-01-31', 'value': 14433.533513768267},
#    {'date': '2018-02-28', 'value': 13897.436388016917},
#    {'date': '2018-03-31', 'value': 13621.834908763372},
#    {'date': '2018-04-30', 'value': 13673.394437268866},
#    {'date': '2018-05-31', 'value': 14059.053552165124},
#    {'date': '2018-06-30', 'value': 14153.897733841088},
#    {'date': '2018-07-31', 'value': 14628.179926521621},
#    {'date': '2018-08-31', 'value': 15133.528775445504},
#    {'date': '2018-09-30', 'value': 15157.913948172318},
#    {'date': '2018-10-31', 'value': 14036.261771256797},
#    {'date': '2018-11-30', 'value': 14327.599863141695},
#    {'date': '2018-12-31', 'value': 12995.69320839906},
#    {'date': '2019-01-31', 'value': 14113.376853158781},
#    {'date': '2019-02-28', 'value': 14609.426930504053},
#    {'date': '2019-03-31', 'value': 14820.542378019205},
#    {'date': '2019-04-30', 'value': 15409.7445924452},
#    {'date': '2019-05-31', 'value': 14418.62199708795},
#    {'date': '2019-06-30', 'value': 15426.60076461881},
#    {'date': '2019-07-31', 'value': 15648.367722545345},
#    {'date': '2019-08-31', 'value': 15333.668354177222},
#    {'date': '2019-09-30', 'value': 15594.497327481331},
#    {'date': '2019-10-31', 'value': 15923.360843008904},
#    {'date': '2019-11-30', 'value': 16525.9230349899},
#    {'date': '2019-12-31', 'value': 16999.01242591513},
#    {'date': '2020-01-31', 'value': 16986.212975500777},
#    {'date': '2020-02-29', 'value': 15599.670619304765},
#    {'date': '2020-03-31', 'value': 13451.428679049784},
#    {'date': '2020-04-30', 'value': 15234.948314166046},
#    {'date': '2020-05-31', 'value': 16053.824656049339},
#    {'date': '2020-06-30', 'value': 16421.502060273557},
#    {'date': '2020-07-31', 'value': 17349.59898393619},
#    {'date': '2020-08-31', 'value': 18594.239783944442},
#    {'date': '2020-09-30', 'value': 17932.73853680892},
#    {'date': '2020-10-31', 'value': 17547.87761256095},
#    {'date': '2020-11-30', 'value': 19688.390257231138},
#    {'date': '2020-12-31', 'value': 20566.748244541104},
#    {'date': '2021-01-31', 'value': 20499.452103404255},
#    {'date': '2021-02-28', 'value': 21152.88175971442},
#    {'date': '2021-03-31', 'value': 21889.245517016036},
#    {'date': '2021-04-30', 'value': 23013.111402452363},
#    {'date': '2021-05-31', 'value': 23113.300770941558},
#    {'date': '2021-06-30', 'value': 23701.37894160817},
#    {'date': '2021-07-31', 'value': 24107.726739581038},
#    {'date': '2021-08-31', 'value': 24798.07943970006},
#    {'date': '2021-09-30', 'value': 23685.735002797403},
#    {'date': '2021-10-31', 'value': 25278.956421032715},
#    {'date': '2021-11-30', 'value': 24904.21039588014},
#    {'date': '2021-12-31', 'value': 25854.931689678426},
#    {'date': '2022-01-31', 'value': 24295.63038451714},
#    {'date': '2022-02-28', 'value': 23675.428777104662},
#    {'date': '2022-03-31', 'value': 24443.712686642462},
#    {'date': '2022-04-30', 'value': 22239.806664473388},
#    {'date': '2022-05-31', 'value': 22180.242808399424},
#    {'date': '2022-06-30', 'value': 20325.953258613325},
#    {'date': '2022-07-31', 'value': 22235.180447139228},
#    {'date': '2022-08-31', 'value': 21404.600298559177},
#    {'date': '2022-09-30', 'value': 19419.609272225014},
#    {'date': '2022-10-31', 'value': 21005.473584896918},
#    {'date': '2022-11-30', 'value': 22104.23383338832},
#    {'date': '2022-12-31', 'value': 20806.713650300717},
#    {'date': '2023-01-31', 'value': 22241.50618276384},
#    {'date': '2023-02-28', 'value': 21723.014093446003},
#    {'date': '2023-03-31', 'value': 22296.79060096133},
#    {'date': '2023-04-30', 'value': 22530.14776541745},
#    {'date': '2023-05-31', 'value': 22624.388072520553},
#    {'date': '2023-06-30', 'value': 24171.87944451312},
#    {'date': '2023-07-31', 'value': 25034.51726132119},
#    {'date': '2023-08-31', 'value': 24550.26814871039},
#    {'date': '2023-09-30', 'value': 23376.06244182663},
#    {'date': '2023-10-31', 'value': 22761.20004227122},
#    {'date': '2023-11-30', 'value': 24895.132845679705},
#    {'date': '2023-12-31', 'value': 26218.169718948702},
#    {'date': '2024-01-31', 'value': 26511.021981482878},
#    {'date': '2024-02-29', 'value': 27943.497668431308},
#    {'date': '2024-03-31', 'value': 28840.87770478635},
#    {'date': '2024-04-30', 'value': 27567.413851836387},
#    {'date': '2024-05-31', 'value': 28870.492969420182},
#    {'date': '2024-06-30', 'value': 29777.20466161276},
#    {'date': '2024-07-31', 'value': 30321.309104410666},
#    {'date': '2024-08-31', 'value': 30979.723715425007},
#    {'date': '2024-09-30', 'value': 31613.503532292572},
#    {'date': '2024-10-31', 'value': 31375.014928706183},
#    {'date': '2024-11-30', 'value': 33454.91142101702},
#    {'date': '2024-12-31', 'value': 32443.236163835958},
#    {'date': '2025-01-31', 'value': 33446.23147140168},
#    {'date': '2025-02-28', 'value': 32806.70737239674},
#    {'date': '2025-03-31', 'value': 30876.302721127584},
#    {'date': '2025-04-30', 'value': 30668.536983804956},
#    {'date': '2025-05-31', 'value': 32614.609489709546},
#    {'date': '2025-06-30', 'value': 34270.04045212269},
#    {'date': '2025-07-17', 'value': 34846.57176369192}],
#   'index': [{'date': '2015-01-31', 'value': 9727.833528062985},
#    {'date': '2015-02-28', 'value': 10287.522234063872},
#    {'date': '2015-03-31', 'value': 10158.274330959053},
#    {'date': '2015-04-30', 'value': 10234.152491802679},
#    {'date': '2015-05-31', 'value': 10369.474866150838},
#    {'date': '2015-06-30', 'value': 10172.493117578551},
#    {'date': '2015-07-31', 'value': 10374.338395055447},
#    {'date': '2015-08-31', 'value': 9748.732545098768},
#    {'date': '2015-09-30', 'value': 9487.318323525276},
#    {'date': '2015-10-31', 'value': 10254.469754137459},
#    {'date': '2015-11-30', 'value': 10271.002486703012},
#    {'date': '2015-12-31', 'value': 10092.191484772082},
#    {'date': '2016-01-31', 'value': 9553.890663093873},
#    {'date': '2016-02-29', 'value': 9540.731479195028},
#    {'date': '2016-03-31', 'value': 10198.48679264938},
#    {'date': '2016-04-30', 'value': 10241.486490335785},
#    {'date': '2016-05-31', 'value': 10428.45948855804},
#    {'date': '2016-06-30', 'value': 10453.132066183383},
#    {'date': '2016-07-31', 'value': 10841.86452933887},
#    {'date': '2016-08-31', 'value': 10857.084478996949},
#    {'date': '2016-09-30', 'value': 10866.840399773206},
#    {'date': '2016-10-31', 'value': 10655.481537746156},
#    {'date': '2016-11-30', 'value': 11049.9874833646},
#    {'date': '2016-12-31', 'value': 11261.395017995941},
#    {'date': '2017-01-31', 'value': 11489.435310086865},
#    {'date': '2017-02-28', 'value': 11933.660878213861},
#    {'date': '2017-03-31', 'value': 11945.98845804884},
#    {'date': '2017-04-30', 'value': 12068.878331607208},
#    {'date': '2017-05-31', 'value': 12235.344147919359},
#    {'date': '2017-06-30', 'value': 12316.891734281851},
#    {'date': '2017-07-31', 'value': 12561.784881173657},
#    {'date': '2017-08-31', 'value': 12603.008122717612},
#    {'date': '2017-09-30', 'value': 12863.493107015083},
#    {'date': '2017-10-31', 'value': 13161.693962702255},
#    {'date': '2017-11-30', 'value': 13562.56975853565},
#    {'date': '2017-12-31', 'value': 13706.429472965629},
#    {'date': '2018-01-31', 'value': 14476.175778229115},
#    {'date': '2018-02-28', 'value': 13953.09585787297},
#    {'date': '2018-03-31', 'value': 13631.55836045104},
#    {'date': '2018-04-30', 'value': 13673.049407754705},
#    {'date': '2018-05-31', 'value': 14016.196852778068},
#    {'date': '2018-06-30', 'value': 14104.947671528407},
#    {'date': '2018-07-31', 'value': 14606.104421611712},
#    {'date': '2018-08-31', 'value': 15100.128187135848},
#    {'date': '2018-09-30', 'value': 15160.347781397511},
#    {'date': '2018-10-31', 'value': 14092.242869618743},
#    {'date': '2018-11-30', 'value': 14389.678887984035},
#    {'date': '2018-12-31', 'value': 13086.385811022503},
#    {'date': '2019-01-31', 'value': 14172.238529930779},
#    {'date': '2019-02-28', 'value': 14655.185014273382},
#    {'date': '2019-03-31', 'value': 14917.148483709509},
#    {'date': '2019-04-30', 'value': 15520.351624917927},
#    {'date': '2019-05-31', 'value': 14547.559355270487},
#    {'date': '2019-06-30', 'value': 15563.96816365399},
#    {'date': '2019-07-31', 'value': 15803.280101774353},
#    {'date': '2019-08-31', 'value': 15530.279283478561},
#    {'date': '2019-09-30', 'value': 15799.030721712068},
#    {'date': '2019-10-31', 'value': 16133.193456925403},
#    {'date': '2019-11-30', 'value': 16741.256908911517},
#    {'date': '2019-12-31', 'value': 17222.732558993062},
#    {'date': '2020-01-31', 'value': 17261.577504574638},
#    {'date': '2020-02-29', 'value': 15857.163529717529},
#    {'date': '2020-03-31', 'value': 13820.9237417671},
#    {'date': '2020-04-30', 'value': 15634.571125786295},
#    {'date': '2020-05-31', 'value': 16458.1683145889},
#    {'date': '2020-06-30', 'value': 16828.71479195731},
#    {'date': '2020-07-31', 'value': 17827.293248882135},
#    {'date': '2020-08-31', 'value': 19151.136094717294},
#    {'date': '2020-09-30', 'value': 18438.381777730272},
#    {'date': '2020-10-31', 'value': 17962.31359513266},
#    {'date': '2020-11-30', 'value': 20047.434264047857},
#    {'date': '2020-12-31', 'value': 20857.88988725732},
#    {'date': '2021-01-31', 'value': 20677.160994384485},
#    {'date': '2021-02-28', 'value': 21233.758708270205},
#    {'date': '2021-03-31', 'value': 22018.071833691574},
#    {'date': '2021-04-30', 'value': 23204.220771039265},
#    {'date': '2021-05-31', 'value': 23300.30936993488},
#    {'date': '2021-06-30', 'value': 23937.64094738471},
#    {'date': '2021-07-31', 'value': 24466.045966202135},
#    {'date': '2021-08-31', 'value': 25186.046666025777},
#    {'date': '2021-09-30', 'value': 24007.533880527775},
#    {'date': '2021-10-31', 'value': 25675.14128791763},
#    {'date': '2021-11-30', 'value': 25366.585288710234},
#    {'date': '2021-12-31', 'value': 26373.693760408547},
#    {'date': '2022-01-31', 'value': 24851.277558066664},
#    {'date': '2022-02-28', 'value': 24155.740420403778},
#    {'date': '2022-03-31', 'value': 24984.145841424463},
#    {'date': '2022-04-30', 'value': 22724.4135256717},
#    {'date': '2022-05-31', 'value': 22667.439606489144},
#    {'date': '2022-06-30', 'value': 20768.031168838876},
#    {'date': '2022-07-31', 'value': 22704.663542727776},
#    {'date': '2022-08-31', 'value': 21825.728758362642},
#    {'date': '2022-09-30', 'value': 19804.39800142749},
#    {'date': '2022-10-31', 'value': 21375.92322113177},
#    {'date': '2022-11-30', 'value': 22553.209036265955},
#    {'date': '2022-12-31', 'value': 21231.398719317716},
#    {'date': '2023-01-31', 'value': 22625.906898842164},
#    {'date': '2023-02-28', 'value': 22090.86145671137},
#    {'date': '2023-03-31', 'value': 22839.631509893206},
#    {'date': '2023-04-30', 'value': 23128.885847548867},
#    {'date': '2023-05-31', 'value': 23271.49531341298},
#    {'date': '2023-06-30', 'value': 24825.944387891956},
#    {'date': '2023-07-31', 'value': 25661.120998371258},
#    {'date': '2023-08-31', 'value': 25236.458035557465},
#    {'date': '2023-09-30', 'value': 24058.839225680298},
#    {'date': '2023-10-31', 'value': 23508.120265825397},
#    {'date': '2023-11-30', 'value': 25716.455050237615},
#    {'date': '2023-12-31', 'value': 26932.43922965525},
#    {'date': '2024-01-31', 'value': 27369.350370970395},
#    {'date': '2024-02-29', 'value': 28871.46189548156},
#    {'date': '2024-03-31', 'value': 29780.873881886848},
#    {'date': '2024-04-30', 'value': 28548.730848632487},
#    {'date': '2024-05-31', 'value': 29906.534249668217},
#    {'date': '2024-06-30', 'value': 30965.278181226266},
#    {'date': '2024-07-31', 'value': 31345.38075497698},
#    {'date': '2024-08-31', 'value': 32108.376018510244},
#    {'date': '2024-09-30', 'value': 32791.85846598707},
#    {'date': '2024-10-31', 'value': 32548.172542431304},
#    {'date': '2024-11-30', 'value': 34584.98433052685},
#    {'date': '2024-12-31', 'value': 33683.9032106834},
#    {'date': '2025-01-31', 'value': 34719.43640815684},
#    {'date': '2025-02-28', 'value': 34161.970125574415},
#    {'date': '2025-03-31', 'value': 32157.064801090026},
#    {'date': '2025-04-30', 'value': 32006.966778947826},
#    {'date': '2025-05-31', 'value': 34075.11406982666},
#    {'date': '2025-06-30', 'value': 35824.85208299137},
#    {'date': '2025-07-17', 'value': 36366.31522149636}],
#   'category': [{'date': '2015-01-31', 'value': 9700.863464398704},
#    {'date': '2015-02-28', 'value': 10249.863828201002},
#    {'date': '2015-03-31', 'value': 10111.90229942906},
#    {'date': '2015-04-30', 'value': 10174.554204840404},
#    {'date': '2015-05-31', 'value': 10303.963635379454},
#    {'date': '2015-06-30', 'value': 10103.494146980333},
#    {'date': '2015-07-31', 'value': 10258.411124421138},
#    {'date': '2015-08-31', 'value': 9636.90621837495},
#    {'date': '2015-09-30', 'value': 9344.078468533493},
#    {'date': '2015-10-31', 'value': 10045.365691178971},
#    {'date': '2015-11-30', 'value': 10062.311990639928},
#    {'date': '2015-12-31', 'value': 9859.688893109089},
#    {'date': '2016-01-31', 'value': 9322.103963779398},
#    {'date': '2016-02-29', 'value': 9297.766647700491},
#    {'date': '2016-03-31', 'value': 9894.845713704799},
#    {'date': '2016-04-30', 'value': 9944.502089542098},
#    {'date': '2016-05-31', 'value': 10096.601364704833},
#    {'date': '2016-06-30', 'value': 10070.535586915916},
#    {'date': '2016-07-31', 'value': 10441.384573236175},
#    {'date': '2016-08-31', 'value': 10460.343178767263},
#    {'date': '2016-09-30', 'value': 10452.119401153064},
#    {'date': '2016-10-31', 'value': 10252.471329941938},
#    {'date': '2016-11-30', 'value': 10673.614887797063},
#    {'date': '2016-12-31', 'value': 10855.27815843765},
#    {'date': '2017-01-31', 'value': 11053.216624836012},
#    {'date': '2017-02-28', 'value': 11449.81242490688},
#    {'date': '2017-03-31', 'value': 11458.016858634513},
#    {'date': '2017-04-30', 'value': 11575.464342902122},
#    {'date': '2017-05-31', 'value': 11700.760206422436},
#    {'date': '2017-06-30', 'value': 11789.095976277138},
#    {'date': '2017-07-31', 'value': 12005.250896615033},
#    {'date': '2017-08-31', 'value': 12007.586650371872},
#    {'date': '2017-09-30', 'value': 12286.301927021723},
#    {'date': '2017-10-31', 'value': 12532.437653314539},
#    {'date': '2017-11-30', 'value': 12917.20357446074},
#    {'date': '2017-12-31', 'value': 13073.062956154065},
#    {'date': '2018-01-31', 'value': 13757.476449036185},
#    {'date': '2018-02-28', 'value': 13229.991848881928},
#    {'date': '2018-03-31', 'value': 12953.494120043084},
#    {'date': '2018-04-30', 'value': 12979.647101514707},
#    {'date': '2018-05-31', 'value': 13241.2686429024},
#    {'date': '2018-06-30', 'value': 13298.006041859218},
#    {'date': '2018-07-31', 'value': 13767.225958498217},
#    {'date': '2018-08-31', 'value': 14142.494301353892},
#    {'date': '2018-09-30', 'value': 14182.179854538808},
#    {'date': '2018-10-31', 'value': 13201.168569738142},
#    {'date': '2018-11-30', 'value': 13475.601087376663},
#    {'date': '2018-12-31', 'value': 12260.739109831573},
#    {'date': '2019-01-31', 'value': 13240.205291732731},
#    {'date': '2019-02-28', 'value': 13668.870528648482},
#    {'date': '2019-03-31', 'value': 13843.641885694387},
#    {'date': '2019-04-30', 'value': 14383.152096009786},
#    {'date': '2019-05-31', 'value': 13477.251058585165},
#    {'date': '2019-06-30', 'value': 14374.27847424497},
#    {'date': '2019-07-31', 'value': 14582.23371871036},
#    {'date': '2019-08-31', 'value': 14320.23496485175},
#    {'date': '2019-09-30', 'value': 14584.25234794988},
#    {'date': '2019-10-31', 'value': 14843.52720051452},
#    {'date': '2019-11-30', 'value': 15351.74812482147},
#    {'date': '2019-12-31', 'value': 15766.973335484648},
#    {'date': '2020-01-31', 'value': 15674.468827528046},
#    {'date': '2020-02-29', 'value': 14394.241397061265},
#    {'date': '2020-03-31', 'value': 12461.71041048698},
#    {'date': '2020-04-30', 'value': 13955.416009755672},
#    {'date': '2020-05-31', 'value': 14633.30346109332},
#    {'date': '2020-06-30', 'value': 14870.114414910006},
#    {'date': '2020-07-31', 'value': 15634.844994191166},
#    {'date': '2020-08-31', 'value': 16593.559130763897},
#    {'date': '2020-09-30', 'value': 16068.117826030382},
#    {'date': '2020-10-31', 'value': 15716.039644957227},
#    {'date': '2020-11-30', 'value': 17439.032895935004},
#    {'date': '2020-12-31', 'value': 18107.657924035255},
#    {'date': '2021-01-31', 'value': 17964.76155542573},
#    {'date': '2021-02-28', 'value': 18532.59561104807},
#    {'date': '2021-03-31', 'value': 19327.57718209245},
#    {'date': '2021-04-30', 'value': 20253.628846864434},
#    {'date': '2021-05-31', 'value': 20447.240095847243},
#    {'date': '2021-06-30', 'value': 20783.568976813065},
#    {'date': '2021-07-31', 'value': 21194.859109240344},
#    {'date': '2021-08-31', 'value': 21737.71428544918},
#    {'date': '2021-09-30', 'value': 20732.851292928433},
#    {'date': '2021-10-31', 'value': 22036.487551102215},
#    {'date': '2021-11-30', 'value': 21703.757658835286},
#    {'date': '2021-12-31', 'value': 22685.7193727656},
#    {'date': '2022-01-31', 'value': 21479.364314902195},
#    {'date': '2022-02-28', 'value': 20937.086988884363},
#    {'date': '2022-03-31', 'value': 21526.676458080005},
#    {'date': '2022-04-30', 'value': 19841.46523259349},
#    {'date': '2022-05-31', 'value': 19894.85955153242},
#    {'date': '2022-06-30', 'value': 18317.8809598088},
#    {'date': '2022-07-31', 'value': 19797.877748149593},
#    {'date': '2022-08-31', 'value': 19056.469809599243},
#    {'date': '2022-09-30', 'value': 17397.25536199774},
#    {'date': '2022-10-31', 'value': 18775.351754525604},
#    {'date': '2022-11-30', 'value': 19850.11216876754},
#    {'date': '2022-12-31', 'value': 18820.373033106884},
#    {'date': '2023-01-31', 'value': 20033.531566904665},
#    {'date': '2023-02-28', 'value': 19519.46113580618},
#    {'date': '2023-03-31', 'value': 19991.151255315915},
#    {'date': '2023-04-30', 'value': 20214.674574289213},
#    {'date': '2023-05-31', 'value': 20140.02982597488},
#    {'date': '2023-06-30', 'value': 21415.494012253315},
#    {'date': '2023-07-31', 'value': 22094.25396569716},
#    {'date': '2023-08-31', 'value': 21703.99221834327},
#    {'date': '2023-09-30', 'value': 20727.432682942832},
#    {'date': '2023-10-31', 'value': 20254.45751401396},
#    {'date': '2023-11-30', 'value': 21989.85184789586},
#    {'date': '2023-12-31', 'value': 23048.07317182349},
#    {'date': '2024-01-31', 'value': 23335.289400478465},
#    {'date': '2024-02-29', 'value': 24494.2653359699},
#    {'date': '2024-03-31', 'value': 25303.734475940153},
#    {'date': '2024-04-30', 'value': 24243.044257042573},
#    {'date': '2024-05-31', 'value': 25270.062674360386},
#    {'date': '2024-06-30', 'value': 25912.4131505197},
#    {'date': '2024-07-31', 'value': 26355.588166339126},
#    {'date': '2024-08-31', 'value': 26921.659546138446},
#    {'date': '2024-09-30', 'value': 27408.818522902886},
#    {'date': '2024-10-31', 'value': 27108.307326448165},
#    {'date': '2024-11-30', 'value': 28738.299270992142},
#    {'date': '2024-12-31', 'value': 27797.55727847359},
#    {'date': '2025-01-31', 'value': 28731.71784954732},
#    {'date': '2025-02-28', 'value': 28274.825978125667},
#    {'date': '2025-03-31', 'value': 26746.580886952852},
#    {'date': '2025-04-30', 'value': 26527.248751124913},
#    {'date': '2025-05-31', 'value': 28082.039340914223},
#    {'date': '2025-06-30', 'value': 29388.008886349267},
#    {'date': '2025-07-17', 'value': 29753.51369119159}]},
#  'fundFlowData': [{'date': '2015-01-31', 'value': 7550891684.642},
#   {'date': '2015-02-28', 'value': 3659004325.19},
#   {'date': '2015-03-31', 'value': 2922982894.148},
#   {'date': '2015-04-30', 'value': 917023321.475},
#   {'date': '2015-05-31', 'value': -1425947927.864},
#   {'date': '2015-06-30', 'value': 450041390.504},
#   {'date': '2015-07-31', 'value': -5485673102.051},
#   {'date': '2015-08-31', 'value': -130335327.409},
#   {'date': '2015-09-30', 'value': 2474672484.444},
#   {'date': '2015-10-31', 'value': -300523406.299},
#   {'date': '2015-11-30', 'value': 1638695315.615},
#   {'date': '2015-12-31', 'value': 5073558712.119},
#   {'date': '2016-01-31', 'value': 7955528520.217},
#   {'date': '2016-02-29', 'value': 3978451487.497},
#   {'date': '2016-03-31', 'value': 1140518428.661},
#   {'date': '2016-04-30', 'value': 2751846571.381},
#   {'date': '2016-05-31', 'value': 3200875979.232},
#   {'date': '2016-06-30', 'value': 4206517972.739},
#   {'date': '2016-07-31', 'value': 2404484797.108},
#   {'date': '2016-08-31', 'value': 4621241870.862},
#   {'date': '2016-09-30', 'value': 3871868362.686},
#   {'date': '2016-10-31', 'value': 4701411899.333},
#   {'date': '2016-11-30', 'value': 4364096158.672},
#   {'date': '2016-12-31', 'value': 1544867070.91},
#   {'date': '2017-01-31', 'value': 9950402027.747},
#   {'date': '2017-02-28', 'value': 4137338111.416},
#   {'date': '2017-03-31', 'value': 8291911331.821},
#   {'date': '2017-04-30', 'value': 5069799036.254},
#   {'date': '2017-05-31', 'value': 8492139458.711},
#   {'date': '2017-06-30', 'value': 1549516307.787},
#   {'date': '2017-07-31', 'value': 4598227544.4},
#   {'date': '2017-08-31', 'value': 6193349975.264},
#   {'date': '2017-09-30', 'value': 2530037724.311},
#   {'date': '2017-10-31', 'value': 1048299232.835},
#   {'date': '2017-11-30', 'value': 2663664044.731},
#   {'date': '2017-12-31', 'value': -422106744.391},
#   {'date': '2018-01-31', 'value': 3224286203.305},
#   {'date': '2018-02-28', 'value': 6841601075.336},
#   {'date': '2018-03-31', 'value': 4563530655.653},
#   {'date': '2018-04-30', 'value': 4375929813.38},
#   {'date': '2018-05-31', 'value': 276892810.944},
#   {'date': '2018-06-30', 'value': -1654934625.286},
#   {'date': '2018-07-31', 'value': 1179429064.892},
#   {'date': '2018-08-31', 'value': -1614929832.281},
#   {'date': '2018-09-30', 'value': 6781258078.704},
#   {'date': '2018-10-31', 'value': 7605128797.553},
#   {'date': '2018-11-30', 'value': 3493043779.587},
#   {'date': '2018-12-31', 'value': 14087654877.226},
#   {'date': '2019-01-31', 'value': 1080739704.759},
#   {'date': '2019-02-28', 'value': 314609075.622},
#   {'date': '2019-03-31', 'value': 5486599681.497},
#   {'date': '2019-04-30', 'value': 1111599981.106},
#   {'date': '2019-05-31', 'value': 6193609366.153},
#   {'date': '2019-06-30', 'value': 2680675905.916},
#   {'date': '2019-07-31', 'value': -2013464556.655},
#   {'date': '2019-08-31', 'value': 6286409661.06},
#   {'date': '2019-09-30', 'value': 606851976.615},
#   {'date': '2019-10-31', 'value': 759104522.751},
#   {'date': '2019-11-30', 'value': -2859773430.795},
#   {'date': '2019-12-31', 'value': -966708326.488},
#   {'date': '2020-01-31', 'value': 4733472687.562},
#   {'date': '2020-02-29', 'value': 13176545797.126},
#   {'date': '2020-03-31', 'value': 12545367393.743},
#   {'date': '2020-04-30', 'value': -12187592972.124},
#   {'date': '2020-05-31', 'value': -5939861842.666},
#   {'date': '2020-06-30', 'value': -7231263478.093},
#   {'date': '2020-07-31', 'value': -3576699454.258},
#   {'date': '2020-08-31', 'value': -9708654554.84},
#   {'date': '2020-09-30', 'value': -881327114.375},
#   {'date': '2020-10-31', 'value': 4040994915.647},
#   {'date': '2020-11-30', 'value': 1326169723.048},
#   {'date': '2020-12-31', 'value': 221267621.825},
#   {'date': '2021-01-31', 'value': 2321406189.638},
#   {'date': '2021-02-28', 'value': -2430860855.121},
#   {'date': '2021-03-31', 'value': 4985152507.0},
#   {'date': '2021-04-30', 'value': 1031938618.266},
#   {'date': '2021-05-31', 'value': 4647415455.472},
#   {'date': '2021-06-30', 'value': 3384336523.855},
#   {'date': '2021-07-31', 'value': 141918850.196},
#   {'date': '2021-08-31', 'value': -1079129109.538},
#   {'date': '2021-09-30', 'value': 2586278731.309},
#   {'date': '2021-10-31', 'value': -275125147.822},
#   {'date': '2021-11-30', 'value': 2566346555.666},
#   {'date': '2021-12-31', 'value': -732989157.79},
#   {'date': '2022-01-31', 'value': 12222034153.74},
#   {'date': '2022-02-28', 'value': 2604560491.534},
#   {'date': '2022-03-31', 'value': 1707255548.562},
#   {'date': '2022-04-30', 'value': 5238267535.712},
#   {'date': '2022-05-31', 'value': 10308945150.048},
#   {'date': '2022-06-30', 'value': 4582147661.991},
#   {'date': '2022-07-31', 'value': 2113722752.828},
#   {'date': '2022-08-31', 'value': -347071574.137},
#   {'date': '2022-09-30', 'value': 4440794375.176},
#   {'date': '2022-10-31', 'value': 1382971579.016},
#   {'date': '2022-11-30', 'value': 2535393687.988},
#   {'date': '2022-12-31', 'value': 9139113141.612},
#   {'date': '2023-01-31', 'value': 8529505267.701},
#   {'date': '2023-02-28', 'value': 1753054074.729},
#   {'date': '2023-03-31', 'value': 3779988836.521},
#   {'date': '2023-04-30', 'value': 3043832167.011},
#   {'date': '2023-05-31', 'value': -976208426.558},
#   {'date': '2023-06-30', 'value': -3035465731.371},
#   {'date': '2023-07-31', 'value': -1796079677.014},
#   {'date': '2023-08-31', 'value': -1829747728.243},
#   {'date': '2023-09-30', 'value': 1840860588.77},
#   {'date': '2023-10-31', 'value': 1878449617.026},
#   {'date': '2023-11-30', 'value': -2726472644.511},
#   {'date': '2023-12-31', 'value': -1424991123.72},
#   {'date': '2024-01-31', 'value': 1058790404.784},
#   {'date': '2024-02-29', 'value': -7150020644.414},
#   {'date': '2024-03-31', 'value': 2747701266.736},
#   {'date': '2024-04-30', 'value': 2294956640.236},
#   {'date': '2024-05-31', 'value': -330703528.125},
#   {'date': '2024-06-30', 'value': -2068544754.948},
#   {'date': '2024-07-31', 'value': -3420884842.69},
#   {'date': '2024-08-31', 'value': 5251532076.282},
#   {'date': '2024-09-30', 'value': -1288027665.503},
#   {'date': '2024-10-31', 'value': -6315376800.303},
#   {'date': '2024-11-30', 'value': -10292841695.803},
#   {'date': '2024-12-31', 'value': -227938393.357},
#   {'date': '2025-01-31', 'value': 4496289776.587},
#   {'date': '2025-02-28', 'value': 4915967497.912},
#   {'date': '2025-03-31', 'value': 5060310921.394},
#   {'date': '2025-04-30', 'value': 22884276410.705},
#   {'date': '2025-05-31', 'value': -1697678591.881},
#   {'date': '2025-06-30', 'value': -1747294106.213},
#   {'date': '2025-07-31', 'value': None},
#   {'date': '2025-08-31', 'value': None},
#   {'date': '2025-09-30', 'value': None},
#   {'date': '2025-10-31', 'value': None},
#   {'date': '2025-11-30', 'value': None},
#   {'date': '2025-12-31', 'value': None}],
#  'managerChange': [{'date': '2016-04-27 00:00:00.0', 'value': 'partial'},
#   {'date': '2023-02-17 00:00:00.0', 'value': 'partial'},
#   {'date': '2025-06-18 00:00:00.0', 'value': 'partial'}],
#  'table': {'columnDefs': ['2015',
#    '2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    'YTD'],
#   'growth10KReturnData': [{'label': 'fund',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['0.38764',
#      '12.66422',
#      '21.16927',
#      '-5.1711',
#      '30.80497',
#      '20.98791',
#      '25.71229',
#      '-19.52516',
#      '26.00822',
#      '23.74332',
#      '7.40782'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'category',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['-1.06996',
#      '10.36891',
#      '20.43837',
#      '-6.26928',
#      '28.77649',
#      '15.82748',
#      '26.06759',
#      '-16.95545',
#      '22.31864',
#      '21.44601',
#      '7.0525'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'index',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['0.92191',
#      '11.58523',
#      '21.71165',
#      '-4.52374',
#      '31.60802',
#      '21.10674',
#      '26.44469',
#      '-19.49782',
#      '26.85193',
#      '25.06815',
#      '7.96348'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'percentileRank',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['38',
#      '20',
#      '45',
#      '42',
#      '39',
#      '17',
#      '63',
#      '75',
#      '33',
#      '43',
#      '49'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'fundNumber',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['1606',
#      '1409',
#      '1396',
#      '1402',
#      '1387',
#      '1363',
#      '1382',
#      '1358',
#      '1430',
#      '1386',
#      '1392'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'categoryName',
#     'endDate': None,
#     'datum': ['US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend'],
#     'epFlag': []},
#    {'label': 'categoryNameAbbr',
#     'endDate': None,
#     'datum': ['LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB'],
#     'epFlag': []}]},
#  'currentValues': [{'type': 'fund',
#    'name': 'VTSAX',
#    'baseCurrency': 'USD',
#    'currentValue': '34846.57176369192',
#    'currentSymbol': '$'},
#   {'type': 'index',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': '36366.31522149636',
#    'currentSymbol': '$'},
#   {'type': 'category',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': '29753.51369119159',
#    'currentSymbol': '$'}],
#  'instrumentId': '52.8.VTSAX',
#  'fundFlowQuarterlyData': [],
#  'isLimitAgeData': False,
#  'cur': 'USD',
#  'isUKCefAvailable': False,
#  'template': 'SA_USA'}

# %% [markdown]
# Historical expense ratio
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.historicalExpenses()
# Out:
# {'feeLevelComparisonGroup': 'Large Cap Institutional',
#  'currentYear': '2025',
#  'fundExpenseHistoryList': [{'annualReportDate': '2021-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None},
#   {'annualReportDate': '2022-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None},
#   {'annualReportDate': '2023-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None},
#   {'annualReportDate': '2024-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None}],
#  'feeLevelMedianList': [{'date': '2021-12-31T06:00:00.000', 'median': 0.7},
#   {'date': '2022-12-31T06:00:00.000', 'median': 0.7},
#   {'date': '2023-12-31T06:00:00.000', 'median': 0.7},
#   {'date': '2024-12-31T06:00:00.000', 'median': 0.69},
#   {'date': '2025-06-30T05:00:00.000', 'median': 0.69}],
#  'categoryExpenseAverageList': [{'year': '2025',
#    'categoryExpenseRatio': 0.835,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2021',
#    'categoryExpenseRatio': 0.825,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2022',
#    'categoryExpenseRatio': 0.819,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2023',
#    'categoryExpenseRatio': 0.833,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2024',
#    'categoryExpenseRatio': 0.819,
#    'categoryManagementExpenseRatio': None}]}

# %% [markdown]
# Historical raiting

# %%
funds.historicalRating()
# Out:
# {'medalistStartDate': '2023-05-01',
#  'ticker': 'VTSAX',
#  'userType': 'Free',
#  'years': {'2022': [{'date': '2022-08-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': None,
#     'overallRatingAnalystPercetage': None,
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2022-09-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': None,
#     'overallRatingAnalystPercetage': None,
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2022-10-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': None,
#     'overallRatingAnalystPercetage': None,
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2022-11-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': None,
#     'overallRatingAnalystPercetage': None,
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2022-12-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': None,
#     'overallRatingAnalystPercetage': None,
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}],
#   '2023': [{'date': '2023-01-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': None,
#     'overallRatingAnalystPercetage': None,
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-02-28',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': None,
#     'overallRatingAnalystPercetage': None,
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-03-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'Y',
#     'analysisPublishedDate': '2023-03-06T06:00:00.000'},
#    {'date': '2023-04-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-05-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-06-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-07-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-08-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-09-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-10-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-11-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-12-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}],
#   '2024': [{'date': '2024-01-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-02-29',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'Y',
#     'analysisPublishedDate': '2024-02-07T06:00:00.000'},
#    {'date': '2024-03-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-04-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-05-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-06-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-07-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-08-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-09-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-10-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-11-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-12-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}],
#   '2025': [{'date': '2025-01-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-02-28',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-03-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-04-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-05-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-06-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-07-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}]}}

# %% [markdown]
# Holdings in a DataFrame format
#
# Holdings
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.holdings()
# Out:
#                     securityName       secId performanceId holdingTypeId  \
# 0                 Microsoft Corp  0P000003MH    0P000003MH             E
# 1                    NVIDIA Corp  0P000003RE    0P000003RE             E
# 2                      Apple Inc  0P000000GY    0P000000GY             E
# 3                 Amazon.com Inc  0P000000B7    0P000000B7             E
# 4     Meta Platforms Inc Class A  0P0000W3KZ    0P0000W3KZ             E
# ...                          ...         ...           ...           ...
# 3556        Usd/Eur Fwd 20250530        None          None            CU
# 3557                        Euro        None          None            CH
# 3558          Btcs Incorporation  B10003UJJ6          None             P
# 3559        Eur/Usd Fwd 20250530        None          None            CU
# 3560                   Us Dollar        None          None            CH
#
#       weighting  numberOfShare   marketValue  shareChange        country  \
# 0       6.02457    238818012.0  1.099423e+11     282870.0  United States
# 1       5.51387    744635666.0  1.006226e+11     870143.0  United States
# 2       5.31119    482568559.0  9.692390e+10     565311.0  United States
# 3       3.44210    306398771.0  6.281481e+10     354439.0  United States
# 4       2.49597     70346890.0  4.554891e+10      80511.0  United States
# ...         ...            ...           ...          ...            ...
# 3556    0.00036      6518119.0  6.518119e+06    6518119.0           None
# 3557    0.00030      4885284.0  5.546996e+06    4885284.0           None
# 3558    0.00000       280193.0  3.000000e+00          0.0  United States
# 3559   -0.00036      5747394.0 -6.525878e+06    5747394.0           None
# 3560   -0.00103     18878765.0 -1.887876e+07   18878765.0           None
#
#      ticker  ...  susEsgRiskCategory  managementExpenseRatio qualRating  \
# 0      MSFT  ...                 Low                    None       None
# 1      NVDA  ...                 Low                    None       None
# 2      AAPL  ...                 Low                    None       None
# 3      AMZN  ...              Medium                    None       None
# 4      META  ...                High                    None       None
# ...     ...  ...                 ...                     ...        ...
# 3556   None  ...                None                    None       None
# 3557   None  ...                None                    None       None
# 3558   None  ...                None                    None       None
# 3559   None  ...                None                    None       None
# 3560   None  ...                None                    None       None
#
#      quantRating bestRatingType securityType domicileCountryId currencyName  \
# 0              3           Qual           ST               USA    US Dollar
# 1              1           Qual           ST               USA    US Dollar
# 2              2           Qual           ST               USA    US Dollar
# 3              3           Qual           ST               USA    US Dollar
# 4              3           Qual           ST               USA    US Dollar
# ...          ...            ...          ...               ...          ...
# 3556        None           None         None              None         None
# 3557        None           None         None              None         None
# 3558        None           None         None              None    US Dollar
# 3559        None           None         None              None         None
# 3560        None           None         None              None         None
#
#      originalMarketValue isMomentumFilterFlag
# 0           1.099423e+11                False
# 1           1.006226e+11                False
# 2           9.692390e+10                False
# 3           6.281481e+10                False
# 4           4.554891e+10                False
# ...                  ...                  ...
# 3556        6.518119e+06                 None
# 3557        5.546996e+06                 None
# 3558        3.000000e+00                 None
# 3559       -6.525878e+06                 None
# 3560       -1.887876e+07                 None
#
# [3561 rows x 57 columns]

# %% [markdown]
# Summmary of fees
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/quote

# %%
ms.Funds("IE00B04GQT48").investmentFee()
# Out:
# {'domicileCountryId': 'IRL',
#  'priceTemplate': 'EEA_OE',
#  'actualInvestmentFees': {'kiidOngoingCharge': 0.12,
#   'kiidOngoingChargeDate': '2025-03-19T05:00:00.000',
#   'ongoingCost': 0.12145,
#   'performanceFee': 0.0,
#   'managementFee': 0.12,
#   'transactionFee': 0.01431,
#   'distributionFee': 0.0},
#  'estimatedInvestmentFees': {'ongoingCost': 0.12145,
#   'performanceFee': 0.0,
#   'managementFee': 0.12,
#   'transactionFee': 0.01725,
#   'distributionFee': 0.0}}

# %% [markdown]
# Quick lookup on the fund

# %%
ms.Funds("IE00B04GQT48").investmentLookup()
# Out:
# {'dbgtime': '133',
#  'Id': 'F0000022KV',
#  'InceptionDate': '2008-08-06T00:00:00',
#  'Isin': 'IE00B04GQT48',
#  'InvestmentType': 'FD',
#  'HoldingType': '2',
#  'Type': 'Fund',
#  'Name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'LegalName': 'Vanguard U.S. Investment Grade Credit Index Fund EUR Acc',
#  'FundNetAssetValues': [{'CurrencyId': 'EUR',
#    'DayEndDate': '2025-07-17T00:00:00',
#    'DayEndValue': 1411262287.053,
#    'MonthEndDate': '2025-06-30T00:00:00',
#    'MonthEndValue': 1399736551.7394}],
#  'ESG': {'SustainabilityDate': '2025-05-31T00:00:00',
#   'SustainabilityRank': 3,
#   'EnvironmentalScore': 4.38,
#   'SocialScore': 8.53,
#   'GovernanceScore': 5.65,
#   'RawSustainabilityScore': 22.04923,
#   'AUMCoverage': 93.41693,
#   'SustainabilityRating': {'Date': '2025-05-31T00:00:00',
#    'SustainabilityFundQuintile': 3,
#    'SustainabilityFundQuintileDesc': 'Average'},
#   'CarbonScore': {'Date': '2025-05-31T00:00:00',
#    'LowCarbonDesignation': 'No',
#    'CarbonRiskClassification': 'Low Risk',
#    'CarbonRiskScore': 9.3,
#    'CarbonExposureScore': 19.29,
#    'CarbonManagementScore': 9.99,
#    'CarbonOperationsRisk': 3.95,
#    'CarbonProductsAndServicesRisk': 0.67,
#    'StrandedAssetsRisk': 74.61,
#    'PercentOfAUMWithNegligibleCarbonRisk': 9.15132,
#    'PercentOfAUMWithLowCarbonRisk': 60.41253,
#    'PercentOfAUMWithMediumCarbonRisk': 25.54605,
#    'PercentOfAUMWithHighCarbonRisk': 4.11237,
#    'PercentOfAUMWithSevereCarbonRisk': 0.77773,
#    'OilSandsExtractionInvolvement': 1.48517,
#    'ArcticOilAndGasExplorationInvolvement': 1.32668,
#    'FossilFuelInvolvement': 12.09726,
#    'CarbonSolutionsInvolvement': 6.46512,
#    'ThermalCoalPowerGenerationInvolvement': 6.05676,
#    'ThermalCoalExtractionInvolvement': 0.9817,
#    'OilAndGasGenerationInvolvement': 8.771,
#    'OilAndGasProductionInvolvement': 12.86552,
#    'OilAndGasProductsAndServiceInvolvement': 7.93592,
#    'HistoricCarbonRiskScore': 9.42},
#   'ProductInvolvement': {'Date': '2025-05-31T00:00:00',
#    'AbortiveContraceptivesStemCell': 6.14,
#    'AdultEntertainment': 0.0,
#    'Alcohol': 0.79,
#    'AnimalTesting': 10.34,
#    'ControversialWeapons': 1.63,
#    'FurAndSpecialtyLeather': 0.0,
#    'Gambling': 0.26,
#    'GMO': 0.25,
#    'MilitaryContracting': 1.99,
#    'Nuclear': 4.38,
#    'PalmOil': 0.02,
#    'Pesticides': 0.33,
#    'SmallArms': 0.75,
#    'ThermalCoal': 3.69,
#    'Tobacco': 1.03},
#   'RatingAndScore': {'Date': '2025-05-31T00:00:00',
#    'SustainabilityRatingDate': '2025-05-31T00:00:00',
#    'SustainabilityRating': 3,
#    'SustainabilityScore': 22.09,
#    'SustainabilityPercentRank': 62,
#    'SustainabilityAbsoluteRank': 2227,
#    'HistoricalSustainabilityScore': 22.05,
#    'EnvironmentalScore': 4.38,
#    'SocialScore': 8.53,
#    'GovernanceScore': 5.65,
#    'PercentAUMCoveredESG': 93.41693,
#    'NumberOfSecuritiesScoredESG': 7116,
#    'PercentAUMCoveredControversy': 94.1,
#    'NumberOfSecuritiesScoredControversy': 7193,
#    'NumberOfSecuritiesNotScoredControversy': 1257,
#    'PercentAUMWithLow': 6.20107,
#    'PercentAUMWithBelowAverage': 38.18786,
#    'PercentAUMWithAverage': 41.88514,
#    'PercentAUMWithAboveAverage': 10.74433,
#    'PercentAUMWithHigh': 2.9816},
#   'SustainableInvestment': {'Overall': 'No',
#    'Date': '2025-05-28',
#    'GeneralESGInvestment': 'No',
#    'InvolvedInHealthyEcosystems': 'No',
#    'InvolvedInHumanDevelopment': 'No',
#    'InvolvedInResourceSecurity': 'No',
#    'InvolvedInBasicNeeds': 'No'},
#   'EmploysExclusions': {'Overall': 'No',
#    'UsesNormsBasedScreening': 'No',
#    'ExcludesAbortionStemCells': 'No',
#    'ExcludesAdultEntertainment': 'No',
#    'ExcludesAlcohol': 'No',
#    'ExcludesAnimalTesting': 'No',
#    'ExcludesControversialWeapons': 'No',
#    'ExcludesFurSpecialtyLeather': 'No',
#    'ExcludesGambling': 'No',
#    'ExcludesGMOs': 'No',
#    'ExcludesMilitaryContracting': 'No',
#    'ExcludesNuclear': 'No',
#    'ExcludesPalmOil': 'No',
#    'ExcludesPesticides': 'No',
#    'ExcludesSmallArms': 'No',
#    'ExcludesThermalCoal': 'No',
#    'ExcludesTobacco': 'No',
#    'ExcludesOther': 'No',
#    'ExcludesFossilFuel': 'No'}},
#  'Domicile': 'IRL',
#  'RealtimeId': '52.8.IE00B04GQT48',
#  'Currency': {'Id': 'EUR'},
#  'RiskAndRating': [{'Date': '2025-06-30T00:00:00',
#    'TimePeriod': 'M255',
#    'RatingValue': 3}],
#  'LastPrice': {'Date': '2025-07-17T00:00:00',
#   'MarketDate': '2025-07-17',
#   'MarketTime': '00:00:00',
#   'MarketTimeZone': 'BST',
#   'Value': 256.1925,
#   'Currency': {'Id': 'EUR'}},
#  'Benchmark': [{'Id': 'EUCA000691',
#    'GlobalAssetClassId': '$BCG$FXINC',
#    'Type': 'Category',
#    'Name': 'USD Corporate Bond'}],
#  'FundBenchmark': [{'Id': 'F00000WZ2U',
#    'Name': 'Bloomberg Gbl Agg USD Credit FA TR USD',
#    'Weighting': 100.0}],
#  'Research': {'MedalistRating': {'OverallRating': {'Date': '2025-05-31',
#     'AnalystDrivenPercentage': 20,
#     'RatingNumber': 7,
#     'RatingText': 'Gold'}}}}

# %% [markdown]
# Investment strategy
#
# https://www.morningstar.com/funds/xnas/vtsax/quote

# %%
funds.investmentStrategy()
# Out:
# {'investmentStrategy': 'The investment seeks to track the performance of the CRSP US Total Market Index that measures the investment return of the overall stock market.\n The fund employs an indexing investment approach designed to track the performance of the index, which represents approximately 100% of the investable U.S. stock market and includes large-, mid-, small-, and micro-cap stocks. It invests by sampling the index, meaning that it holds a broadly diversified collection of securities that, in the aggregate, approximates the full index in terms of key characteristics. The fund is non-diversified.',
#  'languageId': '0L00000122',
#  'isInvestmentStrategyEmpty': False,
#  'template': 'USA_OE',
#  'domicileCountryId': 'USA'}

# %% [markdown]
# Breakdown by market capitalization
#
# Style Measures - Market Cap
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.marketCapitalization()
# Out:
# {'portfolioDate': '2025-05-31T05:00:00.000',
#  'assetType': 'EQUITY',
#  'currencyId': 'USD',
#  'fund': {'portfolioDate': '2025-05-31T05:00:00.000',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'avgMarketCap': 221358.24276,
#   'giant': 40.9498,
#   'large': 30.64315,
#   'medium': 19.47595,
#   'small': 6.34507,
#   'micro': 2.15518},
#  'category': {'portfolioDate': '2025-06-30T05:00:00.000',
#   'name': 'Large Blend',
#   'avgMarketCap': 435892.74079,
#   'giant': 53.97224,
#   'large': 18.80933,
#   'medium': 20.49673,
#   'small': 3.73373,
#   'micro': 0.07678},
#  'index': {'portfolioDate': '2025-06-30T05:00:00.000',
#   'name': 'Morningstar US Large-Mid TR USD',
#   'avgMarketCap': 350831.98296,
#   'giant': 45.16413,
#   'large': 33.93648,
#   'medium': 20.55481,
#   'small': 0.33466,
#   'micro': 0.0}}

# %% [markdown]
# Breakdown by bond maturity
#
# Bond Breakdown - Maturity Schedule
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
ms.Funds("IE00B04GQT48").maturitySchedule()
# Out:
# {'fund': {'date': '2025-06-30T05:00:00.000',
#   'name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'schedule': ['21.36231',
#    '21.51212',
#    '12.09525',
#    '15.06504',
#    '6.15020',
#    '5.56168',
#    '15.33176',
#    '2.76761']},
#  'benchMark': None,
#  'category': {'date': '2025-06-30T05:00:00.000',
#   'name': 'USD Corporate Bond',
#   'schedule': ['4.39391',
#    '21.13154',
#    '2.75780',
#    '11.87403',
#    '1.26773',
#    '12.18917',
#    '38.91835',
#    '2.08716']},
#  'proxy': {'date': '2025-06-30T05:00:00.000',
#   'name': 'Morningstar US Corp Bd TR USD',
#   'schedule': ['20.94310',
#    '19.39971',
#    '11.35383',
#    '14.48031',
#    '5.26244',
#    '6.23281',
#    '18.47392',
#    '2.96990']},
#  'scheduleLabel': ['Maturity1-3Yr%',
#   'Maturity3-5Yr%',
#   'Maturity5-7Yr%',
#   'Maturity7-10Yr%',
#   'Maturity10-15Yr%',
#   'Maturity15-20Yr%',
#   'Maturity20-30Yr%',
#   'Maturity30+Yr%']}

# %% [markdown]
# Max Drawdown
#
# Market Volatility Measures
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.maxDrawDown()
# Out:
# {'year': 3,
#  'maxDrawDownAsOfDate': '2025-06-30T05:00:00.000',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'categoryName': 'Large Blend',
#  'peakDate': '2022-08-01T00:00:00.000',
#  'valleyDate': '2022-09-30T00:00:00.000',
#  'duration': 2.0,
#  'inceptionDate': '2000-11-13T06:00:00.000',
#  'calculationBenchmark': 'S&P 500 TR USD',
#  'cur': 'USD',
#  'measureMap': {'fund': {'secId': 'FOUSA00L83',
#    'asOfDate': '2025-06-30T05:00:00.000',
#    'upside': 100.629,
#    'downside': 104.998,
#    'maxDrawDown': -12.6626885487,
#    'peakDate': '2022-08-01T00:00:00.000',
#    'valleyDate': '2022-09-30T00:00:00.000',
#    'duration': 2.0,
#    'isAddExtendedFlag': False},
#   'index': {'secId': 'F00000GWXD',
#    'asOfDate': '2025-06-30T05:00:00.000',
#    'upside': 101.05,
#    'downside': 101.014,
#    'maxDrawDown': -12.7738729687,
#    'peakDate': '2022-08-01T00:00:00.000',
#    'valleyDate': '2022-09-30T00:00:00.000',
#    'duration': 2.0,
#    'isAddExtendedFlag': False},
#   'category': {'secId': '$FOCA$LB$$',
#    'asOfDate': '2025-06-30T05:00:00.000',
#    'upside': 95.087,
#    'downside': 101.567,
#    'maxDrawDown': -12.556859078,
#    'peakDate': '2022-06-01T00:00:00.000',
#    'valleyDate': '2022-09-30T00:00:00.000',
#    'duration': 4.0,
#    'isAddExtendedFlag': False}}}

# %% [markdown]
# Comparable funds with MorningStar medal
#
# https://www.morningstar.com/funds/xnas/vtsax/analysis

# %%
funds.medaListComparables()
# Out:
# {'userType': 'Free',
#  'categoryName': 'Large Blend',
#  'secId': 'FOUSA00L83',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'getCategoryId': 'Large Blend',
#  'ticker': 'VTSAX',
#  'categoryMedalist': [{'secId': 'FOUSA00AOK',
#    'endDate': None,
#    'tradingSymbol': 'DFUSX',
#    'legalName': 'DFA U.S. Large Company Portfolio',
#    'name': 'DFA US Large Company I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '12882049753',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 12882049753.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000LZSI',
#    'endDate': None,
#    'tradingSymbol': 'FXAIX',
#    'legalName': 'Fidelity 500 Index Fund',
#    'name': 'Fidelity 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '665836971612',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 665836971612.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Y8H0',
#    'endDate': None,
#    'tradingSymbol': 'FDFIX',
#    'legalName': 'Fidelity Flex 500 Index Fund',
#    'name': 'Fidelity Flex 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '6504084028',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 6504084028.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000WCQA',
#    'endDate': None,
#    'tradingSymbol': 'FLCPX',
#    'legalName': 'Fidelity SAI U.S. Large Cap Index Fund',
#    'name': 'Fidelity SAI US Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '14063285773',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 14063285773.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000011YJJ',
#    'endDate': None,
#    'tradingSymbol': 'FCFMX',
#    'legalName': 'Fidelity Series Total Market Index Fund',
#    'name': 'Fidelity Series Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '85391779075',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 85391779075.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000MJS0',
#    'endDate': None,
#    'tradingSymbol': 'FSKAX',
#    'legalName': 'Fidelity Total Market Index Fund',
#    'name': 'Fidelity Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '111510925713',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 111510925713.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000010QVC',
#    'endDate': None,
#    'tradingSymbol': 'FNILX',
#    'legalName': 'Fidelity ZERO Large Cap Index Fund',
#    'name': 'Fidelity ZERO Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '93',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '13565110871',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 13565110871.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Y8GT',
#    'endDate': None,
#    'tradingSymbol': 'FZROX',
#    'legalName': 'Fidelity ZERO Total Market Index Fund',
#    'name': 'Fidelity ZERO Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '93',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '27741669557',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 27741669557.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA057GT',
#    'endDate': None,
#    'tradingSymbol': 'GQEFX',
#    'legalName': 'GMO Quality Fund Class IV',
#    'name': 'GMO Quality IV',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '10739035000',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 1060405100.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Y66G',
#    'endDate': None,
#    'tradingSymbol': 'GSPFX',
#    'legalName': 'Gotham Enhanced S&P 500 Index Fund Institutional Class',
#    'name': 'Gotham Enhanced S&P 500 Index Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '0',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '22856672',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 22856672.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000010SV0',
#    'endDate': None,
#    'tradingSymbol': 'GQEIX',
#    'legalName': 'GQG Partners US Select Quality Equity Fund Institutional Shares',
#    'name': 'GQG Partners US Select Quality Eq Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4074394438',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 3476298299.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00B6B',
#    'endDate': None,
#    'tradingSymbol': 'WFSPX',
#    'legalName': 'iShares S&P 500 Index Fund Class K',
#    'name': 'iShares S&P 500 Index K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '49610674370',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 18738802740.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000015VV2',
#    'endDate': None,
#    'tradingSymbol': 'NWAVX',
#    'legalName': 'Nationwide GQG US Quality Equity Fund Class R6',
#    'name': 'Nationwide GQG US Quality Eq R6',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '273838879',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 196546275.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00K0Q',
#    'endDate': None,
#    'tradingSymbol': 'SWTSX',
#    'legalName': 'Schwab Total Stock Market Index Fund®',
#    'name': 'Schwab Total Stock Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '29265377924',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 29265377924.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00JLQ',
#    'endDate': None,
#    'tradingSymbol': 'SWPPX',
#    'legalName': 'Schwab® S&P 500 Index Fund',
#    'name': 'Schwab® S&P 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '119690329757',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 119690329757.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000T8Y5',
#    'endDate': None,
#    'tradingSymbol': 'SSEYX',
#    'legalName': 'State Street Equity 500 Index II Portfolio',
#    'name': 'State Street Equity 500 Index II',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '19194489043',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 19194489043.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000ZXDE',
#    'endDate': None,
#    'tradingSymbol': 'FCTDX',
#    'legalName': 'Strategic Advisers Fidelity U.S. Total Stock Fund',
#    'name': 'Strategic Advisers Fidelity US TtlStk',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '163505080000',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 163505080000.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00EJ4',
#    'endDate': None,
#    'tradingSymbol': 'PRDGX',
#    'legalName': 'T. Rowe Price Dividend Growth Fund',
#    'name': 'T. Rowe Price Dividend Growth',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '24188885999',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 12412829298.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00FUG',
#    'endDate': None,
#    'tradingSymbol': 'VDIGX',
#    'legalName': 'Vanguard Dividend Growth Fund Investor Shares',
#    'name': 'Vanguard Dividend Growth Inv',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '47611990745',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 47611990745.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00FR3',
#    'endDate': None,
#    'tradingSymbol': 'VINIX',
#    'legalName': 'Vanguard Institutional Index Fund Institutional Shares',
#    'name': 'Vanguard Institutional Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '321075200378',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 124697021240.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA02T7X',
#    'endDate': None,
#    'tradingSymbol': 'VITPX',
#    'legalName': 'Vanguard Institutional Total Stock Market Index Fund Institutional Plus Shares',
#    'name': 'Vanguard Instl Ttl Stk Mkt Idx InstlPls',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '30164241608',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 28475990137.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA02TYG',
#    'endDate': None,
#    'tradingSymbol': 'VTCLX',
#    'legalName': 'Vanguard Tax-Managed Capital Appreciation Fund Admiral Shares',
#    'name': 'Vanguard Tax-Managed Capital App Adm',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '24646109326',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 20824680779.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00FUA',
#    'endDate': None,
#    'tradingSymbol': 'WFIOX',
#    'legalName': 'Allspring Index Fund - Class Admin',
#    'name': 'Allspring Index Admin',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1366285281',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 420698169.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00FUP',
#    'endDate': None,
#    'tradingSymbol': 'AWSHX',
#    'legalName': 'American Funds Washington Mutual Investors Fund Class A',
#    'name': 'American Funds Washington Mutual A',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '202060453473',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '1',
#    'fundShareClassTypeName': 'A',
#    'lastShareClassNetAsset': 92795376574.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000013TAS',
#    'endDate': None,
#    'tradingSymbol': 'AVUSX',
#    'legalName': 'Avantis® U.S. Equity Fund Institutional Class',
#    'name': 'Avantis® U.S. Equity Institutional',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '925595392',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 679663423.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000W3UB',
#    'endDate': None,
#    'tradingSymbol': 'BIRIX',
#    'legalName': 'BlackRock Sustainable Advantage Large Cap Core Fund Institutional Shares',
#    'name': 'BlackRock Sustainable Adg Lg Cp Cr Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '879529439',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 363059789.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00ER2',
#    'endDate': None,
#    'tradingSymbol': 'DSPIX',
#    'legalName': 'BNY Mellon Institutional S&P 500 Stock Index Fund Class I',
#    'name': 'BNY Mellon Instl S&P 500 Stk Idx I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1554197365',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1554197365.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00001DJ2I',
#    'endDate': None,
#    'tradingSymbol': 'BBTLX',
#    'legalName': 'Bridge Builder Tax Managed Large Cap Fund',
#    'name': 'Bridge Builder Tax Managed Large Cap',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '45',
#    'dataCoverage': '88',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '6684603180',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 6684603180.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000LL3D',
#    'endDate': None,
#    'tradingSymbol': 'CUSEX',
#    'legalName': 'Capital Group U.S. Equity Fund',
#    'name': 'Capital Group US Equity',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '55',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '387083916',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 387083916.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00001BQAK',
#    'endDate': None,
#    'tradingSymbol': 'CRQSX',
#    'legalName': 'Catholic Responsible Investments Equity Index Fund Institutional Shares',
#    'name': 'Catholic Rspnsbl Invst Equity Idx Ins',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'BELOW_AVERAGE',
#    'peopleScoreLabel': 'BELOW_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '80',
#    'dataCoverage': '95',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
# ...
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4430346348',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 4430346348.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 5,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA0592C',
#    'endDate': None,
#    'tradingSymbol': 'GEQYX',
#    'legalName': 'GuideStone Funds Equity Index Fund Institutional Class',
#    'name': 'GuideStone Funds Equity Index Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '80',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '5373176401',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 3822350042.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA02TLS',
#    'endDate': None,
#    'tradingSymbol': 'HSTAX',
#    'legalName': 'Hartford Stock HLS Fund Class IA',
#    'name': 'Hartford Stock HLS IA',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1229620351',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1130191344.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 1,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00JVG',
#    'endDate': None,
#    'tradingSymbol': 'SPIDX',
#    'legalName': 'Invesco S&P 500 Index Fund Class Y',
#    'name': 'Invesco S&P 500 Index Y',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '3779364679',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 558695757.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000LVY9',
#    'endDate': None,
#    'tradingSymbol': 'BRGKX',
#    'legalName': 'iShares Russell 1000 Large-Cap Index Fund Class K',
#    'name': 'iShares Russell 1000 Large-Cap Idx K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1721015000',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 1399532236.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000VW8W',
#    'endDate': None,
#    'tradingSymbol': 'BKTSX',
#    'legalName': 'iShares Total U.S. Stock Market Index Fund Class K',
#    'name': 'iShares Total US Stock Market Idx K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4109359867',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 3598971385.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00DA1',
#    'endDate': None,
#    'tradingSymbol': 'JENSX',
#    'legalName': 'Jensen Quality Growth Fund Class J',
#    'name': 'Jensen Quality Growth J',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '5897237823',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 2024547597.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 1,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 5,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Z27W',
#    'endDate': None,
#    'tradingSymbol': None,
#    'legalName': 'JNL S&P 500 Index Fund Class I',
#    'name': 'JNL S&P 500 Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '533552704',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 533552704.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Z28N',
#    'endDate': None,
#    'tradingSymbol': None,
#    'legalName': 'JNL/Mellon U.S. Stock Market Index Fund Class I',
#    'name': 'JNL/Mellon US Stock Market Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4950534909',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 72752529.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'}],
#  'primaryMedalist': {'secId': 'FOUSA00L83',
#   'endDate': None,
#   'tradingSymbol': 'VTSAX',
#   'legalName': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'medalistRating': '_PO_',
#   'medalistRatingDate': '_PO_',
#   'parentScoreType': None,
#   'peopleScoreType': None,
#   'processScoreType': None,
#   'parentScore': '_PO_',
#   'peopleScore': '_PO_',
#   'processScore': '_PO_',
#   'parentScoreLabel': 'HIGH',
#   'peopleScoreLabel': 'ABOVE_AVERAGE',
#   'processScoreLabel': 'HIGH',
#   'medalistRatingLabel': 'GOLD',
#   'analystDriven': '100',
#   'dataCoverage': '100',
#   'analystRating': None,
#   'overallMorningstarRating': 3,
#   'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#   'ePUsedForOverallRating': None,
#   'trailingYearToDateReturn': None,
#   'trailing1YearReturn': None,
#   'trailing3YearReturn': None,
#   'trailing5YearReturn': None,
#   'ePUsedFor1YearReturn': None,
#   'ePUsedFor5YearReturn': None,
#   'ePUsedFor3YearReturn': None,
#   'expenseRatio': None,
#   'managementExpenseRatio': None,
#   'ongoingCharge': None,
#   'baseCurrencyId': 'USD',
#   'tNAInShareClassCurrency': '1912236548176',
#   'flow1Yr': None,
#   'fundShareClassTypeId': '6',
#   'fundShareClassTypeName': 'Inst',
#   'lastShareClassNetAsset': 418703223349.0,
#   'SecurityType': 'FO',
#   'morningstarRatingFor3Year': 3,
#   'morningstarRatingFor5Year': 3,
#   'morningstarRatingFor10Year': 3,
#   'process': None,
#   'people': None,
#   'parent': None,
#   'sustainabilityFundQuintile': 3,
#   'isLowCarbon': 'false',
#   'isDesignatedLowCarbon': 'false',
#   'domicileCountryId': 'USA'}}

# %% [markdown]
# Meta Data

# %%
funds.metaData()
# Out:
# {'secId': 'FOUSA00L83',
#  'fundId': 'FSUSA002PT',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'tradingSymbol': 'VTSAX',
#  'performanceId': '0P00002YGZ',
#  'masterPortfolioId': '3506',
#  'isin': 'US9229087286',
#  'securityType': 'FO',
#  'shortCountryId': 'USA',
#  'categoryId': '$FOCA$LB$$',
#  'domicileCountryId': 'USA',
#  'fundShareClassId': 'FOUSA00L83',
#  'assetType': 'EQUITY',
#  'quoteTemplate': 'OE_USA_EQUITY',
#  'quoteTemplateForEtf': None,
#  'securityTemplate': 'USA_OE_EQUITY',
#  'priceTemplate': 'USA_OE',
#  'caFundCode': None,
#  'alternativeFundCodes': None,
#  'selectedFundCode': None,
#  'baseCurrencyId': 'USD',
#  'performanceTemplate': 'OE_USA_EQUITY',
#  'countryId': 'USA',
#  'broadCategoryGroupId': '$BCG$EQUTY',
#  'template': 'Equity',
#  'userType': 'Free',
#  'newAssetType': 'EQUITY',
#  'countryOfSales18': 0,
#  'countryOfSales34': 0,
#  'newStatus': 0,
#  'legalStructure': '08',
#  'fundSubType': None,
#  'taxClassDesignation': None}

# %% [markdown]
# Rating of Analyst

# %%
funds.morningstarAnalyst()
# Out:
# {'morningstarRatingFor3Year': 3,
#  'morningstarRatingFor5Year': 3,
#  'morningstarRatingFor10Year': 3,
#  'overallMorningstarRating': 3,
#  'categoryMedalist': [{'secId': 'FOUSA00AOK',
#    'endDate': None,
#    'tradingSymbol': 'DFUSX',
#    'legalName': 'DFA U.S. Large Company Portfolio',
#    'name': 'DFA US Large Company I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-01-30T17:49:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '12882049753',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 12882049753.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000LZSI',
#    'endDate': None,
#    'tradingSymbol': 'FXAIX',
#    'legalName': 'Fidelity 500 Index Fund',
#    'name': 'Fidelity 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-01-30T15:59:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '665836971612',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 665836971612.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Y8H0',
#    'endDate': None,
#    'tradingSymbol': 'FDFIX',
#    'legalName': 'Fidelity Flex 500 Index Fund',
#    'name': 'Fidelity Flex 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-01-30T15:59:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '6504084028',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 6504084028.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000WCQA',
#    'endDate': None,
#    'tradingSymbol': 'FLCPX',
#    'legalName': 'Fidelity SAI U.S. Large Cap Index Fund',
#    'name': 'Fidelity SAI US Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-01-30T15:59:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '14063285773',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 14063285773.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000011YJJ',
#    'endDate': None,
#    'tradingSymbol': 'FCFMX',
#    'legalName': 'Fidelity Series Total Market Index Fund',
#    'name': 'Fidelity Series Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '85391779075',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 85391779075.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000MJS0',
#    'endDate': None,
#    'tradingSymbol': 'FSKAX',
#    'legalName': 'Fidelity Total Market Index Fund',
#    'name': 'Fidelity Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '111510925713',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 111510925713.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000010QVC',
#    'endDate': None,
#    'tradingSymbol': 'FNILX',
#    'legalName': 'Fidelity ZERO Large Cap Index Fund',
#    'name': 'Fidelity ZERO Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '93',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '13565110871',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 13565110871.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Y8GT',
#    'endDate': None,
#    'tradingSymbol': 'FZROX',
#    'legalName': 'Fidelity ZERO Total Market Index Fund',
#    'name': 'Fidelity ZERO Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '93',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '27741669557',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 27741669557.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA057GT',
#    'endDate': None,
#    'tradingSymbol': 'GQEFX',
#    'legalName': 'GMO Quality Fund Class IV',
#    'name': 'GMO Quality IV',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '10739035000',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 1060405100.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Y66G',
#    'endDate': None,
#    'tradingSymbol': 'GSPFX',
#    'legalName': 'Gotham Enhanced S&P 500 Index Fund Institutional Class',
#    'name': 'Gotham Enhanced S&P 500 Index Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '0',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '22856672',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 22856672.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000010SV0',
#    'endDate': None,
#    'tradingSymbol': 'GQEIX',
#    'legalName': 'GQG Partners US Select Quality Equity Fund Institutional Shares',
#    'name': 'GQG Partners US Select Quality Eq Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-20T17:02:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4074394438',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 3476298299.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00B6B',
#    'endDate': None,
#    'tradingSymbol': 'WFSPX',
#    'legalName': 'iShares S&P 500 Index Fund Class K',
#    'name': 'iShares S&P 500 Index K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-01-29T21:51:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '49610674370',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 18738802740.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000015VV2',
#    'endDate': None,
#    'tradingSymbol': 'NWAVX',
#    'legalName': 'Nationwide GQG US Quality Equity Fund Class R6',
#    'name': 'Nationwide GQG US Quality Eq R6',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '273838879',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 196546275.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00K0Q',
#    'endDate': None,
#    'tradingSymbol': 'SWTSX',
#    'legalName': 'Schwab Total Stock Market Index Fund®',
#    'name': 'Schwab Total Stock Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-02-07T23:22:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '29265377924',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 29265377924.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00JLQ',
#    'endDate': None,
#    'tradingSymbol': 'SWPPX',
#    'legalName': 'Schwab® S&P 500 Index Fund',
#    'name': 'Schwab® S&P 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '119690329757',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 119690329757.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000T8Y5',
#    'endDate': None,
#    'tradingSymbol': 'SSEYX',
#    'legalName': 'State Street Equity 500 Index II Portfolio',
#    'name': 'State Street Equity 500 Index II',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-01-30T16:46:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '19194489043',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 19194489043.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000ZXDE',
#    'endDate': None,
#    'tradingSymbol': 'FCTDX',
#    'legalName': 'Strategic Advisers Fidelity U.S. Total Stock Fund',
#    'name': 'Strategic Advisers Fidelity US TtlStk',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '163505080000',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 163505080000.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00EJ4',
#    'endDate': None,
#    'tradingSymbol': 'PRDGX',
#    'legalName': 'T. Rowe Price Dividend Growth Fund',
#    'name': 'T. Rowe Price Dividend Growth',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-04-02T19:41:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '24188885999',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 12412829298.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00FUG',
#    'endDate': None,
#    'tradingSymbol': 'VDIGX',
#    'legalName': 'Vanguard Dividend Growth Fund Investor Shares',
#    'name': 'Vanguard Dividend Growth Inv',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-04-01T19:55:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '47611990745',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 47611990745.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00FR3',
#    'endDate': None,
#    'tradingSymbol': 'VINIX',
#    'legalName': 'Vanguard Institutional Index Fund Institutional Shares',
#    'name': 'Vanguard Institutional Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-01-28T00:22:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '321075200378',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 124697021240.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA02T7X',
#    'endDate': None,
#    'tradingSymbol': 'VITPX',
#    'legalName': 'Vanguard Institutional Total Stock Market Index Fund Institutional Plus Shares',
#    'name': 'Vanguard Instl Ttl Stk Mkt Idx InstlPls',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-01-29T20:42:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '30164241608',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 28475990137.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA02TYG',
#    'endDate': None,
#    'tradingSymbol': 'VTCLX',
#    'legalName': 'Vanguard Tax-Managed Capital Appreciation Fund Admiral Shares',
#    'name': 'Vanguard Tax-Managed Capital App Adm',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-03-13T19:56:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '24646109326',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 20824680779.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00FUA',
#    'endDate': None,
#    'tradingSymbol': 'WFIOX',
#    'legalName': 'Allspring Index Fund - Class Admin',
#    'name': 'Allspring Index Admin',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1366285281',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 420698169.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00FUP',
#    'endDate': None,
#    'tradingSymbol': 'AWSHX',
#    'legalName': 'American Funds Washington Mutual Investors Fund Class A',
#    'name': 'American Funds Washington Mutual A',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-07-01T17:05:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '202060453473',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '1',
#    'fundShareClassTypeName': 'A',
#    'lastShareClassNetAsset': 92795376574.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000013TAS',
#    'endDate': None,
#    'tradingSymbol': 'AVUSX',
#    'legalName': 'Avantis® U.S. Equity Fund Institutional Class',
#    'name': 'Avantis® U.S. Equity Institutional',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-20T15:29:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '925595392',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 679663423.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000W3UB',
#    'endDate': None,
#    'tradingSymbol': 'BIRIX',
#    'legalName': 'BlackRock Sustainable Advantage Large Cap Core Fund Institutional Shares',
#    'name': 'BlackRock Sustainable Adg Lg Cp Cr Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2024-10-18T17:28:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '879529439',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 363059789.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00ER2',
#    'endDate': None,
#    'tradingSymbol': 'DSPIX',
#    'legalName': 'BNY Mellon Institutional S&P 500 Stock Index Fund Class I',
#    'name': 'BNY Mellon Instl S&P 500 Stk Idx I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1554197365',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1554197365.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00001DJ2I',
#    'endDate': None,
#    'tradingSymbol': 'BBTLX',
#    'legalName': 'Bridge Builder Tax Managed Large Cap Fund',
#    'name': 'Bridge Builder Tax Managed Large Cap',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '45',
#    'dataCoverage': '88',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '6684603180',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 6684603180.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000LL3D',
#    'endDate': None,
#    'tradingSymbol': 'CUSEX',
#    'legalName': 'Capital Group U.S. Equity Fund',
#    'name': 'Capital Group US Equity',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '55',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '387083916',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 387083916.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00001BQAK',
#    'endDate': None,
#    'tradingSymbol': 'CRQSX',
#    'legalName': 'Catholic Responsible Investments Equity Index Fund Institutional Shares',
#    'name': 'Catholic Rspnsbl Invst Equity Idx Ins',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
# ...
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '5373176401',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 3822350042.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA02TLS',
#    'endDate': None,
#    'tradingSymbol': 'HSTAX',
#    'legalName': 'Hartford Stock HLS Fund Class IA',
#    'name': 'Hartford Stock HLS IA',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-04-01T19:55:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1229620351',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1130191344.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 1,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00JVG',
#    'endDate': None,
#    'tradingSymbol': 'SPIDX',
#    'legalName': 'Invesco S&P 500 Index Fund Class Y',
#    'name': 'Invesco S&P 500 Index Y',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '3779364679',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 558695757.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000LVY9',
#    'endDate': None,
#    'tradingSymbol': 'BRGKX',
#    'legalName': 'iShares Russell 1000 Large-Cap Index Fund Class K',
#    'name': 'iShares Russell 1000 Large-Cap Idx K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-02-19T17:22:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1721015000',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 1399532236.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000VW8W',
#    'endDate': None,
#    'tradingSymbol': 'BKTSX',
#    'legalName': 'iShares Total U.S. Stock Market Index Fund Class K',
#    'name': 'iShares Total US Stock Market Idx K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4109359867',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 3598971385.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00DA1',
#    'endDate': None,
#    'tradingSymbol': 'JENSX',
#    'legalName': 'Jensen Quality Growth Fund Class J',
#    'name': 'Jensen Quality Growth J',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2024-09-26T19:50:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '5897237823',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 2024547597.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 1,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 5,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Z27W',
#    'endDate': None,
#    'tradingSymbol': None,
#    'legalName': 'JNL S&P 500 Index Fund Class I',
#    'name': 'JNL S&P 500 Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '533552704',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 533552704.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000Z28N',
#    'endDate': None,
#    'tradingSymbol': None,
#    'legalName': 'JNL/Mellon U.S. Stock Market Index Fund Class I',
#    'name': 'JNL/Mellon US Stock Market Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-31T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4950534909',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 72752529.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA'}],
#  'primaryMedalist': {'secId': 'FOUSA00L83',
#   'endDate': None,
#   'tradingSymbol': 'VTSAX',
#   'legalName': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'medalistRating': '_PO_',
#   'medalistRatingDate': '2025-01-29T20:42:00.000',
#   'parentScoreType': None,
#   'peopleScoreType': None,
#   'processScoreType': None,
#   'parentScore': '_PO_',
#   'peopleScore': '_PO_',
#   'processScore': '_PO_',
#   'parentScoreLabel': 'HIGH',
#   'peopleScoreLabel': 'ABOVE_AVERAGE',
#   'processScoreLabel': 'HIGH',
#   'medalistRatingLabel': 'GOLD',
#   'analystDriven': '100',
#   'dataCoverage': '100',
#   'analystRating': None,
#   'overallMorningstarRating': 3,
#   'overallMorningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#   'ePUsedForOverallRating': None,
#   'trailingYearToDateReturn': None,
#   'trailing1YearReturn': None,
#   'trailing3YearReturn': None,
#   'trailing5YearReturn': None,
#   'ePUsedFor1YearReturn': None,
#   'ePUsedFor5YearReturn': None,
#   'ePUsedFor3YearReturn': None,
#   'expenseRatio': None,
#   'managementExpenseRatio': None,
#   'ongoingCharge': None,
#   'baseCurrencyId': 'USD',
#   'tNAInShareClassCurrency': '1912236548176',
#   'flow1Yr': None,
#   'fundShareClassTypeId': '6',
#   'fundShareClassTypeName': 'Inst',
#   'lastShareClassNetAsset': 418703223349.0,
#   'SecurityType': 'FO',
#   'morningstarRatingFor3Year': 3,
#   'morningstarRatingFor5Year': 3,
#   'morningstarRatingFor10Year': 3,
#   'process': None,
#   'people': None,
#   'parent': None,
#   'sustainabilityFundQuintile': 3,
#   'isLowCarbon': 'false',
#   'isDesignatedLowCarbon': 'false',
#   'domicileCountryId': 'USA'},
#  'analystRating': '_PO_',
#  'analystRatingDate': '2023-03-06 00:00:00.0',
#  'morningstarRatingDate': '2025-06-30 00:00:00.0',
#  'history': [{'date': '2022-07-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2022-08-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2022-09-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2022-10-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2022-11-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2022-12-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-01-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-02-28T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-03-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-04-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-05-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-06-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-07-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-08-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-09-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-10-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-11-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-12-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-01-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-02-29T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-03-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-04-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-05-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-06-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-07-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-08-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-09-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-10-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-11-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-12-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-01-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-02-28T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-03-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-04-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-05-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-06-30T00:00:00.000', 'rating': '_PO_'}],
#  'userType': 'Free',
#  'categoryName': 'US Fund Large Blend',
#  'flagshipShareClassID': None,
#  'flagshipName': None,
#  'isAusFlagship': False,
#  'quantHistory': [],
#  'quantRating': None,
#  'quantRatingDate': None}

# %% [markdown]
# Morningstar’s Analysis - Our Take
#
# https://www.morningstar.com/funds/xnas/vtsax/analysis

# %%
funds.morningstarOpinion()
# Out:
# {'analysis': {'authorId': 2835,
#   'title': 'A one-stop shop for all US stocks.',
#   'publishDate': '2025-01-29T14:42:00.000',
#   'scorePublishDate': '2025-01-29T14:42:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'process': {'authorId': 2835,
#   'title': 'This strategy constructs a broadly diversified portfolio that accurately captures the entire investable US equity market.',
#   'publishDate': '2025-01-29T14:42:00.000',
#   'scorePublishDate': '2025-01-29T14:42:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'parent': {'authorId': 2118,
#   'title': 'The Vanguard Group retains a High Parent rating as its new CEO settles in.',
#   'publishDate': '2024-10-02T14:14:00.000',
#   'scorePublishDate': '2024-10-02T14:14:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Daniel Sotiroff',
#   'content': None,
#   'authorTitle': 'Senior Analyst'},
#  'people': {'authorId': 2835,
#   'title': "Vanguard's equity index group earns an Above Average People Pillar for its well-supported and stable management team adept at leveraging Vanguard's comprehensive resources.",
#   'publishDate': '2025-01-29T14:42:00.000',
#   'scorePublishDate': '2025-01-29T14:42:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'price': {'authorId': 2835,
#   'title': 'It’s critical to evaluate expenses, as they come directly out of returns.',
#   'publishDate': '2025-01-29T14:42:00.000',
#   'scorePublishDate': '2025-01-29T14:42:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'performance': {'authorId': 2835,
#   'title': 'This strategy accurately represents the investable US equity market, allowing the fund to leverage its cost advantage and drive sound category-relative performance.',
#   'publishDate': '2025-01-29T14:42:00.000',
#   'scorePublishDate': '2025-01-29T14:42:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'reasonMissing': None,
#  'notes': None,
#  'processText': ['This strategy constructs a broadly diversified portfolio that accurately captures the entire investable US equity market. It also keeps a lid on turnover by leveraging the market’s collective wisdom to size its positions. These simple yet effective traits earn a High Process Pillar rating.'],
#  'portfolioText': ['The fund tracks the CRSP US Total Market Index. The index ranks all US stocks by their float-adjusted market cap after they pass basic liquidity and volume screens to ensure investability and easier tracking. Eligible stocks must have a market cap of at least USD 15 million and at least 12.5% of total shares publicly available. The index implements buffers along the lower market-cap bound to mitigate unnecessary turnover. It also spreads the rebalancing process over a five-day period to reduce potential market impact costs. The index reconstitutes quarterly.',
#   'The strategy approximates the contours of the US stock market because it relies on the market’s collective wisdom to size stock and sector weightings. Its sector composition is in line with the US large-blend category average, with no sector deviating more than 2 percentage points as of year-end 2024. Its value-growth bias also falls in line with its category peers. ',
#   'Market-cap weighting consistently guides the index toward the largest and most established names. Small-cap stocks represent a much smaller slice of the portfolio. About 90% of the strategy’s assets represented companies with a wide or narrow Morningstar Economic Moat Rating at year-end 2024.',
#   'This portfolio tends to diversify away stock-specific risk. It has been significantly less concentrated than its average peer from its inception through year-end 2024. The strategy held 32% of its portfolio in the top 10, versus the US category average of 51% at year-end 2024. However, the fund’s share of assets in the top 10 holdings more than doubled since 2015. Apple and Microsoft have been fighting for the top two spots, and their collective share of the portfolio grew to 12% from 4% during that time.'],
#  'ecl': {'sustainabilityDistribution': {'sec_id': 'FOUSA00L83',
#    'end_date': '2025-04-30T05:00:00.000',
#    'publishDate': '2025-06-30T03:05:44.000',
#    'title': 'Vanguard Total Stock Market Index Fund may not appeal to sustainability-conscious investors.',
#    'content': ["Vanguard Total Stock Market Index Fund's holdings are exposed to average levels of ESG risk relative to those of its peers in the US Equity Large Cap Blend category, thus earning it an average Morningstar Sustainability Rating of 3 globes. Competing funds in the category with ratings of 4 or 5 globes have less ESG risk in their holdings. ESG risk provides investors with a signal that reflects to what degree their investments are exposed to risks related to material ESG issues, including climate change, biodiversity, product safety, community relations, data privacy and security, bribery and corruption, and corporate governance, that are not sufficiently managed. ESG risk differs from impact, which is about seeking positive environmental and social outcomes.",
#     'Vanguard Total Stock Market Index Fund has an asset-weighted Carbon Risk Score of 7.4, indicating that its companies have low exposure to carbon-related risks. These are risks associated with the transition to a low-carbon economy such as increased regulation, changing consumer preferences, technological advancements, and stranded assets.',
#     'One potential issue for a sustainability-focused investor is that Vanguard Total Stock Market Index Fund doesn’t have an ESG-focused mandate. Funds with an ESG-focused mandate would have a higher probability to drive positive ESG outcomes.',
#     'Currently, the fund has 8.3% involvement in fossil fuels, which is roughly in line with 8.6% for its average category peer. Companies are considered involved in fossil fuels if they derive some revenue from thermal coal, oil, and gas. The fund exhibits moderate exposure (8.01%) to companies with high or severe controversies. Controversies are incidents that have a negative impact on stakeholders or the environment, which create some degree of financial risk for the company. Examples of types of controversies include bribery and corruption scandals, workplace discrimination and environmental incidents. Severe and high controversies can have significant financial repercussions, ranging from legal penalties to consumer boycotts. Such controversies can also damage the reputation of both companies themselves and their shareholders.'],
#    'isDefaultText': False},
#   'assetManager': None},
#  'userType': 'Free',
#  'id': 0,
#  'rpsCovered': True,
#  'isLocalized': False,
#  'shareClassId': 'FOUSA00L83',
#  'flagshipShareClassID': None,
#  'flagshipName': None,
#  'isRatingV2': True,
#  'isAusFlagship': False,
#  'suitability': None,
#  'fundamental': None,
#  'fees': None,
#  'portfolioConstruction': None,
#  'alternatives': None,
#  'analystDrivenPortion': '100',
#  'dataCoverage': '100',
#  'translationautomated': False}

# %% [markdown]
# Fixed Income Exposure Analysis
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
ms.Funds("IE00B04GQT48").multiLevelFixedIncomeData()
# Out:
# {'fundName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'assetType': 'FIXEDINCOME',
#  'asOfDate': '2025-06-30T00:00:00.000',
#  'primary': 'superEffectiveDuration',
#  'secondary': 'superSector',
#  'data': [{'secondaryAttributeName': 'Government',
#    'weight': 13.56588,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.06351,
#     '1 to 3%': 4.59588,
#     '3 to 5%': 3.61786,
#     '5 to 7%': 2.10837,
#     '7 to 10%': 1.19728,
#     '10 to 20%': 1.98298,
#     'Greater than 20%': None,
#     'Unknown': None,
#     'Not Applicable': None,
#     'weight': 13.56588}},
#   {'secondaryAttributeName': 'Municipal',
#    'weight': 1.1864,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.00316,
#     '1 to 3%': 0.05674,
#     '3 to 5%': 0.1575,
#     '5 to 7%': 0.12306,
#     '7 to 10%': 0.34928,
#     '10 to 20%': 0.49041,
#     'Greater than 20%': None,
#     'Unknown': 0.00625,
#     'Not Applicable': None,
#     'weight': 1.1864}},
#   {'secondaryAttributeName': 'Corporate',
#    'weight': 81.70452,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.68752,
#     '1 to 3%': 20.7163,
#     '3 to 5%': 17.24488,
#     '5 to 7%': 15.1813,
#     '7 to 10%': 7.98905,
#     '10 to 20%': 19.63963,
#     'Greater than 20%': None,
#     'Unknown': 0.24583,
#     'Not Applicable': None,
#     'weight': 81.70452}},
#   {'secondaryAttributeName': 'Securitized',
#    'weight': 2.87118,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.18532,
#     '1 to 3%': 1.26748,
#     '3 to 5%': 0.71199,
#     '5 to 7%': 0.56476,
#     '7 to 10%': 0.07873,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': 0.0629,
#     'Not Applicable': None,
#     'weight': 2.87118}},
#   {'secondaryAttributeName': 'Derivatives',
#    'weight': None,
#    'primaryData': {'Negative': None,
#     '0 to 1%': None,
#     '1 to 3%': None,
#     '3 to 5%': None,
#     '5 to 7%': None,
#     '7 to 10%': None,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': None,
#     'Not Applicable': None,
#     'weight': None}},
#   {'secondaryAttributeName': 'Cash & Equivalents',
#    'weight': None,
#    'primaryData': {'Negative': None,
#     '0 to 1%': None,
#     '1 to 3%': None,
#     '3 to 5%': None,
#     '5 to 7%': None,
#     '7 to 10%': None,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': None,
#     'Not Applicable': None,
#     'weight': None}},
#   {'secondaryAttributeName': 'Unknown',
#    'weight': 0.67202,
#    'primaryData': {'Negative': None,
#     '0 to 1%': None,
#     '1 to 3%': None,
#     '3 to 5%': 0.01588,
#     '5 to 7%': None,
#     '7 to 10%': 0.01011,
#     '10 to 20%': 0.01279,
#     'Greater than 20%': None,
#     'Unknown': 0.63324,
#     'Not Applicable': None,
#     'weight': 0.67202}}]}

# %% [markdown]
# Historical Net Asset Value and Total Return
#
# Fund Chart
#
# https://www.morningstar.com/funds/xnas/vtsax/chart

# %%
import datetime
end_date = datetime.datetime.today()
start_date = end_date - datetime.timedelta(30)
funds.nav(start_date,end_date)
# Out:
# [{'nav': 143.17, 'totalReturn': 221.11497, 'date': '2025-06-18'},
#  {'nav': 142.87, 'totalReturn': 220.65164, 'date': '2025-06-20'},
#  {'nav': 144.22, 'totalReturn': 222.73661, 'date': '2025-06-23'},
#  {'nav': 145.88, 'totalReturn': 225.30035, 'date': '2025-06-24'},
#  {'nav': 145.69, 'totalReturn': 225.00691, 'date': '2025-06-25'},
#  {'nav': 146.97, 'totalReturn': 226.98377, 'date': '2025-06-26'},
#  {'nav': 147.67, 'totalReturn': 228.06487, 'date': '2025-06-27'},
#  {'nav': 148.01, 'totalReturn': 229.27106, 'date': '2025-06-30'},
#  {'nav': 147.93, 'totalReturn': 229.14714, 'date': '2025-07-01'},
#  {'nav': 148.73, 'totalReturn': 230.38636, 'date': '2025-07-02'},
#  {'nav': 150.01, 'totalReturn': 232.36911, 'date': '2025-07-03'},
#  {'nav': 148.8, 'totalReturn': 230.49479, 'date': '2025-07-07'},
#  {'nav': 148.74, 'totalReturn': 230.40185, 'date': '2025-07-08'},
#  {'nav': 149.69, 'totalReturn': 231.87342, 'date': '2025-07-09'},
#  {'nav': 150.1, 'totalReturn': 232.50852, 'date': '2025-07-10'},
#  {'nav': 149.48, 'totalReturn': 231.54813, 'date': '2025-07-11'},
#  {'nav': 149.82, 'totalReturn': 232.0748, 'date': '2025-07-14'},
#  {'nav': 149.02, 'totalReturn': 230.83558, 'date': '2025-07-15'},
#  {'nav': 149.59, 'totalReturn': 231.71852, 'date': '2025-07-16'},
#  {'nav': 150.5, 'totalReturn': 233.12813, 'date': '2025-07-17'}]

# %% [markdown]
# Other fees
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.otherFee()
# Out:
# {'actualManagementFee': 0.04,
#  'maximumManagementFee': 0.04,
#  'actual12b1': None,
#  'administrativeFee': 0.0336,
#  'expenseWaivers': None,
#  'performanceFee': None,
#  'fundSubType': None}

# %% [markdown]
# Ownership zone
#
# Style box - map
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.ownershipZone()
# Out:
# {'portfolioDate': '2025-05-31T05:00:00.000',
#  'fund': {'portfolioDate': '2025-05-31T05:00:00.000',
#   'scaledSizeScore': 270.243,
#   'scaledStyleScore': 146.167,
#   'sizeVariance': 113.826,
#   'styleVariance': 128.186,
#   'rho': 0.187,
#   'secId': 'FOUSA00L83',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'objectZone75Percentile': 2.489},
#  'benchmark': {'portfolioDate': '2025-06-30T05:00:00.000',
#   'scaledSizeScore': 297.74,
#   'scaledStyleScore': 147.497,
#   'sizeVariance': 93.864,
#   'styleVariance': 127.934,
#   'rho': 0.23,
#   'secId': 'F00000GWXD',
#   'name': 'Morningstar US Large-Mid TR USD',
#   'objectZone75Percentile': 2.551},
#  'category': {'portfolioDate': '2025-06-30T05:00:00.000',
#   'scaledSizeScore': 312.978,
#   'scaledStyleScore': 153.745,
#   'sizeVariance': 96.371,
#   'styleVariance': 123.967,
#   'rho': 0.283,
#   'secId': '$FOCA$LB$$',
#   'name': 'Large Blend',
#   'objectZone75Percentile': 2.613}}

# %% [markdown]
# Rating of top rated medalists funds of the asset manager
#
# Rating Breakdown - Medalist Rating
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentMedal()
# Out:
# {'userType': 'Free',
#  'analystRatingFundList': [{'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'calendarYearFlow': 9415656518.0,
#    'netAsset': 786337258753.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 19.04603,
#    'trailing3YearReturnRank': 39.0,
#    'fundShareClassId': 'F00000VE7X',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA002PT',
#    'secId': 'F00000VE7X',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'calendarYearFlow': -15928247136.0,
#    'netAsset': 586598496648.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 19.65995,
#    'trailing3YearReturnRank': 23.0,
#    'fundShareClassId': 'FOUSA00L8W',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA002QH',
#    'secId': 'FOUSA00L8W',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'calendarYearFlow': 1380413493.0,
#    'netAsset': 234254459616.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 13.73202,
#    'trailing3YearReturnRank': 77.0,
#    'fundShareClassId': 'FOUSA00KIR',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA004JJ',
#    'secId': 'FOUSA00KIR',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'calendarYearFlow': -3932520588.0,
#    'netAsset': 196378179138.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 19.68529,
#    'trailing3YearReturnRank': 22.0,
#    'fundShareClassId': 'FOUSA00GPG',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA002Q0',
#    'secId': 'FOUSA00GPG',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'calendarYearFlow': 7985822603.0,
#    'netAsset': 166807538024.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 2.6004,
#    'trailing3YearReturnRank': 52.0,
#    'fundShareClassId': 'FOUSA08OZU',
#    'name': '_PO_',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'fundId': 'FSUSA09PA2',
#    'secId': 'FOUSA08OZU',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2025-06-30T05:00:00.000',
#  'footerReturnDate': '2025-06-30T05:00:00.000',
#  'currency': 'USD',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Breakdown of asset manager funds by medalist rating
#
# Rating Breakdown - Medalist Rating
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentMedaListRating()
# Out:
# [{'rating': None,
#   'medalistRating': '7',
#   'medalistRatingLabel': 'GOLD',
#   'shareClassCount': 106,
#   'percent': 0.7456841595,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '6',
#   'medalistRatingLabel': 'SILVER',
#   'shareClassCount': 101,
#   'percent': 0.1329987125,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '5',
#   'medalistRatingLabel': 'BRONZE',
#   'shareClassCount': 58,
#   'percent': 0.1158315591,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '4',
#   'medalistRatingLabel': 'NEUTRAL',
#   'shareClassCount': 10,
#   'percent': 0.0054855689,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '3',
#   'medalistRatingLabel': 'NEGATIVE',
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '2',
#   'medalistRatingLabel': 'UNDER_REVIEW',
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False}]

# %% [markdown]
# Breakdown of asset manager funds by star rating
#
# Rating Breakdown - Morningstar Rating
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentMstarRating()
# Out:
# [{'naPercentage': 0.0006052299, 'mstarRating': '1'},
#  {'naPercentage': 0.0217474786, 'mstarRating': '2'},
#  {'naPercentage': 0.5173783902, 'mstarRating': '3'},
#  {'naPercentage': 0.2914460753, 'mstarRating': '4'},
#  {'naPercentage': 0.1674096282, 'mstarRating': '5'},
#  {'naPercentage': 0.0014131979, 'mstarRating': 'Not Rated'}]

# %% [markdown]
# Recent change in rating
#
# Rating Breakdown - Medalist List - Recent Investment Ratings Change
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentRatingRecentChange()
# Out:
# {'topAnalystRatingUpDownList': [{'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '4',
#    'medalistPrevRating': '2',
#    'medalistCurrRatingLabel': 'NEUTRAL',
#    'medalistPrevRatingLabel': 'UNDER_REVIEW',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2025-07-08T05:00:00.000',
#    'medalistPrevRatingDate': '2025-06-16T20:55:00.000',
#    'netAsset': 11725879136.0,
#    'fundId': 'FSUSA002L7',
#    'securityType': 'FO',
#    'secId': 'FOUSA00FIG'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '6',
#    'medalistPrevRating': '2',
#    'medalistCurrRatingLabel': 'SILVER',
#    'medalistPrevRatingLabel': 'UNDER_REVIEW',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2025-07-17T05:00:00.000',
#    'medalistPrevRatingDate': '2025-07-07T18:39:00.000',
#    'netAsset': 1222166813.0,
#    'fundId': 'FS0000F6SK',
#    'securityType': 'FO',
#    'secId': 'F000013C48'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '6',
#    'medalistPrevRating': '6',
#    'medalistCurrRatingLabel': 'SILVER',
#    'medalistPrevRatingLabel': 'SILVER',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2025-07-14T05:00:00.000',
#    'medalistPrevRatingDate': '2024-07-16T00:47:00.000',
#    'netAsset': 4648389100.0,
#    'fundId': 'FSUSA0A4QR',
#    'securityType': 'FO',
#    'secId': 'F000003Z36'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '6',
#    'medalistPrevRating': '7',
#    'medalistCurrRatingLabel': 'SILVER',
#    'medalistPrevRatingLabel': 'GOLD',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2025-07-01T05:00:00.000',
#    'medalistPrevRatingDate': '2024-07-02T00:29:00.000',
#    'netAsset': 4870132386.0,
#    'fundId': 'FSUSA002QX',
#    'securityType': 'FO',
#    'secId': 'FOUSA00FTH'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '6',
#    'medalistPrevRating': '7',
#    'medalistCurrRatingLabel': 'SILVER',
#    'medalistPrevRatingLabel': 'GOLD',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2025-07-01T05:00:00.000',
#    'medalistPrevRatingDate': '2024-07-02T00:29:00.000',
#    'netAsset': 12585930855.0,
#    'fundId': 'FSUSA065DY',
#    'securityType': 'FO',
#    'secId': 'FOUSA05B7U'}],
#  'userType': 'Free',
#  'currency': 'USD',
#  'securityType': 'FO',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'secId': 'FOUSA00L83',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Information about the asset manager
#
# Parent
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentSummary()
# Out:
# {'secId': 'FOUSA00L83',
#  'fundId': 'FSUSA002PT',
#  'companyId': '0C00001YUF',
#  'marketName': 'US Open-end ex MM ex FoF ex Feeder',
#  'firmName': 'Vanguard',
#  'currency': 'USD',
#  'netAsset': 5952615841955.0,
#  'netFlowTTM': -129674343114.0,
#  'netAssetTTM': 5430862178294.0,
#  'assetGrowthRate': -0.0238773032,
#  'numFund': 149,
#  'managerRetention5Year': 91.62,
#  'template': 'USA_OE',
#  'domicileCountryId': 'USA'}

# %% [markdown]
# People who manage the fund
#
# Management Team
#
# https://www.morningstar.com/funds/xnas/vtsax/people

# %%
funds.people()
# Out:
# {'inceptionDate': '2000-11-13T06:00:00.000',
#  'averageManagerTenure': 4.03,
#  'longestManagerTenure': 9.25,
#  'advisorType': 'Vanguard Group Inc',
#  'subadvised': '0',
#  'managerCount': 3,
#  'womenOnTeams': None,
#  'advisorList': [{'advisorId': '0C00001G3E',
#    'advisorDisplayName': 'Vanguard Group Inc',
#    'regionId': None,
#    'languageId': None,
#    'subAdvisorId': None,
#    'subAdvisorName': None}],
#  'subAdvisorList': [],
#  'currentManagerList': [{'personId': '168359',
#    'familyName': 'Nejman',
#    'middleName': None,
#    'givenName': 'Walter',
#    'startDate': '2016-04-27T05:00:00.000',
#    'ownershipLevelId': '1',
#    'endDate': None,
#    'gender': 'male',
#    'genderSourceType': 'reported'},
#   {'personId': '182724',
#    'familyName': 'Louie',
#    'middleName': None,
#    'givenName': 'Michelle',
#    'startDate': '2023-02-17T06:00:00.000',
#    'ownershipLevelId': '7',
#    'endDate': None,
#    'gender': 'female',
#    'genderSourceType': 'derived'},
#   {'personId': '205451',
#    'familyName': 'Birkett',
#    'middleName': None,
#    'givenName': 'Nick',
#    'startDate': '2025-02-18T06:00:00.000',
#    'ownershipLevelId': '1',
#    'endDate': None,
#    'gender': 'male',
#    'genderSourceType': 'derived'}],
#  'pastManagerList': [{'personId': '1597',
#    'familyName': 'Sauter',
#    'middleName': 'U.',
#    'givenName': 'George',
#    'startDate': '1992-04-27T05:00:00.000',
#    'ownershipLevelId': None,
#    'endDate': '2005-04-29T05:00:00.000',
#    'gender': 'male',
#    'genderSourceType': 'reported'},
#   {'personId': '98675',
#    'familyName': 'O’Reilly',
#    'middleName': 'C.',
#    'givenName': 'Gerard',
#    'startDate': '1994-12-31T06:00:00.000',
#    'ownershipLevelId': '6',
#    'endDate': '2025-06-18T05:00:00.000',
#    'gender': 'male',
#    'genderSourceType': 'reported'}],
#  'lastTurnoverRatio': 0.02,
#  'longestTenureStartDate': '2016-04-27'}

# %% [markdown]
# Performance of the fund, category and index by year
#
# Annual Returns
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.performanceTable()
# Out:
# {'userType': 'Free',
#  'baseCurrency': 'USD',
#  'domicileCountryId': 'USA',
#  'asOfDate': '2025-07-17T00:00:00.000',
#  'startDate': '2015-01-01T00:00:00.000',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'table': {'columnDefs': ['2015',
#    '2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    'YTD'],
#   'growth10KReturnData': [{'label': 'fund',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['0.38764',
#      '12.66422',
#      '21.16927',
#      '-5.1711',
#      '30.80497',
#      '20.98791',
#      '25.71229',
#      '-19.52516',
#      '26.00822',
#      '23.74332',
#      '7.40782'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'category',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['-1.06996',
#      '10.36891',
#      '20.43837',
#      '-6.26928',
#      '28.77649',
#      '15.82748',
#      '26.06759',
#      '-16.95545',
#      '22.31864',
#      '21.44601',
#      '7.0525'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'index',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['0.92191',
#      '11.58523',
#      '21.71165',
#      '-4.52374',
#      '31.60802',
#      '21.10674',
#      '26.44469',
#      '-19.49782',
#      '26.85193',
#      '25.06815',
#      '7.96348'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'percentileRank',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['38',
#      '20',
#      '45',
#      '42',
#      '39',
#      '17',
#      '63',
#      '75',
#      '33',
#      '43',
#      '49'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'fundNumber',
#     'endDate': '2025-07-17T00:00:00.000',
#     'datum': ['1606',
#      '1409',
#      '1396',
#      '1402',
#      '1387',
#      '1363',
#      '1382',
#      '1358',
#      '1430',
#      '1386',
#      '1392'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'categoryName',
#     'endDate': None,
#     'datum': ['US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend'],
#     'epFlag': []},
#    {'label': 'categoryNameAbbr',
#     'endDate': None,
#     'datum': ['LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB'],
#     'epFlag': []}]},
#  'currentValues': [{'type': 'fund',
#    'name': 'VTSAX',
#    'baseCurrency': 'USD',
#    'currentValue': '34846.57176369192',
#    'currentSymbol': '$'},
#   {'type': 'index',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': '36366.31522149636',
#    'currentSymbol': '$'},
#   {'type': 'category',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': '29753.51369119159',
#    'currentSymbol': '$'}]}

# %% [markdown]
# Holdings in dict format
#
# Holdings
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.position()
# Out:
# {'masterPortfolioId': '3506',
#  'secId': 'FOUSA00L83',
#  'baseCurrencyId': 'USD',
#  'domicileCountryId': 'USA',
#  'numberOfHolding': 3559,
#  'numberOfEquityHolding': 3552,
#  'numberOfBondHolding': 0,
#  'numberOfOtherHolding': 7,
#  'numberOfHoldingShort': 2,
#  'numberOfEquityHoldingShort': 0,
#  'numberOfBondHoldingShort': 0,
#  'numberOfOtherHoldingShort': 2,
#  'topNCount': 0,
#  'portfolioSuppression': '0',
#  'assetType': 'EQUITY',
#  'holdingSummary': {'portfolioDate': '2025-05-31T05:00:00.000',
#   'topHoldingWeighting': 31.20963,
#   'equityNumberOfHolding': 3552,
#   'fixedIncomeNumberOfHolding': 0,
#   'numberOfHolding': 3561,
#   'numberOfOtherHolding': 9,
#   'lastTurnover': 2.0,
#   'LastTurnoverDate': '2024-12-31T06:00:00.000',
#   'secId': 'FOUSA00L83',
#   'averageTurnoverRatio': 46.79362,
#   'womenDirectors': 34.94,
#   'womenExecutives': 26.69},
#  'holdingActiveShare': {'activeShareValue': None,
#   'activeShareDate': None,
#   'etfBenchmarkProxyName': None,
#   'primaryProspectusBenchmark': 'CRSP US Total Market TR USD'},
#  'equityHoldingPage': {'pageSize': 10000,
#   'pageNumber': 1,
#   'totalPage': 1,
#   'numberOfCurPageHolding': 3554,
#   'numberOfAllHolding': 3554,
#   'holdingList': [{'securityName': 'Microsoft Corp',
#     'secId': '0P000003MH',
#     'performanceId': '0P000003MH',
#     'holdingTypeId': 'E',
#     'weighting': 6.02457,
#     'numberOfShare': 238818012.0,
#     'marketValue': 109942260004.0,
#     'shareChange': 282870.0,
#     'country': 'United States',
#     'ticker': 'MSFT',
#     'totalReturn1Year': 16.103,
#     'forwardPERatio': 34.0136,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [93097490907.0,
#       88204381129.0,
#       94283400227.0,
#       109942260004.0]},
#     'holdingType': 'Equity',
#     'isin': 'US5949181045',
#     'cusip': '594918104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 17.3926,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 109942260004.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'NVIDIA Corp',
#     'secId': '0P000003RE',
#     'performanceId': '0P000003RE',
#     'holdingTypeId': 'E',
#     'weighting': 5.51387,
#     'numberOfShare': 744635666.0,
#     'marketValue': 100622617547.0,
#     'shareChange': 870143.0,
#     'country': 'United States',
#     'ticker': 'NVDA',
#     'totalReturn1Year': 46.6565,
#     'forwardPERatio': 38.7597,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [91669159291.0,
#       79402796079.0,
#       81010940765.0,
#       100622617547.0]},
#     'holdingType': 'Equity',
#     'isin': 'US67066G1040',
#     'cusip': '67066G104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 12.4578,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 100622617547.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Apple Inc',
#     'secId': '0P000000GY',
#     'performanceId': '0P000000GY',
#     'holdingTypeId': 'E',
#     'weighting': 5.31119,
#     'numberOfShare': 482568559.0,
#     'marketValue': 96923895075.0,
#     'shareChange': 565311.0,
#     'country': 'United States',
#     'ticker': 'AAPL',
#     'totalReturn1Year': -7.7989,
#     'forwardPERatio': 26.9542,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [115302521616.0,
#       105465688901.0,
#       102425690200.0,
#       96923895075.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0378331005',
#     'cusip': '037833100',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 18.991,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 96923895075.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Amazon.com Inc',
#     'secId': '0P000000B7',
#     'performanceId': '0P000000B7',
#     'holdingTypeId': 'E',
#     'weighting': 3.4421,
#     'numberOfShare': 306398771.0,
#     'marketValue': 62814812043.0,
#     'shareChange': 354439.0,
#     'country': 'United States',
#     'ticker': 'AMZN',
#     'totalReturn1Year': 19.1295,
#     'forwardPERatio': 34.965,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Cyclical',
#     'sectorCode': 'consumerCyclical',
#     'holdingTrend': {'trend': [63363654408.0,
#       57355680094.0,
#       56440695707.0,
#       62814812043.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0231351067',
#     'cusip': '023135106',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 25.8196,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 62814812043.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Meta Platforms Inc Class A',
#     'secId': '0P0000W3KZ',
#     'performanceId': '0P0000W3KZ',
#     'holdingTypeId': 'E',
#     'weighting': 2.49597,
#     'numberOfShare': 70346890.0,
#     'marketValue': 45548907806.0,
#     'shareChange': 80511.0,
#     'country': 'United States',
#     'ticker': 'META',
#     'totalReturn1Year': 52.2674,
#     'forwardPERatio': 27.7778,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [45945100573.0,
#       39892679015.0,
#       38576242071.0,
#       45548907806.0]},
#     'holdingType': 'Equity',
#     'isin': 'US30303M1027',
#     'cusip': '30303M102',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2012-06-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 32.7323,
#     'susEsgRiskGlobes': 2,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'High',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 45548907806.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Broadcom Inc',
#     'secId': '0P0000KU35',
#     'performanceId': '0P0000KU35',
#     'holdingTypeId': 'E',
#     'weighting': 1.99735,
#     'numberOfShare': 150574411.0,
#     'marketValue': 36449547671.0,
#     'shareChange': 173747.0,
#     'country': 'United States',
#     'ticker': 'AVGO',
#     'totalReturn1Year': 85.1199,
#     'forwardPERatio': 34.8432,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [29379271162.0,
#       24804748138.0,
#       28947615800.0,
#       36449547671.0]},
#     'holdingType': 'Equity',
#     'isin': 'US11135F1012',
#     'cusip': '11135F101',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2018-04-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 19.1951,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 36449547671.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Alphabet Inc Class A',
#     'secId': '0P000002HD',
#     'performanceId': '0P000002HD',
#     'holdingTypeId': 'E',
#     'weighting': 1.74482,
#     'numberOfShare': 185403254.0,
#     'marketValue': 31841154842.0,
#     'shareChange': 308918.0,
#     'country': 'United States',
#     'ticker': 'GOOGL',
#     'totalReturn1Year': 1.8617,
#     'forwardPERatio': 19.2308,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [31382538783.0,
#       28507857711.0,
#       29392980557.0,
#       31841154842.0]},
#     'holdingType': 'Equity',
#     'isin': 'US02079K3059',
#     'cusip': '02079K305',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-09-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 24.8887,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '5',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 31841154842.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Tesla Inc',
#     'secId': '0P0000OQN8',
#     'performanceId': '0P0000OQN8',
#     'holdingTypeId': 'E',
#     'weighting': 1.66736,
#     'numberOfShare': 87824146.0,
#     'marketValue': 30427553623.0,
#     'shareChange': 98627.0,
#     'country': 'United States',
#     'ticker': 'TSLA',
#     'totalReturn1Year': 28.5352,
#     'forwardPERatio': 163.9344,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Narrow',
#     'sector': 'Consumer Cyclical',
#     'sectorCode': 'consumerCyclical',
#     'holdingTrend': {'trend': [25214305887.0,
#       22394433366.0,
#       24752632441.0,
#       30427553623.0]},
#     'holdingType': 'Equity',
#     'isin': 'US88160R1014',
#     'cusip': '88160R101',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2010-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 24.7644,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 30427553623.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Berkshire Hathaway Inc Class B',
#     'secId': '0P000000RD',
#     'performanceId': '0P000000RD',
#     'holdingTypeId': 'E',
#     'weighting': 1.57216,
#     'numberOfShare': 56929698.0,
#     'marketValue': 28690290604.0,
#     'shareChange': 65455.0,
#     'country': 'United States',
#     'ticker': 'BRK.B',
#     'totalReturn1Year': 6.2364,
#     'forwardPERatio': 23.4742,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Narrow',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [28683224820.0,
#       29868641534.0,
#       30322857580.0,
#       28690290604.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0846707026',
#     'cusip': '084670702',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2010-03-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 26.1924,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 28690290604.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Alphabet Inc Class C',
#     'secId': '0P00012BBI',
#     'performanceId': '0P00012BBI',
#     'holdingTypeId': 'E',
#     'weighting': 1.44024,
#     'numberOfShare': 152056204.0,
#     'marketValue': 26282914861.0,
#     'shareChange': 90807.0,
#     'country': 'United States',
#     'ticker': 'GOOG',
#     'totalReturn1Year': 1.5825,
#     'forwardPERatio': 19.3424,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [25550474640.0,
#       23073346702.0,
#       24449712723.0,
#       26282914861.0]},
#     'holdingType': 'Equity',
#     'isin': 'US02079K1079',
#     'cusip': '02079K107',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2018-05-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 24.8887,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '5',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 26282914861.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'JPMorgan Chase & Co',
#     'secId': '0P0000031C',
#     'performanceId': '0P0000031C',
#     'holdingTypeId': 'E',
#     'weighting': 1.27905,
#     'numberOfShare': 88414309.0,
#     'marketValue': 23341377576.0,
#     'shareChange': 95991.0,
#     'country': 'United States',
#     'ticker': 'JPM',
#     'totalReturn1Year': 36.1184,
#     'forwardPERatio': 15.674,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [23502817011.0,
#       21678823643.0,
#       21604426949.0,
#       23341377576.0]},
#     'holdingType': 'Equity',
#     'isin': 'US46625H1005',
#     'cusip': '46625H100',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 27.3043,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 23341377576.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Eli Lilly and Co',
#     'secId': '0P000001WJ',
#     'performanceId': '0P000001WJ',
#     'holdingTypeId': 'E',
#     'weighting': 1.10802,
#     'numberOfShare': 27410967.0,
#     'marketValue': 20220248027.0,
#     'shareChange': 30119.0,
#     'country': 'United States',
#     'ticker': 'LLY',
#     'totalReturn1Year': -15.2928,
#     'forwardPERatio': 34.965,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': {'trend': [24809244033.0,
#       22275683857.0,
#       24614013310.0,
#       20220248027.0]},
#     'holdingType': 'Equity',
#     'isin': 'US5324571083',
#     'cusip': '532457108',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 23.0903,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 20220248027.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Visa Inc Class A',
#     'secId': '0P0000CPCP',
#     'performanceId': '0P0000CPCP',
#     'holdingTypeId': 'E',
#     'weighting': 1.09979,
#     'numberOfShare': 54957933.0,
#     'marketValue': 20070087552.0,
#     'shareChange': 75091.0,
#     'country': 'United States',
#     'ticker': 'V',
#     'totalReturn1Year': 29.1162,
#     'forwardPERatio': 27.3973,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [19616995161.0,
#       18943691944.0,
#       18962021911.0,
#       20070087552.0]},
#     'holdingType': 'Equity',
#     'isin': 'US92826C8394',
#     'cusip': '92826C839',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2008-03-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 14.4619,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 20070087552.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Netflix Inc',
#     'secId': '0P000003UP',
#     'performanceId': '0P000003UP',
#     'holdingTypeId': 'E',
#     'weighting': 0.90908,
#     'numberOfShare': 13742068.0,
#     'marketValue': 16589836752.0,
#     'shareChange': 16322.0,
#     'country': 'United States',
#     'ticker': 'NFLX',
#     'totalReturn1Year': 96.7952,
#     'forwardPERatio': 51.0204,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Narrow',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [13220289397.0,
#       12607921234.0,
#       15533701263.0,
#       16589836752.0]},
#     'holdingType': 'Equity',
#     'isin': 'US64110L1061',
#     'cusip': '64110L106',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 15.8808,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 16589836752.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Mastercard Inc Class A',
#     'secId': '0P00005U6B',
#     'performanceId': '0P00005U6B',
#     'holdingTypeId': 'E',
#     'weighting': 0.84001,
#     'numberOfShare': 26177224.0,
#     'marketValue': 15329382374.0,
#     'shareChange': 38546.0,
#     'country': 'United States',
#     'ticker': 'MA',
#     'totalReturn1Year': 23.8031,
#     'forwardPERatio': 34.8432,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [14901114583.0,
#       14112673110.0,
#       14325563865.0,
#       15329382374.0]},
#     'holdingType': 'Equity',
#     'isin': 'US57636Q1040',
#     'cusip': '57636Q104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2006-06-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 14.2468,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 15329382374.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Costco Wholesale Corp',
#     'secId': '0P000001IK',
#     'performanceId': '0P000001IK',
#     'holdingTypeId': 'E',
#     'weighting': 0.81284,
#     'numberOfShare': 14260561.0,
#     'marketValue': 14833550341.0,
#     'shareChange': 16126.0,
#     'country': 'United States',
#     'ticker': 'COST',
#     'totalReturn1Year': 13.2828,
#     'forwardPERatio': 47.1698,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Defensive',
#     'sectorCode': 'consumerDefensive',
#     'holdingTrend': {'trend': [14654906729.0,
#       13268973726.0,
#       14166090608.0,
#       14833550341.0]},
#     'holdingType': 'Equity',
#     'isin': 'US22160K1051',
#     'cusip': '22160K105',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 29.1246,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 14833550341.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Exxon Mobil Corp',
#     'secId': '0P00000220',
#     'performanceId': '0P00000220',
#     'holdingTypeId': 'E',
#     'weighting': 0.78173,
#     'numberOfShare': 139451222.0,
#     'marketValue': 14265860011.0,
#     'shareChange': 203551.0,
#     'country': 'United States',
#     'ticker': 'XOM',
#     'totalReturn1Year': -1.7511,
#     'forwardPERatio': 17.6678,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Narrow',
#     'sector': 'Energy',
#     'sectorCode': 'energy',
#     'holdingTrend': {'trend': [15435157030.0,
#       16314048874.0,
#       14708731488.0,
#       14265860011.0]},
#     'holdingType': 'Equity',
#     'isin': 'US30231G1022',
#     'cusip': '30231G102',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 42.8896,
#     'susEsgRiskGlobes': 1,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Severe',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '5',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 14265860011.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Walmart Inc',
#     'secId': '0P000005UH',
#     'performanceId': '0P000005UH',
#     'holdingTypeId': 'E',
#     'weighting': 0.76779,
#     'numberOfShare': 141930987.0,
#     'marketValue': 14011427037.0,
#     'shareChange': 151961.0,
#     'country': 'United States',
#     'ticker': 'WMT',
#     'totalReturn1Year': 35.119,
#     'forwardPERatio': 36.4964,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Defensive',
#     'sectorCode': 'consumerDefensive',
#     'holdingTrend': {'trend': [13750524324.0,
#       12258993405.0,
#       13788010278.0,
#       14011427037.0]},
#     'holdingType': 'Equity',
#     'isin': 'US9311421039',
#     'cusip': '931142103',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 25.1607,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 14011427037.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Procter & Gamble Co',
#     'secId': '0P000004GV',
#     'performanceId': '0P000004GV',
#     'holdingTypeId': 'E',
#     'weighting': 0.7015,
#     'numberOfShare': 75352918.0,
#     'marketValue': 12801707239.0,
#     'shareChange': 98032.0,
#     'country': 'United States',
#     'ticker': 'PG',
#     'totalReturn1Year': -5.7505,
#     'forwardPERatio': 22.2222,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Defensive',
#     'sectorCode': 'consumerDefensive',
#     'holdingTrend': {'trend': [12914480248.0,
#       12633513066.0,
#       12234186817.0,
#       12801707239.0]},
#     'holdingType': 'Equity',
#     'isin': 'US7427181091',
#     'cusip': '742718109',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 25.9194,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 12801707239.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Johnson & Johnson',
#     'secId': '0P0000032S',
#     'performanceId': '0P0000032S',
#     'holdingTypeId': 'E',
#     'weighting': 0.65774,
#     'numberOfShare': 77334501.0,
#     'marketValue': 12003087900.0,
#     'shareChange': 83047.0,
#     'country': 'United States',
#     'ticker': 'JNJ',
#     'totalReturn1Year': 7.2934,
#     'forwardPERatio': 15.4083,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': {'trend': [12531384637.0,
#       12621425342.0,
#       12075174775.0,
#       12003087900.0]},
#     'holdingType': 'Equity',
#     'isin': 'US4781601046',
#     'cusip': '478160104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 22.4538,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '4',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 12003087900.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'The Home Depot Inc',
#     'secId': '0P000002OY',
#     'performanceId': '0P000002OY',
#     'holdingTypeId': 'E',
#     'weighting': 0.64419,
#     'numberOfShare': 31920157.0,
#     'marketValue': 11755874622.0,
#     'shareChange': 41228.0,
#     'country': 'United States',
#     'ticker': 'HD',
#     'totalReturn1Year': -1.0084,
#     'forwardPERatio': 23.9808,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Cyclical',
#     'sectorCode': 'consumerCyclical',
#     'holdingTrend': {'trend': [12427117544.0,
#       11507715634.0,
#       11492035115.0,
#       11755874622.0]},
#     'holdingType': 'Equity',
#     'isin': 'US4370761029',
#     'cusip': '437076102',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 12.7762,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 11755874622.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'AbbVie Inc',
#     'secId': '0P0000XPGW',
#     'performanceId': '0P0000XPGW',
#     'holdingTypeId': 'E',
#     'weighting': 0.57822,
#     'numberOfShare': 56697669.0,
#     'marketValue': 10552003178.0,
#     'shareChange': 54628.0,
#     'country': 'United States',
#     'ticker': 'ABBV',
#     'totalReturn1Year': 12.8944,
#     'forwardPERatio': 15.748,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': {'trend': [11650657242.0,
#       11690648410.0,
#       11051057299.0,
#       10552003178.0]},
#     'holdingType': 'Equity',
#     'isin': 'US00287Y1091',
#     'cusip': '00287Y109',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2013-03-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 24.303,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 10552003178.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Bank of America Corp',
#     'secId': '0P000000PA',
#     'performanceId': '0P000000PA',
#     'holdingTypeId': 'E',
#     'weighting': 0.50471,
#     'numberOfShare': 208713544.0,
#     'marketValue': 9210528697.0,
#     'shareChange': -3273760.0,
#     'country': 'United States',
#     'ticker': 'BAC',
#     'totalReturn1Year': 9.2769,
#     'forwardPERatio': 12.9199,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [9692737014.0,
#       8709914102.0,
#       8454053684.0,
#       9210528697.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0605051046',
#     'cusip': '060505104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 23.8088,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 9210528697.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Palantir Technologies Inc Ordinary Shares - Class A',
#     'secId': '0P0001KOSE',
#     'performanceId': '0P0001KOSE',
#     'holdingTypeId': 'E',
#     'weighting': 0.49558,
#     'numberOfShare': 68627762.0,
#     'marketValue': 9043766476.0,
#     'shareChange': 73451.0,
#     'country': 'United States',
#     'ticker': 'PLTR',
#     'totalReturn1Year': 445.6768,
#     'forwardPERatio': 270.2703,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Narrow',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [5548708381.0,
#       5698717878.0,
#       8119572595.0,
#       9043766476.0]},
#     'holdingType': 'Equity',
#     'isin': 'US69608A1088',
#     'cusip': '69608A108',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2020-09-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 21.5881,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 9043766476.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Philip Morris International Inc',
#     'secId': '0P0000CUPM',
#     'performanceId': '0P0000CUPM',
#     'holdingTypeId': 'E',
#     'weighting': 0.4942,
#     'numberOfShare': 49939978.0,
#     'marketValue': 9018660627.0,
#     'shareChange': 50127.0,
#     'country': 'United States',
#     'ticker': 'PM',
#     'totalReturn1Year': 70.409,
#     'forwardPERatio': 23.9808,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Defensive',
#     'sectorCode': 'consumerDefensive',
#     'holdingTrend': {'trend': [7614138030.0,
#       7799118868.0,
#       8549124867.0,
#       9018660627.0]},
#     'holdingType': 'Equity',
#     'isin': 'US7181721090',
#     'cusip': '718172109',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2008-03-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 27.3073,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 9018660627.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'UnitedHealth Group Inc',
#     'secId': '0P000005NU',
#     'performanceId': '0P000005NU',
#     'holdingTypeId': 'E',
#     'weighting': 0.48906,
#     'numberOfShare': 29561575.0,
#     'marketValue': 8924935108.0,
#     'shareChange': 32136.0,
#     'country': 'United States',
#     'ticker': 'UNH',
#     'totalReturn1Year': -48.2661,
#     'forwardPERatio': 12.6582,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Narrow',
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': {'trend': [13787102308.0,
# ...
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 128891630.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Integer Holdings Corp',
#     'secId': '0P000002I9',
#     'performanceId': '0P000002I9',
#     'holdingTypeId': 'E',
#     'weighting': 0.00706,
#     'numberOfShare': 1085042.0,
#     'marketValue': 128859588.0,
#     'shareChange': 722.0,
#     'country': 'United States',
#     'ticker': 'ITGR',
#     'totalReturn1Year': -7.8308,
#     'forwardPERatio': 20.5339,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': None,
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': None,
#     'holdingType': 'Equity',
#     'isin': 'US45826H1095',
#     'cusip': '45826H109',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2016-07-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 28.2479,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Quan',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 128859588.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Macerich Co',
#     'secId': '0P000003EN',
#     'performanceId': '0P000003EN',
#     'holdingTypeId': 'ER',
#     'weighting': 0.00705,
#     'numberOfShare': 7949879.0,
#     'marketValue': 128629042.0,
#     'shareChange': 6508.0,
#     'country': 'United States',
#     'ticker': 'MAC',
#     'totalReturn1Year': 8.1875,
#     'forwardPERatio': -65.3595,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'None',
#     'sector': 'Real Estate',
#     'sectorCode': 'realEstate',
#     'holdingTrend': None,
#     'holdingType': 'Equity',
#     'isin': 'US5543821012',
#     'cusip': '554382101',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2019-10-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 12.3937,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2025-06-04T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '5',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 128629042.0,
#     'isMomentumFilterFlag': False},
#    ...],
#   'previousPeriodsDate': '2025-04-30T05:00:00.000'},
#  'boldHoldingPage': {'pageSize': 10000,
#   'pageNumber': 1,
#   'totalPage': 0,
#   'numberOfCurPageHolding': 0,
#   'numberOfAllHolding': 0,
#   'holdingList': [],
#   'previousPeriodsDate': None},
#  'otherHoldingPage': {'pageSize': 10000,
#   'pageNumber': 1,
#   'totalPage': 1,
#   'numberOfCurPageHolding': 7,
#   'numberOfAllHolding': 7,
#   'holdingList': [{'securityName': 'Slcmt1142',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'C',
#     'weighting': 0.21472,
#     'numberOfShare': 39188944.0,
#     'marketValue': 3918502489.0,
#     'shareChange': 39188944.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': '501011',
#     'superSectorName': 'cashAndEquivalents',
#     'primarySectorName': 'cashAndEquivalents',
#     'secondarySectorName': 'Cash',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 3918502489.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Mktliq 12/31/2049',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'C',
#     'weighting': 0.20986,
#     'numberOfShare': 38301730.0,
#     'marketValue': 3829789933.0,
#     'shareChange': 38301730.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': '501011',
#     'superSectorName': 'cashAndEquivalents',
#     'primarySectorName': 'cashAndEquivalents',
#     'secondarySectorName': 'Cash',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 3829789933.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Usd/Eur Fwd 20250530',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'CU',
#     'weighting': 0.00036,
#     'numberOfShare': 6518119.0,
#     'marketValue': 6518119.0,
#     'shareChange': 6518119.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': '602030',
#     'superSectorName': 'derivative',
#     'primarySectorName': 'Future/Forward',
#     'secondarySectorName': 'Currency Forward/Future',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 6518119.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Euro',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'CH',
#     'weighting': 0.0003,
#     'numberOfShare': 4885284.0,
#     'marketValue': 5546996.0,
#     'shareChange': 4885284.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': '501013',
#     'superSectorName': 'cashAndEquivalents',
#     'primarySectorName': 'cashAndEquivalents',
#     'secondarySectorName': 'Currency',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 5546996.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Btcs Incorporation',
#     'secId': 'B10003UJJ6',
#     'performanceId': None,
#     'holdingTypeId': 'P',
#     'weighting': 0.0,
#     'numberOfShare': 280193.0,
#     'marketValue': 3.0,
#     'shareChange': 0.0,
#     'country': 'United States',
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': 'US05581M5031',
#     'cusip': '05581M503',
#     'secondarySectorId': '304011',
#     'superSectorName': 'corporate',
#     'primarySectorName': 'Preferred',
#     'secondarySectorName': 'Technology',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 3.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Eur/Usd Fwd 20250530',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'CU',
#     'weighting': -0.00036,
#     'numberOfShare': 5747394.0,
#     'marketValue': -6525878.0,
#     'shareChange': 5747394.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': '602030',
#     'superSectorName': 'derivative',
#     'primarySectorName': 'Future/Forward',
#     'secondarySectorName': 'Currency Forward/Future',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': -6525878.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Us Dollar',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'CH',
#     'weighting': -0.00103,
#     'numberOfShare': 18878765.0,
#     'marketValue': -18878765.0,
#     'shareChange': 18878765.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': '501013',
#     'superSectorName': 'cashAndEquivalents',
#     'primarySectorName': 'cashAndEquivalents',
#     'secondarySectorName': 'Currency',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': -18878765.0,
#     'isMomentumFilterFlag': None}],
#   'previousPeriodsDate': None},
#  'userType': 'Free',
#  'portfolioLastestDateFooter': '2025-05-31T05:00:00.000',
#  'noPremiumChinaFund': False,
#  'numberOfEquityHoldingPer': 99.803,
#  'numberOfBondHoldingPer': 0.0,
#  'numberOfOtherHoldingPer': 0.197}

# %% [markdown]
# Assets exposed to a range of activities
#
# Sustainability - Values - Product Involvement
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.productInvolvement()
# Out:
# {'fundEffectiveDate': '2025-05-31T05:00:00.000',
#  'categoryEffectiveDate': '2019-08-31T05:00:00.000',
#  'excludesEffectiveDate': '2025-04-29T05:00:00.000',
#  'portfolioDate': '2025-05-31T05:00:00.000',
#  'categoryName': 'Large Blend',
#  'categoryAsOfDate': '2022-12-31T06:00:00.000',
#  'businessPractices': [{'label': 'animalTesting',
#    'fundPercent': '15.01642',
#    'categoryPercent': '17.06000',
#    'employsExclusions': '0'},
#   {'label': 'furAndSpecialityLeather',
#    'fundPercent': '0.00000',
#    'categoryPercent': '0.00000',
#    'employsExclusions': '0'}],
#  'defenceAndMilitary': [{'label': 'controversialWeapons',
#    'fundPercent': '1.54762',
#    'categoryPercent': '2.75000',
#    'employsExclusions': '0'},
#   {'label': 'militaryContracting',
#    'fundPercent': '3.50885',
#    'categoryPercent': '3.33000',
#    'employsExclusions': '0'},
#   {'label': 'smallArms',
#    'fundPercent': '0.92269',
#    'categoryPercent': '0.50000',
#    'employsExclusions': '0'}],
#  'energy': [{'label': 'nuclear',
#    'fundPercent': '1.65476',
#    'categoryPercent': '2.16000',
#    'employsExclusions': '0'},
#   {'label': 'thermalCoal',
#    'fundPercent': '1.18548',
#    'categoryPercent': '3.42000',
#    'employsExclusions': '0'}],
#  'environment': [{'label': 'gmo',
#    'fundPercent': '0.08675',
#    'categoryPercent': '0.03000',
#    'employsExclusions': '0'},
#   {'label': 'palmOil',
#    'fundPercent': '0.00013',
#    'categoryPercent': '0.00000',
#    'employsExclusions': '0'},
#   {'label': 'pesticides',
#    'fundPercent': '0.11696',
#    'categoryPercent': '0.30000',
#    'employsExclusions': '0'}],
#  'healthAndLife': [{'label': 'alcohol',
#    'fundPercent': '0.09055',
#    'categoryPercent': '0.45000',
#    'employsExclusions': '0'},
#   {'label': 'tobacco',
#    'fundPercent': '0.73708',
#    'categoryPercent': '0.80000',
#    'employsExclusions': '0'},
#   {'label': 'lifeEthics',
#    'fundPercent': '6.13273',
#    'categoryPercent': '7.09000',
#    'employsExclusions': '0'}],
#  'valueBased': [{'label': 'adultEntertainment',
#    'fundPercent': '0.00000',
#    'categoryPercent': '0.00000',
#    'employsExclusions': '0'},
#   {'label': 'gambling',
#    'fundPercent': '0.21664',
#    'categoryPercent': '0.22000',
#    'employsExclusions': '0'}]}

# %% [markdown]
# How fund managers voted on Management resolutions
#
# Sustainability - Proxy Voting - Management
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.proxyVotingManagement()
# Out:
# {'template': 'US',
#  'managementList': [{'proxyYear': '2024',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '74',
#    'allManagementResolution': {'voteCount': '2571',
#     'supportPer': '92.92104',
#     'againstPer': '7.07896',
#     'abstainedPer': '0.00000'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '221',
#     'supportPer': '97.28506',
#     'againstPer': '2.71493',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '288',
#     'supportPer': '100.00000',
#     'againstPer': '0.00000',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '1859',
#     'supportPer': '91.82356',
#     'againstPer': '8.17644',
#     'abstainedPer': '0.00000'},
#    'compensation': {'voteCount': '67',
#     'supportPer': '85.07462',
#     'againstPer': '14.92537',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2023',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '1566',
#    'allManagementResolution': {'voteCount': '31439',
#     'supportPer': '94.63087',
#     'againstPer': '5.36595',
#     'abstainedPer': '0.00954'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2952',
#     'supportPer': '95.22358',
#     'againstPer': '4.77642',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3665',
#     'supportPer': '99.91814',
#     'againstPer': '0.08186',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '22536',
#     'supportPer': '94.20483',
#     'againstPer': '5.78186',
#     'abstainedPer': '0.01331'},
#    'compensation': {'voteCount': '827',
#     'supportPer': '83.79686',
#     'againstPer': '16.20314',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2022',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '319',
#    'allManagementResolution': {'voteCount': '27018',
#     'supportPer': '95.31794',
#     'againstPer': '4.67836',
#     'abstainedPer': '0.00740'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2459',
#     'supportPer': '94.18463',
#     'againstPer': '5.81537',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3250',
#     'supportPer': '99.87692',
#     'againstPer': '0.12308',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '19848',
#     'supportPer': '95.11790',
#     'againstPer': '4.87203',
#     'abstainedPer': '0.01008'},
#    'compensation': {'voteCount': '594',
#     'supportPer': '86.02694',
#     'againstPer': '14.14141',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2021',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '273',
#    'allManagementResolution': {'voteCount': '29224',
#     'supportPer': '95.14783',
#     'againstPer': '4.84875',
#     'abstainedPer': '0.00342'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2704',
#     'supportPer': '95.15533',
#     'againstPer': '4.84467',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3400',
#     'supportPer': '99.79412',
#     'againstPer': '0.20588',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '21286',
#     'supportPer': '94.90745',
#     'againstPer': '5.08785',
#     'abstainedPer': '0.00470'},
#    'compensation': {'voteCount': '787',
#     'supportPer': '88.43710',
#     'againstPer': '11.56290',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2020',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '303',
#    'allManagementResolution': {'voteCount': '27535',
#     'supportPer': '95.04630',
#     'againstPer': '4.95733',
#     'abstainedPer': '0.00000'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2657',
#     'supportPer': '94.76854',
#     'againstPer': '5.23146',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3158',
#     'supportPer': '99.87334',
#     'againstPer': '0.12666',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '19987',
#     'supportPer': '94.94672',
#     'againstPer': '5.05829',
#     'abstainedPer': '0.00000'},
#    'compensation': {'voteCount': '731',
#     'supportPer': '83.85773',
#     'againstPer': '16.14227',
#     'abstainedPer': '0.00000'}}]}

# %% [markdown]
# How fund managers voted on Shareholder resolutions
#
# Sustainability - Proxy Voting - Shareholder
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.proxyVotingShareHolder()
# Out:
# {'template': 'US',
#  'shareholderList': [{'year': '2024',
#    'boardGovernance': {'voteCount': '55',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '72',
#     'supportPer': '0.00000',
#     'againstPer': '98.61111',
#     'abstainedPer': '1.38889'},
#    'directorElections': {'voteCount': '25',
#     'supportPer': '40.00000',
#     'againstPer': '60.00000',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '26',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '14',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '55',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'humanAndWorkersRights': {'voteCount': '136',
#     'supportPer': '0.00000',
#     'againstPer': '98.52941',
#     'abstainedPer': '1.47059'},
#    'humaneTreatmentOfAnimals': {'voteCount': '19',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '7',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '7',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '36',
#     'supportPer': '0.00000',
#     'againstPer': '97.22222',
#     'abstainedPer': '2.77778'},
#    'politicalInfluence': {'voteCount': '66',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '22',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '35',
#     'supportPer': '22.85714',
#     'againstPer': '77.14286',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '60',
#     'supportPer': '55.00000',
#     'againstPer': '45.00000',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2023',
#    'boardGovernance': {'voteCount': '94',
#     'supportPer': '3.19149',
#     'againstPer': '96.80851',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '79',
#     'supportPer': '5.06329',
#     'againstPer': '89.87342',
#     'abstainedPer': '5.06329'},
#    'directorElections': {'voteCount': '25',
#     'supportPer': '16.00000',
#     'againstPer': '84.00000',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '14',
#     'supportPer': '7.14286',
#     'againstPer': '92.85714',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '8',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '55',
#     'supportPer': '9.09091',
#     'againstPer': '89.09091',
#     'abstainedPer': '1.81818'},
#    'humanAndWorkersRights': {'voteCount': '85',
#     'supportPer': '1.17647',
#     'againstPer': '97.64706',
#     'abstainedPer': '1.17647'},
#    'humaneTreatmentOfAnimals': {'voteCount': '13',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '9',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '3',
#     'supportPer': '33.33333',
#     'againstPer': '66.66666',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '16',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '51',
#     'supportPer': '1.96078',
#     'againstPer': '98.03922',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '25',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '49',
#     'supportPer': '6.12245',
#     'againstPer': '93.87755',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '23',
#     'supportPer': '34.78261',
#     'againstPer': '65.21739',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2022',
#    'boardGovernance': {'voteCount': '36',
#     'supportPer': '2.77778',
#     'againstPer': '97.22222',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '34',
#     'supportPer': '26.47059',
#     'againstPer': '73.52941',
#     'abstainedPer': '0.00000'},
#    'directorElections': {'voteCount': '15',
#     'supportPer': '53.33333',
#     'againstPer': '46.66667',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '8',
#     'supportPer': '12.50000',
#     'againstPer': '87.50000',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '4',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '18',
#     'supportPer': '16.66667',
#     'againstPer': '77.77778',
#     'abstainedPer': '5.55556'},
#    'humanAndWorkersRights': {'voteCount': '50',
#     'supportPer': '14.00000',
#     'againstPer': '86.00000',
#     'abstainedPer': '0.00000'},
#    'humaneTreatmentOfAnimals': {'voteCount': '7',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '1',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'otherEnvironmentalAndSocial': {'voteCount': '9',
#     'supportPer': '11.11111',
#     'againstPer': '88.88889',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '34',
#     'supportPer': '11.76471',
#     'againstPer': '88.23529',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '12',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '104',
#     'supportPer': '6.73077',
#     'againstPer': '93.26923',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '17',
#     'supportPer': '70.58823',
#     'againstPer': '29.41176',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '4',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2021',
#    'boardGovernance': {'voteCount': '52',
#     'supportPer': '15.38461',
#     'againstPer': '84.61539',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '25',
#     'supportPer': '44.00000',
#     'againstPer': '56.00000',
#     'abstainedPer': '0.00000'},
#    'directorElections': {'voteCount': '42',
#     'supportPer': '54.76191',
#     'againstPer': '45.23809',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '7',
#     'supportPer': '28.57143',
#     'againstPer': '71.42857',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '8',
#     'supportPer': '12.50000',
#     'againstPer': '87.50000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '20',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'humanAndWorkersRights': {'voteCount': '37',
#     'supportPer': '29.72973',
#     'againstPer': '70.27027',
#     'abstainedPer': '0.00000'},
#    'humaneTreatmentOfAnimals': {'voteCount': '1',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '2',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '9',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '11',
#     'supportPer': '9.09091',
#     'againstPer': '90.90909',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '47',
#     'supportPer': '23.40425',
#     'againstPer': '76.59574',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '13',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '116',
#     'supportPer': '6.89655',
#     'againstPer': '93.10345',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '29',
#     'supportPer': '89.65517',
#     'againstPer': '10.34483',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '12',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2020',
#    'boardGovernance': {'voteCount': '66',
#     'supportPer': '6.06061',
#     'againstPer': '93.93939',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '21',
#     'supportPer': '19.04762',
#     'againstPer': '80.95238',
#     'abstainedPer': '0.00000'},
#    'directorElections': {'voteCount': '41',
#     'supportPer': '65.85366',
#     'againstPer': '34.14634',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '11',
#     'supportPer': '18.18182',
#     'againstPer': '81.81818',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '12',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '18',
#     'supportPer': '5.55556',
#     'againstPer': '94.44444',
#     'abstainedPer': '0.00000'},
#    'humanAndWorkersRights': {'voteCount': '50',
#     'supportPer': '12.00000',
#     'againstPer': '88.00000',
#     'abstainedPer': '0.00000'},
#    'humaneTreatmentOfAnimals': {'voteCount': '4',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '3',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '1',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '10',
#     'supportPer': '10.00000',
#     'againstPer': '90.00000',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '45',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '9',
#     'supportPer': '11.11111',
#     'againstPer': '88.88889',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '102',
#     'supportPer': '3.92157',
#     'againstPer': '96.07843',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '38',
#     'supportPer': '50.00000',
#     'againstPer': '50.00000',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '2',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}}]}

# %% [markdown]
# Information on the fund
#
# https://www.morningstar.com/funds/xnas/vtsax/quote

# %%
funds.quote()
# Out:
# {'taxClassDesignation': None,
#  'nCENAverageNetAssets': None,
#  'totalLeverage': None,
#  'totalLeverageRatio': None,
#  'prospectusBenchmarkName': 'CRSP US Total Market TR USD',
#  'primaryIndexNameNew': 'S&P 500 TR USD',
#  'index': 'Morningstar US Large-Mid TR USD',
#  'tNAInShareClassCurrency': 1912236548176.0,
#  'sECYield': 1.18,
#  'trailing1DayReturn': 0.60833,
#  'trailing1DayReturnAsOfDate': '2025-07-17T05:00:00.000',
#  'yield12Month': 1.211,
#  'trailing7DayYield': None,
#  'expenseRatio': 0.04,
#  'morningstarFeeLevel': '1',
#  'morningstarFeeLevelBroad': '1',
#  'inceptionDate': '2000-11-13T06:00:00.000',
#  'minimumInitialInvestment': 3000.0,
#  'lastTurnoverRatio': 2.0,
#  'equityStyleBox': 2,
#  'expense': 0.04,
#  'load': 'None',
#  'iFICRiskClassification': None,
#  'managementExpenseRatio': None,
#  'fundShareClassTypeName': 'Inst',
#  'fundShareClassTypeId': 'Inst',
#  'fixedIncomeStyleBox': None,
#  'isMonthlyRatio': False,
#  'expenseRatioDate': None,
#  'annualReportNetExpenseRatioDate': None,
#  'monthlyNetExpenseRatioDate': None,
#  'annualReportNetExpenseRatio': None,
#  'monthlyNetExpenseRatio': None,
#  'totalAsset': None,
#  'secId': 'FOUSA00L83',
#  'ticker': 'VTSAX',
#  'fundSubType': None,
#  'userType': 'Free',
#  'investmentName': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#  'isin': 'US9229087286',
#  'morningstarRating': '3',
#  'morningstarRatingAsOfDate': '2025-06-30T05:00:00.000',
#  'analystRating': None,
#  'quantRating': 'NA',
#  'hasExtendedPerformance': False,
#  'domicileCountryId': 'USA',
#  'baseCurrencyId': 'USD',
#  'caFundCode': None,
#  'dayEndReturnDate': '2025-07-17T05:00:00.000',
#  'returnEndDate': '2025-07-17T05:00:00.000',
#  'template': 'OE_USA_EQUITY',
#  'templateWithAssetType': None,
#  'categoryName': 'US Fund Large Blend',
#  'nav': 150.5,
#  'status': 'Open',
#  'APIRCode': None,
#  'securityType': 'FO',
#  'alternativeFundCodes': None,
#  'selectedFundCode': None,
#  'hasAnalystRating': False,
#  'hasQuantRating': False,
#  'analystRatingDate': None,
#  'quantRatingDate': None,
#  'altStyle': None,
#  'adjustedExpenseRatio': 0.0004,
#  'flagshipShareClassID': None,
#  'flagshipName': None,
#  'isAusFlagship': False,
#  'productInvolvementEffectiveDate': '2025-05-31T05:00:00.000',
#  'topProductInvolvementCategories': {'Animal_Testing': 15.01642,
#   'Catholic_Values': 6.13273,
#   'Military_Contracting': 3.50885,
#   'Nuclear': 1.65476,
#   'Controversial_Weapons': 1.54762,
#   'Thermal_Coal': 1.18548},
#  'sustainabilityFundQuintile': 3,
#  'sustainabilityAsOfDate': '2025-05-31T00:00:00.000',
#  'isLowCarbon': None,
#  'isDesignatedLowCarbon': 'false',
#  'medalistRatingLabel': '_PO_',
#  'medalistRating': '_PO_',
#  'medalistRatingDate': '_PO_',
#  'medalistRatingScale': '_PO_',
#  'hasMedalistRating': True,
#  'analystScale': None,
#  'performanceScale': None,
#  'parentScale': None,
#  'peopleScale': None,
#  'priceScale': None,
#  'processScale': None,
#  'parentScaleQuant': None,
#  'processScaleQuant': None,
#  'performanceScaleQuant': None,
#  'priceScaleQuant': None,
#  'peopleScaleQuant': None,
#  'quanRatingEndDate': None,
#  'analystDrivenProportion': '100',
#  'dataCoverage': '100',
#  'performanceScore': '_PO_',
#  'parentScore': '_PO_',
#  'peopleScore': '_PO_',
#  'priceScore': '_PO_',
#  'processScore': '_PO_',
#  'performanceScoreLabel': '_PO_',
#  'parentScoreLabel': '_PO_',
#  'peopleScoreLabel': '_PO_',
#  'priceScoreLabel': '_PO_',
#  'processScoreLabel': '_PO_',
#  'performanceScoreType': '_PO_',
#  'parentScoreType': '_PO_',
#  'peopleScoreType': '_PO_',
#  'priceScoreType': '_PO_',
#  'processScoreType': '_PO_',
#  'assetType': 'EQUITY'}

# %% [markdown]
# Breakdown by region
#
# Exposure - Region
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.regionalSector()
# Out:
# {'fundPortfolio': {'portfolioDate': '2025-05-31T05:00:00.000',
#   'masterPortfolioId': '3506',
#   'northAmerica': 99.583,
#   'unitedKingdom': 0.02759,
#   'europeDeveloped': 0.296,
#   'europeEmerging': 0.0,
#   'africaMiddleEast': 0.0,
#   'japan': 0.0,
#   'australasia': 0.0,
#   'asiaDeveloped': 0.049,
#   'asiaEmerging': 0.013,
#   'latinAmerica': 0.03},
#  'categoryPortfolio': {'portfolioDate': '2025-06-30T05:00:00.000',
#   'masterPortfolioId': '204178',
#   'northAmerica': 98.206,
#   'unitedKingdom': 0.37567,
#   'europeDeveloped': 0.927,
#   'europeEmerging': 0.0,
#   'africaMiddleEast': 0.027,
#   'japan': 0.076,
#   'australasia': 0.003,
#   'asiaDeveloped': 0.25,
#   'asiaEmerging': 0.051,
#   'latinAmerica': 0.08},
#  'indexPortfolio': {'portfolioDate': '2025-06-30T05:00:00.000',
#   'masterPortfolioId': '471834',
#   'northAmerica': 99.24,
#   'unitedKingdom': 0.03841,
#   'europeDeveloped': 0.399,
#   'europeEmerging': 0.0,
#   'africaMiddleEast': 0.0,
#   'japan': 0.0,
#   'australasia': 0.0,
#   'asiaDeveloped': 0.054,
#   'asiaEmerging': 0.0,
#   'latinAmerica': 0.259},
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'assetType': 'EQUITY'}

# %% [markdown]
# Breakdown by country
#
# Exposure - Country
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.regionalSectorIncludeCountries()
# Out:
# {'fundPortfolio': {'countries': [{'name': 'unitedStates', 'percent': 99.45542},
#    {'name': 'switzerland', 'percent': 0.25649},
#    {'name': 'canada', 'percent': 0.12816},
#    {'name': 'singapore', 'percent': 0.04413},
#    {'name': 'ireland', 'percent': 0.03992},
#    {'name': 'unitedKingdom', 'percent': 0.02759},
#    {'name': 'india', 'percent': 0.01341},
#    {'name': 'brazil', 'percent': 0.00406},
#    {'name': 'taiwan', 'percent': 0.0037},
#    {'name': 'hongKong', 'percent': 0.00089},
#    {'name': 'argentina', 'percent': 0.0},
#    {'name': 'australia', 'percent': 0.0},
#    {'name': 'austria', 'percent': 0.0},
#    {'name': 'belgium', 'percent': 0.0},
#    {'name': 'chile', 'percent': 0.0},
#    {'name': 'china', 'percent': 0.0},
#    {'name': 'colombia', 'percent': 0.0},
#    {'name': 'czechRepublic', 'percent': 0.0},
#    {'name': 'denmark', 'percent': 0.0},
#    {'name': 'estonia', 'percent': 0.0},
#    {'name': 'finland', 'percent': 0.0},
#    {'name': 'france', 'percent': 0.0},
#    {'name': 'germany', 'percent': 0.0},
#    {'name': 'greece', 'percent': 0.0},
#    {'name': 'hungary', 'percent': 0.0},
#    {'name': 'indonesia', 'percent': 0.0},
#    {'name': 'israel', 'percent': 0.0},
#    {'name': 'italy', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0},
#    {'name': 'latvia', 'percent': 0.0},
#    {'name': 'lithuania', 'percent': 0.0},
#    {'name': 'malaysia', 'percent': 0.0},
#    {'name': 'mexico', 'percent': 0.0},
#    {'name': 'netherlands', 'percent': 0.0},
#    {'name': 'newZealand', 'percent': 0.0},
#    {'name': 'norway', 'percent': 0.0},
#    {'name': 'pakistan', 'percent': 0.0},
#    {'name': 'peru', 'percent': 0.0},
#    {'name': 'philippines', 'percent': 0.0},
#    {'name': 'poland', 'percent': 0.0},
#    {'name': 'portugal', 'percent': 0.0},
#    {'name': 'russia', 'percent': 0.0},
#    {'name': 'slovakia', 'percent': 0.0},
#    {'name': 'southAfrica', 'percent': 0.0},
#    {'name': 'southKorea', 'percent': 0.0},
#    {'name': 'spain', 'percent': 0.0},
#    {'name': 'sweden', 'percent': 0.0},
#    {'name': 'thailand', 'percent': 0.0},
#    {'name': 'turkey', 'percent': 0.0},
#    {'name': 'venezuela', 'percent': 0.0},
#    {'name': 'vietnam', 'percent': 0.0}],
#   'regions': [{'name': 'northAmerica', 'percent': 99.583},
#    {'name': 'europeDeveloped', 'percent': 0.296},
#    {'name': 'asiaDeveloped', 'percent': 0.049},
#    {'name': 'latinAmerica', 'percent': 0.03},
#    {'name': 'unitedKingdom', 'percent': 0.02759},
#    {'name': 'other Countries', 'percent': 0.02624},
#    {'name': 'asiaEmerging', 'percent': 0.013},
#    {'name': 'australasia', 'percent': 0.0},
#    {'name': 'europeEmerging', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0}],
#   'portfolioDate': '2025-05-31T05:00:00.000'},
#  'categoryPortfolio': {'countries': [{'name': 'unitedStates',
#     'percent': 97.81195},
#    {'name': 'switzerland', 'percent': 0.41129},
#    {'name': 'canada', 'percent': 0.40593},
#    {'name': 'unitedKingdom', 'percent': 0.37567},
#    {'name': 'netherlands', 'percent': 0.25618},
#    {'name': 'taiwan', 'percent': 0.1843},
#    {'name': 'japan', 'percent': 0.076},
#    {'name': 'germany', 'percent': 0.07143},
#    {'name': 'france', 'percent': 0.0611},
#    {'name': 'singapore', 'percent': 0.04851},
#    {'name': 'denmark', 'percent': 0.04652},
#    {'name': 'belgium', 'percent': 0.03731},
#    {'name': 'brazil', 'percent': 0.03513},
#    {'name': 'mexico', 'percent': 0.03211},
#    {'name': 'china', 'percent': 0.03134},
#    {'name': 'ireland', 'percent': 0.02996},
#    {'name': 'israel', 'percent': 0.02447},
#    {'name': 'india', 'percent': 0.01858},
#    {'name': 'southKorea', 'percent': 0.01482},
#    {'name': 'sweden', 'percent': 0.00402},
#    {'name': 'australia', 'percent': 0.00306},
#    {'name': 'spain', 'percent': 0.00143},
#    {'name': 'italy', 'percent': 0.00117},
#    {'name': 'southAfrica', 'percent': 0.00107},
#    {'name': 'hongKong', 'percent': 0.00081},
#    {'name': 'finland', 'percent': 0.00053},
#    {'name': 'norway', 'percent': 0.00042},
#    {'name': 'malaysia', 'percent': 0.00032},
#    {'name': 'indonesia', 'percent': 0.00026},
#    {'name': 'poland', 'percent': 0.00024},
#    {'name': 'thailand', 'percent': 0.00023},
#    {'name': 'austria', 'percent': 0.00015},
#    {'name': 'turkey', 'percent': 0.00013},
#    {'name': 'greece', 'percent': 0.00012},
#    {'name': 'chile', 'percent': 0.0001},
#    {'name': 'philippines', 'percent': 0.0001},
#    {'name': 'newZealand', 'percent': 9e-05},
#    {'name': 'portugal', 'percent': 8e-05},
#    {'name': 'hungary', 'percent': 5e-05},
#    {'name': 'peru', 'percent': 4e-05},
#    {'name': 'czechRepublic', 'percent': 3e-05},
#    {'name': 'colombia', 'percent': 1e-05},
#    {'name': 'argentina', 'percent': 0.0},
#    {'name': 'estonia', 'percent': 0.0},
#    {'name': 'latvia', 'percent': 0.0},
#    {'name': 'lithuania', 'percent': 0.0},
#    {'name': 'pakistan', 'percent': 0.0},
#    {'name': 'russia', 'percent': 0.0},
#    {'name': 'slovakia', 'percent': 0.0},
#    {'name': 'venezuela', 'percent': 0.0},
#    {'name': 'vietnam', 'percent': 0.0}],
#   'regions': [{'name': 'northAmerica', 'percent': 98.206},
#    {'name': 'europeDeveloped', 'percent': 0.927},
#    {'name': 'unitedKingdom', 'percent': 0.37567},
#    {'name': 'asiaDeveloped', 'percent': 0.25},
#    {'name': 'latinAmerica', 'percent': 0.08},
#    {'name': 'japan', 'percent': 0.076},
#    {'name': 'asiaEmerging', 'percent': 0.051},
#    {'name': 'other Countries', 'percent': 0.01366},
#    {'name': 'australasia', 'percent': 0.003},
#    {'name': 'europeEmerging', 'percent': 0.0}],
#   'portfolioDate': '2025-06-30T05:00:00.000'},
#  'indexPortfolio': {'countries': [{'name': 'unitedStates',
#     'percent': 99.24039},
#    {'name': 'switzerland', 'percent': 0.25965},
#    {'name': 'brazil', 'percent': 0.22518},
#    {'name': 'netherlands', 'percent': 0.09826},
#    {'name': 'singapore', 'percent': 0.05391},
#    {'name': 'ireland', 'percent': 0.04082},
#    {'name': 'unitedKingdom', 'percent': 0.03841},
#    {'name': 'mexico', 'percent': 0.03346},
#    {'name': 'argentina', 'percent': 0.0},
#    {'name': 'australia', 'percent': 0.0},
#    {'name': 'austria', 'percent': 0.0},
#    {'name': 'belgium', 'percent': 0.0},
#    {'name': 'canada', 'percent': 0.0},
#    {'name': 'chile', 'percent': 0.0},
#    {'name': 'china', 'percent': 0.0},
#    {'name': 'colombia', 'percent': 0.0},
#    {'name': 'czechRepublic', 'percent': 0.0},
#    {'name': 'denmark', 'percent': 0.0},
#    {'name': 'estonia', 'percent': 0.0},
#    {'name': 'finland', 'percent': 0.0},
#    {'name': 'france', 'percent': 0.0},
#    {'name': 'germany', 'percent': 0.0},
#    {'name': 'greece', 'percent': 0.0},
#    {'name': 'hongKong', 'percent': 0.0},
#    {'name': 'hungary', 'percent': 0.0},
#    {'name': 'india', 'percent': 0.0},
#    {'name': 'indonesia', 'percent': 0.0},
#    {'name': 'israel', 'percent': 0.0},
#    {'name': 'italy', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0},
#    {'name': 'latvia', 'percent': 0.0},
#    {'name': 'lithuania', 'percent': 0.0},
#    {'name': 'malaysia', 'percent': 0.0},
#    {'name': 'newZealand', 'percent': 0.0},
#    {'name': 'norway', 'percent': 0.0},
#    {'name': 'pakistan', 'percent': 0.0},
#    {'name': 'peru', 'percent': 0.0},
#    {'name': 'philippines', 'percent': 0.0},
#    {'name': 'poland', 'percent': 0.0},
#    {'name': 'portugal', 'percent': 0.0},
#    {'name': 'russia', 'percent': 0.0},
#    {'name': 'slovakia', 'percent': 0.0},
#    {'name': 'southAfrica', 'percent': 0.0},
#    {'name': 'southKorea', 'percent': 0.0},
#    {'name': 'spain', 'percent': 0.0},
#    {'name': 'sweden', 'percent': 0.0},
#    {'name': 'taiwan', 'percent': 0.0},
#    {'name': 'thailand', 'percent': 0.0},
#    {'name': 'turkey', 'percent': 0.0},
#    {'name': 'venezuela', 'percent': 0.0},
#    {'name': 'vietnam', 'percent': 0.0}],
#   'regions': [{'name': 'northAmerica', 'percent': 99.24},
#    {'name': 'europeDeveloped', 'percent': 0.399},
#    {'name': 'latinAmerica', 'percent': 0.259},
#    {'name': 'asiaDeveloped', 'percent': 0.054},
#    {'name': 'unitedKingdom', 'percent': 0.03841},
#    {'name': 'asiaEmerging', 'percent': 0.0},
#    {'name': 'australasia', 'percent': 0.0},
#    {'name': 'europeEmerging', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0},
#    {'name': 'other Countries', 'percent': 0.0}],
#   'portfolioDate': '2025-06-30T05:00:00.000'},
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'assetType': 'EQUITY'}

# %% [markdown]
# Return vs Standard deviation
#
#
# Risk/Return Analysis
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.riskReturnScatterplot()
# Out:
# {'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'cur': 'USD',
#  'isUKCefTemplateAvailable': False,
#  'extendedPerformanceData': {'ePUsedFor1YearFlag': False,
#   'ePUsedFor3YearFlag': False,
#   'ePUsedFor5YearFlag': False,
#   'ePUsedFor10YearFlag': False,
#   'ePUsedFor15YearFlag': False},
#  'fundScatterplot': {'standardDeviationEndDate': '2025-06-30T05:00:00.000',
#   'trailingReturnEndDate': '2025-06-30T05:00:00.000',
#   'trailingReturnPriceEndDate': '2025-06-30T05:00:00.000',
#   'for1Year': {'trailingReturn': 15.08818,
#    'trailingReturnPrice': None,
#    'standardDeviation': 13.278},
#   'for3Year': {'trailingReturn': 19.02035,
#    'trailingReturnPrice': None,
#    'standardDeviation': 16.261},
#   'for5Year': {'trailingReturn': 15.85115,
#    'trailingReturnPrice': None,
#    'standardDeviation': 16.714},
#   'for10Year': {'trailingReturn': 12.89736,
#    'trailingReturnPrice': None,
#    'standardDeviation': 16.002},
#   'for15Year': {'trailingReturn': 14.43193,
#    'trailingReturnPrice': None,
#    'standardDeviation': 14.901},
#   'forLongestTenure': None},
#  'categoryScatterplot': {'standardDeviationEndDate': '2025-06-30T05:00:00.000',
#   'trailingReturnEndDate': '2025-06-30T05:00:00.000',
#   'trailingReturnPriceEndDate': None,
#   'for1Year': {'trailingReturn': 13.30443,
#    'trailingReturnPrice': None,
#    'standardDeviation': 13.263},
#   'for3Year': {'trailingReturn': 17.55486,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.936},
#   'for5Year': {'trailingReturn': 15.14455,
#    'trailingReturnPrice': None,
#    'standardDeviation': 16.318},
#   'for10Year': {'trailingReturn': 12.05058,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.691},
#   'for15Year': {'trailingReturn': 13.53229,
#    'trailingReturnPrice': None,
#    'standardDeviation': 14.769},
#   'forLongestTenure': None},
#  'indexScatterplot': {'standardDeviationEndDate': '2025-06-30T05:00:00.000',
#   'trailingReturnEndDate': '2025-06-30T05:00:00.000',
#   'trailingReturnPriceEndDate': None,
#   'for1Year': {'trailingReturn': 15.69362,
#    'trailingReturnPrice': None,
#    'standardDeviation': 12.938},
#   'for3Year': {'trailingReturn': 19.93051,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.998},
#   'for5Year': {'trailingReturn': 16.31258,
#    'trailingReturnPrice': None,
#    'standardDeviation': 16.595},
#   'for10Year': {'trailingReturn': 13.41636,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.754},
#   'for15Year': {'trailingReturn': 14.81809,
#    'trailingReturnPrice': None,
#    'standardDeviation': 14.63},
#   'forLongestTenure': None}}

# %% [markdown]
# Return and risk compare to the category
#
# Morningstar Risk & Return
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.riskReturnSummary()
# Out:
# {'endDate': '2025-06-30T05:00:00.000',
#  'categoryName': 'Large Blend',
#  'for3Year': {'epUsedFlag': False,
#   'riskVsCategory': 4,
#   'returnVsCategory': 3,
#   'numberOfFunds': 1265},
#  'for5Year': {'epUsedFlag': False,
#   'riskVsCategory': 4,
#   'returnVsCategory': 3,
#   'numberOfFunds': 1161},
#  'for10Year': {'epUsedFlag': False,
#   'riskVsCategory': 4,
#   'returnVsCategory': 3,
#   'numberOfFunds': 894}}

# %% [markdown]
# Overal risk of the fund
#
# Portfolio Risk Score
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.riskScore()
# Out:
# {'riskScore': '73',
#  'riskLevel': 'Aggressive',
#  'asOfDate': '2025-05-31T05:00:00.000',
#  'portfolioDate': None,
#  'privateAllocationPercent': None,
#  'riskScoreRangeList': [{'riskScoreRegion': 'US',
#    'rangeName': 'Conservative',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '1',
#    'maximumScore': 23,
#    'minimumScore': 0,
#    'rangeDisplay': '0-23'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Moderate',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '2',
#    'maximumScore': 47,
#    'minimumScore': 24,
#    'rangeDisplay': '24-47'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Aggressive',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '3',
#    'maximumScore': 78,
#    'minimumScore': 48,
#    'rangeDisplay': '48-78'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Very Aggressive',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '4',
#    'maximumScore': 99,
#    'minimumScore': 79,
#    'rangeDisplay': '79-99'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Extreme',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '5',
#    'maximumScore': 500,
#    'minimumScore': 100,
#    'rangeDisplay': '100+'}]}

# %% [markdown]
# Alpha, beta, RSquared, Standard deviation end Sharpe ratio over time

# %%
funds.riskVolatility()
# Out:
# {'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'calculationBenchmark': 'S&P 500 TR USD',
#  'extendedPerformanceData': {'ePUsedFor1YearFlag': False,
#   'ePUsedFor3YearFlag': False,
#   'ePUsedFor5YearFlag': False,
#   'ePUsedFor10YearFlag': False,
#   'ePUsedFor15YearFlag': False},
#  'fundRiskVolatility': {'primaryIndexNameNew': 'S&P 500 TR USD',
#   'bestFitIndexName': 'Morningstar US Market TR USD',
#   'bestFitAlphaFor3Year': -0.367,
#   'bestFitBetaFor3Year': 1.004,
#   'bestFitRSquaredFor3Year': 99.952,
#   'endDate': '2025-06-30T05:00:00.000',
#   'for1Year': {'alpha': -0.623,
#    'beta': 1.064,
#    'rSquared': 99.128,
#    'standardDeviation': 13.278,
#    'sharpeRatio': 0.778},
#   'for3Year': {'alpha': -0.892,
#    'beta': 1.026,
#    'rSquared': 99.304,
#    'standardDeviation': 16.261,
#    'sharpeRatio': 0.864},
#   'for5Year': {'alpha': -0.914,
#    'beta': 1.021,
#    'rSquared': 99.116,
#    'standardDeviation': 16.714,
#    'sharpeRatio': 0.79},
#   'for10Year': {'alpha': -0.93,
#    'beta': 1.029,
#    'rSquared': 99.263,
#    'standardDeviation': 16.002,
#    'sharpeRatio': 0.713},
#   'for15Year': {'alpha': -0.73,
#    'beta': 1.031,
#    'rSquared': 99.258,
#    'standardDeviation': 14.901,
#    'sharpeRatio': 0.89},
#   'forLongestTenure': None},
#  'categoryRiskVolatility': {'endDate': '2025-06-30T05:00:00.000',
#   'for1Year': {'alpha': -1.635,
#    'beta': 1.003,
#    'rSquared': 89.428,
#    'standardDeviation': 13.263,
#    'sharpeRatio': 0.662},
#   'for3Year': {'alpha': -1.465,
#    'beta': 0.973,
#    'rSquared': 93.234,
#    'standardDeviation': 15.936,
#    'sharpeRatio': 0.796},
#   'for5Year': {'alpha': -0.895,
#    'beta': 0.97,
#    'rSquared': 93.785,
#    'standardDeviation': 16.318,
#    'sharpeRatio': 0.767},
#   'for10Year': {'alpha': -1.221,
#    'beta': 0.985,
#    'rSquared': 94.791,
#    'standardDeviation': 15.691,
#    'sharpeRatio': 0.678},
#   'for15Year': {'alpha': -1.138,
#    'beta': 1.001,
#    'rSquared': 95.375,
#    'standardDeviation': 14.769,
#    'sharpeRatio': 0.845},
#   'forLongestTenure': None},
#  'indexRiskVolatility': {'endDate': '2025-06-30T05:00:00.000',
#   'for1Year': {'alpha': 0.109,
#    'beta': 1.04,
#    'rSquared': 99.819,
#    'standardDeviation': 12.938,
#    'sharpeRatio': 0.836},
#   'for3Year': {'alpha': 0.044,
#    'beta': 1.012,
#    'rSquared': 99.858,
#    'standardDeviation': 15.998,
#    'sharpeRatio': 0.924},
#   'for5Year': {'alpha': -0.468,
#    'beta': 1.017,
#    'rSquared': 99.741,
#    'standardDeviation': 16.595,
#    'sharpeRatio': 0.82},
#   'for10Year': {'alpha': -0.346,
#    'beta': 1.015,
#    'rSquared': 99.798,
#    'standardDeviation': 15.754,
#    'sharpeRatio': 0.751},
#   'for15Year': {'alpha': -0.209,
#    'beta': 1.015,
#    'rSquared': 99.786,
#    'standardDeviation': 14.63,
#    'sharpeRatio': 0.927},
#   'forLongestTenure': None},
#  'cur': 'USD'}

# %% [markdown]
# Maximum Sales Fees
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.salesFees()
# Out:
# {'salesFees': {'frontloadFee': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   'frontloadFeeLowBreakpoint': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   'deferredloadFee': [None, None, None, None, None, None, None],
#   'redemptionFeeLowBreakpoint': [None, None, None, None, None, None],
#   'redemptionFee': [None, None, None, None, None, None],
#   'deferredloadFeeLowBreakpoint': [None, None, None, None, None, None, None]},
#  'minInitialInvestment': 3000,
#  'currencyId': 'USD',
#  'minInvestmentCurrency': 'USD',
#  'frontloadFeeBreakpointUnit': None,
#  'frontloadFeeUnit': None,
#  'redemptionFeeBreakpointUnit': None,
#  'redemptionFeeUnit': None,
#  'deferredloadFeeBreakpointUnit': None,
#  'deferredloadFeeUnit': None,
#  'minimumInitialInvestmentUnit': 'Monetary'}

# %% [markdown]
# Breakdown by sector
#
# Exposure - Sector
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.sector()
# Out:
# {'FIXEDINCOME': {'fundPortfolio': {'portfolioDate': '2025-05-31T05:00:00.000',
#    'government': 0.0,
#    'municipal': 0.0,
#    'corporate': 0.0,
#    'securitized': 0.0,
#    'cashAndEquivalents': 99.91534,
#    'derivative': 0.08466},
#   'categoryPortfolio': {'portfolioDate': '2025-06-30T05:00:00.000',
#    'government': 15.79906,
#    'municipal': 0.0023,
#    'corporate': 3.33771,
#    'securitized': 9.26651,
#    'cashAndEquivalents': 71.57645,
#    'derivative': 0.01797},
#   'indexPortfolio': {'portfolioDate': None,
#    'government': None,
#    'municipal': None,
#    'corporate': None,
#    'securitized': None,
#    'cashAndEquivalents': None,
#    'derivative': None},
#   'categoryName': 'Large Blend',
#   'indexName': 'Morningstar US Large-Mid TR USD',
#   'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#   'assetType': 'FIXEDINCOME'},
#  'EQUITY': {'fundPortfolio': {'portfolioDate': '2025-05-31T05:00:00.000',
#    'basicMaterials': 1.98487,
#    'consumerCyclical': 10.7713,
#    'financialServices': 14.1605,
#    'realEstate': 2.65379,
#    'communicationServices': 9.14374,
#    'energy': 3.11043,
#    'industrials': 9.08901,
#    'technology': 31.10133,
#    'consumerDefensive': 5.60003,
#    'healthcare': 9.96466,
#    'utilities': 2.42034},
#   'categoryPortfolio': {'portfolioDate': '2025-06-30T05:00:00.000',
#    'basicMaterials': 2.14212,
#    'consumerCyclical': 10.26762,
#    'financialServices': 14.61103,
#    'realEstate': 1.85469,
#    'communicationServices': 9.12757,
#    'energy': 3.15553,
#    'industrials': 9.81213,
#    'technology': 30.37248,
#    'consumerDefensive': 5.7441,
#    'healthcare': 10.62608,
#    'utilities': 2.28666},
#   'indexPortfolio': {'portfolioDate': '2025-06-30T05:00:00.000',
#    'basicMaterials': 1.74581,
#    'consumerCyclical': 10.71225,
#    'financialServices': 13.73463,
#    'realEstate': 2.02242,
#    'communicationServices': 10.05093,
#    'energy': 2.9537,
#    'industrials': 7.87957,
#    'technology': 34.05922,
#    'consumerDefensive': 5.33928,
#    'healthcare': 9.24072,
#    'utilities': 2.25155},
#   'categoryName': 'Large Blend',
#   'indexName': 'Morningstar US Large-Mid TR USD',
#   'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#   'assetType': 'EQUITY'},
#  'assetType': 'EQUITY'}

# %% [markdown]
# Snapshot of the fund and asset manager

# %%
funds.snapshot()
# Out:
# {}

# %% [markdown]
# Funds of the asset manager with lower rating
#
# Lowest Rated Investments
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.starRatingFundAsc()
# Out:
# {'StarRatingFund': [{'calendarYearFlow': -135965136.0,
#    'netAsset': 1715584319.0,
#    'fundShareClassId': 'F000011J08',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Long-Term Bond Index Admiral',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': -0.31457,
#    'trailing3YearReturnRank': '99',
#    'secId': 'F000011J08',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 106435492.0,
#    'netAsset': 918848081.0,
#    'fundShareClassId': 'F00001CKVW',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Advice Select Dividend Gr Admrl',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 10.7584,
#    'trailing3YearReturnRank': '97',
#    'secId': 'F00001CKVW',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 107089735.0,
#    'netAsset': 707516771.0,
#    'fundShareClassId': 'FOUSA06KY1',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Extended Duration Trs Idx Instl',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': -9.09381,
#    'trailing3YearReturnRank': '92',
#    'secId': 'FOUSA06KY1',
#    'securityType': 'FO'},
#   {'calendarYearFlow': -14224117.0,
#    'netAsset': 260751897.0,
#    'fundShareClassId': 'F00000ZAFI',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Baillie GiffordGlbPstvImpStkInv',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 14.05346,
#    'trailing3YearReturnRank': '74',
#    'secId': 'F00000ZAFI',
#    'securityType': 'FO'},
#   {'calendarYearFlow': -6960690119.0,
#    'netAsset': 47611990745.0,
#    'fundShareClassId': 'FOUSA00FUG',
#    'mstarRating': '2',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Dividend Growth Inv',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 9.28939,
#    'trailing3YearReturnRank': '99',
#    'secId': 'FOUSA00FUG',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2025-06-30T05:00:00.000',
#  'footerReturnDate': '2025-06-30T05:00:00.000',
#  'currency': 'USD',
#  'secId': None,
#  'securityType': None,
#  'userType': 'Free'}

# %% [markdown]
# Funds of the asset manager with higher rating
#
# Highest Rated Investments
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.starRatingFundDesc()
# Out:
# {'StarRatingFund': [{'calendarYearFlow': -15928247136.0,
#    'netAsset': 586598496648.0,
#    'fundShareClassId': 'FOUSA00L8W',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard 500 Index Admiral',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 19.65995,
#    'trailing3YearReturnRank': '23',
#    'secId': 'FOUSA00L8W',
#    'securityType': 'FO'},
#   {'calendarYearFlow': -3932520588.0,
#    'netAsset': 196378179138.0,
#    'fundShareClassId': 'FOUSA00GPG',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Institutional Index Instl Pl',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 19.68529,
#    'trailing3YearReturnRank': '22',
#    'secId': 'FOUSA00GPG',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 387727358.0,
#    'netAsset': 15549399884.0,
#    'fundShareClassId': 'FOUSA04BNE',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Information Technology Idx Adm',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 27.52502,
#    'trailing3YearReturnRank': '31',
#    'secId': 'FOUSA04BNE',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 220343015.0,
#    'netAsset': 14024999022.0,
#    'fundShareClassId': 'FOUSA02TY9',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard High-Yield Tax-Exempt Adm',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 3.36723,
#    'trailing3YearReturnRank': '6',
#    'secId': 'FOUSA02TY9',
#    'securityType': 'FO'},
#   {'calendarYearFlow': -800556246.0,
#    'netAsset': 12723327580.0,
#    'fundShareClassId': 'FOUSA02T4I',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Growth & Income Adm',
#    'returnEndDate': '2025-06-30T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 19.83566,
#    'trailing3YearReturnRank': '20',
#    'secId': 'FOUSA02T4I',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2025-06-30T05:00:00.000',
#  'footerReturnDate': '2025-06-30T05:00:00.000',
#  'currency': 'USD',
#  'secId': None,
#  'securityType': None,
#  'userType': 'Free'}

# %% [markdown]
# General information and return on funds

# %%
funds.strategyPreview()
# Out:
# {'shareClassList': [{'fundSimplePerformance': [{'year': 1,
#      'returnData': [1.82697,
#       2.17113,
#       2.04794,
#       -0.75428,
#       6.63549,
#       -3.02793,
#       3.0911,
#       -1.90496,
#       -5.88726,
#       -0.66532,
#       6.33654,
#       5.07742],
#      'trailingReturn': 15.09726,
#      'epUsed': '0'},
#     {'year': 3,
#      'returnData': [9.39202,
#       -3.7251,
#       -9.27952,
#       8.17682,
#       5.22973,
#       -5.86639,
#       6.89433,
#       -2.33072,
#       2.63319,
#       1.04649,
#       0.41824,
#       6.85179,
#       3.5681,
#       -1.93397,
#       -4.78878,
#       -2.62038,
#       9.37345,
#       5.31606,
#       1.11679,
#       5.4024,
#       3.21334,
#       -4.41478,
#       4.7261,
#       3.1428,
#       1.82697,
#       2.17113,
#       2.04794,
#       -0.75428,
#       6.63549,
#       -3.02793,
#       3.0911,
#       -1.90496,
#       -5.88726,
#       -0.66532,
#       6.33654,
#       5.07742],
#      'trailingReturn': 19.03317,
#      'epUsed': '0'},
#     {'year': 5,
#      'returnData': [5.63713,
#       7.18541,
#       -3.56568,
#       -2.14587,
#       12.20894,
#       4.45185,
#       -0.32718,
#       3.1978,
#       3.47287,
#       5.14377,
#       0.42581,
#       2.55619,
#       1.70491,
#       2.87242,
#       -4.48234,
#       6.72525,
#       -1.48219,
#       3.8195,
#       -6.02994,
#       -2.55227,
#       3.23794,
#       -9.01543,
#       -0.25789,
#       -8.36577,
#       9.39202,
#       -3.7251,
#       -9.27952,
#       8.17682,
#       5.22973,
#       -5.86639,
#       6.89433,
#       -2.33072,
#       2.63319,
#       1.04649,
#       0.41824,
#       6.85179,
#       3.5681,
#       -1.93397,
#       -4.78878,
#       -2.62038,
#       9.37345,
#       5.31606,
#       1.11679,
#       5.4024,
#       3.21334,
#       -4.41478,
#       4.7261,
#       3.1428,
#       1.82697,
#       2.17113,
#       2.04794,
#       -0.75428,
#       6.63549,
#       -3.02793,
#       3.0911,
#       -1.90496,
#       -5.88726,
#       -0.66532,
#       6.33654,
#       5.07742],
#      'trailingReturn': 15.85987,
#      'epUsed': '0'},
#     {'year': 10,
#      'returnData': [1.65036,
#       -6.0034,
#       -2.94335,
#       7.8619,
#       0.5592,
#       -2.02959,
#       -5.66929,
#       -0.02087,
#       7.03439,
#       0.62696,
#       1.79128,
#       0.2337,
#       3.9678,
#       0.27655,
#       0.15565,
#       -2.21361,
#       4.45199,
#       1.93526,
#       1.90765,
#       3.72638,
#       0.08018,
#       1.0496,
#       1.02195,
#       0.92881,
#       1.8653,
#       0.17825,
#       2.44691,
#       2.17253,
#       3.04206,
#       1.004,
#       5.31995,
#       -3.71372,
#       -1.98143,
#       0.37844,
#       2.82009,
#       0.67561,
#       3.3504,
#       3.45413,
#       0.1618,
#       -7.38504,
#       2.06017,
#       -9.28992,
#       8.61514,
#       3.49889,
#       1.44776,
#       3.98921,
#       -6.44369,
#       6.99241,
#       1.45106,
#       -2.02402,
#       1.70337,
#       2.12216,
#       3.76981,
#       2.8651,
#       -0.06274,
#       -8.17326,
#       -13.76591,
#       13.25685,
#       5.38829,
#       2.29198,
#       5.63713,
#       7.18541,
#       -3.56568,
#       -2.14587,
#       12.20894,
#       4.45185,
#       -0.32718,
#       3.1978,
#       3.47287,
#       5.14377,
#       0.42581,
#       2.55619,
#       1.70491,
#       2.87242,
#       -4.48234,
#       6.72525,
#       -1.48219,
#       3.8195,
#       -6.02994,
#       -2.55227,
#       3.23794,
#       -9.01543,
#       -0.25789,
#       -8.36577,
#       9.39202,
#       -3.7251,
#       -9.27952,
#       8.17682,
#       5.22973,
#       -5.86639,
#       6.89433,
#       -2.33072,
#       2.63319,
#       1.04649,
#       0.41824,
#       6.85179,
#       3.5681,
#       -1.93397,
#       -4.78878,
#       -2.62038,
#       9.37345,
#       5.31606,
#       1.11679,
#       5.4024,
#       3.21334,
#       -4.41478,
#       4.7261,
#       3.1428,
#       1.82697,
#       2.17113,
#       2.04794,
#       -0.75428,
#       6.63549,
#       -3.02793,
#       3.0911,
#       -1.90496,
#       -5.88726,
#       -0.66532,
#       6.33654,
#       5.07742],
#      'trailingReturn': 12.90725,
#      'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Market Idx I',
#     'secId': 'FOUSA00GQ7',
#     'securityType': 'FO',
#     'fundShareClassId': 'FOUSA00GQ7',
#     'ticker': 'VITSX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229088011',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2025-06-30 00:00:00.0',
#     'analystRating': '7',
#     'analystRatingEndDate': '2023-03-06 00:00:00.0',
#     'quantRatingEndDate': None,
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2024-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.03,
#     'indiaMonthlyReportDate': None,
#     'rating': None,
#     'adjustExpenseRatio': 0.03,
#     'expenseRatio': 0.03,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2024-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 96696700218.0,
#     'minimumInitialInvestment': 5000000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.22029,
#     'secYield': 1.19,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '1',
#     'qualifiedInvestment': '1',
#     'returnEndDate': '2025-06-30 00:00:00.0',
#     'trailing1YearReturn': 15.09726,
#     'trailing3YearReturn': 19.03317,
#     'trailing5YearReturn': 15.85987,
#     'trailing10YearReturn': 12.90725,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '1997-07-07 00:00:00.0',
#     'actual12b1': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [1.82726,
#       2.17145,
#       2.04579,
#       -0.75439,
#       6.62915,
#       -3.024,
#       3.09154,
#       -1.9121,
#       -5.88418,
#       -0.6729,
#       6.3455,
#       5.07574],
#      'trailingReturn': 15.08818,
#      'epUsed': '0'},
#     {'year': 3,
#      'returnData': [9.39305,
#       -3.73543,
#       -9.27367,
#       8.1663,
#       5.23083,
#       -5.87001,
#       6.89581,
#       -2.33119,
#       2.64133,
#       1.04659,
#       0.41829,
#       6.83993,
#       3.56877,
#       -1.93432,
#       -4.78287,
#       -2.63031,
#       9.37531,
#       5.31444,
#       1.11698,
#       5.40332,
#       3.21141,
#       -4.41548,
#       4.72688,
#       3.14061,
#       1.82726,
#       2.17145,
#       2.04579,
#       -0.75439,
#       6.62915,
#       -3.024,
#       3.09154,
#       -1.9121,
#       -5.88418,
#       -0.6729,
#       6.3455,
#       5.07574],
#      'trailingReturn': 19.02035,
#      'epUsed': '0'},
#     {'year': 5,
#      'returnData': [5.65172,
#       7.17389,
#       -3.55756,
#       -2.14613,
#       12.19813,
#       4.4613,
#       -0.32721,
#       3.18755,
#       3.48115,
#       5.13433,
#       0.43536,
#       2.54433,
#       1.71444,
#       2.86362,
#       -4.4856,
#       6.7265,
#       -1.48244,
#       3.81751,
#       -6.03096,
#       -2.55273,
#       3.24507,
#       -9.01625,
#       -0.26783,
#       -8.36009,
#       9.39305,
#       -3.73543,
#       -9.27367,
#       8.1663,
#       5.23083,
#       -5.87001,
#       6.89581,
#       -2.33119,
#       2.64133,
#       1.04659,
#       0.41829,
#       6.83993,
#       3.56877,
#       -1.93432,
#       -4.78287,
#       -2.63031,
#       9.37531,
#       5.31444,
#       1.11698,
#       5.40332,
#       3.21141,
#       -4.41548,
#       4.72688,
#       3.14061,
#       1.82726,
#       2.17145,
#       2.04579,
#       -0.75439,
#       6.62915,
#       -3.024,
#       3.09154,
#       -1.9121,
#       -5.88418,
#       -0.6729,
#       6.3455,
#       5.07574],
#      'trailingReturn': 15.85115,
#      'epUsed': '0'},
#     {'year': 10,
#      'returnData': [1.65067,
#       -6.00453,
#       -2.94394,
#       7.86353,
#       0.55931,
#       -2.03595,
#       -5.65072,
#       -0.04174,
#       7.03363,
#       0.64668,
#       1.77181,
#       0.2491,
#       3.94863,
#       0.2766,
#       0.15383,
#       -2.21402,
#       4.45283,
#       1.93382,
#       1.92582,
#       3.70889,
#       0.07849,
#       1.04978,
#       1.02212,
#       0.92732,
#       1.86561,
#       0.16207,
#       2.46232,
#       2.17288,
#       3.04253,
#       1.00521,
#       5.32074,
#       -3.71425,
#       -1.98311,
#       0.3785,
#       2.82051,
#       0.67461,
#       3.35089,
#       3.45462,
#       0.16114,
#       -7.39978,
#       2.07561,
#       -9.2961,
#       8.60042,
#       3.51476,
#       1.44506,
#       3.97558,
#       -6.43179,
#       6.9908,
#       1.43757,
#       -2.01107,
#       1.70101,
#       2.10884,
#       3.78414,
#       2.86271,
#       -0.07529,
#       -8.16275,
#       -13.77107,
#       13.25896,
#       5.37498,
#       2.29028,
#       5.65172,
#       7.17389,
#       -3.55756,
#       -2.14613,
#       12.19813,
#       4.4613,
#       -0.32721,
#       3.18755,
#       3.48115,
#       5.13433,
#       0.43536,
#       2.54433,
#       1.71444,
#       2.86362,
#       -4.4856,
#       6.7265,
#       -1.48244,
#       3.81751,
#       -6.03096,
#       -2.55273,
#       3.24507,
#       -9.01625,
#       -0.26783,
#       -8.36009,
#       9.39305,
#       -3.73543,
#       -9.27367,
#       8.1663,
#       5.23083,
#       -5.87001,
#       6.89581,
#       -2.33119,
#       2.64133,
#       1.04659,
#       0.41829,
#       6.83993,
#       3.56877,
#       -1.93432,
#       -4.78287,
#       -2.63031,
#       9.37531,
#       5.31444,
#       1.11698,
#       5.40332,
#       3.21141,
#       -4.41548,
#       4.72688,
#       3.14061,
#       1.82726,
#       2.17145,
#       2.04579,
#       -0.75439,
#       6.62915,
#       -3.024,
#       3.09154,
#       -1.9121,
#       -5.88418,
#       -0.6729,
#       6.3455,
#       5.07574],
#      'trailingReturn': 12.89736,
#      'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Adm',
#     'secId': 'FOUSA00L83',
#     'securityType': 'FO',
#     'fundShareClassId': 'FOUSA00L83',
#     'ticker': 'VTSAX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229087286',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2025-06-30 00:00:00.0',
#     'analystRating': '7',
#     'analystRatingEndDate': '2023-03-06 00:00:00.0',
#     'quantRatingEndDate': None,
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2024-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.04,
#     'indiaMonthlyReportDate': None,
#     'rating': None,
#     'adjustExpenseRatio': 0.04,
#     'expenseRatio': 0.04,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2024-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 418703223349.0,
#     'minimumInitialInvestment': 3000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.211,
#     'secYield': 1.18,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '0',
#     'qualifiedInvestment': '1',
#     'returnEndDate': '2025-06-30 00:00:00.0',
#     'trailing1YearReturn': 15.08818,
#     'trailing3YearReturn': 19.02035,
#     'trailing5YearReturn': 15.85115,
#     'trailing10YearReturn': 12.89736,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2000-11-13 00:00:00.0',
#     'actual12b1': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [1.8376,
#       2.16614,
#       2.04874,
#       -0.75011,
#       6.63446,
#       -3.0297,
#       3.09547,
#       -1.90637,
#       -5.88712,
#       -0.66552,
#       6.33876,
#       5.08206],
#      'trailingReturn': 15.11683,
#      'epUsed': '0'},
#     {'year': 3,
#      'returnData': [9.40042,
#       -3.7334,
#       -9.27641,
#       8.1766,
#       5.23285,
#       -5.87297,
#       6.9003,
#       -2.33019,
#       2.63821,
#       1.04619,
#       0.41945,
#       6.84591,
#       3.57161,
#       -1.92806,
#       -4.78702,
#       -2.62398,
#       9.37053,
#       5.31952,
#       1.11701,
#       5.40467,
#       3.21616,
#       -4.41263,
#       4.72646,
#       3.1375,
#       1.8376,
#       2.16614,
#       2.04874,
#       -0.75011,
#       6.63446,
#       -3.0297,
#       3.09547,
#       -1.90637,
#       -5.88712,
#       -0.66552,
#       6.33876,
#       5.08206],
#      'trailingReturn': 19.04603,
#      'epUsed': '0'},
#     {'year': 5,
#      'returnData': [5.64877,
#       7.18634,
#       -3.56074,
#       -2.14694,
#       12.19865,
#       4.45879,
#       -0.32641,
#       3.19575,
#       3.47551,
#       5.14616,
#       0.42888,
#       2.5517,
#       1.71016,
#       2.86998,
#       -4.48318,
#       6.72356,
#       -1.47908,
#       3.8167,
#       -6.02748,
#       -2.54344,
#       3.23576,
#       -9.01304,
#       -0.25915,
#       -8.3666,
#       9.40042,
#       -3.7334,
#       -9.27641,
#       8.1766,
#       5.23285,
#       -5.87297,
#       6.9003,
#       -2.33019,
#       2.63821,
#       1.04619,
#       0.41945,
#       6.84591,
#       3.57161,
#       -1.92806,
#       -4.78702,
#       -2.62398,
#       9.37053,
#       5.31952,
#       1.11701,
#       5.40467,
#       3.21616,
#       -4.41263,
#       4.72646,
#       3.1375,
#       1.8376,
#       2.16614,
#       2.04874,
#       -0.75011,
#       6.63446,
#       -3.0297,
#       3.09547,
#       -1.90637,
#       -5.88712,
#       -0.66552,
#       6.33876,
#       5.08206],
#      'trailingReturn': 15.87351,
#      'epUsed': '0'},
#     {'year': 10,
#      'returnData': [1.63716,
#       -6.0002,
#       -2.92788,
#       7.86293,
#       0.55521,
#       -2.0343,
#       -5.6582,
#       -0.02225,
#       7.02809,
#       0.64779,
#       1.78553,
#       0.23369,
#       3.96566,
#       0.26543,
#       0.1688,
#       -2.20342,
#       4.43573,
#       1.93631,
#       1.92052,
#       3.72201,
#       0.07811,
#       1.06527,
#       1.01831,
#       0.9269,
#       1.86603,
#       0.17282,
#       2.45415,
#       2.17318,
#       3.03733,
#       1.00981,
#       5.33003,
#       -3.71747,
#       -1.97819,
#       0.37937,
#       2.81441,
#       0.67951,
#       3.34686,
#       3.45739,
#       0.16519,
#       -7.39277,
#       2.07082,
#       -9.29026,
#       8.60381,
#       3.51044,
#       1.4489,
#       3.98183,
#       -6.43564,
#       6.98951,
#       1.44536,
#       -2.01482,
#       1.70735,
#       2.11084,
#       3.77921,
#       2.8638,
#       -0.06691,
#       -8.16818,
#       -13.7663,
#       13.26366,
#       5.37884,
#       2.29532,
#       5.64877,
#       7.18634,
#       -3.56074,
#       -2.14694,
#       12.19865,
#       4.45879,
#       -0.32641,
#       3.19575,
#       3.47551,
#       5.14616,
#       0.42888,
#       2.5517,
#       1.71016,
#       2.86998,
#       -4.48318,
#       6.72356,
#       -1.47908,
#       3.8167,
#       -6.02748,
#       -2.54344,
#       3.23576,
#       -9.01304,
#       -0.25915,
#       -8.3666,
#       9.40042,
#       -3.7334,
#       -9.27641,
#       8.1766,
#       5.23285,
#       -5.87297,
#       6.9003,
#       -2.33019,
#       2.63821,
#       1.04619,
#       0.41945,
#       6.84591,
#       3.57161,
#       -1.92806,
#       -4.78702,
#       -2.62398,
#       9.37053,
#       5.31952,
#       1.11701,
#       5.40467,
#       3.21616,
#       -4.41263,
#       4.72646,
#       3.1375,
#       1.8376,
#       2.16614,
#       2.04874,
#       -0.75011,
#       6.63446,
#       -3.0297,
#       3.09547,
#       -1.90637,
#       -5.88712,
#       -0.66552,
#       6.33876,
#       5.08206],
#      'trailingReturn': 12.91997,
#      'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Instl Pls',
#     'secId': 'F00000VE7X',
#     'securityType': 'FO',
#     'fundShareClassId': 'F00000VE7X',
#     'ticker': 'VSMPX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229083558',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2025-06-30 00:00:00.0',
#     'analystRating': '7',
#     'analystRatingEndDate': '2023-03-06 00:00:00.0',
#     'quantRatingEndDate': None,
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2024-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.02,
#     'indiaMonthlyReportDate': None,
#     'rating': None,
#     'adjustExpenseRatio': 0.02,
#     'expenseRatio': 0.02,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2024-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 786337258753.0,
#     'minimumInitialInvestment': 100000000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.22331,
#     'secYield': 1.25,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '1',
#     'qualifiedInvestment': '1',
#     'returnEndDate': '2025-06-30 00:00:00.0',
#     'trailing1YearReturn': 15.11683,
#     'trailing3YearReturn': 19.04603,
#     'trailing5YearReturn': 15.87351,
#     'trailing10YearReturn': 12.91997,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2015-04-28 00:00:00.0',
#     'actual12b1': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [1.83669,
#       2.16734,
#       2.0531,
#       -0.75152,
#       6.63301,
#       -3.02523,
#       3.09687,
#       -1.90709,
#       -5.88466,
#       -0.66824,
#       6.34126,
#       5.0821],
#      'trailingReturn': 15.12748,
#      'epUsed': '0'},
#     {'year': 3,
#      'returnData': [9.39594,
#       -3.73013,
#       -9.27449,
#       8.17621,
#       5.23428,
#       -5.87204,
#       6.90314,
#       -2.33282,
#       2.63796,
#       1.05322,
#       0.41993,
#       6.84483,
#       3.5738,
#       -1.93318,
#       -4.78301,
#       -2.62318,
#       9.37295,
#       5.32061,
#       1.11712,
#       5.40646,
#       3.21776,
#       -4.41707,
#       4.73033,
#       3.13899,
#       1.83669,
#       2.16734,
#       2.0531,
#       -0.75152,
#       6.63301,
#       -3.02523,
#       3.09687,
#       -1.90709,
#       -5.88466,
#       -0.66824,
#       6.34126,
#       5.0821],
#      'trailingReturn': 19.05707,
#      'epUsed': '0'},
#     {'year': 5,
#      'returnData': [5.64328,
#       7.18971,
#       -3.56079,
#       -2.14421,
#       12.20184,
#       4.46145,
#       -0.32717,
#       3.1963,
#       3.47695,
#       5.14713,
#       0.42797,
#       2.55454,
#       1.70944,
#       2.87333,
#       -4.48416,
#       6.72277,
#       -1.47571,
#       3.81835,
#       -6.02524,
#       -2.54806,
#       3.24236,
#       -9.01587,
#       -0.25706,
#       -8.36423,
#       9.39594,
#       -3.73013,
#       -9.27449,
#       8.17621,
#       5.23428,
#       -5.87204,
#       6.90314,
#       -2.33282,
#       2.63796,
#       1.05322,
#       0.41993,
#       6.84483,
#       3.5738,
#       -1.93318,
#       -4.78301,
#       -2.62318,
#       9.37295,
#       5.32061,
#       1.11712,
#       5.40646,
#       3.21776,
#       -4.41707,
#       4.73033,
#       3.13899,
#       1.83669,
#       2.16734,
#       2.0531,
#       -0.75152,
#       6.63301,
#       -3.02523,
#       3.09687,
#       -1.90709,
#       -5.88466,
#       -0.66824,
#       6.34126,
#       5.0821],
#      'trailingReturn': 15.88493,
#      'epUsed': '0'},
#     {'year': 10,
#      'returnData': [1.63179,
#       -6.02569,
#       -2.93337,
#       7.84436,
#       0.54023,
#       -2.02798,
#       -5.67152,
#       -0.04175,
#       7.01096,
#       0.62733,
#       1.79232,
#       0.22593,
#       3.96416,
#       0.26232,
#       0.16756,
#       -2.20306,
#       4.43827,
#       1.94229,
#       1.92081,
#       3.71589,
#       0.08152,
#       1.05825,
#       1.03014,
#       0.92456,
#       1.87065,
#       0.16469,
#       2.46086,
#       2.16778,
#       3.04464,
#       1.0111,
#       5.3309,
#       -3.72352,
#       -1.9768,
#       0.38464,
#       2.81248,
#       0.68518,
#       3.34572,
#       3.45324,
#       0.17562,
#       -7.39397,
#       2.07141,
#       -9.29122,
#       8.60884,
#       3.51115,
#       1.44536,
#       3.9824,
#       -6.43169,
#       6.98604,
#       1.44706,
#       -2.01618,
#       1.71454,
#       2.10839,
#       3.78444,
#       2.86232,
#       -0.06376,
#       -8.16691,
#       -13.76993,
#       13.26423,
#       5.38357,
#       2.29305,
#       5.64328,
#       7.18971,
#       -3.56079,
#       -2.14421,
#       12.20184,
#       4.46145,
#       -0.32717,
#       3.1963,
#       3.47695,
#       5.14713,
#       0.42797,
#       2.55454,
#       1.70944,
#       2.87333,
#       -4.48416,
#       6.72277,
#       -1.47571,
#       3.81835,
#       -6.02524,
#       -2.54806,
#       3.24236,
#       -9.01587,
#       -0.25706,
#       -8.36423,
#       9.39594,
#       -3.73013,
#       -9.27449,
#       8.17621,
#       5.23428,
#       -5.87204,
#       6.90314,
#       -2.33282,
#       2.63796,
#       1.05322,
#       0.41993,
#       6.84483,
#       3.5738,
#       -1.93318,
#       -4.78301,
#       -2.62318,
#       9.37295,
#       5.32061,
#       1.11712,
#       5.40646,
#       3.21776,
#       -4.41707,
#       4.73033,
#       3.13899,
#       1.83669,
#       2.16734,
#       2.0531,
#       -0.75152,
#       6.63301,
#       -3.02523,
#       3.09687,
#       -1.90709,
#       -5.88466,
#       -0.66824,
#       6.34126,
#       5.0821],
#      'trailingReturn': 12.914,
#      'epUsed': '1'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Instl Sel',
#     'secId': 'F00000WTNR',
#     'securityType': 'FO',
#     'fundShareClassId': 'F00000WTNR',
#     'ticker': 'VSTSX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229083301',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2025-06-30 00:00:00.0',
#     'analystRating': '7',
#     'analystRatingEndDate': '2023-03-06 00:00:00.0',
#     'quantRatingEndDate': None,
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2024-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.01,
#     'indiaMonthlyReportDate': None,
#     'rating': None,
#     'adjustExpenseRatio': 0.01,
#     'expenseRatio': 0.01,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2024-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 88885592027.0,
#     'minimumInitialInvestment': 5000000000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.22617,
#     'secYield': 1.26,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '1',
#     'qualifiedInvestment': '1',
#     'returnEndDate': '2025-06-30 00:00:00.0',
#     'trailing1YearReturn': 15.12748,
#     'trailing3YearReturn': 19.05707,
#     'trailing5YearReturn': 15.88493,
#     'trailing10YearReturn': 12.914,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '1',
#     'inceptionDate': '2016-06-27 00:00:00.0',
#     'actual12b1': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [1.81986,
#       2.1644,
#       2.03656,
#       -0.76175,
#       6.62329,
#       -3.04076,
#       3.08511,
#       -1.91262,
#       -5.8979,
#       -0.673,
#       6.32387,
#       5.07406],
#      'trailingReturn': 14.9768,
#      'epUsed': '0'},
#     {'year': 3,
#      'returnData': [9.3951,
#       -3.74614,
#       -9.28109,
#       8.15578,
#       5.23194,
#       -5.88435,
#       6.88581,
#       -2.34171,
#       2.62659,
#       1.0468,
#       0.40841,
#       6.83597,
#       3.55978,
#       -1.94367,
#       -4.7994,
#       -2.63082,
#       9.36724,
#       5.30867,
#       1.09976,
#       5.39615,
#       3.21157,
#       -4.43163,
#       4.71979,
#       3.13095,
#       1.81986,
#       2.1644,
#       2.03656,
#       -0.76175,
#       6.62329,
#       -3.04076,
#       3.08511,
#       -1.91262,
#       -5.8979,
#       -0.673,
#       6.32387,
#       5.07406],
#      'trailingReturn': 18.9047,
#      'epUsed': '0'},
#     {'year': 5,
#      'returnData': [5.64008,
#       7.17656,
#       -3.5722,
#       -2.15871,
#       12.19031,
#       4.44976,
#       -0.33787,
#       3.1889,
#       3.46728,
#       5.13586,
#       0.42602,
#       2.52663,
#       1.7057,
#       2.85559,
#       -4.48801,
#       6.70924,
#       -1.49163,
#       3.81079,
#       -6.04101,
#       -2.55365,
#       3.23323,
#       -9.0269,
#       -0.26791,
#       -8.37843,
#       9.3951,
#       -3.74614,
#       -9.28109,
#       8.15578,
#       5.23194,
#       -5.88435,
#       6.88581,
#       -2.34171,
#       2.62659,
#       1.0468,
#       0.40841,
#       6.83597,
#       3.55978,
#       -1.94367,
#       -4.7994,
#       -2.63082,
#       9.36724,
#       5.30867,
#       1.09976,
#       5.39615,
#       3.21157,
#       -4.43163,
#       4.71979,
#       3.13095,
#       1.81986,
#       2.1644,
#       2.03656,
#       -0.76175,
#       6.62329,
#       -3.04076,
#       3.08511,
#       -1.91262,
#       -5.8979,
#       -0.673,
#       6.32387,
#       5.07406],
#      'trailingReturn': 15.73537,
#      'epUsed': '0'},
#     {'year': 10,
#      'returnData': [1.63179,
#       -6.02569,
#       -2.93337,
#       7.84436,
#       0.54023,
#       -2.02798,
#       -5.67152,
#       -0.04175,
#       7.01096,
#       0.62733,
#       1.79232,
#       0.22593,
#       3.95014,
#       0.25825,
#       0.1501,
#       -2.21484,
#       4.43564,
#       1.92062,
#       1.90867,
#       3.71083,
#       0.06644,
#       1.05014,
#       1.0057,
#       0.92114,
#       1.86623,
#       0.14591,
#       2.45348,
#       2.1577,
#       3.04395,
#       0.99454,
#       5.30735,
#       -3.71583,
#       -1.99368,
#       0.37862,
#       2.79119,
#       0.67843,
#       3.33724,
#       3.44193,
#       0.15957,
#       -7.40181,
#       2.0614,
#       -9.29319,
#       8.5857,
#       3.50096,
#       1.43576,
#       3.97671,
#       -6.44721,
#       6.96924,
#       1.43816,
#       -2.02538,
#       1.7035,
#       2.09581,
#       3.77233,
#       2.85019,
#       -0.07532,
#       -8.17839,
#       -13.77742,
#       13.24725,
#       5.37725,
#       2.2796,
#       5.64008,
#       7.17656,
#       -3.5722,
#       -2.15871,
#       12.19031,
#       4.44976,
#       -0.33787,
#       3.1889,
#       3.46728,
#       5.13586,
#       0.42602,
#       2.52663,
#       1.7057,
#       2.85559,
#       -4.48801,
#       6.70924,
#       -1.49163,
#       3.81079,
#       -6.04101,
#       -2.55365,
#       3.23323,
#       -9.0269,
#       -0.26791,
#       -8.37843,
#       9.3951,
#       -3.74614,
#       -9.28109,
#       8.15578,
#       5.23194,
#       -5.88435,
#       6.88581,
#       -2.34171,
#       2.62659,
#       1.0468,
#       0.40841,
#       6.83597,
#       3.55978,
#       -1.94367,
#       -4.7994,
#       -2.63082,
#       9.36724,
#       5.30867,
#       1.09976,
#       5.39615,
#       3.21157,
#       -4.43163,
#       4.71979,
#       3.13095,
#       1.81986,
#       2.1644,
#       2.03656,
#       -0.76175,
#       6.62329,
#       -3.04076,
#       3.08511,
#       -1.91262,
#       -5.8979,
#       -0.673,
#       6.32387,
#       5.07406],
#      'trailingReturn': 12.78175,
#      'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Inv',
#     'secId': 'FOUSA00FQU',
#     'securityType': 'FO',
#     'fundShareClassId': 'FOUSA00FQU',
#     'ticker': 'VTSMX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229083061',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2025-06-30 00:00:00.0',
#     'analystRating': '6',
#     'analystRatingEndDate': '2023-03-06 00:00:00.0',
#     'quantRatingEndDate': None,
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2024-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.14,
#     'indiaMonthlyReportDate': None,
#     'rating': None,
#     'adjustExpenseRatio': 0.14,
#     'expenseRatio': 0.14,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2024-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 23121549164.0,
#     'minimumInitialInvestment': 3000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.11683,
#     'secYield': 1.08,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '1',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': None,
#     'qualifiedInvestment': '1',
#     'returnEndDate': '2025-06-30 00:00:00.0',
#     'trailing1YearReturn': 14.9768,
#     'trailing3YearReturn': 18.9047,
#     'trailing5YearReturn': 15.73537,
#     'trailing10YearReturn': 12.78175,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '1992-04-27 00:00:00.0',
#     'actual12b1': None}}],
#  'template': 'USA_OE'}

# %% [markdown]
# Sustainability data

# %%
funds.sustainability()
# Out:
# {}

# %% [markdown]
# Return of the fund after taxes
#
# Taxes
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.taxes()
# Out:
# {'categoryEndDate': '2025-06-30T05:00:00.000',
#  'returnEndDate': '2025-06-30T05:00:00.000',
#  'trailing1YearTaxCostRatio': None,
#  'trailing3YearTaxCostRatio': 0.37,
#  'trailing5YearTaxCostRatio': None,
#  'trailing10YearTaxCostRatio': None,
#  'trailing15YearTaxCostRatio': None,
#  'sinceInceptionTaxCostRatio': None,
#  'potentialCapitalGain': 0.5640532,
#  'trailing1YearTaxCostRatioCategory': None,
#  'trailing3YearTaxCostRatioCategory': 1.22275,
#  'trailing5YearTaxCostRatioCategory': None,
#  'trailing10YearTaxCostRatioCategory': None,
#  'trailing15YearTaxCostRatioCategory': None,
#  'sinceInceptionTaxCostRatioCategory': None,
#  'priceTemplate': 'USA_OE'}

# %% [markdown]
# Traling Returns
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.trailingReturn()
# Out:
# {'columnDefs': ['1Day',
#   '1Week',
#   '1Month',
#   '3Month',
#   'YearToDate',
#   '1Year',
#   '3Year',
#   '5Year',
#   '10Year',
#   '15Year',
#   'SinceInception'],
#  'hasDailyData': True,
#  'investorRankApplicable': False,
#  'adjustedTaxReturnApplicable': False,
#  'duration': 'daily',
#  'totalReturnNAV': ['0.60833',
#   '0.26649',
#   '5.4772',
#   '19.82886',
#   '7.40782',
#   '13.81734',
#   '18.84393',
#   '15.30409',
#   '12.78007',
#   '14.32426',
#   '8.63297'],
#  'netReturn': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'netOfFeesReturn': [],
#  'totalReturnNavEPFlag': [],
#  'totalReturnPrice': [],
#  'totalReturnCategory': [0.017900000000000027,
#   0.19495,
#   0.6872400000000001,
#   1.9332799999999999,
#   0.35531999999999986,
#   1.8371300000000002,
#   1.4852300000000014,
#   0.7820800000000006,
#   0.8850700000000007,
#   0.9263900000000014,
#   None],
#  'totalReturnCategoryNew': [0.59043,
#   0.07154,
#   4.78996,
#   17.89558,
#   7.0525,
#   11.98021,
#   17.3587,
#   14.52201,
#   11.895,
#   13.39787,
#   None],
#  'totalReturnCategoryPrice': [],
#  'totalReturnCategoryEPFlag': [],
#  'fundNumber': [1428,
#   1428,
#   1417,
#   1411,
#   1392,
#   1356,
#   1265,
#   1162,
#   894,
#   699,
#   None],
#  'fundNumberPrice': [],
#  'totalReturnIndex': [0.06519000000000008,
#   -0.06825999999999999,
#   0.10675999999999952,
#   -0.11593000000000231,
#   -0.5556599999999996,
#   -0.9069900000000004,
#   -0.8421300000000009,
#   -0.37417999999999907,
#   -0.4736399999999996,
#   -0.3555899999999994,
#   None],
#  'totalReturnIndexNew': [0.54314,
#   0.33475,
#   5.37044,
#   19.94479,
#   7.96348,
#   14.72433,
#   19.68606,
#   15.67827,
#   13.25371,
#   14.67985,
#   None],
#  'returnRank': [40, 41, 26, 32, 49, 33, 40, 47, 36, 32, None],
#  'returnMarketPriceRank': [],
#  'extendedPerformanceFlag': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'investorReturn': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'investorReturnRank': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'taxAdjustedReturn': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'taxAdjustedReturnRank': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'taxCostRatio': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'overallMorningstarRating': 3,
#  'morningstarRatingFor3Year': 3,
#  'morningstarRatingFor5Year': 3,
#  'morningstarRatingFor10Year': 3,
#  'ePUsedForOverallRating': False,
#  'ePUsedFor3YearRating': False,
#  'ePUsedFor5YearRating': False,
#  'ePUsedFor10YearRating': False,
#  'fundReturnDate': '2025-07-17T05:00:00.000',
#  'fundPriceReturnDate': None,
#  'ratingDate': '2025-06-30T05:00:00.000',
#  'categoryDate': '2025-07-17T05:00:00.000',
#  'indexDate': '2025-07-17T05:00:00.000',
#  'fundInvestorDate': None,
#  'indexId': 'F00000GWXD',
#  'isDailyData': False,
#  'isMonthlyData': False,
#  'isQuarterlyData': False,
#  'inceptionDate': '2000-11-13T06:00:00.000',
#  'potentialCapitalGainsExposure': None,
#  'startDate': '2000-11-13T06:00:00.000',
#  'cur': 'USD',
#  'isUKCefTemplateAvailable': False}
