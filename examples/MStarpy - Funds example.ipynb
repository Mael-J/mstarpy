# %% [markdown]
# # Fund Analysis
#
# In this example, we will explore all the key methods used to perform an in-depth analysis of a fund.

# %%
import mstarpy as ms

# %% [markdown]
# Initialize Funds to start you analysis

# %%
funds = ms.Funds("VTSAX")
funds_2 = ms.Funds("IE00B04GQT48")

# %% [markdown]
# Find the fund name

# %%
print(funds.name)
print(funds_2.name)
# Out:
# Vanguard Total Stock Market Index Fund Admiral Shares
# Vanguard U.S. Investment Grade Credit Index Fund EUR Acc

# %% [markdown]
# Find the fund isin

# %%
funds.isin
# Out:
# 'US9229087286'

# %% [markdown]
# Asset allocation split of the fund, index and category
#
# Asset Allocation
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.allocationMap()
# Out:
# {'assetType': 'EQUITY',
#  'portfolioDate': '2026-01-31T06:00:00.000',
#  'portfolioDateCategory': '2026-01-31T06:00:00.000',
#  'portfolioDateIndex': '2026-02-28T06:00:00.000',
#  'portfolioDateGlobal': '2026-01-31T06:00:00.000',
#  'portfolioDateCategoryGlobal': '2026-01-31T06:00:00.000',
#  'portfolioDateIndexGlobal': '2026-02-28T06:00:00.000',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'allocationMap': {'AssetAllocCash': {'netAllocation': '0.48781',
#    'shortAllocation': None,
#    'longAllocation': '0.48781',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '1.40661',
#    'targetAllocation': None},
#   'AssetAllocNotClassified': {'netAllocation': '0.0',
#    'shortAllocation': None,
#    'longAllocation': '0.0',
#    'longAllocationIndex': '0.0',
#    'longAllocationCategory': '0.026639999999999997',
#    'targetAllocation': None},
#   'AssetAllocNonUSEquity': {'netAllocation': '0.56712',
#    'shortAllocation': None,
#    'longAllocation': '0.56712',
#    'longAllocationIndex': '0.76679',
#    'longAllocationCategory': '2.34874',
#    'targetAllocation': None},
#   'AssetAllocOther': {'netAllocation': '0.12296',
#    'shortAllocation': None,
#    'longAllocation': '0.12296',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '1.28267',
#    'targetAllocation': None},
#   'AssetAllocUSEquity': {'netAllocation': '98.82211',
#    'shortAllocation': None,
#    'longAllocation': '98.82211',
#    'longAllocationIndex': '99.23323',
#    'longAllocationCategory': '96.32497',
#    'targetAllocation': None},
#   'AssetAllocBond': {'netAllocation': '0.00000',
#    'shortAllocation': None,
#    'longAllocation': '0.00000',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '0.68261',
#    'targetAllocation': None}},
#  'japanAssetAllocation': None,
#  'countryCode': 'USA',
#  'securityType': None,
#  'dualViewData': None,
#  'targetDate': None,
#  'hasRegionalAssetAlloc': True,
#  'globalAllocationMap': {'assetAllocPreferred': {'netAllocation': '0.00000',
#    'shortAllocation': None,
#    'longAllocation': '0.00000',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '0.02575',
#    'targetAllocation': None},
#   'assetAllocOther': {'netAllocation': '0.12296',
#    'shortAllocation': None,
#    'longAllocation': '0.12296',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '1.28267',
#    'targetAllocation': None},
#   'assetAllocEquity': {'netAllocation': '99.38923',
#    'shortAllocation': None,
#    'longAllocation': '99.38923',
#    'longAllocationIndex': '100.00002',
#    'longAllocationCategory': '98.67371',
#    'targetAllocation': None},
#   'assetAllocCash': {'netAllocation': '0.48781',
#    'shortAllocation': None,
#    'longAllocation': '0.48781',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '1.40661',
#    'targetAllocation': None},
#   'assetAllocConvertible': {'netAllocation': '0.00000',
#    'shortAllocation': None,
#    'longAllocation': '0.00000',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '0.00089',
#    'targetAllocation': None},
#   'assetAllocFixedIncome': {'netAllocation': '0.00000',
#    'shortAllocation': None,
#    'longAllocation': '0.00000',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '0.68261',
#    'targetAllocation': None}}}

# %% [markdown]
# Fund allocation by Market Capitalization and Style
#
# Stock Style - Weight
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.allocationWeighting()
# Out:
# {'portfolioDate': '2026-01-31T06:00:00.000',
#  'masterPortfolioId': '3506',
#  'largeValue': '19.76300',
#  'largeBlend': '34.33100',
#  'largeGrowth': '17.99300',
#  'middleValue': '5.98900',
#  'middleBlend': '7.75100',
#  'middleGrowth': '5.64800',
#  'smallValue': '2.87800',
#  'smallBlend': '3.48200',
#  'smallGrowth': '2.16500'}

# %% [markdown]
# Ratings of the asset manager funds

# %%
funds.analystRating()
# Out:
# [{'rating': '7',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.7321948367,
#   'noPremiumChinaFund': False},
#  {'rating': '6',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.1730571903,
#   'noPremiumChinaFund': False},
#  {'rating': '5',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0819812808,
#   'noPremiumChinaFund': False},
#  {'rating': '4',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0041455761,
#   'noPremiumChinaFund': False},
#  {'rating': '3',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': '2',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': '1',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': '0',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0086211161,
#   'noPremiumChinaFund': False}]

# %% [markdown]
# Rating and Performance of the best funds of the asset manager

# %%
funds.analystRatingTopFunds()
# Out:
# {'userType': 'Free',
#  'analystRatingFundList': [{'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': 18721399518.0,
#    'netAsset': 877945594480.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 20.9307,
#    'trailing3YearReturnRank': 40.0,
#    'fundShareClassId': 'F00000VE7X',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA002PT',
#    'secId': 'F00000VE7X',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': -30593220008.0,
#    'netAsset': 631465941078.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 21.75376,
#    'trailing3YearReturnRank': 24.0,
#    'fundShareClassId': 'FOUSA00L8W',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA002QH',
#    'secId': 'FOUSA00L8W',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': -20067948877.0,
#    'netAsset': 270609179567.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 19.73698,
#    'trailing3YearReturnRank': 34.0,
#    'fundShareClassId': 'FOUSA00KIR',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA004JJ',
#    'secId': 'FOUSA00KIR',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': -11475564193.0,
#    'netAsset': 208236930965.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 21.77842,
#    'trailing3YearReturnRank': 23.0,
#    'fundShareClassId': 'FOUSA00GPG',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA002Q0',
#    'secId': 'FOUSA00GPG',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': 24839221053.0,
#    'netAsset': 201318808012.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 5.10535,
#    'trailing3YearReturnRank': 53.0,
#    'fundShareClassId': 'FOUSA08OZU',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA09PA2',
#    'secId': 'FOUSA08OZU',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2026-02-28T06:00:00.000',
#  'footerReturnDate': '2026-02-28T06:00:00.000',
#  'currency': 'USD',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Recent change in ratings for asset manager funds

# %%
funds.analystRatingTopFundsUpDown()
# Out:
# {'topAnalystRatingUpDownList': [],
#  'userType': 'Free',
#  'currency': 'USD',
#  'securityType': 'FO',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'secId': 'FOUSA00L83',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Carbon metrics
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.carbonMetrics()
# Out:
# {'carbonPortfolioCoveragePct': None,
#  'carbonRiskScore': None,
#  'carbonRiskScoreCategoryAverage': '7.36695',
#  'carbonRiskScoreCategoryHigh': '28.27492',
#  'carbonRiskScoreCategoryLow': '0.00000',
#  'carbonRiskScoreCategoryAverageDate': '2022-12-31T06:00:00.000',
#  'carbonRiskScoreCategoryRankPct': None,
#  'carbonRiskScoreDate': '2026-01-31T06:00:00.000',
#  'categoryDate': '2022-12-31T06:00:00.000',
#  'categoryName': 'Large Blend',
#  'fossilFuelInvolvementPctCategoryAverage': '11.30159',
#  'fossilFuelInvolvementPct': None,
#  'fossilFuelInvolvementPctCategoryHigh': '100.00000',
#  'fossilFuelInvolvementPctCategoryLow': '0.00000',
#  'isLowCarbon': None,
#  'fossilFuelPercentageOfPortfolioCovered': '42.69205',
#  'portfolioCarbonRiskScore': '7.23134',
#  'carbonRiskPercentageOfPortfolioCovered': '99.22915',
#  'isDesignatedLowCarbon': None}

# %% [markdown]
# Cost Illustration
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.costIllustration()
# Out:
# {'prospectusDate': '2025-04-29T05:00:00.000',
#  'expectedReturn': 5.0,
#  'initial': 10000.0,
#  'mer': None,
#  'priceTemplate': 'USA_OE',
#  'baseCurrencyId': 'USD',
#  'costItems': [{'year': 1,
#    'endNetAsset': 10499.90772386964,
#    'purchase': 0.0,
#    'ongoing': 4.0984318959,
#    'redemption': 0.0,
#    'total': 4.0984318959,
#    'purchasePer': 0.0,
#    'ongoingPer': 0.0003903303,
#    'redemptionPer': 0.0,
#    'totalPer': 0.0003903303},
#   {'year': 5,
#    'endNetAsset': 12759.994261123229,
#    'purchase': 0.0,
#    'ongoing': 22.6274729756,
#    'redemption': 0.0,
#    'total': 22.6274729756,
#    'purchasePer': 0.0,
#    'ongoingPer': 0.0017733137,
#    'redemptionPer': 0.0,
#    'totalPer': 0.0017733137},
#   {'year': 10,
#    'endNetAsset': 16275.500184834224,
#    'purchase': 0.0,
#    'ongoing': 51.4489152536,
#    'redemption': 0.0,
#    'total': 51.4489152536,
#    'purchasePer': 0.0,
#    'ongoingPer': 0.0031611265,
#    'redemptionPer': 0.0,
#    'totalPer': 0.0031611265}]}

# %% [markdown]
# Performance including and excluding fees

# %%
funds.costProjection()
# Out:
# {'initialInvestment': 10000.0,
#  'yearsToCalculate': 5,
#  'growthRatePercent': 5.0,
#  'returnExcludingFeeAmount': 12762.81563,
#  'returnIncludingFeeAmount': 12762.81563,
#  'returnFeeReductionAmount': 0.0,
#  'reducedRateOfReturn': 5.0,
#  'currency': 'USD'}

# %% [markdown]
# Coupon distributed by the fund, category and benchmark
#
# Bond Breakdown - Coupon Range
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.couponRange()
# Out:
# {'fundCouponRange': {'portfolioDate': '2026-01-31T06:00:00.000',
#   'name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'coupon0': 0.01121,
#   'coupon0To2': 3.73248,
#   'coupon2To4': 29.05652,
#   'coupon4To6': 58.42191,
#   'coupon6To8': 8.31091,
#   'coupon8To10': 0.46637,
#   'couponMoreThan10': 0.0},
#  'categoryCouponRange': {'portfolioDate': '2026-01-31T06:00:00.000',
#   'name': 'USD Corporate Bond',
#   'coupon0': 0.01314,
#   'coupon0To2': 0.52061,
#   'coupon2To4': 20.7285,
#   'coupon4To6': 51.88545,
#   'coupon6To8': 24.01936,
#   'coupon8To10': 0.39191,
#   'couponMoreThan10': 0.0},
#  'benchmarkCouponRange': None,
#  'morningstarIndexCouponRange': {'portfolioDate': '2026-02-28T06:00:00.000',
#   'name': 'Morningstar US Corp Bd TR USD',
#   'coupon0': 0.0,
#   'coupon0To2': 3.61619,
#   'coupon2To4': 27.86921,
#   'coupon4To6': 59.86483,
#   'coupon6To8': 8.21848,
#   'coupon8To10': 0.43132,
#   'couponMoreThan10': 0.0}}

# %% [markdown]
# Credit rating split of the fund, catory and benchmark
#
# Bond Breakdown - Credit quality
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.creditQuality()
# Out:
# {'fundName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'categoryName': 'USD Corporate Bond',
#  'indexName': 'Morningstar US Corp Bd TR USD',
#  'fund': {'creditQualityDate': '2026-01-31T06:00:00.000',
#   'creditQualityAAA': '6.69308',
#   'creditQualityAA': '13.35389',
#   'creditQualityA': '39.58700',
#   'creditQualityBBB': '40.37140',
#   'creditQualityBB': '0.00000',
#   'creditQualityB': '0.00000',
#   'creditQualityBelowB': '0.00000',
#   'creditQualityNotRated': '-0.00538'},
#  'category': {'creditQualityDate': '2025-12-31T06:00:00.000',
#   'creditQualityAAA': '2.89321',
#   'creditQualityAA': '10.14661',
#   'creditQualityA': '37.76773',
#   'creditQualityBBB': '46.68459',
#   'creditQualityBB': '1.51608',
#   'creditQualityB': '0.12487',
#   'creditQualityBelowB': '0.57469',
#   'creditQualityNotRated': '0.29036'},
#  'index': {'creditQualityDate': None,
#   'creditQualityAAA': None,
#   'creditQualityAA': None,
#   'creditQualityA': None,
#   'creditQualityBBB': None,
#   'creditQualityBB': None,
#   'creditQualityB': None,
#   'creditQualityBelowB': None,
#   'creditQualityNotRated': None}}

# %% [markdown]
# Information of the fund

# %%
funds.dataPoint(field=["name", "alpha", "fundSize"])
# Out:
# {'name': {'value': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#   'sortAs': 'vanguard total stock market index fund admiral shares'},
#  'alpha': {'value': -1.335},
#  'fundSize': {'value': 2088924581446,
#   'properties': {'currency': {'value': 'USD'},
#    'date': {'value': '2026-02-28'},
#    'asOfDate': {'value': '2026-02-28'}}}}

# %% [markdown]
# Coupon distributed by the fund
#
# Performance - Distributions
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.distribution("annual")
# Out:
# {'distribution': [{'distributionDate': '2025-12-22T06:00:00.000',
#    'distributionNav': 164.37,
#    'income': 1.8136,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.8136,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2024-12-23T06:00:00.000',
#    'distributionNav': 143.11,
#    'income': 1.7759,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.7759,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2023-12-20T06:00:00.000',
#    'distributionNav': 113.64,
#    'income': 1.651,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.651,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2022-12-21T06:00:00.000',
#    'distributionNav': 94.0,
#    'income': 1.5396999999999998,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.5396999999999998,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2021-12-23T06:00:00.000',
#    'distributionNav': 116.71,
#    'income': 1.4152,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.4152,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None}],
#  'baseCurrencyId': 'USD',
#  'template': 'OE_USA_EQUITY'}

# %% [markdown]
# Download a PDF file
#
# https://global.morningstar.com/fr/investissements/fonds/0P0000GFVM/documents

# %%
funds_2.downloadDocument("fr","PRIIP KID","en")
# Out:
# {'page': {'securityID': 'F0000022KV', 'performanceID': '0P0000GFVM', 'fundID': 'FSGBR065UB', 'masterPortfolioID': '107906', 'universe': 'FO', 'countriesOfSale': ['AUT', 'CHE', 'DEU', 'DNK', 'ESP', 'FIN', 'FRA', 'GBR', 'IRL', 'ITA', 'LIE', 'LUX', 'NLD', 'NOR', 'PRT', 'SWE'], 'investmentType': 'FO', 'isin': 'IE00B04GQT48', 'name': 'Vanguard U.S. Investment Grade Credit Index Fund EUR Acc', 'domicile': 'IRL', 'allowedMarketIds': ['at', 'bnl', 'eu', 'dk', 'fi', 'fr', 'de', 'ie', 'it', 'lu', 'nl', 'nord', 'no', 'pt', 'es', 'se', 'ch', 'gb'], 'fundStarRating': 4, 'fundStarRatingDate': '2026-02-28', 'medalistRating': 'Gold'}, 'components': {'ads': {'status': 200, 'payload': {'fundcat': 'USDCorporateBond', 'familyid': '0C000022HA', 'brandingNameId': 'BN00000AAL', 'sustainabilityRating': 3}}, 'documents': {'status': 200, 'payload': [{'id': '4', 'name': 'Annual Report', 'categoryId': 'shareholder', 'documents': [{'effectiveDate': '2024-12-31', 'postedDate': '2025-05-08', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-12-31', 'postedDate': '2013-05-08', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '52', 'name': 'Factsheet', 'categoryId': 'other', 'documents': [{'effectiveDate': '2026-01-31', 'postedDate': '2026-02-20', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2026-01-31', 'postedDate': '2026-02-20', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '299', 'name': 'PRIIP KID', 'categoryId': 'offering', 'documents': [{'effectiveDate': '2025-07-23', 'postedDate': '2025-08-04', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2025-07-23', 'postedDate': '2025-07-25', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '1', 'name': 'Prospectus', 'categoryId': 'offering', 'documents': [{'effectiveDate': '2026-02-04', 'postedDate': '2026-03-04', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2016-05-02', 'postedDate': '2017-11-28', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '5', 'name': 'Semi-Annual Report', 'categoryId': 'shareholder', 'documents': [{'effectiveDate': '2025-06-30', 'postedDate': '2025-09-03', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-06-30', 'postedDate': '2013-04-21', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}]}}}
# {'status': 200,
#  'mesage': 'File downloaded',
#  'filename': 'PRIIP KID-F0000022KV-2025-07-23-20260314115950.pdf',
#  'folder': '.'}

# %% [markdown]
# Yield and growth forecast for the Equity fund, category and benchmark
#
# Style Measures - Measures
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.equityStyle()
# Out:
# {'portfolioDate': '2026-01-31T06:00:00.000',
#  'assetType': 'EQUITY',
#  'fund': {'prospectiveEarningsYield': 21.94529,
#   'prospectiveBookValueYield': 4.10319,
#   'prospectiveRevenueYield': 2.88282,
#   'prospectiveCashFlowYield': 15.09499,
#   'prospectiveDividendYield': 1.22327,
#   'forecasted5YearEarningsGrowth': 10.81141,
#   'forecastedEarningsGrowth': 8.44202,
#   'forecastedBookValueGrowth': -22.78433,
#   'forecastedRevenueGrowth': -16.5863,
#   'forecastedCashFlowGrowth': 10.17448,
#   'portfolioDate': '2026-01-31T06:00:00.000',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'secId': 'FOUSA00L83',
#   'currencyId': 'USD'},
#  'categoryAverage': {'prospectiveEarningsYield': 21.83355,
#   'prospectiveBookValueYield': 4.87979,
#   'prospectiveRevenueYield': 2.97313,
#   'prospectiveCashFlowYield': 14.77868,
#   'prospectiveDividendYield': 1.14259,
#   'forecasted5YearEarningsGrowth': 9.91205,
#   'forecastedEarningsGrowth': 13.98591,
#   'forecastedBookValueGrowth': 8.8094,
#   'forecastedRevenueGrowth': 7.59518,
#   'forecastedCashFlowGrowth': 12.99778,
#   'portfolioDate': '2026-01-31T06:00:00.000',
#   'name': 'Large Blend',
#   'secId': '$FOCA$LB$$',
#   'currencyId': ''},
#  'indexAverage': {'prospectiveEarningsYield': 22.39851,
#   'prospectiveBookValueYield': 4.48748,
#   'prospectiveRevenueYield': 3.19415,
#   'prospectiveCashFlowYield': 14.55066,
#   'prospectiveDividendYield': 1.18057,
#   'forecasted5YearEarningsGrowth': 11.66731,
#   'forecastedEarningsGrowth': 11.02017,
#   'forecastedBookValueGrowth': 9.88196,
#   'forecastedRevenueGrowth': 7.47819,
#   'forecastedCashFlowGrowth': 11.60687,
#   'portfolioDate': '2026-02-28T06:00:00.000',
#   'name': 'Morningstar US Large-Mid TR USD',
#   'secId': 'F00000GWXD',
#   'currencyId': ''}}

# %% [markdown]
# Historical equity exposure and style
# 1 = Large Value, 2 = Large Blend, 3 = Large Growth,
# 4 = Mid Value, 5 = Mid Blend, 6 = Mid Growth
# 7 = Small Value, 8 = Small Blend, 9 = Small Growth
#
# Stock Style - historical
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.equityStyleBoxHistory()
# Out:
# {'history': [{'year': 2026,
#    'portfolioDate': '2026-01-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.38923,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2025,
#    'portfolioDate': '2025-12-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.4358,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2024,
#    'portfolioDate': '2024-12-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.61408,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2023,
#    'portfolioDate': '2023-12-31T06:00:00.000',
#    'style': 3,
#    'percentage': 99.54633,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2022,
#    'portfolioDate': '2022-12-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.02589,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'}],
#  'secId': 'FOUSA00L83',
#  'masterPortfolioId': '3506',
#  'asOfDate': '2026-01-31T06:00:00.000'}

# %% [markdown]
# Environment, Social and Governance data

# %%
funds.esgData()
# Out:
# {'userType': 'Free',
#  'esgData': {'sociallyResponsibleFund': None,
#   'ethicalIssueStrategyFocus': None,
#   'portfolioDate': '2026-01-31T00:00:00.000',
#   'portfolioDateSustainabilityRating': '2026-01-31T06:00:00.000',
#   'fundESGScore': None,
#   'percentAUMCoveredESG': 99.37568,
#   'fundSustainabilityScore': 19.16,
#   'percentAUMCoveredControversy': 99.74559,
#   'categoryRankDate': '2026-01-31T06:00:00.000',
#   'sustainabilityFundQuintile': 2,
#   'sustainabilityPercentCategoryRank': 73.0,
#   'sustainabilityMandate': 'No',
#   'secId': 'FOUSA00L83',
#   'performanceId': '0P00002YGZ',
#   'tradingSymbol': None,
#   'iSIN': None,
#   'fundId': 'FSUSA002PT',
#   'masterPortfolioId': '3506',
#   'categoryId': '$FOCA$LB$$',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'controversyDeduction': None,
#   'categoryName': 'Large Blend',
#   'globalCategoryName': 'US Equity Large Cap Blend',
#   'fundHistoryAvgSustainabilityScore': 19.98039,
#   'historicalSustainabilityScoreGlobalCategoryAverage': 19.54186,
#   'currentSustainabilityScoreGlobalCategoryAverage': 18.74477,
#   'numberofFundsAnalyzedinCategorySustainability': 3864,
#   'HistoryAvgSustainabilityPercentCategoryRank': None,
#   'sustainabilityRatingCorporateContributionPercent': 100.0,
#   'sustainabilityRatingSovereignContributionPercent': 0.0,
#   'portfolioSovereignsustainabilityscore': None,
#   'historicalSovereignSustainabilityScore': None,
#   'historicalSovereignSustainabilityCategoryAverage': 13.87611,
#   'sovereignSustainabilityRatingPercentOfEligiblePortfolioCovered': None,
#   'sustainabilityMandateSurveyed': None},
#  'esgScoreCalculation': {'basedPercentAUM': 99.37568,
#   'portfolioESGScore': None,
#   'portfolioESGScoreCategory': None,
#   'controversyScore': None,
#   'controversyScoreCategory': None,
#   'sustainabilityScore': 19.16,
#   'sustainabilityScoreCategory': 18.74477,
#   'environmentalScore': 4.97,
#   'environmentalScoreCategory': None,
#   'socialScore': 8.16,
#   'socialScoreCategory': None,
#   'governanceScore': 4.67,
#   'governanceScoreCategory': None,
#   'portfolioDate': '2026-01-31T06:00:00.000',
#   'portfolioSustainabilityScore': 19.16,
#   'portfolioEnvironmentalRiskScore': 4.97,
#   'portfolioSocialRiskScore': 8.16,
#   'portfolioGovernanceRiskScore': 4.67,
#   'portfolioUnallocatedEsgRiskScore': 1.35,
#   'percentAUMCoveredControversy': 99.74559,
#   'esgFundQuintile': None,
#   'esgPercentCategoryRank': None,
#   'controversyFundQuintile': None,
#   'controversyPercentCategoryRank': None,
#   'ePercentCategoryRank': None,
#   'sPercentCategoryRank': None,
#   'gPercentCategoryRank': None,
#   'categoryRankDate': '2026-01-31T06:00:00.000',
#   'historicalSustainabilityScoreGlobalCategoryAverage': 19.54186,
#   'currentSustainabilityScoreGlobalCategoryAverage': 18.74477,
#   'HistoryAvgSustainabilityPercentCategoryRank': 73.0,
#   'numberofFundsAnalyzedinCategorySustainability': 3864},
#  'esgHoldingsAnalyst': '_PO_',
#  'esgScoreDistribution': '_PO_',
#  'esgLevelDistribution': '_PO_',
#  'sustainabilityIntentionality': {'investmentId': 'FSUSA002PT',
#   'eSGIncorporation': False,
#   'eSGEngagement': False,
#   'genderDiversity': False,
#   'lowCarbonFossilFuelFree': False,
#   'communityDevelopment': False,
#   'environmental': False,
#   'otherImpactThemes': False,
#   'renewableEnergy': False,
#   'waterFocused': False,
#   'generalEnvironmentalSector': False,
#   'sustainableInvestmentOverall': False,
#   'eSGFundOverall': False,
#   'impactFundOverall': False,
#   'environmentalSectorOverall': False,
#   'createdOn': '2019-05-01 04:01:00.0',
#   'lastUpdateDate': '2025-06-03 04:04:00.0',
#   'usesNormsBasedScreening': None,
#   'excludesAbortionStemCells': None,
#   'excludesAdultEntertainment': None,
#   'excludesAlcohol': None,
#   'excludesAnimalTesting': None,
#   'excludesControversialWeapons': None,
#   'excludesFurSpecialtyLeather': None,
#   'excludesGambling': None,
#   'excludesGMOs': None,
#   'excludesMilitaryContracting': None,
#   'excludesNuclear': None,
#   'excludesPalmOil': None,
#   'excludesPesticides': None,
#   'excludesSmallArms': None,
#   'excludesThermalCoal': None,
#   'excludesTobacco': None,
#   'excludesOther': None,
#   'employsExclusionsOverall': None}}

# %% [markdown]
# Environment, Social and Governance risk
#
# Sustainability - Risk
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.esgRisk()
# Out:
# {'sustainabilityFundQuintile': 2,
#  'fundHistoryAvgSustainabilityScore': 19.98039,
#  'fundSustainabilityScore': 19.16,
#  'historicalSustainabilityScoreGlobalCategoryAverage': 19.54186,
#  'historicalSovereignSustainabilityScore': None,
#  'portfolioSovereignSustainabilityScore': None,
#  'historicalSovereignSustainabilityCategoryAverage': 13.87611,
#  'percentAUMCoveredESG': 99.37568,
#  'sovereignSustainabilityRatingPercentOfEligiblePortfolioCovered': None,
#  'globalCategoryName': 'US Equity Large Cap Blend',
#  'categoryRankDate': '2026-01-31T00:00:00.000',
#  'portfolioDateSustainabilityRating': '2026-01-31T06:00:00.000',
#  'categoryId': '$FOCA$LB$$',
#  'portfolioDate': '2026-01-31T00:00:00.000',
#  'carbon': {'carbonPortfolioCoveragePct': None,
#   'carbonRiskScore': None,
#   'carbonRiskScoreCategoryAverage': '7.36695',
#   'carbonRiskScoreCategoryHigh': '28.27492',
#   'carbonRiskScoreCategoryLow': '0.00000',
#   'carbonRiskScoreCategoryAverageDate': '2022-12-31T06:00:00.000',
#   'carbonRiskScoreCategoryRankPct': None,
#   'carbonRiskScoreDate': '2026-01-31T06:00:00.000',
#   'categoryDate': '2022-12-31T06:00:00.000',
#   'categoryName': 'Large Blend',
#   'fossilFuelInvolvementPctCategoryAverage': '11.30159',
#   'fossilFuelInvolvementPct': None,
#   'fossilFuelInvolvementPctCategoryHigh': '100.00000',
#   'fossilFuelInvolvementPctCategoryLow': '0.00000',
#   'isLowCarbon': None,
#   'fossilFuelPercentageOfPortfolioCovered': '42.69205',
#   'portfolioCarbonRiskScore': '7.23134',
#   'carbonRiskPercentageOfPortfolioCovered': '99.22915',
#   'isDesignatedLowCarbon': None}}

# %% [markdown]
# Factor Style, Yield, Momemtum, Quality, Volatility, Liquidity and Size
# of the fund, category and benchmark
#
# Factor Profile
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.factorProfile()
# Out:
# {'secId': 'FOUSA00L83',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryId': '$FOCA$LB$$',
#  'categoryName': 'Large Blend',
#  'indexId': 'F00000GWXD',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'indexEffectiveDate': '2026-01-31',
#  'categoryEffectiveDate': '2026-01-31',
#  'ticker': 'VTSAX',
#  'id': '0P00002YGZ',
#  'effectiveDate': '2026-01-31',
#  'endDate': '2026-01-31',
#  'factors': {'style': {'categoryAvg': 58.77725,
#    'indexAvg': 51.652725,
#    'percentile': 51.386565,
#    'historicRange': [{'year': '1', 'min': 49.767313, 'max': 54.106062},
#     {'year': '3', 'min': 46.648119, 'max': 54.106062},
#     {'year': '5', 'min': 42.991865, 'max': 54.106062}]},
#   'yield': {'categoryAvg': 56.592522,
#    'indexAvg': 61.313688,
#    'percentile': 58.626743,
#    'historicRange': [{'year': '1', 'min': 54.986708, 'max': 59.746585},
#     {'year': '3', 'min': 51.984305, 'max': 59.746585},
#     {'year': '5', 'min': 48.040725, 'max': 59.746585}]},
#   'quality': {'categoryAvg': 23.265526,
#    'indexAvg': 32.815589,
#    'percentile': 42.519328,
#    'historicRange': [{'year': '1', 'min': 39.852423, 'max': 46.548254},
#     {'year': '3', 'min': 38.575843, 'max': 46.548254},
#     {'year': '5', 'min': 38.575843, 'max': 49.495372}]},
#   'momentum': {'categoryAvg': 53.354246,
#    'indexAvg': 40.732256,
#    'percentile': 47.364068,
#    'historicRange': [{'year': '1', 'min': 42.988317, 'max': 49.614182},
#     {'year': '3', 'min': 37.715893, 'max': 58.089713},
#     {'year': '5', 'min': 37.715893, 'max': 58.089713}]},
#   'volatility': {'categoryAvg': 77.470215,
#    'indexAvg': 52.151774,
#    'percentile': 45.12706,
#    'historicRange': [{'year': '1', 'min': 41.9081, 'max': 47.04423},
#     {'year': '3', 'min': 41.9081, 'max': 50.013595},
#     {'year': '5', 'min': 41.9081, 'max': 50.826434}]},
#   'liquidity': {'categoryAvg': 83.270279,
#    'indexAvg': 68.1673,
#    'percentile': 55.62294,
#    'historicRange': [{'year': '1', 'min': 54.073253, 'max': 59.283712},
#     {'year': '3', 'min': 53.138036, 'max': 61.044202},
#     {'year': '5', 'min': 50.494437, 'max': 62.222358}]},
#   'size': {'categoryAvg': 83.393853,
#    'indexAvg': 74.959125,
#    'percentile': 59.187579,
#    'historicRange': [{'year': '1', 'min': 58.423386, 'max': 60.264784},
#     {'year': '3', 'min': 56.810835, 'max': 60.360978},
#     {'year': '5', 'min': 55.076956, 'max': 60.360978}]}}}

# %% [markdown]
# Ongoing Fee Level
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.feeLevel()
# Out:
# {'morningstarFeeLevelRankDate': '2026-02-28T06:00:00.000',
#  'morningstarFeeLevelGroup': 'IC00000272',
#  'name': 'Large Cap Institutional',
#  'morningstarFeeLevel': 1,
#  'morningstarFeeLevelPercentileRank': 3.0,
#  'morningstarFeeLevelGroupSize': 891.0,
#  'median': 0.68,
#  'morningstarFeeLevelGroupStartingDistribution': 0.0,
#  'morningstarFeeLevelGroup1stBreakpointDistribution': 0.46,
#  'morningstarFeeLevelGroup2ndBreakpointDistribution': 0.65,
#  'morningstarFeeLevelGroup3rdBreakpointDistribution': 0.72,
#  'morningstarFeeLevelGroup4thBreakpointDistribution': 0.84,
#  'morningstarFeeLevelGroupEndBreakpointDistribution': 1.5,
#  'fundFee': None,
#  'reportDate': '2025-12-31T06:00:00.000',
#  'peerMedian': None,
#  'fundIndex': None,
#  'prospectusExpenseRatio': 0.04,
#  'adjustedProspectusExpenseRatio': 0.04,
#  'icrFund': None,
#  'priceTemplate': 'USA_OE',
#  'morningstarTotalCostRatioPDS': None,
#  'ongoingCostChargeDate': None,
#  'fundSubType': None,
#  'PRIIPSKIDOngoingCostsOtherCosts': None,
#  'PRIIPSKIDOngoingCostsOtherCostsDate': None}

# %% [markdown]
# MiFID fees
#
# Price
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/quote

# %%
funds_2.feeMifid()
# Out:
# {'dbgtime': '172',
#  'Id': 'F0000022KV',
#  'Name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'Mifid': {'SummaryRiskIndicator': 3,
#   'SummaryRiskIndicatorDate': '2025-04-30T00:00:00',
#   'PerformanceFeeEstimated': 0.0,
#   'PerformanceFeeEstimatedDate': '2024-07-31T00:00:00',
#   'TransactionFeeActual': 0.0143,
#   'TransactionFeeActualDate': '2025-01-31T00:00:00',
#   'TransactionFeeEstimated': 0.0172,
#   'TransactionFeeEstimatedDate': '2025-01-31T00:00:00',
#   'PerformanceFeeActual': 0.0,
#   'PerformanceFeeActualDate': '2024-07-31T00:00:00',
#   'OngoingCostEstimated': 0.1214,
#   'OngoingCostEstimatedDate': '2025-01-31T00:00:00',
#   'OngoingCostActual': 0.1214,
#   'OngoingCostActualDate': '2025-01-31T00:00:00',
#   'MaximumEntryCostAcquired': 0.0,
#   'MaximumEntryCostAcquiredDate': '2025-01-31T00:00:00',
#   'MaximumExitCostAcquired': 0.0,
#   'MaximumExitCostAcquiredDate': '2025-01-31T00:00:00',
#   'TypicalExitCost': 0.0,
#   'TypicalExitCostDate': '2025-01-31T00:00:00',
#   'ManagementFeeExDistFeeActual': 0.12,
#   'ManagementFeeExDistFeeActualDate': '2025-01-31T00:00:00',
#   'ManagementFeeExDistFeeEstimate': 0.12,
#   'ManagementFeeExDistFeeEstimateDate': '2025-01-31T00:00:00',
#   'DistributionFeePercOfNAVActual': 0.0,
#   'DistributionFeePercOfNAVActualDate': '2025-01-31T00:00:00',
#   'DistributionFeePercOfNAVEstimated': 0.0,
#   'InvestorTypeRetail': 'Y',
#   'InvestorTypeProfessional': 'Y',
#   'InvestorTypeEligibleCounterparty': 'Y',
#   'ExpertiseBasic': 'Y',
#   'ExpertiseInformed': 'Y',
#   'ExpertiseAdvanced': 'Y',
#   'DistributionExecutionOnly': 'Both (Retail and Professional)',
#   'DistributionInvestmentAdvice': 'Both (Retail and Professional)',
#   'DistributionPortfolioManagement': 'Both (Retail and Professional)',
#   'DistExecAppTestNonAdv': 'Both (Retail and Professional)',
#   'CapitalLossNone': 'N',
#   'CapitalLossLimited': 'Neutral',
#   'MaximumExitFees': [{'Date': '2025-01-31',
#     'Unit': '1',
#     'Value': 0.0,
#     'Currency': 'EUR'},
#    {'Date': '2025-01-31', 'Unit': '2', 'Value': 0.0, 'Currency': 'EUR'}],
#   'MaximumExitFeesDate': '2025-01-31T00:00:00',
#   'CapitalLossNoGuarantee': 'Y',
#   'CapitalLossBeyondInitial': 'Y',
#   'ReturnProfilePreservation': 'Neutral',
#   'ReturnProfileGrowth': 'Y',
#   'ReturnProfileIncome': 'Neutral',
#   'ReturnProfileHedging': 'Neutral',
#   'ReturnProfileOptionOrLeveraged': 'Neutral',
#   'ReturnProfileOther': 'Neutral',
#   'ReturnProfilePensionSchemeGermany': 'Neutral',
#   'LeverageProduct': 'N',
#   'MIFIDInstrumentType': 'UCITS',
#   'ExpertiseExpertInvestorGermany': 'Y',
#   'NotForInvWithLowRiskTolGermany': 'Neutral',
#   'RecommendedHoldingPeriod': '7',
#   'EMTTransactionCostsEstimatedUK': 0.017,
#   'EMTTransactionCostsEstimatedDateUK': '2025-01-31',
#   'EMTTransactionCostsActualUK': 0.014,
#   'EMTTransactionCostsActualDateUK': '2025-01-31',
#   'EMTValueAssessmentReviewDateUK': '2025-06-30',
#   'EMTEffectiveDate': '2025-06-30',
#   'EMTDataReportingValueForMoneyUK': True,
#   'EMTIsAssessmentOfValueRequiredUnderCOLLUK': False,
#   'EMTOutcomeOfPRINValueAssessmentOrReviewCodeUK': 1,
#   'EMTValueAssessmentReviewNextDateUK': '2026-06-30'},
#  'CollectedSRRI': {'Date': '2025-07-23T00:00:00', 'Rank': 4},
#  'KID': {'SRI': 3}}

# %% [markdown]
# Financial metrics of fund, category and benchmark

# %%
funds_2.financialMetrics()
# Out:
# {'userType': 'Free',
#  'fund': {'masterPortfolioId': '107906',
#   'portfolioDate': '2026-01-31T06:00:00.000',
#   'wideMoatPercentage': '_PO_',
#   'narrowMoatPercentage': '_PO_',
#   'noMoatPercentage': '_PO_',
#   'financialHealthGradeType': '_PO_',
#   'profitabilityGradeType': '_PO_',
#   'growthGradeType': '_PO_',
#   'roic': '_PO_',
#   'cashReturn': '_PO_',
#   'freeCashFlowYield': '_PO_',
#   'debtToCapital': '_PO_',
#   'securityName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc'},
#  'category': {'masterPortfolioId': '211369',
#   'portfolioDate': '2026-01-31T06:00:00.000',
#   'wideMoatPercentage': '_PO_',
#   'narrowMoatPercentage': '_PO_',
#   'noMoatPercentage': '_PO_',
#   'financialHealthGradeType': '_PO_',
#   'profitabilityGradeType': '_PO_',
#   'growthGradeType': '_PO_',
#   'roic': '_PO_',
#   'cashReturn': '_PO_',
#   'freeCashFlowYield': '_PO_',
#   'debtToCapital': '_PO_',
#   'securityName': 'USD Corporate Bond'},
#  'index': {'masterPortfolioId': '1861103',
#   'portfolioDate': '2026-02-28T06:00:00.000',
#   'wideMoatPercentage': '_PO_',
#   'narrowMoatPercentage': '_PO_',
#   'noMoatPercentage': '_PO_',
#   'financialHealthGradeType': '_PO_',
#   'profitabilityGradeType': '_PO_',
#   'growthGradeType': '_PO_',
#   'roic': '_PO_',
#   'cashReturn': '_PO_',
#   'freeCashFlowYield': '_PO_',
#   'debtToCapital': '_PO_',
#   'securityName': 'Morningstar US Corp Bd TR USD'}}

# %% [markdown]
# Fixed Income metrics for the fund, category and benchmark
#
# Fixed Income style - Current
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.fixedIncomeStyle()
# Out:
# {'isCan': False,
#  'portfolioDate': '2026-01-31T06:00:00.000',
#  'assetType': 'FIXEDINCOME',
#  'fixedIncStyleBox': 6,
#  'fund': {'secId': 'F0000022KV',
#   'secName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'portfolioDate': '2026-01-31T06:00:00.000',
#   'avgEffectiveDuration': 6.0883,
#   'modifiedDuration': 6.19152,
#   'avgEffectiveMaturity': 9.28024,
#   'avgCreditQualityName': 'A-',
#   'surveyedAverageSurveyedCreditRating': 'A-',
#   'calculatedAverageCreditRating': 'A-',
#   'avgCreditQualityDate': '2026-01-31T06:00:00.000',
#   'avgCoupon': 4.50578,
#   'avgPrice': 97.08798,
#   'yieldToMaturity': 4.78468},
#  'categoryAverage': {'secId': 'EUCA000691',
#   'secName': 'USD Corporate Bond',
#   'portfolioDate': '2026-01-31T06:00:00.000',
#   'avgEffectiveDuration': 5.78954,
#   'modifiedDuration': 5.71723,
#   'avgEffectiveMaturity': 8.90655,
#   'avgCreditQualityName': 'A-',
#   'surveyedAverageSurveyedCreditRating': 'A-',
#   'calculatedAverageCreditRating': 'A-',
#   'avgCreditQualityDate': '2025-12-31T06:00:00.000',
#   'avgCoupon': 5.20483,
#   'avgPrice': 98.10672,
#   'yieldToMaturity': 4.84009}}

# %% [markdown]
# Historical Fixed Income Style
#
# Fixed Income Style - Historical
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.fixedincomeStyleBoxHistory()
# Out:
# {'history': [{'year': 2026,
#    'portfolioDate': '2026-01-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.96383,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2025,
#    'portfolioDate': '2025-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.95802,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2024,
#    'portfolioDate': '2024-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.95603,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2023,
#    'portfolioDate': '2023-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.89898,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2022,
#    'portfolioDate': '2022-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.86471,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'}],
#  'secId': 'F0000022KV',
#  'masterPortfolioId': '107906',
#  'asOfDate': '2026-01-31T06:00:00.000'}

# %% [markdown]
# Available documents and their countries
#
# https://global.morningstar.com/fr/investissements/fonds/0P0000GFVM/documents

# %%
funds_2.getDocumentInformation("fr")
# Out:
# {'page': {'securityID': 'F0000022KV', 'performanceID': '0P0000GFVM', 'fundID': 'FSGBR065UB', 'masterPortfolioID': '107906', 'universe': 'FO', 'countriesOfSale': ['AUT', 'CHE', 'DEU', 'DNK', 'ESP', 'FIN', 'FRA', 'GBR', 'IRL', 'ITA', 'LIE', 'LUX', 'NLD', 'NOR', 'PRT', 'SWE'], 'investmentType': 'FO', 'isin': 'IE00B04GQT48', 'name': 'Vanguard U.S. Investment Grade Credit Index Fund EUR Acc', 'domicile': 'IRL', 'allowedMarketIds': ['at', 'bnl', 'eu', 'dk', 'fi', 'fr', 'de', 'ie', 'it', 'lu', 'nl', 'nord', 'no', 'pt', 'es', 'se', 'ch', 'gb'], 'fundStarRating': 4, 'fundStarRatingDate': '2026-02-28', 'medalistRating': 'Gold'}, 'components': {'ads': {'status': 200, 'payload': {'fundcat': 'USDCorporateBond', 'familyid': '0C000022HA', 'brandingNameId': 'BN00000AAL', 'sustainabilityRating': 3}}, 'documents': {'status': 200, 'payload': [{'id': '4', 'name': 'Annual Report', 'categoryId': 'shareholder', 'documents': [{'effectiveDate': '2024-12-31', 'postedDate': '2025-05-08', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-12-31', 'postedDate': '2013-05-08', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '52', 'name': 'Factsheet', 'categoryId': 'other', 'documents': [{'effectiveDate': '2026-01-31', 'postedDate': '2026-02-20', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2026-01-31', 'postedDate': '2026-02-20', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '299', 'name': 'PRIIP KID', 'categoryId': 'offering', 'documents': [{'effectiveDate': '2025-07-23', 'postedDate': '2025-08-04', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2025-07-23', 'postedDate': '2025-07-25', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '1', 'name': 'Prospectus', 'categoryId': 'offering', 'documents': [{'effectiveDate': '2026-02-04', 'postedDate': '2026-03-04', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2016-05-02', 'postedDate': '2017-11-28', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '5', 'name': 'Semi-Annual Report', 'categoryId': 'shareholder', 'documents': [{'effectiveDate': '2025-06-30', 'postedDate': '2025-09-03', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-06-30', 'postedDate': '2013-04-21', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}]}}}
# {'page': {'securityID': 'F0000022KV',
#   'performanceID': '0P0000GFVM',
#   'fundID': 'FSGBR065UB',
#   'masterPortfolioID': '107906',
#   'universe': 'FO',
#   'countriesOfSale': ['AUT',
#    'CHE',
#    'DEU',
#    'DNK',
#    'ESP',
#    'FIN',
#    'FRA',
#    'GBR',
#    'IRL',
#    'ITA',
#    'LIE',
#    'LUX',
#    'NLD',
#    'NOR',
#    'PRT',
#    'SWE'],
#   'investmentType': 'FO',
#   'isin': 'IE00B04GQT48',
#   'name': 'Vanguard U.S. Investment Grade Credit Index Fund EUR Acc',
#   'domicile': 'IRL',
#   'allowedMarketIds': ['at',
#    'bnl',
#    'eu',
#    'dk',
#    'fi',
#    'fr',
#    'de',
#    'ie',
#    'it',
#    'lu',
#    'nl',
#    'nord',
#    'no',
#    'pt',
#    'es',
#    'se',
#    'ch',
#    'gb'],
#   'fundStarRating': 4,
#   'fundStarRatingDate': '2026-02-28',
#   'medalistRating': 'Gold'},
#  'components': {'ads': {'status': 200,
#    'payload': {'fundcat': 'USDCorporateBond',
#     'familyid': '0C000022HA',
#     'brandingNameId': 'BN00000AAL',
#     'sustainabilityRating': 3}},
#   'documents': {'status': 200,
#    'payload': [{'id': '4',
#      'name': 'Annual Report',
#      'categoryId': 'shareholder',
#      'documents': [{'effectiveDate': '2024-12-31',
#        'postedDate': '2025-05-08',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2012-12-31',
#        'postedDate': '2013-05-08',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'},
#     {'id': '52',
#      'name': 'Factsheet',
#      'categoryId': 'other',
#      'documents': [{'effectiveDate': '2026-01-31',
#        'postedDate': '2026-02-20',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2026-01-31',
#        'postedDate': '2026-02-20',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'},
#     {'id': '299',
#      'name': 'PRIIP KID',
#      'categoryId': 'offering',
#      'documents': [{'effectiveDate': '2025-07-23',
#        'postedDate': '2025-08-04',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2025-07-23',
#        'postedDate': '2025-07-25',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'},
#     {'id': '1',
#      'name': 'Prospectus',
#      'categoryId': 'offering',
#      'documents': [{'effectiveDate': '2026-02-04',
#        'postedDate': '2026-03-04',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2016-05-02',
#        'postedDate': '2017-11-28',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'},
#     {'id': '5',
#      'name': 'Semi-Annual Report',
#      'categoryId': 'shareholder',
#      'documents': [{'effectiveDate': '2025-06-30',
#        'postedDate': '2025-09-03',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2012-06-30',
#        'postedDate': '2013-04-21',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'}]}}}

# %% [markdown]
# Historical Total Assets and Net flow
#
# chart Fund flows
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.graphData()
# Out:
# {'startYear': 2016,
#  'latestDate': '2026-02-28T06:00:00.000',
#  'endYear': 2026,
#  'secId': 'FOUSA00L83',
#  'currency': 'USD',
#  'data': [{'yr': 2016,
#    'naQ1': 2.4945725779,
#    'naQ2': 2.5996820759,
#    'naQ3': 2.7346545656,
#    'naQ4': 2.7925682151,
#    'naYr': 2.7925682151,
#    'nfQ1': 55.267908625,
#    'nfQ2': 47.781899567,
#    'nfQ3': 46.422851269,
#    'nfQ4': 33.470349127,
#    'nfYr': 182.943008588,
#    'numFund': 137,
#    'industryMarketShare': 22.59186181,
#    'growthRate': 7.59122893,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2017,
#    'naQ1': 2.9992043692,
#    'naQ2': 3.1367856448,
#    'naQ3': 3.2933485512,
#    'naQ4': 3.4662529642,
#    'naYr': 3.4662529642,
#    'nfQ1': 76.544077129,
#    'nfQ2': 49.738990644,
#    'nfQ3': 45.596474987,
#    'nfQ4': 35.126500497,
#    'nfYr': 207.006043257,
#    'numFund': 141,
#    'industryMarketShare': 23.83123391,
#    'growthRate': 7.41274796,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2018,
#    'naQ1': 3.4775429338,
#    'naQ2': 3.5487050769,
#    'naQ3': 3.7130380885,
#    'naQ4': 3.3519682965,
#    'naYr': 3.3519682965,
#    'nfQ1': 39.248219565,
#    'nfQ2': 13.00945,
#    'nfQ3': 17.920405053,
#    'nfQ4': 5.657726543,
#    'nfYr': 75.835801161,
#    'numFund': 141,
#    'industryMarketShare': 24.96542604,
#    'growthRate': 2.18783228,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2019,
#    'naQ1': 3.7386327959,
#    'naQ2': 3.8794341613,
#    'naQ3': 3.9250090712,
#    'naQ4': 4.1801009687,
#    'naYr': 4.1801009687,
#    'nfQ1': 45.451464496,
#    'nfQ2': 15.283373029,
#    'nfQ3': 5.873646418,
#    'nfQ4': 10.633977324,
#    'nfYr': 77.242461267,
#    'numFund': 145,
#    'industryMarketShare': 25.77113894,
#    'growthRate': 2.30439116,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2020,
#    'naQ1': 3.5116894508,
#    'naQ2': 4.0330797614,
#    'naQ3': 4.2458626145,
#    'naQ4': 4.6431199711,
#    'naYr': 4.6431199711,
#    'nfQ1': -21.871656285,
#    'nfQ2': -12.506920716,
#    'nfQ3': -13.738040134,
#    'nfQ4': -11.539924045,
#    'nfYr': -59.65654118,
#    'numFund': 143,
#    'industryMarketShare': 25.72410291,
#    'growthRate': -1.42715551,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2021,
#    'naQ1': 4.7898002858,
#    'naQ2': 5.0998775849,
#    'naQ3': 5.0752681636,
#    'naQ4': 5.3260283229,
#    'naYr': 5.3260283229,
#    'nfQ1': 30.98485722,
#    'nfQ2': 23.482260266,
#    'nfQ3': 0.437017041,
#    'nfQ4': -20.671589069,
#    'nfYr': 34.232545458,
#    'numFund': 148,
#    'industryMarketShare': 25.86466027,
#    'growthRate': 0.73727463,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2022,
#    'naQ1': 5.0096266344,
#    'naQ2': 4.3528344385,
#    'naQ3': 4.1135320631,
#    'naQ4': 4.3508557423,
#    'naYr': 4.3508557423,
#    'nfQ1': -24.924057486,
#    'nfQ2': -25.609908649,
#    'nfQ3': -19.02818459,
#    'nfQ4': -36.841482467,
#    'nfYr': -106.403633192,
#    'numFund': 148,
#    'industryMarketShare': 26.94249695,
#    'growthRate': -1.99780449,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2023,
#    'naQ1': 4.5911608054,
#    'naQ2': 4.7857922788,
#    'naQ3': 4.605537003,
#    'naQ4': 5.0312120502,
#    'naYr': 5.0312120502,
#    'nfQ1': 6.347600952,
#    'nfQ2': -25.736576417,
#    'nfQ3': -22.906856471,
#    'nfQ4': -38.386126697,
#    'nfYr': -80.681958633,
#    'numFund': 149,
#    'industryMarketShare': 27.49664382,
#    'growthRate': -1.85439287,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2024,
#    'naQ1': 5.3558837273,
#    'naQ2': 5.4308621783,
#    'naQ3': 5.7172046904,
#    'naQ4': 5.6735103501,
#    'naYr': 5.6735103501,
#    'nfQ1': 4.694823757,
#    'nfQ2': -22.445750808,
#    'nfQ3': -35.720628211,
#    'nfQ4': -30.512048727,
#    'nfYr': -83.983603989,
#    'numFund': 148,
#    'industryMarketShare': 27.96630376,
#    'growthRate': -1.66925192,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2025,
#    'naQ1': 5.5306047054,
#    'naQ2': 5.952615842,
#    'naQ3': 5.9687938668,
#    'naQ4': 6.0365460956,
#    'naYr': 6.0365460956,
#    'nfQ1': -34.103413968,
#    'nfQ2': -29.338507423,
#    'nfQ3': -60.637586081,
#    'nfQ4': -61.241481801,
#    'nfYr': -185.320989273,
#    'numFund': 149,
#    'industryMarketShare': 29.24059968,
#    'growthRate': -3.26642551,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2026,
#    'naQ1': None,
#    'naQ2': None,
#    'naQ3': None,
#    'naQ4': None,
#    'naYr': 6.2011540264,
#    'nfQ1': 2.976182624,
#    'nfQ2': None,
#    'nfQ3': None,
#    'nfQ4': None,
#    'nfYr': 2.976182624,
#    'numFund': 149,
#    'industryMarketShare': None,
#    'growthRate': 0.04930274,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'}]}

# %% [markdown]
# Historical performance
#
# Performance - Returns
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.historicalData()
# Out:
# {'userType': 'Free',
#  'baseCurrency': 'USD',
#  'asOfDate': '2026-03-13T00:00:00.000',
#  'startDate': '2016-01-01T00:00:00.000',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'graphData': {'fund': [{'date': '2016-01-31', 'value': 9434.928041941224},
#    {'date': '2016-02-29', 'value': 9430.98972389338},
#    {'date': '2016-03-31', 'value': 10094.330534323297},
#    {'date': '2016-04-30', 'value': 10159.608342087218},
#    {'date': '2016-05-31', 'value': 10339.617022765564},
#    {'date': '2016-06-30', 'value': 10365.37317610833},
#    {'date': '2016-07-31', 'value': 10774.663437593292},
#    {'date': '2016-08-31', 'value': 10804.466603584093},
#    {'date': '2016-09-30', 'value': 10821.086454642713},
#    {'date': '2016-10-31', 'value': 10581.505688226662},
#    {'date': '2016-11-30', 'value': 11052.681890362883},
#    {'date': '2016-12-31', 'value': 11266.420143342864},
#    {'date': '2017-01-31', 'value': 11483.392432920169},
#    {'date': '2017-02-28', 'value': 11909.298078562371},
#    {'date': '2017-03-31', 'value': 11918.645814178393},
#    {'date': '2017-04-30', 'value': 12043.765210729793},
#    {'date': '2017-05-31', 'value': 12166.865567858558},
#    {'date': '2017-06-30', 'value': 12279.692051819033},
#    {'date': '2017-07-31', 'value': 12508.783044833544},
#    {'date': '2017-08-31', 'value': 12529.056821218972},
#    {'date': '2017-09-30', 'value': 12837.561875890122},
#    {'date': '2017-10-31', 'value': 13116.506466211984},
#    {'date': '2017-11-30', 'value': 13515.580924246562},
#    {'date': '2017-12-31', 'value': 13651.440240676644},
#    {'date': '2018-01-31', 'value': 14377.79860677346},
#    {'date': '2018-02-28', 'value': 13843.771613288434},
#    {'date': '2018-03-31', 'value': 13569.234365659058},
#    {'date': '2018-04-30', 'value': 13620.594797697759},
#    {'date': '2018-05-31', 'value': 14004.764694802685},
#    {'date': '2018-06-30', 'value': 14099.24263687144},
#    {'date': '2018-07-31', 'value': 14571.69339486738},
#    {'date': '2018-08-31', 'value': 15075.090845606765},
#    {'date': '2018-09-30', 'value': 15099.381855297706},
#    {'date': '2018-10-31', 'value': 13982.060924067888},
#    {'date': '2018-11-30', 'value': 14272.274017598102},
#    {'date': '2018-12-31', 'value': 12945.510503546348},
#    {'date': '2019-01-31', 'value': 14058.878227057063},
#    {'date': '2019-02-28', 'value': 14553.012813306601},
#    {'date': '2019-03-31', 'value': 14763.31304119302},
#    {'date': '2019-04-30', 'value': 15350.240058724863},
#    {'date': '2019-05-31', 'value': 14362.944670726085},
#    {'date': '2019-06-30', 'value': 15367.031141002952},
#    {'date': '2019-07-31', 'value': 15587.9417486281},
#    {'date': '2019-08-31', 'value': 15274.457587888144},
#    {'date': '2019-09-30', 'value': 15534.279373412852},
#    {'date': '2019-10-31', 'value': 15861.872986637265},
#    {'date': '2019-11-30', 'value': 16462.108392339862},
#    {'date': '2019-12-31', 'value': 16933.37095456938},
#    {'date': '2020-01-31', 'value': 16920.620929070814},
#    {'date': '2020-02-29', 'value': 15539.432688635381},
#    {'date': '2020-03-31', 'value': 13399.486157444873},
#    {'date': '2020-04-30', 'value': 15176.118754062087},
#    {'date': '2020-05-31', 'value': 15991.83301531477},
#    {'date': '2020-06-30', 'value': 16358.09063789585},
#    {'date': '2020-07-31', 'value': 17282.603727033613},
#    {'date': '2020-08-31', 'value': 18522.43836234462},
#    {'date': '2020-09-30', 'value': 17863.49149390305},
#    {'date': '2020-10-31', 'value': 17480.116705243323},
#    {'date': '2020-11-30', 'value': 19612.36378742612},
#    {'date': '2020-12-31', 'value': 20487.33000648445},
#    {'date': '2021-01-31', 'value': 20420.293728544915},
#    {'date': '2021-02-28', 'value': 21071.200174506943},
#    {'date': '2021-03-31', 'value': 21804.720472479046},
#    {'date': '2021-04-30', 'value': 22924.246564022236},
#    {'date': '2021-05-31', 'value': 23024.04905253299},
#    {'date': '2021-06-30', 'value': 23609.856366786204},
#    {'date': '2021-07-31', 'value': 24014.63505787987},
#    {'date': '2021-08-31', 'value': 24702.321969784385},
#    {'date': '2021-09-30', 'value': 23594.27283684717},
#    {'date': '2021-10-31', 'value': 25181.34205073953},
#    {'date': '2021-11-30', 'value': 24808.043102620355},
#    {'date': '2021-12-31', 'value': 25755.09319817482},
#    {'date': '2022-01-31', 'value': 24201.813115269135},
#    {'date': '2022-02-28', 'value': 23584.006408514506},
#    {'date': '2022-03-31', 'value': 24349.32359945891},
#    {'date': '2022-04-30', 'value': 22153.92793250214},
#    {'date': '2022-05-31', 'value': 22094.594081504572},
#    {'date': '2022-06-30', 'value': 20247.464847347368},
#    {'date': '2022-07-31', 'value': 22149.31957924767},
#    {'date': '2022-08-31', 'value': 21321.946705399663},
#    {'date': '2022-09-30', 'value': 19344.620696791942},
#    {'date': '2022-10-31', 'value': 20924.361214490924},
#    {'date': '2022-11-30', 'value': 22018.878614188514},
#    {'date': '2022-12-31', 'value': 20726.368788866694},
#    {'date': '2023-01-31', 'value': 22155.620888124216},
#    {'date': '2023-02-28', 'value': 21639.130949447335},
#    {'date': '2023-03-31', 'value': 22210.691826240512},
#    {'date': '2023-04-30', 'value': 22443.14788495942},
#    {'date': '2023-05-31', 'value': 22537.024284309337},
#    {'date': '2023-06-30', 'value': 24078.54003795377},
#    {'date': '2023-07-31', 'value': 24937.84678974965},
#    {'date': '2023-08-31', 'value': 24455.467598958614},
#    {'date': '2023-09-30', 'value': 23285.796072551413},
#    {'date': '2023-10-31', 'value': 22673.30795637028},
#    {'date': '2023-11-30', 'value': 24799.000605265137},
#    {'date': '2023-12-31', 'value': 26116.92858839216},
#    {'date': '2024-01-31', 'value': 26408.65000562085},
#    {'date': '2024-02-29', 'value': 27835.594205833324},
#    {'date': '2024-03-31', 'value': 28729.50902053509},
#    {'date': '2024-04-30', 'value': 27460.96263213652},
#    {'date': '2024-05-31', 'value': 28759.009926199346},
#    {'date': '2024-06-30', 'value': 29662.220362667726},
#    {'date': '2024-07-31', 'value': 30204.22375304587},
#    {'date': '2024-08-31', 'value': 30860.095904372574},
#    {'date': '2024-09-30', 'value': 31491.42838849832},
#    {'date': '2024-10-31', 'value': 31253.86070563641},
#    {'date': '2024-11-30', 'value': 33325.72570396504},
#    {'date': '2024-12-31', 'value': 32317.957017985973},
#    {'date': '2025-01-31', 'value': 33317.079271865296},
#    {'date': '2025-02-28', 'value': 32680.024687074943},
#    {'date': '2025-03-31', 'value': 30757.07426893575},
#    {'date': '2025-04-30', 'value': 30550.110816378343},
#    {'date': '2025-05-31', 'value': 32488.66858793058},
#    {'date': '2025-06-30', 'value': 34137.70712463325},
#    {'date': '2025-07-31', 'value': 34914.980721598135},
#    {'date': '2025-08-31', 'value': 35710.7041102193},
#    {'date': '2025-09-30', 'value': 36949.08402464836},
#    {'date': '2025-10-31', 'value': 37753.9332927838},
#    {'date': '2025-11-30', 'value': 37862.633848838566},
#    {'date': '2025-12-31', 'value': 37850.083344934865},
#    {'date': '2026-01-31', 'value': 38448.44860792741},
#    {'date': '2026-02-28', 'value': 38246.674205803545},
#    {'date': '2026-03-15', 'value': 36818.01918236348}],
#   'index': [{'date': '2016-01-31', 'value': 9466.616519820853},
#    {'date': '2016-02-29', 'value': 9453.577544174485},
#    {'date': '2016-03-31', 'value': 10105.32430744867},
#    {'date': '2016-04-30', 'value': 10147.931205812902},
#    {'date': '2016-05-31', 'value': 10333.196218376701},
#    {'date': '2016-06-30', 'value': 10357.643413678701},
#    {'date': '2016-07-31', 'value': 10742.82483214667},
#    {'date': '2016-08-31', 'value': 10757.905748596822},
#    {'date': '2016-09-30', 'value': 10767.572549698425},
#    {'date': '2016-10-31', 'value': 10558.144436541868},
#    {'date': '2016-11-30', 'value': 10949.046597102046},
#    {'date': '2016-12-31', 'value': 11158.522938241957},
#    {'date': '2017-01-31', 'value': 11384.48009773007},
#    {'date': '2017-02-28', 'value': 11824.647695419115},
#    {'date': '2017-03-31', 'value': 11836.862663648344},
#    {'date': '2017-04-30', 'value': 11958.62994654601},
#    {'date': '2017-05-31', 'value': 12123.57510891568},
#    {'date': '2017-06-30', 'value': 12204.37776360722},
#    {'date': '2017-07-31', 'value': 12447.03382821055},
#    {'date': '2017-08-31', 'value': 12487.880498238717},
#    {'date': '2017-09-30', 'value': 12745.985969870435},
#    {'date': '2017-10-31', 'value': 13041.462780964559},
#    {'date': '2017-11-30', 'value': 13438.67660358997},
#    {'date': '2017-12-31', 'value': 13581.222169285038},
#    {'date': '2018-01-31', 'value': 14343.93689425329},
#    {'date': '2018-02-28', 'value': 13825.635273494894},
#    {'date': '2018-03-31', 'value': 13507.034999305593},
#    {'date': '2018-04-30', 'value': 13548.147028706016},
#    {'date': '2018-05-31', 'value': 13888.159845090973},
#    {'date': '2018-06-30', 'value': 13976.099931131012},
#    {'date': '2018-07-31', 'value': 14472.678648290203},
#    {'date': '2018-08-31', 'value': 14962.189540220425},
#    {'date': '2018-09-30', 'value': 15021.859032572536},
#    {'date': '2018-10-31', 'value': 13963.511186725165},
#    {'date': '2018-11-30', 'value': 14258.230147234473},
#    {'date': '2018-12-31', 'value': 12966.842564143084},
#    {'date': '2019-01-31', 'value': 14042.776092105469},
#    {'date': '2019-02-28', 'value': 14521.310893066502},
#    {'date': '2019-03-31', 'value': 14780.881343975403},
#    {'date': '2019-04-30', 'value': 15378.574265397456},
#    {'date': '2019-05-31', 'value': 14414.668387159543},
#    {'date': '2019-06-30', 'value': 15421.79237001019},
#    {'date': '2019-07-31', 'value': 15658.918209805695},
#    {'date': '2019-08-31', 'value': 15388.411235470421},
#    {'date': '2019-09-30', 'value': 15654.707647542093},
#    {'date': '2019-10-31', 'value': 15985.817828831801},
#    {'date': '2019-11-30', 'value': 16588.326662422216},
#    {'date': '2019-12-31', 'value': 17065.404065093415},
#    {'date': '2020-01-31', 'value': 17103.894164731522},
#    {'date': '2020-02-29', 'value': 15712.309416288925},
#    {'date': '2020-03-31', 'value': 13694.670540705882},
#    {'date': '2020-04-30', 'value': 15491.750378871631},
#    {'date': '2020-05-31', 'value': 16307.824063209979},
#    {'date': '2020-06-30', 'value': 16674.985623637684},
#    {'date': '2020-07-31', 'value': 17664.44213408099},
#    {'date': '2020-08-31', 'value': 18976.19176530101},
#    {'date': '2020-09-30', 'value': 18269.94841066145},
#    {'date': '2020-10-31', 'value': 17798.229078625445},
#    {'date': '2020-11-30', 'value': 19864.302311640695},
#    {'date': '2020-12-31', 'value': 20667.354477696343},
#    {'date': '2021-01-31', 'value': 20488.27653100307},
#    {'date': '2021-02-28', 'value': 21039.789762520286},
#    {'date': '2021-03-31', 'value': 21816.938240732183},
#    {'date': '2021-04-30', 'value': 22992.251787980516},
#    {'date': '2021-05-31', 'value': 23087.462624041844},
#    {'date': '2021-06-30', 'value': 23718.972220754797},
#    {'date': '2021-07-31', 'value': 24242.55029556117},
#    {'date': '2021-08-31', 'value': 24955.97383782158},
#    {'date': '2021-09-30', 'value': 23788.226686693655},
#    {'date': '2021-10-31', 'value': 25440.600613512306},
#    {'date': '2021-11-30', 'value': 25134.86325243174},
#    {'date': '2021-12-31', 'value': 26132.771856542076},
#    {'date': '2022-01-31', 'value': 24624.26282296},
#    {'date': '2022-02-28', 'value': 23935.0793698791},
#    {'date': '2022-03-31', 'value': 24755.917363560304},
#    {'date': '2022-04-30', 'value': 22516.827549259393},
#    {'date': '2022-05-31', 'value': 22460.374082964652},
#    {'date': '2022-06-30', 'value': 20578.316612576527},
#    {'date': '2022-07-31', 'value': 22497.257981070234},
#    {'date': '2022-08-31', 'value': 21626.352206351887},
#    {'date': '2022-09-30', 'value': 19623.486168796906},
#    {'date': '2022-10-31', 'value': 21180.655612198298},
#    {'date': '2022-11-30', 'value': 22347.187001253467},
#    {'date': '2022-12-31', 'value': 21037.45133190683},
#    {'date': '2023-01-31', 'value': 22419.22077378532},
#    {'date': '2023-02-28', 'value': 21889.062935482205},
#    {'date': '2023-03-31', 'value': 22630.993025008986},
#    {'date': '2023-04-30', 'value': 22917.605043907075},
#    {'date': '2023-05-31', 'value': 23058.911781972132},
#    {'date': '2023-06-30', 'value': 24599.161069576767},
#    {'date': '2023-07-31', 'value': 25426.708398360097},
#    {'date': '2023-08-31', 'value': 25005.924702911434},
#    {'date': '2023-09-30', 'value': 23839.063360997687},
#    {'date': '2023-10-31', 'value': 23293.375181491905},
#    {'date': '2023-11-30', 'value': 25481.536977415355},
#    {'date': '2023-12-31', 'value': 26686.413223820717},
#    {'date': '2024-01-31', 'value': 27119.333211490783},
#    {'date': '2024-02-29', 'value': 28607.72304909708},
#    {'date': '2024-03-31', 'value': 29508.827618681877},
#    {'date': '2024-04-30', 'value': 28287.940128473714},
#    {'date': '2024-05-31', 'value': 29633.340087525714},
#    {'date': '2024-06-30', 'value': 30682.412465071822},
#    {'date': '2024-07-31', 'value': 31059.042827589466},
#    {'date': '2024-08-31', 'value': 31815.06818113585},
#    {'date': '2024-09-30', 'value': 32492.307062808002},
#    {'date': '2024-10-31', 'value': 32250.847193637408},
#    {'date': '2024-11-30', 'value': 34269.05284418303},
#    {'date': '2024-12-31', 'value': 33376.20303925902},
#    {'date': '2025-01-31', 'value': 34402.27671120227},
#    {'date': '2025-02-28', 'value': 33849.90284530448},
#    {'date': '2025-03-31', 'value': 31863.31219498879},
#    {'date': '2025-04-30', 'value': 31714.585308099373},
#    {'date': '2025-05-31', 'value': 33763.8402137355},
#    {'date': '2025-06-30', 'value': 35497.59448881526},
#    {'date': '2025-07-31', 'value': 36306.17522948018},
#    {'date': '2025-08-31', 'value': 37025.706069742584},
#    {'date': '2025-09-30', 'value': 38373.563695559315},
#    {'date': '2025-10-31', 'value': 39273.12859266914},
#    {'date': '2025-11-30', 'value': 39307.20107355119},
#    {'date': '2025-12-31', 'value': 39287.28519940799},
#    {'date': '2026-01-31', 'value': 39808.7791478836},
#    {'date': '2026-02-28', 'value': 39472.070004192086},
#    {'date': '2026-03-14', 'value': 38091.76734067943}],
#   'category': [{'date': '2016-01-31', 'value': 9454.76481544422},
#    {'date': '2016-02-29', 'value': 9430.081160267315},
#    {'date': '2016-03-31', 'value': 10035.657129729805},
#    {'date': '2016-04-30', 'value': 10086.02015474574},
#    {'date': '2016-05-31', 'value': 10240.283921900744},
#    {'date': '2016-06-30', 'value': 10213.847207647888},
#    {'date': '2016-07-31', 'value': 10589.973665937505},
#    {'date': '2016-08-31', 'value': 10609.202067296435},
#    {'date': '2016-09-30', 'value': 10600.861258876053},
#    {'date': '2016-10-31', 'value': 10398.372039007607},
#    {'date': '2016-11-30', 'value': 10825.5088000361},
#    {'date': '2016-12-31', 'value': 11009.757281514609},
#    {'date': '2017-01-31', 'value': 11210.512567552792},
#    {'date': '2017-02-28', 'value': 11612.752236948496},
#    {'date': '2017-03-31', 'value': 11621.073426203635},
#    {'date': '2017-04-30', 'value': 11740.192280298199},
#    {'date': '2017-05-31', 'value': 11867.27120223851},
#    {'date': '2017-06-30', 'value': 11956.86405938884},
#    {'date': '2017-07-31', 'value': 12176.095033795105},
#    {'date': '2017-08-31', 'value': 12178.46402716007},
#    {'date': '2017-09-30', 'value': 12461.145640820967},
#    {'date': '2017-10-31', 'value': 12710.784071567845},
#    {'date': '2017-11-30', 'value': 13101.025513582423},
#    {'date': '2017-12-31', 'value': 13259.102896533375},
#    {'date': '2018-01-31', 'value': 13953.256130273288},
#    {'date': '2018-02-28', 'value': 13418.26501049981},
#    {'date': '2018-03-31', 'value': 13137.832502094712},
#    {'date': '2018-04-30', 'value': 13164.357661007083},
#    {'date': '2018-05-31', 'value': 13429.702282144714},
#    {'date': '2018-06-30', 'value': 13487.247098793514},
#    {'date': '2018-07-31', 'value': 13963.144382902483},
#    {'date': '2018-08-31', 'value': 14343.753088637559},
#    {'date': '2018-09-30', 'value': 14384.00339837365},
#    {'date': '2018-10-31', 'value': 13389.03155348482},
#    {'date': '2018-11-30', 'value': 13667.36946111426},
#    {'date': '2018-12-31', 'value': 12435.219044690724},
#    {'date': '2019-01-31', 'value': 13428.623798653807},
#    {'date': '2019-02-28', 'value': 13863.389278135966},
#    {'date': '2019-03-31', 'value': 14040.647768683322},
#    {'date': '2019-04-30', 'value': 14587.835632483428},
#    {'date': '2019-05-31', 'value': 13669.042912707297},
#    {'date': '2019-06-30', 'value': 14578.835732120428},
#    {'date': '2019-07-31', 'value': 14789.750342834697},
#    {'date': '2019-08-31', 'value': 14524.023141196805},
#    {'date': '2019-09-30', 'value': 14791.797698751707},
#    {'date': '2019-10-31', 'value': 15054.76223584359},
#    {'date': '2019-11-30', 'value': 15570.215542552023},
#    {'date': '2019-12-31', 'value': 15991.34973366568},
#    {'date': '2020-01-31', 'value': 15897.5288140003},
#    {'date': '2020-02-29', 'value': 14599.082742987319},
#    {'date': '2020-03-31', 'value': 12639.050324596383},
#    {'date': '2020-04-30', 'value': 14154.012526205646},
#    {'date': '2020-05-31', 'value': 14841.546847710883},
#    {'date': '2020-06-30', 'value': 15081.727807154939},
#    {'date': '2020-07-31', 'value': 15857.341102434095},
#    {'date': '2020-08-31', 'value': 16829.698493185817},
#    {'date': '2020-09-30', 'value': 16296.779746529679},
#    {'date': '2020-10-31', 'value': 15939.691216769656},
#    {'date': '2020-11-30', 'value': 17687.204013225102},
#    {'date': '2020-12-31', 'value': 18365.34409994483},
#    {'date': '2021-01-31', 'value': 18220.41420392205},
#    {'date': '2021-02-28', 'value': 18796.328983565043},
#    {'date': '2021-03-31', 'value': 19602.62376594909},
#    {'date': '2021-04-30', 'value': 20541.8538723059},
#    {'date': '2021-05-31', 'value': 20738.220361230426},
#    {'date': '2021-06-30', 'value': 21079.33546598884},
#    {'date': '2021-07-31', 'value': 21496.478579616625},
#    {'date': '2021-08-31', 'value': 22047.059010798625},
#    {'date': '2021-09-30', 'value': 21027.89602967957},
#    {'date': '2021-10-31', 'value': 22350.08405437971},
#    {'date': '2021-11-30', 'value': 22012.619154752425},
#    {'date': '2021-12-31', 'value': 23008.554954122937},
#    {'date': '2022-01-31', 'value': 21785.032517520984},
#    {'date': '2022-02-28', 'value': 21235.03815979147},
#    {'date': '2022-03-31', 'value': 21833.01794960787},
#    {'date': '2022-04-30', 'value': 20123.824846502655},
#    {'date': '2022-05-31', 'value': 20177.979008482595},
#    {'date': '2022-06-30', 'value': 18578.558774416422},
#    {'date': '2022-07-31', 'value': 20079.61707796509},
#    {'date': '2022-08-31', 'value': 19327.658322888627},
#    {'date': '2022-09-30', 'value': 17644.831952209606},
#    {'date': '2022-10-31', 'value': 19042.53973738223},
#    {'date': '2022-11-30', 'value': 20132.59483536112},
#    {'date': '2022-12-31', 'value': 19088.201704072424},
#    {'date': '2023-01-31', 'value': 20318.624435407946},
#    {'date': '2023-02-28', 'value': 19797.238378837978},
#    {'date': '2023-03-31', 'value': 20275.641018742164},
#    {'date': '2023-04-30', 'value': 20502.345249876187},
#    {'date': '2023-05-31', 'value': 20426.638248241987},
#    {'date': '2023-06-30', 'value': 21720.253290365534},
#    {'date': '2023-07-31', 'value': 22408.672530366326},
#    {'date': '2023-08-31', 'value': 22012.857052226198},
#    {'date': '2023-09-30', 'value': 21022.400308623513},
#    {'date': '2023-10-31', 'value': 20542.694332038966},
#    {'date': '2023-11-30', 'value': 22302.784688535678},
#    {'date': '2023-12-31', 'value': 23376.06533197181},
#    {'date': '2024-01-31', 'value': 23667.368872853018},
#    {'date': '2024-02-29', 'value': 24842.837945007457},
#    {'date': '2024-03-31', 'value': 25663.82646578724},
#    {'date': '2024-04-30', 'value': 24588.041793069126},
#    {'date': '2024-05-31', 'value': 25629.67548805883},
#    {'date': '2024-06-30', 'value': 26281.16711535373},
#    {'date': '2024-07-31', 'value': 26730.64885927484},
#    {'date': '2024-08-31', 'value': 27304.77587883521},
#    {'date': '2024-09-30', 'value': 27798.867509966603},
#    {'date': '2024-10-31', 'value': 27494.079803465294},
#    {'date': '2024-11-30', 'value': 29147.267811946138},
#    {'date': '2024-12-31', 'value': 28193.13832295584},
#    {'date': '2025-01-31', 'value': 29140.59273171169},
#    {'date': '2025-02-28', 'value': 28677.19893057363},
#    {'date': '2025-03-31', 'value': 27127.205712997667},
#    {'date': '2025-04-30', 'value': 26904.752308832725},
#    {'date': '2025-05-31', 'value': 28481.66878829279},
#    {'date': '2025-06-30', 'value': 29806.26493572959},
#    {'date': '2025-07-31', 'value': 30332.903098044},
#    {'date': '2025-08-31', 'value': 30959.961220893925},
#    {'date': '2025-09-30', 'value': 31865.758518298015},
#    {'date': '2025-10-31', 'value': 32365.989713346415},
#    {'date': '2025-11-30', 'value': 32553.809711602284},
#    {'date': '2025-12-31', 'value': 32579.735895750582},
#    {'date': '2026-01-31', 'value': 33120.929565557795},
#    {'date': '2026-02-28', 'value': 33065.196181570274},
#    {'date': '2026-03-13', 'value': 31713.13876972129}]},
#  'fundFlowData': [{'date': '2016-01-31', 'value': 7955528520.217},
#   {'date': '2016-02-29', 'value': 3978451487.497},
#   {'date': '2016-03-31', 'value': 1140518428.661},
#   {'date': '2016-04-30', 'value': 2751846571.381},
#   {'date': '2016-05-31', 'value': 3200875979.232},
#   {'date': '2016-06-30', 'value': 4206517972.739},
#   {'date': '2016-07-31', 'value': 2404484797.108},
#   {'date': '2016-08-31', 'value': 4621241870.862},
#   {'date': '2016-09-30', 'value': 3871868362.686},
#   {'date': '2016-10-31', 'value': 4701411899.333},
#   {'date': '2016-11-30', 'value': 4364096158.672},
#   {'date': '2016-12-31', 'value': 1544867070.91},
#   {'date': '2017-01-31', 'value': 9950402027.747},
#   {'date': '2017-02-28', 'value': 4137338111.416},
#   {'date': '2017-03-31', 'value': 8291911331.821},
#   {'date': '2017-04-30', 'value': 5069799036.254},
#   {'date': '2017-05-31', 'value': 8492139458.711},
#   {'date': '2017-06-30', 'value': 1549516307.787},
#   {'date': '2017-07-31', 'value': 4598227544.4},
#   {'date': '2017-08-31', 'value': 6193349975.264},
#   {'date': '2017-09-30', 'value': 2530037724.311},
#   {'date': '2017-10-31', 'value': 1048299232.835},
#   {'date': '2017-11-30', 'value': 2663664044.731},
#   {'date': '2017-12-31', 'value': -422106744.391},
#   {'date': '2018-01-31', 'value': 3224286203.305},
#   {'date': '2018-02-28', 'value': 6841601075.336},
#   {'date': '2018-03-31', 'value': 4563530655.653},
#   {'date': '2018-04-30', 'value': 4375929813.38},
#   {'date': '2018-05-31', 'value': 276892810.944},
#   {'date': '2018-06-30', 'value': -1654934625.286},
#   {'date': '2018-07-31', 'value': 1179429064.892},
#   {'date': '2018-08-31', 'value': -1614929832.281},
#   {'date': '2018-09-30', 'value': 6781258078.704},
#   {'date': '2018-10-31', 'value': 7605128797.553},
#   {'date': '2018-11-30', 'value': 3493043779.587},
#   {'date': '2018-12-31', 'value': 14087654877.226},
#   {'date': '2019-01-31', 'value': 1080739704.759},
#   {'date': '2019-02-28', 'value': 314609075.622},
#   {'date': '2019-03-31', 'value': 5486599681.497},
#   {'date': '2019-04-30', 'value': 1111599981.106},
#   {'date': '2019-05-31', 'value': 6193609366.153},
#   {'date': '2019-06-30', 'value': 2680675905.916},
#   {'date': '2019-07-31', 'value': -2013464556.655},
#   {'date': '2019-08-31', 'value': 6286409661.06},
#   {'date': '2019-09-30', 'value': 606851976.615},
#   {'date': '2019-10-31', 'value': 759104522.751},
#   {'date': '2019-11-30', 'value': -2859773430.795},
#   {'date': '2019-12-31', 'value': -966708326.488},
#   {'date': '2020-01-31', 'value': 4733472687.562},
#   {'date': '2020-02-29', 'value': 13176545797.126},
#   {'date': '2020-03-31', 'value': 12545367393.743},
#   {'date': '2020-04-30', 'value': -12187592972.124},
#   {'date': '2020-05-31', 'value': -5939861842.666},
#   {'date': '2020-06-30', 'value': -7231263478.093},
#   {'date': '2020-07-31', 'value': -3576699454.258},
#   {'date': '2020-08-31', 'value': -9708654554.84},
#   {'date': '2020-09-30', 'value': -881327114.375},
#   {'date': '2020-10-31', 'value': 4040994915.647},
#   {'date': '2020-11-30', 'value': 1326169723.048},
#   {'date': '2020-12-31', 'value': 221267621.825},
#   {'date': '2021-01-31', 'value': 2321406189.638},
#   {'date': '2021-02-28', 'value': -2430860855.121},
#   {'date': '2021-03-31', 'value': 4985152507.0},
#   {'date': '2021-04-30', 'value': 1031938618.266},
#   {'date': '2021-05-31', 'value': 4647415455.472},
#   {'date': '2021-06-30', 'value': 3384336523.855},
#   {'date': '2021-07-31', 'value': 141918850.196},
#   {'date': '2021-08-31', 'value': -1079129109.538},
#   {'date': '2021-09-30', 'value': 2586278731.309},
#   {'date': '2021-10-31', 'value': -275125147.822},
#   {'date': '2021-11-30', 'value': 2566346555.666},
#   {'date': '2021-12-31', 'value': -732989157.79},
#   {'date': '2022-01-31', 'value': 12222034153.74},
#   {'date': '2022-02-28', 'value': 2604560491.534},
#   {'date': '2022-03-31', 'value': 1707255548.562},
#   {'date': '2022-04-30', 'value': 5238267535.712},
#   {'date': '2022-05-31', 'value': 10308945150.048},
#   {'date': '2022-06-30', 'value': 4582147661.991},
#   {'date': '2022-07-31', 'value': 2113722752.828},
#   {'date': '2022-08-31', 'value': -347071574.137},
#   {'date': '2022-09-30', 'value': 4440794375.176},
#   {'date': '2022-10-31', 'value': 1382971579.016},
#   {'date': '2022-11-30', 'value': 2535393687.988},
#   {'date': '2022-12-31', 'value': 9139113141.612},
#   {'date': '2023-01-31', 'value': 8529505267.701},
#   {'date': '2023-02-28', 'value': 1753054074.729},
#   {'date': '2023-03-31', 'value': 3779988836.521},
#   {'date': '2023-04-30', 'value': 3043832167.011},
#   {'date': '2023-05-31', 'value': -976208426.558},
#   {'date': '2023-06-30', 'value': -3035465731.371},
#   {'date': '2023-07-31', 'value': -1796079677.014},
#   {'date': '2023-08-31', 'value': -1829747728.243},
#   {'date': '2023-09-30', 'value': 1840860588.77},
#   {'date': '2023-10-31', 'value': 1878449617.026},
#   {'date': '2023-11-30', 'value': -2726472644.511},
#   {'date': '2023-12-31', 'value': -1424991123.72},
#   {'date': '2024-01-31', 'value': 1058790404.784},
#   {'date': '2024-02-29', 'value': -7150020644.414},
#   {'date': '2024-03-31', 'value': 2747701266.736},
#   {'date': '2024-04-30', 'value': 2294956640.236},
#   {'date': '2024-05-31', 'value': -330703528.125},
#   {'date': '2024-06-30', 'value': -2068544754.948},
#   {'date': '2024-07-31', 'value': -3420884842.69},
#   {'date': '2024-08-31', 'value': 5251532076.282},
#   {'date': '2024-09-30', 'value': -1288027665.503},
#   {'date': '2024-10-31', 'value': -6315376800.303},
#   {'date': '2024-11-30', 'value': -10292841695.803},
#   {'date': '2024-12-31', 'value': -227938393.357},
#   {'date': '2025-01-31', 'value': 4496289776.587},
#   {'date': '2025-02-28', 'value': 4915967497.912},
#   {'date': '2025-03-31', 'value': 5060310921.394},
#   {'date': '2025-04-30', 'value': 22884276410.705},
#   {'date': '2025-05-31', 'value': -1697678591.881},
#   {'date': '2025-06-30', 'value': -1747294106.213},
#   {'date': '2025-07-31', 'value': -46540277480.787},
#   {'date': '2025-08-31', 'value': 158642416.921},
#   {'date': '2025-09-30', 'value': -2546397701.152},
#   {'date': '2025-10-31', 'value': -7712310161.358},
#   {'date': '2025-11-30', 'value': -260729996.118},
#   {'date': '2025-12-31', 'value': 726767188.212},
#   {'date': '2026-01-31', 'value': 6140168581.776},
#   {'date': '2026-02-28', 'value': 4656470605.452},
#   {'date': '2026-03-31', 'value': None},
#   {'date': '2026-04-30', 'value': None},
#   {'date': '2026-05-31', 'value': None},
#   {'date': '2026-06-30', 'value': None},
#   {'date': '2026-07-31', 'value': None},
#   {'date': '2026-08-31', 'value': None},
#   {'date': '2026-09-30', 'value': None},
#   {'date': '2026-10-31', 'value': None},
#   {'date': '2026-11-30', 'value': None},
#   {'date': '2026-12-31', 'value': None}],
#  'managerChange': [{'date': '2016-04-27 00:00:00.0', 'value': 'partial'},
#   {'date': '2023-02-17 00:00:00.0', 'value': 'partial'},
#   {'date': '2025-06-18 00:00:00.0', 'value': 'partial'}],
#  'table': {'columnDefs': ['2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    '2025',
#    'YTD'],
#   'growth10KReturnData': [{'label': 'fund',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['12.66422',
#      '21.16927',
#      '-5.1711',
#      '30.80497',
#      '20.98791',
#      '25.71229',
#      '-19.52516',
#      '26.00822',
#      '23.74332',
#      '17.11781',
#      '-2.72672'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'category',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['10.36891',
#      '20.43837',
#      '-6.26928',
#      '28.77649',
#      '15.82748',
#      '26.06759',
#      '-16.95545',
#      '22.31864',
#      '21.44601',
#      '15.54386',
#      '-2.68563'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'index',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['11.58523',
#      '21.71165',
#      '-4.52374',
#      '31.60802',
#      '21.10674',
#      '26.44469',
#      '-19.49782',
#      '26.85193',
#      '25.06815',
#      '17.71047',
#      '-3.04301'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'percentileRank',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['20',
#      '45',
#      '42',
#      '39',
#      '17',
#      '63',
#      '75',
#      '33',
#      '43',
#      '40',
#      '41'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'fundNumber',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['1409',
#      '1396',
#      '1402',
#      '1387',
#      '1363',
#      '1382',
#      '1358',
#      '1430',
#      '1386',
#      '1314',
#      '1324'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'fundNet',
#     'endDate': '2026-02-28T00:00:00.000',
#     'datum': ['12.66422',
#      '21.16927',
#      '-5.1711',
#      '30.80497',
#      '20.98791',
#      '25.71229',
#      '-19.52516',
#      '26.00822',
#      '23.74332',
#      '17.11781',
#      None],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]}]},
#  'currentValues': [{'type': 'fund',
#    'name': 'VTSAX',
#    'baseCurrency': 'USD',
#    'currentValue': 36818.01918236348,
#    'currentSymbol': '$'},
#   {'type': 'index',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': 38091.76734067943,
#    'currentSymbol': '$'},
#   {'type': 'category',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': 31713.13876972129,
#    'currentSymbol': '$'}],
#  'instrumentId': '52.8.VTSAX',
#  'fundFlowQuarterlyData': [],
#  'isLimitAgeData': False,
#  'cur': 'USD',
#  'isUKCefAvailable': False,
#  'template': 'SA_USA'}

# %% [markdown]
# Historical expense ratio
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.historicalExpenses()
# Out:
# {'feeLevelComparisonGroup': 'Large Cap Institutional',
#  'currentYear': '2026',
#  'fundExpenseHistoryList': [{'annualReportDate': '2022-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None},
#   {'annualReportDate': '2023-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None},
#   {'annualReportDate': '2024-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None},
#   {'annualReportDate': '2025-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None}],
#  'feeLevelMedianList': [{'date': '2022-12-31T06:00:00.000', 'median': 0.7},
#   {'date': '2023-12-31T06:00:00.000', 'median': 0.7},
#   {'date': '2024-12-31T06:00:00.000', 'median': 0.69},
#   {'date': '2025-12-31T06:00:00.000', 'median': 0.68},
#   {'date': '2026-02-28T06:00:00.000', 'median': 0.68}],
#  'categoryExpenseAverageList': [{'year': '2022',
#    'categoryExpenseRatio': 0.81,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2023',
#    'categoryExpenseRatio': 0.823,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2024',
#    'categoryExpenseRatio': 0.807,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2025',
#    'categoryExpenseRatio': 0.831,
#    'categoryManagementExpenseRatio': None}]}

# %% [markdown]
# Historical raiting

# %%
funds.historicalRating()
# Out:
# {'medalistStartDate': '2023-05-01',
#  'ticker': 'VTSAX',
#  'userType': 'Free',
#  'years': {'2023': [{'date': '2023-04-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-05-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-06-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-07-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-08-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-09-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-10-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-11-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-12-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}],
#   '2024': [{'date': '2024-01-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-02-29',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'Y',
#     'analysisPublishedDate': '2024-02-07T06:00:00.000'},
#    {'date': '2024-03-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-04-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-05-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-06-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-07-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-08-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-09-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-10-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-11-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-12-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}],
#   '2025': [{'date': '2025-01-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'Y',
#     'analysisPublishedDate': '2025-01-29T06:00:00.000'},
#    {'date': '2025-02-28',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-03-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-04-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-05-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-06-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-07-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-08-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-09-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-10-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-11-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-12-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}],
#   '2026': [{'date': '2026-01-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'Y',
#     'analysisPublishedDate': '2026-01-28T06:00:00.000'},
#    {'date': '2026-02-28',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2026-03-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'hasIssuerRating': None,
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}]}}

# %% [markdown]
# Holdings in a DataFrame format
#
# Holdings
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.holdings()
# Out:
#               securityName       secId performanceId holdingTypeId  weighting  \
# 0              NVIDIA Corp  0P000003RE    0P000003RE             E    6.61532
# 1                Apple Inc  0P000000GY    0P000000GY             E    5.74874
# 2           Microsoft Corp  0P000003MH    0P000003MH             E    4.79509
# 3           Amazon.com Inc  0P000000B7    0P000000B7             E    3.45183
# 4     Alphabet Inc Class A  0P000002HD    0P000002HD             E    2.94768
# ...                    ...         ...           ...           ...        ...
# 3520     Escrow Luby's Inc        None          None            AP    0.00001
# 3521              Srax Pfd        None          None             P    0.00000
# 3522          Clearone Inc  B1000HOJJT          None             P    0.00000
# 3523    Btcs Incorporation  B10003UJJ6          None             P    0.00000
# 3524         Nutriband Inc  B1000HLHOF          None             P    0.00000
#
#       numberOfShare   marketValue  shareChange        country ticker  ...  \
# 0       727204610.0  1.389906e+11    2009037.0  United States   NVDA  ...
# 1       465482394.0  1.207834e+11    1292500.0  United States   AAPL  ...
# 2       234137135.0  1.007469e+11     656599.0  United States   MSFT  ...
# 3       303069126.0  7.252444e+10     823152.0  United States   AMZN  ...
# 4       183230859.0  6.193203e+10     447131.0  United States  GOOGL  ...
# ...             ...           ...          ...            ...    ...  ...
# 3520       449752.0  1.124380e+05          0.0           None   None  ...
# 3521       590641.0  4.134500e+04          0.0  United States   None  ...
# 3522        24648.0  5.423000e+03          0.0  United States   None  ...
# 3523       280193.0  3.000000e+00          0.0  United States   None  ...
# 3524        30646.0  0.000000e+00          0.0  United States   None  ...
#
#       susEsgRiskCategory  managementExpenseRatio qualRating quantRating  \
# 0                    Low                    None       None           4
# 1                    Low                    None       None           3
# 2                    Low                    None       None           5
# 3                    Low                    None       None           3
# 4                    Low                    None       None           3
# ...                  ...                     ...        ...         ...
# 3520                None                    None       None        None
# 3521                None                    None       None        None
# 3522                None                    None       None        None
# 3523                None                    None       None        None
# 3524                None                    None       None        None
#
#      bestRatingType securityType domicileCountryId currencyName  \
# 0              Qual           ST               USA    US Dollar
# 1              Qual           ST               USA    US Dollar
# 2              Qual           ST               USA    US Dollar
# 3              Qual           ST               USA    US Dollar
# 4              Qual           ST               USA    US Dollar
# ...             ...          ...               ...          ...
# 3520           None         None              None         None
# 3521           None         None              None    US Dollar
# 3522           None         None              None         None
# 3523           None         None              None    US Dollar
# 3524           None         None              None    US Dollar
#
#      originalMarketValue isMomentumFilterFlag
# 0           1.389906e+11                False
# 1           1.207834e+11                False
# 2           1.007469e+11                False
# 3           7.252444e+10                False
# 4           6.193203e+10                False
# ...                  ...                  ...
# 3520        1.124380e+05                 None
# 3521        4.134500e+04                 None
# 3522        5.423000e+03                 None
# 3523        3.000000e+00                 None
# 3524        0.000000e+00                 None
#
# [3525 rows x 58 columns]

# %% [markdown]
# Summmary of fees
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/quote

# %%
funds_2.investmentFee()
# Out:
# {'domicileCountryId': 'IRL',
#  'priceTemplate': 'EEA_OE',
#  'actualInvestmentFees': {'kiidOngoingCharge': 0.12,
#   'kiidOngoingChargeDate': '2025-07-23T05:00:00.000',
#   'ongoingCost': 0.1214,
#   'performanceFee': 0.0,
#   'managementFee': 0.12,
#   'transactionFee': 0.0143,
#   'distributionFee': 0.0},
#  'estimatedInvestmentFees': {'ongoingCost': 0.1214,
#   'performanceFee': 0.0,
#   'managementFee': 0.12,
#   'transactionFee': 0.0172,
#   'distributionFee': 0.0}}

# %% [markdown]
# Quick lookup on the fund

# %%
funds_2.investmentLookup()
# Out:
# {'dbgtime': '241',
#  'Id': 'F0000022KV',
#  'InceptionDate': '2008-08-06T00:00:00',
#  'Isin': 'IE00B04GQT48',
#  'InvestmentType': 'FD',
#  'HoldingType': '2',
#  'Type': 'Fund',
#  'Name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'LegalName': 'Vanguard U.S. Investment Grade Credit Index Fund EUR Acc',
#  'FundNetAssetValues': [{'CurrencyId': 'EUR',
#    'DayEndDate': '2026-03-13T00:00:00',
#    'DayEndValue': 1572966901.74696,
#    'MonthEndDate': '2026-02-27T00:00:00',
#    'MonthEndValue': 1574262377.12016}],
#  'ESG': {'SustainabilityDate': '2025-10-31T00:00:00',
#   'SustainabilityRank': 3,
#   'EnvironmentalScore': 4.68,
#   'SocialScore': 7.8,
#   'GovernanceScore': 4.53,
#   'RawSustainabilityScore': 21.83857,
#   'AUMCoverage': 90.4255,
#   'SustainabilityRating': {'Date': '2025-10-31T00:00:00',
#    'SustainabilityFundQuintile': 3,
#    'SustainabilityFundQuintileDesc': 'Average'},
#   'CarbonScore': {'Date': '2025-10-31T00:00:00',
#    'LowCarbonDesignation': 'No',
#    'CarbonRiskClassification': 'Low Risk',
#    'CarbonRiskScore': 9.06,
#    'CarbonExposureScore': 19.79,
#    'CarbonManagementScore': 10.73,
#    'CarbonOperationsRisk': 3.98,
#    'CarbonProductsAndServicesRisk': 0.69,
#    'StrandedAssetsRisk': 76.04,
#    'PercentOfAUMWithNegligibleCarbonRisk': 8.92899,
#    'PercentOfAUMWithLowCarbonRisk': 62.59959,
#    'PercentOfAUMWithMediumCarbonRisk': 23.13772,
#    'PercentOfAUMWithHighCarbonRisk': 4.13849,
#    'PercentOfAUMWithSevereCarbonRisk': 1.19521,
#    'OilSandsExtractionInvolvement': 1.56051,
#    'ArcticOilAndGasExplorationInvolvement': 1.6107,
#    'FossilFuelInvolvement': 12.59107,
#    'CarbonSolutionsInvolvement': 6.2024,
#    'ThermalCoalPowerGenerationInvolvement': 6.12346,
#    'ThermalCoalExtractionInvolvement': 0.96167,
#    'OilAndGasGenerationInvolvement': 9.1232,
#    'OilAndGasProductionInvolvement': 13.62976,
#    'OilAndGasProductsAndServiceInvolvement': 9.0089,
#    'HistoricCarbonRiskScore': 9.36},
#   'ProductInvolvement': {'Date': '2025-10-31T00:00:00',
#    'AbortiveContraceptivesStemCell': 6.23,
#    'AdultEntertainment': 0.0,
#    'Alcohol': 0.78,
#    'AnimalTesting': 10.78,
#    'ControversialWeapons': 1.6,
#    'FurAndSpecialtyLeather': 0.0,
#    'Gambling': 0.28,
#    'GMO': 0.26,
#    'MilitaryContracting': 1.95,
#    'Nuclear': 4.64,
#    'PalmOil': 0.02,
#    'Pesticides': 0.32,
#    'SmallArms': 0.7,
#    'ThermalCoal': 3.72,
#    'Tobacco': 1.07},
#   'RatingAndScore': {'Date': '2025-10-31T00:00:00',
#    'SustainabilityRatingDate': '2025-10-31T00:00:00',
#    'SustainabilityRating': 3,
#    'SustainabilityScore': 20.05,
#    'SustainabilityPercentRank': 57,
#    'SustainabilityAbsoluteRank': 2100,
#    'HistoricalSustainabilityScore': 21.84,
#    'EnvironmentalScore': 4.68,
#    'SocialScore': 7.8,
#    'GovernanceScore': 4.53,
#    'PercentAUMCoveredESG': 90.4255,
#    'NumberOfSecuritiesScoredESG': 6897,
#    'PercentAUMCoveredControversy': 91.68,
#    'NumberOfSecuritiesScoredControversy': 7051,
#    'NumberOfSecuritiesNotScoredControversy': 1321,
#    'PercentAUMWithLow': 7.46764,
#    'PercentAUMWithBelowAverage': 45.41733,
#    'PercentAUMWithAverage': 36.169,
#    'PercentAUMWithAboveAverage': 8.06727,
#    'PercentAUMWithHigh': 2.87875},
#   'SustainableInvestment': {'Overall': 'No',
#    'Date': '2025-09-16',
#    'GeneralESGInvestment': 'No',
#    'InvolvedInHealthyEcosystems': 'No',
#    'InvolvedInHumanDevelopment': 'No',
#    'InvolvedInResourceSecurity': 'No',
#    'InvolvedInBasicNeeds': 'No'},
#   'EmploysExclusions': {'Overall': 'No',
#    'UsesNormsBasedScreening': 'No',
#    'ExcludesAbortionStemCells': 'No',
#    'ExcludesAdultEntertainment': 'No',
#    'ExcludesAlcohol': 'No',
#    'ExcludesAnimalTesting': 'No',
#    'ExcludesControversialWeapons': 'No',
#    'ExcludesFurSpecialtyLeather': 'No',
#    'ExcludesGambling': 'No',
#    'ExcludesGMOs': 'No',
#    'ExcludesMilitaryContracting': 'No',
#    'ExcludesNuclear': 'No',
#    'ExcludesPalmOil': 'No',
#    'ExcludesPesticides': 'No',
#    'ExcludesSmallArms': 'No',
#    'ExcludesThermalCoal': 'No',
#    'ExcludesTobacco': 'No',
#    'ExcludesOther': 'No',
#    'ExcludesFossilFuel': 'No'}},
#  'Domicile': 'IRL',
#  'RealtimeId': '52.8.IE00B04GQT48',
#  'Currency': {'Id': 'EUR'},
#  'RiskAndRating': [{'Date': '2026-02-28T00:00:00',
#    'TimePeriod': 'M255',
#    'RatingValue': 4}],
#  'LastPrice': {'Date': '2026-03-13T00:00:00',
#   'MarketDate': '2026-03-13',
#   'MarketTime': '00:00:00',
#   'MarketTimeZone': 'GMT',
#   'Value': 268.5359,
#   'Currency': {'Id': 'EUR'}},
#  'Benchmark': [{'Id': 'EUCA000691',
#    'GlobalAssetClassId': '$BCG$FXINC',
#    'Type': 'Category',
#    'Name': 'USD Corporate Bond'}],
#  'FundBenchmark': [{'Id': 'F00000WZ2U',
#    'Name': 'Bloomberg Gbl Agg USD Credit FA TR USD',
#    'Weighting': 100.0}],
#  'Research': {'MedalistRating': {'OverallRating': {'Date': '2026-01-31',
#     'AnalystDrivenPercentage': 20,
#     'RatingNumber': 7,
#     'RatingText': 'Gold'}}}}

# %% [markdown]
# Investment strategy
#
# https://www.morningstar.com/funds/xnas/vtsax/quote

# %%
funds.investmentStrategy()
# Out:
# {'investmentStrategy': 'The investment seeks to track the performance of the CRSP US Total Market Index that measures the investment return of the overall stock market.\n The fund employs an indexing investment approach designed to track the performance of the index, which represents approximately 100% of the investable U.S. stock market and includes large-, mid-, small-, and micro-cap stocks. It invests by sampling the index, meaning that it holds a broadly diversified collection of securities that, in the aggregate, approximates the full index in terms of key characteristics. The fund is non-diversified.',
#  'languageId': '0L00000122',
#  'isInvestmentStrategyEmpty': False,
#  'template': 'USA_OE',
#  'domicileCountryId': 'USA'}

# %% [markdown]
# Breakdown by market capitalization
#
# Style Measures - Market Cap
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.marketCapitalization()
# Out:
# {'portfolioDate': '2026-01-31T06:00:00.000',
#  'assetType': 'EQUITY',
#  'currencyId': 'USD',
#  'fund': {'portfolioDate': '2026-01-31T06:00:00.000',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'avgMarketCap': 284486.68144,
#   'giant': 40.45803,
#   'large': 31.10366,
#   'medium': 19.24638,
#   'small': 6.3432,
#   'micro': 2.23392},
#  'category': {'portfolioDate': '2026-01-31T06:00:00.000',
#   'name': 'Large Blend',
#   'avgMarketCap': 536122.51863,
#   'giant': 57.17635,
#   'large': 16.94673,
#   'medium': 19.36595,
#   'small': 3.74937,
#   'micro': 0.05403},
#  'index': {'portfolioDate': '2026-02-28T06:00:00.000',
#   'name': 'Morningstar US Large-Mid TR USD',
#   'avgMarketCap': 405003.71907,
#   'giant': 45.49643,
#   'large': 34.48173,
#   'medium': 19.64654,
#   'small': 0.37532,
#   'micro': 0.0}}

# %% [markdown]
# Breakdown by bond maturity
#
# Bond Breakdown - Maturity Schedule
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.maturitySchedule()
# Out:
# {'fund': {'date': '2026-01-31T06:00:00.000',
#   'name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'schedule': ['21.48415',
#    '21.50198',
#    '11.80125',
#    '16.05002',
#    '5.89153',
#    '5.59026',
#    '14.87518',
#    '2.60361']},
#  'benchMark': None,
#  'category': {'date': '2026-01-31T06:00:00.000',
#   'name': 'USD Corporate Bond',
#   'schedule': ['7.30885',
#    '11.44050',
#    '2.83198',
#    '22.56101',
#    '0.95002',
#    '1.82781',
#    '35.91101',
#    '13.87531']},
#  'proxy': {'date': '2026-02-28T06:00:00.000',
#   'name': 'Morningstar US Corp Bd TR USD',
#   'schedule': ['19.88952',
#    '19.73076',
#    '10.84247',
#    '15.75790',
#    '5.37776',
#    '6.43836',
#    '18.25890',
#    '3.01135']},
#  'scheduleLabel': ['Maturity1-3Yr%',
#   'Maturity3-5Yr%',
#   'Maturity5-7Yr%',
#   'Maturity7-10Yr%',
#   'Maturity10-15Yr%',
#   'Maturity15-20Yr%',
#   'Maturity20-30Yr%',
#   'Maturity30+Yr%']}

# %% [markdown]
# Max Drawdown
#
# Market Volatility Measures
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.maxDrawDown()
# Out:
# {'year': 3,
#  'maxDrawDownAsOfDate': '2026-02-28T06:00:00.000',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'categoryName': 'Large Blend',
#  'peakDate': '2023-08-01T00:00:00.000',
#  'valleyDate': '2023-10-31T00:00:00.000',
#  'duration': 3.0,
#  'inceptionDate': '2000-11-13T06:00:00.000',
#  'calculationBenchmark': 'S&P 500 TR USD',
#  'cur': 'USD',
#  'measureMap': {'fund': {'secId': 'FOUSA00L83',
#    'asOfDate': '2026-02-28T06:00:00.000',
#    'upside': 100.216,
#    'downside': 109.579,
#    'maxDrawDown': -9.0807345266,
#    'peakDate': '2023-08-01T00:00:00.000',
#    'valleyDate': '2023-10-31T00:00:00.000',
#    'duration': 3.0,
#    'isAddExtendedFlag': False},
#   'index': {'secId': 'F00000GWXD',
#    'asOfDate': '2026-02-28T06:00:00.000',
#    'upside': 100.584,
#    'downside': 102.775,
#    'maxDrawDown': -8.390128759,
#    'peakDate': '2023-08-01T00:00:00.000',
#    'valleyDate': '2023-10-31T00:00:00.000',
#    'duration': 3.0,
#    'isAddExtendedFlag': False},
#   'category': {'secId': '$FOCA$LB$$',
#    'asOfDate': '2026-02-28T06:00:00.000',
#    'upside': 93.878,
#    'downside': 104.564,
#    'maxDrawDown': -8.342462906,
#    'peakDate': '2023-08-01T00:00:00.000',
#    'valleyDate': '2023-10-31T00:00:00.000',
#    'duration': 3.0,
#    'isAddExtendedFlag': False}}}

# %% [markdown]
# Comparable funds with MorningStar medal
#
# https://www.morningstar.com/funds/xnas/vtsax/analysis

# %%
funds.medaListComparables()
# Out:
# {'userType': 'Free',
#  'categoryName': 'Large Blend',
#  'secId': 'FOUSA00L83',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'getCategoryId': 'Large Blend',
#  'ticker': 'VTSAX',
#  'categoryMedalist': [{'secId': 'FOUSA00AOK',
#    'endDate': None,
#    'tradingSymbol': 'DFUSX',
#    'legalName': 'DFA U.S. Large Company Portfolio',
#    'name': 'DFA US Large Company I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '12995341609',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 12995341609.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000LZSI',
#    'endDate': None,
#    'tradingSymbol': 'FXAIX',
#    'legalName': 'Fidelity 500 Index Fund',
#    'name': 'Fidelity 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '749107075784',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 749107075784.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Y8H0',
#    'endDate': None,
#    'tradingSymbol': 'FDFIX',
#    'legalName': 'Fidelity Flex 500 Index Fund',
#    'name': 'Fidelity Flex 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '8147468390',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 8147468390.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000WCQA',
#    'endDate': None,
#    'tradingSymbol': 'FLCPX',
#    'legalName': 'Fidelity SAI U.S. Large Cap Index Fund',
#    'name': 'Fidelity SAI US Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '15423509175',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 15423509175.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000011YJJ',
#    'endDate': None,
#    'tradingSymbol': 'FCFMX',
#    'legalName': 'Fidelity Series Total Market Index Fund',
#    'name': 'Fidelity Series Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '98703646258',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 98703646258.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000MJS0',
#    'endDate': None,
#    'tradingSymbol': 'FSKAX',
#    'legalName': 'Fidelity Total Market Index Fund',
#    'name': 'Fidelity Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '124713226676',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 124713226676.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000010QVC',
#    'endDate': None,
#    'tradingSymbol': 'FNILX',
#    'legalName': 'Fidelity ZERO Large Cap Index Fund',
#    'name': 'Fidelity ZERO Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '16495148096',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 16495148096.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Y8GT',
#    'endDate': None,
#    'tradingSymbol': 'FZROX',
#    'legalName': 'Fidelity ZERO Total Market Index Fund',
#    'name': 'Fidelity ZERO Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '33731066110',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 33731066110.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Y66G',
#    'endDate': None,
#    'tradingSymbol': 'GSPFX',
#    'legalName': 'Gotham Enhanced S&P 500 Index Fund Institutional Class',
#    'name': 'Gotham Enhanced S&P 500 Index Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '0',
#    'dataCoverage': '98',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '23083405',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 23083405.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 5,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000010SV0',
#    'endDate': None,
#    'tradingSymbol': 'GQEIX',
#    'legalName': 'GQG Partners US Select Quality Equity Fund Institutional Shares',
#    'name': 'GQG Partners US Select Quality Eq Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '2905368015',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2600037997.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00B6B',
#    'endDate': None,
#    'tradingSymbol': 'WFSPX',
#    'legalName': 'iShares S&P 500 Index Fund Class K',
#    'name': 'iShares S&P 500 Index K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '51831161000',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 18475783566.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000015VV2',
#    'endDate': None,
#    'tradingSymbol': 'NWAVX',
#    'legalName': 'Nationwide GQG US Quality Equity Fund Class R6',
#    'name': 'Nationwide GQG US Quality Eq R6',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '257336918',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 203006011.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000XTVA',
#    'endDate': None,
#    'tradingSymbol': 'NUESX',
#    'legalName': 'Northern U.S. Quality ESG Fund Class K',
#    'name': 'Northern US Quality ESG K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '326004256',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 268468560.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00K0Q',
#    'endDate': None,
#    'tradingSymbol': 'SWTSX',
#    'legalName': 'Schwab Total Stock Market Index Fund®',
#    'name': 'Schwab Total Stock Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '37681803874',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 37681803874.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00JLQ',
#    'endDate': None,
#    'tradingSymbol': 'SWPPX',
#    'legalName': 'Schwab® S&P 500 Index Fund',
#    'name': 'Schwab® S&P 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '125856968161',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 125856968161.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000T8Y5',
#    'endDate': None,
#    'tradingSymbol': 'SSEYX',
#    'legalName': 'State Street Equity 500 Index II Portfolio',
#    'name': 'State Street Equity 500 Index II',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '21171255614',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 21171255614.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000ZXDE',
#    'endDate': None,
#    'tradingSymbol': 'FCTDX',
#    'legalName': 'Strategic Advisers Fidelity U.S. Total Stock Fund',
#    'name': 'Strategic Advisers Fidelity US TtlStk',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '220847796440',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 220847796440.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F0000045EO',
#    'endDate': None,
#    'tradingSymbol': 'FSAKX',
#    'legalName': 'Strategic Advisers U.S. Total Stock Fund',
#    'name': 'Strategic Advisers U.S. Total Stock',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '92355068150',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 92355068150.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00EJ4',
#    'endDate': None,
#    'tradingSymbol': 'PRDGX',
#    'legalName': 'T. Rowe Price Dividend Growth Fund',
#    'name': 'T. Rowe Price Dividend Growth',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '24218890030',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 12293851178.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00FUG',
#    'endDate': None,
#    'tradingSymbol': 'VDIGX',
#    'legalName': 'Vanguard Dividend Growth Fund Investor Shares',
#    'name': 'Vanguard Dividend Growth Inv',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '39953552327',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 39953552327.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': 2,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00FR3',
#    'endDate': None,
#    'tradingSymbol': 'VINIX',
#    'legalName': 'Vanguard Institutional Index Fund Institutional Shares',
#    'name': 'Vanguard Institutional Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '333207166840',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 124970235875.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA02T7X',
#    'endDate': None,
#    'tradingSymbol': 'VITPX',
#    'legalName': 'Vanguard Institutional Total Stock Market Index Fund Institutional Plus Shares',
#    'name': 'Vanguard Instl Ttl Stk Mkt Idx InstlPls',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '31781836585',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 29907134432.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA02TYG',
#    'endDate': None,
#    'tradingSymbol': 'VTCLX',
#    'legalName': 'Vanguard Tax-Managed Capital Appreciation Fund Admiral Shares',
#    'name': 'Vanguard Tax-Managed Capital App Adm',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '27393053458',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 22670672224.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00FUA',
#    'endDate': None,
#    'tradingSymbol': 'WFIOX',
#    'legalName': 'Allspring Index Fund - Class Admin',
#    'name': 'Allspring Index Admin',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1381025482',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 439196311.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000013TAS',
#    'endDate': None,
#    'tradingSymbol': 'AVUSX',
#    'legalName': 'Avantis® U.S. Equity Fund Institutional Class',
#    'name': 'Avantis® U.S. Equity Institutional',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '640283974',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 368382982.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00ER2',
#    'endDate': None,
#    'tradingSymbol': 'DSPIX',
#    'legalName': 'BNY Mellon Institutional S&P 500 Stock Index Fund Class I',
#    'name': 'BNY Mellon Instl S&P 500 Stk Idx I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '90',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1312816717',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1312816717.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00001DJ2I',
#    'endDate': None,
#    'tradingSymbol': 'BBTLX',
#    'legalName': 'Bridge Builder Tax Managed Large Cap Fund',
#    'name': 'Bridge Builder Tax Managed Large Cap',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '45',
#    'dataCoverage': '88',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '7792367688',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 7792367688.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000LL3D',
#    'endDate': None,
#    'tradingSymbol': 'CUSEX',
#    'legalName': 'Capital Group U.S. Equity Fund',
#    'name': 'Capital Group US Equity',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '55',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '400912604',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 400912604.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00001BQAK',
#    'endDate': None,
#    'tradingSymbol': 'CRQSX',
#    'legalName': 'Catholic Responsible Investments Equity Index Fund Institutional Shares',
#    'name': 'Catholic Rspnsbl Invst Equity Idx Ins',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
# ...
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '11438283889',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 1062632125.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 5,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 5,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA0592C',
#    'endDate': None,
#    'tradingSymbol': 'GEQYX',
#    'legalName': 'GuideStone Funds Equity Index Fund Institutional Class',
#    'name': 'GuideStone Funds Equity Index Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '80',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '5920145793',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 4268064566.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA02TLS',
#    'endDate': None,
#    'tradingSymbol': 'HSTAX',
#    'legalName': 'Hartford Stock HLS Fund Class IA',
#    'name': 'Hartford Stock HLS IA',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1141229352',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1049322233.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': 2,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000MB9H',
#    'endDate': None,
#    'tradingSymbol': 'IFPUX',
#    'legalName': 'Independent Franchise Partners US Equity Fund',
#    'name': 'Independent Franchise Partners US Equity',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '55',
#    'dataCoverage': '98',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1565598855',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 1565598855.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 5,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00JVG',
#    'endDate': None,
#    'tradingSymbol': 'SPIDX',
#    'legalName': 'Invesco S&P 500 Index Fund Class Y',
#    'name': 'Invesco S&P 500 Index Y',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4149361777',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 629900607.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000LVY9',
#    'endDate': None,
#    'tradingSymbol': 'BRGKX',
#    'legalName': 'iShares Russell 1000 Large-Cap Index Fund Class K',
#    'name': 'iShares Russell 1000 Large-Cap Idx K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1806915962',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 1462139863.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000VW8W',
#    'endDate': None,
#    'tradingSymbol': 'BKTSX',
#    'legalName': 'iShares Total U.S. Stock Market Index Fund Class K',
#    'name': 'iShares Total US Stock Market Idx K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4146865192',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 3651731085.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Z27W',
#    'endDate': None,
#    'tradingSymbol': None,
#    'legalName': 'JNL S&P 500 Index Fund Class I',
#    'name': 'JNL S&P 500 Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '564389180',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 564389180.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Z28N',
#    'endDate': None,
#    'tradingSymbol': None,
#    'legalName': 'JNL/Mellon U.S. Stock Market Index Fund Class I',
#    'name': 'JNL/Mellon US Stock Market Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '10',
#    'dataCoverage': '93',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4608613792',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 72061361.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None}],
#  'primaryMedalist': {'secId': 'FOUSA00L83',
#   'endDate': None,
#   'tradingSymbol': 'VTSAX',
#   'legalName': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'medalistRating': '_PO_',
#   'medalistRatingDate': '_PO_',
#   'parentScoreType': None,
#   'peopleScoreType': None,
#   'processScoreType': None,
#   'parentScore': '_PO_',
#   'peopleScore': '_PO_',
#   'processScore': '_PO_',
#   'priceScore': None,
#   'parentScoreLabel': 'HIGH',
#   'peopleScoreLabel': 'ABOVE_AVERAGE',
#   'processScoreLabel': 'HIGH',
#   'medalistRatingLabel': 'GOLD',
#   'analystDriven': '100',
#   'dataCoverage': '100',
#   'analystRating': None,
#   'overallMorningstarRating': 3,
#   'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#   'ePUsedForOverallRating': None,
#   'trailingYearToDateReturn': None,
#   'trailing1YearReturn': None,
#   'trailing3YearReturn': None,
#   'trailing5YearReturn': None,
#   'ePUsedFor1YearReturn': None,
#   'ePUsedFor5YearReturn': None,
#   'ePUsedFor3YearReturn': None,
#   'expenseRatio': None,
#   'managementExpenseRatio': None,
#   'ongoingCharge': None,
#   'baseCurrencyId': 'USD',
#   'tNAInShareClassCurrency': '2088924581446',
#   'flow1Yr': None,
#   'fundShareClassTypeId': '6',
#   'fundShareClassTypeName': 'Inst',
#   'lastShareClassNetAsset': 448062080139.0,
#   'SecurityType': 'FO',
#   'morningstarRatingFor3Year': 3,
#   'morningstarRatingFor5Year': 3,
#   'morningstarRatingFor10Year': 3,
#   'process': None,
#   'people': None,
#   'parent': None,
#   'sustainabilityFundQuintile': 2,
#   'isLowCarbon': 'false',
#   'isDesignatedLowCarbon': None,
#   'domicileCountryId': 'USA',
#   'hasIssuerRating': None,
#   'disclosureCodes': None}}

# %% [markdown]
# Meta Data

# %%
funds.metaData()
# Out:
# {'secId': 'FOUSA00L83',
#  'fundId': 'FSUSA002PT',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'tradingSymbol': 'VTSAX',
#  'performanceId': '0P00002YGZ',
#  'masterPortfolioId': '3506',
#  'isin': 'US9229087286',
#  'securityType': 'FO',
#  'shortCountryId': 'USA',
#  'categoryId': '$FOCA$LB$$',
#  'domicileCountryId': 'USA',
#  'fundShareClassId': 'FOUSA00L83',
#  'assetType': 'EQUITY',
#  'quoteTemplate': 'OE_USA_EQUITY',
#  'quoteTemplateForEtf': None,
#  'securityTemplate': 'USA_OE_EQUITY',
#  'priceTemplate': 'USA_OE',
#  'caFundCode': None,
#  'alternativeFundCodes': None,
#  'selectedFundCode': None,
#  'baseCurrencyId': 'USD',
#  'performanceTemplate': 'OE_USA_EQUITY',
#  'countryId': 'USA',
#  'broadCategoryGroupId': '$BCG$EQUTY',
#  'template': 'Equity',
#  'userType': 'Free',
#  'newAssetType': 'EQUITY',
#  'countryOfSales18': 0,
#  'countryOfSales34': 0,
#  'newStatus': 0,
#  'legalStructure': '08',
#  'fundSubType': None,
#  'taxClassDesignation': None,
#  'is_ltaf': None,
#  'is_eltif': None,
#  'is_reit': None,
#  'is_business_development_company': None,
#  'morningstarIndex': 'Morningstar US Large-Mid TR USD',
#  'morningstarIndexId': 'F00000GWXD',
#  'primaryProspectusBenchmarkIndex': 'CRSP US Total Market TR USD',
#  'primaryProspectusBenchmarkIndexId': 'F00000P7NL',
#  'morningstarCategoryIndex': 'Morningstar US Large-Mid TR USD',
#  'morningstarCategoryIndexId': 'F00000GWXD',
#  'hasParent': True}

# %% [markdown]
# Rating of Analyst

# %%
funds.morningstarAnalyst()
# Out:
# {'morningstarRatingFor3Year': 3,
#  'morningstarRatingFor5Year': 3,
#  'morningstarRatingFor10Year': 3,
#  'overallMorningstarRating': 3,
#  'categoryMedalist': [{'secId': 'FOUSA00AOK',
#    'endDate': None,
#    'tradingSymbol': 'DFUSX',
#    'legalName': 'DFA U.S. Large Company Portfolio',
#    'name': 'DFA US Large Company I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-28T23:33:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '12995341609',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 12995341609.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000LZSI',
#    'endDate': None,
#    'tradingSymbol': 'FXAIX',
#    'legalName': 'Fidelity 500 Index Fund',
#    'name': 'Fidelity 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-29T01:50:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '749107075784',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 749107075784.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Y8H0',
#    'endDate': None,
#    'tradingSymbol': 'FDFIX',
#    'legalName': 'Fidelity Flex 500 Index Fund',
#    'name': 'Fidelity Flex 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-29T01:50:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '8147468390',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 8147468390.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000WCQA',
#    'endDate': None,
#    'tradingSymbol': 'FLCPX',
#    'legalName': 'Fidelity SAI U.S. Large Cap Index Fund',
#    'name': 'Fidelity SAI US Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-29T01:50:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '15423509175',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 15423509175.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000011YJJ',
#    'endDate': None,
#    'tradingSymbol': 'FCFMX',
#    'legalName': 'Fidelity Series Total Market Index Fund',
#    'name': 'Fidelity Series Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '98703646258',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 98703646258.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000MJS0',
#    'endDate': None,
#    'tradingSymbol': 'FSKAX',
#    'legalName': 'Fidelity Total Market Index Fund',
#    'name': 'Fidelity Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '124713226676',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 124713226676.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000010QVC',
#    'endDate': None,
#    'tradingSymbol': 'FNILX',
#    'legalName': 'Fidelity ZERO Large Cap Index Fund',
#    'name': 'Fidelity ZERO Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '16495148096',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 16495148096.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Y8GT',
#    'endDate': None,
#    'tradingSymbol': 'FZROX',
#    'legalName': 'Fidelity ZERO Total Market Index Fund',
#    'name': 'Fidelity ZERO Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '33731066110',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 33731066110.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Y66G',
#    'endDate': None,
#    'tradingSymbol': 'GSPFX',
#    'legalName': 'Gotham Enhanced S&P 500 Index Fund Institutional Class',
#    'name': 'Gotham Enhanced S&P 500 Index Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '0',
#    'dataCoverage': '98',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '23083405',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 23083405.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 5,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000010SV0',
#    'endDate': None,
#    'tradingSymbol': 'GQEIX',
#    'legalName': 'GQG Partners US Select Quality Equity Fund Institutional Shares',
#    'name': 'GQG Partners US Select Quality Eq Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-20T17:02:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '2905368015',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2600037997.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00B6B',
#    'endDate': None,
#    'tradingSymbol': 'WFSPX',
#    'legalName': 'iShares S&P 500 Index Fund Class K',
#    'name': 'iShares S&P 500 Index K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-28T23:49:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '51831161000',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 18475783566.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000015VV2',
#    'endDate': None,
#    'tradingSymbol': 'NWAVX',
#    'legalName': 'Nationwide GQG US Quality Equity Fund Class R6',
#    'name': 'Nationwide GQG US Quality Eq R6',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '257336918',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 203006011.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000XTVA',
#    'endDate': None,
#    'tradingSymbol': 'NUESX',
#    'legalName': 'Northern U.S. Quality ESG Fund Class K',
#    'name': 'Northern US Quality ESG K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '326004256',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 268468560.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00K0Q',
#    'endDate': None,
#    'tradingSymbol': 'SWTSX',
#    'legalName': 'Schwab Total Stock Market Index Fund®',
#    'name': 'Schwab Total Stock Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-29T04:04:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '37681803874',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 37681803874.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00JLQ',
#    'endDate': None,
#    'tradingSymbol': 'SWPPX',
#    'legalName': 'Schwab® S&P 500 Index Fund',
#    'name': 'Schwab® S&P 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '125856968161',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 125856968161.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000T8Y5',
#    'endDate': None,
#    'tradingSymbol': 'SSEYX',
#    'legalName': 'State Street Equity 500 Index II Portfolio',
#    'name': 'State Street Equity 500 Index II',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-29T02:41:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '21171255614',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 21171255614.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000ZXDE',
#    'endDate': None,
#    'tradingSymbol': 'FCTDX',
#    'legalName': 'Strategic Advisers Fidelity U.S. Total Stock Fund',
#    'name': 'Strategic Advisers Fidelity US TtlStk',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '220847796440',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 220847796440.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F0000045EO',
#    'endDate': None,
#    'tradingSymbol': 'FSAKX',
#    'legalName': 'Strategic Advisers U.S. Total Stock Fund',
#    'name': 'Strategic Advisers U.S. Total Stock',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '92355068150',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 92355068150.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00EJ4',
#    'endDate': None,
#    'tradingSymbol': 'PRDGX',
#    'legalName': 'T. Rowe Price Dividend Growth Fund',
#    'name': 'T. Rowe Price Dividend Growth',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-04-02T19:41:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '24218890030',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 12293851178.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00FUG',
#    'endDate': None,
#    'tradingSymbol': 'VDIGX',
#    'legalName': 'Vanguard Dividend Growth Fund Investor Shares',
#    'name': 'Vanguard Dividend Growth Inv',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-04-01T19:55:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '39953552327',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '7',
#    'fundShareClassTypeName': 'Inv',
#    'lastShareClassNetAsset': 39953552327.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': 2,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00FR3',
#    'endDate': None,
#    'tradingSymbol': 'VINIX',
#    'legalName': 'Vanguard Institutional Index Fund Institutional Shares',
#    'name': 'Vanguard Institutional Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-27T01:44:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '333207166840',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 124970235875.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA02T7X',
#    'endDate': None,
#    'tradingSymbol': 'VITPX',
#    'legalName': 'Vanguard Institutional Total Stock Market Index Fund Institutional Plus Shares',
#    'name': 'Vanguard Instl Ttl Stk Mkt Idx InstlPls',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-02-12T02:20:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '31781836585',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 29907134432.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA02TYG',
#    'endDate': None,
#    'tradingSymbol': 'VTCLX',
#    'legalName': 'Vanguard Tax-Managed Capital Appreciation Fund Admiral Shares',
#    'name': 'Vanguard Tax-Managed Capital App Adm',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-02-12T00:52:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '27393053458',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 22670672224.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00FUA',
#    'endDate': None,
#    'tradingSymbol': 'WFIOX',
#    'legalName': 'Allspring Index Fund - Class Admin',
#    'name': 'Allspring Index Admin',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1381025482',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 439196311.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F000013TAS',
#    'endDate': None,
#    'tradingSymbol': 'AVUSX',
#    'legalName': 'Avantis® U.S. Equity Fund Institutional Class',
#    'name': 'Avantis® U.S. Equity Institutional',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-05-20T15:29:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '640283974',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 368382982.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00ER2',
#    'endDate': None,
#    'tradingSymbol': 'DSPIX',
#    'legalName': 'BNY Mellon Institutional S&P 500 Stock Index Fund Class I',
#    'name': 'BNY Mellon Instl S&P 500 Stk Idx I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '90',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1312816717',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1312816717.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00001DJ2I',
#    'endDate': None,
#    'tradingSymbol': 'BBTLX',
#    'legalName': 'Bridge Builder Tax Managed Large Cap Fund',
#    'name': 'Bridge Builder Tax Managed Large Cap',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '45',
#    'dataCoverage': '88',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '7792367688',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 7792367688.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000LL3D',
#    'endDate': None,
#    'tradingSymbol': 'CUSEX',
#    'legalName': 'Capital Group U.S. Equity Fund',
#    'name': 'Capital Group US Equity',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '55',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '400912604',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 400912604.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
# ...
#    'legalName': 'Hartford Stock HLS Fund Class IA',
#    'name': 'Hartford Stock HLS IA',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2025-04-01T19:55:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1141229352',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1049322233.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': 2,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 4,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000MB9H',
#    'endDate': None,
#    'tradingSymbol': 'IFPUX',
#    'legalName': 'Independent Franchise Partners US Equity Fund',
#    'name': 'Independent Franchise Partners US Equity',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '55',
#    'dataCoverage': '98',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1565598855',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 1565598855.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 5,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00JVG',
#    'endDate': None,
#    'tradingSymbol': 'SPIDX',
#    'legalName': 'Invesco S&P 500 Index Fund Class Y',
#    'name': 'Invesco S&P 500 Index Y',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4149361777',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 629900607.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000LVY9',
#    'endDate': None,
#    'tradingSymbol': 'BRGKX',
#    'legalName': 'iShares Russell 1000 Large-Cap Index Fund Class K',
#    'name': 'iShares Russell 1000 Large-Cap Idx K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-02-12T00:02:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1806915962',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 1462139863.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000VW8W',
#    'endDate': None,
#    'tradingSymbol': 'BKTSX',
#    'legalName': 'iShares Total U.S. Stock Market Index Fund Class K',
#    'name': 'iShares Total US Stock Market Idx K',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4146865192',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 3651731085.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Z27W',
#    'endDate': None,
#    'tradingSymbol': None,
#    'legalName': 'JNL S&P 500 Index Fund Class I',
#    'name': 'JNL S&P 500 Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '564389180',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 564389180.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None},
#   {'secId': 'F00000Z28N',
#    'endDate': None,
#    'tradingSymbol': None,
#    'legalName': 'JNL/Mellon U.S. Stock Market Index Fund Class I',
#    'name': 'JNL/Mellon US Stock Market Index I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-01-31T06:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': None,
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'SILVER',
#    'analystDriven': '10',
#    'dataCoverage': '93',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4608613792',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 72061361.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'hasIssuerRating': None,
#    'disclosureCodes': None}],
#  'primaryMedalist': {'secId': 'FOUSA00L83',
#   'endDate': None,
#   'tradingSymbol': 'VTSAX',
#   'legalName': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'medalistRating': '_PO_',
#   'medalistRatingDate': '2026-02-12T02:20:00.000',
#   'parentScoreType': None,
#   'peopleScoreType': None,
#   'processScoreType': None,
#   'parentScore': '_PO_',
#   'peopleScore': '_PO_',
#   'processScore': '_PO_',
#   'priceScore': None,
#   'parentScoreLabel': 'HIGH',
#   'peopleScoreLabel': 'ABOVE_AVERAGE',
#   'processScoreLabel': 'HIGH',
#   'medalistRatingLabel': 'GOLD',
#   'analystDriven': '100',
#   'dataCoverage': '100',
#   'analystRating': None,
#   'overallMorningstarRating': 3,
#   'overallMorningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#   'ePUsedForOverallRating': None,
#   'trailingYearToDateReturn': None,
#   'trailing1YearReturn': None,
#   'trailing3YearReturn': None,
#   'trailing5YearReturn': None,
#   'ePUsedFor1YearReturn': None,
#   'ePUsedFor5YearReturn': None,
#   'ePUsedFor3YearReturn': None,
#   'expenseRatio': None,
#   'managementExpenseRatio': None,
#   'ongoingCharge': None,
#   'baseCurrencyId': 'USD',
#   'tNAInShareClassCurrency': '2088924581446',
#   'flow1Yr': None,
#   'fundShareClassTypeId': '6',
#   'fundShareClassTypeName': 'Inst',
#   'lastShareClassNetAsset': 448062080139.0,
#   'SecurityType': 'FO',
#   'morningstarRatingFor3Year': 3,
#   'morningstarRatingFor5Year': 3,
#   'morningstarRatingFor10Year': 3,
#   'process': None,
#   'people': None,
#   'parent': None,
#   'sustainabilityFundQuintile': 2,
#   'isLowCarbon': 'false',
#   'isDesignatedLowCarbon': None,
#   'domicileCountryId': 'USA',
#   'hasIssuerRating': None,
#   'disclosureCodes': None},
#  'analystRating': '_PO_',
#  'analystRatingDate': '2023-03-06 00:00:00.0',
#  'morningstarRatingDate': '2026-02-28 00:00:00.0',
#  'history': [{'date': '2023-03-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-04-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-05-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-06-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-07-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-08-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-09-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-10-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-11-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-12-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-01-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-02-29T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-03-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-04-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-05-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-06-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-07-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-08-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-09-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-10-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-11-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-12-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-01-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-02-28T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-03-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-04-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-05-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-06-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-07-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-08-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-09-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-10-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-11-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-12-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2026-01-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2026-02-28T00:00:00.000', 'rating': '_PO_'}],
#  'userType': 'Free',
#  'categoryName': 'US Fund Large Blend',
#  'flagshipShareClassID': None,
#  'flagshipName': None,
#  'isAusFlagship': False,
#  'quantHistory': [],
#  'quantRating': None,
#  'quantRatingDate': None}

# %% [markdown]
# Morningstar’s Analysis - Our Take
#
# https://www.morningstar.com/funds/xnas/vtsax/analysis

# %%
funds.morningstarOpinion()
# Out:
# {'analysis': {'authorId': 2835,
#   'title': 'A one-stop shop for all US stocks.',
#   'publishDate': '2026-02-11T20:20:00.000',
#   'scorePublishDate': '2026-02-11T20:20:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'process': {'authorId': 2835,
#   'title': 'This fund holds a representative basket of the expansive CRSP US Total Market Index, which efficiently captures the US stock market, earning it a High Process Pillar rating.',
#   'publishDate': '2026-02-11T20:20:00.000',
#   'scorePublishDate': '2026-02-11T20:20:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'parent': {'authorId': 2118,
#   'title': 'Vanguard maintains its High Parent Pillar rating as it continues to grow under new leadership.',
#   'publishDate': '2025-07-28T11:24:00.000',
#   'scorePublishDate': '2025-07-28T11:24:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Daniel Sotiroff',
#   'content': None,
#   'authorTitle': 'Senior Analyst'},
#  'people': {'authorId': 2835,
#   'title': "Vanguard's equity index group earns an Above Average People Pillar for a well-supported and stable management team that's adept at leveraging Vanguard's comprehensive resources.",
#   'publishDate': '2026-02-11T20:20:00.000',
#   'scorePublishDate': '2026-02-11T20:20:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'price': {'authorId': 2835,
#   'title': "It's critical to evaluate expenses, as they come directly out of returns.",
#   'publishDate': '2026-02-11T20:20:00.000',
#   'scorePublishDate': '2026-02-11T20:20:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'performance': {'authorId': 2835,
#   'title': 'The CRSP US Total Market Index returned 14.3% annualized over the past 10 years through 2025.',
#   'publishDate': '2026-02-11T20:20:00.000',
#   'scorePublishDate': '2026-02-11T20:20:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'reasonMissing': None,
#  'notes': None,
#  'recentNotes': {'authorId': None,
#   'title': 'Vanguard Cuts Fees for Small Investors',
#   'publishDate': '2018-11-19T06:00:00Z',
#   'scorePublishDate': None,
#   'ratingScale': None,
#   'rating': None,
#   'ratingType': None,
#   'authorName': 'Alex Bryan',
#   'content': ["On Nov. 19, Vanguard announced it is cutting the investment minimums for the Admiral share class of 38 of its index funds, including this one. The investment minimum for the affected funds will now be $3,000 versus $10,000 previously. The Investor share classes of these funds were closed to new investors, effective Nov. 19, 2018. According to Vanguard, qualifying clients can convert to Admiral shares by visiting the company's website. Any remaining investors in the Investor share class of these funds will be automatically converted to the Admiral share class beginning in the second quarter of 2019.",
#    "This move is in response to intensifying competitive pressure from Schwab and Fidelity, which have both recently zeroed out investment minimums and streamlined their existing index fund lineups into single low-cost share classes. It is an improvement that is long overdue, as Vanguard's Investor share classes tended to charge fees that were a multiple of those levied by the Admiral shares classes. Consequently, these changes resulted in considerable fee cuts for smaller investors. However, they are immaterial to our Morningstar Analyst Ratings for any of the affected funds--all of which remain unchanged."],
#   'authorTitle': None},
#  'processText': ['This fund holds a representative basket of the expansive CRSP US Total Market Index, which efficiently captures the US stock market, earning it a High Process Pillar rating.'],
#  'portfolioText': ['The CRSP US Total Market Index includes all US stocks that pass its eligibility screen and weights them by market cap. Stocks must meet minimum market-cap and liquidity requirements for initial inclusion and less stringent requirements for ongoing inclusion. It spreads the rebalancing process over five days to reduce potential market impact costs. The index is reconstituted quarterly.',
#   '',
#   'Market-cap-weighting is a sensible approach for the US stock market. Highly traded stocks usually reflect new information quickly, and market-cap weighting requires minimal trading costs, which can detract from returns. It follows the wisdom of crowds and takes the guesswork out of stock selection. The US stock market has historically produced solid long-term gains, and owning nearly the entire market has allowed investors to capitalize on those gains. Should strong market performance continue, the fund is well positioned to reap those rewards.',
#   '',
#   "The index's market-cap weighting tilts it toward the largest and most established names. Companies with wide or narrow Morningstar Economic Moat Ratings dominate the portfolio, showcasing the strategy’s durability. Holding around 3,500 stocks reduces the opportunity cost of missing out on strong performers, too. When a portfolio owns a greater chunk of the US stock universe, it has a better chance of capturing gains from companies that end up driving returns. Concentrated active funds are more likely to miss out if those stocks are excluded from their narrow portfolios.",
#   '',
#   'Large allocations to the biggest names in the US stock market present some concentration risk, but the index simply represents the market. While higher concentration may be a concern for investors, there isn’t a clear relationship between index performance and market concentration. In addition, the largest companies, such as Apple and Microsoft, often have diversified business lines, so they don’t rely on a single product, service, or market to determine company success.'],
#  'ecl': {'sustainabilityDistribution': None, 'assetManager': None},
#  'userType': 'Free',
#  'id': 0,
#  'rpsCovered': True,
#  'isLocalized': False,
#  'shareClassId': 'FOUSA00L83',
#  'isRatingV2': True,
#  'suitability': None,
#  'fundamental': None,
#  'fees': None,
#  'portfolioConstruction': None,
#  'alternatives': None,
#  'analystDrivenPortion': '100',
#  'dataCoverage': '100',
#  'translationautomated': False,
#  'disclosureCodes': None,
#  'disclosureDescriptions': None,
#  'hasIssuerRating': False,
#  'issuerDisclosure': None}

# %% [markdown]
# Fixed Income Exposure Analysis
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.multiLevelFixedIncomeData()
# Out:
# {'fundName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'assetType': 'FIXEDINCOME',
#  'asOfDate': '2026-01-31T00:00:00.000',
#  'primary': 'superEffectiveDuration',
#  'secondary': 'superSector',
#  'data': [{'secondaryAttributeName': 'Government',
#    'weight': 15.0751,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.07766,
#     '1 to 3%': 5.42385,
#     '3 to 5%': 3.83467,
#     '5 to 7%': 2.12716,
#     '7 to 10%': 1.10851,
#     '10 to 20%': 2.13317,
#     'Greater than 20%': None,
#     'Unknown': 0.37008,
#     'Not Applicable': None,
#     'weight': 15.0751}},
#   {'secondaryAttributeName': 'Municipal',
#    'weight': 1.11778,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.01207,
#     '1 to 3%': 0.12368,
#     '3 to 5%': 0.08193,
#     '5 to 7%': 0.09201,
#     '7 to 10%': 0.32702,
#     '10 to 20%': 0.47527,
#     'Greater than 20%': None,
#     'Unknown': 0.00581,
#     'Not Applicable': None,
#     'weight': 1.11778}},
#   {'secondaryAttributeName': 'Corporate',
#    'weight': 80.75893,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.78857,
#     '1 to 3%': 20.01555,
#     '3 to 5%': 16.8649,
#     '5 to 7%': 14.49775,
#     '7 to 10%': 8.43975,
#     '10 to 20%': 19.27147,
#     'Greater than 20%': None,
#     'Unknown': 0.88094,
#     'Not Applicable': None,
#     'weight': 80.75893}},
#   {'secondaryAttributeName': 'Securitized',
#    'weight': 2.97024,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.30242,
#     '1 to 3%': 1.08842,
#     '3 to 5%': 0.60068,
#     '5 to 7%': 0.37266,
#     '7 to 10%': 0.14972,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': 0.45634,
#     'Not Applicable': None,
#     'weight': 2.97024}},
#   {'secondaryAttributeName': 'Derivatives',
#    'weight': None,
#    'primaryData': {'Negative': None,
#     '0 to 1%': None,
#     '1 to 3%': None,
#     '3 to 5%': None,
#     '5 to 7%': None,
#     '7 to 10%': None,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': None,
#     'Not Applicable': None,
#     'weight': None}},
#   {'secondaryAttributeName': 'Cash & Equivalents',
#    'weight': None,
#    'primaryData': {'Negative': None,
#     '0 to 1%': None,
#     '1 to 3%': None,
#     '3 to 5%': None,
#     '5 to 7%': None,
#     '7 to 10%': None,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': None,
#     'Not Applicable': None,
#     'weight': None}},
#   {'secondaryAttributeName': 'Unknown',
#    'weight': 0.07795,
#    'primaryData': {'Negative': None,
#     '0 to 1%': None,
#     '1 to 3%': None,
#     '3 to 5%': None,
#     '5 to 7%': None,
#     '7 to 10%': None,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': 0.07795,
#     'Not Applicable': None,
#     'weight': 0.07795}}]}

# %% [markdown]
# Historical Net Asset Value and Total Return
#
# Fund Chart
#
# https://www.morningstar.com/funds/xnas/vtsax/chart

# %%
import datetime
end_date = datetime.datetime.today()
start_date = end_date - datetime.timedelta(30)
funds.nav(start_date,end_date)
# Out:
# [{'nav': 163.59, 'totalReturn': 254.81109, 'date': '2026-02-12'},
#  {'nav': 163.89, 'totalReturn': 255.27838, 'date': '2026-02-13'},
#  {'nav': 164.06, 'totalReturn': 255.54318, 'date': '2026-02-17'},
#  {'nav': 164.99, 'totalReturn': 256.99176, 'date': '2026-02-18'},
#  {'nav': 164.64, 'totalReturn': 256.4466, 'date': '2026-02-19'},
#  {'nav': 165.62, 'totalReturn': 257.97306, 'date': '2026-02-20'},
#  {'nav': 163.74, 'totalReturn': 255.04474, 'date': '2026-02-23'},
#  {'nav': 165.1, 'totalReturn': 257.1631, 'date': '2026-02-24'},
#  {'nav': 166.39, 'totalReturn': 259.17243, 'date': '2026-02-25'},
#  {'nav': 165.76, 'totalReturn': 258.19113, 'date': '2026-02-26'},
#  {'nav': 164.91, 'totalReturn': 256.86715, 'date': '2026-02-27'},
#  {'nav': 165.12, 'totalReturn': 257.19425, 'date': '2026-03-02'},
#  {'nav': 163.42, 'totalReturn': 254.5463, 'date': '2026-03-03'},
#  {'nav': 164.67, 'totalReturn': 256.49332, 'date': '2026-03-04'},
#  {'nav': 163.6, 'totalReturn': 254.82667, 'date': '2026-03-05'},
#  {'nav': 161.36, 'totalReturn': 251.3376, 'date': '2026-03-06'},
#  {'nav': 162.75, 'totalReturn': 253.50269, 'date': '2026-03-09'},
#  {'nav': 162.35, 'totalReturn': 252.87965, 'date': '2026-03-10'},
#  {'nav': 162.22, 'totalReturn': 252.67715, 'date': '2026-03-11'},
#  {'nav': 159.64, 'totalReturn': 248.65849, 'date': '2026-03-12'},
#  {'nav': 158.75, 'totalReturn': 247.27221, 'date': '2026-03-13'}]

# %% [markdown]
# Other fees
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.otherFee()
# Out:
# {'actualManagementFee': 0.04,
#  'maximumManagementFee': 0.04,
#  'actual12b1': None,
#  'administrativeFee': 0.03394,
#  'expenseWaivers': None,
#  'performanceFee': None,
#  'fundSubType': None,
#  'PerformanceFeeCharged': None,
#  'FeeNegotiable': None}

# %% [markdown]
# Ownership zone
#
# Style box - map
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.ownershipZone()
# Out:
# {'portfolioDate': '2026-01-31T06:00:00.000',
#  'fund': {'portfolioDate': '2026-01-31T06:00:00.000',
#   'scaledSizeScore': 271.687,
#   'scaledStyleScore': 149.707,
#   'sizeVariance': 115.029,
#   'styleVariance': 131.376,
#   'rho': 0.221,
#   'secId': 'FOUSA00L83',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'objectZone75Percentile': 2.705},
#  'benchmark': {'portfolioDate': '2026-02-28T06:00:00.000',
#   'scaledSizeScore': 299.614,
#   'scaledStyleScore': 148.52,
#   'sizeVariance': 92.499,
#   'styleVariance': 130.963,
#   'rho': 0.268,
#   'secId': 'F00000GWXD',
#   'name': 'Morningstar US Large-Mid TR USD',
#   'objectZone75Percentile': 2.884},
#  'category': {'portfolioDate': '2026-01-31T06:00:00.000',
#   'scaledSizeScore': 309.654,
#   'scaledStyleScore': 146.359,
#   'sizeVariance': 96.426,
#   'styleVariance': 129.5,
#   'rho': 0.252,
#   'secId': '$FOCA$LB$$',
#   'name': 'Large Blend',
#   'objectZone75Percentile': 2.466}}

# %% [markdown]
# Rating of top rated medalists funds of the asset manager
#
# Rating Breakdown - Medalist Rating
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentMedal()
# Out:
# {'userType': 'Free',
#  'analystRatingFundList': [{'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': None,
#    'calendarYearFlow': 18721399518.0,
#    'netAsset': 877945594480.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 20.9307,
#    'trailing3YearReturnRank': 40.0,
#    'fundShareClassId': 'F00000VE7X',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA002PT',
#    'secId': 'F00000VE7X',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': None,
#    'calendarYearFlow': -30593220008.0,
#    'netAsset': 631465941078.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 21.75376,
#    'trailing3YearReturnRank': 24.0,
#    'fundShareClassId': 'FOUSA00L8W',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA002QH',
#    'secId': 'FOUSA00L8W',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': None,
#    'calendarYearFlow': -20067948877.0,
#    'netAsset': 270609179567.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 19.73698,
#    'trailing3YearReturnRank': 34.0,
#    'fundShareClassId': 'FOUSA00KIR',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA004JJ',
#    'secId': 'FOUSA00KIR',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': None,
#    'calendarYearFlow': -11475564193.0,
#    'netAsset': 208236930965.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 21.77842,
#    'trailing3YearReturnRank': 23.0,
#    'fundShareClassId': 'FOUSA00GPG',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA002Q0',
#    'secId': 'FOUSA00GPG',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': None,
#    'calendarYearFlow': 24839221053.0,
#    'netAsset': 201318808012.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 5.10535,
#    'trailing3YearReturnRank': 53.0,
#    'fundShareClassId': 'FOUSA08OZU',
#    'name': '_PO_',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'fundId': 'FSUSA09PA2',
#    'secId': 'FOUSA08OZU',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2026-02-28T06:00:00.000',
#  'footerReturnDate': '2026-02-28T06:00:00.000',
#  'currency': 'USD',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Breakdown of asset manager funds by medalist rating
#
# Rating Breakdown - Medalist Rating
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentMedaListRating()
# Out:
# [{'rating': None,
#   'medalistRating': '7',
#   'medalistRatingLabel': 'GOLD',
#   'shareClassCount': 102,
#   'percent': 0.738562066,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '6',
#   'medalistRatingLabel': 'SILVER',
#   'shareClassCount': 113,
#   'percent': 0.1745621105,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '5',
#   'medalistRatingLabel': 'BRONZE',
#   'shareClassCount': 45,
#   'percent': 0.0826941971,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '4',
#   'medalistRatingLabel': 'NEUTRAL',
#   'shareClassCount': 9,
#   'percent': 0.0041816264,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '3',
#   'medalistRatingLabel': 'NEGATIVE',
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '2',
#   'medalistRatingLabel': 'UNDER_REVIEW',
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False}]

# %% [markdown]
# Breakdown of asset manager funds by star rating
#
# Rating Breakdown - Morningstar Rating
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentMstarRating()
# Out:
# [{'naPercentage': 0.0007533454, 'mstarRating': '1'},
#  {'naPercentage': 0.0537545477, 'mstarRating': '2'},
#  {'naPercentage': 0.4978326254, 'mstarRating': '3'},
#  {'naPercentage': 0.417830566, 'mstarRating': '4'},
#  {'naPercentage': 0.0276017743, 'mstarRating': '5'},
#  {'naPercentage': 0.0022271412, 'mstarRating': 'Not Rated'}]

# %% [markdown]
# Recent change in rating
#
# Rating Breakdown - Medalist List - Recent Investment Ratings Change
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentRatingRecentChange()
# Out:
# {'topAnalystRatingUpDownList': [{'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '5',
#    'medalistPrevRating': '5',
#    'currRatingDisclosureCodes': None,
#    'medalistCurrRatingLabel': 'BRONZE',
#    'medalistPrevRatingLabel': 'BRONZE',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-03-11T05:00:00.000',
#    'medalistPrevRatingDate': '2025-03-13T13:51:00.000',
#    'netAsset': 38037634662.0,
#    'fundId': 'FSUSA001QL',
#    'securityType': 'FO',
#    'secId': 'FOUSA02SM8'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '6',
#    'medalistPrevRating': '6',
#    'currRatingDisclosureCodes': None,
#    'medalistCurrRatingLabel': 'SILVER',
#    'medalistPrevRatingLabel': 'SILVER',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-03-12T05:00:00.000',
#    'medalistPrevRatingDate': '2025-04-10T18:12:00.000',
#    'netAsset': 1815311686.0,
#    'fundId': 'FSUSA09LOL',
#    'securityType': 'FO',
#    'secId': 'F000011IZM'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '6',
#    'medalistPrevRating': '6',
#    'currRatingDisclosureCodes': None,
#    'medalistCurrRatingLabel': 'SILVER',
#    'medalistPrevRatingLabel': 'SILVER',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-03-12T05:00:00.000',
#    'medalistPrevRatingDate': '2025-06-24T20:25:00.000',
#    'netAsset': 104586110824.0,
#    'fundId': 'FSUSA002PJ',
#    'securityType': 'FO',
#    'secId': 'FOUSA02TYI'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '5',
#    'medalistPrevRating': '5',
#    'currRatingDisclosureCodes': None,
#    'medalistCurrRatingLabel': 'BRONZE',
#    'medalistPrevRatingLabel': 'BRONZE',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-03-12T05:00:00.000',
#    'medalistPrevRatingDate': '2025-06-24T20:25:00.000',
#    'netAsset': 174591411089.0,
#    'fundId': 'FSUSA09PA2',
#    'securityType': 'FO',
#    'secId': 'FOUSA08OZT'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '5',
#    'medalistPrevRating': '5',
#    'currRatingDisclosureCodes': None,
#    'medalistCurrRatingLabel': 'BRONZE',
#    'medalistPrevRatingLabel': 'BRONZE',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-03-09T05:00:00.000',
#    'medalistPrevRatingDate': '2025-03-11T16:35:00.000',
#    'netAsset': 38846917257.0,
#    'fundId': 'FSUSA002QD',
#    'securityType': 'FO',
#    'secId': 'FOUSA02SL6'}],
#  'userType': 'Free',
#  'currency': 'USD',
#  'securityType': 'FO',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'secId': 'FOUSA00L83',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Information about the asset manager
#
# Parent
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentSummary()
# Out:
# {'secId': 'FOUSA00L83',
#  'fundId': 'FSUSA002PT',
#  'companyId': '0C00001YUF',
#  'marketName': 'US Open-end ex MM ex FoF ex Feeder',
#  'firmName': 'Vanguard',
#  'currency': 'USD',
#  'netAsset': 6201154026384.0,
#  'netFlowTTM': -162884467180.0,
#  'netAssetTTM': 5731884454830.0,
#  'assetGrowthRate': -0.0284172629,
#  'numFund': 149,
#  'managerRetention5Year': 91.66,
#  'template': 'USA_OE',
#  'domicileCountryId': 'USA'}

# %% [markdown]
# People who manage the fund
#
# Management Team
#
# https://www.morningstar.com/funds/xnas/vtsax/people

# %%
funds.people()
# Out:
# {'inceptionDate': '2000-11-13T06:00:00.000',
#  'averageManagerTenure': 4.69,
#  'longestManagerTenure': 9.92,
#  'advisorType': 'Vanguard Group Inc',
#  'subadvised': '0',
#  'managerCount': 3,
#  'womenOnTeams': 33.01,
#  'advisorList': [{'advisorId': '0C00001G3E',
#    'advisorDisplayName': 'Vanguard Group Inc',
#    'regionId': None,
#    'languageId': None,
#    'subAdvisorId': None,
#    'subAdvisorName': None}],
#  'subAdvisorList': [],
#  'currentManagerList': [{'personId': '168359',
#    'familyName': 'Nejman',
#    'middleName': None,
#    'givenName': 'Walter',
#    'startDate': '2016-04-27T05:00:00.000',
#    'ownershipLevelId': '1',
#    'endDate': None,
#    'gender': 'male',
#    'genderSourceType': 'reported'},
#   {'personId': '182724',
#    'familyName': 'Louie',
#    'middleName': None,
#    'givenName': 'Michelle',
#    'startDate': '2023-02-17T06:00:00.000',
#    'ownershipLevelId': '7',
#    'endDate': None,
#    'gender': 'female',
#    'genderSourceType': 'derived'},
#   {'personId': '205451',
#    'familyName': 'Birkett',
#    'middleName': None,
#    'givenName': 'Nick',
#    'startDate': '2025-02-18T06:00:00.000',
#    'ownershipLevelId': '1',
#    'endDate': None,
#    'gender': 'male',
#    'genderSourceType': 'derived'}],
#  'pastManagerList': [{'personId': '1597',
#    'familyName': 'Sauter',
#    'middleName': 'U.',
#    'givenName': 'George',
#    'startDate': '1992-04-27T05:00:00.000',
#    'ownershipLevelId': None,
#    'endDate': '2005-04-29T05:00:00.000',
#    'gender': 'male',
#    'genderSourceType': 'reported'},
#   {'personId': '98675',
#    'familyName': 'O’Reilly',
#    'middleName': 'C.',
#    'givenName': 'Gerard',
#    'startDate': '1994-12-31T06:00:00.000',
#    'ownershipLevelId': '6',
#    'endDate': '2025-06-18T05:00:00.000',
#    'gender': 'male',
#    'genderSourceType': 'reported'}],
#  'lastTurnoverRatio': 0.03,
#  'longestTenureStartDate': '2016-04-27'}

# %% [markdown]
# Performance of the fund, category and index by year
#
# Annual Returns
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.performanceTable()
# Out:
# {'userType': 'Free',
#  'baseCurrency': 'USD',
#  'domicileCountryId': 'USA',
#  'asOfDate': '2026-03-13T00:00:00.000',
#  'startDate': '2016-01-01T00:00:00.000',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'table': {'columnDefs': ['2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    '2025',
#    'YTD'],
#   'growth10KReturnData': [{'label': 'fund',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['12.66422',
#      '21.16927',
#      '-5.1711',
#      '30.80497',
#      '20.98791',
#      '25.71229',
#      '-19.52516',
#      '26.00822',
#      '23.74332',
#      '17.11781',
#      '-2.72672'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'category',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['10.36891',
#      '20.43837',
#      '-6.26928',
#      '28.77649',
#      '15.82748',
#      '26.06759',
#      '-16.95545',
#      '22.31864',
#      '21.44601',
#      '15.54386',
#      '-2.68563'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'index',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['11.58523',
#      '21.71165',
#      '-4.52374',
#      '31.60802',
#      '21.10674',
#      '26.44469',
#      '-19.49782',
#      '26.85193',
#      '25.06815',
#      '17.71047',
#      '-3.04301'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'percentileRank',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['20',
#      '45',
#      '42',
#      '39',
#      '17',
#      '63',
#      '75',
#      '33',
#      '43',
#      '40',
#      '41'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'fundNumber',
#     'endDate': '2026-03-13T00:00:00.000',
#     'datum': ['1409',
#      '1396',
#      '1402',
#      '1387',
#      '1363',
#      '1382',
#      '1358',
#      '1430',
#      '1386',
#      '1314',
#      '1324'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'categoryName',
#     'endDate': None,
#     'datum': ['US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend'],
#     'epFlag': []},
#    {'label': 'categoryNameAbbr',
#     'endDate': None,
#     'datum': ['LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB'],
#     'epFlag': []}]},
#  'currentValues': [{'type': 'fund',
#    'name': 'VTSAX',
#    'baseCurrency': 'USD',
#    'currentValue': '36818.01918236348',
#    'currentSymbol': '$'},
#   {'type': 'index',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': '38091.76734067943',
#    'currentSymbol': '$'},
#   {'type': 'category',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': '31713.13876972129',
#    'currentSymbol': '$'}],
#  'restructureDate': None}

# %% [markdown]
# Holdings in dict format
#
# Holdings
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.position()
# Out:
# {'masterPortfolioId': '3506',
#  'secId': 'FOUSA00L83',
#  'baseCurrencyId': 'USD',
#  'domicileCountryId': 'USA',
#  'numberOfHolding': 3525,
#  'numberOfEquityHolding': 3504,
#  'numberOfBondHolding': 0,
#  'numberOfOtherHolding': 21,
#  'numberOfHoldingShort': 0,
#  'numberOfEquityHoldingShort': 0,
#  'numberOfBondHoldingShort': 0,
#  'numberOfOtherHoldingShort': 0,
#  'topNCount': 0,
#  'portfolioSuppression': '0',
#  'assetType': 'EQUITY',
#  'holdingSummary': {'portfolioDate': '2026-01-31T06:00:00.000',
#   'topHoldingWeighting': 33.72405,
#   'equityNumberOfHolding': 3504,
#   'fixedIncomeNumberOfHolding': 0,
#   'numberOfHolding': 3525,
#   'numberOfOtherHolding': 21,
#   'lastTurnover': 3.0,
#   'LastTurnoverDate': '2025-12-31T06:00:00.000',
#   'secId': 'FOUSA00L83',
#   'averageTurnoverRatio': 48.39113,
#   'womenDirectors': 34.57,
#   'womenExecutives': 26.67},
#  'holdingActiveShare': {'activeShareValue': None,
#   'activeShareDate': None,
#   'etfBenchmarkProxyName': None,
#   'primaryProspectusBenchmark': 'CRSP US Total Market TR USD'},
#  'equityHoldingPage': {'pageSize': 10000,
#   'pageNumber': 1,
#   'totalPage': 1,
#   'numberOfCurPageHolding': 3506,
#   'numberOfAllHolding': 3506,
#   'holdingList': [{'securityName': 'NVIDIA Corp',
#     'secId': '0P000003RE',
#     'performanceId': '0P000003RE',
#     'holdingTypeId': 'E',
#     'weighting': 6.61532,
#     'numberOfShare': 727204610.0,
#     'marketValue': 138990617109.0,
#     'shareChange': 2009037.0,
#     'country': 'United States',
#     'ticker': 'NVDA',
#     'totalReturn1Year': 58.2685,
#     'forwardPERatio': 22.8311,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [146719498522.0,
#       128271925665.0,
#       135248974364.0,
#       138990617109.0]},
#     'holdingType': 'Equity',
#     'isin': 'US67066G1040',
#     'cusip': '67066G104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 12.4478,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '4',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 138990617109.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Apple Inc',
#     'secId': '0P000000GY',
#     'performanceId': '0P000000GY',
#     'holdingTypeId': 'E',
#     'weighting': 5.74874,
#     'numberOfShare': 465482394.0,
#     'marketValue': 120783371595.0,
#     'shareChange': 1292500.0,
#     'country': 'United States',
#     'ticker': 'AAPL',
#     'totalReturn1Year': 18.3519,
#     'forwardPERatio': 29.9401,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [125938663414.0,
#       129910442247.0,
#       126194664583.0,
#       120783371595.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0378331005',
#     'cusip': '037833100',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 15.3101,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 120783371595.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Microsoft Corp',
#     'secId': '0P000003MH',
#     'performanceId': '0P000003MH',
#     'holdingTypeId': 'E',
#     'weighting': 4.79509,
#     'numberOfShare': 234137135.0,
#     'marketValue': 100746867819.0,
#     'shareChange': 656599.0,
#     'country': 'United States',
#     'ticker': 'MSFT',
#     'totalReturn1Year': 5.7583,
#     'forwardPERatio': 21.0084,
#     'stockRating': '5',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [120808631908.0,
#       114808547256.0,
#       112915856820.0,
#       100746867819.0]},
#     'holdingType': 'Equity',
#     'isin': 'US5949181045',
#     'cusip': '594918104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 14.3584,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '5',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 100746867819.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Amazon.com Inc',
#     'secId': '0P000000B7',
#     'performanceId': '0P000000B7',
#     'holdingTypeId': 'E',
#     'weighting': 3.45183,
#     'numberOfShare': 303069126.0,
#     'marketValue': 72524441852.0,
#     'shareChange': 823152.0,
#     'country': 'United States',
#     'ticker': 'AMZN',
#     'totalReturn1Year': 5.3497,
#     'forwardPERatio': 25.7732,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Cyclical',
#     'sectorCode': 'consumerCyclical',
#     'holdingTrend': {'trend': [73575777440.0,
#       70273919433.0,
#       69764415719.0,
#       72524441852.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0231351067',
#     'cusip': '023135106',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 16.6413,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 72524441852.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Alphabet Inc Class A',
#     'secId': '0P000002HD',
#     'performanceId': '0P000002HD',
#     'holdingTypeId': 'E',
#     'weighting': 2.94768,
#     'numberOfShare': 183230859.0,
#     'marketValue': 61932030342.0,
#     'shareChange': 447131.0,
#     'country': 'United States',
#     'ticker': 'GOOGL',
#     'totalReturn1Year': 82.1495,
#     'forwardPERatio': 26.5957,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [51328478557.0,
#       58470862730.0,
#       57211306864.0,
#       61932030342.0]},
#     'holdingType': 'Equity',
#     'isin': 'US02079K3059',
#     'cusip': '02079K305',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-09-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 19.8604,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 61932030342.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Broadcom Inc',
#     'secId': '0P0000KU35',
#     'performanceId': '0P0000KU35',
#     'holdingTypeId': 'E',
#     'weighting': 2.34558,
#     'numberOfShare': 148752251.0,
#     'marketValue': 49281620756.0,
#     'shareChange': 401182.0,
#     'country': 'United States',
#     'ticker': 'AVGO',
#     'totalReturn1Year': 74.2213,
#     'forwardPERatio': 31.4465,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [54568927479.0,
#       59499364647.0,
#       51344304981.0,
#       49281620756.0]},
#     'holdingType': 'Equity',
#     'isin': 'US11135F1012',
#     'cusip': '11135F101',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2018-04-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 20.1132,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '4',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 49281620756.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Meta Platforms Inc Class A',
#     'secId': '0P0000W3KZ',
#     'performanceId': '0P0000W3KZ',
#     'holdingTypeId': 'E',
#     'weighting': 2.33951,
#     'numberOfShare': 68603036.0,
#     'marketValue': 49154075294.0,
#     'shareChange': 186804.0,
#     'country': 'United States',
#     'ticker': 'META',
#     'totalReturn1Year': 3.3443,
#     'forwardPERatio': 21.3675,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [44138448454.0,
#       44118557184.0,
#       45160870581.0,
#       49154075294.0]},
#     'holdingType': 'Equity',
#     'isin': 'US30303M1027',
#     'cusip': '30303M102',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2012-06-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 24.315,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '5',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 49154075294.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Alphabet Inc Class C',
#     'secId': '0P00012BBI',
#     'performanceId': '0P00012BBI',
#     'holdingTypeId': 'E',
#     'weighting': 2.33331,
#     'numberOfShare': 144813987.0,
#     'marketValue': 49023879019.0,
#     'shareChange': 448319.0,
#     'country': 'United States',
#     'ticker': 'GOOG',
#     'totalReturn1Year': 79.9112,
#     'forwardPERatio': 26.5252,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [40838683592.0,
#       46380956579.0,
#       45301946618.0,
#       49023879019.0]},
#     'holdingType': 'Equity',
#     'isin': 'US02079K1079',
#     'cusip': '02079K107',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2018-05-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 19.8604,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 49023879019.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Tesla Inc',
#     'secId': '0P0000OQN8',
#     'performanceId': '0P0000OQN8',
#     'holdingTypeId': 'E',
#     'weighting': 1.82412,
#     'numberOfShare': 89044399.0,
#     'marketValue': 38325599774.0,
#     'shareChange': 235766.0,
#     'country': 'United States',
#     'ticker': 'TSLA',
#     'totalReturn1Year': 59.2204,
#     'forwardPERatio': 192.3077,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Narrow',
#     'sector': 'Consumer Cyclical',
#     'sectorCode': 'consumerCyclical',
#     'holdingTrend': {'trend': [39288758083.0,
#       37023921030.0,
#       39939018433.0,
#       38325599774.0]},
#     'holdingType': 'Equity',
#     'isin': 'US88160R1014',
#     'cusip': '88160R101',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2010-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 18.8401,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 38325599774.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Eli Lilly and Co',
#     'secId': '0P000001WJ',
#     'performanceId': '0P000001WJ',
#     'holdingTypeId': 'E',
#     'weighting': 1.32287,
#     'numberOfShare': 26798485.0,
#     'marketValue': 27794048718.0,
#     'shareChange': 67687.0,
#     'country': 'United States',
#     'ticker': 'LLY',
#     'totalReturn1Year': 19.6652,
#     'forwardPERatio': 28.5714,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': {'trend': [23070330963.0,
#       28759166930.0,
#       28727053995.0,
#       27794048718.0]},
#     'holdingType': 'Equity',
#     'isin': 'US5324571083',
#     'cusip': '532457108',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 20.5875,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 27794048718.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Berkshire Hathaway Inc Class B',
#     'secId': '0P000000RD',
#     'performanceId': '0P000000RD',
#     'holdingTypeId': 'E',
#     'weighting': 1.29258,
#     'numberOfShare': 56516004.0,
#     'marketValue': 27157635402.0,
#     'shareChange': 137168.0,
#     'country': 'United States',
#     'ticker': 'BRK.B',
#     'totalReturn1Year': -0.8166,
#     'forwardPERatio': 22.3214,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Narrow',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [26850739953.0,
#       28899527073.0,
#       28338821915.0,
#       27157635402.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0846707026',
#     'cusip': '084670702',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2010-03-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 25.1673,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 27157635402.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'JPMorgan Chase & Co',
#     'secId': '0P0000031C',
#     'performanceId': '0P0000031C',
#     'holdingTypeId': 'E',
#     'weighting': 1.19317,
#     'numberOfShare': 81954009.0,
#     'marketValue': 25068911813.0,
#     'shareChange': 38418.0,
#     'country': 'United States',
#     'ticker': 'JPM',
#     'totalReturn1Year': 26.674,
#     'forwardPERatio': 13.21,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [25917781287.0,
#       25725799567.0,
#       26394841732.0,
#       25068911813.0]},
#     'holdingType': 'Equity',
#     'isin': 'US46625H1005',
#     'cusip': '46625H100',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 16.6445,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 25068911813.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Exxon Mobil Corp',
#     'secId': '0P00000220',
#     'performanceId': '0P00000220',
#     'holdingTypeId': 'E',
#     'weighting': 0.89443,
#     'numberOfShare': 132902573.0,
#     'marketValue': 18792423822.0,
#     'shareChange': 428023.0,
#     'country': 'United States',
#     'ticker': 'XOM',
#     'totalReturn1Year': 44.3874,
#     'forwardPERatio': 20.8333,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Narrow',
#     'sector': 'Energy',
#     'sectorCode': 'energy',
#     'holdingTrend': {'trend': [15301947920.0,
#       15513937241.0,
#       15941987347.0,
#       18792423822.0]},
#     'holdingType': 'Equity',
#     'isin': 'US30231G1022',
#     'cusip': '30231G102',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 37.2692,
#     'susEsgRiskGlobes': 2,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'High',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 18792423822.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Johnson & Johnson',
#     'secId': '0P0000032S',
#     'performanceId': '0P0000032S',
#     'holdingTypeId': 'E',
#     'weighting': 0.82071,
#     'numberOfShare': 75878525.0,
#     'marketValue': 17243394806.0,
#     'shareChange': 179982.0,
#     'country': 'United States',
#     'ticker': 'JNJ',
#     'totalReturn1Year': 51.8207,
#     'forwardPERatio': 20.9644,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': {'trend': [14277277296.0,
#       15643966230.0,
#       15665813474.0,
#       17243394806.0]},
#     'holdingType': 'Equity',
#     'isin': 'US4781601046',
#     'cusip': '478160104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 18.7989,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 17243394806.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Visa Inc Class A',
#     'secId': '0P0000CPCP',
#     'performanceId': '0P0000CPCP',
#     'holdingTypeId': 'E',
#     'weighting': 0.79879,
#     'numberOfShare': 52148375.0,
#     'marketValue': 16782911526.0,
#     'shareChange': 158334.0,
#     'country': 'United States',
#     'ticker': 'V',
#     'totalReturn1Year': -7.1566,
#     'forwardPERatio': 23.8663,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [17936300771.0,
#       17608041925.0,
#       18233427279.0,
#       16782911526.0]},
#     'holdingType': 'Equity',
#     'isin': 'US92826C8394',
#     'cusip': '92826C839',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2008-03-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 13.9457,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 16782911526.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Walmart Inc',
#     'secId': '0P000005UH',
#     'performanceId': '0P000005UH',
#     'holdingTypeId': 'E',
#     'weighting': 0.78337,
#     'numberOfShare': 138148036.0,
#     'marketValue': 16458957009.0,
#     'shareChange': 396305.0,
#     'country': 'United States',
#     'ticker': 'WMT',
#     'totalReturn1Year': 48.2042,
#     'forwardPERatio': 42.1941,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Defensive',
#     'sectorCode': 'consumerDefensive',
#     'holdingTrend': {'trend': [13939281046.0,
#       15226553270.0,
#       15346920351.0,
#       16458957009.0]},
#     'holdingType': 'Equity',
#     'isin': 'US9311421039',
#     'cusip': '931142103',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 18.6338,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 16458957009.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Micron Technology Inc',
#     'secId': '0P000003MC',
#     'performanceId': '0P000003MC',
#     'holdingTypeId': 'E',
#     'weighting': 0.69989,
#     'numberOfShare': 35444027.0,
#     'marketValue': 14705017922.0,
#     'shareChange': 91994.0,
#     'country': 'United States',
#     'ticker': 'MU',
#     'totalReturn1Year': 324.3099,
#     'forwardPERatio': 12.6582,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'None',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [7860890398.0,
#       8308389235.0,
#       10089823739.0,
#       14705017922.0]},
#     'holdingType': 'Equity',
#     'isin': 'US5951121038',
#     'cusip': '595112103',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 19.5642,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '6',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 14705017922.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Mastercard Inc Class A',
#     'secId': '0P00005U6B',
#     'performanceId': '0P00005U6B',
#     'holdingTypeId': 'E',
#     'weighting': 0.64837,
#     'numberOfShare': 25283537.0,
#     'marketValue': 13622516900.0,
#     'shareChange': 90696.0,
#     'country': 'United States',
#     'ticker': 'MA',
#     'totalReturn1Year': -4.6089,
#     'forwardPERatio': 25.4453,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [13986055457.0,
#       13954983083.0,
#       14382089070.0,
#       13622516900.0]},
#     'holdingType': 'Equity',
#     'isin': 'US57636Q1040',
#     'cusip': '57636Q104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2006-06-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 16.3025,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 13622516900.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Costco Wholesale Corp',
#     'secId': '0P000001IK',
#     'performanceId': '0P000001IK',
#     'holdingTypeId': 'E',
#     'weighting': 0.62482,
#     'numberOfShare': 13961975.0,
#     'marketValue': 13127746994.0,
#     'shareChange': 42166.0,
#     'country': 'United States',
#     'ticker': 'COST',
#     'totalReturn1Year': 8.7846,
#     'forwardPERatio': 49.505,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Defensive',
#     'sectorCode': 'consumerDefensive',
#     'holdingTrend': {'trend': [12685859144.0,
#       12718315701.0,
#       12003608093.0,
#       13127746994.0]},
#     'holdingType': 'Equity',
#     'isin': 'US22160K1051',
#     'cusip': '22160K105',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 24.608,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 13127746994.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'AbbVie Inc',
#     'secId': '0P0000XPGW',
#     'performanceId': '0P0000XPGW',
#     'holdingTypeId': 'E',
#     'weighting': 0.59066,
#     'numberOfShare': 55648043.0,
#     'marketValue': 12410070069.0,
#     'shareChange': 118663.0,
#     'country': 'United States',
#     'ticker': 'ABBV',
#     'totalReturn1Year': 9.4124,
#     'forwardPERatio': 15.4799,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': {'trend': [12090793109.0,
#       12628368829.0,
#       12687908036.0,
#       12410070069.0]},
#     'holdingType': 'Equity',
#     'isin': 'US00287Y1091',
#     'cusip': '00287Y109',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2013-03-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 18.6926,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 12410070069.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Advanced Micro Devices Inc',
#     'secId': '0P0000006A',
#     'performanceId': '0P0000006A',
#     'holdingTypeId': 'E',
#     'weighting': 0.57774,
#     'numberOfShare': 51275865.0,
#     'marketValue': 12138535521.0,
#     'shareChange': 137585.0,
#     'country': 'United States',
#     'ticker': 'AMD',
#     'totalReturn1Year': 96.1901,
#     'forwardPERatio': 29.4985,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Narrow',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [13046256183.0,
#       11082449355.0,
#       10951774045.0,
#       12138535521.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0079031078',
#     'cusip': '007903107',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2013-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 11.6166,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '4',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 12138535521.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'The Home Depot Inc',
#     'secId': '0P000002OY',
#     'performanceId': '0P000002OY',
#     'holdingTypeId': 'E',
#     'weighting': 0.55919,
#     'numberOfShare': 31364599.0,
#     'marketValue': 11748865139.0,
#     'shareChange': 99290.0,
#     'country': 'United States',
#     'ticker': 'HD',
#     'totalReturn1Year': -3.9125,
#     'forwardPERatio': 22.6244,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Cyclical',
#     'sectorCode': 'consumerCyclical',
#     'holdingTrend': {'trend': [11854739944.0,
#       11151090232.0,
#       10758392827.0,
#       11748865139.0]},
#     'holdingType': 'Equity',
#     'isin': 'US4370761029',
#     'cusip': '437076102',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 12.5924,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 11748865139.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Procter & Gamble Co',
#     'secId': '0P000004GV',
#     'performanceId': '0P000004GV',
#     'holdingTypeId': 'E',
#     'weighting': 0.53171,
#     'numberOfShare': 73608358.0,
#     'marketValue': 11171540494.0,
#     'shareChange': 202964.0,
#     'country': 'United States',
#     'ticker': 'PG',
#     'totalReturn1Year': -8.1029,
#     'forwardPERatio': 20.4918,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Defensive',
#     'sectorCode': 'consumerDefensive',
#     'holdingTrend': {'trend': [11056296041.0,
#       10894216208.0,
#       10519727014.0,
#       11171540494.0]},
#     'holdingType': 'Equity',
#     'isin': 'US7427181091',
#     'cusip': '742718109',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 23.9426,
#     'susEsgRiskGlobes': 3,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 11171540494.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Netflix Inc',
#     'secId': '0P000003UP',
#     'performanceId': '0P000003UP',
#     'holdingTypeId': 'E',
#     'weighting': 0.53043,
#     'numberOfShare': 133484847.0,
#     'marketValue': 11144649876.0,
#     'shareChange': 367212.0,
#     'country': 'United States',
#     'ticker': 'NFLX',
#     'totalReturn1Year': 2.5465,
#     'forwardPERatio': 29.8507,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Narrow',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [14923328946.0,
#       14350979862.0,
#       12481109458.0,
#       11144649876.0]},
#     'holdingType': 'Equity',
#     'isin': 'US64110L1061',
#     'cusip': '64110L106',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 12.1212,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 11144649876.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Bank of America Corp',
#     'secId': '0P000000PA',
#     'performanceId': '0P000000PA',
#     'holdingTypeId': 'E',
#     'weighting': 0.50949,
#     'numberOfShare': 201215235.0,
#     'marketValue': 10704650502.0,
#     'shareChange': 2794747.0,
#     'country': 'United States',
#     'ticker': 'BAC',
#     'totalReturn1Year': 20.8469,
#     'forwardPERatio': 10.8225,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [9974869680.0,
#       9863954017.0,
#       10913126840.0,
#       10704650502.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0605051046',
#     'cusip': '060505104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 19.2224,
#     'susEsgRiskGlobes': 4,
#     'esgAsOfDate': '2026-03-04T06:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
# ...
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 52750809.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Trs:elevance Health Inc Usd 2026-Aug-31',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'ST',
#     'weighting': 0.00177,
#     'numberOfShare': 107616.0,
#     'marketValue': 37207156.0,
#     'shareChange': 107616.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 37207156.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Trs:netapp Inc Usd 2026-Aug-31',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'ST',
#     'weighting': 0.00078,
#     'numberOfShare': 170365.0,
#     'marketValue': 16414668.0,
#     'shareChange': -22417.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 16414668.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Trs:global Payments Inc Usd 2026-Aug-31',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'ST',
#     'weighting': 0.00047,
#     'numberOfShare': 136717.0,
#     'marketValue': 9808078.0,
#     'shareChange': -1663283.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 9808078.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Trs:arbor Realty Trust Inc Usd 2027-Jan-29',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'ST',
#     'weighting': 0.00018,
#     'numberOfShare': 500000.0,
#     'marketValue': 3850000.0,
#     'shareChange': 0.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 3850000.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': "Escrow Luby's Inc",
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'AP',
#     'weighting': 1e-05,
#     'numberOfShare': 449752.0,
#     'marketValue': 112438.0,
#     'shareChange': 0.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 112438.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Srax Pfd',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'P',
#     'weighting': 0.0,
#     'numberOfShare': 590641.0,
#     'marketValue': 41345.0,
#     'shareChange': 0.0,
#     'country': 'United States',
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': '78472M205',
#     'secondarySectorId': '304012',
#     'superSectorName': 'corporate',
#     'primarySectorName': 'Preferred',
#     'secondarySectorName': 'Unspecified',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 41345.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Clearone Inc',
#     'secId': 'B1000HOJJT',
#     'performanceId': None,
#     'holdingTypeId': 'P',
#     'weighting': 0.0,
#     'numberOfShare': 24648.0,
#     'marketValue': 5423.0,
#     'shareChange': 0.0,
#     'country': 'United States',
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': 'US18506U3023',
#     'cusip': '18506U302',
#     'secondarySectorId': '304011',
#     'superSectorName': 'corporate',
#     'primarySectorName': 'Preferred',
#     'secondarySectorName': 'Technology',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 5423.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Btcs Incorporation',
#     'secId': 'B10003UJJ6',
#     'performanceId': None,
#     'holdingTypeId': 'P',
#     'weighting': 0.0,
#     'numberOfShare': 280193.0,
#     'marketValue': 3.0,
#     'shareChange': 0.0,
#     'country': 'United States',
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': 'US05581M5031',
#     'cusip': '05581M503',
#     'secondarySectorId': '304011',
#     'superSectorName': 'corporate',
#     'primarySectorName': 'Preferred',
#     'secondarySectorName': 'Technology',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 3.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Nutriband Inc',
#     'secId': 'B1000HLHOF',
#     'performanceId': None,
#     'holdingTypeId': 'P',
#     'weighting': 0.0,
#     'numberOfShare': 30646.0,
#     'marketValue': 0.0,
#     'shareChange': 0.0,
#     'country': 'United States',
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': 'US67092M4069',
#     'cusip': '67092M406',
#     'secondarySectorId': '304001',
#     'superSectorName': 'corporate',
#     'primarySectorName': 'Preferred',
#     'secondarySectorName': 'Basic Materials',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 0.0,
#     'isMomentumFilterFlag': None}],
#   'previousPeriodsDate': None},
#  'userType': 'Free',
#  'portfolioLastestDateFooter': '2026-01-31T06:00:00.000',
#  'noPremiumChinaFund': False,
#  'numberOfEquityHoldingPer': 99.404,
#  'numberOfBondHoldingPer': 0.0,
#  'numberOfOtherHoldingPer': 0.596}

# %% [markdown]
# Assets exposed to a range of activities
#
# Sustainability - Values - Product Involvement
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.productInvolvement()
# Out:
# {'fundEffectiveDate': '2026-01-31T06:00:00.000',
#  'categoryEffectiveDate': '2019-08-31T05:00:00.000',
#  'excludesEffectiveDate': '2025-04-29T05:00:00.000',
#  'portfolioDate': '2026-01-31T06:00:00.000',
#  'categoryName': 'Large Blend',
#  'categoryAsOfDate': '2022-12-31T06:00:00.000',
#  'businessPractices': [{'label': 'animalTesting',
#    'fundPercent': '14.65287',
#    'categoryPercent': '17.06000',
#    'employsExclusions': '0'},
#   {'label': 'furAndSpecialityLeather',
#    'fundPercent': '0.00000',
#    'categoryPercent': '0.00000',
#    'employsExclusions': '0'}],
#  'defenceAndMilitary': [{'label': 'controversialWeapons',
#    'fundPercent': '1.67105',
#    'categoryPercent': '2.75000',
#    'employsExclusions': '0'},
#   {'label': 'militaryContracting',
#    'fundPercent': '3.89015',
#    'categoryPercent': '3.33000',
#    'employsExclusions': '0'},
#   {'label': 'smallArms',
#    'fundPercent': '1.00930',
#    'categoryPercent': '0.50000',
#    'employsExclusions': '0'}],
#  'energy': [{'label': 'nuclear',
#    'fundPercent': '1.55116',
#    'categoryPercent': '2.16000',
#    'employsExclusions': '0'},
#   {'label': 'thermalCoal',
#    'fundPercent': '1.07903',
#    'categoryPercent': '3.42000',
#    'employsExclusions': '0'}],
#  'environment': [{'label': 'gmo',
#    'fundPercent': '0.07510',
#    'categoryPercent': '0.03000',
#    'employsExclusions': '0'},
#   {'label': 'palmOil',
#    'fundPercent': '0.00014',
#    'categoryPercent': '0.00000',
#    'employsExclusions': '0'},
#   {'label': 'pesticides',
#    'fundPercent': '0.10600',
#    'categoryPercent': '0.30000',
#    'employsExclusions': '0'}],
#  'healthAndLife': [{'label': 'alcohol',
#    'fundPercent': '0.06364',
#    'categoryPercent': '0.45000',
#    'employsExclusions': '0'},
#   {'label': 'tobacco',
#    'fundPercent': '0.62815',
#    'categoryPercent': '0.80000',
#    'employsExclusions': '0'},
#   {'label': 'lifeEthics',
#    'fundPercent': '6.42693',
#    'categoryPercent': '7.09000',
#    'employsExclusions': '0'}],
#  'valueBased': [{'label': 'adultEntertainment',
#    'fundPercent': '0.00000',
#    'categoryPercent': '0.00000',
#    'employsExclusions': '0'},
#   {'label': 'gambling',
#    'fundPercent': '0.20467',
#    'categoryPercent': '0.22000',
#    'employsExclusions': '0'}]}

# %% [markdown]
# How fund managers voted on Management resolutions
#
# Sustainability - Proxy Voting - Management
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.proxyVotingManagement()
# Out:
# {'template': 'US',
#  'managementList': [{'proxyYear': '2026',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': None,
#    'twoYrAdvisoryVoteFreq': None,
#    'threeYrAdvisoryVoteFreq': None,
#    'voteCountAdvisoryVoteFreq': None,
#    'allManagementResolution': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'advisoryVoteOnExecutiveComp': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'auditorRactification': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'directElection': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'compensation': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None}},
#   {'proxyYear': '2025',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '376',
#    'allManagementResolution': {'voteCount': '29208',
#     'supportPer': '97.73350',
#     'againstPer': '2.26650',
#     'abstainedPer': '0.00342'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2798',
#     'supportPer': '98.10579',
#     'againstPer': '1.89421',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3326',
#     'supportPer': '99.87974',
#     'againstPer': '0.12026',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '20928',
#     'supportPer': '97.95967',
#     'againstPer': '2.04033',
#     'abstainedPer': '0.00478'},
#    'compensation': {'voteCount': '814',
#     'supportPer': '88.82064',
#     'againstPer': '11.17936',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2024',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '522',
#    'allManagementResolution': {'voteCount': '30337',
#     'supportPer': '95.95544',
#     'againstPer': '4.04457',
#     'abstainedPer': '0.00000'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2866',
#     'supportPer': '98.15073',
#     'againstPer': '1.84927',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3453',
#     'supportPer': '99.85520',
#     'againstPer': '0.14480',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '21767',
#     'supportPer': '95.42886',
#     'againstPer': '4.57114',
#     'abstainedPer': '0.00000'},
#    'compensation': {'voteCount': '793',
#     'supportPer': '88.39848',
#     'againstPer': '11.60151',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2023',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '1566',
#    'allManagementResolution': {'voteCount': '31435',
#     'supportPer': '94.63655',
#     'againstPer': '5.36027',
#     'abstainedPer': '0.00954'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2952',
#     'supportPer': '95.22358',
#     'againstPer': '4.77642',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3664',
#     'supportPer': '99.91812',
#     'againstPer': '0.08188',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '22534',
#     'supportPer': '94.20875',
#     'againstPer': '5.77794',
#     'abstainedPer': '0.01331'},
#    'compensation': {'voteCount': '826',
#     'supportPer': '83.89831',
#     'againstPer': '16.10169',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2022',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '371',
#    'allManagementResolution': {'voteCount': '31092',
#     'supportPer': '94.95690',
#     'againstPer': '5.04953',
#     'abstainedPer': '0.00643'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2822',
#     'supportPer': '93.90503',
#     'againstPer': '6.09497',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3754',
#     'supportPer': '99.86681',
#     'againstPer': '0.13319',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '22753',
#     'supportPer': '94.85782',
#     'againstPer': '5.13778',
#     'abstainedPer': '0.00879'},
#    'compensation': {'voteCount': '731',
#     'supportPer': '83.31053',
#     'againstPer': '16.82627',
#     'abstainedPer': '0.00000'}}]}

# %% [markdown]
# How fund managers voted on Shareholder resolutions
#
# Sustainability - Proxy Voting - Shareholder
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.proxyVotingShareHolder()
# Out:
# {'template': 'US',
#  'shareholderList': [{'year': '2026',
#    'boardGovernance': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'climateChange': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'directorElections': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'environment': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'esgGovernanceArrangements': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'executiveCompensation': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'humanAndWorkersRights': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'humaneTreatmentOfAnimals': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'militarismAndAggression': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'otherCorporateGovernance': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'otherEnvironmentalAndSocial': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'politicalInfluence': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'publicHealthOrProductSafety': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'shareholderRights': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'strategyOrBusiness': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None}},
#   {'year': '2025',
#    'boardGovernance': {'voteCount': '35',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '52',
#     'supportPer': '0.00000',
#     'againstPer': '98.07692',
#     'abstainedPer': '1.92308'},
#    'directorElections': {'voteCount': '37',
#     'supportPer': '40.54054',
#     'againstPer': '59.45946',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '26',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '3',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '50',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'humanAndWorkersRights': {'voteCount': '80',
#     'supportPer': '0.00000',
#     'againstPer': '98.75000',
#     'abstainedPer': '1.25000'},
#    'humaneTreatmentOfAnimals': {'voteCount': '8',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '6',
#     'supportPer': '16.66667',
#     'againstPer': '83.33334',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '32',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '21',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '14',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '80',
#     'supportPer': '13.75000',
#     'againstPer': '86.25000',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '42',
#     'supportPer': '52.38095',
#     'againstPer': '47.61905',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '8',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2024',
#    'boardGovernance': {'voteCount': '55',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '72',
#     'supportPer': '0.00000',
#     'againstPer': '98.61111',
#     'abstainedPer': '1.38889'},
#    'directorElections': {'voteCount': '25',
#     'supportPer': '40.00000',
#     'againstPer': '60.00000',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '26',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '14',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '55',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'humanAndWorkersRights': {'voteCount': '136',
#     'supportPer': '0.00000',
#     'againstPer': '98.52941',
#     'abstainedPer': '1.47059'},
#    'humaneTreatmentOfAnimals': {'voteCount': '19',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '7',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '7',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '36',
#     'supportPer': '0.00000',
#     'againstPer': '97.22222',
#     'abstainedPer': '2.77778'},
#    'politicalInfluence': {'voteCount': '66',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '22',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '35',
#     'supportPer': '22.85714',
#     'againstPer': '77.14286',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '60',
#     'supportPer': '55.00000',
#     'againstPer': '45.00000',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2023',
#    'boardGovernance': {'voteCount': '94',
#     'supportPer': '3.19149',
#     'againstPer': '96.80851',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '80',
#     'supportPer': '5.00000',
#     'againstPer': '90.00000',
#     'abstainedPer': '5.00000'},
#    'directorElections': {'voteCount': '25',
#     'supportPer': '16.00000',
#     'againstPer': '84.00000',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '14',
#     'supportPer': '7.14286',
#     'againstPer': '92.85714',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '8',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '55',
#     'supportPer': '9.09091',
#     'againstPer': '89.09091',
#     'abstainedPer': '1.81818'},
#    'humanAndWorkersRights': {'voteCount': '85',
#     'supportPer': '1.17647',
#     'againstPer': '97.64706',
#     'abstainedPer': '1.17647'},
#    'humaneTreatmentOfAnimals': {'voteCount': '13',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '9',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '3',
#     'supportPer': '33.33333',
#     'againstPer': '66.66666',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '16',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '52',
#     'supportPer': '1.92308',
#     'againstPer': '98.07692',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '25',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '49',
#     'supportPer': '6.12245',
#     'againstPer': '93.87755',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '23',
#     'supportPer': '34.78261',
#     'againstPer': '65.21739',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2022',
#    'boardGovernance': {'voteCount': '56',
#     'supportPer': '7.14286',
#     'againstPer': '92.85714',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '52',
#     'supportPer': '25.00000',
#     'againstPer': '75.00000',
#     'abstainedPer': '0.00000'},
#    'directorElections': {'voteCount': '20',
#     'supportPer': '45.00000',
#     'againstPer': '55.00000',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '14',
#     'supportPer': '7.14286',
#     'againstPer': '92.85714',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '29',
#     'supportPer': '13.79310',
#     'againstPer': '79.31035',
#     'abstainedPer': '6.89655'},
#    'humanAndWorkersRights': {'voteCount': '87',
#     'supportPer': '13.79310',
#     'againstPer': '86.20689',
#     'abstainedPer': '0.00000'},
#    'humaneTreatmentOfAnimals': {'voteCount': '9',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '3',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '3',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '12',
#     'supportPer': '8.33333',
#     'againstPer': '91.66666',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '52',
#     'supportPer': '13.46154',
#     'againstPer': '86.53846',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '22',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '121',
#     'supportPer': '6.61157',
#     'againstPer': '93.38843',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '24',
#     'supportPer': '75.00000',
#     'againstPer': '25.00000',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '7',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}}]}

# %% [markdown]
# Information on the fund
#
# https://www.morningstar.com/funds/xnas/vtsax/quote

# %%
funds.quote()
# Out:
# {'taxClassDesignation': None,
#  'nCENAverageNetAssets': None,
#  'totalLeverage': None,
#  'totalLeverageRatio': None,
#  'prospectusBenchmarkName': 'CRSP US Total Market TR USD',
#  'primaryIndexNameNew': 'S&P 500 TR USD',
#  'index': 'Morningstar US Large-Mid TR USD',
#  'tNAInShareClassCurrency': 2088924581446.0,
#  'sECYield': 1.09,
#  'trailing1DayReturn': -0.5575,
#  'trailing1DayReturnAsOfDate': '2026-03-13T05:00:00.000',
#  'yield12Month': 1.09975,
#  'trailing7DayYield': None,
#  'expenseRatio': 0.04,
#  'morningstarFeeLevel': '1',
#  'morningstarFeeLevelBroad': '1',
#  'inceptionDate': '2000-11-13T06:00:00.000',
#  'minimumInitialInvestment': 3000.0,
#  'lastTurnoverRatio': 3.0,
#  'equityStyleBox': 2,
#  'expense': 0.04,
#  'load': 'None',
#  'iFICRiskClassification': None,
#  'managementExpenseRatio': None,
#  'fundShareClassTypeName': 'Inst',
#  'fundShareClassTypeId': 'Inst',
#  'fixedIncomeStyleBox': None,
#  'isMonthlyRatio': False,
#  'expenseRatioDate': None,
#  'annualReportNetExpenseRatioDate': None,
#  'monthlyNetExpenseRatioDate': None,
#  'annualReportNetExpenseRatio': None,
#  'monthlyNetExpenseRatio': None,
#  'repurchase_offer_frequency': None,
#  'repurchase_offer_intended_frequency': None,
#  'countryAvailableForSale': None,
#  'prospectusAdjustedExpenseRatio': None,
#  'totalAsset': None,
#  'secId': 'FOUSA00L83',
#  'ticker': 'VTSAX',
#  'fundSubType': None,
#  'userType': 'Free',
#  'investmentName': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#  'isin': 'US9229087286',
#  'morningstarRating': '3',
#  'morningstarRatingAsOfDate': '2026-02-28T06:00:00.000',
#  'analystRating': None,
#  'hasExtendedPerformance': False,
#  'domicileCountryId': 'USA',
#  'baseCurrencyId': 'USD',
#  'caFundCode': None,
#  'dayEndReturnDate': '2026-03-13T05:00:00.000',
#  'returnEndDate': '2026-03-13T05:00:00.000',
#  'template': 'OE_USA_EQUITY',
#  'templateWithAssetType': None,
#  'categoryName': 'US Fund Large Blend',
#  'nav': 158.75,
#  'status': 'Open',
#  'APIRCode': None,
#  'securityType': 'FO',
#  'alternativeFundCodes': None,
#  'selectedFundCode': None,
#  'hasAnalystRating': False,
#  'hasQuantRating': False,
#  'hasIssuerRating': False,
#  'analystRatingDate': None,
#  'altStyle': None,
#  'adjustedExpenseRatio': 0.0004,
#  'productInvolvementEffectiveDate': '2026-01-31T06:00:00.000',
#  'topProductInvolvementCategories': {'Animal_Testing': 14.65287,
#   'Catholic_Values': 6.42693,
#   'Military_Contracting': 3.89015,
#   'Controversial_Weapons': 1.67105,
#   'Nuclear': 1.55116,
#   'Thermal_Coal': 1.07903},
#  'sustainabilityFundQuintile': 2,
#  'sustainabilityAsOfDate': '2026-01-31T00:00:00.000',
#  'isLowCarbon': None,
#  'isDesignatedLowCarbon': None,
#  'medalistRatingLabel': '_PO_',
#  'medalistRating': '_PO_',
#  'medalistRatingDate': '_PO_',
#  'medalistRatingScale': '_PO_',
#  'hasMedalistRating': True,
#  'analystScale': None,
#  'parentScale': None,
#  'peopleScale': None,
#  'processScale': None,
#  'analystDrivenProportion': '100',
#  'dataCoverage': '100',
#  'parentScore': '_PO_',
#  'peopleScore': '_PO_',
#  'priceScore': '_PO_',
#  'processScore': '_PO_',
#  'parentScoreLabel': '_PO_',
#  'peopleScoreLabel': '_PO_',
#  'processScoreLabel': '_PO_',
#  'parentScoreType': '_PO_',
#  'peopleScoreType': '_PO_',
#  'processScoreType': '_PO_',
#  'assetType': 'EQUITY',
#  'disclosureCodes': None,
#  'disclosureDescriptions': None,
#  'issuerDisclosure': None}

# %% [markdown]
# Breakdown by region
#
# Exposure - Region
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.regionalSector()
# Out:
# {'fundPortfolio': {'portfolioDate': '2026-01-31T06:00:00.000',
#   'masterPortfolioId': '3506',
#   'northAmerica': 99.529,
#   'unitedKingdom': 0.04305,
#   'europeDeveloped': 0.248,
#   'europeEmerging': 0.0,
#   'africaMiddleEast': 0.0,
#   'japan': 0.0,
#   'australasia': 0.0,
#   'asiaDeveloped': 0.005,
#   'asiaEmerging': 0.11,
#   'latinAmerica': 0.064},
#  'categoryPortfolio': {'portfolioDate': '2026-01-31T06:00:00.000',
#   'masterPortfolioId': '204178',
#   'northAmerica': 98.02,
#   'unitedKingdom': 0.4183,
#   'europeDeveloped': 0.825,
#   'europeEmerging': 0.0,
#   'africaMiddleEast': 0.024,
#   'japan': 0.068,
#   'australasia': 0.002,
#   'asiaDeveloped': 0.378,
#   'asiaEmerging': 0.169,
#   'latinAmerica': 0.092},
#  'indexPortfolio': {'portfolioDate': '2026-02-28T06:00:00.000',
#   'masterPortfolioId': '471834',
#   'northAmerica': 99.233,
#   'unitedKingdom': 0.06865,
#   'europeDeveloped': 0.409,
#   'europeEmerging': 0.0,
#   'africaMiddleEast': 0.0,
#   'japan': 0.0,
#   'australasia': 0.0,
#   'asiaDeveloped': 0.0,
#   'asiaEmerging': 0.114,
#   'latinAmerica': 0.175},
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'assetType': 'EQUITY'}

# %% [markdown]
# Breakdown by country
#
# Exposure - Country
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.regionalSectorIncludeCountries()
# Out:
# {'fundPortfolio': {'countries': [{'name': 'unitedStates', 'percent': 99.42939},
#    {'name': 'switzerland', 'percent': 0.21539},
#    {'name': 'canada', 'percent': 0.10038},
#    {'name': 'china', 'percent': 0.09874},
#    {'name': 'unitedKingdom', 'percent': 0.04305},
#    {'name': 'mexico', 'percent': 0.03515},
#    {'name': 'ireland', 'percent': 0.03285},
#    {'name': 'india', 'percent': 0.01142},
#    {'name': 'brazil', 'percent': 0.00474},
#    {'name': 'taiwan', 'percent': 0.0039},
#    {'name': 'hongKong', 'percent': 0.00079},
#    {'name': 'argentina', 'percent': 0.0},
#    {'name': 'australia', 'percent': 0.0},
#    {'name': 'austria', 'percent': 0.0},
#    {'name': 'belgium', 'percent': 0.0},
#    {'name': 'chile', 'percent': 0.0},
#    {'name': 'colombia', 'percent': 0.0},
#    {'name': 'czechRepublic', 'percent': 0.0},
#    {'name': 'denmark', 'percent': 0.0},
#    {'name': 'estonia', 'percent': 0.0},
#    {'name': 'finland', 'percent': 0.0},
#    {'name': 'france', 'percent': 0.0},
#    {'name': 'germany', 'percent': 0.0},
#    {'name': 'greece', 'percent': 0.0},
#    {'name': 'hungary', 'percent': 0.0},
#    {'name': 'indonesia', 'percent': 0.0},
#    {'name': 'israel', 'percent': 0.0},
#    {'name': 'italy', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0},
#    {'name': 'latvia', 'percent': 0.0},
#    {'name': 'lithuania', 'percent': 0.0},
#    {'name': 'malaysia', 'percent': 0.0},
#    {'name': 'netherlands', 'percent': 0.0},
#    {'name': 'newZealand', 'percent': 0.0},
#    {'name': 'norway', 'percent': 0.0},
#    {'name': 'pakistan', 'percent': 0.0},
#    {'name': 'peru', 'percent': 0.0},
#    {'name': 'philippines', 'percent': 0.0},
#    {'name': 'poland', 'percent': 0.0},
#    {'name': 'portugal', 'percent': 0.0},
#    {'name': 'russia', 'percent': 0.0},
#    {'name': 'singapore', 'percent': 0.0},
#    {'name': 'slovakia', 'percent': 0.0},
#    {'name': 'southAfrica', 'percent': 0.0},
#    {'name': 'southKorea', 'percent': 0.0},
#    {'name': 'spain', 'percent': 0.0},
#    {'name': 'sweden', 'percent': 0.0},
#    {'name': 'thailand', 'percent': 0.0},
#    {'name': 'turkey', 'percent': 0.0},
#    {'name': 'venezuela', 'percent': 0.0},
#    {'name': 'vietnam', 'percent': 0.0}],
#   'regions': [{'name': 'northAmerica', 'percent': 99.529},
#    {'name': 'europeDeveloped', 'percent': 0.248},
#    {'name': 'asiaEmerging', 'percent': 0.11},
#    {'name': 'latinAmerica', 'percent': 0.064},
#    {'name': 'unitedKingdom', 'percent': 0.04305},
#    {'name': 'other Countries', 'percent': 0.02418},
#    {'name': 'asiaDeveloped', 'percent': 0.005},
#    {'name': 'australasia', 'percent': 0.0},
#    {'name': 'europeEmerging', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0}],
#   'portfolioDate': '2026-01-31T06:00:00.000'},
#  'categoryPortfolio': {'countries': [{'name': 'unitedStates',
#     'percent': 97.6197},
#    {'name': 'unitedKingdom', 'percent': 0.4183},
#    {'name': 'canada', 'percent': 0.41333},
#    {'name': 'switzerland', 'percent': 0.38487},
#    {'name': 'taiwan', 'percent': 0.33033},
#    {'name': 'netherlands', 'percent': 0.2638},
#    {'name': 'china', 'percent': 0.14942},
#    {'name': 'japan', 'percent': 0.068},
#    {'name': 'germany', 'percent': 0.06179},
#    {'name': 'brazil', 'percent': 0.04255},
#    {'name': 'southKorea', 'percent': 0.03975},
#    {'name': 'mexico', 'percent': 0.0361},
#    {'name': 'france', 'percent': 0.03112},
#    {'name': 'ireland', 'percent': 0.02691},
#    {'name': 'belgium', 'percent': 0.02622},
#    {'name': 'israel', 'percent': 0.02138},
#    {'name': 'denmark', 'percent': 0.01783},
#    {'name': 'india', 'percent': 0.01765},
#    {'name': 'sweden', 'percent': 0.00352},
#    {'name': 'singapore', 'percent': 0.00338},
#    {'name': 'australia', 'percent': 0.00224},
#    {'name': 'hongKong', 'percent': 0.00174},
#    {'name': 'spain', 'percent': 0.00162},
#    {'name': 'southAfrica', 'percent': 0.00137},
#    {'name': 'italy', 'percent': 0.00106},
#    {'name': 'finland', 'percent': 0.00067},
#    {'name': 'malaysia', 'percent': 0.00039},
#    {'name': 'norway', 'percent': 0.00037},
#    {'name': 'poland', 'percent': 0.00016},
#    {'name': 'austria', 'percent': 0.00013},
#    {'name': 'indonesia', 'percent': 0.00013},
#    {'name': 'thailand', 'percent': 0.00012},
#    {'name': 'portugal', 'percent': 9e-05},
#    {'name': 'chile', 'percent': 6e-05},
#    {'name': 'greece', 'percent': 6e-05},
#    {'name': 'turkey', 'percent': 6e-05},
#    {'name': 'newZealand', 'percent': 4e-05},
#    {'name': 'philippines', 'percent': 4e-05},
#    {'name': 'hungary', 'percent': 3e-05},
#    {'name': 'colombia', 'percent': 2e-05},
#    {'name': 'peru', 'percent': 2e-05},
#    {'name': 'czechRepublic', 'percent': 1e-05},
#    {'name': 'argentina', 'percent': 0.0},
#    {'name': 'estonia', 'percent': 0.0},
#    {'name': 'latvia', 'percent': 0.0},
#    {'name': 'lithuania', 'percent': 0.0},
#    {'name': 'pakistan', 'percent': 0.0},
#    {'name': 'russia', 'percent': 0.0},
#    {'name': 'slovakia', 'percent': 0.0},
#    {'name': 'venezuela', 'percent': 0.0},
#    {'name': 'vietnam', 'percent': 0.0}],
#   'regions': [{'name': 'northAmerica', 'percent': 98.02},
#    {'name': 'europeDeveloped', 'percent': 0.825},
#    {'name': 'unitedKingdom', 'percent': 0.4183},
#    {'name': 'asiaDeveloped', 'percent': 0.378},
#    {'name': 'asiaEmerging', 'percent': 0.169},
#    {'name': 'latinAmerica', 'percent': 0.092},
#    {'name': 'japan', 'percent': 0.068},
#    {'name': 'other Countries', 'percent': 0.01386},
#    {'name': 'australasia', 'percent': 0.002},
#    {'name': 'europeEmerging', 'percent': 0.0}],
#   'portfolioDate': '2026-01-31T06:00:00.000'},
#  'indexPortfolio': {'countries': [{'name': 'unitedStates',
#     'percent': 99.23319},
#    {'name': 'switzerland', 'percent': 0.27669},
#    {'name': 'brazil', 'percent': 0.13806},
#    {'name': 'china', 'percent': 0.1139},
#    {'name': 'netherlands', 'percent': 0.09178},
#    {'name': 'unitedKingdom', 'percent': 0.06865},
#    {'name': 'ireland', 'percent': 0.04055},
#    {'name': 'mexico', 'percent': 0.03718},
#    {'name': 'argentina', 'percent': 0.0},
#    {'name': 'australia', 'percent': 0.0},
#    {'name': 'austria', 'percent': 0.0},
#    {'name': 'belgium', 'percent': 0.0},
#    {'name': 'canada', 'percent': 0.0},
#    {'name': 'chile', 'percent': 0.0},
#    {'name': 'colombia', 'percent': 0.0},
#    {'name': 'czechRepublic', 'percent': 0.0},
#    {'name': 'denmark', 'percent': 0.0},
#    {'name': 'estonia', 'percent': 0.0},
#    {'name': 'finland', 'percent': 0.0},
#    {'name': 'france', 'percent': 0.0},
#    {'name': 'germany', 'percent': 0.0},
#    {'name': 'greece', 'percent': 0.0},
#    {'name': 'hongKong', 'percent': 0.0},
#    {'name': 'hungary', 'percent': 0.0},
#    {'name': 'india', 'percent': 0.0},
#    {'name': 'indonesia', 'percent': 0.0},
#    {'name': 'israel', 'percent': 0.0},
#    {'name': 'italy', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0},
#    {'name': 'latvia', 'percent': 0.0},
#    {'name': 'lithuania', 'percent': 0.0},
#    {'name': 'malaysia', 'percent': 0.0},
#    {'name': 'newZealand', 'percent': 0.0},
#    {'name': 'norway', 'percent': 0.0},
#    {'name': 'pakistan', 'percent': 0.0},
#    {'name': 'peru', 'percent': 0.0},
#    {'name': 'philippines', 'percent': 0.0},
#    {'name': 'poland', 'percent': 0.0},
#    {'name': 'portugal', 'percent': 0.0},
#    {'name': 'russia', 'percent': 0.0},
#    {'name': 'singapore', 'percent': 0.0},
#    {'name': 'slovakia', 'percent': 0.0},
#    {'name': 'southAfrica', 'percent': 0.0},
#    {'name': 'southKorea', 'percent': 0.0},
#    {'name': 'spain', 'percent': 0.0},
#    {'name': 'sweden', 'percent': 0.0},
#    {'name': 'taiwan', 'percent': 0.0},
#    {'name': 'thailand', 'percent': 0.0},
#    {'name': 'turkey', 'percent': 0.0},
#    {'name': 'venezuela', 'percent': 0.0},
#    {'name': 'vietnam', 'percent': 0.0}],
#   'regions': [{'name': 'northAmerica', 'percent': 99.233},
#    {'name': 'europeDeveloped', 'percent': 0.409},
#    {'name': 'latinAmerica', 'percent': 0.175},
#    {'name': 'asiaEmerging', 'percent': 0.114},
#    {'name': 'unitedKingdom', 'percent': 0.06865},
#    {'name': 'asiaDeveloped', 'percent': 0.0},
#    {'name': 'australasia', 'percent': 0.0},
#    {'name': 'europeEmerging', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0},
#    {'name': 'other Countries', 'percent': 0.0}],
#   'portfolioDate': '2026-02-28T06:00:00.000'},
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'assetType': 'EQUITY'}

# %% [markdown]
# Return vs Standard deviation
#
#
# Risk/Return Analysis
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.riskReturnScatterplot()
# Out:
# {'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'cur': 'USD',
#  'isUKCefTemplateAvailable': False,
#  'extendedPerformanceData': {'ePUsedFor1YearFlag': False,
#   'ePUsedFor3YearFlag': False,
#   'ePUsedFor5YearFlag': False,
#   'ePUsedFor10YearFlag': False,
#   'ePUsedFor15YearFlag': False},
#  'fundScatterplot': {'standardDeviationEndDate': '2026-02-28T06:00:00.000',
#   'trailingReturnEndDate': '2026-02-28T06:00:00.000',
#   'trailingReturnPriceEndDate': '2026-02-28T06:00:00.000',
#   'for1Year': {'trailingReturn': 17.0338,
#    'trailingReturnPrice': None,
#    'standardDeviation': 10.893},
#   'for3Year': {'trailingReturn': 20.90696,
#    'trailingReturnPrice': None,
#    'standardDeviation': 12.026},
#   'for5Year': {'trailingReturn': 12.66289,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.366},
#   'for10Year': {'trailingReturn': 15.02802,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.493},
#   'for15Year': {'trailingReturn': 13.1864,
#    'trailingReturnPrice': None,
#    'standardDeviation': 14.509},
#   'forLongestTenure': None},
#  'categoryScatterplot': {'standardDeviationEndDate': '2026-02-28T06:00:00.000',
#   'trailingReturnEndDate': '2026-02-28T06:00:00.000',
#   'trailingReturnPriceEndDate': None,
#   'for1Year': {'trailingReturn': 15.42125,
#    'trailingReturnPrice': None,
#    'standardDeviation': 10.822},
#   'for3Year': {'trailingReturn': 19.35831,
#    'trailingReturnPrice': None,
#    'standardDeviation': 11.979},
#   'for5Year': {'trailingReturn': 12.46182,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.143},
#   'for10Year': {'trailingReturn': 14.11418,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.212},
#   'for15Year': {'trailingReturn': 12.36596,
#    'trailingReturnPrice': None,
#    'standardDeviation': 14.404},
#   'forLongestTenure': None},
#  'indexScatterplot': {'standardDeviationEndDate': '2026-02-28T06:00:00.000',
#   'trailingReturnEndDate': '2026-02-28T06:00:00.000',
#   'trailingReturnPriceEndDate': None,
#   'for1Year': {'trailingReturn': 16.60911,
#    'trailingReturnPrice': None,
#    'standardDeviation': 11.041},
#   'for3Year': {'trailingReturn': 21.71784,
#    'trailingReturnPrice': None,
#    'standardDeviation': 11.762},
#   'for5Year': {'trailingReturn': 13.40957,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.289},
#   'for10Year': {'trailingReturn': 15.36375,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.252},
#   'for15Year': {'trailingReturn': 13.54358,
#    'trailingReturnPrice': None,
#    'standardDeviation': 14.265},
#   'forLongestTenure': None}}

# %% [markdown]
# Return and risk compare to the category
#
# Morningstar Risk & Return
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.riskReturnSummary()
# Out:
# {'endDate': '2026-02-28T06:00:00.000',
#  'categoryName': 'Large Blend',
#  'pricingFrequencyName': 'Daily',
#  'for3Year': {'epUsedFlag': False,
#   'riskVsCategory': 3,
#   'returnVsCategory': 3,
#   'numberOfFunds': 1208},
#  'for5Year': {'epUsedFlag': False,
#   'riskVsCategory': 3,
#   'returnVsCategory': 3,
#   'numberOfFunds': 1120},
#  'for10Year': {'epUsedFlag': False,
#   'riskVsCategory': 4,
#   'returnVsCategory': 4,
#   'numberOfFunds': 880}}

# %% [markdown]
# Overal risk of the fund
#
# Portfolio Risk Score
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.riskScore()
# Out:
# {'riskScore': '75',
#  'riskLevel': 'Aggressive',
#  'asOfDate': '2026-01-31T06:00:00.000',
#  'portfolioDate': '2026-01-31T06:00:00.000',
#  'privateAllocationPercent': 1e-05,
#  'riskScoreRangeList': [{'riskScoreRegion': 'US',
#    'rangeName': 'Conservative',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '1',
#    'maximumScore': 23,
#    'minimumScore': 0,
#    'rangeDisplay': '0-23'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Moderate',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '2',
#    'maximumScore': 47,
#    'minimumScore': 24,
#    'rangeDisplay': '24-47'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Aggressive',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '3',
#    'maximumScore': 78,
#    'minimumScore': 48,
#    'rangeDisplay': '48-78'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Very Aggressive',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '4',
#    'maximumScore': 99,
#    'minimumScore': 79,
#    'rangeDisplay': '79-99'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Extreme',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '5',
#    'maximumScore': 500,
#    'minimumScore': 100,
#    'rangeDisplay': '100+'}]}

# %% [markdown]
# Alpha, beta, RSquared, Standard deviation end Sharpe ratio over time

# %%
funds.riskVolatility()
# Out:
# {'fundName': None,
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'calculationBenchmark': 'S&P 500 TR USD',
#  'extendedPerformanceData': {'ePUsedFor1YearFlag': False,
#   'ePUsedFor3YearFlag': False,
#   'ePUsedFor5YearFlag': False,
#   'ePUsedFor10YearFlag': False,
#   'ePUsedFor15YearFlag': False},
#  'fundRiskVolatility': {'primaryIndexNameNew': 'S&P 500 TR USD',
#   'bestFitIndexName': 'Morningstar US Market TR USD',
#   'bestFitAlphaFor3Year': -0.344,
#   'bestFitBetaFor3Year': 1.009,
#   'bestFitRSquaredFor3Year': 99.919,
#   'endDate': '2026-02-28T06:00:00.000',
#   'for1Year': {'alpha': -0.084,
#    'beta': 1.011,
#    'rSquared': 99.761,
#    'standardDeviation': 10.893,
#    'sharpeRatio': 1.129},
#   'for3Year': {'alpha': -1.335,
#    'beta': 1.041,
#    'rSquared': 98.89,
#    'standardDeviation': 12.026,
#    'sharpeRatio': 1.25},
#   'for5Year': {'alpha': -1.469,
#    'beta': 1.014,
#    'rSquared': 99.197,
#    'standardDeviation': 15.366,
#    'sharpeRatio': 0.632},
#   'for10Year': {'alpha': -0.73,
#    'beta': 1.03,
#    'rSquared': 99.262,
#    'standardDeviation': 15.493,
#    'sharpeRatio': 0.836},
#   'for15Year': {'alpha': -0.742,
#    'beta': 1.03,
#    'rSquared': 99.226,
#    'standardDeviation': 14.509,
#    'sharpeRatio': 0.823},
#   'forLongestTenure': None},
#  'categoryRiskVolatility': {'endDate': '2026-02-28T06:00:00.000',
#   'for1Year': {'alpha': -0.457,
#    'beta': 0.918,
#    'rSquared': 84.215,
#    'standardDeviation': 10.822,
#    'sharpeRatio': 0.991},
#   'for3Year': {'alpha': -1.692,
#    'beta': 0.978,
#    'rSquared': 88.828,
#    'standardDeviation': 11.979,
#    'sharpeRatio': 1.15},
#   'for5Year': {'alpha': -1.169,
#    'beta': 0.966,
#    'rSquared': 92.701,
#    'standardDeviation': 15.143,
#    'sharpeRatio': 0.627},
#   'for10Year': {'alpha': -0.988,
#    'beta': 0.985,
#    'rSquared': 94.302,
#    'standardDeviation': 15.212,
#    'sharpeRatio': 0.797},
#   'for15Year': {'alpha': -1.123,
#    'beta': 1.0,
#    'rSquared': 95.045,
#    'standardDeviation': 14.404,
#    'sharpeRatio': 0.779},
#   'forLongestTenure': None},
#  'indexRiskVolatility': {'endDate': '2026-02-28T06:00:00.000',
#   'for1Year': {'alpha': -0.612,
#    'beta': 1.025,
#    'rSquared': 99.894,
#    'standardDeviation': 11.041,
#    'sharpeRatio': 1.082},
#   'for3Year': {'alpha': -0.395,
#    'beta': 1.022,
#    'rSquared': 99.787,
#    'standardDeviation': 11.762,
#    'sharpeRatio': 1.334},
#   'for5Year': {'alpha': -0.789,
#    'beta': 1.012,
#    'rSquared': 99.739,
#    'standardDeviation': 15.289,
#    'sharpeRatio': 0.678},
#   'for10Year': {'alpha': -0.294,
#    'beta': 1.016,
#    'rSquared': 99.798,
#    'standardDeviation': 15.252,
#    'sharpeRatio': 0.866},
#   'for15Year': {'alpha': -0.279,
#    'beta': 1.015,
#    'rSquared': 99.779,
#    'standardDeviation': 14.265,
#    'sharpeRatio': 0.857},
#   'forLongestTenure': None},
#  'cur': 'USD'}

# %% [markdown]
# Maximum Sales Fees
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.salesFees()
# Out:
# {'salesFees': {'frontloadFee': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   'frontloadFeeLowBreakpoint': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   'deferredloadFee': [None, None, None, None, None, None, None],
#   'redemptionFeeLowBreakpoint': [None, None, None, None, None, None],
#   'redemptionFee': [None, None, None, None, None, None],
#   'deferredloadFeeLowBreakpoint': [None, None, None, None, None, None, None]},
#  'minInitialInvestment': 3000,
#  'currencyId': 'USD',
#  'minInvestmentCurrency': 'USD',
#  'frontloadFeeBreakpointUnit': None,
#  'frontloadFeeUnit': None,
#  'redemptionFeeBreakpointUnit': None,
#  'redemptionFeeUnit': None,
#  'deferredloadFeeBreakpointUnit': None,
#  'deferredloadFeeUnit': None,
#  'minimumInitialInvestmentUnit': 'Monetary'}

# %% [markdown]
# Breakdown by sector
#
# Exposure - Sector
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.sector()
# Out:
# {'FIXEDINCOME': {'fundPortfolio': {'portfolioDate': '2026-01-31T06:00:00.000',
#    'government': 0.0,
#    'municipal': 0.0,
#    'corporate': 0.0,
#    'securitized': 0.0,
#    'cashAndEquivalents': 100.0,
#    'derivative': 0.0},
#   'categoryPortfolio': {'portfolioDate': '2026-01-31T06:00:00.000',
#    'government': 11.46779,
#    'municipal': 0.00268,
#    'corporate': 4.07556,
#    'securitized': 13.51414,
#    'cashAndEquivalents': 70.93877,
#    'derivative': 0.00107},
#   'indexPortfolio': {'portfolioDate': None,
#    'government': None,
#    'municipal': None,
#    'corporate': None,
#    'securitized': None,
#    'cashAndEquivalents': None,
#    'derivative': None},
#   'categoryName': 'Large Blend',
#   'indexName': 'Morningstar US Large-Mid TR USD',
#   'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#   'assetType': 'FIXEDINCOME'},
#  'EQUITY': {'fundPortfolio': {'portfolioDate': '2026-01-31T06:00:00.000',
#    'basicMaterials': 2.02124,
#    'consumerCyclical': 10.50078,
#    'financialServices': 12.8489,
#    'realEstate': 2.36182,
#    'communicationServices': 10.34844,
#    'energy': 3.31572,
#    'industrials': 9.43091,
#    'technology': 32.12289,
#    'consumerDefensive': 4.7274,
#    'healthcare': 10.09085,
#    'utilities': 2.23104},
#   'categoryPortfolio': {'portfolioDate': '2026-01-31T06:00:00.000',
#    'basicMaterials': 1.99352,
#    'consumerCyclical': 10.13878,
#    'financialServices': 13.84054,
#    'realEstate': 1.58381,
#    'communicationServices': 10.308,
#    'energy': 2.88186,
#    'industrials': 9.63754,
#    'technology': 32.12944,
#    'consumerDefensive': 4.74117,
#    'healthcare': 10.46953,
#    'utilities': 2.27582},
#   'indexPortfolio': {'portfolioDate': '2026-02-28T06:00:00.000',
#    'basicMaterials': 1.95201,
#    'consumerCyclical': 10.05112,
#    'financialServices': 12.15468,
#    'realEstate': 1.836,
#    'communicationServices': 10.86794,
#    'energy': 3.50146,
#    'industrials': 9.0614,
#    'technology': 33.04679,
#    'consumerDefensive': 5.28327,
#    'healthcare': 9.81753,
#    'utilities': 2.42781},
#   'categoryName': 'Large Blend',
#   'indexName': 'Morningstar US Large-Mid TR USD',
#   'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#   'assetType': 'EQUITY'},
#  'assetType': 'EQUITY'}

# %% [markdown]
# Snapshot of the fund and asset manager

# %%
funds.snapshot()
# Out:
# {}

# %% [markdown]
# Funds of the asset manager with lower rating
#
# Lowest Rated Investments
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.starRatingFundAsc()
# Out:
# {'StarRatingFund': [{'calendarYearFlow': -139554924.0,
#    'netAsset': 1723711793.0,
#    'fundShareClassId': 'F000011J08',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Long-Term Bond Index Admiral',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 3.66847,
#    'trailing3YearReturnRank': '99',
#    'secId': 'F000011J08',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 125242336.0,
#    'netAsset': 1042474087.0,
#    'fundShareClassId': 'F00001CKVW',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Advice Select Dividend Gr Admrl',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 10.60523,
#    'trailing3YearReturnRank': '98',
#    'secId': 'F00001CKVW',
#    'securityType': 'FO'},
#   {'calendarYearFlow': -64031132.0,
#    'netAsset': 685499821.0,
#    'fundShareClassId': 'FOUSA06KY1',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Extended Duration Trs Idx Instl',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': -2.81469,
#    'trailing3YearReturnRank': '92',
#    'secId': 'FOUSA06KY1',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 28527243.0,
#    'netAsset': 276805218.0,
#    'fundShareClassId': 'F00000ZAFI',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Baillie GiffordGlbPstvImpStkInv',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 10.82712,
#    'trailing3YearReturnRank': '88',
#    'secId': 'F00000ZAFI',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 20298842.0,
#    'netAsset': 89567801.0,
#    'fundShareClassId': 'F00001EBZW',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Global Environmental Opp StkAdm',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 8.67113,
#    'trailing3YearReturnRank': '95',
#    'secId': 'F00001EBZW',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2026-02-28T06:00:00.000',
#  'footerReturnDate': '2026-02-28T06:00:00.000',
#  'currency': 'USD',
#  'secId': None,
#  'securityType': None,
#  'userType': 'Free'}

# %% [markdown]
# Funds of the asset manager with higher rating
#
# Highest Rated Investments
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.starRatingFundDesc()
# Out:
# {'StarRatingFund': [{'calendarYearFlow': -16221558862.0,
#    'netAsset': 73531440069.0,
#    'fundShareClassId': 'FOUSA02TYD',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard PRIMECAP Adm',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 24.66978,
#    'trailing3YearReturnRank': '5',
#    'secId': 'FOUSA02TYD',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 278064468.0,
#    'netAsset': 15418806585.0,
#    'fundShareClassId': 'FOUSA02TY9',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard High-Yield Tax-Exempt Adm',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 5.63333,
#    'trailing3YearReturnRank': '9',
#    'secId': 'FOUSA02TY9',
#    'securityType': 'FO'},
#   {'calendarYearFlow': -1725794462.0,
#    'netAsset': 14575090701.0,
#    'fundShareClassId': 'FOUSA05B7U',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard PRIMECAP Core Inv',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 24.47374,
#    'trailing3YearReturnRank': '5',
#    'secId': 'FOUSA05B7U',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 57615698.0,
#    'netAsset': 11760749307.0,
#    'fundShareClassId': 'FOUSA00BB5',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Tax-Managed Balanced Adm',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 12.74358,
#    'trailing3YearReturnRank': '9',
#    'secId': 'FOUSA00BB5',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 56041798.0,
#    'netAsset': 6702875666.0,
#    'fundShareClassId': 'FOUSA02SNG',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Interm-Term Treasury Adm',
#    'returnEndDate': '2026-02-28T06:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 5.04287,
#    'trailing3YearReturnRank': '9',
#    'secId': 'FOUSA02SNG',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2026-02-28T06:00:00.000',
#  'footerReturnDate': '2026-02-28T06:00:00.000',
#  'currency': 'USD',
#  'secId': None,
#  'securityType': None,
#  'userType': 'Free'}

# %% [markdown]
# General information and return on funds

# %%
funds.strategyPreview()
# Out:
# {'shareClassList': [{'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': -1.90636,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 18.40818, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 8.36639, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 14.46412, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Market ETF',
#     'secId': '0P0000M4Z0',
#     'securityType': 'FE',
#     'fundShareClassId': 'FEUSA0002P',
#     'APIRCode': None,
#     'ticker': 'VTI',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229087690',
#     'baseCurrencyId': 'MXN',
#     'overallMorningstarRating': None,
#     'epUsedForOverallRating': None,
#     'ratingEndDate': None,
#     'analystRating': None,
#     'medalistRating': None,
#     'analystRatingEndDate': None,
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': None,
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': None,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': None,
#     'expenseRatio': 0.03,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': None,
#     'lastShareClassNetAsset': None,
#     'minimumInitialInvestment': None,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': None,
#     'secYield': 1.1,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': None,
#     'qualifiedInvestment': None,
#     'returnEndDate': None,
#     'trailing1YearReturn': -1.90636,
#     'trailing3YearReturn': 18.40818,
#     'trailing5YearReturn': 8.36639,
#     'trailing10YearReturn': 14.46412,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2001-05-24 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': None,
#     'FundShareClassTypeId': None,
#     'MorningstarFeeLevel': None,
#     'MorningstarFeeLevelGroup': None,
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': None,
#     'maximumManagementFee': '0.020000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 17.04134,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 20.92137, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.67602, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.03713, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Market ETF',
#     'secId': 'FEUSA0002P',
#     'securityType': 'FE',
#     'fundShareClassId': 'FEUSA0002P',
#     'APIRCode': None,
#     'ticker': 'VTI',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229087690',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-02-28 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-02-11 20:20:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.03,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.03,
#     'expenseRatio': 0.03,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 566980860182.0,
#     'minimumInitialInvestment': None,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.10889,
#     'secYield': 1.1,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': None,
#     'qualifiedInvestment': None,
#     'returnEndDate': None,
#     'trailing1YearReturn': 17.04134,
#     'trailing3YearReturn': 20.92137,
#     'trailing5YearReturn': 12.67602,
#     'trailing10YearReturn': 15.03713,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2001-05-24 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': None,
#     'FundShareClassTypeId': '44',
#     'MorningstarFeeLevel': None,
#     'MorningstarFeeLevelGroup': None,
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '41789802401.270',
#     'maximumManagementFee': '0.020000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 17.0417,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 20.91766, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.67359, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.03829, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Market Idx I',
#     'secId': 'FOUSA00GQ7',
#     'securityType': 'FO',
#     'fundShareClassId': 'FOUSA00GQ7',
#     'APIRCode': None,
#     'ticker': 'VITSX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229088011',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-02-28 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-02-11 20:20:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.03,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.03,
#     'expenseRatio': 0.03,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 102247977241.0,
#     'minimumInitialInvestment': 5000000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.10852,
#     'secYield': 1.1,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '1',
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 17.0417,
#     'trailing3YearReturn': 20.91766,
#     'trailing5YearReturn': 12.67359,
#     'trailing10YearReturn': 15.03829,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '1997-07-07 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inst',
#     'FundShareClassTypeId': '6',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap Institutional',
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '-7592420053.505',
#     'maximumManagementFee': '0.030000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 17.0338,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 20.90696, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.66289, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.02802, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Adm',
#     'secId': 'FOUSA00L83',
#     'securityType': 'FO',
#     'fundShareClassId': 'FOUSA00L83',
#     'APIRCode': None,
#     'ticker': 'VTSAX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229087286',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-02-28 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-02-11 20:20:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.04,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.04,
#     'expenseRatio': 0.04,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 448062080139.0,
#     'minimumInitialInvestment': 3000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.09975,
#     'secYield': 1.09,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '0',
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 17.0338,
#     'trailing3YearReturn': 20.90696,
#     'trailing5YearReturn': 12.66289,
#     'trailing10YearReturn': 15.02802,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2000-11-13 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inst',
#     'FundShareClassTypeId': '6',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap Institutional',
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '-27212728620.665',
#     'maximumManagementFee': '0.040000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 17.05426,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 20.9307, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.68508, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.05071, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Instl Pls',
#     'secId': 'F00000VE7X',
#     'securityType': 'FO',
#     'fundShareClassId': 'F00000VE7X',
#     'APIRCode': None,
#     'ticker': 'VSMPX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229083558',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-02-28 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-02-11 20:20:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.02,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.02,
#     'expenseRatio': 0.02,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 877945594480.0,
#     'minimumInitialInvestment': 100000000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.11596,
#     'secYield': 1.09,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '1',
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 17.05426,
#     'trailing3YearReturn': 20.9307,
#     'trailing5YearReturn': 12.68508,
#     'trailing10YearReturn': 15.05071,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2015-04-28 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inst',
#     'FundShareClassTypeId': '6',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap Institutional',
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '18721399517.555',
#     'maximumManagementFee': '0.020000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 17.06461,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 20.94321, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.69635, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.05659, 'epUsed': '1'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Instl Sel',
#     'secId': 'F00000WTNR',
#     'securityType': 'FO',
#     'fundShareClassId': 'F00000WTNR',
#     'APIRCode': None,
#     'ticker': 'VSTSX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229083301',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-02-28 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-02-11 20:20:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.01,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.01,
#     'expenseRatio': 0.01,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 49983150658.0,
#     'minimumInitialInvestment': 5000000000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.12286,
#     'secYield': 1.1,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '1',
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 17.06461,
#     'trailing3YearReturn': 20.94321,
#     'trailing5YearReturn': 12.69635,
#     'trailing10YearReturn': 15.05659,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '1',
#     'inceptionDate': '2016-06-27 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inst',
#     'FundShareClassTypeId': '6',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap Institutional',
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '-45090110120.556',
#     'maximumManagementFee': '0.010000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 16.9161,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 20.78845, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.55029, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 14.91217, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Inv',
#     'secId': 'FOUSA00FQU',
#     'securityType': 'FO',
#     'fundShareClassId': 'FOUSA00FQU',
#     'APIRCode': None,
#     'ticker': 'VTSMX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229083061',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-02-28 00:00:00.0',
#     'analystRating': '6',
#     'medalistRating': 'SILVER',
#     'analystRatingEndDate': '2026-02-11 20:20:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.14,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.06,
#     'expenseRatio': 0.06,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 24349883938.0,
#     'minimumInitialInvestment': 3000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.00952,
#     'secYield': 1.06,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '1',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': None,
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 16.9161,
#     'trailing3YearReturn': 20.78845,
#     'trailing5YearReturn': 12.55029,
#     'trailing10YearReturn': 14.91217,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '1992-04-27 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inv',
#     'FundShareClassTypeId': '7',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap No Load',
#     'Status': 'Closed',
#     'FundSizeCashFlowForYear': '-1493995037.148',
#     'maximumManagementFee': '0.050000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}}],
#  'template': 'USA_OE',
#  'fundSubType': None}

# %% [markdown]
# Sustainability data

# %%
funds.sustainability()
# Out:
# {}

# %% [markdown]
# Return of the fund after taxes
#
# Taxes
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.taxes()
# Out:
# {'categoryEndDate': '2026-02-28T06:00:00.000',
#  'returnEndDate': '2026-02-28T06:00:00.000',
#  'trailing1YearTaxCostRatio': None,
#  'trailing3YearTaxCostRatio': 0.34,
#  'trailing5YearTaxCostRatio': None,
#  'trailing10YearTaxCostRatio': None,
#  'trailing15YearTaxCostRatio': None,
#  'sinceInceptionTaxCostRatio': None,
#  'potentialCapitalGain': 0.596394,
#  'trailing1YearTaxCostRatioCategory': None,
#  'trailing3YearTaxCostRatioCategory': 1.27854,
#  'trailing5YearTaxCostRatioCategory': None,
#  'trailing10YearTaxCostRatioCategory': None,
#  'trailing15YearTaxCostRatioCategory': None,
#  'sinceInceptionTaxCostRatioCategory': None,
#  'priceTemplate': 'USA_OE'}

# %% [markdown]
# Traling Returns
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.trailingReturn()
# Out:
# {'columnDefs': ['1Day',
#   '1Week',
#   '1Month',
#   '3Month',
#   'YearToDate',
#   '1Year',
#   '3Year',
#   '5Year',
#   '10Year',
#   '15Year',
#   'SinceInception'],
#  'hasDailyData': True,
#  'investorRankApplicable': False,
#  'adjustedTaxReturnApplicable': False,
#  'duration': 'daily',
#  'totalReturnNAV': ['-0.5575',
#   '-1.6175',
#   '-3.13625',
#   '-2.66978',
#   '-2.72672',
#   '21.76393',
#   '20.83349',
#   '11.0264',
#   '14.04343',
#   '13.03361',
#   '8.65321'],
#  'netReturn': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'netOfFeesReturn': [],
#  'totalReturnNavEPFlag': [],
#  'totalReturnPrice': [],
#  'totalReturnCategory': [-0.05915999999999999,
#   0.11221000000000014,
#   0.19884000000000013,
#   -0.06962999999999964,
#   -0.006429999999999936,
#   2.9164499999999975,
#   1.9581499999999998,
#   0.42910000000000004,
#   0.96462,
#   0.8556799999999996,
#   None],
#  'totalReturnCategoryNew': [-0.49834,
#   -1.72971,
#   -3.33509,
#   -2.60015,
#   -2.72029,
#   18.84748,
#   18.87534,
#   10.5973,
#   13.07881,
#   12.17793,
#   None],
#  'totalReturnCategoryPrice': [],
#  'totalReturnCategoryEPFlag': [],
#  'fundNumber': [1215, 1212, 1208, 1193, 1200, 1140, 1061, 990, 785, 603, None],
#  'fundNumberPrice': [],
#  'totalReturnIndex': [0.025329999999999964,
#   -0.05708000000000002,
#   -0.27857999999999983,
#   0.14742000000000033,
#   0.3162900000000004,
#   0.2123199999999983,
#   -0.7079599999999999,
#   -0.8802199999999996,
#   -0.37264999999999837,
#   -0.3654400000000013,
#   None],
#  'totalReturnIndexNew': [-0.58283,
#   -1.56042,
#   -2.85767,
#   -2.8172,
#   -3.04301,
#   21.55161,
#   21.54145,
#   11.90662,
#   14.41608,
#   13.39905,
#   None],
#  'returnRank': [49, 45, 48, 49, 41, 25, 36, 51, 31, 31, None],
#  'returnMarketPriceRank': [],
#  'extendedPerformanceFlag': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'investorReturn': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'investorReturnRank': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'taxAdjustedReturn': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'taxAdjustedReturnRank': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'taxCostRatio': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US Large-Mid TR USD',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'overallMorningstarRating': 3,
#  'morningstarRatingFor3Year': 3,
#  'morningstarRatingFor5Year': 3,
#  'morningstarRatingFor10Year': 3,
#  'ePUsedForOverallRating': False,
#  'ePUsedFor3YearRating': False,
#  'ePUsedFor5YearRating': False,
#  'ePUsedFor10YearRating': False,
#  'fundReturnDate': '2026-03-13T05:00:00.000',
#  'fundPriceReturnDate': None,
#  'ratingDate': '2026-02-28T06:00:00.000',
#  'categoryDate': '2026-03-13T05:00:00.000',
#  'indexDate': '2026-03-13T05:00:00.000',
#  'fundInvestorDate': None,
#  'indexId': 'F00000GWXD',
#  'isDailyData': False,
#  'isMonthlyData': False,
#  'isQuarterlyData': False,
#  'inceptionDate': '2000-11-13T06:00:00.000',
#  'potentialCapitalGainsExposure': None,
#  'startDate': '2000-11-13T06:00:00.000',
#  'cur': 'USD',
#  'isUKCefTemplateAvailable': False,
#  'restructureDate': None}
