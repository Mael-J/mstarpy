# %% [markdown]
# # Fund Analysis
#
# In this example, we will explore all the key methods used to perform an in-depth analysis of a fund.

# %%
import mstarpy as ms

# %% [markdown]
# Initialize a session and keep it alive to scrape data with Selenium

# %%
session = ms.MorningstarSession()

# %% [markdown]
# Initialize Funds to start you analysis

# %%
funds = ms.Funds("VTSAX", session=session)
funds_2 = ms.Funds("IE00B04GQT48", session=session)

# %% [markdown]
# Find the fund name

# %%
print(funds.name)
print(funds_2.name)
# Out:
# Vanguard Total Stock Market Index Fund Admiral Shares
# Vanguard U.S. Investment Grade Credit Index Fund EUR Acc

# %% [markdown]
# Find the fund isin

# %%
funds.isin
# Out:
# 'US9229087286'

# %% [markdown]
# Asset allocation split of the fund, index and category
#
# Asset Allocation
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.allocationMap()
# Out:
# {'assetType': 'EQUITY',
#  'portfolioDate': '2026-05-31T05:00:00.000',
#  'portfolioDateCategory': '2026-05-31T05:00:00.000',
#  'portfolioDateIndex': '2026-05-31T05:00:00.000',
#  'portfolioDateGlobal': '2026-05-31T05:00:00.000',
#  'portfolioDateCategoryGlobal': '2026-05-31T05:00:00.000',
#  'portfolioDateIndexGlobal': '2026-05-31T05:00:00.000',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'allocationMap': {'AssetAllocCash': {'netAllocation': '0.42073',
#    'shortAllocation': None,
#    'longAllocation': '0.42073',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '1.53687',
#    'targetAllocation': None},
#   'AssetAllocNotClassified': {'netAllocation': '0.0',
#    'shortAllocation': None,
#    'longAllocation': '0.0',
#    'longAllocationIndex': '0.0',
#    'longAllocationCategory': '0.02562',
#    'targetAllocation': None},
#   'AssetAllocNonUSEquity': {'netAllocation': '0.60454',
#    'shortAllocation': None,
#    'longAllocation': '0.60454',
#    'longAllocationIndex': '0.62520',
#    'longAllocationCategory': '2.24525',
#    'targetAllocation': None},
#   'AssetAllocOther': {'netAllocation': '0.16027',
#    'shortAllocation': None,
#    'longAllocation': '0.16027',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '1.75123',
#    'targetAllocation': None},
#   'AssetAllocUSEquity': {'netAllocation': '98.81446',
#    'shortAllocation': None,
#    'longAllocation': '98.81446',
#    'longAllocationIndex': '99.37487',
#    'longAllocationCategory': '95.32859',
#    'targetAllocation': None},
#   'AssetAllocBond': {'netAllocation': '0.00000',
#    'shortAllocation': None,
#    'longAllocation': '0.00000',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '0.85353',
#    'targetAllocation': None}},
#  'japanAssetAllocation': None,
#  'countryCode': 'USA',
#  'securityType': None,
#  'dualViewData': None,
#  'targetDate': None,
#  'hasRegionalAssetAlloc': True,
#  'globalAllocationMap': {'assetAllocPreferred': {'netAllocation': '0.00000',
#    'shortAllocation': None,
#    'longAllocation': '0.00000',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '0.02531',
#    'targetAllocation': None},
#   'assetAllocOther': {'netAllocation': '0.16027',
#    'shortAllocation': None,
#    'longAllocation': '0.16027',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '1.75123',
#    'targetAllocation': None},
#   'assetAllocEquity': {'netAllocation': '99.41900',
#    'shortAllocation': None,
#    'longAllocation': '99.41900',
#    'longAllocationIndex': '100.00007',
#    'longAllocationCategory': '97.57384',
#    'targetAllocation': None},
#   'assetAllocCash': {'netAllocation': '0.42073',
#    'shortAllocation': None,
#    'longAllocation': '0.42073',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '1.53687',
#    'targetAllocation': None},
#   'assetAllocConvertible': {'netAllocation': '0.00000',
#    'shortAllocation': None,
#    'longAllocation': '0.00000',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '0.00031',
#    'targetAllocation': None},
#   'assetAllocFixedIncome': {'netAllocation': '0.00000',
#    'shortAllocation': None,
#    'longAllocation': '0.00000',
#    'longAllocationIndex': '0.00000',
#    'longAllocationCategory': '0.85353',
#    'targetAllocation': None}}}

# %% [markdown]
# Fund allocation by Market Capitalization and Style
#
# Stock Style - Weight
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.allocationWeighting()
# Out:
# {'portfolioDate': '2026-05-31T05:00:00.000',
#  'masterPortfolioId': '3506',
#  'largeValue': '18.64200',
#  'largeBlend': '33.89600',
#  'largeGrowth': '19.52300',
#  'middleValue': '5.71400',
#  'middleBlend': '8.64400',
#  'middleGrowth': '5.04400',
#  'smallValue': '2.82500',
#  'smallBlend': '3.73700',
#  'smallGrowth': '1.97400'}

# %% [markdown]
# Ratings of the asset manager funds

# %%
funds.analystRating()
# Out:
# [{'rating': '7',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.9053194587,
#   'noPremiumChinaFund': False},
#  {'rating': '6',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0504921989,
#   'noPremiumChinaFund': False},
#  {'rating': '5',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0294881863,
#   'noPremiumChinaFund': False},
#  {'rating': '4',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0076445849,
#   'noPremiumChinaFund': False},
#  {'rating': '3',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': '2',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': '1',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': '0',
#   'medalistRating': None,
#   'medalistRatingLabel': None,
#   'shareClassCount': 0,
#   'percent': 0.0070555713,
#   'noPremiumChinaFund': False}]

# %% [markdown]
# Rating and Performance of the best funds of the asset manager

# %%
funds.analystRatingTopFunds()
# Out:
# {'userType': 'Free',
#  'analystRatingFundList': [{'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': -3675204664.0,
#    'netAsset': 967688547381.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 23.26132,
#    'trailing3YearReturnRank': 33.0,
#    'fundShareClassId': 'F00000VE7X',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA002PT',
#    'secId': 'F00000VE7X',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': -32256404070.0,
#    'netAsset': 690292250669.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 23.55714,
#    'trailing3YearReturnRank': 24.0,
#    'fundShareClassId': 'FOUSA00L8W',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA002QH',
#    'secId': 'FOUSA00L8W',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': -23326815029.0,
#    'netAsset': 274018141189.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 20.39869,
#    'trailing3YearReturnRank': 28.0,
#    'fundShareClassId': 'FOUSA00KIR',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA004JJ',
#    'secId': 'FOUSA00KIR',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': -21368706418.0,
#    'netAsset': 220336782281.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 23.58254,
#    'trailing3YearReturnRank': 23.0,
#    'fundShareClassId': 'FOUSA00GPG',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA002Q0',
#    'secId': 'FOUSA00GPG',
#    'securityType': 'FO'},
#   {'rating': '7',
#    'medalistRating': None,
#    'medalistRatingLabel': None,
#    'disclosureCodes': None,
#    'calendarYearFlow': 37045340978.0,
#    'netAsset': 206720364043.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 3.92422,
#    'trailing3YearReturnRank': 59.0,
#    'fundShareClassId': 'FOUSA08OZU',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA09PA2',
#    'secId': 'FOUSA08OZU',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2026-05-31T05:00:00.000',
#  'footerReturnDate': '2026-05-31T05:00:00.000',
#  'currency': 'USD',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Recent change in ratings for asset manager funds

# %%
funds.analystRatingTopFundsUpDown()
# Out:
# {'topAnalystRatingUpDownList': [],
#  'userType': 'Free',
#  'currency': 'USD',
#  'securityType': 'FO',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'secId': 'FOUSA00L83',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Carbon metrics
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.carbonMetrics()
# Out:
# {'carbonPortfolioCoveragePct': None,
#  'carbonRiskScore': None,
#  'carbonRiskScoreCategoryAverage': '7.63087',
#  'carbonRiskScoreCategoryHigh': '31.30894',
#  'carbonRiskScoreCategoryLow': '0.00000',
#  'carbonRiskScoreCategoryAverageDate': '2022-12-31T06:00:00.000',
#  'carbonRiskScoreCategoryRankPct': None,
#  'carbonRiskScoreDate': '2026-04-30T05:00:00.000',
#  'categoryDate': '2022-12-31T06:00:00.000',
#  'categoryName': 'Large Blend',
#  'fossilFuelInvolvementPctCategoryAverage': '8.17663',
#  'fossilFuelInvolvementPct': '7.36026',
#  'fossilFuelInvolvementPctCategoryHigh': '100.00000',
#  'fossilFuelInvolvementPctCategoryLow': '0.00000',
#  'isLowCarbon': None,
#  'fossilFuelPercentageOfPortfolioCovered': '99.70043',
#  'portfolioCarbonRiskScore': '7.47438',
#  'carbonRiskPercentageOfPortfolioCovered': '99.13154',
#  'isDesignatedLowCarbon': 'false'}

# %% [markdown]
# Cost Illustration
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.costIllustration()
# Out:
# {'prospectusDate': '2026-04-28T05:00:00.000',
#  'expectedReturn': 5.0,
#  'initial': 10000.0,
#  'mer': None,
#  'priceTemplate': 'USA_OE',
#  'baseCurrencyId': 'USD',
#  'costItems': [{'year': 1,
#    'endNetAsset': 10499.90772386964,
#    'purchase': 0.0,
#    'ongoing': 4.0984318959,
#    'redemption': 0.0,
#    'total': 4.0984318959,
#    'purchasePer': 0.0,
#    'ongoingPer': 0.0003903303,
#    'redemptionPer': 0.0,
#    'totalPer': 0.0003903303},
#   {'year': 5,
#    'endNetAsset': 12759.994261123229,
#    'purchase': 0.0,
#    'ongoing': 22.6274729756,
#    'redemption': 0.0,
#    'total': 22.6274729756,
#    'purchasePer': 0.0,
#    'ongoingPer': 0.0017733137,
#    'redemptionPer': 0.0,
#    'totalPer': 0.0017733137},
#   {'year': 10,
#    'endNetAsset': 16275.500184834224,
#    'purchase': 0.0,
#    'ongoing': 51.4489152536,
#    'redemption': 0.0,
#    'total': 51.4489152536,
#    'purchasePer': 0.0,
#    'ongoingPer': 0.0031611265,
#    'redemptionPer': 0.0,
#    'totalPer': 0.0031611265}]}

# %% [markdown]
# Performance including and excluding fees

# %%
funds.costProjection()
# Out:
# {'initialInvestment': 10000.0,
#  'yearsToCalculate': 5,
#  'growthRatePercent': 5.0,
#  'returnExcludingFeeAmount': 12762.81563,
#  'returnIncludingFeeAmount': 12762.81563,
#  'returnFeeReductionAmount': 0.0,
#  'reducedRateOfReturn': 5.0,
#  'currency': 'USD'}

# %% [markdown]
# Coupon distributed by the fund, category and benchmark
#
# Bond Breakdown - Coupon Range
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.couponRange()
# Out:
# {'fundCouponRange': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'coupon0': 0.01287,
#   'coupon0To2': 3.45596,
#   'coupon2To4': 25.73077,
#   'coupon4To6': 61.22718,
#   'coupon6To8': 9.06612,
#   'coupon8To10': 0.45891,
#   'couponMoreThan10': 0.0},
#  'categoryCouponRange': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'name': 'USD Corporate Bond',
#   'coupon0': 0.06008,
#   'coupon0To2': 0.09299,
#   'coupon2To4': 17.34861,
#   'coupon4To6': 57.39738,
#   'coupon6To8': 21.8843,
#   'coupon8To10': 0.23363,
#   'couponMoreThan10': 0.0},
#  'benchmarkCouponRange': None,
#  'morningstarIndexCouponRange': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'name': 'Morningstar US Corp Bd TR USD',
#   'coupon0': 0.0,
#   'coupon0To2': 3.40899,
#   'coupon2To4': 25.71287,
#   'coupon4To6': 62.14054,
#   'coupon6To8': 8.31482,
#   'coupon8To10': 0.42295,
#   'couponMoreThan10': 0.0}}

# %% [markdown]
# Credit rating split of the fund, catory and benchmark
#
# Bond Breakdown - Credit quality
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.creditQuality()
# Out:
# {'fundName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'categoryName': 'USD Corporate Bond',
#  'indexName': 'Morningstar US Corp Bd TR USD',
#  'fund': {'creditQualityDate': '2026-04-30T05:00:00.000',
#   'creditQualityAAA': '6.61872',
#   'creditQualityAA': '13.29019',
#   'creditQualityA': '39.52497',
#   'creditQualityBBB': '39.26765',
#   'creditQualityBB': '0.00000',
#   'creditQualityB': '0.00000',
#   'creditQualityBelowB': '0.00000',
#   'creditQualityNotRated': '1.29844'},
#  'category': {'creditQualityDate': '2026-03-31T05:00:00.000',
#   'creditQualityAAA': '2.21740',
#   'creditQualityAA': '10.82406',
#   'creditQualityA': '38.68348',
#   'creditQualityBBB': '44.08453',
#   'creditQualityBB': '2.50533',
#   'creditQualityB': '0.78153',
#   'creditQualityBelowB': '0.61741',
#   'creditQualityNotRated': '0.28539'},
#  'index': {'creditQualityDate': None,
#   'creditQualityAAA': None,
#   'creditQualityAA': None,
#   'creditQualityA': None,
#   'creditQualityBBB': None,
#   'creditQualityBB': None,
#   'creditQualityB': None,
#   'creditQualityBelowB': None,
#   'creditQualityNotRated': None}}

# %% [markdown]
# Coupon distributed by the fund
#
# Performance - Distributions
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.distribution("annual")
# Out:
# {'distribution': [{'distributionDate': '2026-03-27T05:00:00.000',
#    'distributionNav': 152.42,
#    'income': 0.4808,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 0.4808,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2025-12-22T06:00:00.000',
#    'distributionNav': 164.37,
#    'income': 1.8136,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.8136,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2024-12-23T06:00:00.000',
#    'distributionNav': 143.11,
#    'income': 1.7759,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.7759,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2023-12-20T06:00:00.000',
#    'distributionNav': 113.64,
#    'income': 1.651,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.651,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None},
#   {'distributionDate': '2022-12-21T06:00:00.000',
#    'distributionNav': 94.0,
#    'income': 1.5396999999999998,
#    'capGainShortTerm': 0.0,
#    'capGainLongTerm': 0.0,
#    'returnOfCapital': 0.0,
#    'total': 1.5396999999999998,
#    'interestIncome': None,
#    'foreignIncome': None,
#    'capitalGains': None,
#    'canadianDividend': None}],
#  'baseCurrencyId': 'USD',
#  'template': 'OE_USA_EQUITY'}

# %% [markdown]
# Download a PDF file
#
# https://global.morningstar.com/fr/investissements/fonds/0P0000GFVM/documents

# %%
funds_2.downloadDocument("fr","PRIIP KID","en")
# Out:
# {'page': {'securityID': 'F0000022KV', 'performanceID': '0P0000GFVM', 'fundID': 'FSGBR065UB', 'masterPortfolioID': '107906', 'universe': 'FO', 'countriesOfSale': ['AUT', 'CHE', 'DEU', 'DNK', 'ESP', 'FIN', 'FRA', 'GBR', 'IRL', 'ITA', 'LIE', 'LUX', 'NLD', 'NOR', 'PRT', 'SWE'], 'investmentType': 'FO', 'isin': 'IE00B04GQT48', 'name': 'Vanguard U.S. Investment Grade Credit Index Fund EUR Acc', 'domicile': 'IRL', 'allowedMarketIds': ['at', 'bnl', 'eu', 'dk', 'fi', 'fr', 'de', 'ie', 'it', 'lu', 'nl', 'nord', 'no', 'pt', 'es', 'se', 'ch', 'gb'], 'identifierField': 'isin', 'fundStarRating': 3, 'fundStarRatingDate': '2026-05-31', 'medalistRating': 'Gold'}, 'components': {'ads': {'status': 200, 'payload': {'fundcat': 'USDCorporateBond', 'familyid': '0C000022HA', 'brandingNameId': 'BN00000AAL', 'sustainabilityRating': 3}}, 'documents': {'status': 200, 'payload': [{'id': '4', 'name': 'Annual Report', 'categoryId': 'shareholder', 'documents': [{'effectiveDate': '2025-12-31', 'postedDate': '2026-05-04', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-12-31', 'postedDate': '2013-05-08', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '52', 'name': 'Factsheet', 'categoryId': 'other', 'documents': [{'effectiveDate': '2026-05-31', 'postedDate': '2026-06-17', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2026-05-31', 'postedDate': '2026-06-17', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '299', 'name': 'PRIIP KID', 'categoryId': 'offering', 'documents': [{'effectiveDate': '2026-03-24', 'postedDate': '2026-03-26', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2026-03-24', 'postedDate': '2026-03-26', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '1', 'name': 'Prospectus', 'categoryId': 'offering', 'documents': [{'effectiveDate': '2026-06-03', 'postedDate': '2026-06-09', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2016-05-02', 'postedDate': '2017-11-28', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '5', 'name': 'Semi-Annual Report', 'categoryId': 'shareholder', 'documents': [{'effectiveDate': '2025-06-30', 'postedDate': '2025-09-03', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-06-30', 'postedDate': '2013-04-21', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}]}}}
# {'status': 200,
#  'mesage': 'File downloaded',
#  'filename': 'PRIIP KID-F0000022KV-2026-03-24-20260618193459.pdf',
#  'folder': '.'}

# %% [markdown]
# Yield and growth forecast for the Equity fund, category and benchmark
#
# Style Measures - Measures
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.equityStyle()
# Out:
# {'portfolioDate': '2026-05-31T05:00:00.000',
#  'assetType': 'EQUITY',
#  'fund': {'prospectiveEarningsYield': 21.55032,
#   'prospectiveBookValueYield': 4.32487,
#   'prospectiveRevenueYield': 2.85335,
#   'prospectiveCashFlowYield': 15.33628,
#   'prospectiveDividendYield': 1.14274,
#   'forecasted5YearEarningsGrowth': 11.56744,
#   'forecastedEarningsGrowth': 3.63318,
#   'forecastedBookValueGrowth': -22.63485,
#   'forecastedRevenueGrowth': -17.5104,
#   'forecastedCashFlowGrowth': 10.40566,
#   'portfolioDate': '2026-05-31T05:00:00.000',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'secId': 'FOUSA00L83',
#   'currencyId': 'USD'},
#  'categoryAverage': {'prospectiveEarningsYield': 20.78496,
#   'prospectiveBookValueYield': 4.82157,
#   'prospectiveRevenueYield': 2.05021,
#   'prospectiveCashFlowYield': 15.54409,
#   'prospectiveDividendYield': 1.12039,
#   'forecasted5YearEarningsGrowth': 10.36073,
#   'forecastedEarningsGrowth': 16.46781,
#   'forecastedBookValueGrowth': 7.40527,
#   'forecastedRevenueGrowth': 1.55336,
#   'forecastedCashFlowGrowth': 12.01712,
#   'portfolioDate': '2026-05-31T05:00:00.000',
#   'name': 'Large Blend',
#   'secId': '$FOCA$LB$$',
#   'currencyId': ''},
#  'indexAverage': {'prospectiveEarningsYield': 22.2222,
#   'prospectiveBookValueYield': 4.81051,
#   'prospectiveRevenueYield': 3.20981,
#   'prospectiveCashFlowYield': 16.17106,
#   'prospectiveDividendYield': 1.10995,
#   'forecasted5YearEarningsGrowth': 11.58072,
#   'forecastedEarningsGrowth': 10.40626,
#   'forecastedBookValueGrowth': 9.82928,
#   'forecastedRevenueGrowth': 6.70081,
#   'forecastedCashFlowGrowth': 11.79614,
#   'portfolioDate': '2026-05-31T05:00:00.000',
#   'name': 'Morningstar US LM Cap Mkt TR USD',
#   'secId': 'F00000GWXD',
#   'currencyId': ''}}

# %% [markdown]
# Historical equity exposure and style
# 1 = Large Value, 2 = Large Blend, 3 = Large Growth,
# 4 = Mid Value, 5 = Mid Blend, 6 = Mid Growth
# 7 = Small Value, 8 = Small Blend, 9 = Small Growth
#
# Stock Style - historical
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.equityStyleBoxHistory()
# Out:
# {'history': [{'year': 2026,
#    'portfolioDate': '2026-05-31T05:00:00.000',
#    'style': 2,
#    'percentage': 99.419,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2025,
#    'portfolioDate': '2025-12-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.4358,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2024,
#    'portfolioDate': '2024-12-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.61408,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2023,
#    'portfolioDate': '2023-12-31T06:00:00.000',
#    'style': 3,
#    'percentage': 99.54633,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'},
#   {'year': 2022,
#    'portfolioDate': '2022-12-31T06:00:00.000',
#    'style': 2,
#    'percentage': 99.02589,
#    'relativeVolatility': None,
#    'categoryName': 'US Fund Large Blend'}],
#  'secId': 'FOUSA00L83',
#  'masterPortfolioId': '3506',
#  'asOfDate': '2026-05-31T05:00:00.000'}

# %% [markdown]
# Environment, Social and Governance data

# %%
funds.esgData()
# Out:
# {'userType': 'Free',
#  'esgData': {'sociallyResponsibleFund': None,
#   'ethicalIssueStrategyFocus': None,
#   'portfolioDate': '2026-04-30T00:00:00.000',
#   'portfolioDateSustainabilityRating': '2026-04-30T05:00:00.000',
#   'fundESGScore': None,
#   'percentAUMCoveredESG': 99.20939,
#   'fundSustainabilityScore': 19.29,
#   'percentAUMCoveredControversy': 99.76025,
#   'categoryRankDate': '2026-04-30T05:00:00.000',
#   'sustainabilityFundQuintile': 2,
#   'sustainabilityPercentCategoryRank': 72.0,
#   'sustainabilityMandate': 'No',
#   'secId': 'FOUSA00L83',
#   'performanceId': '0P00002YGZ',
#   'tradingSymbol': None,
#   'iSIN': None,
#   'fundId': 'FSUSA002PT',
#   'masterPortfolioId': '3506',
#   'categoryId': '$FOCA$LB$$',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'controversyDeduction': None,
#   'categoryName': 'Large Blend',
#   'globalCategoryName': 'US Equity Large Cap Blend',
#   'fundHistoryAvgSustainabilityScore': 19.55893,
#   'historicalSustainabilityScoreGlobalCategoryAverage': 19.17656,
#   'currentSustainabilityScoreGlobalCategoryAverage': 19.03414,
#   'numberofFundsAnalyzedinCategorySustainability': 3990,
#   'HistoryAvgSustainabilityPercentCategoryRank': None,
#   'sustainabilityRatingCorporateContributionPercent': 100.0,
#   'sustainabilityRatingSovereignContributionPercent': 0.0,
#   'portfolioSovereignsustainabilityscore': None,
#   'historicalSovereignSustainabilityScore': None,
#   'historicalSovereignSustainabilityCategoryAverage': 13.75386,
#   'sovereignSustainabilityRatingPercentOfEligiblePortfolioCovered': None,
#   'sustainabilityMandateSurveyed': None},
#  'esgScoreCalculation': {'basedPercentAUM': 99.20939,
#   'portfolioESGScore': None,
#   'portfolioESGScoreCategory': None,
#   'controversyScore': None,
#   'controversyScoreCategory': None,
#   'sustainabilityScore': 19.29,
#   'sustainabilityScoreCategory': 19.03414,
#   'environmentalScore': 5.2,
#   'environmentalScoreCategory': None,
#   'socialScore': 8.02,
#   'socialScoreCategory': None,
#   'governanceScore': 4.6,
#   'governanceScoreCategory': None,
#   'portfolioDate': '2026-04-30T05:00:00.000',
#   'portfolioSustainabilityScore': 19.29,
#   'portfolioEnvironmentalRiskScore': 5.2,
#   'portfolioSocialRiskScore': 8.02,
#   'portfolioGovernanceRiskScore': 4.6,
#   'portfolioUnallocatedEsgRiskScore': 1.47,
#   'percentAUMCoveredControversy': 99.76025,
#   'esgFundQuintile': None,
#   'esgPercentCategoryRank': None,
#   'controversyFundQuintile': None,
#   'controversyPercentCategoryRank': None,
#   'ePercentCategoryRank': None,
#   'sPercentCategoryRank': None,
#   'gPercentCategoryRank': None,
#   'categoryRankDate': '2026-04-30T05:00:00.000',
#   'historicalSustainabilityScoreGlobalCategoryAverage': 19.17656,
#   'currentSustainabilityScoreGlobalCategoryAverage': 19.03414,
#   'HistoryAvgSustainabilityPercentCategoryRank': 72.0,
#   'numberofFundsAnalyzedinCategorySustainability': 3990},
#  'esgHoldingsAnalyst': '_PO_',
#  'esgScoreDistribution': '_PO_',
#  'esgLevelDistribution': '_PO_',
#  'sustainabilityIntentionality': {'investmentId': 'FSUSA002PT',
#   'eSGIncorporation': False,
#   'eSGEngagement': False,
#   'genderDiversity': False,
#   'lowCarbonFossilFuelFree': False,
#   'communityDevelopment': False,
#   'environmental': False,
#   'otherImpactThemes': False,
#   'renewableEnergy': False,
#   'waterFocused': False,
#   'generalEnvironmentalSector': False,
#   'sustainableInvestmentOverall': False,
#   'eSGFundOverall': False,
#   'impactFundOverall': False,
#   'environmentalSectorOverall': False,
#   'createdOn': '2019-05-01 04:01:00.0',
#   'lastUpdateDate': '2025-06-03 04:04:00.0',
#   'usesNormsBasedScreening': None,
#   'excludesAbortionStemCells': None,
#   'excludesAdultEntertainment': None,
#   'excludesAlcohol': None,
#   'excludesAnimalTesting': None,
#   'excludesControversialWeapons': None,
#   'excludesFurSpecialtyLeather': None,
#   'excludesGambling': None,
#   'excludesGMOs': None,
#   'excludesMilitaryContracting': None,
#   'excludesNuclear': None,
#   'excludesPalmOil': None,
#   'excludesPesticides': None,
#   'excludesSmallArms': None,
#   'excludesThermalCoal': None,
#   'excludesTobacco': None,
#   'excludesOther': None,
#   'employsExclusionsOverall': None}}

# %% [markdown]
# Environment, Social and Governance risk
#
# Sustainability - Risk
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.esgRisk()
# Out:
# {'sustainabilityFundQuintile': 2,
#  'fundHistoryAvgSustainabilityScore': 19.55893,
#  'fundSustainabilityScore': 19.29,
#  'historicalSustainabilityScoreGlobalCategoryAverage': 19.17656,
#  'historicalSovereignSustainabilityScore': None,
#  'portfolioSovereignSustainabilityScore': None,
#  'historicalSovereignSustainabilityCategoryAverage': 13.75386,
#  'percentAUMCoveredESG': 99.20939,
#  'sovereignSustainabilityRatingPercentOfEligiblePortfolioCovered': None,
#  'globalCategoryName': 'US Equity Large Cap Blend',
#  'categoryRankDate': '2026-04-30T00:00:00.000',
#  'portfolioDateSustainabilityRating': '2026-04-30T05:00:00.000',
#  'categoryId': '$FOCA$LB$$',
#  'portfolioDate': '2026-04-30T00:00:00.000',
#  'carbon': {'carbonPortfolioCoveragePct': None,
#   'carbonRiskScore': None,
#   'carbonRiskScoreCategoryAverage': '7.63087',
#   'carbonRiskScoreCategoryHigh': '31.30894',
#   'carbonRiskScoreCategoryLow': '0.00000',
#   'carbonRiskScoreCategoryAverageDate': '2022-12-31T06:00:00.000',
#   'carbonRiskScoreCategoryRankPct': None,
#   'carbonRiskScoreDate': '2026-04-30T05:00:00.000',
#   'categoryDate': '2022-12-31T06:00:00.000',
#   'categoryName': 'Large Blend',
#   'fossilFuelInvolvementPctCategoryAverage': '8.17663',
#   'fossilFuelInvolvementPct': '7.36026',
#   'fossilFuelInvolvementPctCategoryHigh': '100.00000',
#   'fossilFuelInvolvementPctCategoryLow': '0.00000',
#   'isLowCarbon': None,
#   'fossilFuelPercentageOfPortfolioCovered': '99.70043',
#   'portfolioCarbonRiskScore': '7.47438',
#   'carbonRiskPercentageOfPortfolioCovered': '99.13154',
#   'isDesignatedLowCarbon': 'false'}}

# %% [markdown]
# Factor Style, Yield, Momemtum, Quality, Volatility, Liquidity and Size
# of the fund, category and benchmark
#
# Factor Profile
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.factorProfile()
# Out:
# {'secId': 'FOUSA00L83',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryId': '$FOCA$LB$$',
#  'categoryName': 'Large Blend',
#  'indexId': 'F00000GWXD',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'indexEffectiveDate': '2026-04-30',
#  'categoryEffectiveDate': '2026-04-30',
#  'ticker': 'VTSAX',
#  'id': '0P00002YGZ',
#  'effectiveDate': '2026-04-30',
#  'endDate': '2026-04-30',
#  'factors': {'style': {'categoryAvg': 55.451326,
#    'indexAvg': 47.37133,
#    'percentile': 56.464675,
#    'historicRange': [{'year': '1', 'min': 49.521975, 'max': 56.464675},
#     {'year': '3', 'min': 46.715419, 'max': 56.464675},
#     {'year': '5', 'min': 42.936172, 'max': 56.464675}]},
#   'yield': {'categoryAvg': 55.883142,
#    'indexAvg': 64.9166,
#    'percentile': 56.7909,
#    'historicRange': [{'year': '1', 'min': 56.7909, 'max': 59.908728},
#     {'year': '3', 'min': 54.195932, 'max': 59.908728},
#     {'year': '5', 'min': 48.813473, 'max': 59.908728}]},
#   'quality': {'categoryAvg': 26.031125,
#    'indexAvg': 30.391833,
#    'percentile': 45.125573,
#    'historicRange': [{'year': '1', 'min': 39.786053, 'max': 46.36145},
#     {'year': '3', 'min': 38.308305, 'max': 46.36145},
#     {'year': '5', 'min': 38.308305, 'max': 48.209574}]},
#   'momentum': {'categoryAvg': 46.45254,
#    'indexAvg': 45.959261,
#    'percentile': 50.90623,
#    'historicRange': [{'year': '1', 'min': 43.19784, 'max': 50.90623},
#     {'year': '3', 'min': 37.721129, 'max': 50.90623},
#     {'year': '5', 'min': 37.721129, 'max': 57.935967}]},
#   'volatility': {'categoryAvg': 79.878855,
#    'indexAvg': 51.607536,
#    'percentile': 51.820292,
#    'historicRange': [{'year': '1', 'min': 42.210801, 'max': 51.820292},
#     {'year': '3', 'min': 42.127391, 'max': 51.820292},
#     {'year': '5', 'min': 42.127391, 'max': 51.820292}]},
#   'liquidity': {'categoryAvg': 88.735804,
#    'indexAvg': 66.966936,
#    'percentile': 54.880825,
#    'historicRange': [{'year': '1', 'min': 54.02147, 'max': 57.509221},
#     {'year': '3', 'min': 52.956601, 'max': 61.303616},
#     {'year': '5', 'min': 50.236227, 'max': 61.999565}]},
#   'size': {'categoryAvg': 79.729138,
#    'indexAvg': 74.785321,
#    'percentile': 55.533277,
#    'historicRange': [{'year': '1', 'min': 55.533277, 'max': 60.175615},
#     {'year': '3', 'min': 55.533277, 'max': 60.175615},
#     {'year': '5', 'min': 54.95907, 'max': 60.175615}]}}}

# %% [markdown]
# Ongoing Fee Level
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.feeLevel()
# Out:
# {'morningstarFeeLevelRankDate': '2026-05-31T05:00:00.000',
#  'morningstarFeeLevelGroup': 'IC00000272',
#  'name': 'Large Cap Institutional',
#  'morningstarFeeLevel': 1,
#  'morningstarFeeLevelPercentileRank': 3.0,
#  'morningstarFeeLevelGroupSize': 892.0,
#  'median': 0.68,
#  'morningstarFeeLevelGroupStartingDistribution': 0.0,
#  'morningstarFeeLevelGroup1stBreakpointDistribution': 0.46,
#  'morningstarFeeLevelGroup2ndBreakpointDistribution': 0.64,
#  'morningstarFeeLevelGroup3rdBreakpointDistribution': 0.72,
#  'morningstarFeeLevelGroup4thBreakpointDistribution': 0.83,
#  'morningstarFeeLevelGroupEndBreakpointDistribution': 1.54,
#  'fundFee': None,
#  'reportDate': '2025-12-31T06:00:00.000',
#  'peerMedian': None,
#  'fundIndex': None,
#  'prospectusExpenseRatio': 0.04,
#  'adjustedProspectusExpenseRatio': 0.04,
#  'icrFund': None,
#  'priceTemplate': 'USA_OE',
#  'morningstarTotalCostRatioPDS': None,
#  'ongoingCostChargeDate': None,
#  'fundSubType': None,
#  'PRIIPSKIDOngoingCostsOtherCosts': None,
#  'PRIIPSKIDOngoingCostsOtherCostsDate': None}

# %% [markdown]
# MiFID fees
#
# Price
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/quote

# %%
funds_2.feeMifid()
# Out:
# {'dbgtime': '135',
#  'Id': 'F0000022KV',
#  'Name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'Mifid': {'SummaryRiskIndicator': 3,
#   'SummaryRiskIndicatorDate': '2026-01-31T00:00:00',
#   'PerformanceFeeEstimated': 0.0,
#   'PerformanceFeeEstimatedDate': '2024-07-31T00:00:00',
#   'TransactionFeeActual': 0.038,
#   'TransactionFeeActualDate': '2026-01-31T00:00:00',
#   'TransactionFeeEstimated': 0.0404,
#   'TransactionFeeEstimatedDate': '2026-01-31T00:00:00',
#   'PerformanceFeeActual': 0.0,
#   'PerformanceFeeActualDate': '2024-07-31T00:00:00',
#   'OngoingCostEstimated': 0.1203,
#   'OngoingCostEstimatedDate': '2026-01-31T00:00:00',
#   'OngoingCostActual': 0.1203,
#   'OngoingCostActualDate': '2026-01-31T00:00:00',
#   'MaximumEntryCostAcquired': 0.0,
#   'MaximumEntryCostAcquiredDate': '2026-01-31T00:00:00',
#   'MaximumExitCostAcquired': 0.0,
#   'MaximumExitCostAcquiredDate': '2026-01-31T00:00:00',
#   'TypicalExitCost': 0.0,
#   'TypicalExitCostDate': '2026-01-31T00:00:00',
#   'ManagementFeeExDistFeeActual': 0.12,
#   'ManagementFeeExDistFeeActualDate': '2026-01-31T00:00:00',
#   'ManagementFeeExDistFeeEstimate': 0.12,
#   'ManagementFeeExDistFeeEstimateDate': '2026-01-31T00:00:00',
#   'DistributionFeePercOfNAVActual': 0.0,
#   'DistributionFeePercOfNAVActualDate': '2026-01-31T00:00:00',
#   'DistributionFeePercOfNAVEstimated': 0.0,
#   'InvestorTypeRetail': 'Y',
#   'InvestorTypeProfessional': 'Y',
#   'InvestorTypeEligibleCounterparty': 'Y',
#   'ExpertiseBasic': 'Y',
#   'ExpertiseInformed': 'Y',
#   'ExpertiseAdvanced': 'Y',
#   'DistributionExecutionOnly': 'Both (Retail and Professional)',
#   'DistributionInvestmentAdvice': 'Both (Retail and Professional)',
#   'DistributionPortfolioManagement': 'Both (Retail and Professional)',
#   'DistExecAppTestNonAdv': 'Both (Retail and Professional)',
#   'CapitalLossNone': 'N',
#   'CapitalLossLimited': 'Neutral',
#   'MaximumExitFees': [{'Date': '2026-01-31',
#     'Unit': '1',
#     'Value': 0.0,
#     'Currency': 'EUR'},
#    {'Date': '2026-01-31', 'Unit': '2', 'Value': 0.0, 'Currency': 'EUR'}],
#   'MaximumExitFeesDate': '2026-01-31T00:00:00',
#   'CapitalLossNoGuarantee': 'Y',
#   'CapitalLossBeyondInitial': 'Y',
#   'ReturnProfilePreservation': 'Neutral',
#   'ReturnProfileGrowth': 'Y',
#   'ReturnProfileIncome': 'Neutral',
#   'ReturnProfileHedging': 'Neutral',
#   'ReturnProfileOptionOrLeveraged': 'Neutral',
#   'ReturnProfileOther': 'Neutral',
#   'ReturnProfilePensionSchemeGermany': 'Neutral',
#   'LeverageProduct': 'N',
#   'MIFIDInstrumentType': 'UCITS',
#   'ExpertiseExpertInvestorGermany': 'Y',
#   'NotForInvWithLowRiskTolGermany': 'Neutral',
#   'RecommendedHoldingPeriod': '7',
#   'EMTTransactionCostsEstimatedUK': 0.04,
#   'EMTTransactionCostsEstimatedDateUK': '2026-01-31',
#   'EMTTransactionCostsActualUK': 0.038,
#   'EMTTransactionCostsActualDateUK': '2026-01-31',
#   'EMTValueAssessmentReviewDateUK': '2025-06-30',
#   'EMTEffectiveDate': '2025-06-30',
#   'EMTDataReportingValueForMoneyUK': True,
#   'EMTIsAssessmentOfValueRequiredUnderCOLLUK': False,
#   'EMTOutcomeOfPRINValueAssessmentOrReviewCodeUK': 1,
#   'EMTValueAssessmentReviewNextDateUK': '2026-06-30'},
#  'CollectedSRRI': {'Date': '2026-01-31T00:00:00', 'Rank': 4},
#  'KID': {'SRI': 3}}

# %% [markdown]
# Financial metrics of fund, category and benchmark

# %%
funds_2.financialMetrics()
# Out:
# {'userType': 'Free',
#  'fund': {'masterPortfolioId': '107906',
#   'portfolioDate': '2026-05-31T05:00:00.000',
#   'wideMoatPercentage': '_PO_',
#   'narrowMoatPercentage': '_PO_',
#   'noMoatPercentage': '_PO_',
#   'financialHealthGradeType': '_PO_',
#   'profitabilityGradeType': '_PO_',
#   'growthGradeType': '_PO_',
#   'roic': '_PO_',
#   'cashReturn': '_PO_',
#   'freeCashFlowYield': '_PO_',
#   'debtToCapital': '_PO_',
#   'securityName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc'},
#  'category': {'masterPortfolioId': '211369',
#   'portfolioDate': '2026-05-31T05:00:00.000',
#   'wideMoatPercentage': '_PO_',
#   'narrowMoatPercentage': '_PO_',
#   'noMoatPercentage': '_PO_',
#   'financialHealthGradeType': '_PO_',
#   'profitabilityGradeType': '_PO_',
#   'growthGradeType': '_PO_',
#   'roic': '_PO_',
#   'cashReturn': '_PO_',
#   'freeCashFlowYield': '_PO_',
#   'debtToCapital': '_PO_',
#   'securityName': 'USD Corporate Bond'},
#  'index': {'masterPortfolioId': '1861103',
#   'portfolioDate': '2026-05-31T05:00:00.000',
#   'wideMoatPercentage': '_PO_',
#   'narrowMoatPercentage': '_PO_',
#   'noMoatPercentage': '_PO_',
#   'financialHealthGradeType': '_PO_',
#   'profitabilityGradeType': '_PO_',
#   'growthGradeType': '_PO_',
#   'roic': '_PO_',
#   'cashReturn': '_PO_',
#   'freeCashFlowYield': '_PO_',
#   'debtToCapital': '_PO_',
#   'securityName': 'Morningstar US Corp Bd TR USD'}}

# %% [markdown]
# Fixed Income metrics for the fund, category and benchmark
#
# Fixed Income style - Current
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.fixedIncomeStyle()
# Out:
# {'isCan': False,
#  'portfolioDate': '2026-05-31T05:00:00.000',
#  'assetType': 'FIXEDINCOME',
#  'fixedIncStyleBox': 6,
#  'fund': {'secId': 'F0000022KV',
#   'secName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'portfolioDate': '2026-05-31T05:00:00.000',
#   'avgEffectiveDuration': 6.07626,
#   'modifiedDuration': 6.16555,
#   'avgEffectiveMaturity': 9.27725,
#   'avgCreditQualityName': 'A-',
#   'surveyedAverageSurveyedCreditRating': 'A-',
#   'calculatedAverageCreditRating': 'A-',
#   'avgCreditQualityDate': '2026-04-30T05:00:00.000',
#   'avgCoupon': 4.58859,
#   'avgPrice': 96.1727,
#   'yieldToMaturity': 5.05234},
#  'categoryAverage': {'secId': 'EUCA000691',
#   'secName': 'USD Corporate Bond',
#   'portfolioDate': '2026-05-31T05:00:00.000',
#   'avgEffectiveDuration': 5.7595,
#   'modifiedDuration': 5.72388,
#   'avgEffectiveMaturity': 9.05172,
#   'avgCreditQualityName': 'A-',
#   'surveyedAverageSurveyedCreditRating': 'A-',
#   'calculatedAverageCreditRating': 'A-',
#   'avgCreditQualityDate': '2026-03-31T05:00:00.000',
#   'avgCoupon': 5.27374,
#   'avgPrice': 96.81046,
#   'yieldToMaturity': 5.20181}}

# %% [markdown]
# Historical Fixed Income Style
#
# Fixed Income Style - Historical
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.fixedincomeStyleBoxHistory()
# Out:
# {'history': [{'year': 2026,
#    'portfolioDate': '2026-05-31T05:00:00.000',
#    'style': 6,
#    'percentage': 99.91954,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2025,
#    'portfolioDate': '2025-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.95802,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2024,
#    'portfolioDate': '2024-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.95603,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2023,
#    'portfolioDate': '2023-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.89898,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'},
#   {'year': 2022,
#    'portfolioDate': '2022-12-31T06:00:00.000',
#    'style': 6,
#    'percentage': 99.86471,
#    'relativeVolatility': None,
#    'categoryName': 'EAA Fund USD Corporate Bond'}],
#  'secId': 'F0000022KV',
#  'masterPortfolioId': '107906',
#  'asOfDate': '2026-05-31T05:00:00.000'}

# %% [markdown]
# Available documents and their countries
#
# https://global.morningstar.com/fr/investissements/fonds/0P0000GFVM/documents

# %%
funds_2.getDocumentInformation("fr")
# Out:
# {'page': {'securityID': 'F0000022KV', 'performanceID': '0P0000GFVM', 'fundID': 'FSGBR065UB', 'masterPortfolioID': '107906', 'universe': 'FO', 'countriesOfSale': ['AUT', 'CHE', 'DEU', 'DNK', 'ESP', 'FIN', 'FRA', 'GBR', 'IRL', 'ITA', 'LIE', 'LUX', 'NLD', 'NOR', 'PRT', 'SWE'], 'investmentType': 'FO', 'isin': 'IE00B04GQT48', 'name': 'Vanguard U.S. Investment Grade Credit Index Fund EUR Acc', 'domicile': 'IRL', 'allowedMarketIds': ['at', 'bnl', 'eu', 'dk', 'fi', 'fr', 'de', 'ie', 'it', 'lu', 'nl', 'nord', 'no', 'pt', 'es', 'se', 'ch', 'gb'], 'identifierField': 'isin', 'fundStarRating': 3, 'fundStarRatingDate': '2026-05-31', 'medalistRating': 'Gold'}, 'components': {'ads': {'status': 200, 'payload': {'fundcat': 'USDCorporateBond', 'familyid': '0C000022HA', 'brandingNameId': 'BN00000AAL', 'sustainabilityRating': 3}}, 'documents': {'status': 200, 'payload': [{'id': '4', 'name': 'Annual Report', 'categoryId': 'shareholder', 'documents': [{'effectiveDate': '2025-12-31', 'postedDate': '2026-05-04', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-12-31', 'postedDate': '2013-05-08', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '52', 'name': 'Factsheet', 'categoryId': 'other', 'documents': [{'effectiveDate': '2026-05-31', 'postedDate': '2026-06-17', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2026-05-31', 'postedDate': '2026-06-17', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '299', 'name': 'PRIIP KID', 'categoryId': 'offering', 'documents': [{'effectiveDate': '2026-03-24', 'postedDate': '2026-03-26', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2026-03-24', 'postedDate': '2026-03-26', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '1', 'name': 'Prospectus', 'categoryId': 'offering', 'documents': [{'effectiveDate': '2026-06-03', 'postedDate': '2026-06-09', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2016-05-02', 'postedDate': '2017-11-28', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}, {'id': '5', 'name': 'Semi-Annual Report', 'categoryId': 'shareholder', 'documents': [{'effectiveDate': '2025-06-30', 'postedDate': '2025-09-03', 'mimeType': 'application/pdf', 'languages': ['en']}, {'effectiveDate': '2012-06-30', 'postedDate': '2013-04-21', 'mimeType': 'application/pdf', 'languages': ['fr']}], 'mimeType': 'application/pdf'}]}}}
# {'page': {'securityID': 'F0000022KV',
#   'performanceID': '0P0000GFVM',
#   'fundID': 'FSGBR065UB',
#   'masterPortfolioID': '107906',
#   'universe': 'FO',
#   'countriesOfSale': ['AUT',
#    'CHE',
#    'DEU',
#    'DNK',
#    'ESP',
#    'FIN',
#    'FRA',
#    'GBR',
#    'IRL',
#    'ITA',
#    'LIE',
#    'LUX',
#    'NLD',
#    'NOR',
#    'PRT',
#    'SWE'],
#   'investmentType': 'FO',
#   'isin': 'IE00B04GQT48',
#   'name': 'Vanguard U.S. Investment Grade Credit Index Fund EUR Acc',
#   'domicile': 'IRL',
#   'allowedMarketIds': ['at',
#    'bnl',
#    'eu',
#    'dk',
#    'fi',
#    'fr',
#    'de',
#    'ie',
#    'it',
#    'lu',
#    'nl',
#    'nord',
#    'no',
#    'pt',
#    'es',
#    'se',
#    'ch',
#    'gb'],
#   'identifierField': 'isin',
#   'fundStarRating': 3,
#   'fundStarRatingDate': '2026-05-31',
#   'medalistRating': 'Gold'},
#  'components': {'ads': {'status': 200,
#    'payload': {'fundcat': 'USDCorporateBond',
#     'familyid': '0C000022HA',
#     'brandingNameId': 'BN00000AAL',
#     'sustainabilityRating': 3}},
#   'documents': {'status': 200,
#    'payload': [{'id': '4',
#      'name': 'Annual Report',
#      'categoryId': 'shareholder',
#      'documents': [{'effectiveDate': '2025-12-31',
#        'postedDate': '2026-05-04',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2012-12-31',
#        'postedDate': '2013-05-08',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'},
#     {'id': '52',
#      'name': 'Factsheet',
#      'categoryId': 'other',
#      'documents': [{'effectiveDate': '2026-05-31',
#        'postedDate': '2026-06-17',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2026-05-31',
#        'postedDate': '2026-06-17',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'},
#     {'id': '299',
#      'name': 'PRIIP KID',
#      'categoryId': 'offering',
#      'documents': [{'effectiveDate': '2026-03-24',
#        'postedDate': '2026-03-26',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2026-03-24',
#        'postedDate': '2026-03-26',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'},
#     {'id': '1',
#      'name': 'Prospectus',
#      'categoryId': 'offering',
#      'documents': [{'effectiveDate': '2026-06-03',
#        'postedDate': '2026-06-09',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2016-05-02',
#        'postedDate': '2017-11-28',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'},
#     {'id': '5',
#      'name': 'Semi-Annual Report',
#      'categoryId': 'shareholder',
#      'documents': [{'effectiveDate': '2025-06-30',
#        'postedDate': '2025-09-03',
#        'mimeType': 'application/pdf',
#        'languages': ['en']},
#       {'effectiveDate': '2012-06-30',
#        'postedDate': '2013-04-21',
#        'mimeType': 'application/pdf',
#        'languages': ['fr']}],
#      'mimeType': 'application/pdf'}]}}}

# %% [markdown]
# Historical Total Assets and Net flow
#
# chart Fund flows
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.graphData()
# Out:
# {'startYear': 2016,
#  'latestDate': '2026-05-31T05:00:00.000',
#  'endYear': 2026,
#  'secId': 'FOUSA00L83',
#  'currency': 'USD',
#  'data': [{'yr': 2016,
#    'naQ1': 2.4945725779,
#    'naQ2': 2.5996820759,
#    'naQ3': 2.7346545656,
#    'naQ4': 2.7925682151,
#    'naYr': 2.7925682151,
#    'nfQ1': 55.267908625,
#    'nfQ2': 47.781899567,
#    'nfQ3': 46.422851269,
#    'nfQ4': 33.470349127,
#    'nfYr': 182.943008588,
#    'numFund': 137,
#    'industryMarketShare': 22.60905856,
#    'growthRate': 7.59122893,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2017,
#    'naQ1': 2.9992043692,
#    'naQ2': 3.1367856448,
#    'naQ3': 3.2933485512,
#    'naQ4': 3.4662529642,
#    'naYr': 3.4662529642,
#    'nfQ1': 76.544077129,
#    'nfQ2': 49.738990644,
#    'nfQ3': 45.596474987,
#    'nfQ4': 35.126500497,
#    'nfYr': 207.006043257,
#    'numFund': 141,
#    'industryMarketShare': 23.8484434,
#    'growthRate': 7.41274796,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2018,
#    'naQ1': 3.4775429338,
#    'naQ2': 3.5487050769,
#    'naQ3': 3.7130380885,
#    'naQ4': 3.3519682965,
#    'naYr': 3.3519682965,
#    'nfQ1': 39.248219565,
#    'nfQ2': 13.00945,
#    'nfQ3': 17.920405053,
#    'nfQ4': 5.657726543,
#    'nfYr': 75.835801161,
#    'numFund': 141,
#    'industryMarketShare': 24.98352605,
#    'growthRate': 2.18783228,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2019,
#    'naQ1': 3.7386327959,
#    'naQ2': 3.8794341613,
#    'naQ3': 3.9250090712,
#    'naQ4': 4.1801009687,
#    'naYr': 4.1801009687,
#    'nfQ1': 45.451464496,
#    'nfQ2': 15.283373029,
#    'nfQ3': 5.873646418,
#    'nfQ4': 10.633977324,
#    'nfYr': 77.242461267,
#    'numFund': 145,
#    'industryMarketShare': 25.78850997,
#    'growthRate': 2.30439116,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2020,
#    'naQ1': 3.5116894508,
#    'naQ2': 4.0330797614,
#    'naQ3': 4.2458626145,
#    'naQ4': 4.6431199711,
#    'naYr': 4.6431199711,
#    'nfQ1': -21.871656285,
#    'nfQ2': -12.506920716,
#    'nfQ3': -13.738040134,
#    'nfQ4': -11.539924045,
#    'nfYr': -59.65654118,
#    'numFund': 143,
#    'industryMarketShare': 25.73833106,
#    'growthRate': -1.42715551,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2021,
#    'naQ1': 4.7898002858,
#    'naQ2': 5.0998775849,
#    'naQ3': 5.0752681636,
#    'naQ4': 5.3260283229,
#    'naYr': 5.3260283229,
#    'nfQ1': 30.98485722,
#    'nfQ2': 23.482260266,
#    'nfQ3': 0.437017041,
#    'nfQ4': -20.671589069,
#    'nfYr': 34.232545458,
#    'numFund': 148,
#    'industryMarketShare': 25.874192,
#    'growthRate': 0.73727463,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2022,
#    'naQ1': 5.0096266344,
#    'naQ2': 4.3528344385,
#    'naQ3': 4.1135320631,
#    'naQ4': 4.3508557423,
#    'naYr': 4.3508557423,
#    'nfQ1': -24.924057486,
#    'nfQ2': -25.609908649,
#    'nfQ3': -19.02818459,
#    'nfQ4': -36.841482467,
#    'nfYr': -106.403633192,
#    'numFund': 148,
#    'industryMarketShare': 26.9500911,
#    'growthRate': -1.99780449,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2023,
#    'naQ1': 4.5911608054,
#    'naQ2': 4.7857922788,
#    'naQ3': 4.605537003,
#    'naQ4': 5.0312120502,
#    'naYr': 5.0312120502,
#    'nfQ1': 6.347600952,
#    'nfQ2': -25.736576417,
#    'nfQ3': -22.906856471,
#    'nfQ4': -38.386126697,
#    'nfYr': -80.681958633,
#    'numFund': 149,
#    'industryMarketShare': 27.50039792,
#    'growthRate': -1.85439287,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2024,
#    'naQ1': 5.3558837273,
#    'naQ2': 5.4308621783,
#    'naQ3': 5.7172046904,
#    'naQ4': 5.6735103501,
#    'naYr': 5.6735103501,
#    'nfQ1': 4.694823757,
#    'nfQ2': -22.445750808,
#    'nfQ3': -35.720628211,
#    'nfQ4': -30.512048727,
#    'nfYr': -83.983603989,
#    'numFund': 148,
#    'industryMarketShare': 27.96374675,
#    'growthRate': -1.66925192,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2025,
#    'naQ1': 5.5306047054,
#    'naQ2': 5.952615842,
#    'naQ3': 5.9687938668,
#    'naQ4': 6.0365460956,
#    'naYr': 6.0365460956,
#    'nfQ1': -34.103413968,
#    'nfQ2': -29.338507423,
#    'nfQ3': -60.637586081,
#    'nfQ4': -61.241481801,
#    'nfYr': -185.320989273,
#    'numFund': 149,
#    'industryMarketShare': 27.27072754,
#    'growthRate': -3.26642551,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'},
#   {'yr': 2026,
#    'naQ1': 5.9016855997,
#    'naQ2': None,
#    'naQ3': None,
#    'naQ4': None,
#    'naYr': 6.5386632871,
#    'nfQ1': -4.18953742,
#    'nfQ2': -26.872887476,
#    'nfQ3': None,
#    'nfQ4': None,
#    'nfYr': -31.062424896,
#    'numFund': 149,
#    'industryMarketShare': 27.52175852,
#    'growthRate': -0.51457281,
#    'nfMagnitude': 'Bil',
#    'naMagnitude': 'Tri'}]}

# %% [markdown]
# Historical performance
#
# Performance - Returns
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.historicalData()
# Out:
# {'userType': 'Free',
#  'baseCurrency': 'USD',
#  'asOfDate': '2026-06-17T00:00:00.000',
#  'startDate': '2016-01-01T00:00:00.000',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'graphData': {'fund': [{'date': '2016-01-31', 'value': 9434.928041941224},
#    {'date': '2016-02-29', 'value': 9430.98972389338},
#    {'date': '2016-03-31', 'value': 10094.330534323297},
#    {'date': '2016-04-30', 'value': 10159.608342087218},
#    {'date': '2016-05-31', 'value': 10339.617022765564},
#    {'date': '2016-06-30', 'value': 10365.37317610833},
#    {'date': '2016-07-31', 'value': 10774.663437593292},
#    {'date': '2016-08-31', 'value': 10804.466603584093},
#    {'date': '2016-09-30', 'value': 10821.086454642713},
#    {'date': '2016-10-31', 'value': 10581.505688226662},
#    {'date': '2016-11-30', 'value': 11052.681890362883},
#    {'date': '2016-12-31', 'value': 11266.420143342864},
#    {'date': '2017-01-31', 'value': 11483.392432920169},
#    {'date': '2017-02-28', 'value': 11909.298078562371},
#    {'date': '2017-03-31', 'value': 11918.645814178393},
#    {'date': '2017-04-30', 'value': 12043.765210729793},
#    {'date': '2017-05-31', 'value': 12166.865567858558},
#    {'date': '2017-06-30', 'value': 12279.692051819033},
#    {'date': '2017-07-31', 'value': 12508.783044833544},
#    {'date': '2017-08-31', 'value': 12529.056821218972},
#    {'date': '2017-09-30', 'value': 12837.561875890122},
#    {'date': '2017-10-31', 'value': 13116.506466211984},
#    {'date': '2017-11-30', 'value': 13515.580924246562},
#    {'date': '2017-12-31', 'value': 13651.440240676644},
#    {'date': '2018-01-31', 'value': 14377.79860677346},
#    {'date': '2018-02-28', 'value': 13843.771613288434},
#    {'date': '2018-03-31', 'value': 13569.234365659058},
#    {'date': '2018-04-30', 'value': 13620.594797697759},
#    {'date': '2018-05-31', 'value': 14004.764694802685},
#    {'date': '2018-06-30', 'value': 14099.24263687144},
#    {'date': '2018-07-31', 'value': 14571.69339486738},
#    {'date': '2018-08-31', 'value': 15075.090845606765},
#    {'date': '2018-09-30', 'value': 15099.381855297706},
#    {'date': '2018-10-31', 'value': 13982.060924067888},
#    {'date': '2018-11-30', 'value': 14272.274017598102},
#    {'date': '2018-12-31', 'value': 12945.510503546348},
#    {'date': '2019-01-31', 'value': 14058.878227057063},
#    {'date': '2019-02-28', 'value': 14553.012813306601},
#    {'date': '2019-03-31', 'value': 14763.31304119302},
#    {'date': '2019-04-30', 'value': 15350.240058724863},
#    {'date': '2019-05-31', 'value': 14362.944670726085},
#    {'date': '2019-06-30', 'value': 15367.031141002952},
#    {'date': '2019-07-31', 'value': 15587.9417486281},
#    {'date': '2019-08-31', 'value': 15274.457587888144},
#    {'date': '2019-09-30', 'value': 15534.279373412852},
#    {'date': '2019-10-31', 'value': 15861.872986637265},
#    {'date': '2019-11-30', 'value': 16462.108392339862},
#    {'date': '2019-12-31', 'value': 16933.37095456938},
#    {'date': '2020-01-31', 'value': 16920.620929070814},
#    {'date': '2020-02-29', 'value': 15539.432688635381},
#    {'date': '2020-03-31', 'value': 13399.486157444873},
#    {'date': '2020-04-30', 'value': 15176.118754062087},
#    {'date': '2020-05-31', 'value': 15991.83301531477},
#    {'date': '2020-06-30', 'value': 16358.09063789585},
#    {'date': '2020-07-31', 'value': 17282.603727033613},
#    {'date': '2020-08-31', 'value': 18522.43836234462},
#    {'date': '2020-09-30', 'value': 17863.49149390305},
#    {'date': '2020-10-31', 'value': 17480.116705243323},
#    {'date': '2020-11-30', 'value': 19612.36378742612},
#    {'date': '2020-12-31', 'value': 20487.33000648445},
#    {'date': '2021-01-31', 'value': 20420.293728544915},
#    {'date': '2021-02-28', 'value': 21071.200174506943},
#    {'date': '2021-03-31', 'value': 21804.720472479046},
#    {'date': '2021-04-30', 'value': 22924.246564022236},
#    {'date': '2021-05-31', 'value': 23024.04905253299},
#    {'date': '2021-06-30', 'value': 23609.856366786204},
#    {'date': '2021-07-31', 'value': 24014.63505787987},
#    {'date': '2021-08-31', 'value': 24702.321969784385},
#    {'date': '2021-09-30', 'value': 23594.27283684717},
#    {'date': '2021-10-31', 'value': 25181.34205073953},
#    {'date': '2021-11-30', 'value': 24808.043102620355},
#    {'date': '2021-12-31', 'value': 25755.09319817482},
#    {'date': '2022-01-31', 'value': 24201.813115269135},
#    {'date': '2022-02-28', 'value': 23584.006408514506},
#    {'date': '2022-03-31', 'value': 24349.32359945891},
#    {'date': '2022-04-30', 'value': 22153.92793250214},
#    {'date': '2022-05-31', 'value': 22094.594081504572},
#    {'date': '2022-06-30', 'value': 20247.464847347368},
#    {'date': '2022-07-31', 'value': 22149.31957924767},
#    {'date': '2022-08-31', 'value': 21321.946705399663},
#    {'date': '2022-09-30', 'value': 19344.620696791942},
#    {'date': '2022-10-31', 'value': 20924.361214490924},
#    {'date': '2022-11-30', 'value': 22018.878614188514},
#    {'date': '2022-12-31', 'value': 20726.368788866694},
#    {'date': '2023-01-31', 'value': 22155.620888124216},
#    {'date': '2023-02-28', 'value': 21639.130949447335},
#    {'date': '2023-03-31', 'value': 22210.691826240512},
#    {'date': '2023-04-30', 'value': 22443.14788495942},
#    {'date': '2023-05-31', 'value': 22537.024284309337},
#    {'date': '2023-06-30', 'value': 24078.54003795377},
#    {'date': '2023-07-31', 'value': 24937.84678974965},
#    {'date': '2023-08-31', 'value': 24455.467598958614},
#    {'date': '2023-09-30', 'value': 23285.796072551413},
#    {'date': '2023-10-31', 'value': 22673.30795637028},
#    {'date': '2023-11-30', 'value': 24799.000605265137},
#    {'date': '2023-12-31', 'value': 26116.92858839216},
#    {'date': '2024-01-31', 'value': 26408.65000562085},
#    {'date': '2024-02-29', 'value': 27835.594205833324},
#    {'date': '2024-03-31', 'value': 28729.50902053509},
#    {'date': '2024-04-30', 'value': 27460.96263213652},
#    {'date': '2024-05-31', 'value': 28759.009926199346},
#    {'date': '2024-06-30', 'value': 29662.220362667726},
#    {'date': '2024-07-31', 'value': 30204.22375304587},
#    {'date': '2024-08-31', 'value': 30860.095904372574},
#    {'date': '2024-09-30', 'value': 31491.42838849832},
#    {'date': '2024-10-31', 'value': 31253.86070563641},
#    {'date': '2024-11-30', 'value': 33325.72570396504},
#    {'date': '2024-12-31', 'value': 32317.957017985973},
#    {'date': '2025-01-31', 'value': 33317.079271865296},
#    {'date': '2025-02-28', 'value': 32680.024687074943},
#    {'date': '2025-03-31', 'value': 30757.07426893575},
#    {'date': '2025-04-30', 'value': 30550.110816378343},
#    {'date': '2025-05-31', 'value': 32488.66858793058},
#    {'date': '2025-06-30', 'value': 34137.70712463325},
#    {'date': '2025-07-31', 'value': 34914.980721598135},
#    {'date': '2025-08-31', 'value': 35710.7041102193},
#    {'date': '2025-09-30', 'value': 36949.08402464836},
#    {'date': '2025-10-31', 'value': 37753.9332927838},
#    {'date': '2025-11-30', 'value': 37862.633848838566},
#    {'date': '2025-12-31', 'value': 37850.083344934865},
#    {'date': '2026-01-31', 'value': 38448.44860792741},
#    {'date': '2026-02-28', 'value': 38246.674205803545},
#    {'date': '2026-03-31', 'value': 36347.86590064271},
#    {'date': '2026-04-30', 'value': 40109.91555322945},
#    {'date': '2026-05-31', 'value': 42178.229364962965},
#    {'date': '2026-06-17', 'value': 41436.055190055486}],
#   'index': [{'date': '2016-01-31', 'value': 9466.616519820853},
#    {'date': '2016-02-29', 'value': 9453.577544174485},
#    {'date': '2016-03-31', 'value': 10105.32430744867},
#    {'date': '2016-04-30', 'value': 10147.931205812902},
#    {'date': '2016-05-31', 'value': 10333.196218376701},
#    {'date': '2016-06-30', 'value': 10357.643413678701},
#    {'date': '2016-07-31', 'value': 10742.82483214667},
#    {'date': '2016-08-31', 'value': 10757.905748596822},
#    {'date': '2016-09-30', 'value': 10767.572549698425},
#    {'date': '2016-10-31', 'value': 10558.144436541868},
#    {'date': '2016-11-30', 'value': 10949.046597102046},
#    {'date': '2016-12-31', 'value': 11158.522938241957},
#    {'date': '2017-01-31', 'value': 11384.48009773007},
#    {'date': '2017-02-28', 'value': 11824.647695419115},
#    {'date': '2017-03-31', 'value': 11836.862663648344},
#    {'date': '2017-04-30', 'value': 11958.62994654601},
#    {'date': '2017-05-31', 'value': 12123.57510891568},
#    {'date': '2017-06-30', 'value': 12204.37776360722},
#    {'date': '2017-07-31', 'value': 12447.03382821055},
#    {'date': '2017-08-31', 'value': 12487.880498238717},
#    {'date': '2017-09-30', 'value': 12745.985969870435},
#    {'date': '2017-10-31', 'value': 13041.462780964559},
#    {'date': '2017-11-30', 'value': 13438.67660358997},
#    {'date': '2017-12-31', 'value': 13581.222169285038},
#    {'date': '2018-01-31', 'value': 14343.93689425329},
#    {'date': '2018-02-28', 'value': 13825.635273494894},
#    {'date': '2018-03-31', 'value': 13507.034999305593},
#    {'date': '2018-04-30', 'value': 13548.147028706016},
#    {'date': '2018-05-31', 'value': 13888.159845090973},
#    {'date': '2018-06-30', 'value': 13976.099931131012},
#    {'date': '2018-07-31', 'value': 14472.678648290203},
#    {'date': '2018-08-31', 'value': 14962.189540220425},
#    {'date': '2018-09-30', 'value': 15021.859032572536},
#    {'date': '2018-10-31', 'value': 13963.511186725165},
#    {'date': '2018-11-30', 'value': 14258.230147234473},
#    {'date': '2018-12-31', 'value': 12966.842564143084},
#    {'date': '2019-01-31', 'value': 14042.776092105469},
#    {'date': '2019-02-28', 'value': 14521.310893066502},
#    {'date': '2019-03-31', 'value': 14780.881343975403},
#    {'date': '2019-04-30', 'value': 15378.574265397456},
#    {'date': '2019-05-31', 'value': 14414.668387159543},
#    {'date': '2019-06-30', 'value': 15421.79237001019},
#    {'date': '2019-07-31', 'value': 15658.918209805695},
#    {'date': '2019-08-31', 'value': 15388.411235470421},
#    {'date': '2019-09-30', 'value': 15654.707647542093},
#    {'date': '2019-10-31', 'value': 15985.817828831801},
#    {'date': '2019-11-30', 'value': 16588.326662422216},
#    {'date': '2019-12-31', 'value': 17065.404065093415},
#    {'date': '2020-01-31', 'value': 17103.894164731522},
#    {'date': '2020-02-29', 'value': 15712.309416288925},
#    {'date': '2020-03-31', 'value': 13694.670540705882},
#    {'date': '2020-04-30', 'value': 15491.750378871631},
#    {'date': '2020-05-31', 'value': 16307.824063209979},
#    {'date': '2020-06-30', 'value': 16674.985623637684},
#    {'date': '2020-07-31', 'value': 17664.44213408099},
#    {'date': '2020-08-31', 'value': 18976.19176530101},
#    {'date': '2020-09-30', 'value': 18269.94841066145},
#    {'date': '2020-10-31', 'value': 17798.229078625445},
#    {'date': '2020-11-30', 'value': 19864.302311640695},
#    {'date': '2020-12-31', 'value': 20667.354477696343},
#    {'date': '2021-01-31', 'value': 20488.27653100307},
#    {'date': '2021-02-28', 'value': 21039.789762520286},
#    {'date': '2021-03-31', 'value': 21816.938240732183},
#    {'date': '2021-04-30', 'value': 22992.251787980516},
#    {'date': '2021-05-31', 'value': 23087.462624041844},
#    {'date': '2021-06-30', 'value': 23718.972220754797},
#    {'date': '2021-07-31', 'value': 24242.55029556117},
#    {'date': '2021-08-31', 'value': 24955.97383782158},
#    {'date': '2021-09-30', 'value': 23788.226686693655},
#    {'date': '2021-10-31', 'value': 25440.600613512306},
#    {'date': '2021-11-30', 'value': 25134.86325243174},
#    {'date': '2021-12-31', 'value': 26132.771856542076},
#    {'date': '2022-01-31', 'value': 24624.26282296},
#    {'date': '2022-02-28', 'value': 23935.0793698791},
#    {'date': '2022-03-31', 'value': 24755.917363560304},
#    {'date': '2022-04-30', 'value': 22516.827549259393},
#    {'date': '2022-05-31', 'value': 22460.374082964652},
#    {'date': '2022-06-30', 'value': 20578.316612576527},
#    {'date': '2022-07-31', 'value': 22497.257981070234},
#    {'date': '2022-08-31', 'value': 21626.352206351887},
#    {'date': '2022-09-30', 'value': 19623.486168796906},
#    {'date': '2022-10-31', 'value': 21180.655612198298},
#    {'date': '2022-11-30', 'value': 22347.187001253467},
#    {'date': '2022-12-31', 'value': 21037.45133190683},
#    {'date': '2023-01-31', 'value': 22419.22077378532},
#    {'date': '2023-02-28', 'value': 21889.062935482205},
#    {'date': '2023-03-31', 'value': 22630.993025008986},
#    {'date': '2023-04-30', 'value': 22917.605043907075},
#    {'date': '2023-05-31', 'value': 23058.911781972132},
#    {'date': '2023-06-30', 'value': 24599.161069576767},
#    {'date': '2023-07-31', 'value': 25426.708398360097},
#    {'date': '2023-08-31', 'value': 25005.924702911434},
#    {'date': '2023-09-30', 'value': 23839.063360997687},
#    {'date': '2023-10-31', 'value': 23293.375181491905},
#    {'date': '2023-11-30', 'value': 25481.536977415355},
#    {'date': '2023-12-31', 'value': 26686.413223820717},
#    {'date': '2024-01-31', 'value': 27119.333211490783},
#    {'date': '2024-02-29', 'value': 28607.72304909708},
#    {'date': '2024-03-31', 'value': 29508.827618681877},
#    {'date': '2024-04-30', 'value': 28287.940128473714},
#    {'date': '2024-05-31', 'value': 29633.340087525714},
#    {'date': '2024-06-30', 'value': 30682.412465071822},
#    {'date': '2024-07-31', 'value': 31059.042827589466},
#    {'date': '2024-08-31', 'value': 31815.06818113585},
#    {'date': '2024-09-30', 'value': 32492.307062808002},
#    {'date': '2024-10-31', 'value': 32250.847193637408},
#    {'date': '2024-11-30', 'value': 34269.05284418303},
#    {'date': '2024-12-31', 'value': 33376.20303925902},
#    {'date': '2025-01-31', 'value': 34402.27671120227},
#    {'date': '2025-02-28', 'value': 33849.90284530448},
#    {'date': '2025-03-31', 'value': 31863.31219498879},
#    {'date': '2025-04-30', 'value': 31714.585308099373},
#    {'date': '2025-05-31', 'value': 33763.8402137355},
#    {'date': '2025-06-30', 'value': 35497.59448881526},
#    {'date': '2025-07-31', 'value': 36306.17522948018},
#    {'date': '2025-08-31', 'value': 37025.706069742584},
#    {'date': '2025-09-30', 'value': 38373.563695559315},
#    {'date': '2025-10-31', 'value': 39273.12859266914},
#    {'date': '2025-11-30', 'value': 39307.20107355119},
#    {'date': '2025-12-31', 'value': 39287.28519940799},
#    {'date': '2026-01-31', 'value': 39808.7791478836},
#    {'date': '2026-02-28', 'value': 39472.070004192086},
#    {'date': '2026-03-31', 'value': 37528.826583424234},
#    {'date': '2026-04-30', 'value': 41514.12915078491},
#    {'date': '2026-05-31', 'value': 43757.39297483104},
#    {'date': '2026-06-17', 'value': 42899.42153083712}],
#   'category': [{'date': '2016-01-31', 'value': 9454.76481544422},
#    {'date': '2016-02-29', 'value': 9430.081160267315},
#    {'date': '2016-03-31', 'value': 10035.657129729805},
#    {'date': '2016-04-30', 'value': 10086.02015474574},
#    {'date': '2016-05-31', 'value': 10240.283921900744},
#    {'date': '2016-06-30', 'value': 10213.847207647888},
#    {'date': '2016-07-31', 'value': 10589.973665937505},
#    {'date': '2016-08-31', 'value': 10609.202067296435},
#    {'date': '2016-09-30', 'value': 10600.861258876053},
#    {'date': '2016-10-31', 'value': 10398.372039007607},
#    {'date': '2016-11-30', 'value': 10825.5088000361},
#    {'date': '2016-12-31', 'value': 11009.757281514609},
#    {'date': '2017-01-31', 'value': 11210.512567552792},
#    {'date': '2017-02-28', 'value': 11612.752236948496},
#    {'date': '2017-03-31', 'value': 11621.073426203635},
#    {'date': '2017-04-30', 'value': 11740.192280298199},
#    {'date': '2017-05-31', 'value': 11867.27120223851},
#    {'date': '2017-06-30', 'value': 11956.86405938884},
#    {'date': '2017-07-31', 'value': 12176.095033795105},
#    {'date': '2017-08-31', 'value': 12178.46402716007},
#    {'date': '2017-09-30', 'value': 12461.145640820967},
#    {'date': '2017-10-31', 'value': 12710.784071567845},
#    {'date': '2017-11-30', 'value': 13101.025513582423},
#    {'date': '2017-12-31', 'value': 13259.102896533375},
#    {'date': '2018-01-31', 'value': 13953.256130273288},
#    {'date': '2018-02-28', 'value': 13418.26501049981},
#    {'date': '2018-03-31', 'value': 13137.832502094712},
#    {'date': '2018-04-30', 'value': 13164.357661007083},
#    {'date': '2018-05-31', 'value': 13429.702282144714},
#    {'date': '2018-06-30', 'value': 13487.247098793514},
#    {'date': '2018-07-31', 'value': 13963.144382902483},
#    {'date': '2018-08-31', 'value': 14343.753088637559},
#    {'date': '2018-09-30', 'value': 14384.00339837365},
#    {'date': '2018-10-31', 'value': 13389.03155348482},
#    {'date': '2018-11-30', 'value': 13667.36946111426},
#    {'date': '2018-12-31', 'value': 12435.219044690724},
#    {'date': '2019-01-31', 'value': 13428.623798653807},
#    {'date': '2019-02-28', 'value': 13863.389278135966},
#    {'date': '2019-03-31', 'value': 14040.647768683322},
#    {'date': '2019-04-30', 'value': 14587.835632483428},
#    {'date': '2019-05-31', 'value': 13669.042912707297},
#    {'date': '2019-06-30', 'value': 14578.835732120428},
#    {'date': '2019-07-31', 'value': 14789.750342834697},
#    {'date': '2019-08-31', 'value': 14524.023141196805},
#    {'date': '2019-09-30', 'value': 14791.797698751707},
#    {'date': '2019-10-31', 'value': 15054.76223584359},
#    {'date': '2019-11-30', 'value': 15570.215542552023},
#    {'date': '2019-12-31', 'value': 15991.34973366568},
#    {'date': '2020-01-31', 'value': 15897.5288140003},
#    {'date': '2020-02-29', 'value': 14599.082742987319},
#    {'date': '2020-03-31', 'value': 12639.050324596383},
#    {'date': '2020-04-30', 'value': 14154.012526205646},
#    {'date': '2020-05-31', 'value': 14841.546847710883},
#    {'date': '2020-06-30', 'value': 15081.727807154939},
#    {'date': '2020-07-31', 'value': 15857.341102434095},
#    {'date': '2020-08-31', 'value': 16829.698493185817},
#    {'date': '2020-09-30', 'value': 16296.779746529679},
#    {'date': '2020-10-31', 'value': 15939.691216769656},
#    {'date': '2020-11-30', 'value': 17687.204013225102},
#    {'date': '2020-12-31', 'value': 18365.34409994483},
#    {'date': '2021-01-31', 'value': 18220.41420392205},
#    {'date': '2021-02-28', 'value': 18796.328983565043},
#    {'date': '2021-03-31', 'value': 19602.62376594909},
#    {'date': '2021-04-30', 'value': 20541.8538723059},
#    {'date': '2021-05-31', 'value': 20738.220361230426},
#    {'date': '2021-06-30', 'value': 21079.33546598884},
#    {'date': '2021-07-31', 'value': 21496.478579616625},
#    {'date': '2021-08-31', 'value': 22047.059010798625},
#    {'date': '2021-09-30', 'value': 21027.89602967957},
#    {'date': '2021-10-31', 'value': 22350.08405437971},
#    {'date': '2021-11-30', 'value': 22012.619154752425},
#    {'date': '2021-12-31', 'value': 23008.554954122937},
#    {'date': '2022-01-31', 'value': 21785.032517520984},
#    {'date': '2022-02-28', 'value': 21235.03815979147},
#    {'date': '2022-03-31', 'value': 21833.01794960787},
#    {'date': '2022-04-30', 'value': 20123.824846502655},
#    {'date': '2022-05-31', 'value': 20177.979008482595},
#    {'date': '2022-06-30', 'value': 18578.558774416422},
#    {'date': '2022-07-31', 'value': 20079.61707796509},
#    {'date': '2022-08-31', 'value': 19327.658322888627},
#    {'date': '2022-09-30', 'value': 17644.831952209606},
#    {'date': '2022-10-31', 'value': 19042.53973738223},
#    {'date': '2022-11-30', 'value': 20132.59483536112},
#    {'date': '2022-12-31', 'value': 19088.201704072424},
#    {'date': '2023-01-31', 'value': 20318.624435407946},
#    {'date': '2023-02-28', 'value': 19797.238378837978},
#    {'date': '2023-03-31', 'value': 20275.641018742164},
#    {'date': '2023-04-30', 'value': 20502.345249876187},
#    {'date': '2023-05-31', 'value': 20426.638248241987},
#    {'date': '2023-06-30', 'value': 21720.253290365534},
#    {'date': '2023-07-31', 'value': 22408.672530366326},
#    {'date': '2023-08-31', 'value': 22012.857052226198},
#    {'date': '2023-09-30', 'value': 21022.400308623513},
#    {'date': '2023-10-31', 'value': 20542.694332038966},
#    {'date': '2023-11-30', 'value': 22302.784688535678},
#    {'date': '2023-12-31', 'value': 23376.06533197181},
#    {'date': '2024-01-31', 'value': 23667.368872853018},
#    {'date': '2024-02-29', 'value': 24842.837945007457},
#    {'date': '2024-03-31', 'value': 25663.82646578724},
#    {'date': '2024-04-30', 'value': 24588.041793069126},
#    {'date': '2024-05-31', 'value': 25629.67548805883},
#    {'date': '2024-06-30', 'value': 26281.16711535373},
#    {'date': '2024-07-31', 'value': 26730.64885927484},
#    {'date': '2024-08-31', 'value': 27304.77587883521},
#    {'date': '2024-09-30', 'value': 27798.867509966603},
#    {'date': '2024-10-31', 'value': 27494.079803465294},
#    {'date': '2024-11-30', 'value': 29147.267811946138},
#    {'date': '2024-12-31', 'value': 28193.13832295584},
#    {'date': '2025-01-31', 'value': 29140.59273171169},
#    {'date': '2025-02-28', 'value': 28677.19893057363},
#    {'date': '2025-03-31', 'value': 27127.205712997667},
#    {'date': '2025-04-30', 'value': 26904.752308832725},
#    {'date': '2025-05-31', 'value': 28481.66878829279},
#    {'date': '2025-06-30', 'value': 29806.26493572959},
#    {'date': '2025-07-31', 'value': 30332.903098044},
#    {'date': '2025-08-31', 'value': 30959.961220893925},
#    {'date': '2025-09-30', 'value': 31865.758518298015},
#    {'date': '2025-10-31', 'value': 32365.989713346415},
#    {'date': '2025-11-30', 'value': 32553.809711602284},
#    {'date': '2025-12-31', 'value': 32579.735895750582},
#    {'date': '2026-01-31', 'value': 33120.929565557795},
#    {'date': '2026-02-28', 'value': 33065.196181570274},
#    {'date': '2026-03-31', 'value': 31319.571547125146},
#    {'date': '2026-04-30', 'value': 34260.89972731807},
#    {'date': '2026-05-31', 'value': 35732.60368338742},
#    {'date': '2026-06-17', 'value': 35228.619683596844}]},
#  'fundFlowData': [{'date': '2016-01-31', 'value': 7955528520.217},
#   {'date': '2016-02-29', 'value': 3978451487.497},
#   {'date': '2016-03-31', 'value': 1140518428.661},
#   {'date': '2016-04-30', 'value': 2751846571.381},
#   {'date': '2016-05-31', 'value': 3200875979.232},
#   {'date': '2016-06-30', 'value': 4206517972.739},
#   {'date': '2016-07-31', 'value': 2404484797.108},
#   {'date': '2016-08-31', 'value': 4621241870.862},
#   {'date': '2016-09-30', 'value': 3871868362.686},
#   {'date': '2016-10-31', 'value': 4701411899.333},
#   {'date': '2016-11-30', 'value': 4364096158.672},
#   {'date': '2016-12-31', 'value': 1544867070.91},
#   {'date': '2017-01-31', 'value': 9950402027.747},
#   {'date': '2017-02-28', 'value': 4137338111.416},
#   {'date': '2017-03-31', 'value': 8291911331.821},
#   {'date': '2017-04-30', 'value': 5069799036.254},
#   {'date': '2017-05-31', 'value': 8492139458.711},
#   {'date': '2017-06-30', 'value': 1549516307.787},
#   {'date': '2017-07-31', 'value': 4598227544.4},
#   {'date': '2017-08-31', 'value': 6193349975.264},
#   {'date': '2017-09-30', 'value': 2530037724.311},
#   {'date': '2017-10-31', 'value': 1048299232.835},
#   {'date': '2017-11-30', 'value': 2663664044.731},
#   {'date': '2017-12-31', 'value': -422106744.391},
#   {'date': '2018-01-31', 'value': 3224286203.305},
#   {'date': '2018-02-28', 'value': 6841601075.336},
#   {'date': '2018-03-31', 'value': 4563530655.653},
#   {'date': '2018-04-30', 'value': 4375929813.38},
#   {'date': '2018-05-31', 'value': 276892810.944},
#   {'date': '2018-06-30', 'value': -1654934625.286},
#   {'date': '2018-07-31', 'value': 1179429064.892},
#   {'date': '2018-08-31', 'value': -1614929832.281},
#   {'date': '2018-09-30', 'value': 6781258078.704},
#   {'date': '2018-10-31', 'value': 7605128797.553},
#   {'date': '2018-11-30', 'value': 3493043779.587},
#   {'date': '2018-12-31', 'value': 14087654877.226},
#   {'date': '2019-01-31', 'value': 1080739704.759},
#   {'date': '2019-02-28', 'value': 314609075.622},
#   {'date': '2019-03-31', 'value': 5486599681.497},
#   {'date': '2019-04-30', 'value': 1111599981.106},
#   {'date': '2019-05-31', 'value': 6193609366.153},
#   {'date': '2019-06-30', 'value': 2680675905.916},
#   {'date': '2019-07-31', 'value': -2013464556.655},
#   {'date': '2019-08-31', 'value': 6286409661.06},
#   {'date': '2019-09-30', 'value': 606851976.615},
#   {'date': '2019-10-31', 'value': 759104522.751},
#   {'date': '2019-11-30', 'value': -2859773430.795},
#   {'date': '2019-12-31', 'value': -966708326.488},
#   {'date': '2020-01-31', 'value': 4733472687.562},
#   {'date': '2020-02-29', 'value': 13176545797.126},
#   {'date': '2020-03-31', 'value': 12545367393.743},
#   {'date': '2020-04-30', 'value': -12187592972.124},
#   {'date': '2020-05-31', 'value': -5939861842.666},
#   {'date': '2020-06-30', 'value': -7231263478.093},
#   {'date': '2020-07-31', 'value': -3576699454.258},
#   {'date': '2020-08-31', 'value': -9708654554.84},
#   {'date': '2020-09-30', 'value': -881327114.375},
#   {'date': '2020-10-31', 'value': 4040994915.647},
#   {'date': '2020-11-30', 'value': 1326169723.048},
#   {'date': '2020-12-31', 'value': 221267621.825},
#   {'date': '2021-01-31', 'value': 2321406189.638},
#   {'date': '2021-02-28', 'value': -2430860855.121},
#   {'date': '2021-03-31', 'value': 4985152507.0},
#   {'date': '2021-04-30', 'value': 1031938618.266},
#   {'date': '2021-05-31', 'value': 4647415455.472},
#   {'date': '2021-06-30', 'value': 3384336523.855},
#   {'date': '2021-07-31', 'value': 141918850.196},
#   {'date': '2021-08-31', 'value': -1079129109.538},
#   {'date': '2021-09-30', 'value': 2586278731.309},
#   {'date': '2021-10-31', 'value': -275125147.822},
#   {'date': '2021-11-30', 'value': 2566346555.666},
#   {'date': '2021-12-31', 'value': -732989157.79},
#   {'date': '2022-01-31', 'value': 12222034153.74},
#   {'date': '2022-02-28', 'value': 2604560491.534},
#   {'date': '2022-03-31', 'value': 1707255548.562},
#   {'date': '2022-04-30', 'value': 5238267535.712},
#   {'date': '2022-05-31', 'value': 10308945150.048},
#   {'date': '2022-06-30', 'value': 4582147661.991},
#   {'date': '2022-07-31', 'value': 2113722752.828},
#   {'date': '2022-08-31', 'value': -347071574.137},
#   {'date': '2022-09-30', 'value': 4440794375.176},
#   {'date': '2022-10-31', 'value': 1382971579.016},
#   {'date': '2022-11-30', 'value': 2535393687.988},
#   {'date': '2022-12-31', 'value': 9139113141.612},
#   {'date': '2023-01-31', 'value': 8529505267.701},
#   {'date': '2023-02-28', 'value': 1753054074.729},
#   {'date': '2023-03-31', 'value': 3779988836.521},
#   {'date': '2023-04-30', 'value': 3043832167.011},
#   {'date': '2023-05-31', 'value': -976208426.558},
#   {'date': '2023-06-30', 'value': -3035465731.371},
#   {'date': '2023-07-31', 'value': -1796079677.014},
#   {'date': '2023-08-31', 'value': -1829747728.243},
#   {'date': '2023-09-30', 'value': 1840860588.77},
#   {'date': '2023-10-31', 'value': 1878449617.026},
#   {'date': '2023-11-30', 'value': -2726472644.511},
#   {'date': '2023-12-31', 'value': -1424991123.72},
#   {'date': '2024-01-31', 'value': 1058790404.784},
#   {'date': '2024-02-29', 'value': -7150020644.414},
#   {'date': '2024-03-31', 'value': 2747701266.736},
#   {'date': '2024-04-30', 'value': 2294956640.236},
#   {'date': '2024-05-31', 'value': -330703528.125},
#   {'date': '2024-06-30', 'value': -2068544754.948},
#   {'date': '2024-07-31', 'value': -3420884842.69},
#   {'date': '2024-08-31', 'value': 5251532076.282},
#   {'date': '2024-09-30', 'value': -1288027665.503},
#   {'date': '2024-10-31', 'value': -6315376800.303},
#   {'date': '2024-11-30', 'value': -10292841695.803},
#   {'date': '2024-12-31', 'value': -227938393.357},
#   {'date': '2025-01-31', 'value': 4496289776.587},
#   {'date': '2025-02-28', 'value': 4915967497.912},
#   {'date': '2025-03-31', 'value': 5060310921.394},
#   {'date': '2025-04-30', 'value': 22884276410.705},
#   {'date': '2025-05-31', 'value': -1697678591.881},
#   {'date': '2025-06-30', 'value': -1747294106.213},
#   {'date': '2025-07-31', 'value': -46540277480.787},
#   {'date': '2025-08-31', 'value': 158642416.921},
#   {'date': '2025-09-30', 'value': -2546397701.152},
#   {'date': '2025-10-31', 'value': -7712310161.358},
#   {'date': '2025-11-30', 'value': -260729996.118},
#   {'date': '2025-12-31', 'value': 726767188.212},
#   {'date': '2026-01-31', 'value': 6140168581.776},
#   {'date': '2026-02-28', 'value': 4656470605.452},
#   {'date': '2026-03-31', 'value': 9425546265.258},
#   {'date': '2026-04-30', 'value': 4197908957.881},
#   {'date': '2026-05-31', 'value': -7857023504.956},
#   {'date': '2026-06-30', 'value': None},
#   {'date': '2026-07-31', 'value': None},
#   {'date': '2026-08-31', 'value': None},
#   {'date': '2026-09-30', 'value': None},
#   {'date': '2026-10-31', 'value': None},
#   {'date': '2026-11-30', 'value': None},
#   {'date': '2026-12-31', 'value': None}],
#  'managerChange': [{'date': '2016-04-27 00:00:00.0', 'value': 'partial'},
#   {'date': '2023-02-17 00:00:00.0', 'value': 'partial'},
#   {'date': '2025-06-18 00:00:00.0', 'value': 'partial'}],
#  'table': {'columnDefs': ['2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    '2025',
#    'YTD'],
#   'growth10KReturnData': [{'label': 'fund',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['12.66422',
#      '21.16927',
#      '-5.1711',
#      '30.80497',
#      '20.98791',
#      '25.71229',
#      '-19.52516',
#      '26.00822',
#      '23.74332',
#      '17.11781',
#      '9.47415'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'category',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['10.36891',
#      '20.43837',
#      '-6.26928',
#      '28.77649',
#      '15.82748',
#      '26.06759',
#      '-16.95545',
#      '22.31864',
#      '21.44601',
#      '15.54386',
#      '8.21613'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'index',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['11.58523',
#      '21.71165',
#      '-4.52374',
#      '31.60802',
#      '21.10674',
#      '26.44469',
#      '-19.49782',
#      '26.85193',
#      '25.06815',
#      '17.71047',
#      '9.19416'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'percentileRank',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['20',
#      '45',
#      '42',
#      '39',
#      '17',
#      '63',
#      '75',
#      '33',
#      '43',
#      '40',
#      '31'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'fundNumber',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['1409',
#      '1396',
#      '1402',
#      '1387',
#      '1363',
#      '1382',
#      '1358',
#      '1430',
#      '1386',
#      '1314',
#      '1343'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'fundNet',
#     'endDate': '2026-05-31T00:00:00.000',
#     'datum': ['12.66422',
#      '21.16927',
#      '-5.1711',
#      '30.80497',
#      '20.98791',
#      '25.71229',
#      '-19.52516',
#      '26.00822',
#      '23.74332',
#      '17.11781',
#      None],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]}]},
#  'currentValues': [{'type': 'fund',
#    'name': 'VTSAX',
#    'baseCurrency': 'USD',
#    'currentValue': 41436.055190055486,
#    'currentSymbol': '$'},
#   {'type': 'index',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': 42899.42153083712,
#    'currentSymbol': '$'},
#   {'type': 'category',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': 35228.619683596844,
#    'currentSymbol': '$'}],
#  'instrumentId': '52.8.VTSAX',
#  'fundFlowQuarterlyData': [],
#  'isLimitAgeData': False,
#  'cur': 'USD',
#  'isUKCefAvailable': False,
#  'template': 'SA_USA'}

# %% [markdown]
# Historical expense ratio
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.historicalExpenses()
# Out:
# {'feeLevelComparisonGroup': 'Large Cap Institutional',
#  'currentYear': '2026',
#  'fundExpenseHistoryList': [{'annualReportDate': '2022-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None},
#   {'annualReportDate': '2023-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None},
#   {'annualReportDate': '2024-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None},
#   {'annualReportDate': '2025-12-31T06:00:00.000',
#    'netExpenseRatio': 0.04,
#    'managementExpenseRatio': None}],
#  'feeLevelMedianList': [{'date': '2022-12-31T06:00:00.000', 'median': 0.7},
#   {'date': '2023-12-31T06:00:00.000', 'median': 0.7},
#   {'date': '2024-12-31T06:00:00.000', 'median': 0.69},
#   {'date': '2025-12-31T06:00:00.000', 'median': 0.68},
#   {'date': '2026-05-31T05:00:00.000', 'median': 0.68}],
#  'categoryExpenseAverageList': [{'year': '2026',
#    'categoryExpenseRatio': 0.76,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2022',
#    'categoryExpenseRatio': 0.81,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2023',
#    'categoryExpenseRatio': 0.823,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2024',
#    'categoryExpenseRatio': 0.807,
#    'categoryManagementExpenseRatio': None},
#   {'year': '2025',
#    'categoryExpenseRatio': 0.806,
#    'categoryManagementExpenseRatio': None}]}

# %% [markdown]
# Historical raiting

# %%
funds.historicalRating()
# Out:
# {'medalistStartDate': '2023-05-01',
#  'ticker': 'VTSAX',
#  'userType': 'Free',
#  'years': {'2023': [{'date': '2023-07-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-08-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-09-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-10-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-11-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2023-12-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}],
#   '2024': [{'date': '2024-01-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-02-29',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'Y',
#     'analysisPublishedDate': '2024-02-07T06:00:00.000'},
#    {'date': '2024-03-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-04-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-05-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-06-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-07-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-08-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-09-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-10-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-11-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2024-12-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}],
#   '2025': [{'date': '2025-01-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'Y',
#     'analysisPublishedDate': '2025-01-29T06:00:00.000'},
#    {'date': '2025-02-28',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-03-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-04-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-05-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-06-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-07-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-08-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-09-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-10-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-11-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2025-12-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}],
#   '2026': [{'date': '2026-01-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'Y',
#     'analysisPublishedDate': '2026-01-28T06:00:00.000'},
#    {'date': '2026-02-28',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'Y',
#     'analysisPublishedDate': '2026-02-11T06:00:00.000'},
#    {'date': '2026-03-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2026-04-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2026-05-31',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None},
#    {'date': '2026-06-30',
#     'overallRating': '_PO_',
#     'overallRatingType': None,
#     'peoplePillarScore': '_PO_',
#     'peoplePillarScoreType': '_PO_',
#     'processPillarScore': '_PO_',
#     'processPillarScoreType': '_PO_',
#     'parentPillarScore': '_PO_',
#     'parentPillarScoreType': '_PO_',
#     'pricePillarScore': '_PO_',
#     'disclosureCodes': None,
#     'overallDataAvailablityPercentage': '100',
#     'overallRatingAnalystPercetage': '100',
#     'notePublished': 'N',
#     'analysisPublished': 'N',
#     'analysisPublishedDate': None}]}}

# %% [markdown]
# Holdings in a DataFrame format
#
# Holdings
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.holdings()
# Out:
#               securityName       secId performanceId holdingTypeId  weighting  \
# 0              NVIDIA Corp  0P000003RE    0P000003RE             E    6.69694
# 1                Apple Inc  0P000000GY    0P000000GY             E    6.29467
# 2           Microsoft Corp  0P000003MH    0P000003MH             E    4.59357
# 3           Amazon.com Inc  0P000000B7    0P000000B7             E    3.59259
# 4     Alphabet Inc Class A  0P000002HD    0P000002HD             E    3.04395
# ...                    ...         ...           ...           ...        ...
# 3493     Escrow Luby's Inc         NaN           NaN            AP    0.00000
# 3494              Srax Pfd         NaN           NaN             P    0.00000
# 3495          Clearone Inc  B1000HOJJT           NaN             P    0.00000
# 3496    Btcs Incorporation  B10003UJJ6           NaN             P    0.00000
# 3497         Nutriband Inc  B1000HLHOF           NaN             P    0.00000
#
#       numberOfShare   marketValue  shareChange        country ticker  ...  \
# 0       734760640.0  1.551374e+11    -812255.0  United States   NVDA  ...
# 1       467277295.0  1.458186e+11    -518710.0  United States   AAPL  ...
# 2       236344917.0  1.064119e+11    -264058.0  United States   MSFT  ...
# 3       307507663.0  8.322387e+10    -341886.0  United States   AMZN  ...
# 4       185398372.0  7.051442e+10     -68340.0  United States  GOOGL  ...
# ...             ...           ...          ...            ...    ...  ...
# 3493       449752.0  1.124380e+05          0.0            NaN    NaN  ...
# 3494       590641.0  4.134500e+04          0.0  United States    NaN  ...
# 3495        12200.0  2.684000e+03     -12448.0  United States    NaN  ...
# 3496       280193.0  3.000000e+00          0.0  United States    NaN  ...
# 3497        30646.0  0.000000e+00          0.0  United States    NaN  ...
#
#       susEsgRiskCategory  managementExpenseRatio qualRating quantRating  \
# 0                    Low                    None       None           3
# 1                    Low                    None       None           2
# 2                    Low                    None       None           5
# 3                    Low                    None       None           3
# 4                    Low                    None       None           3
# ...                  ...                     ...        ...         ...
# 3493                 NaN                    None       None         NaN
# 3494                 NaN                    None       None         NaN
# 3495                 NaN                    None       None         NaN
# 3496                 NaN                    None       None         NaN
# 3497                 NaN                    None       None         NaN
#
#      bestRatingType securityType domicileCountryId currencyName  \
# 0              Qual           ST               USA    US Dollar
# 1              Qual           ST               USA    US Dollar
# 2              Qual           ST               USA    US Dollar
# 3              Qual           ST               USA    US Dollar
# 4              Qual           ST               USA    US Dollar
# ...             ...          ...               ...          ...
# 3493            NaN          NaN               NaN          NaN
# 3494            NaN          NaN               NaN    US Dollar
# 3495            NaN          NaN               NaN          NaN
# 3496            NaN          NaN               NaN    US Dollar
# 3497            NaN          NaN               NaN    US Dollar
#
#      originalMarketValue isMomentumFilterFlag
# 0           1.551374e+11                False
# 1           1.458186e+11                False
# 2           1.064119e+11                False
# 3           8.322387e+10                False
# 4           7.051442e+10                False
# ...                  ...                  ...
# 3493        1.124380e+05                 None
# 3494        4.134500e+04                 None
# 3495        2.684000e+03                 None
# 3496        3.000000e+00                 None
# 3497        0.000000e+00                 None
#
# [3498 rows x 58 columns]

# %% [markdown]
# Summmary of fees
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/quote

# %%
funds_2.investmentFee()
# Out:
# {'domicileCountryId': 'IRL',
#  'priceTemplate': 'EEA_OE',
#  'actualInvestmentFees': {'kiidOngoingCharge': 0.12,
#   'kiidOngoingChargeDate': '2026-03-24T05:00:00.000',
#   'ongoingCost': 0.1203,
#   'performanceFee': 0.0,
#   'managementFee': 0.12,
#   'transactionFee': 0.038,
#   'distributionFee': 0.0},
#  'estimatedInvestmentFees': {'ongoingCost': 0.1203,
#   'performanceFee': 0.0,
#   'managementFee': 0.12,
#   'transactionFee': 0.0404,
#   'distributionFee': 0.0}}

# %% [markdown]
# Quick lookup on the fund

# %%
funds_2.investmentLookup()
# Out:
# {'dbgtime': '247',
#  'Id': 'F0000022KV',
#  'InceptionDate': '2008-08-06T00:00:00',
#  'Isin': 'IE00B04GQT48',
#  'InvestmentType': 'FD',
#  'HoldingType': '2',
#  'Type': 'Fund',
#  'Name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'LegalName': 'Vanguard U.S. Investment Grade Credit Index Fund EUR Acc',
#  'FundNetAssetValues': [{'CurrencyId': 'EUR',
#    'DayEndDate': '2026-06-17T00:00:00',
#    'DayEndValue': 1272966606.8983,
#    'MonthEndDate': '2026-05-29T00:00:00',
#    'MonthEndValue': 1306353583.99215}],
#  'ESG': {'SustainabilityDate': '2025-10-31T00:00:00',
#   'SustainabilityRank': 3,
#   'EnvironmentalScore': 4.68,
#   'SocialScore': 7.8,
#   'GovernanceScore': 4.53,
#   'RawSustainabilityScore': 21.83857,
#   'AUMCoverage': 90.4255,
#   'SustainabilityRating': {'Date': '2025-10-31T00:00:00',
#    'SustainabilityFundQuintile': 3,
#    'SustainabilityFundQuintileDesc': 'Average'},
#   'CarbonScore': {'Date': '2025-10-31T00:00:00',
#    'LowCarbonDesignation': 'No',
#    'CarbonRiskClassification': 'Low Risk',
#    'CarbonRiskScore': 9.06,
#    'CarbonExposureScore': 19.79,
#    'CarbonManagementScore': 10.73,
#    'CarbonOperationsRisk': 3.98,
#    'CarbonProductsAndServicesRisk': 0.69,
#    'StrandedAssetsRisk': 76.04,
#    'PercentOfAUMWithNegligibleCarbonRisk': 8.92899,
#    'PercentOfAUMWithLowCarbonRisk': 62.59959,
#    'PercentOfAUMWithMediumCarbonRisk': 23.13772,
#    'PercentOfAUMWithHighCarbonRisk': 4.13849,
#    'PercentOfAUMWithSevereCarbonRisk': 1.19521,
#    'OilSandsExtractionInvolvement': 1.56051,
#    'ArcticOilAndGasExplorationInvolvement': 1.6107,
#    'FossilFuelInvolvement': 12.59107,
#    'CarbonSolutionsInvolvement': 6.2024,
#    'ThermalCoalPowerGenerationInvolvement': 6.12346,
#    'ThermalCoalExtractionInvolvement': 0.96167,
#    'OilAndGasGenerationInvolvement': 9.1232,
#    'OilAndGasProductionInvolvement': 13.62976,
#    'OilAndGasProductsAndServiceInvolvement': 9.0089,
#    'HistoricCarbonRiskScore': 9.36},
#   'ProductInvolvement': {'Date': '2025-10-31T00:00:00',
#    'AbortiveContraceptivesStemCell': 6.23,
#    'AdultEntertainment': 0.0,
#    'Alcohol': 0.78,
#    'AnimalTesting': 10.78,
#    'ControversialWeapons': 1.6,
#    'FurAndSpecialtyLeather': 0.0,
#    'Gambling': 0.28,
#    'GMO': 0.26,
#    'MilitaryContracting': 1.95,
#    'Nuclear': 4.64,
#    'PalmOil': 0.02,
#    'Pesticides': 0.32,
#    'SmallArms': 0.7,
#    'ThermalCoal': 3.72,
#    'Tobacco': 1.07},
#   'RatingAndScore': {'Date': '2025-10-31T00:00:00',
#    'SustainabilityRatingDate': '2025-10-31T00:00:00',
#    'SustainabilityRating': 3,
#    'SustainabilityScore': 20.05,
#    'SustainabilityPercentRank': 57,
#    'SustainabilityAbsoluteRank': 2100,
#    'HistoricalSustainabilityScore': 21.84,
#    'EnvironmentalScore': 4.68,
#    'SocialScore': 7.8,
#    'GovernanceScore': 4.53,
#    'PercentAUMCoveredESG': 90.4255,
#    'NumberOfSecuritiesScoredESG': 6897,
#    'PercentAUMCoveredControversy': 91.68,
#    'NumberOfSecuritiesScoredControversy': 7051,
#    'NumberOfSecuritiesNotScoredControversy': 1321,
#    'PercentAUMWithLow': 7.46764,
#    'PercentAUMWithBelowAverage': 45.41733,
#    'PercentAUMWithAverage': 36.169,
#    'PercentAUMWithAboveAverage': 8.06727,
#    'PercentAUMWithHigh': 2.87875},
#   'SustainableInvestment': {'Overall': 'No',
#    'Date': '2025-09-16',
#    'GeneralESGInvestment': 'No',
#    'InvolvedInHealthyEcosystems': 'No',
#    'InvolvedInHumanDevelopment': 'No',
#    'InvolvedInResourceSecurity': 'No',
#    'InvolvedInBasicNeeds': 'No'},
#   'EmploysExclusions': {'Overall': 'No',
#    'UsesNormsBasedScreening': 'No',
#    'ExcludesAbortionStemCells': 'No',
#    'ExcludesAdultEntertainment': 'No',
#    'ExcludesAlcohol': 'No',
#    'ExcludesAnimalTesting': 'No',
#    'ExcludesControversialWeapons': 'No',
#    'ExcludesFurSpecialtyLeather': 'No',
#    'ExcludesGambling': 'No',
#    'ExcludesGMOs': 'No',
#    'ExcludesMilitaryContracting': 'No',
#    'ExcludesNuclear': 'No',
#    'ExcludesPalmOil': 'No',
#    'ExcludesPesticides': 'No',
#    'ExcludesSmallArms': 'No',
#    'ExcludesThermalCoal': 'No',
#    'ExcludesTobacco': 'No',
#    'ExcludesOther': 'No',
#    'ExcludesFossilFuel': 'No'}},
#  'Domicile': 'IRL',
#  'RealtimeId': '52.8.IE00B04GQT48',
#  'Currency': {'Id': 'EUR'},
#  'RiskAndRating': [{'Date': '2026-05-31T00:00:00',
#    'TimePeriod': 'M255',
#    'RatingValue': 3}],
#  'LastPrice': {'Date': '2026-06-17T00:00:00',
#   'MarketDate': '2026-06-17',
#   'MarketTime': '00:00:00',
#   'MarketTimeZone': 'BST',
#   'Value': 268.3436,
#   'Currency': {'Id': 'EUR'}},
#  'Benchmark': [{'Id': 'EUCA000691',
#    'GlobalAssetClassId': '$BCG$FXINC',
#    'Type': 'Category',
#    'Name': 'USD Corporate Bond'}],
#  'FundBenchmark': [{'Id': 'F00000WZ2U',
#    'Name': 'Bloomberg Gbl Agg USD Credit FA TR USD',
#    'Weighting': 100.0}],
#  'Research': {'MedalistRating': {'OverallRating': {'Date': '2026-04-30',
#     'AnalystDrivenPercentage': 20,
#     'RatingNumber': 7,
#     'RatingText': 'Gold'}}}}

# %% [markdown]
# Investment strategy
#
# https://www.morningstar.com/funds/xnas/vtsax/quote

# %%
funds.investmentStrategy()
# Out:
# {'investmentStrategy': 'The investment seeks to track the performance of the CRSP U.S. Total Market Index that measures the investment return of the overall stock market.\n The fund manager employs an indexing investment approach designed to track the performance of the CRSP U.S. Total Market Index (the “Target Index”), which represents 100% of the investable U.S. stock market, as determined by the index provider. Under normal circumstances, the fund invests at least 80% of its net assets, plus the amount of any borrowings for investment purposes, in the stocks that make up the target index.',
#  'languageId': '0L00000122',
#  'isInvestmentStrategyEmpty': False,
#  'template': 'USA_OE',
#  'domicileCountryId': 'USA'}

# %% [markdown]
# Breakdown by market capitalization
#
# Style Measures - Market Cap
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.marketCapitalization()
# Out:
# {'portfolioDate': '2026-05-31T05:00:00.000',
#  'assetType': 'EQUITY',
#  'currencyId': 'USD',
#  'fund': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'avgMarketCap': 331583.70978,
#   'giant': 40.8356,
#   'large': 30.73171,
#   'medium': 19.26939,
#   'small': 6.34067,
#   'micro': 2.22877},
#  'category': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'name': 'Large Blend',
#   'avgMarketCap': 589476.3113,
#   'giant': 47.89625,
#   'large': 23.54575,
#   'medium': 20.91331,
#   'small': 4.23209,
#   'micro': 0.1359},
#  'index': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'name': 'Morningstar US LM Cap Mkt TR USD',
#   'avgMarketCap': 502411.58345,
#   'giant': 45.41398,
#   'large': 34.05366,
#   'medium': 19.84179,
#   'small': 0.69064,
#   'micro': 0.0}}

# %% [markdown]
# Breakdown by bond maturity
#
# Bond Breakdown - Maturity Schedule
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.maturitySchedule()
# Out:
# {'fund': {'date': '2026-05-31T05:00:00.000',
#   'name': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#   'schedule': ['21.56032',
#    '21.67501',
#    '11.53591',
#    '16.27388',
#    '6.04438',
#    '5.57749',
#    '14.76020',
#    '2.37454']},
#  'benchMark': None,
#  'category': {'date': '2026-05-31T05:00:00.000',
#   'name': 'USD Corporate Bond',
#   'schedule': ['7.04386',
#    '9.86127',
#    '2.29163',
#    '22.32747',
#    '1.10081',
#    '1.82284',
#    '36.51000',
#    '15.78998']},
#  'proxy': {'date': '2026-05-31T05:00:00.000',
#   'name': 'Morningstar US Corp Bd TR USD',
#   'schedule': ['19.92086',
#    '19.39042',
#    '11.13575',
#    '15.45851',
#    '5.56329',
#    '6.58575',
#    '17.92770',
#    '3.19613']},
#  'scheduleLabel': ['Maturity1-3Yr%',
#   'Maturity3-5Yr%',
#   'Maturity5-7Yr%',
#   'Maturity7-10Yr%',
#   'Maturity10-15Yr%',
#   'Maturity15-20Yr%',
#   'Maturity20-30Yr%',
#   'Maturity30+Yr%']}

# %% [markdown]
# Max Drawdown
#
# Market Volatility Measures
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.maxDrawDown()
# Out:
# {'year': 3,
#  'maxDrawDownAsOfDate': '2026-05-31T05:00:00.000',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'categoryName': 'Large Blend',
#  'peakDate': '2023-08-01T00:00:00.000',
#  'valleyDate': '2023-10-31T00:00:00.000',
#  'duration': 3.0,
#  'inceptionDate': '2000-11-13T06:00:00.000',
#  'calculationBenchmark': 'S&P 500 (TR) (1970)',
#  'cur': 'USD',
#  'measureMap': {'fund': {'secId': 'FOUSA00L83',
#    'asOfDate': '2026-05-31T05:00:00.000',
#    'upside': 101.605,
#    'downside': 107.875,
#    'maxDrawDown': -9.0807345266,
#    'peakDate': '2023-08-01T00:00:00.000',
#    'valleyDate': '2023-10-31T00:00:00.000',
#    'duration': 3.0,
#    'isAddExtendedFlag': False},
#   'index': {'secId': 'F00000GWXD',
#    'asOfDate': '2026-05-31T05:00:00.000',
#    'upside': 101.213,
#    'downside': 102.1,
#    'maxDrawDown': -8.390128759,
#    'peakDate': '2023-08-01T00:00:00.000',
#    'valleyDate': '2023-10-31T00:00:00.000',
#    'duration': 3.0,
#    'isAddExtendedFlag': False},
#   'category': {'secId': '$FOCA$LB$$',
#    'asOfDate': '2026-05-31T05:00:00.000',
#    'upside': 94.563,
#    'downside': 104.877,
#    'maxDrawDown': -8.342462906,
#    'peakDate': '2023-08-01T00:00:00.000',
#    'valleyDate': '2023-10-31T00:00:00.000',
#    'duration': 3.0,
#    'isAddExtendedFlag': False}}}

# %% [markdown]
# Comparable funds with MorningStar medal
#
# https://www.morningstar.com/funds/xnas/vtsax/analysis

# %%
funds.medaListComparables()
# Out:
# {'userType': 'Free',
#  'categoryName': 'Large Blend',
#  'secId': 'FOUSA00L83',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'getCategoryId': 'Large Blend',
#  'ticker': 'VTSAX',
#  'categoryMedalist': [{'secId': 'FOUSA00FUA',
#    'endDate': None,
#    'tradingSymbol': 'WFIOX',
#    'legalName': 'Allspring Index Fund - Class Admin',
#    'name': 'Allspring Index Admin',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.59',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1518783984',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 482560792.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F000013TAS',
#    'endDate': None,
#    'tradingSymbol': 'AVUSX',
#    'legalName': 'Avantis® U.S. Equity Fund Institutional Class',
#    'name': 'Avantis® U.S. Equity Institutional',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.94',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '694477790',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 373105093.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00L0J',
#    'endDate': None,
#    'tradingSymbol': 'MALRX',
#    'legalName': 'BlackRock Advantage Large Cap Core Fund Institutional Shares',
#    'name': 'BlackRock Advantage Large Cap Core Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '0.90',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '3871946863',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1678423615.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 5,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00001GBFE',
#    'endDate': None,
#    'tradingSymbol': 'BDVEX',
#    'legalName': 'Blackrock Diversified Equity Alpha Fund Institutional',
#    'name': 'BlackRock Diversified Equity Alpha Inst',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.16',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '76',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': None,
#    'overallMorningstarRatingAsOfDate': None,
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1294571415',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1294571415.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': None,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000W3UB',
#    'endDate': None,
#    'tradingSymbol': 'BIRIX',
#    'legalName': 'BlackRock Sustainable Aware Advantage Large Cap Core Fund Institutional Shares',
#    'name': 'BlackRock Sust Awr Advtg Lg Cp Cr Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '0.90',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1214117180',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 461390338.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00ER2',
#    'endDate': None,
#    'tradingSymbol': 'DSPIX',
#    'legalName': 'BNY Mellon Institutional S&P 500 Stock Index Fund Class I',
#    'name': 'BNY Mellon Instl S&P 500 Stk Idx I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.70',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1357704239',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1357704239.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00001BQAK',
#    'endDate': None,
#    'tradingSymbol': 'CRQSX',
#    'legalName': 'Catholic Responsible Investments Equity Index Fund Institutional Shares',
#    'name': 'Catholic Rspnsbl Invst Equity Idx Ins',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.15',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '80',
#    'dataCoverage': '96',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4675220189',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 4675220189.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00BP5',
#    'endDate': None,
#    'tradingSymbol': 'NINDX',
#    'legalName': 'Columbia Large Cap Index Fund Institutional Class',
#    'name': 'Columbia Large Cap Index Inst',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.74',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '3027016587',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2109096677.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000TWEM',
#    'endDate': None,
#    'tradingSymbol': 'INDEX',
#    'legalName': 'CYBER HORNET S&P 500®',
#    'name': 'CYBER HORNET S&P 500®',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.59',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '80',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '167206343',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 167206343.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 2,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA05CLG',
#    'endDate': None,
#    'tradingSymbol': 'DFEOX',
#    'legalName': 'DFA U.S. Core Equity 1 Portfolio Institutional Class',
#    'name': 'DFA US Core Equity 1 I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.95',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '40988166112',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 40988166112.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA05CLH',
#    'endDate': None,
#    'tradingSymbol': 'DFQTX',
#    'legalName': 'DFA U.S. Core Equity II Portfolio Institutional Class',
#    'name': 'DFA US Core Equity 2 I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.85',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '38542884629',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 38542884629.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000YHTC',
#    'endDate': None,
#    'tradingSymbol': 'DURPX',
#    'legalName': 'DFA US High Relative Profitability Portfolio Institutional Class',
#    'name': 'DFA US Hi Relatv Profitability Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.69',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '6330350358',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 6330350358.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000PRZR',
#    'endDate': None,
#    'tradingSymbol': 'DUSQX',
#    'legalName': 'DFA U.S. Large Cap Equity Portfolio Institutional Class',
#    'name': 'DFA US Large Cap Equity Institutional',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.02',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '2616953647',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2616953647.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00AOK',
#    'endDate': None,
#    'tradingSymbol': 'DFUSX',
#    'legalName': 'DFA U.S. Large Company Portfolio',
#    'name': 'DFA US Large Company I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.21',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '14380094635',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 14380094635.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA06JB4',
#    'endDate': None,
#    'tradingSymbol': 'DFUEX',
#    'legalName': 'DFA U.S. Social Core Equity 2 Portfolio',
#    'name': 'DFA US Social Core Equity 2 Portfolio',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.68',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '2449332907',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2449332907.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA06M6P',
#    'endDate': None,
#    'tradingSymbol': 'DFSIX',
#    'legalName': 'DFA U.S. Sustainability Core 1 Portfolio',
#    'name': 'DFA US Sustainability Core 1',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.86',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '8408224079',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 8408224079.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00001P4QF',
#    'endDate': None,
#    'tradingSymbol': 'ETLGX',
#    'legalName': 'E*TRADE No Fee Large Cap Index Fund',
#    'name': 'E*TRADE No Fee Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': None,
#    'overallMorningstarRatingAsOfDate': None,
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '123603241',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 123603241.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': None,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00001P4QC',
#    'endDate': None,
#    'tradingSymbol': 'ETTOX',
#    'legalName': 'E*TRADE No Fee Total Market Index Fund',
#    'name': 'E*TRADE No Fee Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '96',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': None,
#    'overallMorningstarRatingAsOfDate': None,
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '98170274',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 98170274.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': None,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00CDC',
#    'endDate': None,
#    'tradingSymbol': 'FISPX',
#    'legalName': 'Federated Hermes Max-Cap Index Fund Institutional Shares',
#    'name': 'Federated Hermes Max-Cap Index IS',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.24',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '281020155',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 107665767.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000LZSI',
#    'endDate': None,
#    'tradingSymbol': 'FXAIX',
#    'legalName': 'Fidelity 500 Index Fund',
#    'name': 'Fidelity 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.44',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '832153251408',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 832153251408.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000Y8H0',
#    'endDate': None,
#    'tradingSymbol': 'FDFIX',
#    'legalName': 'Fidelity Flex 500 Index Fund',
#    'name': 'Fidelity Flex 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '9204222402',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 9204222402.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000WCQA',
#    'endDate': None,
#    'tradingSymbol': 'FLCPX',
#    'legalName': 'Fidelity SAI U.S. Large Cap Index Fund',
#    'name': 'Fidelity SAI US Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.44',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '15852636182',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 15852636182.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F000011YJJ',
#    'endDate': None,
#    'tradingSymbol': 'FCFMX',
#    'legalName': 'Fidelity Series Total Market Index Fund',
#    'name': 'Fidelity Series Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '111948068228',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 111948068228.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000MJS0',
#    'endDate': None,
#    'tradingSymbol': 'FSKAX',
#    'legalName': 'Fidelity Total Market Index Fund',
#    'name': 'Fidelity Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.43',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '138489956382',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 138489956382.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000YJ0A',
#    'endDate': None,
#    'tradingSymbol': 'FITLX',
#    'legalName': 'Fidelity U.S. Sustainability Index Fund',
#    'name': 'Fidelity U.S. Sustainability Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.09',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '5946452686',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 5946452686.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 5,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F000010QVC',
#    'endDate': None,
#    'tradingSymbol': 'FNILX',
#    'legalName': 'Fidelity ZERO Large Cap Index Fund',
#    'name': 'Fidelity ZERO Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '18621749913',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 18621749913.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000Y8GT',
#    'endDate': None,
#    'tradingSymbol': 'FZROX',
#    'legalName': 'Fidelity ZERO Total Market Index Fund',
#    'name': 'Fidelity ZERO Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '38628614452',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 38628614452.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F000010SV0',
#    'endDate': None,
#    'tradingSymbol': 'GQEIX',
#    'legalName': 'GQG Partners US Select Quality Equity Fund Institutional Shares',
#    'name': 'GQG Partners US Select Quality Eq Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '0.85',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '2603890832',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2361142640.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA0592C',
#    'endDate': None,
#    'tradingSymbol': 'GEQYX',
#    'legalName': 'GuideStone Funds Equity Index Fund Institutional Class',
#    'name': 'GuideStone Funds Equity Index Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.05',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
# ...
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '14007861673',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 9184800271.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00E93',
#    'endDate': None,
#    'tradingSymbol': 'MSPIX',
#    'legalName': 'NYLI S&P 500 Index Class I',
#    'name': 'NYLI S&P 500 Index Class I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.55',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '2116850257',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 460870433.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00F90',
#    'endDate': None,
#    'tradingSymbol': 'PSIFX',
#    'legalName': 'PGIM Quant Solutions Large-Cap Index Fund - Class Z',
#    'name': 'PGIM Quant Solutions Large-Cap Index Z',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.59',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '910191966',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 183235010.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00LMC',
#    'endDate': None,
#    'tradingSymbol': 'PLFPX',
#    'legalName': 'Principal LargeCap S&P 500 Index Fund R-5 Class',
#    'name': 'Principal Large Cap S&P 500 Index R5',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.31',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '13657973756',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 423391070.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00EY5',
#    'endDate': None,
#    'tradingSymbol': 'SNXFX',
#    'legalName': 'Schwab 1000 Index® Fund',
#    'name': 'Schwab 1000 Index®',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.28',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '22063139065',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 22063139065.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00K0Q',
#    'endDate': None,
#    'tradingSymbol': 'SWTSX',
#    'legalName': 'Schwab Total Stock Market Index Fund®',
#    'name': 'Schwab Total Stock Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.37',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '43542383060',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 43542383060.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA00JLQ',
#    'endDate': None,
#    'tradingSymbol': 'SWPPX',
#    'legalName': 'Schwab® S&P 500 Index Fund',
#    'name': 'Schwab® S&P 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.41',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '142276927056',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 142276927056.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'FOUSA05KH9',
#    'endDate': None,
#    'tradingSymbol': 'LCIAX',
#    'legalName': 'SEI Institutional Investments Trust Large Cap Index Fund Class A',
#    'name': 'SEI Large Cap Index A (SIIT)',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.32',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1895709188',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 1895709188.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []},
#   {'secId': 'F00000ZQQE',
#    'endDate': None,
#    'tradingSymbol': 'SLGFX',
#    'legalName': 'SEI Institutional Managed Trust Large Cap Index Fund Class F',
#    'name': 'SEI Large Cap Index F (SIMT)',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '_PO_',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.59',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1290104427',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 1290104427.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': []}],
#  'primaryMedalist': {'secId': 'FOUSA00L83',
#   'endDate': None,
#   'tradingSymbol': 'VTSAX',
#   'legalName': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'medalistRating': '_PO_',
#   'medalistRatingDate': '_PO_',
#   'parentScoreType': None,
#   'peopleScoreType': None,
#   'processScoreType': None,
#   'parentScore': '_PO_',
#   'peopleScore': '_PO_',
#   'processScore': '_PO_',
#   'priceScore': '2.32',
#   'parentScoreLabel': 'HIGH',
#   'peopleScoreLabel': 'ABOVE_AVERAGE',
#   'processScoreLabel': 'HIGH',
#   'medalistRatingLabel': 'GOLD',
#   'analystDriven': '100',
#   'dataCoverage': '100',
#   'analystRating': None,
#   'overallMorningstarRating': 3,
#   'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#   'ePUsedForOverallRating': None,
#   'trailingYearToDateReturn': None,
#   'trailing1YearReturn': None,
#   'trailing3YearReturn': None,
#   'trailing5YearReturn': None,
#   'ePUsedFor1YearReturn': None,
#   'ePUsedFor5YearReturn': None,
#   'ePUsedFor3YearReturn': None,
#   'expenseRatio': None,
#   'managementExpenseRatio': None,
#   'ongoingCharge': None,
#   'baseCurrencyId': 'USD',
#   'tNAInShareClassCurrency': '2308925120464',
#   'flow1Yr': None,
#   'fundShareClassTypeId': '6',
#   'fundShareClassTypeName': 'Inst',
#   'lastShareClassNetAsset': 488951580677.0,
#   'SecurityType': 'FO',
#   'morningstarRatingFor3Year': 3,
#   'morningstarRatingFor5Year': 3,
#   'morningstarRatingFor10Year': 3,
#   'process': None,
#   'people': None,
#   'parent': None,
#   'sustainabilityFundQuintile': 2,
#   'isLowCarbon': 'false',
#   'isDesignatedLowCarbon': 'false',
#   'domicileCountryId': 'USA',
#   'disclosureCodes': ['Tracks Morningstar Index']}}

# %% [markdown]
# Meta Data

# %%
funds.metaData()
# Out:
# {'secId': 'FOUSA00L83',
#  'fundId': 'FSUSA002PT',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'tradingSymbol': 'VTSAX',
#  'performanceId': '0P00002YGZ',
#  'masterPortfolioId': '3506',
#  'isin': 'US9229087286',
#  'securityType': 'FO',
#  'shortCountryId': 'USA',
#  'categoryId': '$FOCA$LB$$',
#  'domicileCountryId': 'USA',
#  'fundShareClassId': 'FOUSA00L83',
#  'assetType': 'EQUITY',
#  'quoteTemplate': 'OE_USA_EQUITY',
#  'quoteTemplateForEtf': None,
#  'securityTemplate': 'USA_OE_EQUITY',
#  'priceTemplate': 'USA_OE',
#  'caFundCode': None,
#  'alternativeFundCodes': None,
#  'selectedFundCode': None,
#  'baseCurrencyId': 'USD',
#  'performanceTemplate': 'OE_USA_EQUITY',
#  'countryId': 'USA',
#  'broadCategoryGroupId': '$BCG$EQUTY',
#  'template': 'Equity',
#  'userType': 'Free',
#  'newAssetType': 'EQUITY',
#  'countryOfSales18': 0,
#  'countryOfSales34': 0,
#  'newStatus': 0,
#  'legalStructure': '08',
#  'fundSubType': None,
#  'taxClassDesignation': None,
#  'is_ltaf': None,
#  'is_eltif': None,
#  'is_reit': None,
#  'is_business_development_company': None,
#  'morningstarIndex': 'Morningstar US LM Cap Mkt TR USD',
#  'morningstarIndexId': 'F00000GWXD',
#  'primaryProspectusBenchmarkIndex': 'CRSP US Total Market TR USD',
#  'primaryProspectusBenchmarkIndexId': 'F00000P7NL',
#  'morningstarCategoryIndex': 'Morningstar US LM Cap Mkt TR USD',
#  'morningstarCategoryIndexId': 'F00000GWXD',
#  'hasParent': True}

# %% [markdown]
# Rating of Analyst

# %%
funds.morningstarAnalyst()
# Out:
# {'morningstarRatingFor3Year': 3,
#  'morningstarRatingFor5Year': 3,
#  'morningstarRatingFor10Year': 3,
#  'overallMorningstarRating': 3,
#  'categoryMedalist': [{'secId': 'FOUSA00FUA',
#    'endDate': None,
#    'tradingSymbol': 'WFIOX',
#    'legalName': 'Allspring Index Fund - Class Admin',
#    'name': 'Allspring Index Admin',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.59',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1518783984',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 482560792.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F000013TAS',
#    'endDate': None,
#    'tradingSymbol': 'AVUSX',
#    'legalName': 'Avantis® U.S. Equity Fund Institutional Class',
#    'name': 'Avantis® U.S. Equity Institutional',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-05-21T01:50:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.94',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '694477790',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 373105093.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00L0J',
#    'endDate': None,
#    'tradingSymbol': 'MALRX',
#    'legalName': 'BlackRock Advantage Large Cap Core Fund Institutional Shares',
#    'name': 'BlackRock Advantage Large Cap Core Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '0.90',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 5,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '3871946863',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1678423615.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 5,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 5,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00001GBFE',
#    'endDate': None,
#    'tradingSymbol': 'BDVEX',
#    'legalName': 'Blackrock Diversified Equity Alpha Fund Institutional',
#    'name': 'BlackRock Diversified Equity Alpha Inst',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.16',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '76',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': None,
#    'overallMorningstarRatingAsOfDate': None,
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1294571415',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1294571415.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': None,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000W3UB',
#    'endDate': None,
#    'tradingSymbol': 'BIRIX',
#    'legalName': 'BlackRock Sustainable Aware Advantage Large Cap Core Fund Institutional Shares',
#    'name': 'BlackRock Sust Awr Advtg Lg Cp Cr Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '0.90',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1214117180',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 461390338.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00ER2',
#    'endDate': None,
#    'tradingSymbol': 'DSPIX',
#    'legalName': 'BNY Mellon Institutional S&P 500 Stock Index Fund Class I',
#    'name': 'BNY Mellon Instl S&P 500 Stk Idx I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.70',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1357704239',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 1357704239.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00001BQAK',
#    'endDate': None,
#    'tradingSymbol': 'CRQSX',
#    'legalName': 'Catholic Responsible Investments Equity Index Fund Institutional Shares',
#    'name': 'Catholic Rspnsbl Invst Equity Idx Ins',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.15',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '80',
#    'dataCoverage': '96',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '4675220189',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 4675220189.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00BP5',
#    'endDate': None,
#    'tradingSymbol': 'NINDX',
#    'legalName': 'Columbia Large Cap Index Fund Institutional Class',
#    'name': 'Columbia Large Cap Index Inst',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.74',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '3027016587',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2109096677.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000TWEM',
#    'endDate': None,
#    'tradingSymbol': 'INDEX',
#    'legalName': 'CYBER HORNET S&P 500®',
#    'name': 'CYBER HORNET S&P 500®',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.59',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '80',
#    'dataCoverage': '97',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '167206343',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 167206343.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 2,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA05CLG',
#    'endDate': None,
#    'tradingSymbol': 'DFEOX',
#    'legalName': 'DFA U.S. Core Equity 1 Portfolio Institutional Class',
#    'name': 'DFA US Core Equity 1 I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-27T11:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.95',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '40988166112',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 40988166112.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA05CLH',
#    'endDate': None,
#    'tradingSymbol': 'DFQTX',
#    'legalName': 'DFA U.S. Core Equity II Portfolio Institutional Class',
#    'name': 'DFA US Core Equity 2 I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-27T14:38:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.85',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '38542884629',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 38542884629.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000YHTC',
#    'endDate': None,
#    'tradingSymbol': 'DURPX',
#    'legalName': 'DFA US High Relative Profitability Portfolio Institutional Class',
#    'name': 'DFA US Hi Relatv Profitability Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-27T14:39:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.69',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '6330350358',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 6330350358.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 2,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': None,
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000PRZR',
#    'endDate': None,
#    'tradingSymbol': 'DUSQX',
#    'legalName': 'DFA U.S. Large Cap Equity Portfolio Institutional Class',
#    'name': 'DFA US Large Cap Equity Institutional',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.02',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '2616953647',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2616953647.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00AOK',
#    'endDate': None,
#    'tradingSymbol': 'DFUSX',
#    'legalName': 'DFA U.S. Large Company Portfolio',
#    'name': 'DFA US Large Company I',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-28T16:30:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.21',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '14380094635',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 14380094635.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA06JB4',
#    'endDate': None,
#    'tradingSymbol': 'DFUEX',
#    'legalName': 'DFA U.S. Social Core Equity 2 Portfolio',
#    'name': 'DFA US Social Core Equity 2 Portfolio',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.68',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '2449332907',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2449332907.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA06M6P',
#    'endDate': None,
#    'tradingSymbol': 'DFSIX',
#    'legalName': 'DFA U.S. Sustainability Core 1 Portfolio',
#    'name': 'DFA US Sustainability Core 1',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.86',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '8408224079',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 8408224079.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00001P4QF',
#    'endDate': None,
#    'tradingSymbol': 'ETLGX',
#    'legalName': 'E*TRADE No Fee Large Cap Index Fund',
#    'name': 'E*TRADE No Fee Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '99',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': None,
#    'overallMorningstarRatingAsOfDate': None,
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '123603241',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 123603241.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': None,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00001P4QC',
#    'endDate': None,
#    'tradingSymbol': 'ETTOX',
#    'legalName': 'E*TRADE No Fee Total Market Index Fund',
#    'name': 'E*TRADE No Fee Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '10',
#    'dataCoverage': '96',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': None,
#    'overallMorningstarRatingAsOfDate': None,
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '98170274',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 98170274.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': None,
#    'morningstarRatingFor5Year': None,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00CDC',
#    'endDate': None,
#    'tradingSymbol': 'FISPX',
#    'legalName': 'Federated Hermes Max-Cap Index Fund Institutional Shares',
#    'name': 'Federated Hermes Max-Cap Index IS',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.24',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '281020155',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 107665767.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000LZSI',
#    'endDate': None,
#    'tradingSymbol': 'FXAIX',
#    'legalName': 'Fidelity 500 Index Fund',
#    'name': 'Fidelity 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-27T13:29:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.44',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '832153251408',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 832153251408.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000Y8H0',
#    'endDate': None,
#    'tradingSymbol': 'FDFIX',
#    'legalName': 'Fidelity Flex 500 Index Fund',
#    'name': 'Fidelity Flex 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-27T13:29:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '9204222402',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 9204222402.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000WCQA',
#    'endDate': None,
#    'tradingSymbol': 'FLCPX',
#    'legalName': 'Fidelity SAI U.S. Large Cap Index Fund',
#    'name': 'Fidelity SAI US Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-27T13:29:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.44',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '15852636182',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 15852636182.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F000011YJJ',
#    'endDate': None,
#    'tradingSymbol': 'FCFMX',
#    'legalName': 'Fidelity Series Total Market Index Fund',
#    'name': 'Fidelity Series Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '111948068228',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 111948068228.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000MJS0',
#    'endDate': None,
#    'tradingSymbol': 'FSKAX',
#    'legalName': 'Fidelity Total Market Index Fund',
#    'name': 'Fidelity Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.43',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '138489956382',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 138489956382.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000YJ0A',
#    'endDate': None,
#    'tradingSymbol': 'FITLX',
#    'legalName': 'Fidelity U.S. Sustainability Index Fund',
#    'name': 'Fidelity U.S. Sustainability Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-28T16:31:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.09',
#    'parentScoreLabel': 'HIGH',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '5946452686',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 5946452686.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 5,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'true',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F000010QVC',
#    'endDate': None,
#    'tradingSymbol': 'FNILX',
#    'legalName': 'Fidelity ZERO Large Cap Index Fund',
#    'name': 'Fidelity ZERO Large Cap Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '18621749913',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 18621749913.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000Y8GT',
#    'endDate': None,
#    'tradingSymbol': 'FZROX',
#    'legalName': 'Fidelity ZERO Total Market Index Fund',
#    'name': 'Fidelity ZERO Total Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.48',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '38628614452',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 38628614452.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F000010SV0',
#    'endDate': None,
#    'tradingSymbol': 'GQEIX',
#    'legalName': 'GQG Partners US Select Quality Equity Fund Institutional Shares',
#    'name': 'GQG Partners US Select Quality Eq Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-05-20T02:11:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '0.85',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'HIGH',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 2,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '2603890832',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 2361142640.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 1,
#    'morningstarRatingFor5Year': 2,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 1,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA0592C',
#    'endDate': None,
#    'tradingSymbol': 'GEQYX',
#    'legalName': 'GuideStone Funds Equity Index Fund Institutional Class',
#    'name': 'GuideStone Funds Equity Index Instl',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
# ...
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00F90',
#    'endDate': None,
#    'tradingSymbol': 'PSIFX',
#    'legalName': 'PGIM Quant Solutions Large-Cap Index Fund - Class Z',
#    'name': 'PGIM Quant Solutions Large-Cap Index Z',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.59',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '910191966',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '6',
#    'fundShareClassTypeName': 'Inst',
#    'lastShareClassNetAsset': 183235010.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00LMC',
#    'endDate': None,
#    'tradingSymbol': 'PLFPX',
#    'legalName': 'Principal LargeCap S&P 500 Index Fund R-5 Class',
#    'name': 'Principal Large Cap S&P 500 Index R5',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': 'quantitative',
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.31',
#    'parentScoreLabel': 'AVERAGE',
#    'peopleScoreLabel': 'AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '13657973756',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '12',
#    'fundShareClassTypeName': 'Retirement',
#    'lastShareClassNetAsset': 423391070.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00EY5',
#    'endDate': None,
#    'tradingSymbol': 'SNXFX',
#    'legalName': 'Schwab 1000 Index® Fund',
#    'name': 'Schwab 1000 Index®',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': 'quantitative',
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.28',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'ABOVE_AVERAGE',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '20',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '22063139065',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 22063139065.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00K0Q',
#    'endDate': None,
#    'tradingSymbol': 'SWTSX',
#    'legalName': 'Schwab Total Stock Market Index Fund®',
#    'name': 'Schwab Total Stock Market Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-27T13:10:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.37',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '43542383060',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 43542383060.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 3,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 2,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA00JLQ',
#    'endDate': None,
#    'tradingSymbol': 'SWPPX',
#    'legalName': 'Schwab® S&P 500 Index Fund',
#    'name': 'Schwab® S&P 500 Index',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': None,
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.41',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '100',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '142276927056',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 142276927056.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 4,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'FOUSA05KH9',
#    'endDate': None,
#    'tradingSymbol': 'LCIAX',
#    'legalName': 'SEI Institutional Investments Trust Large Cap Index Fund Class A',
#    'name': 'SEI Large Cap Index A (SIIT)',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '2.32',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 4,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1895709188',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '10',
#    'fundShareClassTypeName': 'No Load',
#    'lastShareClassNetAsset': 1895709188.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 4,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': 4,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None},
#   {'secId': 'F00000ZQQE',
#    'endDate': None,
#    'tradingSymbol': 'SLGFX',
#    'legalName': 'SEI Institutional Managed Trust Large Cap Index Fund Class F',
#    'name': 'SEI Large Cap Index F (SIMT)',
#    'medalistRating': '_PO_',
#    'medalistRatingDate': '2026-04-30T05:00:00.000',
#    'parentScoreType': 'quantitative',
#    'peopleScoreType': None,
#    'processScoreType': None,
#    'parentScore': '_PO_',
#    'peopleScore': '_PO_',
#    'processScore': '_PO_',
#    'priceScore': '1.59',
#    'parentScoreLabel': 'ABOVE_AVERAGE',
#    'peopleScoreLabel': 'ABOVE_AVERAGE',
#    'processScoreLabel': 'HIGH',
#    'medalistRatingLabel': 'GOLD',
#    'analystDriven': '90',
#    'dataCoverage': '100',
#    'analystRating': '_PO_',
#    'overallMorningstarRating': 3,
#    'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#    'ePUsedForOverallRating': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'ePUsedFor1YearReturn': None,
#    'ePUsedFor5YearReturn': None,
#    'ePUsedFor3YearReturn': None,
#    'expenseRatio': None,
#    'managementExpenseRatio': None,
#    'ongoingCharge': None,
#    'baseCurrencyId': 'USD',
#    'tNAInShareClassCurrency': '1290104427',
#    'flow1Yr': None,
#    'fundShareClassTypeId': '11',
#    'fundShareClassTypeName': 'Other',
#    'lastShareClassNetAsset': 1290104427.0,
#    'SecurityType': 'FO',
#    'morningstarRatingFor3Year': 3,
#    'morningstarRatingFor5Year': 3,
#    'morningstarRatingFor10Year': None,
#    'process': None,
#    'people': None,
#    'parent': None,
#    'sustainabilityFundQuintile': 3,
#    'isLowCarbon': 'false',
#    'isDesignatedLowCarbon': 'false',
#    'domicileCountryId': 'USA',
#    'disclosureCodes': None}],
#  'primaryMedalist': {'secId': 'FOUSA00L83',
#   'endDate': None,
#   'tradingSymbol': 'VTSAX',
#   'legalName': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'medalistRating': '_PO_',
#   'medalistRatingDate': '2026-04-27T13:14:00.000',
#   'parentScoreType': None,
#   'peopleScoreType': None,
#   'processScoreType': None,
#   'parentScore': '_PO_',
#   'peopleScore': '_PO_',
#   'processScore': '_PO_',
#   'priceScore': '2.32',
#   'parentScoreLabel': 'HIGH',
#   'peopleScoreLabel': 'ABOVE_AVERAGE',
#   'processScoreLabel': 'HIGH',
#   'medalistRatingLabel': 'GOLD',
#   'analystDriven': '100',
#   'dataCoverage': '100',
#   'analystRating': None,
#   'overallMorningstarRating': 3,
#   'overallMorningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#   'ePUsedForOverallRating': None,
#   'trailingYearToDateReturn': None,
#   'trailing1YearReturn': None,
#   'trailing3YearReturn': None,
#   'trailing5YearReturn': None,
#   'ePUsedFor1YearReturn': None,
#   'ePUsedFor5YearReturn': None,
#   'ePUsedFor3YearReturn': None,
#   'expenseRatio': None,
#   'managementExpenseRatio': None,
#   'ongoingCharge': None,
#   'baseCurrencyId': 'USD',
#   'tNAInShareClassCurrency': '2308925120464',
#   'flow1Yr': None,
#   'fundShareClassTypeId': '6',
#   'fundShareClassTypeName': 'Inst',
#   'lastShareClassNetAsset': 488951580677.0,
#   'SecurityType': 'FO',
#   'morningstarRatingFor3Year': 3,
#   'morningstarRatingFor5Year': 3,
#   'morningstarRatingFor10Year': 3,
#   'process': None,
#   'people': None,
#   'parent': None,
#   'sustainabilityFundQuintile': 2,
#   'isLowCarbon': 'false',
#   'isDesignatedLowCarbon': 'false',
#   'domicileCountryId': 'USA',
#   'disclosureCodes': None},
#  'analystRating': '_PO_',
#  'analystRatingDate': '2023-03-06 00:00:00.0',
#  'morningstarRatingDate': '2026-05-31 00:00:00.0',
#  'history': [{'date': '2023-06-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-07-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-08-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-09-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-10-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-11-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2023-12-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-01-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-02-29T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-03-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-04-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-05-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-06-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-07-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-08-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-09-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-10-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-11-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2024-12-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-01-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-02-28T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-03-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-04-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-05-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-06-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-07-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-08-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-09-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-10-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-11-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2025-12-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2026-01-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2026-02-28T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2026-03-31T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2026-04-30T00:00:00.000', 'rating': '_PO_'},
#   {'date': '2026-05-31T00:00:00.000', 'rating': '_PO_'}],
#  'userType': 'Free',
#  'categoryName': 'US Fund Large Blend',
#  'flagshipShareClassID': None,
#  'flagshipName': None,
#  'isAusFlagship': False,
#  'quantHistory': [],
#  'quantRating': None,
#  'quantRatingDate': None}

# %% [markdown]
# Morningstar’s Analysis - Our Take
#
# https://www.morningstar.com/funds/xnas/vtsax/analysis

# %%
funds.morningstarOpinion()
# Out:
# {'analysis': {'authorId': 2835,
#   'title': 'A one-stop shop for all US stocks.',
#   'publishDate': '2026-04-27T08:14:00.000',
#   'scorePublishDate': '2026-04-27T08:14:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'process': {'authorId': 2835,
#   'title': 'This fund holds a representative basket of the expansive CRSP US Total Market Index, which efficiently captures the US stock market, earning it a High Process Pillar rating.',
#   'publishDate': '2026-04-27T08:14:00.000',
#   'scorePublishDate': '2026-04-27T08:14:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'parent': {'authorId': 2118,
#   'title': 'Vanguard maintains its High Parent Pillar rating as it continues to grow under new leadership.',
#   'publishDate': '2025-07-28T11:24:00.000',
#   'scorePublishDate': '2025-07-28T11:24:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Daniel Sotiroff',
#   'content': None,
#   'authorTitle': 'Senior Analyst'},
#  'people': {'authorId': 2835,
#   'title': "Vanguard's equity index group earns an Above Average People Pillar for a well-supported and stable management team that's adept at leveraging Vanguard's comprehensive resources.",
#   'publishDate': '2026-04-27T08:14:00.000',
#   'scorePublishDate': '2026-04-27T08:14:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'price': {'authorId': 2835,
#   'title': "Vanguard Total Stock Mkt Idx Adm's Prospectus Adjusted Expense Ratio is 0.04% per year.",
#   'publishDate': '2026-04-27T08:14:00.000',
#   'scorePublishDate': '2026-04-27T08:14:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'performance': {'authorId': 2835,
#   'title': 'The CRSP US Total Market Index returned 14.3% annualized over the past 10 years through 2025.',
#   'publishDate': '2026-04-27T08:14:00.000',
#   'scorePublishDate': '2026-04-27T08:14:00.000',
#   'ratingScale': '_PO_',
#   'rating': '_PO_',
#   'ratingType': None,
#   'authorName': 'Brendan McCann',
#   'content': None,
#   'authorTitle': 'Associate Analyst'},
#  'reasonMissing': None,
#  'notes': None,
#  'recentNotes': {'authorId': None,
#   'title': 'Vanguard Cuts Fees for Small Investors',
#   'publishDate': '2018-11-19T06:00:00Z',
#   'scorePublishDate': None,
#   'ratingScale': None,
#   'rating': None,
#   'ratingType': None,
#   'authorName': 'Alex Bryan',
#   'content': ["On Nov. 19, Vanguard announced it is cutting the investment minimums for the Admiral share class of 38 of its index funds, including this one. The investment minimum for the affected funds will now be $3,000 versus $10,000 previously. The Investor share classes of these funds were closed to new investors, effective Nov. 19, 2018. According to Vanguard, qualifying clients can convert to Admiral shares by visiting the company's website. Any remaining investors in the Investor share class of these funds will be automatically converted to the Admiral share class beginning in the second quarter of 2019.",
#    "This move is in response to intensifying competitive pressure from Schwab and Fidelity, which have both recently zeroed out investment minimums and streamlined their existing index fund lineups into single low-cost share classes. It is an improvement that is long overdue, as Vanguard's Investor share classes tended to charge fees that were a multiple of those levied by the Admiral shares classes. Consequently, these changes resulted in considerable fee cuts for smaller investors. However, they are immaterial to our Morningstar Analyst Ratings for any of the affected funds--all of which remain unchanged."],
#   'authorTitle': None},
#  'processText': ['This fund holds a representative basket of the expansive CRSP US Total Market Index, which efficiently captures the US stock market, earning it a High Process Pillar rating.'],
#  'portfolioText': ['The CRSP US Total Market Index includes all US stocks that pass its eligibility screen and weights them by market cap. Stocks must meet minimum market-cap and liquidity requirements for initial inclusion and less stringent requirements for ongoing inclusion. It spreads the rebalancing process over five days to reduce potential market impact costs. The index is reconstituted quarterly.',
#   '',
#   'Market-cap-weighting is a sensible approach for the US stock market. Highly traded stocks usually reflect new information quickly, and market-cap weighting requires minimal trading costs, which can detract from returns. It follows the wisdom of crowds and takes the guesswork out of stock selection. The US stock market has historically produced solid long-term gains, and owning nearly the entire market has allowed investors to capitalize on those gains. Should strong market performance continue, the fund is well positioned to reap those rewards.',
#   '',
#   "The index's market-cap weighting tilts it toward the largest and most established names. Companies with wide or narrow Morningstar Economic Moat Ratings dominate the portfolio, showcasing the strategy’s durability. Holding around 3,500 stocks reduces the opportunity cost of missing out on strong performers, too. When a portfolio owns a greater chunk of the US stock universe, it has a better chance of capturing gains from companies that end up driving returns. Concentrated active funds are more likely to miss out if those stocks are excluded from their narrow portfolios.",
#   '',
#   'Large allocations to the biggest names in the US stock market present some concentration risk, but the index simply represents the market. While higher concentration may be a concern for investors, there isn’t a clear relationship between index performance and market concentration. In addition, the largest companies, such as Apple and Microsoft, often have diversified business lines, so they don’t rely on a single product, service, or market to determine company success.'],
#  'ecl': {'sustainabilityDistribution': None, 'assetManager': None},
#  'userType': 'Free',
#  'id': 0,
#  'rpsCovered': True,
#  'isLocalized': False,
#  'shareClassId': 'FOUSA00L83',
#  'isRatingV2': True,
#  'suitability': None,
#  'fundamental': None,
#  'fees': None,
#  'portfolioConstruction': None,
#  'alternatives': None,
#  'analystDrivenPortion': '100',
#  'dataCoverage': '100',
#  'translationautomated': False,
#  'disclosureCodes': None,
#  'disclosureDescriptions': None}

# %% [markdown]
# Fixed Income Exposure Analysis
#
# https://global.morningstar.com/en-gb/investments/funds/0P0000GFVM/portfolio

# %%
funds_2.multiLevelFixedIncomeData()
# Out:
# {'fundName': 'Vanguard U.S. Invm Grd Crdt Idx € Acc',
#  'assetType': 'FIXEDINCOME',
#  'asOfDate': '2026-05-31T00:00:00.000',
#  'primary': 'superEffectiveDuration',
#  'secondary': 'superSector',
#  'data': [{'secondaryAttributeName': 'Government',
#    'weight': 14.70422,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.02304,
#     '1 to 3%': 4.6412,
#     '3 to 5%': 4.11397,
#     '5 to 7%': 2.12459,
#     '7 to 10%': 1.28955,
#     '10 to 20%': 2.11136,
#     'Greater than 20%': None,
#     'Unknown': 0.40049,
#     'Not Applicable': None,
#     'weight': 14.70422}},
#   {'secondaryAttributeName': 'Municipal',
#    'weight': 1.14866,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.00885,
#     '1 to 3%': 0.13644,
#     '3 to 5%': 0.09108,
#     '5 to 7%': 0.10737,
#     '7 to 10%': 0.35136,
#     '10 to 20%': 0.44692,
#     'Greater than 20%': None,
#     'Unknown': 0.00664,
#     'Not Applicable': None,
#     'weight': 1.14866}},
#   {'secondaryAttributeName': 'Corporate',
#    'weight': 81.33899,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.65611,
#     '1 to 3%': 19.6671,
#     '3 to 5%': 17.88389,
#     '5 to 7%': 14.87137,
#     '7 to 10%': 8.31533,
#     '10 to 20%': 19.39697,
#     'Greater than 20%': None,
#     'Unknown': 0.54823,
#     'Not Applicable': None,
#     'weight': 81.33899}},
#   {'secondaryAttributeName': 'Securitized',
#    'weight': 2.77643,
#    'primaryData': {'Negative': None,
#     '0 to 1%': 0.31086,
#     '1 to 3%': 0.89325,
#     '3 to 5%': 0.64583,
#     '5 to 7%': 0.34215,
#     '7 to 10%': 0.18654,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': 0.39779,
#     'Not Applicable': None,
#     'weight': 2.77643}},
#   {'secondaryAttributeName': 'Derivatives',
#    'weight': None,
#    'primaryData': {'Negative': None,
#     '0 to 1%': None,
#     '1 to 3%': None,
#     '3 to 5%': None,
#     '5 to 7%': None,
#     '7 to 10%': None,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': None,
#     'Not Applicable': None,
#     'weight': None}},
#   {'secondaryAttributeName': 'Cash & Equivalents',
#    'weight': None,
#    'primaryData': {'Negative': None,
#     '0 to 1%': None,
#     '1 to 3%': None,
#     '3 to 5%': None,
#     '5 to 7%': None,
#     '7 to 10%': None,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': None,
#     'Not Applicable': None,
#     'weight': None}},
#   {'secondaryAttributeName': 'Unknown',
#    'weight': 0.0317,
#    'primaryData': {'Negative': None,
#     '0 to 1%': None,
#     '1 to 3%': None,
#     '3 to 5%': None,
#     '5 to 7%': None,
#     '7 to 10%': None,
#     '10 to 20%': None,
#     'Greater than 20%': None,
#     'Unknown': 0.0317,
#     'Not Applicable': None,
#     'weight': 0.0317}}]}

# %% [markdown]
# Historical Net Asset Value and Total Return
#
# Fund Chart
#
# https://www.morningstar.com/funds/xnas/vtsax/chart

# %%
import datetime
end_date = datetime.datetime.today()
start_date = end_date - datetime.timedelta(30)
funds.nav(start_date,end_date)
# Out:
# [{'nav': 175.2, 'totalReturn': 273.7559, 'date': '2026-05-19'},
#  {'nav': 177.29, 'totalReturn': 277.02159, 'date': '2026-05-20'},
#  {'nav': 177.72, 'totalReturn': 277.69348, 'date': '2026-05-21'},
#  {'nav': 178.52, 'totalReturn': 278.94351, 'date': '2026-05-22'},
#  {'nav': 179.79, 'totalReturn': 280.92793, 'date': '2026-05-26'},
#  {'nav': 179.78, 'totalReturn': 280.9123, 'date': '2026-05-27'},
#  {'nav': 180.9, 'totalReturn': 282.66234, 'date': '2026-05-28'},
#  {'nav': 181.29, 'totalReturn': 283.27173, 'date': '2026-05-29'},
#  {'nav': 181.75, 'totalReturn': 283.99049, 'date': '2026-06-01'},
#  {'nav': 182.18, 'totalReturn': 284.66238, 'date': '2026-06-02'},
#  {'nav': 180.81, 'totalReturn': 282.52171, 'date': '2026-06-03'},
#  {'nav': 181.72, 'totalReturn': 283.94362, 'date': '2026-06-04'},
#  {'nav': 176.85, 'totalReturn': 276.33408, 'date': '2026-06-05'},
#  {'nav': 177.43, 'totalReturn': 277.24035, 'date': '2026-06-08'},
#  {'nav': 177.1, 'totalReturn': 276.72471, 'date': '2026-06-09'},
#  {'nav': 174.25, 'totalReturn': 272.27149, 'date': '2026-06-10'},
#  {'nav': 177.52, 'totalReturn': 277.38097, 'date': '2026-06-11'},
#  {'nav': 178.4, 'totalReturn': 278.756, 'date': '2026-06-12'},
#  {'nav': 181.29, 'totalReturn': 283.27173, 'date': '2026-06-15'},
#  {'nav': 180.22, 'totalReturn': 281.59982, 'date': '2026-06-16'},
#  {'nav': 178.1, 'totalReturn': 278.28724, 'date': '2026-06-17'}]

# %% [markdown]
# Other fees
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.otherFee()
# Out:
# {'actualManagementFee': 0.04,
#  'maximumManagementFee': 0.04,
#  'actual12b1': None,
#  'administrativeFee': 0.03394,
#  'expenseWaivers': None,
#  'performanceFee': None,
#  'fundSubType': None,
#  'PerformanceFeeCharged': None,
#  'FeeNegotiable': None}

# %% [markdown]
# Ownership zone
#
# Style box - map
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.ownershipZone()
# Out:
# {'portfolioDate': '2026-05-31T05:00:00.000',
#  'fund': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'scaledSizeScore': 267.894,
#   'scaledStyleScore': 146.48,
#   'sizeVariance': 112.16,
#   'styleVariance': 131.277,
#   'rho': 0.198,
#   'secId': 'FOUSA00L83',
#   'name': 'Vanguard Total Stock Mkt Idx Adm',
#   'objectZone75Percentile': 2.582},
#  'benchmark': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'scaledSizeScore': 288.905,
#   'scaledStyleScore': 145.845,
#   'sizeVariance': 90.098,
#   'styleVariance': 130.674,
#   'rho': 0.248,
#   'secId': 'F00000GWXD',
#   'name': 'Morningstar US LM Cap Mkt TR USD',
#   'objectZone75Percentile': 2.607},
#  'category': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'scaledSizeScore': 298.996,
#   'scaledStyleScore': 124.849,
#   'sizeVariance': 97.865,
#   'styleVariance': 124.194,
#   'rho': 0.354,
#   'secId': '$FOCA$LB$$',
#   'name': 'Large Blend',
#   'objectZone75Percentile': 2.679}}

# %% [markdown]
# Rating of top rated medalists funds of the asset manager
#
# Rating Breakdown - Medalist Rating
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentMedal()
# Out:
# {'userType': 'Free',
#  'analystRatingFundList': [{'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': ['Tracks Morningstar Index'],
#    'calendarYearFlow': -3675204664.0,
#    'netAsset': 967688547381.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 23.26132,
#    'trailing3YearReturnRank': 33.0,
#    'fundShareClassId': 'F00000VE7X',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA002PT',
#    'secId': 'F00000VE7X',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': [],
#    'calendarYearFlow': -32256404070.0,
#    'netAsset': 690292250669.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 23.55714,
#    'trailing3YearReturnRank': 24.0,
#    'fundShareClassId': 'FOUSA00L8W',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA002QH',
#    'secId': 'FOUSA00L8W',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': [],
#    'calendarYearFlow': -23326815029.0,
#    'netAsset': 274018141189.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 20.39869,
#    'trailing3YearReturnRank': 28.0,
#    'fundShareClassId': 'FOUSA00KIR',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA004JJ',
#    'secId': 'FOUSA00KIR',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': [],
#    'calendarYearFlow': -21368706418.0,
#    'netAsset': 220336782281.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 23.58254,
#    'trailing3YearReturnRank': 23.0,
#    'fundShareClassId': 'FOUSA00GPG',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA002Q0',
#    'secId': 'FOUSA00GPG',
#    'securityType': 'FO'},
#   {'rating': None,
#    'medalistRating': '7',
#    'medalistRatingLabel': 'GOLD',
#    'disclosureCodes': [],
#    'calendarYearFlow': 37045340978.0,
#    'netAsset': 206720364043.0,
#    'epUsedFor3YearReturn': '0',
#    'trailing3YearReturn': 3.92422,
#    'trailing3YearReturnRank': 59.0,
#    'fundShareClassId': 'FOUSA08OZU',
#    'name': '_PO_',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'fundId': 'FSUSA09PA2',
#    'secId': 'FOUSA08OZU',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2026-05-31T05:00:00.000',
#  'footerReturnDate': '2026-05-31T05:00:00.000',
#  'currency': 'USD',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Breakdown of asset manager funds by medalist rating
#
# Rating Breakdown - Medalist Rating
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentMedaListRating()
# Out:
# [{'rating': None,
#   'medalistRating': '7',
#   'medalistRatingLabel': 'GOLD',
#   'shareClassCount': 186,
#   'percent': 0.9117523926,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '6',
#   'medalistRatingLabel': 'SILVER',
#   'shareClassCount': 36,
#   'percent': 0.0508509816,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '5',
#   'medalistRatingLabel': 'BRONZE',
#   'shareClassCount': 31,
#   'percent': 0.0296977207,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '4',
#   'medalistRatingLabel': 'NEUTRAL',
#   'shareClassCount': 18,
#   'percent': 0.007698905,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '3',
#   'medalistRatingLabel': 'NEGATIVE',
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False},
#  {'rating': None,
#   'medalistRating': '2',
#   'medalistRatingLabel': 'UNDER_REVIEW',
#   'shareClassCount': 0,
#   'percent': 0.0,
#   'noPremiumChinaFund': False}]

# %% [markdown]
# Breakdown of asset manager funds by star rating
#
# Rating Breakdown - Morningstar Rating
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentMstarRating()
# Out:
# [{'naPercentage': 0.0007371934, 'mstarRating': '1'},
#  {'naPercentage': 0.0445830524, 'mstarRating': '2'},
#  {'naPercentage': 0.4379595087, 'mstarRating': '3'},
#  {'naPercentage': 0.4824366493, 'mstarRating': '4'},
#  {'naPercentage': 0.0321577899, 'mstarRating': '5'},
#  {'naPercentage': 0.0021258063, 'mstarRating': 'Not Rated'}]

# %% [markdown]
# Recent change in rating
#
# Rating Breakdown - Medalist List - Recent Investment Ratings Change
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentRatingRecentChange()
# Out:
# {'topAnalystRatingUpDownList': [{'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '6',
#    'medalistPrevRating': '6',
#    'currRatingDisclosureCodes': [],
#    'medalistCurrRatingLabel': 'SILVER',
#    'medalistPrevRatingLabel': 'SILVER',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-06-03T05:00:00.000',
#    'medalistPrevRatingDate': '2026-04-27T10:53:00.000',
#    'netAsset': 15293511767.0,
#    'fundId': 'FSUSA002QB',
#    'securityType': 'FO',
#    'secId': 'FOUSA02T4I'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '6',
#    'medalistPrevRating': '6',
#    'currRatingDisclosureCodes': [],
#    'medalistCurrRatingLabel': 'SILVER',
#    'medalistPrevRatingLabel': 'SILVER',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-06-15T05:00:00.000',
#    'medalistPrevRatingDate': '2026-04-27T10:52:00.000',
#    'netAsset': 38217559111.0,
#    'fundId': 'FSUSA002RC',
#    'securityType': 'FO',
#    'secId': 'FOUSA02TIF'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '4',
#    'medalistPrevRating': '4',
#    'currRatingDisclosureCodes': [],
#    'medalistCurrRatingLabel': 'NEUTRAL',
#    'medalistPrevRatingLabel': 'NEUTRAL',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-04-30T05:00:00.000',
#    'medalistPrevRatingDate': '2026-03-31T05:00:00.000',
#    'netAsset': 6644844199.0,
#    'fundId': 'FSUSA002PN',
#    'securityType': 'FO',
#    'secId': 'FOUSA02SNG'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '4',
#    'medalistPrevRating': '4',
#    'currRatingDisclosureCodes': [],
#    'medalistCurrRatingLabel': 'NEUTRAL',
#    'medalistPrevRatingLabel': 'NEUTRAL',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-04-30T05:00:00.000',
#    'medalistPrevRatingDate': '2026-03-31T05:00:00.000',
#    'netAsset': 18933630064.0,
#    'fundId': 'FSUSA0005G',
#    'securityType': 'FO',
#    'secId': 'FOUSA02TYB'},
#   {'fundName': '_PO_',
#    'mstarCurrRating': None,
#    'mstarPrevRating': None,
#    'mstarCurrRatingValue': None,
#    'mstarPrevRatingValue': None,
#    'medalistCurrRating': '5',
#    'medalistPrevRating': '5',
#    'currRatingDisclosureCodes': [],
#    'medalistCurrRatingLabel': 'BRONZE',
#    'medalistPrevRatingLabel': 'BRONZE',
#    'currRatingDate': None,
#    'prevRatingDate': None,
#    'medalistCurrRatingDate': '2026-04-30T05:00:00.000',
#    'medalistPrevRatingDate': '2026-03-31T05:00:00.000',
#    'netAsset': 22836526548.0,
#    'fundId': 'FSUSA04CI9',
#    'securityType': 'FO',
#    'secId': 'FOUSA04BNE'}],
#  'userType': 'Free',
#  'currency': 'USD',
#  'securityType': 'FO',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'secId': 'FOUSA00L83',
#  'noPremiumChinaFund': False}

# %% [markdown]
# Information about the asset manager
#
# Parent
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.parentSummary()
# Out:
# {'secId': 'FOUSA00L83',
#  'fundId': 'FSUSA002PT',
#  'companyId': '0C00001YUF',
#  'marketName': 'US Open-end ex MM ex FoF ex Feeder',
#  'firmName': 'Vanguard',
#  'currency': 'USD',
#  'netAsset': 6538663287123.0,
#  'netFlowTTM': -164300216825.0,
#  'netAssetTTM': 5708288227885.0,
#  'assetGrowthRate': -0.0287827472,
#  'numFund': 149,
#  'managerRetention5Year': 91.43,
#  'template': 'USA_OE',
#  'domicileCountryId': 'USA'}

# %% [markdown]
# People who manage the fund
#
# Management Team
#
# https://www.morningstar.com/funds/xnas/vtsax/people

# %%
funds.people()
# Out:
# {'inceptionDate': '2000-11-13T06:00:00.000',
#  'averageManagerTenure': 4.94,
#  'longestManagerTenure': 10.17,
#  'advisorType': 'Vanguard Group, Inc. (via Vanguard Capital Mgmt)',
#  'subadvised': '0',
#  'managerCount': 3,
#  'womenOnTeams': 32.65,
#  'advisorList': [{'advisorId': '0C00015RYO',
#    'advisorDisplayName': 'Vanguard Group, Inc. (via Vanguard Capital Mgmt)',
#    'regionId': None,
#    'languageId': None,
#    'subAdvisorId': None,
#    'subAdvisorName': None}],
#  'subAdvisorList': [],
#  'currentManagerList': [{'personId': '168359',
#    'familyName': 'Nejman',
#    'middleName': None,
#    'givenName': 'Walter',
#    'startDate': '2016-04-27T05:00:00.000',
#    'ownershipLevelId': '1',
#    'endDate': None,
#    'gender': 'male',
#    'genderSourceType': 'reported'},
#   {'personId': '182724',
#    'familyName': 'Louie',
#    'middleName': None,
#    'givenName': 'Michelle',
#    'startDate': '2023-02-17T06:00:00.000',
#    'ownershipLevelId': '7',
#    'endDate': None,
#    'gender': 'female',
#    'genderSourceType': 'derived'},
#   {'personId': '205451',
#    'familyName': 'Birkett',
#    'middleName': None,
#    'givenName': 'Nick',
#    'startDate': '2025-02-18T06:00:00.000',
#    'ownershipLevelId': '1',
#    'endDate': None,
#    'gender': 'male',
#    'genderSourceType': 'derived'}],
#  'pastManagerList': [{'personId': '1597',
#    'familyName': 'Sauter',
#    'middleName': 'U.',
#    'givenName': 'George',
#    'startDate': '1992-04-27T05:00:00.000',
#    'ownershipLevelId': None,
#    'endDate': '2005-04-29T05:00:00.000',
#    'gender': 'male',
#    'genderSourceType': 'reported'},
#   {'personId': '98675',
#    'familyName': 'O’Reilly',
#    'middleName': 'C.',
#    'givenName': 'Gerard',
#    'startDate': '1994-12-31T06:00:00.000',
#    'ownershipLevelId': '6',
#    'endDate': '2025-06-18T05:00:00.000',
#    'gender': 'male',
#    'genderSourceType': 'reported'}],
#  'lastTurnoverRatio': 0.03,
#  'longestTenureStartDate': '2016-04-27'}

# %% [markdown]
# Performance of the fund, category and index by year
#
# Annual Returns
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.performanceTable()
# Out:
# {'userType': 'Free',
#  'baseCurrency': 'USD',
#  'domicileCountryId': 'USA',
#  'asOfDate': '2026-06-17T00:00:00.000',
#  'startDate': '2016-01-01T00:00:00.000',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'table': {'columnDefs': ['2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    '2025',
#    'YTD'],
#   'growth10KReturnData': [{'label': 'fund',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['12.66422',
#      '21.16927',
#      '-5.1711',
#      '30.80497',
#      '20.98791',
#      '25.71229',
#      '-19.52516',
#      '26.00822',
#      '23.74332',
#      '17.11781',
#      '9.47415'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'category',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['10.36891',
#      '20.43837',
#      '-6.26928',
#      '28.77649',
#      '15.82748',
#      '26.06759',
#      '-16.95545',
#      '22.31864',
#      '21.44601',
#      '15.54386',
#      '8.21613'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'index',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['11.58523',
#      '21.71165',
#      '-4.52374',
#      '31.60802',
#      '21.10674',
#      '26.44469',
#      '-19.49782',
#      '26.85193',
#      '25.06815',
#      '17.71047',
#      '9.19416'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'percentileRank',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['20',
#      '45',
#      '42',
#      '39',
#      '17',
#      '63',
#      '75',
#      '33',
#      '43',
#      '40',
#      '31'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'fundNumber',
#     'endDate': '2026-06-17T00:00:00.000',
#     'datum': ['1409',
#      '1396',
#      '1402',
#      '1387',
#      '1363',
#      '1382',
#      '1358',
#      '1430',
#      '1386',
#      '1314',
#      '1343'],
#     'epFlag': [False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False,
#      False]},
#    {'label': 'categoryName',
#     'endDate': None,
#     'datum': ['US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend',
#      'US Fund Large Blend'],
#     'epFlag': []},
#    {'label': 'categoryNameAbbr',
#     'endDate': None,
#     'datum': ['LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB',
#      'LB'],
#     'epFlag': []}]},
#  'currentValues': [{'type': 'fund',
#    'name': 'VTSAX',
#    'baseCurrency': 'USD',
#    'currentValue': '41436.055190055486',
#    'currentSymbol': '$'},
#   {'type': 'index',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': '42899.42153083712',
#    'currentSymbol': '$'},
#   {'type': 'category',
#    'name': '',
#    'baseCurrency': 'USD',
#    'currentValue': '35228.619683596844',
#    'currentSymbol': '$'}],
#  'restructureDate': None}

# %% [markdown]
# Holdings in dict format
#
# Holdings
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.position()
# Out:
# {'masterPortfolioId': '3506',
#  'secId': 'FOUSA00L83',
#  'baseCurrencyId': 'USD',
#  'domicileCountryId': 'USA',
#  'numberOfHolding': 3498,
#  'numberOfEquityHolding': 3478,
#  'numberOfBondHolding': 0,
#  'numberOfOtherHolding': 20,
#  'numberOfHoldingShort': 0,
#  'numberOfEquityHoldingShort': 0,
#  'numberOfBondHoldingShort': 0,
#  'numberOfOtherHoldingShort': 0,
#  'topNCount': 0,
#  'portfolioSuppression': '0',
#  'assetType': 'EQUITY',
#  'holdingSummary': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'topHoldingWeighting': 34.60882,
#   'equityNumberOfHolding': 3478,
#   'fixedIncomeNumberOfHolding': 0,
#   'numberOfHolding': 3498,
#   'numberOfOtherHolding': 20,
#   'lastTurnover': 3.0,
#   'LastTurnoverDate': '2025-12-31T06:00:00.000',
#   'secId': 'FOUSA00L83',
#   'averageTurnoverRatio': 94.24296,
#   'womenDirectors': 33.6,
#   'womenExecutives': 27.53},
#  'holdingActiveShare': {'activeShareValue': None,
#   'activeShareDate': None,
#   'etfBenchmarkProxyName': None,
#   'primaryProspectusBenchmark': 'CRSP US Total Market TR USD'},
#  'equityHoldingPage': {'pageSize': 10000,
#   'pageNumber': 1,
#   'totalPage': 1,
#   'numberOfCurPageHolding': 3479,
#   'numberOfAllHolding': 3479,
#   'holdingList': [{'securityName': 'NVIDIA Corp',
#     'secId': '0P000003RE',
#     'performanceId': '0P000003RE',
#     'holdingTypeId': 'E',
#     'weighting': 6.69694,
#     'numberOfShare': 734760640.0,
#     'marketValue': 155137361530.0,
#     'shareChange': -812255.0,
#     'country': 'United States',
#     'ticker': 'NVDA',
#     'totalReturn1Year': 42.194,
#     'forwardPERatio': 23.31,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [129381996836.0,
#       127888500302.0,
#       146798282655.0,
#       155137361530.0]},
#     'holdingType': 'Equity',
#     'isin': 'US67066G1040',
#     'cusip': '67066G104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 12.44,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-18T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 155137361530.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Apple Inc',
#     'secId': '0P000000GY',
#     'performanceId': '0P000000GY',
#     'holdingTypeId': 'E',
#     'weighting': 6.29467,
#     'numberOfShare': 467277295.0,
#     'marketValue': 145818552678.0,
#     'shareChange': -518710.0,
#     'country': 'United States',
#     'ticker': 'AAPL',
#     'totalReturn1Year': 51.8095,
#     'forwardPERatio': 31.0559,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [123472406131.0,
#       118356069725.0,
#       126936445957.0,
#       145818552678.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0378331005',
#     'cusip': '037833100',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 15.31,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 145818552678.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Microsoft Corp',
#     'secId': '0P000003MH',
#     'performanceId': '0P000003MH',
#     'holdingTypeId': 'E',
#     'weighting': 4.59357,
#     'numberOfShare': 236344917.0,
#     'marketValue': 106411935430.0,
#     'shareChange': -264058.0,
#     'country': 'United States',
#     'ticker': 'MSFT',
#     'totalReturn1Year': -19.9921,
#     'forwardPERatio': 19.5313,
#     'stockRating': '5',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [92328831081.0,
#       87314811932.0,
#       96484407826.0,
#       106411935430.0]},
#     'holdingType': 'Equity',
#     'isin': 'US5949181045',
#     'cusip': '594918104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 14.35,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '5',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 106411935430.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Amazon.com Inc',
#     'secId': '0P000000B7',
#     'performanceId': '0P000000B7',
#     'holdingTypeId': 'E',
#     'weighting': 3.59259,
#     'numberOfShare': 307507663.0,
#     'marketValue': 83223873914.0,
#     'shareChange': -341886.0,
#     'country': 'United States',
#     'ticker': 'AMZN',
#     'totalReturn1Year': 10.5577,
#     'forwardPERatio': 31.1526,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Cyclical',
#     'sectorCode': 'consumerCyclical',
#     'holdingTrend': {'trend': [63907950540.0,
#       63918131729.0,
#       81598601458.0,
#       83223873914.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0231351067',
#     'cusip': '023135106',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 16.64,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 83223873914.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Alphabet Inc Class A',
#     'secId': '0P000002HD',
#     'performanceId': '0P000002HD',
#     'holdingTypeId': 'E',
#     'weighting': 3.04395,
#     'numberOfShare': 185398372.0,
#     'marketValue': 70514416806.0,
#     'shareChange': -68340.0,
#     'country': 'United States',
#     'ticker': 'GOOGL',
#     'totalReturn1Year': 107.2407,
#     'forwardPERatio': 25.7732,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [57348456203.0,
#       53184119916.0,
#       71367590778.0,
#       70514416806.0]},
#     'holdingType': 'Equity',
#     'isin': 'US02079K3059',
#     'cusip': '02079K305',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-09-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 19.86,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 70514416806.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Broadcom Inc',
#     'secId': '0P0000KU35',
#     'performanceId': '0P0000KU35',
#     'holdingTypeId': 'E',
#     'weighting': 2.91042,
#     'numberOfShare': 150907787.0,
#     'marketValue': 67421071998.0,
#     'shareChange': -166530.0,
#     'country': 'United States',
#     'ticker': 'AVGO',
#     'totalReturn1Year': 58.5516,
#     'forwardPERatio': 34.0136,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [47731637261.0,
#       46615025017.0,
#       63062952145.0,
#       67421071998.0]},
#     'holdingType': 'Equity',
#     'isin': 'US11135F1012',
#     'cusip': '11135F101',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2018-04-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 20.11,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '4',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 67421071998.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Alphabet Inc Class C',
#     'secId': '0P00012BBI',
#     'performanceId': '0P00012BBI',
#     'holdingTypeId': 'E',
#     'weighting': 2.38911,
#     'numberOfShare': 147025372.0,
#     'marketValue': 55344760782.0,
#     'shareChange': -302124.0,
#     'country': 'United States',
#     'ticker': 'GOOG',
#     'totalReturn1Year': 104.7904,
#     'forwardPERatio': 25.641,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [45296771294.0,
#       42115190545.0,
#       56270263822.0,
#       55344760782.0]},
#     'holdingType': 'Equity',
#     'isin': 'US02079K1079',
#     'cusip': '02079K107',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2018-05-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 19.86,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 55344760782.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Meta Platforms Inc Class A',
#     'secId': '0P0000W3KZ',
#     'performanceId': '0P0000W3KZ',
#     'holdingTypeId': 'E',
#     'weighting': 1.90076,
#     'numberOfShare': 69614494.0,
#     'marketValue': 44031863600.0,
#     'shareChange': -77172.0,
#     'country': 'United States',
#     'ticker': 'META',
#     'totalReturn1Year': -18.2938,
#     'forwardPERatio': 18.0505,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Communication Services',
#     'sectorCode': 'communicationsServices',
#     'holdingTrend': {'trend': [44651887362.0,
#       39749746136.0,
#       42645027342.0,
#       44031863600.0]},
#     'holdingType': 'Equity',
#     'isin': 'US30303M1027',
#     'cusip': '30303M102',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2012-06-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 24.31,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-18T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '5',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 44031863600.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Tesla Inc',
#     'secId': '0P0000OQN8',
#     'performanceId': '0P0000OQN8',
#     'holdingTypeId': 'E',
#     'weighting': 1.68524,
#     'numberOfShare': 89582914.0,
#     'marketValue': 39039338092.0,
#     'shareChange': -100263.0,
#     'country': 'United States',
#     'ticker': 'TSLA',
#     'totalReturn1Year': 25.2979,
#     'forwardPERatio': 200.0,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Narrow',
#     'sector': 'Consumer Cyclical',
#     'sectorCode': 'consumerCyclical',
#     'holdingTrend': {'trend': [35992300504.0,
#       33236501316.0,
#       34225790839.0,
#       39039338092.0]},
#     'holdingType': 'Equity',
#     'isin': 'US88160R1014',
#     'cusip': '88160R101',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2010-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 18.84,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 39039338092.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Micron Technology Inc',
#     'secId': '0P000003MC',
#     'performanceId': '0P000003MC',
#     'holdingTypeId': 'E',
#     'weighting': 1.50157,
#     'numberOfShare': 35823336.0,
#     'marketValue': 34784459256.0,
#     'shareChange': -39050.0,
#     'country': 'United States',
#     'ticker': 'MU',
#     'totalReturn1Year': 767.2802,
#     'forwardPERatio': 9.6899,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'None',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [14678855716.0,
#       12078496559.0,
#       18546591544.0,
#       34784459256.0]},
#     'holdingType': 'Equity',
#     'isin': 'US5951121038',
#     'cusip': '595112103',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 19.56,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 34784459256.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Eli Lilly and Co',
#     'secId': '0P000001WJ',
#     'performanceId': '0P000001WJ',
#     'holdingTypeId': 'E',
#     'weighting': 1.28903,
#     'numberOfShare': 27023391.0,
#     'marketValue': 29860847055.0,
#     'shareChange': -29991.0,
#     'country': 'United States',
#     'ticker': 'LLY',
#     'totalReturn1Year': 41.3553,
#     'forwardPERatio': 30.6748,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': {'trend': [28312861208.0,
#       24806426842.0,
#       25284090817.0,
#       29860847055.0]},
#     'holdingType': 'Equity',
#     'isin': 'US5324571083',
#     'cusip': '532457108',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 20.58,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 29860847055.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Berkshire Hathaway Inc Class B',
#     'secId': '0P000000RD',
#     'performanceId': '0P000000RD',
#     'holdingTypeId': 'E',
#     'weighting': 1.16595,
#     'numberOfShare': 56924669.0,
#     'marketValue': 27009616947.0,
#     'shareChange': -105045.0,
#     'country': 'United States',
#     'ticker': 'BRK.B',
#     'totalReturn1Year': 1.6133,
#     'forwardPERatio': 23.31,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Narrow',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [28679242705.0,
#       27228502921.0,
#       27009272550.0,
#       27009616947.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0846707026',
#     'cusip': '084670702',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2010-03-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 25.16,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 27009616947.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Advanced Micro Devices Inc',
#     'secId': '0P0000006A',
#     'performanceId': '0P0000006A',
#     'holdingTypeId': 'E',
#     'weighting': 1.15613,
#     'numberOfShare': 51893551.0,
#     'marketValue': 26782261671.0,
#     'shareChange': -56912.0,
#     'country': 'United States',
#     'ticker': 'AMD',
#     'totalReturn1Year': 303.2101,
#     'forwardPERatio': 72.9927,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Narrow',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [10310251609.0,
#       10535864897.0,
#       18415919629.0,
#       26782261671.0]},
#     'holdingType': 'Equity',
#     'isin': 'US0079031078',
#     'cusip': '007903107',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2013-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 11.61,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 26782261671.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'JPMorgan Chase & Co',
#     'secId': '0P0000031C',
#     'performanceId': '0P0000031C',
#     'holdingTypeId': 'E',
#     'weighting': 1.03541,
#     'numberOfShare': 80136501.0,
#     'marketValue': 23985656114.0,
#     'shareChange': -94598.0,
#     'country': 'United States',
#     'ticker': 'JPM',
#     'totalReturn1Year': 25.9127,
#     'forwardPERatio': 15.2207,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [24195851780.0,
#       23763720601.0,
#       25130787140.0,
#       23985656114.0]},
#     'holdingType': 'Equity',
#     'isin': 'US46625H1005',
#     'cusip': '46625H100',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 16.64,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 23985656114.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Exxon Mobil Corp',
#     'secId': '0P00000220',
#     'performanceId': '0P00000220',
#     'holdingTypeId': 'E',
#     'weighting': 0.83159,
#     'numberOfShare': 132617732.0,
#     'marketValue': 19264051750.0,
#     'shareChange': -154714.0,
#     'country': 'United States',
#     'ticker': 'XOM',
#     'totalReturn1Year': 27.0351,
#     'forwardPERatio': 12.5,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Narrow',
#     'sector': 'Energy',
#     'sectorCode': 'energy',
#     'holdingTrend': {'trend': [20342251330.0,
#       22455575457.0,
#       20490771591.0,
#       19264051750.0]},
#     'holdingType': 'Equity',
#     'isin': 'US30231G1022',
#     'cusip': '30231G102',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 38.19,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-18T05:00:00.000',
#     'susEsgRiskCategory': 'High',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 19264051750.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Johnson & Johnson',
#     'secId': '0P0000032S',
#     'performanceId': '0P0000032S',
#     'holdingTypeId': 'E',
#     'weighting': 0.74609,
#     'numberOfShare': 76702652.0,
#     'marketValue': 17283408575.0,
#     'shareChange': -88207.0,
#     'country': 'United States',
#     'ticker': 'JNJ',
#     'totalReturn1Year': 57.1335,
#     'forwardPERatio': 20.2429,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Healthcare',
#     'sectorCode': 'healthcare',
#     'holdingTrend': {'trend': [18932777510.0,
#       18712506055.0,
#       17650378941.0,
#       17283408575.0]},
#     'holdingType': 'Equity',
#     'isin': 'US4781601046',
#     'cusip': '478160104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 18.79,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 17283408575.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Visa Inc Class A',
#     'secId': '0P0000CPCP',
#     'performanceId': '0P0000CPCP',
#     'holdingTypeId': 'E',
#     'weighting': 0.73934,
#     'numberOfShare': 52479243.0,
#     'marketValue': 17127125745.0,
#     'shareChange': -64254.0,
#     'country': 'United States',
#     'ticker': 'V',
#     'totalReturn1Year': -6.9472,
#     'forwardPERatio': 22.0264,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [16759577429.0,
#       15829922459.0,
#       17330947050.0,
#       17127125745.0]},
#     'holdingType': 'Equity',
#     'isin': 'US92826C8394',
#     'cusip': '92826C839',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2008-03-31T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 13.9,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 17127125745.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Walmart Inc',
#     'secId': '0P000005UH',
#     'performanceId': '0P000005UH',
#     'holdingTypeId': 'E',
#     'weighting': 0.69715,
#     'numberOfShare': 139522671.0,
#     'marketValue': 16149749168.0,
#     'shareChange': -163899.0,
#     'country': 'United States',
#     'ticker': 'WMT',
#     'totalReturn1Year': 26.3607,
#     'forwardPERatio': 40.4858,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Defensive',
#     'sectorCode': 'consumerDefensive',
#     'holdingTrend': {'trend': [17747114616.0,
#       17305268306.0,
#       18428849180.0,
#       16149749168.0]},
#     'holdingType': 'Equity',
#     'isin': 'US9311421039',
#     'cusip': '931142103',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 18.63,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-18T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 16149749168.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Intel Corp',
#     'secId': '0P000002X8',
#     'performanceId': '0P000002X8',
#     'holdingTypeId': 'E',
#     'weighting': 0.62964,
#     'numberOfShare': 127187295.0,
#     'marketValue': 14585838991.0,
#     'shareChange': -137828.0,
#     'country': 'United States',
#     'ticker': 'INTC',
#     'totalReturn1Year': 482.2115,
#     'forwardPERatio': 138.8889,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'None',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [5848784804.0,
#       5601810744.0,
#       12029677621.0,
#       14585838991.0]},
#     'holdingType': 'Equity',
#     'isin': 'US4581401001',
#     'cusip': '458140100',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 19.05,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '2',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 14585838991.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Cisco Systems Inc',
#     'secId': '0P0000019Y',
#     'performanceId': '0P0000019Y',
#     'holdingTypeId': 'E',
#     'weighting': 0.58816,
#     'numberOfShare': 113145780.0,
#     'marketValue': 13625014828.0,
#     'shareChange': -127672.0,
#     'country': 'United States',
#     'ticker': 'CSCO',
#     'totalReturn1Year': 82.1215,
#     'forwardPERatio': 24.6914,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [8938087262.0,
#       8761813196.0,
#       10364520858.0,
#       13625014828.0]},
#     'holdingType': 'Equity',
#     'isin': 'US17275R1023',
#     'cusip': '17275R102',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 12.46,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-18T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 13625014828.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Costco Wholesale Corp',
#     'secId': '0P000001IK',
#     'performanceId': '0P000001IK',
#     'holdingTypeId': 'E',
#     'weighting': 0.5832,
#     'numberOfShare': 14127166.0,
#     'marketValue': 13510091389.0,
#     'shareChange': -17090.0,
#     'country': 'United States',
#     'ticker': 'COST',
#     'totalReturn1Year': -0.6914,
#     'forwardPERatio': 42.9185,
#     'stockRating': '2',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Consumer Defensive',
#     'sectorCode': 'consumerDefensive',
#     'holdingTrend': {'trend': [14168609336.0,
#       14048780163.0,
#       14349772040.0,
#       13510091389.0]},
#     'holdingType': 'Equity',
#     'isin': 'US22160K1051',
#     'cusip': '22160K105',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 24.49,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-18T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 13510091389.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Caterpillar Inc',
#     'secId': '0P0000014I',
#     'performanceId': '0P0000014I',
#     'holdingTypeId': 'E',
#     'weighting': 0.55993,
#     'numberOfShare': 14809241.0,
#     'marketValue': 12970969915.0,
#     'shareChange': -16398.0,
#     'country': 'United States',
#     'ticker': 'CAT',
#     'totalReturn1Year': 168.9443,
#     'forwardPERatio': 39.5257,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Industrials',
#     'sectorCode': 'industrials',
#     'holdingTrend': {'trend': [10996013694.0,
#       10470494703.0,
#       13196449530.0,
#       12970969915.0]},
#     'holdingType': 'Equity',
#     'isin': 'US1491231015',
#     'cusip': '149123101',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 24.96,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-17T05:00:00.000',
#     'susEsgRiskCategory': 'Medium',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 12970969915.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Lam Research Corp',
#     'secId': '0P00000384',
#     'performanceId': '0P00000384',
#     'holdingTypeId': 'E',
#     'weighting': 0.54592,
#     'numberOfShare': 39746468.0,
#     'marketValue': 12646531188.0,
#     'shareChange': -41190.0,
#     'country': 'United States',
#     'ticker': 'LRCX',
#     'totalReturn1Year': 305.191,
#     'forwardPERatio': 47.3934,
#     'stockRating': '1',
#     'assessment': 'Overvalued',
#     'economicMoat': 'Wide',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [9292309366.0,
#       8475108281.0,
#       10259645492.0,
#       12646531188.0]},
#     'holdingType': 'Equity',
#     'isin': 'US5128073062',
#     'cusip': '512807306',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2003-12-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 12.63,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-18T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '1',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 12646531188.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Mastercard Inc Class A',
#     'secId': '0P00005U6B',
#     'performanceId': '0P00005U6B',
#     'holdingTypeId': 'E',
#     'weighting': 0.54069,
#     'numberOfShare': 25355800.0,
#     'marketValue': 12525258084.0,
#     'shareChange': -30506.0,
#     'country': 'United States',
#     'ticker': 'MA',
#     'totalReturn1Year': -12.8545,
#     'forwardPERatio': 25.1256,
#     'stockRating': '4',
#     'assessment': 'Undervalued',
#     'economicMoat': 'Wide',
#     'sector': 'Financial Services',
#     'sectorCode': 'financialService',
#     'holdingTrend': {'trend': [13121184278.0,
#       12644581834.0,
#       12767281014.0,
#       12525258084.0]},
#     'holdingType': 'Equity',
#     'isin': 'US57636Q1040',
#     'cusip': '57636Q104',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2006-06-30T05:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 16.3,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-18T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '3',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 12525258084.0,
#     'isMomentumFilterFlag': False},
#    {'securityName': 'Oracle Corp',
#     'secId': '0P0000043L',
#     'performanceId': '0P0000043L',
#     'holdingTypeId': 'E',
#     'weighting': 0.53478,
#     'numberOfShare': 54868880.0,
#     'marketValue': 12388295726.0,
#     'shareChange': -60350.0,
#     'country': 'United States',
#     'ticker': 'ORCL',
#     'totalReturn1Year': -10.88,
#     'forwardPERatio': 22.7273,
#     'stockRating': '3',
#     'assessment': 'Fairly Valued',
#     'economicMoat': 'Narrow',
#     'sector': 'Technology',
#     'sectorCode': 'technology',
#     'holdingTrend': {'trend': [7867156491.0,
#       8055841722.0,
#       8865028430.0,
#       12388295726.0]},
#     'holdingType': 'Equity',
#     'isin': 'US68389X1054',
#     'cusip': '68389X105',
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': '2004-03-31T06:00:00.000',
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': None,
#     'ePUsedForOverallRating': 0,
#     'analystRating': None,
#     'medalistRating': None,
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': 15.78,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': '2026-06-18T05:00:00.000',
#     'susEsgRiskCategory': 'Low',
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': '4',
#     'bestRatingType': 'Qual',
#     'securityType': 'ST',
#     'domicileCountryId': 'USA',
# ...
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 84324408.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Trs:elevance Health Inc Usd 2027-Jan-29',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'ST',
#     'weighting': 0.00307,
#     'numberOfShare': 180923.0,
#     'marketValue': 71137114.0,
#     'shareChange': 0.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 71137114.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Trs:global Payments Inc Usd 2026-Aug-31',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'ST',
#     'weighting': 0.00141,
#     'numberOfShare': 431201.0,
#     'marketValue': 32559988.0,
#     'shareChange': 103559.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 32559988.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Trs:raymond James Financial Inc Usd 2027-Jan-29',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'ST',
#     'weighting': 0.00097,
#     'numberOfShare': 157355.0,
#     'marketValue': 22566281.0,
#     'shareChange': 0.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 22566281.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Euro',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'CH',
#     'weighting': 0.00011,
#     'numberOfShare': 2216062.0,
#     'marketValue': 2584815.0,
#     'shareChange': 2216062.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': '501013',
#     'superSectorName': 'cashAndEquivalents',
#     'primarySectorName': 'cashAndEquivalents',
#     'secondarySectorName': 'Currency',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 2584815.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': "Escrow Luby's Inc",
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'AP',
#     'weighting': 0.0,
#     'numberOfShare': 449752.0,
#     'marketValue': 112438.0,
#     'shareChange': 0.0,
#     'country': None,
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': None,
#     'secondarySectorId': None,
#     'superSectorName': None,
#     'primarySectorName': None,
#     'secondarySectorName': None,
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 112438.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Srax Pfd',
#     'secId': None,
#     'performanceId': None,
#     'holdingTypeId': 'P',
#     'weighting': 0.0,
#     'numberOfShare': 590641.0,
#     'marketValue': 41345.0,
#     'shareChange': 0.0,
#     'country': 'United States',
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': None,
#     'cusip': '78472M205',
#     'secondarySectorId': '304012',
#     'superSectorName': 'corporate',
#     'primarySectorName': 'Preferred',
#     'secondarySectorName': 'Unspecified',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 41345.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Clearone Inc',
#     'secId': 'B1000HOJJT',
#     'performanceId': None,
#     'holdingTypeId': 'P',
#     'weighting': 0.0,
#     'numberOfShare': 12200.0,
#     'marketValue': 2684.0,
#     'shareChange': -12448.0,
#     'country': 'United States',
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': 'US18506U3023',
#     'cusip': '18506U302',
#     'secondarySectorId': '304011',
#     'superSectorName': 'corporate',
#     'primarySectorName': 'Preferred',
#     'secondarySectorName': 'Technology',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': None,
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': None,
#     'originalMarketValue': 2684.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Btcs Incorporation',
#     'secId': 'B10003UJJ6',
#     'performanceId': None,
#     'holdingTypeId': 'P',
#     'weighting': 0.0,
#     'numberOfShare': 280193.0,
#     'marketValue': 3.0,
#     'shareChange': 0.0,
#     'country': 'United States',
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': 'US05581M5031',
#     'cusip': '05581M503',
#     'secondarySectorId': '304011',
#     'superSectorName': 'corporate',
#     'primarySectorName': 'Preferred',
#     'secondarySectorName': 'Technology',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 3.0,
#     'isMomentumFilterFlag': None},
#    {'securityName': 'Nutriband Inc',
#     'secId': 'B1000HLHOF',
#     'performanceId': None,
#     'holdingTypeId': 'P',
#     'weighting': 0.0,
#     'numberOfShare': 30646.0,
#     'marketValue': 0.0,
#     'shareChange': 0.0,
#     'country': 'United States',
#     'ticker': None,
#     'totalReturn1Year': None,
#     'forwardPERatio': None,
#     'stockRating': None,
#     'assessment': None,
#     'economicMoat': None,
#     'sector': None,
#     'sectorCode': None,
#     'holdingTrend': None,
#     'holdingType': 'Other',
#     'isin': 'US67092M4069',
#     'cusip': '67092M406',
#     'secondarySectorId': '304001',
#     'superSectorName': 'corporate',
#     'primarySectorName': 'Preferred',
#     'secondarySectorName': 'Basic Materials',
#     'firstBoughtDate': None,
#     'maturityDate': None,
#     'coupon': None,
#     'currency': 'USD',
#     'localCurrencyCode': None,
#     'prospectusNetExpenseRatio': None,
#     'oneYearReturn': None,
#     'morningstarRating': '_PO_',
#     'ePUsedForOverallRating': 0,
#     'analystRating': '_PO_',
#     'medalistRating': '_PO_',
#     'medalistRatingLabel': None,
#     'disclosureCodes': None,
#     'overallRatingPublishDateUtc': None,
#     'totalAssets': None,
#     'ttmYield': None,
#     'epUsedFor1YearReturn': 0,
#     'morningstarCategory': None,
#     'totalAssetsMagnitude': None,
#     'lastTurnoverRatio': None,
#     'susEsgRiskScore': None,
#     'susEsgRiskGlobes': None,
#     'esgAsOfDate': None,
#     'susEsgRiskCategory': None,
#     'managementExpenseRatio': None,
#     'qualRating': None,
#     'quantRating': None,
#     'bestRatingType': None,
#     'securityType': None,
#     'domicileCountryId': None,
#     'currencyName': 'US Dollar',
#     'originalMarketValue': 0.0,
#     'isMomentumFilterFlag': None}],
#   'previousPeriodsDate': None},
#  'userType': 'Free',
#  'portfolioLastestDateFooter': '2026-05-31T05:00:00.000',
#  'noPremiumChinaFund': False,
#  'numberOfEquityHoldingPer': 99.42800000000001,
#  'numberOfBondHoldingPer': 0.0,
#  'numberOfOtherHoldingPer': 0.5720000000000001}

# %% [markdown]
# Assets exposed to a range of activities
#
# Sustainability - Values - Product Involvement
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.productInvolvement()
# Out:
# {'fundEffectiveDate': '2026-04-30T05:00:00.000',
#  'categoryEffectiveDate': '2019-08-31T05:00:00.000',
#  'excludesEffectiveDate': '2026-04-28T05:00:00.000',
#  'portfolioDate': '2026-04-30T05:00:00.000',
#  'categoryName': 'Large Blend',
#  'categoryAsOfDate': '2022-12-31T06:00:00.000',
#  'businessPractices': [{'label': 'animalTesting',
#    'fundPercent': '13.64899',
#    'categoryPercent': '17.06000',
#    'employsExclusions': '0'},
#   {'label': 'furAndSpecialityLeather',
#    'fundPercent': '0.00000',
#    'categoryPercent': '0.00000',
#    'employsExclusions': '0'}],
#  'defenceAndMilitary': [{'label': 'controversialWeapons',
#    'fundPercent': '1.46130',
#    'categoryPercent': '2.75000',
#    'employsExclusions': '0'},
#   {'label': 'militaryContracting',
#    'fundPercent': '3.76028',
#    'categoryPercent': '3.33000',
#    'employsExclusions': '0'},
#   {'label': 'smallArms',
#    'fundPercent': '0.89181',
#    'categoryPercent': '0.50000',
#    'employsExclusions': '0'}],
#  'energy': [{'label': 'nuclear',
#    'fundPercent': '1.63290',
#    'categoryPercent': '2.16000',
#    'employsExclusions': '0'},
#   {'label': 'thermalCoal',
#    'fundPercent': '1.12102',
#    'categoryPercent': '3.42000',
#    'employsExclusions': '0'}],
#  'environment': [{'label': 'gmo',
#    'fundPercent': '0.08055',
#    'categoryPercent': '0.03000',
#    'employsExclusions': '0'},
#   {'label': 'palmOil',
#    'fundPercent': '0.00027',
#    'categoryPercent': '0.00000',
#    'employsExclusions': '0'},
#   {'label': 'pesticides',
#    'fundPercent': '0.10923',
#    'categoryPercent': '0.30000',
#    'employsExclusions': '0'}],
#  'healthAndLife': [{'label': 'alcohol',
#    'fundPercent': '0.05800',
#    'categoryPercent': '0.45000',
#    'employsExclusions': '0'},
#   {'label': 'tobacco',
#    'fundPercent': '0.60058',
#    'categoryPercent': '0.80000',
#    'employsExclusions': '0'},
#   {'label': 'lifeEthics',
#    'fundPercent': '6.00498',
#    'categoryPercent': '7.09000',
#    'employsExclusions': '0'}],
#  'valueBased': [{'label': 'adultEntertainment',
#    'fundPercent': '0.00000',
#    'categoryPercent': '0.00000',
#    'employsExclusions': '0'},
#   {'label': 'gambling',
#    'fundPercent': '0.18701',
#    'categoryPercent': '0.22000',
#    'employsExclusions': '0'}]}

# %% [markdown]
# How fund managers voted on Management resolutions
#
# Sustainability - Proxy Voting - Management
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.proxyVotingManagement()
# Out:
# {'template': 'US',
#  'managementList': [{'proxyYear': '2026',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': None,
#    'twoYrAdvisoryVoteFreq': None,
#    'threeYrAdvisoryVoteFreq': None,
#    'voteCountAdvisoryVoteFreq': None,
#    'allManagementResolution': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'advisoryVoteOnExecutiveComp': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'auditorRactification': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'directElection': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'compensation': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None}},
#   {'proxyYear': '2025',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '376',
#    'allManagementResolution': {'voteCount': '29208',
#     'supportPer': '97.73350',
#     'againstPer': '2.26650',
#     'abstainedPer': '0.00342'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2798',
#     'supportPer': '98.10579',
#     'againstPer': '1.89421',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3326',
#     'supportPer': '99.87974',
#     'againstPer': '0.12026',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '20928',
#     'supportPer': '97.95967',
#     'againstPer': '2.04033',
#     'abstainedPer': '0.00478'},
#    'compensation': {'voteCount': '814',
#     'supportPer': '88.82064',
#     'againstPer': '11.17936',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2024',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '522',
#    'allManagementResolution': {'voteCount': '30337',
#     'supportPer': '95.95544',
#     'againstPer': '4.04457',
#     'abstainedPer': '0.00000'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2866',
#     'supportPer': '98.15073',
#     'againstPer': '1.84927',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3453',
#     'supportPer': '99.85520',
#     'againstPer': '0.14480',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '21767',
#     'supportPer': '95.42886',
#     'againstPer': '4.57114',
#     'abstainedPer': '0.00000'},
#    'compensation': {'voteCount': '793',
#     'supportPer': '88.39848',
#     'againstPer': '11.60151',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2023',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '1566',
#    'allManagementResolution': {'voteCount': '31435',
#     'supportPer': '94.63655',
#     'againstPer': '5.36027',
#     'abstainedPer': '0.00954'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2952',
#     'supportPer': '95.22358',
#     'againstPer': '4.77642',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3664',
#     'supportPer': '99.91812',
#     'againstPer': '0.08188',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '22534',
#     'supportPer': '94.20875',
#     'againstPer': '5.77794',
#     'abstainedPer': '0.01331'},
#    'compensation': {'voteCount': '826',
#     'supportPer': '83.89831',
#     'againstPer': '16.10169',
#     'abstainedPer': '0.00000'}},
#   {'proxyYear': '2022',
#    'fundId': 'FSUSA002PT',
#    'oneYrAdvisoryVoteFreq': '100.00000',
#    'twoYrAdvisoryVoteFreq': '0.00000',
#    'threeYrAdvisoryVoteFreq': '0.00000',
#    'voteCountAdvisoryVoteFreq': '371',
#    'allManagementResolution': {'voteCount': '31092',
#     'supportPer': '94.95690',
#     'againstPer': '5.04953',
#     'abstainedPer': '0.00643'},
#    'advisoryVoteOnExecutiveComp': {'voteCount': '2822',
#     'supportPer': '93.90503',
#     'againstPer': '6.09497',
#     'abstainedPer': '0.00000'},
#    'auditorRactification': {'voteCount': '3754',
#     'supportPer': '99.86681',
#     'againstPer': '0.13319',
#     'abstainedPer': '0.00000'},
#    'directElection': {'voteCount': '22753',
#     'supportPer': '94.85782',
#     'againstPer': '5.13778',
#     'abstainedPer': '0.00879'},
#    'compensation': {'voteCount': '731',
#     'supportPer': '83.31053',
#     'againstPer': '16.82627',
#     'abstainedPer': '0.00000'}}]}

# %% [markdown]
# How fund managers voted on Shareholder resolutions
#
# Sustainability - Proxy Voting - Shareholder
#
# https://www.morningstar.com/funds/xnas/vtsax/sustainability

# %%
funds.proxyVotingShareHolder()
# Out:
# {'template': 'US',
#  'shareholderList': [{'year': '2026',
#    'boardGovernance': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'climateChange': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'directorElections': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'environment': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'esgGovernanceArrangements': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'executiveCompensation': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'humanAndWorkersRights': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'humaneTreatmentOfAnimals': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'militarismAndAggression': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'otherCorporateGovernance': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'otherEnvironmentalAndSocial': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'politicalInfluence': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'publicHealthOrProductSafety': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'shareholderRights': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None},
#    'strategyOrBusiness': {'voteCount': None,
#     'supportPer': None,
#     'againstPer': None,
#     'abstainedPer': None}},
#   {'year': '2025',
#    'boardGovernance': {'voteCount': '35',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '52',
#     'supportPer': '0.00000',
#     'againstPer': '98.07692',
#     'abstainedPer': '1.92308'},
#    'directorElections': {'voteCount': '37',
#     'supportPer': '40.54054',
#     'againstPer': '59.45946',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '26',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '3',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '50',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'humanAndWorkersRights': {'voteCount': '80',
#     'supportPer': '0.00000',
#     'againstPer': '98.75000',
#     'abstainedPer': '1.25000'},
#    'humaneTreatmentOfAnimals': {'voteCount': '8',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '6',
#     'supportPer': '16.66667',
#     'againstPer': '83.33334',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '32',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '21',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '14',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '80',
#     'supportPer': '13.75000',
#     'againstPer': '86.25000',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '42',
#     'supportPer': '52.38095',
#     'againstPer': '47.61905',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '8',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2024',
#    'boardGovernance': {'voteCount': '55',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '72',
#     'supportPer': '0.00000',
#     'againstPer': '98.61111',
#     'abstainedPer': '1.38889'},
#    'directorElections': {'voteCount': '25',
#     'supportPer': '40.00000',
#     'againstPer': '60.00000',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '26',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '14',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '55',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'humanAndWorkersRights': {'voteCount': '136',
#     'supportPer': '0.00000',
#     'againstPer': '98.52941',
#     'abstainedPer': '1.47059'},
#    'humaneTreatmentOfAnimals': {'voteCount': '19',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '7',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '7',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '36',
#     'supportPer': '0.00000',
#     'againstPer': '97.22222',
#     'abstainedPer': '2.77778'},
#    'politicalInfluence': {'voteCount': '66',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '22',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '35',
#     'supportPer': '22.85714',
#     'againstPer': '77.14286',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '60',
#     'supportPer': '55.00000',
#     'againstPer': '45.00000',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2023',
#    'boardGovernance': {'voteCount': '94',
#     'supportPer': '3.19149',
#     'againstPer': '96.80851',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '80',
#     'supportPer': '5.00000',
#     'againstPer': '90.00000',
#     'abstainedPer': '5.00000'},
#    'directorElections': {'voteCount': '25',
#     'supportPer': '16.00000',
#     'againstPer': '84.00000',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '14',
#     'supportPer': '7.14286',
#     'againstPer': '92.85714',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '8',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '55',
#     'supportPer': '9.09091',
#     'againstPer': '89.09091',
#     'abstainedPer': '1.81818'},
#    'humanAndWorkersRights': {'voteCount': '85',
#     'supportPer': '1.17647',
#     'againstPer': '97.64706',
#     'abstainedPer': '1.17647'},
#    'humaneTreatmentOfAnimals': {'voteCount': '13',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '9',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '3',
#     'supportPer': '33.33333',
#     'againstPer': '66.66666',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '16',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '52',
#     'supportPer': '1.92308',
#     'againstPer': '98.07692',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '25',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '49',
#     'supportPer': '6.12245',
#     'againstPer': '93.87755',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '23',
#     'supportPer': '34.78261',
#     'againstPer': '65.21739',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}},
#   {'year': '2022',
#    'boardGovernance': {'voteCount': '56',
#     'supportPer': '7.14286',
#     'againstPer': '92.85714',
#     'abstainedPer': '0.00000'},
#    'climateChange': {'voteCount': '52',
#     'supportPer': '25.00000',
#     'againstPer': '75.00000',
#     'abstainedPer': '0.00000'},
#    'directorElections': {'voteCount': '20',
#     'supportPer': '45.00000',
#     'againstPer': '55.00000',
#     'abstainedPer': '0.00000'},
#    'environment': {'voteCount': '14',
#     'supportPer': '7.14286',
#     'againstPer': '92.85714',
#     'abstainedPer': '0.00000'},
#    'esgGovernanceArrangements': {'voteCount': '5',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'executiveCompensation': {'voteCount': '29',
#     'supportPer': '13.79310',
#     'againstPer': '79.31035',
#     'abstainedPer': '6.89655'},
#    'humanAndWorkersRights': {'voteCount': '87',
#     'supportPer': '13.79310',
#     'againstPer': '86.20689',
#     'abstainedPer': '0.00000'},
#    'humaneTreatmentOfAnimals': {'voteCount': '9',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'militarismAndAggression': {'voteCount': '3',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherCorporateGovernance': {'voteCount': '3',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'otherEnvironmentalAndSocial': {'voteCount': '12',
#     'supportPer': '8.33333',
#     'againstPer': '91.66666',
#     'abstainedPer': '0.00000'},
#    'politicalInfluence': {'voteCount': '52',
#     'supportPer': '13.46154',
#     'againstPer': '86.53846',
#     'abstainedPer': '0.00000'},
#    'publicHealthOrProductSafety': {'voteCount': '22',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'},
#    'shareholderMeetingsAndProxyProcess': {'voteCount': '121',
#     'supportPer': '6.61157',
#     'againstPer': '93.38843',
#     'abstainedPer': '0.00000'},
#    'shareholderRights': {'voteCount': '24',
#     'supportPer': '75.00000',
#     'againstPer': '25.00000',
#     'abstainedPer': '0.00000'},
#    'strategyOrBusiness': {'voteCount': '7',
#     'supportPer': '0.00000',
#     'againstPer': '100.00000',
#     'abstainedPer': '0.00000'}}]}

# %% [markdown]
# Information on the fund
#
# https://www.morningstar.com/funds/xnas/vtsax/quote

# %%
funds.quote()
# Out:
# {'taxClassDesignation': None,
#  'nCENAverageNetAssets': None,
#  'totalLeverage': None,
#  'totalLeverageRatio': None,
#  'prospectusBenchmarkName': 'CRSP US Total Market TR USD',
#  'primaryIndexNameNew': 'S&P 500 (TR) (1970)',
#  'index': 'Morningstar US LM Cap Mkt TR USD',
#  'tNAInShareClassCurrency': 2308925120464.0,
#  'sECYield': 1.0,
#  'trailing1DayReturn': -1.17634,
#  'trailing1DayReturnAsOfDate': '2026-06-17T05:00:00.000',
#  'yield12Month': 1.00309,
#  'trailing7DayYield': None,
#  'expenseRatio': 0.04,
#  'morningstarFeeLevel': '1',
#  'morningstarFeeLevelBroad': '1',
#  'inceptionDate': '2000-11-13T06:00:00.000',
#  'minimumInitialInvestment': 3000.0,
#  'lastTurnoverRatio': 3.0,
#  'equityStyleBox': 2,
#  'expense': 0.04,
#  'load': 'None',
#  'iFICRiskClassification': None,
#  'managementExpenseRatio': None,
#  'fundShareClassTypeName': 'Inst',
#  'fundShareClassTypeId': 'Inst',
#  'fixedIncomeStyleBox': None,
#  'isMonthlyRatio': False,
#  'expenseRatioDate': None,
#  'annualReportNetExpenseRatioDate': None,
#  'monthlyNetExpenseRatioDate': None,
#  'annualReportNetExpenseRatio': None,
#  'monthlyNetExpenseRatio': None,
#  'repurchase_offer_frequency': None,
#  'repurchase_offer_intended_frequency': None,
#  'countryAvailableForSale': None,
#  'prospectusAdjustedExpenseRatio': None,
#  'capitalCommitment': None,
#  'totalAsset': None,
#  'secId': 'FOUSA00L83',
#  'ticker': 'VTSAX',
#  'fundSubType': None,
#  'userType': 'Free',
#  'investmentName': 'Vanguard Total Stock Market Index Fund Admiral Shares',
#  'isin': 'US9229087286',
#  'morningstarRating': '3',
#  'morningstarRatingAsOfDate': '2026-05-31T05:00:00.000',
#  'analystRating': None,
#  'hasExtendedPerformance': False,
#  'domicileCountryId': 'USA',
#  'baseCurrencyId': 'USD',
#  'caFundCode': None,
#  'dayEndReturnDate': '2026-06-17T05:00:00.000',
#  'returnEndDate': '2026-06-17T05:00:00.000',
#  'template': 'OE_USA_EQUITY',
#  'templateWithAssetType': None,
#  'categoryName': 'US Fund Large Blend',
#  'nav': 178.1,
#  'status': 'Open',
#  'APIRCode': None,
#  'securityType': 'FO',
#  'alternativeFundCodes': None,
#  'selectedFundCode': None,
#  'hasAnalystRating': False,
#  'hasQuantRating': False,
#  'analystRatingDate': None,
#  'surveyedFundSize': None,
#  'altStyle': None,
#  'adjustedExpenseRatio': 0.0004,
#  'productInvolvementEffectiveDate': '2026-04-30T05:00:00.000',
#  'topProductInvolvementCategories': {'Animal_Testing': 13.64899,
#   'Catholic_Values': 6.00498,
#   'Military_Contracting': 3.76028,
#   'Nuclear': 1.6329,
#   'Controversial_Weapons': 1.4613,
#   'Thermal_Coal': 1.12102},
#  'sustainabilityFundQuintile': 2,
#  'sustainabilityAsOfDate': '2026-04-30T00:00:00.000',
#  'isLowCarbon': None,
#  'isDesignatedLowCarbon': 'false',
#  'medalistRatingLabel': '_PO_',
#  'medalistRating': '_PO_',
#  'medalistRatingDate': '_PO_',
#  'medalistRatingScale': '_PO_',
#  'hasMedalistRating': True,
#  'analystScale': None,
#  'parentScale': None,
#  'peopleScale': None,
#  'processScale': None,
#  'analystDrivenProportion': '100',
#  'dataCoverage': '100',
#  'parentScore': '_PO_',
#  'peopleScore': '_PO_',
#  'priceScore': '_PO_',
#  'processScore': '_PO_',
#  'parentScoreLabel': '_PO_',
#  'peopleScoreLabel': '_PO_',
#  'processScoreLabel': '_PO_',
#  'parentScoreType': '_PO_',
#  'peopleScoreType': '_PO_',
#  'processScoreType': '_PO_',
#  'assetType': 'EQUITY',
#  'disclosureCodes': ['Tracks Morningstar Index'],
#  'disclosureDescriptions': None}

# %% [markdown]
# Breakdown by region
#
# Exposure - Region
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.regionalSector()
# Out:
# {'fundPortfolio': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'masterPortfolioId': '3506',
#   'northAmerica': 99.45,
#   'unitedKingdom': 0.1016,
#   'europeDeveloped': 0.234,
#   'europeEmerging': 0.0,
#   'africaMiddleEast': 0.0,
#   'japan': 0.0,
#   'australasia': 0.0,
#   'asiaDeveloped': 0.009,
#   'asiaEmerging': 0.094,
#   'latinAmerica': 0.111},
#  'categoryPortfolio': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'masterPortfolioId': '204178',
#   'northAmerica': 98.037,
#   'unitedKingdom': 0.39424,
#   'europeDeveloped': 0.786,
#   'europeEmerging': 0.001,
#   'africaMiddleEast': 0.02,
#   'japan': 0.044,
#   'australasia': 0.004,
#   'asiaDeveloped': 0.451,
#   'asiaEmerging': 0.148,
#   'latinAmerica': 0.115},
#  'indexPortfolio': {'portfolioDate': '2026-05-31T05:00:00.000',
#   'masterPortfolioId': '471834',
#   'northAmerica': 99.375,
#   'unitedKingdom': 0.06737,
#   'europeDeveloped': 0.262,
#   'europeEmerging': 0.0,
#   'africaMiddleEast': 0.0,
#   'japan': 0.0,
#   'australasia': 0.0,
#   'asiaDeveloped': 0.0,
#   'asiaEmerging': 0.095,
#   'latinAmerica': 0.201},
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'assetType': 'EQUITY'}

# %% [markdown]
# Breakdown by country
#
# Exposure - Country
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.regionalSectorIncludeCountries()
# Out:
# {'fundPortfolio': {'countries': [{'name': 'unitedStates', 'percent': 99.39193},
#    {'name': 'switzerland', 'percent': 0.20448},
#    {'name': 'unitedKingdom', 'percent': 0.1016},
#    {'name': 'china', 'percent': 0.08655},
#    {'name': 'mexico', 'percent': 0.07663},
#    {'name': 'canada', 'percent': 0.05794},
#    {'name': 'ireland', 'percent': 0.02971},
#    {'name': 'brazil', 'percent': 0.01098},
#    {'name': 'india', 'percent': 0.00773},
#    {'name': 'taiwan', 'percent': 0.00408},
#    {'name': 'singapore', 'percent': 0.00325},
#    {'name': 'hongKong', 'percent': 0.00148},
#    {'name': 'argentina', 'percent': 0.0},
#    {'name': 'australia', 'percent': 0.0},
#    {'name': 'austria', 'percent': 0.0},
#    {'name': 'belgium', 'percent': 0.0},
#    {'name': 'chile', 'percent': 0.0},
#    {'name': 'colombia', 'percent': 0.0},
#    {'name': 'czechRepublic', 'percent': 0.0},
#    {'name': 'denmark', 'percent': 0.0},
#    {'name': 'estonia', 'percent': 0.0},
#    {'name': 'finland', 'percent': 0.0},
#    {'name': 'france', 'percent': 0.0},
#    {'name': 'germany', 'percent': 0.0},
#    {'name': 'greece', 'percent': 0.0},
#    {'name': 'hungary', 'percent': 0.0},
#    {'name': 'indonesia', 'percent': 0.0},
#    {'name': 'israel', 'percent': 0.0},
#    {'name': 'italy', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0},
#    {'name': 'latvia', 'percent': 0.0},
#    {'name': 'lithuania', 'percent': 0.0},
#    {'name': 'malaysia', 'percent': 0.0},
#    {'name': 'netherlands', 'percent': 0.0},
#    {'name': 'newZealand', 'percent': 0.0},
#    {'name': 'norway', 'percent': 0.0},
#    {'name': 'pakistan', 'percent': 0.0},
#    {'name': 'peru', 'percent': 0.0},
#    {'name': 'philippines', 'percent': 0.0},
#    {'name': 'poland', 'percent': 0.0},
#    {'name': 'portugal', 'percent': 0.0},
#    {'name': 'russia', 'percent': 0.0},
#    {'name': 'slovakia', 'percent': 0.0},
#    {'name': 'southAfrica', 'percent': 0.0},
#    {'name': 'southKorea', 'percent': 0.0},
#    {'name': 'spain', 'percent': 0.0},
#    {'name': 'sweden', 'percent': 0.0},
#    {'name': 'thailand', 'percent': 0.0},
#    {'name': 'turkey', 'percent': 0.0},
#    {'name': 'venezuela', 'percent': 0.0},
#    {'name': 'vietnam', 'percent': 0.0}],
#   'regions': [{'name': 'northAmerica', 'percent': 99.45},
#    {'name': 'europeDeveloped', 'percent': 0.234},
#    {'name': 'latinAmerica', 'percent': 0.111},
#    {'name': 'unitedKingdom', 'percent': 0.1016},
#    {'name': 'asiaEmerging', 'percent': 0.094},
#    {'name': 'other Countries', 'percent': 0.02364},
#    {'name': 'asiaDeveloped', 'percent': 0.009},
#    {'name': 'australasia', 'percent': 0.0},
#    {'name': 'europeEmerging', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0}],
#   'portfolioDate': '2026-05-31T05:00:00.000'},
#  'categoryPortfolio': {'countries': [{'name': 'unitedStates',
#     'percent': 97.69891},
#    {'name': 'switzerland', 'percent': 0.42905},
#    {'name': 'taiwan', 'percent': 0.41725},
#    {'name': 'unitedKingdom', 'percent': 0.39424},
#    {'name': 'canada', 'percent': 0.33954},
#    {'name': 'netherlands', 'percent': 0.19586},
#    {'name': 'china', 'percent': 0.12577},
#    {'name': 'germany', 'percent': 0.07943},
#    {'name': 'mexico', 'percent': 0.05081},
#    {'name': 'brazil', 'percent': 0.04647},
#    {'name': 'japan', 'percent': 0.044},
#    {'name': 'southKorea', 'percent': 0.02886},
#    {'name': 'ireland', 'percent': 0.02841},
#    {'name': 'belgium', 'percent': 0.0199},
#    {'name': 'india', 'percent': 0.01955},
#    {'name': 'france', 'percent': 0.01932},
#    {'name': 'israel', 'percent': 0.01527},
#    {'name': 'sweden', 'percent': 0.00461},
#    {'name': 'australia', 'percent': 0.00351},
#    {'name': 'singapore', 'percent': 0.00291},
#    {'name': 'denmark', 'percent': 0.00252},
#    {'name': 'spain', 'percent': 0.00237},
#    {'name': 'hongKong', 'percent': 0.00192},
#    {'name': 'southAfrica', 'percent': 0.00154},
#    {'name': 'italy', 'percent': 0.00152},
#    {'name': 'finland', 'percent': 0.0011},
#    {'name': 'malaysia', 'percent': 0.00089},
#    {'name': 'thailand', 'percent': 0.00078},
#    {'name': 'norway', 'percent': 0.00061},
#    {'name': 'indonesia', 'percent': 0.00047},
#    {'name': 'turkey', 'percent': 0.00037},
#    {'name': 'poland', 'percent': 0.00036},
#    {'name': 'chile', 'percent': 0.00025},
#    {'name': 'greece', 'percent': 0.00025},
#    {'name': 'peru', 'percent': 0.00024},
#    {'name': 'hungary', 'percent': 0.00017},
#    {'name': 'philippines', 'percent': 0.00015},
#    {'name': 'portugal', 'percent': 0.00015},
#    {'name': 'austria', 'percent': 0.00011},
#    {'name': 'newZealand', 'percent': 0.00011},
#    {'name': 'colombia', 'percent': 9e-05},
#    {'name': 'czechRepublic', 'percent': 7e-05},
#    {'name': 'argentina', 'percent': 0.0},
#    {'name': 'estonia', 'percent': 0.0},
#    {'name': 'latvia', 'percent': 0.0},
#    {'name': 'lithuania', 'percent': 0.0},
#    {'name': 'pakistan', 'percent': 0.0},
#    {'name': 'russia', 'percent': 0.0},
#    {'name': 'slovakia', 'percent': 0.0},
#    {'name': 'venezuela', 'percent': 0.0},
#    {'name': 'vietnam', 'percent': 0.0}],
#   'regions': [{'name': 'northAmerica', 'percent': 98.037},
#    {'name': 'europeDeveloped', 'percent': 0.786},
#    {'name': 'asiaDeveloped', 'percent': 0.451},
#    {'name': 'unitedKingdom', 'percent': 0.39424},
#    {'name': 'asiaEmerging', 'percent': 0.148},
#    {'name': 'latinAmerica', 'percent': 0.115},
#    {'name': 'japan', 'percent': 0.044},
#    {'name': 'other Countries', 'percent': 0.02036},
#    {'name': 'australasia', 'percent': 0.004},
#    {'name': 'europeEmerging', 'percent': 0.001}],
#   'portfolioDate': '2026-05-31T05:00:00.000'},
#  'indexPortfolio': {'countries': [{'name': 'unitedStates',
#     'percent': 99.37473},
#    {'name': 'switzerland', 'percent': 0.22987},
#    {'name': 'brazil', 'percent': 0.12065},
#    {'name': 'china', 'percent': 0.09466},
#    {'name': 'mexico', 'percent': 0.08057},
#    {'name': 'unitedKingdom', 'percent': 0.06737},
#    {'name': 'ireland', 'percent': 0.03215},
#    {'name': 'argentina', 'percent': 0.0},
#    {'name': 'australia', 'percent': 0.0},
#    {'name': 'austria', 'percent': 0.0},
#    {'name': 'belgium', 'percent': 0.0},
#    {'name': 'canada', 'percent': 0.0},
#    {'name': 'chile', 'percent': 0.0},
#    {'name': 'colombia', 'percent': 0.0},
#    {'name': 'czechRepublic', 'percent': 0.0},
#    {'name': 'denmark', 'percent': 0.0},
#    {'name': 'estonia', 'percent': 0.0},
#    {'name': 'finland', 'percent': 0.0},
#    {'name': 'france', 'percent': 0.0},
#    {'name': 'germany', 'percent': 0.0},
#    {'name': 'greece', 'percent': 0.0},
#    {'name': 'hongKong', 'percent': 0.0},
#    {'name': 'hungary', 'percent': 0.0},
#    {'name': 'india', 'percent': 0.0},
#    {'name': 'indonesia', 'percent': 0.0},
#    {'name': 'israel', 'percent': 0.0},
#    {'name': 'italy', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0},
#    {'name': 'latvia', 'percent': 0.0},
#    {'name': 'lithuania', 'percent': 0.0},
#    {'name': 'malaysia', 'percent': 0.0},
#    {'name': 'netherlands', 'percent': 0.0},
#    {'name': 'newZealand', 'percent': 0.0},
#    {'name': 'norway', 'percent': 0.0},
#    {'name': 'pakistan', 'percent': 0.0},
#    {'name': 'peru', 'percent': 0.0},
#    {'name': 'philippines', 'percent': 0.0},
#    {'name': 'poland', 'percent': 0.0},
#    {'name': 'portugal', 'percent': 0.0},
#    {'name': 'russia', 'percent': 0.0},
#    {'name': 'singapore', 'percent': 0.0},
#    {'name': 'slovakia', 'percent': 0.0},
#    {'name': 'southAfrica', 'percent': 0.0},
#    {'name': 'southKorea', 'percent': 0.0},
#    {'name': 'spain', 'percent': 0.0},
#    {'name': 'sweden', 'percent': 0.0},
#    {'name': 'taiwan', 'percent': 0.0},
#    {'name': 'thailand', 'percent': 0.0},
#    {'name': 'turkey', 'percent': 0.0},
#    {'name': 'venezuela', 'percent': 0.0},
#    {'name': 'vietnam', 'percent': 0.0}],
#   'regions': [{'name': 'northAmerica', 'percent': 99.375},
#    {'name': 'europeDeveloped', 'percent': 0.262},
#    {'name': 'latinAmerica', 'percent': 0.201},
#    {'name': 'asiaEmerging', 'percent': 0.095},
#    {'name': 'unitedKingdom', 'percent': 0.06737},
#    {'name': 'asiaDeveloped', 'percent': 0.0},
#    {'name': 'australasia', 'percent': 0.0},
#    {'name': 'europeEmerging', 'percent': 0.0},
#    {'name': 'japan', 'percent': 0.0},
#    {'name': 'other Countries', 'percent': 0.0}],
#   'portfolioDate': '2026-05-31T05:00:00.000'},
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'assetType': 'EQUITY'}

# %% [markdown]
# Return vs Standard deviation
#
#
# Risk/Return Analysis
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.riskReturnScatterplot()
# Out:
# {'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'cur': 'USD',
#  'isUKCefTemplateAvailable': False,
#  'extendedPerformanceData': {'ePUsedFor1YearFlag': False,
#   'ePUsedFor3YearFlag': False,
#   'ePUsedFor5YearFlag': False,
#   'ePUsedFor10YearFlag': False,
#   'ePUsedFor15YearFlag': False},
#  'fundScatterplot': {'standardDeviationEndDate': '2026-05-31T05:00:00.000',
#   'trailingReturnEndDate': '2026-05-31T05:00:00.000',
#   'trailingReturnPriceEndDate': '2026-05-31T05:00:00.000',
#   'for1Year': {'trailingReturn': 29.82443,
#    'trailingReturnPrice': None,
#    'standardDeviation': 12.911},
#   'for3Year': {'trailingReturn': 23.23401,
#    'trailingReturnPrice': None,
#    'standardDeviation': 13.726},
#   'for5Year': {'trailingReturn': 12.87073,
#    'trailingReturnPrice': None,
#    'standardDeviation': 16.118},
#   'for10Year': {'trailingReturn': 15.09551,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.823},
#   'for15Year': {'trailingReturn': 13.75838,
#    'trailingReturnPrice': None,
#    'standardDeviation': 14.804},
#   'forLongestTenure': None},
#  'categoryScatterplot': {'standardDeviationEndDate': '2026-05-31T05:00:00.000',
#   'trailingReturnEndDate': '2026-05-31T05:00:00.000',
#   'trailingReturnPriceEndDate': None,
#   'for1Year': {'trailingReturn': 25.77933,
#    'trailingReturnPrice': None,
#    'standardDeviation': 12.956},
#   'for3Year': {'trailingReturn': 21.04103,
#    'trailingReturnPrice': None,
#    'standardDeviation': 13.531},
#   'for5Year': {'trailingReturn': 11.92587,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.826},
#   'for10Year': {'trailingReturn': 14.03673,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.537},
#   'for15Year': {'trailingReturn': 12.82316,
#    'trailingReturnPrice': None,
#    'standardDeviation': 14.683},
#   'forLongestTenure': None},
#  'indexScatterplot': {'standardDeviationEndDate': '2026-05-31T05:00:00.000',
#   'trailingReturnEndDate': '2026-05-31T05:00:00.000',
#   'trailingReturnPriceEndDate': None,
#   'for1Year': {'trailingReturn': 29.59839,
#    'trailingReturnPrice': None,
#    'standardDeviation': 13.302},
#   'for3Year': {'trailingReturn': 23.80482,
#    'trailingReturnPrice': None,
#    'standardDeviation': 13.548},
#   'for5Year': {'trailingReturn': 13.641,
#    'trailingReturnPrice': None,
#    'standardDeviation': 16.065},
#   'for10Year': {'trailingReturn': 15.52652,
#    'trailingReturnPrice': None,
#    'standardDeviation': 15.611},
#   'for15Year': {'trailingReturn': 14.1627,
#    'trailingReturnPrice': None,
#    'standardDeviation': 14.579},
#   'forLongestTenure': None}}

# %% [markdown]
# Return and risk compare to the category
#
# Morningstar Risk & Return
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.riskReturnSummary()
# Out:
# {'endDate': '2026-05-31T05:00:00.000',
#  'categoryName': 'Large Blend',
#  'for3Year': {'epUsedFlag': False,
#   'riskVsCategory': 4,
#   'returnVsCategory': 3,
#   'numberOfFunds': 1201},
#  'for5Year': {'epUsedFlag': False,
#   'riskVsCategory': 4,
#   'returnVsCategory': 3,
#   'numberOfFunds': 1117},
#  'for10Year': {'epUsedFlag': False,
#   'riskVsCategory': 4,
#   'returnVsCategory': 3,
#   'numberOfFunds': 886}}

# %% [markdown]
# Overal risk of the fund
#
# Portfolio Risk Score
#
# https://www.morningstar.com/funds/xnas/vtsax/risk

# %%
funds.riskScore()
# Out:
# {'riskScore': '71',
#  'riskLevel': 'Aggressive',
#  'asOfDate': '2026-04-30T05:00:00.000',
#  'portfolioDate': '2026-05-31T05:00:00.000',
#  'privateAllocationPercent': 0.0,
#  'pricingFrequencyName': 'Daily',
#  'riskScoreRangeList': [{'riskScoreRegion': 'US',
#    'rangeName': 'Conservative',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '1',
#    'maximumScore': 28,
#    'minimumScore': 0,
#    'rangeDisplay': '0-28'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Moderate',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '2',
#    'maximumScore': 54,
#    'minimumScore': 29,
#    'rangeDisplay': '29-54'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Aggressive',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '3',
#    'maximumScore': 78,
#    'minimumScore': 55,
#    'rangeDisplay': '55-78'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Very Aggressive',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '4',
#    'maximumScore': 99,
#    'minimumScore': 79,
#    'rangeDisplay': '79-99'},
#   {'riskScoreRegion': 'US',
#    'rangeName': 'Extreme',
#    'effectiveDate': '1900-01-01',
#    'riskLevel': '5',
#    'maximumScore': 500,
#    'minimumScore': 100,
#    'rangeDisplay': '100+'}]}

# %% [markdown]
# Alpha, beta, RSquared, Standard deviation end Sharpe ratio over time

# %%
funds.riskVolatility()
# Out:
# {'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'calculationBenchmark': 'S&P 500 (TR) (1970)',
#  'extendedPerformanceData': {'ePUsedFor1YearFlag': False,
#   'ePUsedFor3YearFlag': False,
#   'ePUsedFor5YearFlag': False,
#   'ePUsedFor10YearFlag': False,
#   'ePUsedFor15YearFlag': False},
#  'fundRiskVolatility': {'primaryIndexNameNew': 'S&P 500 (TR) (1970)',
#   'bestFitIndexName': 'Morningstar US Market TR USD',
#   'bestFitAlphaFor3Year': -0.208,
#   'bestFitBetaFor3Year': 1.005,
#   'bestFitRSquaredFor3Year': 99.946,
#   'endDate': '2026-05-31T05:00:00.000',
#   'for1Year': {'alpha': 0.4,
#    'beta': 0.983,
#    'rSquared': 99.872,
#    'standardDeviation': 12.911,
#    'sharpeRatio': 1.798},
#   'for3Year': {'alpha': -0.795,
#    'beta': 1.031,
#    'rSquared': 99.34,
#    'standardDeviation': 13.726,
#    'sharpeRatio': 1.259},
#   'for5Year': {'alpha': -1.247,
#    'beta': 1.014,
#    'rSquared': 99.324,
#    'standardDeviation': 16.118,
#    'sharpeRatio': 0.61},
#   'for10Year': {'alpha': -0.77,
#    'beta': 1.027,
#    'rSquared': 99.287,
#    'standardDeviation': 15.823,
#    'sharpeRatio': 0.821},
#   'for15Year': {'alpha': -0.779,
#    'beta': 1.028,
#    'rSquared': 99.256,
#    'standardDeviation': 14.804,
#    'sharpeRatio': 0.84},
#   'forLongestTenure': None},
#  'categoryRiskVolatility': {'endDate': '2026-05-31T05:00:00.000',
#   'for1Year': {'alpha': -1.496,
#    'beta': 0.916,
#    'rSquared': 86.948,
#    'standardDeviation': 12.956,
#    'sharpeRatio': 1.507},
#   'for3Year': {'alpha': -1.597,
#    'beta': 0.968,
#    'rSquared': 90.693,
#    'standardDeviation': 13.531,
#    'sharpeRatio': 1.135},
#   'for5Year': {'alpha': -1.581,
#    'beta': 0.961,
#    'rSquared': 92.541,
#    'standardDeviation': 15.826,
#    'sharpeRatio': 0.562},
#   'for10Year': {'alpha': -1.149,
#    'beta': 0.982,
#    'rSquared': 94.164,
#    'standardDeviation': 15.537,
#    'sharpeRatio': 0.773},
#   'for15Year': {'alpha': -1.235,
#    'beta': 0.997,
#    'rSquared': 95.043,
#    'standardDeviation': 14.683,
#    'sharpeRatio': 0.79},
#   'forLongestTenure': None},
#  'indexRiskVolatility': {'endDate': '2026-05-31T05:00:00.000',
#   'for1Year': {'alpha': -0.435,
#    'beta': 1.013,
#    'rSquared': 99.954,
#    'standardDeviation': 13.302,
#    'sharpeRatio': 1.735},
#   'for3Year': {'alpha': -0.163,
#    'beta': 1.021,
#    'rSquared': 99.876,
#    'standardDeviation': 13.548,
#    'sharpeRatio': 1.309},
#   'for5Year': {'alpha': -0.559,
#    'beta': 1.013,
#    'rSquared': 99.801,
#    'standardDeviation': 16.065,
#    'sharpeRatio': 0.655},
#   'for10Year': {'alpha': -0.275,
#    'beta': 1.016,
#    'rSquared': 99.806,
#    'standardDeviation': 15.611,
#    'sharpeRatio': 0.854},
#   'for15Year': {'alpha': -0.286,
#    'beta': 1.015,
#    'rSquared': 99.789,
#    'standardDeviation': 14.579,
#    'sharpeRatio': 0.875},
#   'forLongestTenure': None},
#  'cur': 'USD'}

# %% [markdown]
# Maximum Sales Fees
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.salesFees()
# Out:
# {'salesFees': {'frontloadFee': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   'frontloadFeeLowBreakpoint': [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   'deferredloadFee': [None, None, None, None, None, None, None],
#   'redemptionFeeLowBreakpoint': [None, None, None, None, None, None],
#   'redemptionFee': [None, None, None, None, None, None],
#   'deferredloadFeeLowBreakpoint': [None, None, None, None, None, None, None]},
#  'minInitialInvestment': 3000,
#  'currencyId': 'USD',
#  'minInvestmentCurrency': 'USD',
#  'frontloadFeeBreakpointUnit': None,
#  'frontloadFeeUnit': None,
#  'redemptionFeeBreakpointUnit': None,
#  'redemptionFeeUnit': None,
#  'deferredloadFeeBreakpointUnit': None,
#  'deferredloadFeeUnit': None,
#  'minimumInitialInvestmentUnit': 'Monetary'}

# %% [markdown]
# Breakdown by sector
#
# Exposure - Sector
#
# https://www.morningstar.com/funds/xnas/vtsax/portfolio

# %%
funds.sector()
# Out:
# {'FIXEDINCOME': {'fundPortfolio': {'portfolioDate': '2026-05-31T05:00:00.000',
#    'government': 0.0,
#    'municipal': 0.0,
#    'corporate': 0.0,
#    'securitized': 0.0,
#    'cashAndEquivalents': 100.0,
#    'derivative': 0.0},
#   'categoryPortfolio': {'portfolioDate': '2026-05-31T05:00:00.000',
#    'government': 17.28528,
#    'municipal': 0.01529,
#    'corporate': 6.50372,
#    'securitized': 8.6952,
#    'cashAndEquivalents': 67.49956,
#    'derivative': 0.00096},
#   'indexPortfolio': {'portfolioDate': None,
#    'government': None,
#    'municipal': None,
#    'corporate': None,
#    'securitized': None,
#    'cashAndEquivalents': None,
#    'derivative': None},
#   'categoryName': 'Large Blend',
#   'indexName': 'Morningstar US LM Cap Mkt TR USD',
#   'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#   'assetType': 'FIXEDINCOME'},
#  'EQUITY': {'fundPortfolio': {'portfolioDate': '2026-05-31T05:00:00.000',
#    'basicMaterials': 1.9203,
#    'consumerCyclical': 9.74413,
#    'financialServices': 11.2619,
#    'realEstate': 2.28866,
#    'communicationServices': 9.81148,
#    'energy': 3.30417,
#    'industrials': 9.36376,
#    'technology': 36.95212,
#    'consumerDefensive': 4.26933,
#    'healthcare': 8.97336,
#    'utilities': 2.11078},
#   'categoryPortfolio': {'portfolioDate': '2026-05-31T05:00:00.000',
#    'basicMaterials': 2.12109,
#    'consumerCyclical': 9.77281,
#    'financialServices': 12.5261,
#    'realEstate': 1.57557,
#    'communicationServices': 10.12513,
#    'energy': 3.65765,
#    'industrials': 10.41894,
#    'technology': 32.74365,
#    'consumerDefensive': 4.80733,
#    'healthcare': 9.73407,
#    'utilities': 2.51766},
#   'indexPortfolio': {'portfolioDate': '2026-05-31T05:00:00.000',
#    'basicMaterials': 1.67602,
#    'consumerCyclical': 9.82386,
#    'financialServices': 10.93651,
#    'realEstate': 1.66709,
#    'communicationServices': 10.7366,
#    'energy': 3.14288,
#    'industrials': 8.18245,
#    'technology': 39.08527,
#    'consumerDefensive': 4.38903,
#    'healthcare': 8.29233,
#    'utilities': 2.06795},
#   'categoryName': 'Large Blend',
#   'indexName': 'Morningstar US LM Cap Mkt TR USD',
#   'fundName': 'Vanguard Total Stock Mkt Idx Adm',
#   'assetType': 'EQUITY'},
#  'assetType': 'EQUITY'}

# %% [markdown]
# Snapshot of the fund and asset manager

# %%
funds.snapshot()
# Out:
# {}

# %% [markdown]
# Funds of the asset manager with lower rating
#
# Lowest Rated Investments
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.starRatingFundAsc()
# Out:
# {'StarRatingFund': [{'calendarYearFlow': -140442297.0,
#    'netAsset': 1633457093.0,
#    'fundShareClassId': 'F000011J08',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Long-Term Bond Index Admiral',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 1.88866,
#    'trailing3YearReturnRank': '100',
#    'secId': 'F000011J08',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 125007218.0,
#    'netAsset': 1097661535.0,
#    'fundShareClassId': 'F00001CKVW',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Advice Select Dividend Gr Admrl',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 10.62909,
#    'trailing3YearReturnRank': '98',
#    'secId': 'F00001CKVW',
#    'securityType': 'FO'},
#   {'calendarYearFlow': -87132282.0,
#    'netAsset': 617171104.0,
#    'fundShareClassId': 'FOUSA06KY1',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Extended Duration Trs Idx Instl',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': -5.48465,
#    'trailing3YearReturnRank': '95',
#    'secId': 'FOUSA06KY1',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 32894115.0,
#    'netAsset': 280129006.0,
#    'fundShareClassId': 'F00000ZAFI',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Baillie GiffordGlbPstvImpStkInv',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 10.76601,
#    'trailing3YearReturnRank': '87',
#    'secId': 'F00000ZAFI',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 23176451.0,
#    'netAsset': 95206077.0,
#    'fundShareClassId': 'F00001EBZW',
#    'mstarRating': '1',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Global Environmental Opp StkAdm',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 10.0404,
#    'trailing3YearReturnRank': '90',
#    'secId': 'F00001EBZW',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2026-05-31T05:00:00.000',
#  'footerReturnDate': '2026-05-31T05:00:00.000',
#  'currency': 'USD',
#  'secId': None,
#  'securityType': None,
#  'userType': 'Free'}

# %% [markdown]
# Funds of the asset manager with higher rating
#
# Highest Rated Investments
#
# https://www.morningstar.com/funds/xnas/vtsax/parent

# %%
funds.starRatingFundDesc()
# Out:
# {'StarRatingFund': [{'calendarYearFlow': -14715126125.0,
#    'netAsset': 86298356520.0,
#    'fundShareClassId': 'FOUSA02TYD',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard PRIMECAP Adm',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 29.03303,
#    'trailing3YearReturnRank': '2',
#    'secId': 'FOUSA02TYD',
#    'securityType': 'FO'},
#   {'calendarYearFlow': -1526890436.0,
#    'netAsset': 29705376932.0,
#    'fundShareClassId': 'FOUSA02TY3',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Capital Opportunity Adm',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 27.65646,
#    'trailing3YearReturnRank': '3',
#    'secId': 'FOUSA02TY3',
#    'securityType': 'FO'},
#   {'calendarYearFlow': -1487482809.0,
#    'netAsset': 17174861054.0,
#    'fundShareClassId': 'FOUSA05B7U',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard PRIMECAP Core Inv',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 29.96998,
#    'trailing3YearReturnRank': '2',
#    'secId': 'FOUSA05B7U',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 718931920.0,
#    'netAsset': 15590457102.0,
#    'fundShareClassId': 'FOUSA02TY9',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard High-Yield Tax-Exempt Adm',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 5.02548,
#    'trailing3YearReturnRank': '8',
#    'secId': 'FOUSA02TY9',
#    'securityType': 'FO'},
#   {'calendarYearFlow': 146258868.0,
#    'netAsset': 12262360220.0,
#    'fundShareClassId': 'FOUSA00BB5',
#    'mstarRating': '5',
#    'overallMorningstarRating': None,
#    'name': 'Vanguard Tax-Managed Balanced Adm',
#    'returnEndDate': '2026-05-31T05:00:00.000',
#    'ePUsedFor3YearReturn': 0.0,
#    'trailing3YearReturn': 13.164,
#    'trailing3YearReturnRank': '9',
#    'secId': 'FOUSA00BB5',
#    'securityType': 'FO'}],
#  'footerFundFlowDate': '2026-05-31T05:00:00.000',
#  'footerReturnDate': '2026-05-31T05:00:00.000',
#  'currency': 'USD',
#  'secId': None,
#  'securityType': None,
#  'userType': 'Free'}

# %% [markdown]
# General information and return on funds

# %%
funds.strategyPreview()
# Out:
# {'shareClassList': [{'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 16.02807,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 22.27886, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 9.81194, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 14.42265, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Market ETF',
#     'secId': '0P0000M4Z0',
#     'securityType': 'FE',
#     'fundShareClassId': 'FEUSA0002P',
#     'APIRCode': None,
#     'ticker': 'VTI',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229087690',
#     'baseCurrencyId': 'MXN',
#     'overallMorningstarRating': None,
#     'epUsedForOverallRating': None,
#     'ratingEndDate': None,
#     'analystRating': None,
#     'medalistRating': None,
#     'analystRatingEndDate': None,
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': None,
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': None,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': None,
#     'expenseRatio': 0.03,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': None,
#     'lastShareClassNetAsset': None,
#     'minimumInitialInvestment': None,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': None,
#     'secYield': 1.01,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': None,
#     'qualifiedInvestment': None,
#     'returnEndDate': None,
#     'trailing1YearReturn': 16.02807,
#     'trailing3YearReturn': 22.27886,
#     'trailing5YearReturn': 9.81194,
#     'trailing10YearReturn': 14.42265,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2001-05-24 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': None,
#     'FundShareClassTypeId': None,
#     'MorningstarFeeLevel': None,
#     'MorningstarFeeLevelGroup': None,
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': None,
#     'maximumManagementFee': '0.030000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 29.84529,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 23.25195, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.8864, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.10493, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Market ETF',
#     'secId': 'FEUSA0002P',
#     'securityType': 'FE',
#     'fundShareClassId': 'FEUSA0002P',
#     'APIRCode': None,
#     'ticker': 'VTI',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229087690',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-05-31 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-04-27 08:14:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.03,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.03,
#     'expenseRatio': 0.03,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 655778417890.0,
#     'minimumInitialInvestment': None,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.01211,
#     'secYield': 1.01,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': None,
#     'qualifiedInvestment': None,
#     'returnEndDate': None,
#     'trailing1YearReturn': 29.84529,
#     'trailing3YearReturn': 23.25195,
#     'trailing5YearReturn': 12.8864,
#     'trailing10YearReturn': 15.10493,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2001-05-24 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': None,
#     'FundShareClassTypeId': '44',
#     'MorningstarFeeLevel': None,
#     'MorningstarFeeLevelGroup': None,
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '47272609368.600',
#     'maximumManagementFee': '0.030000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 29.84051,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 23.24889, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.88373, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.10594, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Market Idx I',
#     'secId': 'FOUSA00GQ7',
#     'securityType': 'FO',
#     'fundShareClassId': 'FOUSA00GQ7',
#     'APIRCode': None,
#     'ticker': 'VITSX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229088011',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-05-31 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-04-27 08:14:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.03,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.03,
#     'expenseRatio': 0.03,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 110689482167.0,
#     'minimumInitialInvestment': 5000000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.01169,
#     'secYield': 1.01,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '1',
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 29.84051,
#     'trailing3YearReturn': 23.24889,
#     'trailing5YearReturn': 12.88373,
#     'trailing10YearReturn': 15.10594,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '1997-07-07 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inst',
#     'FundShareClassTypeId': '6',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap Institutional',
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '-9078323815.030',
#     'maximumManagementFee': '0.030000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 29.82443,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 23.23401, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.87073, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.09551, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Adm',
#     'secId': 'FOUSA00L83',
#     'securityType': 'FO',
#     'fundShareClassId': 'FOUSA00L83',
#     'APIRCode': None,
#     'ticker': 'VTSAX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229087286',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-05-31 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-04-27 08:14:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.04,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.04,
#     'expenseRatio': 0.04,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 488951580677.0,
#     'minimumInitialInvestment': 3000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.00309,
#     'secYield': 1.0,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '0',
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 29.82443,
#     'trailing3YearReturn': 23.23401,
#     'trailing5YearReturn': 12.87073,
#     'trailing10YearReturn': 15.09551,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2000-11-13 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inst',
#     'FundShareClassTypeId': '6',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap Institutional',
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '-26679525712.842',
#     'maximumManagementFee': '0.040000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 29.85667,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 23.26132, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.89431, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.11774, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Instl Pls',
#     'secId': 'F00000VE7X',
#     'securityType': 'FO',
#     'fundShareClassId': 'F00000VE7X',
#     'APIRCode': None,
#     'ticker': 'VSMPX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229083558',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-05-31 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-04-27 08:14:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.02,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.02,
#     'expenseRatio': 0.02,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 967688547381.0,
#     'minimumInitialInvestment': 100000000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.0204,
#     'secYield': 1.06,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '1',
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 29.85667,
#     'trailing3YearReturn': 23.26132,
#     'trailing5YearReturn': 12.89431,
#     'trailing10YearReturn': 15.11774,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '2015-04-28 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inst',
#     'FundShareClassTypeId': '6',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap Institutional',
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '-3675204664.139',
#     'maximumManagementFee': '0.020000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 29.8709,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 23.27291, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.90626, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 15.12754, 'epUsed': '1'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Instl Sel',
#     'secId': 'F00000WTNR',
#     'securityType': 'FO',
#     'fundShareClassId': 'F00000WTNR',
#     'APIRCode': None,
#     'ticker': 'VSTSX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229083301',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-05-31 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-04-27 08:14:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.01,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.01,
#     'expenseRatio': 0.01,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 54761301397.0,
#     'minimumInitialInvestment': 5000000000.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 1.02857,
#     'secYield': 1.07,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '0',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '1',
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 29.8709,
#     'trailing3YearReturn': 23.27291,
#     'trailing5YearReturn': 12.90626,
#     'trailing10YearReturn': 15.12754,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '1',
#     'inceptionDate': '2016-06-27 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inst',
#     'FundShareClassTypeId': '6',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap Institutional',
#     'Status': 'Open',
#     'FundSizeCashFlowForYear': '-46838491657.732',
#     'maximumManagementFee': '0.010000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}},
#   {'fundSimplePerformance': [{'year': 1,
#      'returnData': [],
#      'trailingReturn': 29.73769,
#      'epUsed': '0'},
#     {'year': 3, 'returnData': [], 'trailingReturn': 23.12256, 'epUsed': '0'},
#     {'year': 5, 'returnData': [], 'trailingReturn': 12.76243, 'epUsed': '0'},
#     {'year': 10, 'returnData': [], 'trailingReturn': 14.98178, 'epUsed': '0'}],
#    'dataInCard': {'name': 'Vanguard Total Stock Mkt Idx Inv',
#     'secId': 'FOUSA00FQU',
#     'securityType': 'FO',
#     'fundShareClassId': 'FOUSA00FQU',
#     'APIRCode': None,
#     'ticker': 'VTSMX',
#     'domicileCountryId': 'USA',
#     'isin': 'US9229083061',
#     'baseCurrencyId': 'USD',
#     'overallMorningstarRating': '3',
#     'epUsedForOverallRating': None,
#     'ratingEndDate': '2026-05-31 00:00:00.0',
#     'analystRating': '7',
#     'medalistRating': 'GOLD',
#     'analystRatingEndDate': '2026-04-27 08:14:00.0',
#     'annualReportManagementExpenseRatio': None,
#     'semiAnnualReportManagementExpenseRatio': None,
#     'semiAnnualReportDate': '2025-06-30 00:00:00.0',
#     'indiaMonthlyReportNetExpenseRatio': None,
#     'annualReportNetExpenseRatio': 0.14,
#     'indiaMonthlyReportDate': None,
#     'adjustExpenseRatio': 0.06,
#     'expenseRatio': 0.06,
#     'maximumFrontLoad': None,
#     'maximumDeferredLoad': None,
#     'annualReportDate': '2025-12-31 00:00:00.0',
#     'lastShareClassNetAsset': 26180630509.0,
#     'minimumInitialInvestment': 0.0,
#     'indirectCostRatio': None,
#     'ongoingCharge': None,
#     'performanceFee': None,
#     'shareClassWithoutRetrocession': None,
#     'yield12Month': 0.93374,
#     'secYield': 0.98,
#     'closedToAllInvestors': '0',
#     'closedToNewInvestors': '1',
#     'availableFor529Only': '0',
#     'indirectUseOnly': None,
#     'institutionalOnly': '0',
#     'qualifiedInvestment': '1',
#     'returnEndDate': None,
#     'trailing1YearReturn': 29.73769,
#     'trailing3YearReturn': 23.12256,
#     'trailing5YearReturn': 12.76243,
#     'trailing10YearReturn': 14.98178,
#     'epUsedFor1YearReturn': '0',
#     'epUsedFor3YearReturn': '0',
#     'epUsedFor5YearReturn': '0',
#     'epUsedFor10YearReturn': '0',
#     'inceptionDate': '1992-04-27 00:00:00.0',
#     'actual12b1': None,
#     'FundShareClassTypeName': 'Inv',
#     'FundShareClassTypeId': '7',
#     'MorningstarFeeLevel': '1',
#     'MorningstarFeeLevelGroup': 'Large Cap No Load',
#     'Status': 'Closed',
#     'FundSizeCashFlowForYear': '-2359592453.941',
#     'maximumManagementFee': '0.050000000',
#     'MorningstarTotalCostRatioPDS': None,
#     'PerformanceFeeCostsPDS': None,
#     'TotalCostsIncRecoveredCosts': None}}],
#  'template': 'USA_OE',
#  'fundSubType': None}

# %% [markdown]
# Sustainability data

# %%
funds.sustainability()
# Out:
# {}

# %% [markdown]
# Return of the fund after taxes
#
# Taxes
#
# https://www.morningstar.com/funds/xnas/vtsax/price

# %%
funds.taxes()
# Out:
# {'categoryEndDate': '2026-05-31T05:00:00.000',
#  'returnEndDate': '2026-05-31T05:00:00.000',
#  'trailing1YearTaxCostRatio': None,
#  'trailing3YearTaxCostRatio': 0.33,
#  'trailing5YearTaxCostRatio': None,
#  'trailing10YearTaxCostRatio': None,
#  'trailing15YearTaxCostRatio': None,
#  'sinceInceptionTaxCostRatio': None,
#  'potentialCapitalGain': 0.596394,
#  'trailing1YearTaxCostRatioCategory': None,
#  'trailing3YearTaxCostRatioCategory': 1.2552,
#  'trailing5YearTaxCostRatioCategory': None,
#  'trailing10YearTaxCostRatioCategory': None,
#  'trailing15YearTaxCostRatioCategory': None,
#  'sinceInceptionTaxCostRatioCategory': None,
#  'priceTemplate': 'USA_OE'}

# %% [markdown]
# Traling Returns
#
# https://www.morningstar.com/funds/xnas/vtsax/performance

# %%
funds.trailingReturn()
# Out:
# {'columnDefs': ['1Day',
#   '1Week',
#   '1Month',
#   '3Month',
#   'YearToDate',
#   '1Year',
#   '3Year',
#   '5Year',
#   '10Year',
#   '15Year',
#   'SinceInception'],
#  'hasDailyData': True,
#  'investorRankApplicable': False,
#  'adjustedTaxReturnApplicable': False,
#  'duration': 'daily',
#  'totalReturnNAV': ['-1.17634',
#   '2.20947',
#   '0.87794',
#   '11.05284',
#   '9.47415',
#   '25.90912',
#   '20.21413',
#   '12.32289',
#   '15.01135',
#   '14.07631',
#   '9.06307'],
#  'netReturn': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'netOfFeesReturn': [],
#  'totalReturnNavEPFlag': [],
#  'totalReturnPrice': [],
#  'totalReturnCategory': [0.014720000000000066,
#   0.09888999999999992,
#   -0.20064999999999988,
#   1.3000100000000003,
#   1.2580200000000001,
#   3.27374,
#   1.8068600000000004,
#   0.7157599999999995,
#   0.9780800000000003,
#   0.91906,
#   None],
#  'totalReturnCategoryNew': [-1.19106,
#   2.11058,
#   1.07859,
#   9.75283,
#   8.21613,
#   22.63538,
#   18.40727,
#   11.60713,
#   14.03327,
#   13.15725,
#   None],
#  'totalReturnCategoryPrice': [],
#  'totalReturnCategoryEPFlag': [],
#  'fundNumber': [1377,
#   1377,
#   1372,
#   1361,
#   1343,
#   1285,
#   1191,
#   1112,
#   882,
#   674,
#   None],
#  'fundNumberPrice': [],
#  'totalReturnIndex': [0.009850000000000136,
#   -0.029850000000000154,
#   0.3010400000000001,
#   -0.09218000000000082,
#   0.27998999999999974,
#   0.46324000000000254,
#   -0.5269200000000005,
#   -0.7046200000000002,
#   -0.4153000000000002,
#   -0.3703700000000012,
#   None],
#  'totalReturnIndexNew': [-1.18619,
#   2.23932,
#   0.5769,
#   11.14502,
#   9.19416,
#   25.44588,
#   20.74105,
#   13.02751,
#   15.42665,
#   14.44668,
#   None],
#  'returnRank': [43, 40, 42, 32, 31, 27, 37, 48, 35, 31, None],
#  'returnMarketPriceRank': [],
#  'extendedPerformanceFlag': [False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  'investorReturn': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'investorReturnRank': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'taxAdjustedReturn': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'taxAdjustedReturnRank': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'taxCostRatio': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'categoryName': 'Large Blend',
#  'indexName': 'Morningstar US LM Cap Mkt TR USD',
#  'name': 'Vanguard Total Stock Mkt Idx Adm',
#  'overallMorningstarRating': 3,
#  'morningstarRatingFor3Year': 3,
#  'morningstarRatingFor5Year': 3,
#  'morningstarRatingFor10Year': 3,
#  'ePUsedForOverallRating': False,
#  'ePUsedFor3YearRating': False,
#  'ePUsedFor5YearRating': False,
#  'ePUsedFor10YearRating': False,
#  'fundReturnDate': '2026-06-17T05:00:00.000',
#  'fundPriceReturnDate': None,
#  'ratingDate': '2026-05-31T05:00:00.000',
#  'categoryDate': '2026-06-17T05:00:00.000',
#  'indexDate': '2026-06-17T05:00:00.000',
#  'fundInvestorDate': None,
#  'indexId': 'F00000GWXD',
#  'isDailyData': False,
#  'isMonthlyData': False,
#  'isQuarterlyData': False,
#  'inceptionDate': '2000-11-13T06:00:00.000',
#  'potentialCapitalGainsExposure': None,
#  'startDate': '2000-11-13T06:00:00.000',
#  'cur': 'USD',
#  'isUKCefTemplateAvailable': False,
#  'restructureDate': None}
