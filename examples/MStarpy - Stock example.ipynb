# %% [markdown]
# # Stock Analysis
#
# In this example, we will explore all the key methods used to perform an in-depth analysis of a stock.

# %%
import mstarpy as ms

# %% [markdown]
# Initialize Stock to start you analysis

# %%
stock = ms.Stock("FR0000121014")

# %% [markdown]
# Find the stock name

# %%
stock.name
# Out:
# 'Lvmh Moet Hennessy Louis Vuitton SE'

# %% [markdown]
# Find the stock isin

# %%
stock.isin
# Out:
# 'FR0000121014'

# %% [markdown]
# MorningStar take on the stock
#
# https://www.morningstar.com/stocks/pinx/lvmhf/quote

# %%
stock.analysisData()
# Out:
# {'ticker': '1MC',
#  'isQuan': False,
#  'name': 'Lvmh Moet Hennessy Louis Vuitton SE',
#  'secId': '0P0000G5GV',
#  'userType': 'Free',
#  'valuation': {'fairValue': '_PO_',
#   'fairValueDate': '2024-12-02T00:00:00.000',
#   'assessment': '_PO_',
#   'assessmentDate': None,
#   'uncertainty': '_PO_',
#   'moat': '_PO_',
#   'moatDate': '2024-12-02T00:00:00.000',
#   'moatTrendEvaluate': '',
#   'premiumDisc': '_PO_',
#   'stewardship': '_PO_',
#   'stewardshipDate': None,
#   'premDiscDelta': '_PO_',
#   'oneStar': '_PO_',
#   'oneStarDate': '',
#   'fiveStar': '_PO_',
#   'fiveStarDate': '',
#   'fairValCurrency': None,
#   'bf2': '_PO_',
#   'bf3': '_PO_',
#   'bf4': '_PO_',
#   'bf5': '_PO_',
#   'lastClose': '_PO_',
#   'startRating': '_PO_',
#   'lastCloseCurrency': 'EUR',
#   'lastCloseDate': '2025-07-14T05:00:00.000'},
#  'companyProfile': 'LVMH is a global producer and distributor of luxury goods. It operates six segments: fashion and leather goods, its largest and oldest; watches and jewelry; wines and spirits; perfumes and cosmetics; selective retailing (including Sephora and airport duty-free retailer DFS); and other. Higher-profile brands include Louis Vuitton, Bulgari, Fendi, Givenchy, Tag Heuer, Hennessy, Moet & Chandon, Glenmorangie, Sephora, and Benefit. LVMH operates more than 5,000 stores around the globe.',
#  'esgRisk': None}

# %% [markdown]
# MorningStar analyts notes
#
# https://www.morningstar.com/stocks/pinx/lvmhf/quote

# %%
stock.analysisReport()
# Out:
# {'userType': 'Free',
#  'total': 0,
#  'rpsCovered': False,
#  'isLocalized': False,
#  'translationautomated': False,
#  'analysisReport': {'headLine': '',
#   'investmentThesisTitle': None,
#   'investmentThesisText': None,
#   'investmentThesis': '',
#   'investmentThesisDateUTC': '',
#   'economicMoatTitle': None,
#   'economicMoatText': None,
#   'economicMoat': None,
#   'economicMoatDateUTC': '',
#   'valuationTitle': None,
#   'valuationText': None,
#   'valuation': None,
#   'valuationDateUTC': '',
#   'riskTitle': None,
#   'riskText': None,
#   'risk': None,
#   'riskDateUTC': '',
#   'managementTitle': None,
#   'managementText': None,
#   'management': None,
#   'managementDateUTC': '',
#   'bullsSay': None,
#   'bearsSay': None,
#   'bull1UpdateDate': None,
#   'bull2UpdateDate': None,
#   'bull3UpdateDate': None,
#   'bear1UpdateDate': None,
#   'bear2UpdateDate': None,
#   'bear3UpdateDate': None,
#   'publishDate': None,
#   'notes': None,
#   'economicMoatRating': '_PO_',
#   'economicMoatRatingDate': None,
#   'moatTrendEvaluate': '',
#   'valuationRating': '_PO_',
#   'valuationRatingDate': '',
#   'managementRating': '_PO_',
#   'managementRatingDate': None,
#   'riskRating': '_PO_',
#   'riskRatingDate': None,
#   'isQuan': True,
#   'smartText': {'economicMoatHeader': 'The company earns a quantitative moat rating of wide, suggesting a strong ability to maintain superior profitability thanks to competitive advantages that could persist up to two decades.',
#    'economicMoatContent': "In addition, the company's moderate financial health score is decent and doesn't seriously concern us with regard to financial distress.",
#    'economicMoatText': "The company earns a quantitative moat rating of wide, suggesting a strong ability to maintain superior profitability thanks to competitive advantages that could persist up to two decades. In addition, the company's moderate financial health score is decent and doesn't seriously concern us with regard to financial distress.",
#    'valuationHeader': 'On the surface, Lvmh Moet Hennessy Louis Vuitton SE appears cheap due to significant downward price pressure over the past year.',
#    'valuationContent': "To incorporate the risk associated with a potential value trap, we have capped its rating at 3 stars. The stock currently trades at a 21% discount to our quantitative fair value estimate of 604.21 EUR per share; however, some caution is warranted due to this estimate's medium uncertainty rating.\n\nThe firm's profitability bolsters our estimated valuation. Highly profitable companies are often more resilient in recessions and are likely to generate stronger future cash flows for shareholders. Reflecting the firm's profitability is its gross margin of 67.0%, which falls in the top 10% globally. This suggests that it will more easily generate cash flow than peers. We believe this is a sign that shares could be undervalued.\n\nAlternatively, the company's valuation metrics are potentially concerning. A company's valuation metrics provide insights into the market's expectations for its future growth and profitability. The firm's book value yield of 27.7%, for example, ranks in the bottom 30% globally. The market value of this company's shares looks expensive relative to the book (accounting) value of equity, which, despite our favorable price/fair value ratio, is a negative attribute.",
#    'valuationText': "On the surface, Lvmh Moet Hennessy Louis Vuitton SE appears cheap due to significant downward price pressure over the past year. To incorporate the risk associated with a potential value trap, we have capped its rating at 3 stars. The stock currently trades at a 21% discount to our quantitative fair value estimate of 604.21 EUR per share; however, some caution is warranted due to this estimate's medium uncertainty rating.\n\nThe firm's profitability bolsters our estimated valuation. Highly profitable companies are often more resilient in recessions and are likely to generate stronger future cash flows for shareholders. Reflecting the firm's profitability is its gross margin of 67.0%, which falls in the top 10% globally. This suggests that it will more easily generate cash flow than peers. We believe this is a sign that shares could be undervalued.\n\nAlternatively, the company's valuation metrics are potentially concerning. A company's valuation metrics provide insights into the market's expectations for its future growth and profitability. The firm's book value yield of 27.7%, for example, ranks in the bottom 30% globally. The market value of this company's shares looks expensive relative to the book (accounting) value of equity, which, despite our favorable price/fair value ratio, is a negative attribute.",
#    'economicMoatDateUTC': '2025-07-14T23:46:20',
#    'valuationDateUTC': '2025-07-14T23:45:48',
#    'publishedDate': '2025-07-14T23:46:20',
#    'ratingDate': '2025-07-14T23:35:30',
#    'economicMoatRating': 'Wide'},
#   'author': None},
#  'analystNote': {'note': None,
#   'title': None,
#   'date': None,
#   'retailContentHTML': None,
#   'lede': None,
#   'author': None,
#   'author2': None,
#   'institutionalNoteContent': None},
#  'lastUpdateBy': 0,
#  'isQuan': True}

# %% [markdown]
# Balance Sheet
#
# https://www.morningstar.com/stocks/pinx/lvmhf/financials

# %%
stock.balanceSheet()
# Out:
# {'_meta': {'companyId': '0C00000VOS',
#   'statementType': 'balance-sheet',
#   'periodReport': 'Success',
#   'latestReport': 'no data available'},
#  'columnDefs': ['2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2022',
#   '2023',
#   '2024'],
#  'filingIdList': [None,
#   None,
#   None,
#   None,
#   None,
#   '328683655',
#   '384266622',
#   '437916148',
#   '502488388',
#   '577784039'],
#  'rows': [{'parentId': '',
#    'label': 'BalanceSheet',
#    'dataPointId': 'IFBS000000',
#    'order': 0,
#    'subLevel': [{'parentId': 'IFBS0000000',
#      'label': 'Total Assets',
#      'dataPointId': 'IFBS002270',
#      'order': 1,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       108671.0,
#       125311.0,
#       134646.0,
#       143694.0,
#       149190.0],
#      'subLevel': [{'parentId': 'IFBS0022701',
#        'label': 'Total Current Assets',
#        'dataPointId': 'IFBS000470',
#        'order': 2,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         39973.0,
#         34301.0,
#         39740.0,
#         43710.0,
#         47471.0],
#        'subLevel': [{'parentId': 'IFBS0004702',
#          'label': 'Cash, Cash Equivalents and Short Term Investments',
#          'dataPointId': 'IFBS000350',
#          'order': 3,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           20715.0,
#           10565.0,
#           10852.0,
#           11264.0,
#           13587.0],
#          'subLevel': [{'parentId': 'IFBS0003503',
#            'label': 'Cash and Cash Equivalents',
#            'dataPointId': 'IFBS000320',
#            'order': 4,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             19963.0,
#             8021.0,
#             7300.0,
#             7774.0,
#             9631.0],
#            'subLevel': [{'parentId': 'IFBS0003204',
#              'label': 'Cash',
#              'dataPointId': 'IFBS000300',
#              'order': 5,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               4474.0,
#               5717.0,
#               6013.0,
#               6103.0,
#               6865.0]},
#             {'parentId': 'IFBS0003204',
#              'label': 'Cash Equivalents',
#              'dataPointId': 'IFBS000310',
#              'order': 6,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               15489.0,
#               2305.0,
#               1288.0,
#               1671.0,
#               2766.0]}]},
#           {'parentId': 'IFBS0003503',
#            'label': 'Short Term Investments',
#            'dataPointId': 'IFBS001690',
#            'order': 7,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             752.0,
#             2544.0,
#             3552.0,
#             3490.0,
#             3956.0],
#            'subLevel': [{'parentId': 'IFBS0016907',
#              'label': 'Trading/ Listed Investments, Current',
#              'dataPointId': 'IFBS002677',
#              'order': 8,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               752.0,
#               2544.0,
#               3552.0,
#               3490.0,
#               3956.0]}]}]},
#         {'parentId': 'IFBS0004702',
#          'label': 'Derivative Investment and Hedging Assets, Current',
#          'dataPointId': 'IFBS002631',
#          'order': 13,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           968.0,
#           258.0,
#           462.0,
#           543.0,
#           319.0]},
#         {'parentId': 'IFBS0004702',
#          'label': 'Inventories',
#          'dataPointId': 'IFBS001130',
#          'order': 14,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           13015.0,
#           16548.0,
#           20319.0,
#           22952.0,
#           23669.0],
#          'subLevel': [{'parentId': 'IFBS00113014',
#            'label': 'Raw Materials, Consumables and Supplies',
#            'dataPointId': 'IFBS001920',
#            'order': 15,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             1732.0,
#             2885.0,
#             4187.0,
#             4559.0,
#             4373.0]},
#           {'parentId': 'IFBS00113014',
#            'label': 'Work-in-Process',
#            'dataPointId': 'IFBS002470',
#            'order': 16,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             5313.0,
#             5433.0,
#             5932.0,
#             6582.0,
#             7035.0]},
#           {'parentId': 'IFBS00113014',
#            'label': 'Finished Goods and Merchandise',
#            'dataPointId': 'IFBS000890',
#            'order': 17,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             5970.0,
#             8230.0,
#             10200.0,
#             11811.0,
#             12261.0]}]},
#         {'parentId': 'IFBS0004702',
#          'label': 'Trade and Other Receivables, Current',
#          'dataPointId': 'IFBS200660',
#          'order': 22,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           4678.0,
#           6112.0,
#           7110.0,
#           7944.0,
#           8777.0],
#          'subLevel': [{'parentId': 'IFBS20066022',
#            'label': 'Trade/Accounts Receivable, Current',
#            'dataPointId': 'IFBS000020',
#            'order': 23,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             2756.0,
#             3787.0,
#             4258.0,
#             4728.0,
#             4731.0],
#            'subLevel': [{'parentId': 'IFBS00002023',
#              'label': 'Gross Trade/Accounts Receivable, Current',
#              'dataPointId': 'IFBS000030',
#              'order': 24,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               2880.0,
#               3914.0,
#               4369.0,
#               4843.0,
#               4856.0]},
#             {'parentId': 'IFBS00002023',
#              'label': 'Allowance/Adjustments for Trade/Accounts Receivable, Current',
#              'dataPointId': 'IFBS000160',
#              'order': 25,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -124.0,
#               -127.0,
#               -111.0,
#               -115.0,
#               -125.0]}]},
#           {'parentId': 'IFBS20066022',
#            'label': 'Taxes Receivable, Current',
#            'dataPointId': 'IFBS002250',
#            'order': 32,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             1348.0,
#             1548.0,
#             1977.0,
#             2366.0,
#             3015.0]},
#           {'parentId': 'IFBS20066022',
#            'label': 'Other Receivables, Current',
#            'dataPointId': 'IFBS001680',
#            'order': 36,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             574.0,
#             777.0,
#             875.0,
#             850.0,
#             1031.0]}]},
#         {'parentId': 'IFBS0004702',
#          'label': 'Prepayments and Deposits, Current',
#          'dataPointId': 'IFBS100688',
#          'order': 38,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           209.0,
#           315.0,
#           386.0,
#           1007.0,
#           1120.0]},
#         {'parentId': 'IFBS0004702',
#          'label': 'Deferred Costs/Assets, Current',
#          'dataPointId': 'IFBS200665',
#          'order': 40,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           387.0,
#           503.0,
#           613.0,
#           None,
#           None]}]},
#       {'parentId': 'IFBS0022701',
#        'label': 'Total Non-Current Assets',
#        'dataPointId': 'IFBS002330',
#        'order': 44,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         68698.0,
#         91010.0,
#         94906.0,
#         99984.0,
#         101719.0],
#        'subLevel': [{'parentId': 'IFBS00233044',
#          'label': 'Net Property, Plant and Equipment',
#          'dataPointId': 'IFBS001450',
#          'order': 45,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           30118.0,
#           33270.0,
#           36950.0,
#           42372.0,
#           45895.0],
#          'subLevel': [{'parentId': 'IFBS00145045',
#            'label': 'Gross Property, Plant and Equipment',
#            'dataPointId': 'IFBS001050',
#            'order': 46,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             47241.0,
#             55483.0,
#             62626.0,
#             70167.0,
#             77967.0],
#            'subLevel': [{'parentId': 'IFBS00105046',
#              'label': 'Properties',
#              'dataPointId': 'IFBS001880',
#              'order': 47,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               42843.0,
#               50702.0,
#               37605.0,
#               43157.0,
#               47542.0],
#              'subLevel': [{'parentId': 'IFBS00188047',
#                'label': 'Land and Improvements',
#                'dataPointId': 'IFBS001200',
#                'order': 48,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 7167.0,
#                 7563.0,
#                 16062.0,
#                 19375.0,
#                 20734.0]},
#               {'parentId': 'IFBS00188047',
#                'label': 'Buildings and Improvements',
#                'dataPointId': 'IFBS000280',
#                'order': 49,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 21245.0,
#                 25529.0,
#                 21543.0,
#                 23782.0,
#                 26808.0]},
#               {'parentId': 'IFBS00188047',
#                'label': 'Leasehold and Improvements',
#                'dataPointId': 'IFBS002670',
#                'order': 50,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 14431.0,
#                 17610.0,
#                 None,
#                 None,
#                 None]}]},
#             {'parentId': 'IFBS00105046',
#              'label': 'Construction in Progress and Advance Payments',
#              'dataPointId': 'IFBS000430',
#              'order': 62,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               1181.0,
#               1303.0,
#               1810.0,
#               2125.0,
#               2394.0]},
#             {'parentId': 'IFBS00105046',
#              'label': 'Leased Property, Plant and Equipment',
#              'dataPointId': 'IFBS002838',
#              'order': 63,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               922.0,
#               1046.0,
#               20670.0,
#               22166.0,
#               25038.0]},
#             {'parentId': 'IFBS00105046',
#              'label': 'Other Property, Plant and Equipment',
#              'dataPointId': 'IFBS001660',
#              'order': 64,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               2295.0,
#               2432.0,
#               2541.0,
#               2719.0,
#               2993.0]}]},
#           {'parentId': 'IFBS00145045',
#            'label': 'Accumulated Depreciation and Impairment',
#            'dataPointId': 'IFBS002567',
#            'order': 65,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -17123.0,
#             -22213.0,
#             -25676.0,
#             -27795.0,
#             -32072.0],
#            'subLevel': [{'parentId': 'IFBS00256765',
#              'label': 'Accumulated Depreciation',
#              'dataPointId': 'IFBS000090',
#              'order': 66,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -17123.0,
#               -22213.0,
#               -25676.0,
#               -27795.0,
#               -32072.0],
#              'subLevel': [{'parentId': 'IFBS00009066',
#                'label': 'Accumulated Depreciation of Properties',
#                'dataPointId': 'IFBS002579',
#                'order': 67,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 -16363.0,
#                 -21390.0,
#                 -11068.0,
#                 -12535.0,
#                 -15105.0],
#                'subLevel': [{'parentId': 'IFBS00257967',
#                  'label': 'Accumulated Depreciation of Land and Improvements',
#                  'dataPointId': 'IFBS002572',
#                  'order': 68,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   -136.0,
#                   -137.0,
#                   -132.0,
#                   -136.0,
#                   -141.0]},
#                 {'parentId': 'IFBS00257967',
#                  'label': 'Accumulated Depreciation of Buildings',
#                  'dataPointId': 'IFBS002570',
#                  'order': 69,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   -6255.0,
#                   -8757.0,
#                   -10936.0,
#                   -12399.0,
#                   -14964.0]},
#                 {'parentId': 'IFBS00257967',
#                  'label': 'Accumulated Depreciation of Leasehold and Improvements',
#                  'dataPointId': 'IFBS002573',
#                  'order': 70,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   -9972.0,
#                   -12496.0,
#                   None,
#                   None,
#                   None]}]},
#               {'parentId': 'IFBS00009066',
#                'label': 'Accumulated Depreciation of Leased Property, Plant and Equipment',
#                'dataPointId': 'IFBS002836',
#                'order': 82,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 -200.0,
#                 -275.0,
#                 -14043.0,
#                 -14617.0,
#                 -16267.0]},
#               {'parentId': 'IFBS00009066',
#                'label': 'Accumulated Depreciation of Construction in Progress',
#                'dataPointId': 'IFBS002840',
#                'order': 83,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 -5.0,
#                 -1.0,
#                 -1.0,
#                 -45.0,
#                 -74.0]},
#               {'parentId': 'IFBS00009066',
#                'label': 'Accumulated Depreciation of Other Property, Plant and Equipment',
#                'dataPointId': 'IFBS002577',
#                'order': 84,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 -555.0,
#                 -547.0,
#                 -564.0,
#                 -598.0,
#                 -626.0]}]}]}]},
#         {'parentId': 'IFBS00233044',
#          'label': 'Investment Properties and Properties Held for Development',
#          'dataPointId': 'IFBS100681',
#          'order': 89,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           316.0,
#           321.0,
#           435.0,
#           315.0,
#           319.0],
#          'subLevel': [{'parentId': 'IFBS10068189',
#            'label': 'Gross Investment Properties and Properties Held for Development',
#            'dataPointId': 'IFBS002656',
#            'order': 90,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             350.0,
#             358.0,
#             478.0,
#             366.0,
#             375.0]},
#           {'parentId': 'IFBS10068189',
#            'label': 'Accumulated Depreciation of Investment Properties and Properties Held for Development',
#            'dataPointId': 'IFBS002564',
#            'order': 91,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -34.0,
#             -37.0,
#             -43.0,
#             -51.0,
#             -56.0]}]},
#         {'parentId': 'IFBS00233044',
#          'label': 'Net Intangible Assets',
#          'dataPointId': 'IFBS001020',
#          'order': 92,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           33368.0,
#           50762.0,
#           50497.0,
#           49933.0,
#           46880.0],
#          'subLevel': [{'parentId': 'IFBS00102092',
#            'label': 'Gross Goodwill and Other Intangible Assets',
#            'dataPointId': 'IFBS002655',
#            'order': 93,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             40275.0,
#             58646.0,
#             59027.0,
#             58524.0,
#             56155.0],
#            'subLevel': [{'parentId': 'IFBS00265593',
#              'label': 'Goodwill',
#              'dataPointId': 'IFBS001010',
#              'order': 94,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               17856.0,
#               27869.0,
#               26785.0,
#               25712.0,
#               22047.0]},
#             {'parentId': 'IFBS00265593',
#              'label': 'Intangibles other than Goodwill',
#              'dataPointId': 'IFBS003302',
#              'order': 95,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               22419.0,
#               30777.0,
#               32242.0,
#               32812.0,
#               34108.0],
#              'subLevel': [{'parentId': 'IFBS00330295',
#                'label': 'Trademarks and Patents',
#                'dataPointId': 'IFBS002771',
#                'order': 96,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 18127.0,
#                 25534.0,
#                 26453.0,
#                 26269.0,
#                 26869.0]},
#               {'parentId': 'IFBS00330295',
#                'label': 'Software and Technology',
#                'dataPointId': 'IFBS002755',
#                'order': 97,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 2388.0,
#                 3143.0,
#                 3603.0,
#                 3946.0,
#                 4398.0]},
#               {'parentId': 'IFBS00330295',
#                'label': 'Licenses and Rights',
#                'dataPointId': 'IFBS002675',
#                'order': 98,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 922.0,
#                 985.0,
#                 848.0,
#                 915.0,
#                 931.0]},
#               {'parentId': 'IFBS00330295',
#                'label': 'Other Intangible Assets',
#                'dataPointId': 'IFBS001610',
#                'order': 102,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 982.0,
#                 1115.0,
#                 1338.0,
#                 1682.0,
#                 1910.0]}]}]},
#           {'parentId': 'IFBS00102092',
#            'label': 'Accumulated Amortization and Impairment',
#            'dataPointId': 'IFBS002549',
#            'order': 103,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -6907.0,
#             -7884.0,
#             -8530.0,
#             -8591.0,
#             -9275.0],
#            'subLevel': [{'parentId': 'IFBS002549103',
#              'label': 'Accumulated Amortization of Intangible Assets',
#              'dataPointId': 'IFBS002551',
#              'order': 104,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -5093.0,
#               -5919.0,
#               -6527.0,
#               -6901.0,
#               -7535.0],
#              'subLevel': [{'parentId': 'IFBS002551104',
#                'label': 'Accumulated Amortization of Intangibles other than Goodwill',
#                'dataPointId': 'IFBS003304',
#                'order': 106,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 -5093.0,
#                 -5919.0,
#                 -6527.0,
#                 -6901.0,
#                 -7535.0],
#                'subLevel': [{'parentId': 'IFBS003304106',
#                  'label': 'Accumulated Amortization of Trademarks and Patents',
#                  'dataPointId': 'IFBS002556',
#                  'order': 107,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   -2261.0,
#                   -2376.0,
#                   -2498.0,
#                   -2448.0,
#                   -2546.0]},
#                 {'parentId': 'IFBS003304106',
#                  'label': 'Accumulated Amortization of Software and Technology',
#                  'dataPointId': 'IFBS002555',
#                  'order': 108,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   -1722.0,
#                   -2294.0,
#                   -2677.0,
#                   -2912.0,
#                   -3168.0]},
#                 {'parentId': 'IFBS003304106',
#                  'label': 'Accumulated Amortization of Licences and Rights',
#                  'dataPointId': 'IFBS002548',
#                  'order': 109,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   -554.0,
#                   -624.0,
#                   -565.0,
#                   -592.0,
#                   -639.0]},
#                 {'parentId': 'IFBS003304106',
#                  'label': 'Accumulated Amortization of Other Intangible Assets',
#                  'dataPointId': 'IFBS002553',
#                  'order': 113,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   -556.0,
#                   -625.0,
#                   -787.0,
#                   -949.0,
#                   -1182.0]}]}]},
#             {'parentId': 'IFBS002549103',
#              'label': 'Accumulated Impairment of Intangible Assets',
#              'dataPointId': 'IFBS002583',
#              'order': 114,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -1814.0,
#               -1965.0,
#               -2003.0,
#               -1690.0,
#               -1740.0],
#              'subLevel': [{'parentId': 'IFBS002583114',
#                'label': 'Accumulated Impairment of Goodwill',
#                'dataPointId': 'IFBS002582',
#                'order': 115,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 -1814.0,
#                 -1965.0,
#                 -2003.0,
#                 -1690.0,
#                 -1740.0]}]}]}]},
#         {'parentId': 'IFBS00233044',
#          'label': 'Total Long Term Investments',
#          'dataPointId': 'IFBS002310',
#          'order': 121,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           1729.0,
#           2447.0,
#           2175.0,
#           2354.0,
#           2975.0],
#          'subLevel': [{'parentId': 'IFBS002310121',
#            'label': 'Long Term Equity Investments',
#            'dataPointId': 'IFBS001320',
#            'order': 122,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             990.0,
#             1084.0,
#             1066.0,
#             991.0,
#             1343.0]},
#           {'parentId': 'IFBS002310121',
#            'label': 'Investment in Financial Assets, Non-Current',
#            'dataPointId': 'IFBS100685',
#            'order': 127,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             739.0,
#             1363.0,
#             1109.0,
#             1363.0,
#             1632.0],
#            'subLevel': [{'parentId': 'IFBS100685127',
#              'label': 'Financial Investment Securities, Available-for-Sale & Held-to-Maturity, Non-Current',
#              'dataPointId': 'IFBS002642',
#              'order': 132,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               739.0,
#               1363.0,
#               1109.0,
#               1363.0,
#               1632.0],
#              'subLevel': [{'parentId': 'IFBS002642132',
#                'label': 'Available-for-Sale Securities, Non-Current',
#                'dataPointId': 'IFBS000220',
#                'order': 133,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 739.0,
#                 1363.0,
#                 1109.0,
#                 1363.0,
#                 1632.0]}]}]}]},
#         {'parentId': 'IFBS00233044',
#          'label': 'Derivative Investment and Hedging Assets, Non-Current',
#          'dataPointId': 'IFBS200663',
#          'order': 137,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           110.0,
#           55.0,
#           97.0,
#           99.0,
#           105.0]},
#         {'parentId': 'IFBS00233044',
#          'label': 'Trade and Other Receivables, Non-Current',
#          'dataPointId': 'IFBS200020',
#          'order': 138,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           280.0,
#           413.0,
#           444.0,
#           243.0,
#           271.0],
#          'subLevel': [{'parentId': 'IFBS200020138',
#            'label': 'Loans Receivable, Non-Current',
#            'dataPointId': 'IFBS002680',
#            'order': 140,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             280.0,
#             413.0,
#             444.0,
#             243.0,
#             271.0]}]},
#         {'parentId': 'IFBS00233044',
#          'label': 'Prepayments and Deposits, Non-Current',
#          'dataPointId': 'IFBS100733',
#          'order': 148,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           409.0,
#           482.0,
#           554.0,
#           577.0,
#           602.0],
#          'subLevel': [{'parentId': 'IFBS100733148',
#            'label': 'Deposits Paid for Business and Fixed Assets, Non-Current',
#            'dataPointId': 'IFBS002627',
#            'order': 150,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             409.0,
#             482.0,
#             554.0,
#             577.0,
#             602.0]}]},
#         {'parentId': 'IFBS00233044',
#          'label': 'Deferred Tax Assets, Non-Current',
#          'dataPointId': 'IFBS000700',
#          'order': 153,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           2325.0,
#           3156.0,
#           3661.0,
#           3992.0,
#           4545.0]},
#         {'parentId': 'IFBS00233044',
#          'label': 'Other Non-Current Assets',
#          'dataPointId': 'IFBS001650',
#          'order': 158,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           46.0,
#           103.0,
#           91.0,
#           98.0,
#           127.0]}]}]},
#     {'parentId': 'IFBS0000000',
#      'label': 'Total Liabilities',
#      'dataPointId': 'IFBS002646',
#      'order': 159,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       69842.0,
#       76402.0,
#       78042.0,
#       80993.0,
#       79903.0],
#      'subLevel': [{'parentId': 'IFBS002646159',
#        'label': 'Total Current Liabilities',
#        'dataPointId': 'IFBS000500',
#        'order': 160,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         25318.0,
#         27989.0,
#         31543.0,
#         33145.0,
#         33696.0],
#        'subLevel': [{'parentId': 'IFBS000500160',
#          'label': 'Payables and Accrued Expenses, Current',
#          'dataPointId': 'IFBS002716',
#          'order': 161,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           6642.0,
#           9454.0,
#           11260.0,
#           11590.0,
#           11396.0],
#          'subLevel': [{'parentId': 'IFBS002716161',
#            'label': 'Trade and Other Payables, Current',
#            'dataPointId': 'IFBS001710',
#            'order': 162,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             6642.0,
#             9454.0,
#             11260.0,
#             11590.0,
#             11396.0],
#            'subLevel': [{'parentId': 'IFBS001710162',
#              'label': 'Trade/Accounts Payable, Current',
#              'dataPointId': 'IFBS000010',
#              'order': 163,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               5098.0,
#               7086.0,
#               8788.0,
#               9049.0,
#               8630.0]},
#             {'parentId': 'IFBS001710162',
#              'label': 'Taxes Payable, Current',
#              'dataPointId': 'IFBS002240',
#              'order': 168,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               1544.0,
#               2368.0,
#               2472.0,
#               2541.0,
#               2766.0]}]},
#           {'parentId': 'IFBS002716161',
#            'label': 'Accrued Expenses, Current',
#            'dataPointId': 'IFBS002541',
#            'order': 172,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             None,
#             None,
#             None,
#             None,
#             None]}]},
#         {'parentId': 'IFBS000500160',
#          'label': 'Financial Liabilities, Current',
#          'dataPointId': 'IFBS100734',
#          'order': 173,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           13405.0,
#           12437.0,
#           13896.0,
#           13988.0,
#           14460.0],
#          'subLevel': [{'parentId': 'IFBS100734173',
#            'label': 'Current Debt and Capital Lease Obligation',
#            'dataPointId': 'IFBS002965',
#            'order': 174,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             12801.0,
#             12242.0,
#             13596.0,
#             13839.0,
#             14252.0],
#            'subLevel': [{'parentId': 'IFBS002965174',
#              'label': 'Current Debt',
#              'dataPointId': 'IFBS000480',
#              'order': 175,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               9198.0,
#               4627.0,
#               7651.0,
#               7657.0,
#               8014.0],
#              'subLevel': [{'parentId': 'IFBS000480175',
#                'label': 'Bank Overdraft, Current Debt',
#                'dataPointId': 'IFBS003177',
#                'order': 176,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 156.0,
#                 203.0,
#                 200.0,
#                 254.0,
#                 362.0]},
#               {'parentId': 'IFBS000480175',
#                'label': 'Commercial Paper',
#                'dataPointId': 'IFBS000390',
#                'order': 178,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 8575.0,
#                 4172.0,
#                 7247.0,
#                 7291.0,
#                 7190.0]},
#               {'parentId': 'IFBS000480175',
#                'label': 'Other Loans, Current Debt',
#                'dataPointId': 'IFBS100691',
#                'order': 182,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 467.0,
#                 252.0,
#                 204.0,
#                 112.0,
#                 462.0]}]},
#             {'parentId': 'IFBS002965174',
#              'label': 'Current Portion of Long Term Debt and Capital Lease',
#              'dataPointId': 'IFBS003330',
#              'order': 183,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               3603.0,
#               7615.0,
#               5945.0,
#               6182.0,
#               6238.0],
#              'subLevel': [{'parentId': 'IFBS003330183',
#                'label': 'Current Portion of Long Term Debt',
#                'dataPointId': 'IFBS002617',
#                'order': 184,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 1440.0,
#                 3449.0,
#                 1708.0,
#                 3023.0,
#                 2836.0],
#                'subLevel': [{'parentId': 'IFBS002617184',
#                  'label': 'Bank/Institutional Loans, Current Portion of LT Debt',
#                  'dataPointId': 'IFBS100690',
#                  'order': 186,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   346.0,
#                   377.0,
#                   222.0,
#                   338.0,
#                   329.0]},
#                 {'parentId': 'IFBS002617184',
#                  'label': 'Other Current Portion of LT Debt',
#                  'dataPointId': 'IFBS002703',
#                  'order': 189,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   1094.0,
#                   3072.0,
#                   1486.0,
#                   2685.0,
#                   2507.0]}]},
#               {'parentId': 'IFBS003330183',
#                'label': 'Capital Lease Obligations, Current',
#                'dataPointId': 'IFBS100694',
#                'order': 190,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 2163.0,
#                 4166.0,
#                 4237.0,
#                 3159.0,
#                 3402.0]}]}]},
#           {'parentId': 'IFBS100734173',
#            'label': 'Derivative and Hedging Liabilities, Current',
#            'dataPointId': 'IFBS200677',
#            'order': 191,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             604.0,
#             195.0,
#             300.0,
#             149.0,
#             208.0]}]},
#         {'parentId': 'IFBS000500160',
#          'label': 'Provisions, Current',
#          'dataPointId': 'IFBS001890',
#          'order': 193,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           2621.0,
#           3716.0,
#           3923.0,
#           4229.0,
#           4474.0],
#          'subLevel': [{'parentId': 'IFBS001890193',
#            'label': 'Provision for Employee Entitlements, Current',
#            'dataPointId': 'IFBS003035',
#            'order': 194,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             1646.0,
#             2470.0,
#             2714.0,
#             2988.0,
#             3157.0],
#            'subLevel': [{'parentId': 'IFBS003035194',
#              'label': 'Other Employee-Related Liabilities, Current',
#              'dataPointId': 'IFBS002859',
#              'order': 196,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               1646.0,
#               2470.0,
#               2714.0,
#               2988.0,
#               3157.0]}]},
#           {'parentId': 'IFBS001890193',
#            'label': 'Other Provisions, Current',
#            'dataPointId': 'IFBS003036',
#            'order': 199,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             975.0,
#             1246.0,
#             1209.0,
#             1241.0,
#             1317.0]}]},
#         {'parentId': 'IFBS000500160',
#          'label': 'Deferred Liabilities, Current',
#          'dataPointId': 'IFBS000610',
#          'order': 203,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           1614.0,
#           2382.0,
#           2465.0,
#           2394.0,
#           2295.0],
#          'subLevel': [{'parentId': 'IFBS000610203',
#            'label': 'Deferred Income/Customer Advances/Billings in Excess of Cost, Current',
#            'dataPointId': 'IFBS002625',
#            'order': 204,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             1076.0,
#             1475.0,
#             1678.0,
#             1458.0,
#             1388.0]},
#           {'parentId': 'IFBS000610203',
#            'label': 'Other Deferred Liabilities, Current',
#            'dataPointId': 'IFBS002854',
#            'order': 205,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             538.0,
#             907.0,
#             787.0,
#             936.0,
#             907.0]}]},
#         {'parentId': 'IFBS000500160',
#          'label': 'Other Current Liabilities',
#          'dataPointId': 'IFBS001570',
#          'order': 208,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           1035.0,
#           None,
#           None,
#           944.0,
#           1070.0]}]},
#       {'parentId': 'IFBS002646159',
#        'label': 'Total Non-Current Liabilities',
#        'dataPointId': 'IFBS002647',
#        'order': 209,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         44524.0,
#         48413.0,
#         46499.0,
#         47848.0,
#         46207.0],
#        'subLevel': [{'parentId': 'IFBS002647209',
#          'label': 'Financial Liabilities, Non-Current',
#          'dataPointId': 'IFBS100735',
#          'order': 210,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           24876.0,
#           24097.0,
#           23361.0,
#           25167.0,
#           27056.0],
#          'subLevel': [{'parentId': 'IFBS100735210',
#            'label': 'Long Term Debt and Capital Lease Obligation',
#            'dataPointId': 'IFBS002961',
#            'order': 211,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             24730.0,
#             24052.0,
#             23155.0,
#             25037.0,
#             26951.0],
#            'subLevel': [{'parentId': 'IFBS002961211',
#              'label': 'Long Term Debt',
#              'dataPointId': 'IFBS001290',
#              'order': 212,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               14065.0,
#               12165.0,
#               10379.0,
#               11227.0,
#               12091.0],
#              'subLevel': [{'parentId': 'IFBS001290212',
#                'label': 'Notes Payables, Non-Current',
#                'dataPointId': 'IFBS002695',
#                'order': 213,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 13866.0,
#                 11872.0,
#                 10185.0,
#                 11027.0,
#                 11611.0]},
#               {'parentId': 'IFBS001290212',
#                'label': 'Bank/Institutional Loans, Non-Current',
#                'dataPointId': 'IFBS100697',
#                'order': 215,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 199.0,
#                 293.0,
#                 194.0,
#                 200.0,
#                 480.0]}]},
#             {'parentId': 'IFBS002961211',
#              'label': 'Capital Lease Obligations, Non-Current',
#              'dataPointId': 'IFBS100700',
#              'order': 220,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               10665.0,
#               11887.0,
#               12776.0,
#               13810.0,
#               14860.0]}]},
#           {'parentId': 'IFBS100735210',
#            'label': 'Derivative and Hedging Liabilities, Non-Current',
#            'dataPointId': 'IFBS100699',
#            'order': 221,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             146.0,
#             45.0,
#             206.0,
#             130.0,
#             105.0]}]},
#         {'parentId': 'IFBS002647209',
#          'label': 'Provisions, Non-Current',
#          'dataPointId': 'IFBS001900',
#          'order': 223,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           1558.0,
#           1876.0,
#           1652.0,
#           1661.0,
#           1761.0],
#          'subLevel': [{'parentId': 'IFBS001900223',
#            'label': 'Provision for Employee Entitlements, Non-Current',
#            'dataPointId': 'IFBS003129',
#            'order': 224,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             86.0,
#             105.0,
#             123.0,
#             132.0,
#             129.0],
#            'subLevel': [{'parentId': 'IFBS003129224',
#              'label': 'Other Employee-Related Liabilities, Non-Current',
#              'dataPointId': 'IFBS002860',
#              'order': 226,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               86.0,
#               105.0,
#               123.0,
#               132.0,
#               129.0]}]},
#           {'parentId': 'IFBS001900223',
#            'label': 'Other Provisions, Non-Current',
#            'dataPointId': 'IFBS003131',
#            'order': 229,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             1472.0,
#             1771.0,
#             1529.0,
#             1529.0,
#             1632.0]}]},
#         {'parentId': 'IFBS002647209',
#          'label': 'Tax Liabilities, Non-Current',
#          'dataPointId': 'IFBS003143',
#          'order': 230,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           5481.0,
#           6704.0,
#           6952.0,
#           7012.0,
#           7344.0],
#          'subLevel': [{'parentId': 'IFBS003143230',
#            'label': 'Deferred Tax Liabilities, Non-Current',
#            'dataPointId': 'IFBS000710',
#            'order': 231,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             5481.0,
#             6704.0,
#             6952.0,
#             7012.0,
#             7344.0]}]},
#         {'parentId': 'IFBS002647209',
#          'label': 'Payables and Accrued Expenses, Non-Current',
#          'dataPointId': 'IFBS002717',
#          'order': 236,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           1180.0,
#           1404.0,
#           1400.0,
#           1438.0,
#           1348.0],
#          'subLevel': [{'parentId': 'IFBS002717236',
#            'label': 'Trade and Other Payables, Non-Current',
#            'dataPointId': 'IFBS200170',
#            'order': 237,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             1180.0,
#             1404.0,
#             1400.0,
#             1438.0,
#             1348.0],
#            'subLevel': [{'parentId': 'IFBS200170237',
#              'label': 'Taxes Payable, Non-Current',
#              'dataPointId': 'IFBS002761',
#              'order': 240,
#              'collapsed': True,
# ...
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -692.0,
#             1380.0,
#             2586.0,
#             1525.0,
#             2881.0]},
#           {'parentId': 'IFBS002737267',
#            'label': ' Available for Sale Financial Investments Reserves/Accum.Comp.Inc',
#            'dataPointId': 'IFBS002558',
#            'order': 273,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             None,
#             0.0,
#             0.0,
#             None,
#             None]},
#           {'parentId': 'IFBS002737267',
#            'label': 'Gain/Loss from Cash Flow Hedges Reserves/Accum.Comp.Inc',
#            'dataPointId': 'IFBS002560',
#            'order': 274,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -283.0,
#             -239.0,
#             9.0,
#             None,
#             None]},
#           {'parentId': 'IFBS002737267',
#            'label': 'Pension and Other PostRetirement Benefit Plans Reserves/Accum.Comp.Inc',
#            'dataPointId': 'IFBS002563',
#            'order': 275,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -231.0,
#             -53.0,
#             151.0,
#             None,
#             None]}]}]},
#       {'parentId': 'IFBS002220249',
#        'label': 'Non-Controlling/Minority Interests in Equity',
#        'dataPointId': 'IFBS001381',
#        'order': 278,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         1417.0,
#         1790.0,
#         1493.0,
#         1684.0,
#         1770.0]}]},
#     {'parentId': 'IFBS0000000',
#      'label': 'Debt Maturity Schedule Total',
#      'dataPointId': 'DMBS000001',
#      'order': 337,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       24703.0,
#       20240.0,
#       19739.0,
#       21907.0,
#       22942.0],
#      'subLevel': [{'parentId': 'DMBS000001337',
#        'label': 'Debt due in Year 1',
#        'dataPointId': 'DMBS000002',
#        'order': 338,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         10638.0,
#         8076.0,
#         9360.0,
#         10680.0,
#         10851.0]},
#       {'parentId': 'DMBS000001337',
#        'label': 'Debt due in Year 2',
#        'dataPointId': 'DMBS000003',
#        'order': 339,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         3049.0,
#         1654.0,
#         2797.0,
#         2586.0,
#         1678.0]},
#       {'parentId': 'DMBS000001337',
#        'label': 'Debt due in Year 3',
#        'dataPointId': 'DMBS000004',
#        'order': 340,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         1533.0,
#         2784.0,
#         1559.0,
#         1410.0,
#         1889.0]},
#       {'parentId': 'DMBS000001337',
#        'label': 'Debt due in Year 4',
#        'dataPointId': 'DMBS000005',
#        'order': 341,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         2474.0,
#         1530.0,
#         1364.0,
#         946.0,
#         1790.0]},
#       {'parentId': 'DMBS000001337',
#        'label': 'Debt due in Year 5',
#        'dataPointId': 'DMBS000006',
#        'order': 342,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         1508.0,
#         1354.0,
#         885.0,
#         1776.0,
#         1006.0]},
#       {'parentId': 'DMBS000001337',
#        'label': 'Debt due Beyond',
#        'dataPointId': 'DMBS000007',
#        'order': 343,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         5501.0,
#         4844.0,
#         3774.0,
#         4509.0,
#         5728.0]},
#       {'parentId': 'DMBS000001337',
#        'label': 'Debt - Interests Charges and Other Adjustments',
#        'dataPointId': 'DMBS000008',
#        'order': 344,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         -2.0,
#         None,
#         None,
#         None]}]},
#     {'parentId': 'IFBS0000000',
#      'label': 'Capital Lease Obligation Maturity Schedule Total',
#      'dataPointId': 'DMBS000009',
#      'order': 345,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       12829.0,
#       14275.0,
#       15408.0,
#       16538.0,
#       17832.0],
#      'subLevel': [{'parentId': 'DMBS000009345',
#        'label': 'Capital Lease due in Year 1',
#        'dataPointId': 'DMBS000010',
#        'order': 346,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         2388.0,
#         2648.0,
#         2853.0,
#         3041.0,
#         3399.0]},
#       {'parentId': 'DMBS000009345',
#        'label': 'Capital Lease due in Year 2',
#        'dataPointId': 'DMBS000011',
#        'order': 347,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         2065.0,
#         2236.0,
#         2530.0,
#         2749.0,
#         3025.0]},
#       {'parentId': 'DMBS000009345',
#        'label': 'Capital Lease due in Year 3',
#        'dataPointId': 'DMBS000012',
#        'order': 348,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         1791.0,
#         1958.0,
#         2122.0,
#         2379.0,
#         2583.0]},
#       {'parentId': 'DMBS000009345',
#        'label': 'Capital Lease due in Year 4',
#        'dataPointId': 'DMBS000013',
#        'order': 349,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         1552.0,
#         1646.0,
#         1819.0,
#         1997.0,
#         2231.0]},
#       {'parentId': 'DMBS000009345',
#        'label': 'Capital Lease due in Year 5',
#        'dataPointId': 'DMBS000014',
#        'order': 350,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         1318.0,
#         1392.0,
#         1468.0,
#         1661.0,
#         1829.0]},
#       {'parentId': 'DMBS000009345',
#        'label': 'Capital Lease due Beyond',
#        'dataPointId': 'DMBS000015',
#        'order': 351,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         5347.0,
#         5928.0,
#         6283.0,
#         6918.0,
#         7634.0]},
#       {'parentId': 'DMBS000009345',
#        'label': 'Capital Lease - Interests Charges and Other Adjustments',
#        'dataPointId': 'DMBS000016',
#        'order': 352,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -1632.0,
#         -1533.0,
#         -1667.0,
#         -2207.0,
#         -2869.0]}]},
#     {'parentId': 'IFBS0000000',
#      'label': 'Other Contractual Obligations Maturity Schedule Total',
#      'dataPointId': 'DMBS000025',
#      'order': 361,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       10565.0,
#       15496.0,
#       None,
#       17785.0,
#       17644.0],
#      'subLevel': [{'parentId': 'DMBS000025361',
#        'label': 'Other Contractual Obligations due in Year 1',
#        'dataPointId': 'DMBS000026',
#        'order': 362,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         10330.0,
#         15072.0,
#         None,
#         17324.0,
#         17232.0]},
#       {'parentId': 'DMBS000025361',
#        'label': 'Other Contractual Obligations due in Year 2',
#        'dataPointId': 'DMBS000027',
#        'order': 363,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         88.0,
#         129.0,
#         None,
#         226.0,
#         163.0]},
#       {'parentId': 'DMBS000025361',
#        'label': 'Other Contractual Obligations due in Year 3',
#        'dataPointId': 'DMBS000028',
#        'order': 364,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         42.0,
#         69.0,
#         None,
#         26.0,
#         44.0]},
#       {'parentId': 'DMBS000025361',
#        'label': 'Other Contractual Obligations due in Year 4',
#        'dataPointId': 'DMBS000029',
#        'order': 365,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         33.0,
#         37.0,
#         None,
#         23.0,
#         140.0]},
#       {'parentId': 'DMBS000025361',
#        'label': 'Other Contractual Obligations due in Year 5',
#        'dataPointId': 'DMBS000030',
#        'order': 366,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         31.0,
#         137.0,
#         None,
#         135.0,
#         29.0]},
#       {'parentId': 'DMBS000025361',
#        'label': 'Other Contractual Obligations due Beyond',
#        'dataPointId': 'DMBS000031',
#        'order': 367,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         41.0,
#         52.0,
#         None,
#         51.0,
#         36.0]}]},
#     {'parentId': 'IFBS0000000',
#      'label': 'Total Lease Liability',
#      'dataPointId': 'DMBS000033',
#      'order': 369,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       12829.0,
#       14275.0,
#       15408.0,
#       16538.0,
#       17832.0],
#      'subLevel': [{'parentId': 'DMBS000033369',
#        'label': 'Total Lease Liability - Due in year 1',
#        'dataPointId': 'DMBS000034',
#        'order': 370,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         2388.0,
#         2648.0,
#         2853.0,
#         3041.0,
#         3399.0]},
#       {'parentId': 'DMBS000033369',
#        'label': 'Total Lease Liability - Due in year 2',
#        'dataPointId': 'DMBS000035',
#        'order': 371,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         2065.0,
#         2236.0,
#         2530.0,
#         2749.0,
#         3025.0]},
#       {'parentId': 'DMBS000033369',
#        'label': 'Total Lease Liability - Due in year 3',
#        'dataPointId': 'DMBS000036',
#        'order': 372,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         1791.0,
#         1958.0,
#         2122.0,
#         2379.0,
#         2583.0]},
#       {'parentId': 'DMBS000033369',
#        'label': 'Total Lease Liability - Due in year 4',
#        'dataPointId': 'DMBS000037',
#        'order': 373,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         1552.0,
#         1646.0,
#         1819.0,
#         1997.0,
#         2231.0]},
#       {'parentId': 'DMBS000033369',
#        'label': 'Total Lease Liability - Due in year 5',
#        'dataPointId': 'DMBS000038',
#        'order': 374,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         1318.0,
#         1392.0,
#         1468.0,
#         1661.0,
#         1829.0]},
#       {'parentId': 'DMBS000033369',
#        'label': 'Total Lease Liability - Beyond',
#        'dataPointId': 'DMBS000039',
#        'order': 375,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         5347.0,
#         5928.0,
#         6283.0,
#         6918.0,
#         7634.0]},
#       {'parentId': 'DMBS000033369',
#        'label': 'Total Lease Liability - Interest Charges and Other Adjustments',
#        'dataPointId': 'DMBS000040',
#        'order': 376,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -1632.0,
#         -1533.0,
#         -1667.0,
#         -2207.0,
#         -2869.0]}]},
#     {'parentId': 'IFBS0000000',
#      'label': 'Total Contractual Obligations',
#      'dataPointId': 'DMBS000041',
#      'order': 377,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       48097.0,
#       50011.0,
#       35147.0,
#       56230.0,
#       58418.0],
#      'subLevel': [{'parentId': 'DMBS000041377',
#        'label': 'Total Contractual Obligations due in year 1',
#        'dataPointId': 'DMBS000042',
#        'order': 378,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         23356.0,
#         25796.0,
#         12213.0,
#         31045.0,
#         31482.0]},
#       {'parentId': 'DMBS000041377',
#        'label': 'Total Contractual Obligations due in year 2',
#        'dataPointId': 'DMBS000043',
#        'order': 379,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         5202.0,
#         4019.0,
#         5327.0,
#         5561.0,
#         4866.0]},
#       {'parentId': 'DMBS000041377',
#        'label': 'Total Contractual Obligations due in year 3',
#        'dataPointId': 'DMBS000044',
#        'order': 380,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         3366.0,
#         4811.0,
#         3681.0,
#         3815.0,
#         4516.0]},
#       {'parentId': 'DMBS000041377',
#        'label': 'Total Contractual Obligations due in year 4',
#        'dataPointId': 'DMBS000045',
#        'order': 381,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         4059.0,
#         3213.0,
#         3183.0,
#         2966.0,
#         4161.0]},
#       {'parentId': 'DMBS000041377',
#        'label': 'Total Contractual Obligations due in year 5',
#        'dataPointId': 'DMBS000046',
#        'order': 382,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         2857.0,
#         2883.0,
#         2353.0,
#         3572.0,
#         2864.0]},
#       {'parentId': 'DMBS000041377',
#        'label': 'Total Contractual Obligations due Beyond',
#        'dataPointId': 'DMBS000047',
#        'order': 383,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         10889.0,
#         10824.0,
#         10057.0,
#         11478.0,
#         13398.0]},
#       {'parentId': 'DMBS000041377',
#        'label': 'Total Contractual Obligations - Interests Charges and Other Adjustments',
#        'dataPointId': 'DMBS000048',
#        'order': 384,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -1632.0,
#         -1535.0,
#         -1667.0,
#         -2207.0,
#         -2869.0]}]},
#     {'parentId': 'IFBS0000000',
#      'label': 'Operating Lease Obligation Maturity Schedule Total',
#      'dataPointId': 'DMBS000017',
#      'order': 353,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       None,
#       None,
#       None,
#       None,
#       None],
#      'subLevel': [{'parentId': 'DMBS000017353',
#        'label': 'Operating Lease due in Year 1',
#        'dataPointId': 'DMBS000018',
#        'order': 354,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None]},
#       {'parentId': 'DMBS000017353',
#        'label': 'Operating Lease due Beyond',
#        'dataPointId': 'DMBS000022',
#        'order': 358,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None]},
#       {'parentId': 'DMBS000017353',
#        'label': 'Operating Lease - Interests Charges and Other Adjustments',
#        'dataPointId': 'DMBS000023',
#        'order': 359,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None]}]}]}],
#  'footer': {'currency': 'EUR',
#   'currencySymbol': '€',
#   'orderOfMagnitude': 'Million',
#   'fiscalYearEndDate': '12-31'},
#  'userType': 'Free'}

# %% [markdown]
# You can download the balance sheet in .xls format by setting the argument export = True

# %%
stock.balanceSheet(period="quarterly", reportType="restated", export=True)
# Out:
# {'status': 200,
#  'mesage': 'File downloaded',
#  'filename': 'balanceSheet-0P0000G5GV-20250715162445.xls',
#  'folder': '.'}

# %% [markdown]
# Board of directors and their compensation
#
# Profile - Board of Directors
#
# https://www.morningstar.com/stocks/pinx/lvmhf/executive

# %%
stock.boardOfDirectors()
# Out:
# {'rows': [{'type': 'person',
#    'personId': 'PS00007YG6',
#    'name': 'Bernard Arnault',
#    'title': 'Chairman of the Board and Chief Executive Officer',
#    'memberSince': None,
#    'age': '76',
#    'committee': None,
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000FKHV',
#    'name': 'Alexandre Arnault',
#    'title': 'Director',
#    'memberSince': '2024',
#    'age': '33',
#    'committee': None,
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS00007YSU',
#    'name': 'Antoine Arnault',
#    'title': 'Director',
#    'memberSince': None,
#    'age': '48',
#    'committee': None,
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000FKHW',
#    'name': 'Frederic Arnault',
#    'title': 'Director',
#    'memberSince': '2024',
#    'age': '31',
#    'committee': None,
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS00007YT5',
#    'name': 'Delphine Arnault-Gancia',
#    'title': 'Director',
#    'memberSince': '2019',
#    'age': '50',
#    'committee': None,
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000C8NM',
#    'name': 'Dominique Aumont',
#    'title': 'Director',
#    'memberSince': '2020',
#    'age': '68',
#    'committee': None,
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000C8NN',
#    'name': 'Marie-Veronique Belloeil-Melkin',
#    'title': 'Director',
#    'memberSince': '2020',
#    'age': '66',
#    'committee': 'Compensation',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000C8NP',
#    'name': 'Sophie Chassat',
#    'title': 'Independent Director',
#    'memberSince': None,
#    'age': '47',
#    'committee': 'Compensation',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS00007IHX',
#    'name': 'Wei Sun Christianson',
#    'title': 'Independent Director',
#    'memberSince': '2024',
#    'age': '69',
#    'committee': None,
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000FKHX',
#    'name': 'Henri De Castries',
#    'title': 'Lead Independent Director',
#    'memberSince': '2024',
#    'age': '71',
#    'committee': None,
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000C0IC',
#    'name': 'Marie-Laure Sauty de Chalon',
#    'title': 'Independent Director',
#    'memberSince': None,
#    'age': '63',
#    'committee': 'Performance Audit',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000BYS0',
#    'name': 'Clara Gaymard',
#    'title': 'Independent Director',
#    'memberSince': None,
#    'age': '65',
#    'committee': 'Performance Audit',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS00003YM4',
#    'name': 'Marie-Josee Kravis',
#    'title': 'Independent Director',
#    'memberSince': None,
#    'age': '76',
#    'committee': 'Compensation',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS00003X2S',
#    'name': 'Laurent Mignon',
#    'title': 'Independent Director',
#    'memberSince': None,
#    'age': '62',
#    'committee': 'Performance Audit',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000C8O4',
#    'name': 'Natacha Valla',
#    'title': 'Independent Director',
#    'memberSince': None,
#    'age': '49',
#    'committee': 'Compensation, Performance Audit',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'person',
#    'personId': 'PS0000C8O6',
#    'name': 'Hubert Vedrine',
#    'title': 'Independent Director',
#    'memberSince': None,
#    'age': '78',
#    'committee': None,
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'OTHER_COMPENSATION',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'total',
#    'personId': 'totalBoardOfDirectors',
#    'name': 'Compensation for all Board of Directors',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'totalSalary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalNon-Equity',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalOther',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]}],
#  'datesDef': ['2021', '2022', '2023', '2024', '2025'],
#  'currency': '',
#  'template': ''}

# %% [markdown]
# Cash Flow Statement
#
# https://www.morningstar.com/stocks/pinx/lvmhf/financials

# %%
stock.cashFlow()
# Out:
# {'_meta': {'companyId': '0C00000VOS',
#   'statementType': 'cash-flow',
#   'periodReport': 'Success',
#   'latestReport': 'Success'},
#  'columnDefs': ['2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2022',
#   '2023',
#   '2024',
#   'TTM'],
#  'filingIdList': [None,
#   None,
#   None,
#   None,
#   None,
#   '328683655',
#   '384266622',
#   '437916148',
#   '502488388',
#   '577784039',
#   None],
#  'rows': [{'parentId': '',
#    'label': 'CashFlow',
#    'dataPointId': 'IFCF000000',
#    'order': 697,
#    'subLevel': [{'parentId': 'IFCF000000697',
#      'label': 'Cash Flow from Operating Activities, Indirect',
#      'dataPointId': 'IFCF000150',
#      'order': 727,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       10898.0,
#       18647.0,
#       17835.0,
#       18403.0,
#       18925.0,
#       18925.0],
#      'subLevel': [{'parentId': 'IFCF000150727',
#        'label': 'Net Cash Flow from Continuing Operating Activities, Indirect',
#        'dataPointId': 'IFCF001591',
#        'order': 728,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         10898.0,
#         18647.0,
#         17835.0,
#         18403.0,
#         18925.0,
#         18925.0],
#        'subLevel': [{'parentId': 'IFCF001591728',
#          'label': 'Cash Generated from Operating Activities',
#          'dataPointId': 'IFCF200620',
#          'order': 729,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           13631.0,
#           23046.0,
#           23753.0,
#           24946.0,
#           25296.0,
#           25296.0],
#          'subLevel': [{'parentId': 'IFCF200620729',
#            'label': 'Income/Loss before Non-Cash Adjustment',
#            'dataPointId': 'IFCF001613',
#            'order': 730,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             7972.0,
#             17155.0,
#             21001.0,
#             22560.0,
#             18907.0,
#             18907.0]},
#           {'parentId': 'IFCF200620729',
#            'label': 'Total Adjustments for Non-Cash Items',
#            'dataPointId': 'IFCF200190',
#            'order': 733,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             6025.0,
#             5466.0,
#             5769.0,
#             6960.0,
#             8313.0,
#             8313.0],
#            'subLevel': [{'parentId': 'IFCF200190733',
#              'label': 'Depreciation, Amortization and Depletion, Non-Cash Adjustment',
#              'dataPointId': 'IFCF001559',
#              'order': 734,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               6050.0,
#               5830.0,
#               6226.0,
#               7177.0,
#               7796.0,
#               7796.0],
#              'subLevel': [{'parentId': 'IFCF001559734',
#                'label': 'Depreciation and Amortization, Non-Cash Adjustment',
#                'dataPointId': 'IFCF000620',
#                'order': 735,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 6050.0,
#                 5830.0,
#                 6226.0,
#                 7177.0,
#                 7796.0,
#                 7796.0],
#                'subLevel': [{'parentId': 'IFCF000620735',
#                  'label': 'Depreciation, Non-Cash Adjustment',
#                  'dataPointId': 'IFCF000610',
#                  'order': 736,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   6050.0,
#                   5830.0,
#                   6226.0,
#                   7177.0,
#                   7796.0,
#                   7796.0]}]}]},
#             {'parentId': 'IFCF200190733',
#              'label': 'Net Investment Income/Loss, Non-Cash Adjustment',
#              'dataPointId': 'IFCF002200',
#              'order': 748,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               64.0,
#               41.0,
#               26.0,
#               42.0,
#               29.0,
#               29.0],
#              'subLevel': [{'parentId': 'IFCF002200748',
#                'label': 'Share of Profit/Loss from Associates, Joint Ventures and other Equity Investments, Non-Cash Adjustment',
#                'dataPointId': 'IFCF100472',
#                'order': 755,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 64.0,
#                 41.0,
#                 26.0,
#                 42.0,
#                 29.0,
#                 29.0]}]},
#             {'parentId': 'IFCF200190733',
#              'label': 'Other Non-Cash Items',
#              'dataPointId': 'IFCF000920',
#              'order': 771,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -89.0,
#               -405.0,
#               -483.0,
#               -259.0,
#               488.0,
#               488.0]}]},
#           {'parentId': 'IFCF200620729',
#            'label': 'Changes in Operating Capital',
#            'dataPointId': 'IFCF000530',
#            'order': 772,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -366.0,
#             425.0,
#             -3017.0,
#             -4574.0,
#             -1924.0,
#             -1924.0],
#            'subLevel': [{'parentId': 'IFCF000530772',
#              'label': 'Change in Inventories',
#              'dataPointId': 'IFCF000340',
#              'order': 773,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -562.0,
#               -1567.0,
#               -4169.0,
#               -4230.0,
#               -1114.0,
#               -1114.0]},
#             {'parentId': 'IFCF000530772',
#              'label': 'Change in Trade and Other Receivables',
#              'dataPointId': 'IFCF000450',
#              'order': 774,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               528.0,
#               -613.0,
#               -394.0,
#               -695.0,
#               137.0,
#               137.0],
#              'subLevel': [{'parentId': 'IFCF000450774',
#                'label': 'Change in Trade/Accounts Receivable',
#                'dataPointId': 'IFCF001547',
#                'order': 775,
#                'collapsed': True,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 528.0,
#                 -613.0,
#                 -394.0,
#                 -695.0,
#                 137.0,
#                 137.0]}]},
#             {'parentId': 'IFCF000530772',
#              'label': 'Change in Payables and Accrued Expenses',
#              'dataPointId': 'IFCF001537',
#              'order': 787,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -569.0,
#               1603.0,
#               1538.0,
#               458.0,
#               -664.0,
#               -664.0],
#              'subLevel': [{'parentId': 'IFCF001537787',
#                'label': 'Change in Trade and Other Payables',
#                'dataPointId': 'IFCF000400',
#                'order': 788,
#                'datum': ['_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 '_PO_',
#                 -569.0,
#                 1603.0,
#                 1538.0,
#                 458.0,
#                 -664.0,
#                 -664.0],
#                'subLevel': [{'parentId': 'IFCF000400788',
#                  'label': 'Change in Trade/Accounts Payable',
#                  'dataPointId': 'IFCF001545',
#                  'order': 789,
#                  'collapsed': True,
#                  'datum': ['_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   '_PO_',
#                   -569.0,
#                   1603.0,
#                   1538.0,
#                   458.0,
#                   -664.0,
#                   -664.0]}]}]},
#             {'parentId': 'IFCF000530772',
#              'label': 'Change in Deferred Assets/Liabilities',
#              'dataPointId': 'IFCF001525',
#              'order': 797,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               None,
#               None,
#               None,
#               None,
#               106.0,
#               106.0]},
#             {'parentId': 'IFCF000530772',
#              'label': 'Change in Other Operating Capital',
#              'dataPointId': 'IFCF001532',
#              'order': 799,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               237.0,
#               1002.0,
#               8.0,
#               -107.0,
#               -389.0,
#               -389.0]}]}]},
#         {'parentId': 'IFCF001591728',
#          'label': 'Interest Paid, CFO Indirect',
#          'dataPointId': 'IFCF100464',
#          'order': 804,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -348.0,
#           -160.0,
#           -314.0,
#           -813.0,
#           -840.0,
#           -840.0]},
#         {'parentId': 'IFCF001591728',
#          'label': 'Taxes Refund/Paid, Indirect',
#          'dataPointId': 'IFCF200280',
#          'order': 807,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -2385.0,
#           -4239.0,
#           -5604.0,
#           -5730.0,
#           -5531.0,
#           -5531.0]}]}]},
#     {'parentId': 'IFCF000000697',
#      'label': 'Cash Flow from Investing Activities',
#      'dataPointId': 'IFCF000140',
#      'order': 815,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       -2940.0,
#       -15979.0,
#       -5920.0,
#       -8310.0,
#       -6539.0,
#       -6539.0],
#      'subLevel': [{'parentId': 'IFCF000140815',
#        'label': 'Cash Flow from Continuing Investing Activities',
#        'dataPointId': 'IFCF001510',
#        'order': 816,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -2940.0,
#         -15979.0,
#         -5920.0,
#         -8310.0,
#         -6539.0,
#         -6539.0],
#        'subLevel': [{'parentId': 'IFCF001510816',
#          'label': 'Purchase/Sale and Disposal of Property, Plant and Equipment, Net',
#          'dataPointId': 'IFCF001330',
#          'order': 822,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -1933.0,
#           -2231.0,
#           -4324.0,
#           -6671.0,
#           -4694.0,
#           -4694.0],
#          'subLevel': [{'parentId': 'IFCF001330822',
#            'label': 'Purchase of Property, Plant and Equipment',
#            'dataPointId': 'IFCF001260',
#            'order': 823,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -1984.0,
#             -2675.0,
#             -4397.0,
#             -6807.0,
#             -4715.0,
#             -4715.0]},
#           {'parentId': 'IFCF001330822',
#            'label': 'Sale and Disposal of Property, Plant and Equipment',
#            'dataPointId': 'IFCF001430',
#            'order': 825,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             51.0,
#             444.0,
#             73.0,
#             136.0,
#             21.0,
#             21.0]}]},
#         {'parentId': 'IFCF001510816',
#          'label': 'Purchase/Sale of Intangibles, Net',
#          'dataPointId': 'IFCF001310',
#          'order': 827,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -481.0,
#           -580.0,
#           -685.0,
#           -1000.0,
#           -837.0,
#           -837.0],
#          'subLevel': [{'parentId': 'IFCF001310827',
#            'label': 'Purchase of Intangibles',
#            'dataPointId': 'IFCF001220',
#            'order': 828,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -481.0,
#             -580.0,
#             -685.0,
#             -1000.0,
#             -837.0,
#             -837.0]}]},
#         {'parentId': 'IFCF001510816',
#          'label': 'Purchase/Sale of Investments, Net',
#          'dataPointId': 'IFCF001320',
#          'order': 839,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           63.0,
#           -13325.0,
#           -809.0,
#           -837.0,
#           -1017.0,
#           -1017.0],
#          'subLevel': [{'parentId': 'IFCF001320839',
#            'label': 'Purchase of Investments',
#            'dataPointId': 'IFCF001240',
#            'order': 840,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             None,
#             None,
#             None,
#             None,
#             None,
#             None]},
#           {'parentId': 'IFCF001320839',
#            'label': 'Sale of Investments',
#            'dataPointId': 'IFCF001410',
#            'order': 841,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             None,
#             None,
#             None,
#             None,
#             None,
#             None]}]},
#         {'parentId': 'IFCF001510816',
#          'label': 'Increase/Decrease in Restricted Cash and Cash Equivalents',
#          'dataPointId': 'IFCF001578',
#          'order': 845,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -3.0,
#           -37.0,
#           -94.0,
#           -78.0,
#           -33.0,
#           -33.0]},
#         {'parentId': 'IFCF001510816',
#          'label': 'Dividends Received/Paid, CFI',
#          'dataPointId': 'IFCF200390',
#          'order': 846,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           12.0,
#           10.0,
#           7.0,
#           5.0,
#           9.0,
#           9.0]},
#         {'parentId': 'IFCF001510816',
#          'label': 'Other Investing Cash Flow',
#          'dataPointId': 'IFCF000910',
#          'order': 848,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -62.0,
#           184.0,
#           134.0,
#           271.0,
#           33.0,
#           33.0]},
#         {'parentId': 'IFCF001510816',
#          'label': 'Purchase/Sale of Other Non-Current Assets, Net',
#          'dataPointId': 'IFCF002051',
#          'order': 842,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           None,
#           None,
#           -149.0,
#           None,
#           None,
#           None]},
#         {'parentId': 'IFCF001510816',
#          'label': 'Purchase/Sale of Business, Net',
#          'dataPointId': 'IFCF001300',
#          'order': 830,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -536.0,
#           None,
#           None,
#           None,
#           None,
#           None],
#          'subLevel': [{'parentId': 'IFCF001300830',
#            'label': 'Purchase/Acquisition of Business',
#            'dataPointId': 'IFCF001290',
#            'order': 831,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             None,
#             None,
#             None,
#             None,
#             None,
#             None]},
#           {'parentId': 'IFCF001300830',
#            'label': 'Sale of Business',
#            'dataPointId': 'IFCF001390',
#            'order': 832,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             None,
#             None,
#             None,
#             None,
#             None,
#             None]}]}]}]},
#     {'parentId': 'IFCF000000697',
#      'label': 'Cash Flow from Financing Activities',
#      'dataPointId': 'IFCF000130',
#      'order': 850,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       7403.0,
#       -15156.0,
#       -12686.0,
#       -9397.0,
#       -10716.0,
#       -10716.0],
#      'subLevel': [{'parentId': 'IFCF000130850',
#        'label': 'Cash Flow from Continuing Financing Activities',
#        'dataPointId': 'IFCF001509',
#        'order': 851,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         7403.0,
#         -15156.0,
#         -12686.0,
#         -9397.0,
#         -10716.0,
#         -10716.0],
#        'subLevel': [{'parentId': 'IFCF001509851',
#          'label': 'Issuance of/Payments for Common Stock, Net',
#          'dataPointId': 'IFCF000760',
#          'order': 852,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -12.0,
#           -556.0,
#           -1616.0,
#           -1584.0,
#           -259.0,
#           -259.0],
#          'subLevel': [{'parentId': 'IFCF000760852',
#            'label': 'Proceeds from Issuance of Common Stock',
#            'dataPointId': 'IFCF001080',
#            'order': 853,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             0.0,
#             0.0,
#             0.0,
#             0.0,
#             53.0,
#             53.0]},
#           {'parentId': 'IFCF000760852',
#            'label': 'Payments for Common Stock',
#            'dataPointId': 'IFCF000950',
#            'order': 854,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -12.0,
#             -556.0,
#             -1616.0,
#             -1584.0,
#             -312.0,
#             -312.0]}]},
#         {'parentId': 'IFCF001509851',
#          'label': 'Issuance of/Repayments for Debt, Net',
#          'dataPointId': 'IFCF000770',
#          'order': 858,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           12475.0,
#           -6162.0,
#           -117.0,
#           2022.0,
#           -81.0,
#           -81.0],
#          'subLevel': [{'parentId': 'IFCF000770858',
#            'label': 'Issuance of/Repayments for Long Term Debt, Net',
#            'dataPointId': 'IFCF000780',
#            'order': 862,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             12475.0,
#             -6162.0,
#             -117.0,
#             2022.0,
#             -81.0,
#             -81.0],
#            'subLevel': [{'parentId': 'IFCF000780862',
#              'label': 'Proceeds from Issuance of Long Term Debt',
#              'dataPointId': 'IFCF001090',
#              'order': 863,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               17499.0,
#               251.0,
#               3774.0,
#               5990.0,
#               3595.0,
#               3595.0]},
#             {'parentId': 'IFCF000780862',
#              'label': 'Repayments for Long Term Debt',
#              'dataPointId': 'IFCF000980',
#              'order': 864,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -5024.0,
#               -6413.0,
#               -3891.0,
#               -3968.0,
#               -3676.0,
#               -3676.0]}]}]},
#         {'parentId': 'IFCF001509851',
#          'label': 'Issuance of/Repayments for Lease Financing',
#          'dataPointId': 'IFCF100469',
#          'order': 865,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -2302.0,
#           -2453.0,
#           -2751.0,
#           -2818.0,
#           -2915.0,
#           -2915.0],
#          'subLevel': [{'parentId': 'IFCF100469865',
#            'label': 'Repayments for Lease Financing',
#            'dataPointId': 'IFCF100471',
#            'order': 867,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -2302.0,
#             -2453.0,
#             -2751.0,
#             -2818.0,
#             -2915.0,
#             -2915.0]}]},
#         {'parentId': 'IFCF001509851',
#          'label': 'Net Movement in Non-Controlling/Minority Interest',
#          'dataPointId': 'IFCF001615',
#          'order': 873,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -28.0,
#           -431.0,
#           -339.0,
#           -2.0,
#           -138.0,
#           -138.0]},
#         {'parentId': 'IFCF001509851',
#          'label': 'Cash Dividends and Interest Paid',
#          'dataPointId': 'IFCF002150',
#          'order': 877,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -2317.0,
#           -3527.0,
#           -6025.0,
#           -6251.0,
#           -6492.0,
#           -6492.0],
#          'subLevel': [{'parentId': 'IFCF002150877',
#            'label': 'Cash Dividends Paid',
#            'dataPointId': 'IFCF000080',
#            'order': 878,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -2317.0,
#             -3527.0,
#             -6025.0,
#             -6251.0,
#             -6492.0,
#             -6492.0],
#            'subLevel': [{'parentId': 'IFCF000080878',
#              'label': 'Common Stock Dividends Paid',
#              'dataPointId': 'IFCF000540',
#              'order': 879,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -2317.0,
#               -3527.0,
#               -6025.0,
#               -6251.0,
#               -6492.0,
#               -6492.0]}]}]},
#         {'parentId': 'IFCF001509851',
#          'label': 'Cash Dividends Paid to Non-Controlling/Minority Interests',
#          'dataPointId': 'IFCF100478',
#          'order': 882,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -365.0,
#           -408.0,
#           -421.0,
#           -532.0,
#           -571.0,
#           -571.0]},
#         {'parentId': 'IFCF001509851',
#          'label': 'Other Financing Cash Flow',
#          'dataPointId': 'IFCF000900',
#          'order': 885,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -48.0,
#           -1619.0,
#           -1417.0,
#           -232.0,
#           -260.0,
#           -260.0]}]}]},
#     {'parentId': 'IFCF000000697',
#      'label': 'Cash and Cash Equivalents, End of Period',
#      'dataPointId': 'IFCF000170',
#      'order': 889,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       19806.0,
#       7817.0,
#       7100.0,
#       7520.0,
#       9269.0,
#       9269.0],
#      'subLevel': [{'parentId': 'IFCF000170889',
#        'label': 'Change in Cash',
#        'dataPointId': 'IFCF000280',
#        'order': 890,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         15361.0,
#         -12488.0,
#         -771.0,
#         696.0,
#         1670.0,
#         1670.0]},
#       {'parentId': 'IFCF000170889',
#        'label': 'Effect of Exchange Rate Changes',
#        'dataPointId': 'IFCF000650',
#        'order': 891,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -1052.0,
#         498.0,
#         55.0,
#         -273.0,
#         80.0,
#         80.0]},
#       {'parentId': 'IFCF000170889',
#        'label': 'Cash and Cash Equivalents, Beginning of Period',
#        'dataPointId': 'IFCF000160',
#        'order': 896,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         5497.0,
#         19806.0,
#         7817.0,
#         7100.0,
#         7520.0,
#         7520.0]}]},
#     {'parentId': 'IFCF000000697',
#      'label': 'Cash Flow Supplemental Section',
#      'dataPointId': 'IFCF001730',
#      'order': 897,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       None,
#       None,
#       None,
#       None,
#       None,
#       None],
#      'subLevel': [{'parentId': 'IFCF001730897',
#        'label': 'Change in Cash as Reported, Supplemental',
#        'dataPointId': 'IFCF002210',
#        'order': 898,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         14309.0,
#         -11989.0,
#         -717.0,
#         420.0,
#         1749.0,
#         1749.0]},
#       {'parentId': 'IFCF001730897',
#        'label': 'Income Tax Paid, Supplemental',
#        'dataPointId': 'IFCF001580',
#        'order': 899,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         -4464.0,
#         -5933.0,
#         -6106.0,
#         -5790.0,
#         -5790.0]}]}]}],
#  'footer': {'currency': 'EUR',
#   'currencySymbol': '€',
#   'orderOfMagnitude': 'Million',
#   'fiscalYearEndDate': '12-31'},
#  'userType': 'Free'}

# %% [markdown]
# You can download the cashFlow statement in .xls format by setting the argument export = True

# %%
stock.cashFlow(period="annual", reportType="restated", export=True)
# Out:
# {'status': 200,
#  'mesage': 'File downloaded',
#  'filename': 'cashFlow-0P0000G5GV-20250715162447.xls',
#  'folder': '.'}

# %% [markdown]
# Company profile
#
# https://www.morningstar.com/stocks/pinx/lvmhf/quote

# %%
stock.companyProfile()
# Out:
# {'performanceId': '0P0000G5GV',
#  'dataMap': None,
#  'title': 'Company Profile',
#  'sections': {'businessDescription': {'label': 'Business Description',
#    'value': 'LVMH is a global producer and distributor of luxury goods. It operates six segments: fashion and leather goods, its largest and oldest; watches and jewelry; wines and spirits; perfumes and cosmetics; selective retailing (including Sephora and airport duty-free retailer DFS); and other. Higher-profile brands include Louis Vuitton, Bulgari, Fendi, Givenchy, Tag Heuer, Hennessy, Moet & Chandon, Glenmorangie, Sephora, and Benefit. LVMH operates more than 5,000 stores around the globe.'},
#   'contact': {'label': 'Contact',
#    'address1': '22, Avenue Montaigne, Paris 75008',
#    'address2': '',
#    'country': 'France',
#    'phone': 'T +33 144132222',
#    'fax': '',
#    'email': '',
#    'url': 'www.lvmh.com'},
#   'sector': {'label': 'Sector', 'value': 'Consumer Cyclical'},
#   'industry': {'label': 'Industry', 'value': 'Luxury Goods'},
#   'mostRecentEarnings': {'label': 'Most Recent Earnings',
#    'value': '2024-12-31T06:00:00.000'},
#   'fiscalYearEnds': {'label': 'Fiscal Year End',
#    'value': '2025-12-31T06:00:00.000'},
#   'totalEmployees': {'label': 'Total Number of Employees',
#    'value': '215637',
#    'date': '2024-12-31'},
#   'stockType': None}}

# %% [markdown]
# Information of the stock

# %%
stock.dataPoint(["priceToEarnings", "industry", "name"])
# Out:
# [{'meta': {'securityID': '0P0000G5GV',
#    'performanceID': '0P0000G5GV',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'XMIL',
#    'ticker': '1MC'},
#   'fields': {'priceToEarnings': {'value': 19.048567},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}},
#  {'meta': {'securityID': '0P0000E9C5',
#    'performanceID': '0P0000E9C5',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'XFRA',
#    'ticker': 'MOH'},
#   'fields': {'priceToEarnings': {'value': 19.223726},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}},
#  {'meta': {'securityID': '0P0000E9HU',
#    'performanceID': '0P0000E9HU',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'XWBO',
#    'ticker': 'MC'},
#   'fields': {'priceToEarnings': {'value': 19.068471},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}},
#  {'meta': {'securityID': '0P0000EPDV',
#    'performanceID': '0P0000EPDV',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'XHAM',
#    'ticker': 'MOH'},
#   'fields': {'priceToEarnings': {'value': 19.096338},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}},
#  {'meta': {'securityID': '0P0000CN3U',
#    'performanceID': '0P0000CN3U',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'CHIX',
#    'ticker': 'MCp'},
#   'fields': {'priceToEarnings': {'value': 19.084395},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}},
#  {'meta': {'securityID': '0P00015MG9',
#    'performanceID': '0P00015MG9',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'XMEX',
#    'ticker': 'MC'},
#   'fields': {'priceToEarnings': {'value': 21.997975},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}},
#  {'meta': {'securityID': '0P0000EWD1',
#    'performanceID': '0P0000EWD1',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'LTS',
#    'ticker': '0HAU'},
#   'fields': {'priceToEarnings': {'value': 19.082404},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}},
#  {'meta': {'securityID': '0P0000E98L',
#    'performanceID': '0P0000E98L',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'XETR',
#    'ticker': 'MOH'},
#   'fields': {'priceToEarnings': {'value': 19.072452},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}},
#  {'meta': {'securityID': '0P0000CKQ3',
#    'performanceID': '0P0000CKQ3',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'XSTU',
#    'ticker': 'MOH'},
#   'fields': {'priceToEarnings': {'value': 19.15207},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}},
#  {'meta': {'securityID': '0P0000BR00',
#    'performanceID': '0P0000BR00',
#    'companyID': '0C00000VOS',
#    'universe': 'EQ',
#    'exchange': 'PINX',
#    'ticker': 'LVMHF'},
#   'fields': {'priceToEarnings': {'value': 20.607102},
#    'industry': {'value': 'Luxury Goods'},
#    'name': {'value': 'Lvmh Moet Hennessy Louis Vuitton SE'}}}]

# %% [markdown]
# History of dividends
#
# https://www.morningstar.com/stocks/pinx/lvmhf/dividends

# %%
stock.dividends()
# Out:
# {'rows': [{'label': 'Dividend Per Share',
#    'salDataId': 'dividends.per.share.label',
#    'datum': ['3.3',
#     '3.6',
#     '4.2',
#     '5.4',
#     '6.2',
#     '9.2',
#     '7',
#     '12',
#     '12.5',
#     '13',
#     '13',
#     '13',
#     None]},
#   {'label': 'Trailing Dividend Yield %',
#    'salDataId': 'trailing.dividends.yield.label',
#    'datum': ['2.23',
#     '2.01',
#     '1.70',
#     '2.14',
#     '1.49',
#     '0.89',
#     '0.96',
#     '1.76',
#     '1.69',
#     '2.07',
#     '2.66',
#     '2.66',
#     '1.39'],
#    'percentage': True},
#   {'label': 'Buyback Yield %',
#    'salDataId': 'buyback.yield.label',
#    'datum': [None,
#     None,
#     '0.20',
#     '0.07',
#     '0.12',
#     None,
#     '0.00',
#     '0.16',
#     '0.57',
#     '0.07',
#     '0.11',
#     '0.11',
#     '0.02'],
#    'percentage': True},
#   {'label': 'Total Yield %',
#    'salDataId': 'total.yield.label',
#    'datum': ['2.23',
#     '2.01',
#     '1.90',
#     '2.21',
#     '1.61',
#     '0.89',
#     '0.96',
#     '1.92',
#     '2.26',
#     '2.13',
#     '2.83',
#     '2.83',
#     '1.50'],
#    'percentage': True},
#   {'label': 'Payout Ratio %',
#    'salDataId': 'payout.ratio.label',
#    'datum': ['46.61',
#     '45.63',
#     '41.26',
#     '42.82',
#     '43.57',
#     '98.71',
#     '29.30',
#     '42.81',
#     '41.21',
#     None,
#     '51.75',
#     '51.75',
#     '52.46'],
#    'percentage': True}],
#  'columnDefs_labels': ['tabular.data.label.column.year',
#   '2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2022',
#   '2023',
#   '2024',
#   'dividends.headers.current',
#   'dividends.headers.oneyearttm',
#   'dividends.headers.fiveyear'],
#  'dividendData': {'label': ['exdividend.date.label',
#    'declaration.date.label',
#    'record.date.label',
#    'payable.date.label',
#    'dividend.type.label',
#    'dividend.amount.label'],
#   'upcomingData': [],
#   'dividendHistory': [{'year': '2025',
#     'datum': [['2025-04-24T05:00:00.000',
#       '2025-03-10T05:00:00.000',
#       '2025-04-25T05:00:00.000',
#       '2025-04-28T05:00:00.000',
#       'Cash Dividend',
#       '7.5']]},
#    {'year': '2024',
#     'datum': [['2024-12-02T06:00:00.000',
#       '2024-07-23T05:00:00.000',
#       '2024-12-03T06:00:00.000',
#       '2024-12-04T06:00:00.000',
#       'Cash Dividend',
#       '5.5'],
#      ['2024-04-23T05:00:00.000',
#       '2024-01-26T06:00:00.000',
#       '2024-04-24T05:00:00.000',
#       '2024-04-25T05:00:00.000',
#       'Cash Dividend',
#       '7.5']]},
#    {'year': '2023',
#     'datum': [['2023-12-04T06:00:00.000',
#       '2023-11-24T06:00:00.000',
#       '2023-12-05T06:00:00.000',
#       '2023-12-06T06:00:00.000',
#       'Cash Dividend',
#       '5.5'],
#      ['2023-04-25T05:00:00.000',
#       '2023-01-27T06:00:00.000',
#       '2023-04-26T05:00:00.000',
#       '2023-04-27T05:00:00.000',
#       'Cash Dividend',
#       '7']]},
#    {'year': '2022',
#     'datum': [['2022-12-01T06:00:00.000',
#       '2022-07-27T05:00:00.000',
#       '2022-12-02T06:00:00.000',
#       '2022-12-05T06:00:00.000',
#       'Cash Dividend',
#       '5'],
#      ['2022-04-26T05:00:00.000',
#       '2022-03-14T05:00:00.000',
#       '2022-04-27T05:00:00.000',
#       '2022-04-28T05:00:00.000',
#       'Cash Dividend',
#       '7']]},
#    {'year': '2021',
#     'datum': [['2021-11-30T06:00:00.000',
#       '2021-11-17T06:00:00.000',
#       '2021-12-01T06:00:00.000',
#       '2021-12-02T06:00:00.000',
#       'Cash Dividend',
#       '3'],
#      ['2021-04-20T05:00:00.000',
#       '2021-01-27T06:00:00.000',
#       '2021-04-21T05:00:00.000',
#       '2021-04-22T05:00:00.000',
#       'Cash Dividend',
#       '4']]}]},
#  'quoteData': [{'name': 'dividendYield',
#    'label': 'Dividend Yield',
#    'salDataId': 'dividend.yield.label',
#    'date': '2025-07-11T00:00:00.000',
#    'value': '0.0266'},
#   {'name': 'divReinvestmentPlan',
#    'label': 'Div Reinvestment Plan',
#    'salDataId': 'div.reinvestment.plan.label',
#    'date': '2025-04-24T00:00:00.000',
#    'value': 'No'}],
#  'footer': {'asOfLabel': 'As of',
#   'distributionCurrency': 'EUR',
#   'asOfDate': '2025-07-11T00:00:00.000'}}

# %% [markdown]
# Sustainability Risk Rating Assessment
#
# https://www.morningstar.com/stocks/pinx/lvmhf/sustainability

# %%
stock.esgRisk()
# Out:
# {'susEsgRiskScore': 13.8892,
#  'susEsgRiskGlobes': 4,
#  'susEsgRiskCategory': 'Low',
#  'comHighestControversyLevel': 2,
#  'comControversyLevelDescriptor': 'Moderate',
#  'comHighestControversyTopics': 'Operations, Product & Service, Business Ethics, Governance, Employee, Social Supply Chain, Customer',
#  'notableIssue1Name': 'Overall',
#  'notableIssue2Name': 'Overall',
#  'notableIssue3Name': 'Supply Chain',
#  'notableIssue1': 'Human Capital',
#  'notableIssue2': 'Data Privacy & Cybersecurity',
#  'notableIssue3': 'Human Rights',
#  'asOfDate': '2025-06-04T05:00:00.000',
#  'subIndustry': 'Luxury Apparel',
#  'controversyAsOfDate': '2025-07-08T05:00:00.000'}

# %% [markdown]
# Financial Health
#
# https://www.morningstar.com/stocks/pinx/lvmhf/key-metrics

# %%
stock.financialHealth()
# Out:
# {'currency': 'EUR',
#  'asOfDate': '2024-12-31T06:00:00.000',
#  'expectedFiscalYearEnd': '2025-12-31T06:00:00.000',
#  'dataList': [{'fiscalPeriodYearMonth': '2015-12',
#    'morningstarEndingDate': '2015-12-31T06:00:00.000',
#    'currentRatio': 1.4922,
#    'quickRatio': 0.5556,
#    'interestCoverage': 54.7838,
#    'financialLeverage': 2.3666,
#    'debtEquityRatio': 0.1853,
#    'bookValuePerShare': 46.0064,
#    'capExAsPerOfSales': 5.762113055181696},
#   {'fiscalPeriodYearMonth': '2016-12',
#    'morningstarEndingDate': '2016-12-31T06:00:00.000',
#    'currentRatio': 1.5143,
#    'quickRatio': 0.5559,
#    'interestCoverage': 71.3478,
#    'financialLeverage': 2.259,
#    'debtEquityRatio': 0.149,
#    'bookValuePerShare': 49.1247,
#    'capExAsPerOfSales': 6.888297872340425},
#   {'fiscalPeriodYearMonth': '2017-12',
#    'morningstarEndingDate': '2017-12-31T06:00:00.000',
#    'currentRatio': 1.4052,
#    'quickRatio': 0.5034,
#    'interestCoverage': 73.1273,
#    'financialLeverage': 2.3759,
#    'debtEquityRatio': 0.2442,
#    'bookValuePerShare': 53.4011,
#    'capExAsPerOfSales': 5.500046908715639},
#   {'fiscalPeriodYearMonth': '2018-12',
#    'morningstarEndingDate': '2018-12-31T06:00:00.000',
#    'currentRatio': 1.3991,
#    'quickRatio': 0.5368,
#    'interestCoverage': 61.057,
#    'financialLeverage': 2.3008,
#    'debtEquityRatio': 0.186,
#    'bookValuePerShare': 59.6348,
#    'capExAsPerOfSales': 6.707811899372143},
#   {'fiscalPeriodYearMonth': '2019-12',
#    'morningstarEndingDate': '2019-12-31T06:00:00.000',
#    'currentRatio': 1.1718,
#    'quickRatio': 0.4617,
#    'interestCoverage': 25.0202,
#    'financialLeverage': 2.6378,
#    'debtEquityRatio': 0.4229,
#    'bookValuePerShare': 66.8675,
#    'capExAsPerOfSales': 6.312651388112539},
#   {'fiscalPeriodYearMonth': '2020-12',
#    'morningstarEndingDate': '2020-12-31T06:00:00.000',
#    'currentRatio': 1.5788,
#    'quickRatio': 0.9497,
#    'interestCoverage': 21.1175,
#    'financialLeverage': 2.9047,
#    'debtEquityRatio': 0.661,
#    'bookValuePerShare': 71.0683,
#    'capExAsPerOfSales': 5.520716685330347},
#   {'fiscalPeriodYearMonth': '2021-12',
#    'morningstarEndingDate': '2021-12-31T06:00:00.000',
#    'currentRatio': 1.2255,
#    'quickRatio': 0.5405,
#    'interestCoverage': 72.1116,
#    'financialLeverage': 2.6595,
#    'debtEquityRatio': 0.5105,
#    'bookValuePerShare': 81.7927,
#    'capExAsPerOfSales': 5.068909133380052},
#   {'fiscalPeriodYearMonth': '2022-12',
#    'morningstarEndingDate': '2022-12-31T06:00:00.000',
#    'currentRatio': 1.2599,
#    'quickRatio': 0.5068,
#    'interestCoverage': 53.6571,
#    'financialLeverage': 2.4432,
#    'debtEquityRatio': 0.4202,
#    'bookValuePerShare': 101.2898,
#    'capExAsPerOfSales': 6.417963224893918},
#   {'fiscalPeriodYearMonth': '2023-12',
#    'morningstarEndingDate': '2023-12-31T06:00:00.000',
#    'currentRatio': 1.3188,
#    'quickRatio': 0.5081,
#    'interestCoverage': 23.2271,
#    'financialLeverage': 2.355,
#    'debtEquityRatio': 0.4103,
#    'bookValuePerShare': 115.5465,
#    'capExAsPerOfSales': 9.061785428249742},
#   {'fiscalPeriodYearMonth': '2024-12',
#    'morningstarEndingDate': '2024-12-31T06:00:00.000',
#    'currentRatio': 1.4088,
#    'quickRatio': 0.5742,
#    'interestCoverage': 16.2715,
#    'financialLeverage': 2.2097,
#    'debtEquityRatio': 0.3992,
#    'bookValuePerShare': 129.7728,
#    'capExAsPerOfSales': 6.556292954819206},
#   {'fiscalPeriodYearMonth': 'Latest Qtr',
#    'morningstarEndingDate': '2024-12-31T06:00:00.000',
#    'currentRatio': 1.4088,
#    'quickRatio': 0.5742,
#    'interestCoverage': 16.2715,
#    'financialLeverage': 2.2097,
#    'debtEquityRatio': 0.3992,
#    'bookValuePerShare': 129.7728,
#    'capExAsPerOfSales': 6.556292954819206}]}

# %% [markdown]
# Financial Statement

# %%
stock.financialStatement()
# Out:
# {'_meta': {'companyId': '0C00000VOS',
#   'statementType': None,
#   'periodReport': 'no data available',
#   'latestReport': 'no data available'},
#  'columnDefs': [],
#  'filingIdList': [],
#  'rows': [],
#  'footer': {'currency': None,
#   'currencySymbol': '',
#   'orderOfMagnitude': None,
#   'fiscalYearEndDate': None},
#  'userType': 'Free'}

# %% [markdown]
# Financial Summary

# %%
stock.financialSummary()
# Out:
# {'_meta': {'companyId': '0C00000VOS',
#   'statementType': None,
#   'periodReport': 'no data available',
#   'latestReport': 'no data available'},
#  'columnDefs': [],
#  'filingIdList': [],
#  'rows': [],
#  'footer': {'currency': None,
#   'currencySymbol': '',
#   'orderOfMagnitude': None,
#   'fiscalYearEndDate': None},
#  'userType': 'Free'}

# %% [markdown]
# Free Cash Flow
#
# https://www.morningstar.com/stocks/pinx/lvmhf/key-metrics

# %%
stock.freeCashFlow()
# Out:
# {'currency': 'EUR',
#  'asOfDate': '2024-12-31T06:00:00.000',
#  'expectedFiscalYearEnd': '2025-12-31T06:00:00.000',
#  'dataList': [{'fiscalPeriodDate': '2015-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2015-12',
#    'operatingCFGrowthPer': 22.29,
#    'freeCashFlowGrowthPer': 29.720000000000002,
#    'freeCFPerSales': 10.035329744279947,
#    'freeCashFlowPerNetIncome': 1.0016792611251049,
#    'freeCashFlowPerShare': 6.6285},
#   {'fiscalPeriodDate': '2016-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2016-12',
#    'operatingCFGrowthPer': 10.74,
#    'freeCashFlowGrowthPer': 1.96,
#    'freeCFPerSales': 9.704787234042554,
#    'freeCashFlowPerNetIncome': 0.9166038683747803,
#    'freeCashFlowPerShare': 7.3607},
#   {'fiscalPeriodDate': '2017-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2017-12',
#    'operatingCFGrowthPer': 12.68,
#    'freeCashFlowGrowthPer': 28.389999999999997,
#    'freeCFPerSales': 10.988366638521438,
#    'freeCashFlowPerNetIncome': 0.9134334178202379,
#    'freeCashFlowPerShare': 8.4943},
#   {'fiscalPeriodDate': '2018-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2018-12',
#    'operatingCFGrowthPer': 20.77,
#    'freeCashFlowGrowthPer': 14.17,
#    'freeCFPerSales': 11.423140990048264,
#    'freeCashFlowPerNetIncome': 0.8418319169027384,
#    'freeCashFlowPerShare': 10.7571},
#   {'fiscalPeriodDate': '2019-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2019-12',
#    'operatingCFGrowthPer': 37.18,
#    'freeCashFlowGrowthPer': 54.400000000000006,
#    'freeCFPerSales': 15.38848518725545,
#    'freeCashFlowPerNetIncome': 1.1517222144749686,
#    'freeCashFlowPerShare': 12.2743},
#   {'fiscalPeriodDate': '2020-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2020-12',
#    'operatingCFGrowthPer': -6.43,
#    'freeCashFlowGrowthPer': 2.11,
#    'freeCFPerSales': 18.88689809630459,
#    'freeCashFlowPerNetIncome': 1.7934921310080816,
#    'freeCashFlowPerShare': 9.6736},
#   {'fiscalPeriodDate': '2021-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2021-12',
#    'operatingCFGrowthPer': 71.1,
#    'freeCashFlowGrowthPer': 82.52000000000001,
#    'freeCFPerSales': 23.969477536401154,
#    'freeCashFlowPerNetIncome': 1.278830176138252,
#    'freeCashFlowPerShare': 30.9178},
#   {'fiscalPeriodDate': '2022-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2022-12',
#    'operatingCFGrowthPer': -4.35,
#    'freeCashFlowGrowthPer': -17.150000000000002,
#    'freeCFPerSales': 16.105526368963428,
#    'freeCashFlowPerNetIncome': 0.9054955978415223,
#    'freeCashFlowPerShare': 28.3179},
#   {'fiscalPeriodDate': '2023-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2023-12',
#    'operatingCFGrowthPer': 3.18,
#    'freeCashFlowGrowthPer': -16.91,
#    'freeCFPerSales': 12.299049365663413,
#    'freeCashFlowPerNetIncome': 0.6982997232107553,
#    'freeCashFlowPerShare': 20.8691},
#   {'fiscalPeriodDate': '2024-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2024-12',
#    'operatingCFGrowthPer': 2.8400000000000003,
#    'freeCashFlowGrowthPer': 26.21,
#    'freeCFPerSales': 15.792021917290569,
#    'freeCashFlowPerNetIncome': 1.065577689243028,
#    'freeCashFlowPerShare': 24.0784},
#   {'fiscalPeriodDate': '2024-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': 'TTM',
#    'operatingCFGrowthPer': None,
#    'freeCashFlowGrowthPer': None,
#    'freeCFPerSales': 15.792021917290569,
#    'freeCashFlowPerNetIncome': 1.065577689243028,
#    'freeCashFlowPerShare': 24.0784}]}

# %%
import datetime
end_date = datetime.datetime.today()
start_date = end_date - datetime.timedelta(30)

stock.historical(start_date, end_date)
# Out:
# [{'open': 460.35,
#   'high': 462.9,
#   'low': 457.45,
#   'close': 461.6,
#   'volume': 1843,
#   'previousClose': 468.3,
#   'date': '2025-06-13'},
#  {'open': 466.7,
#   'high': 469.25,
#   'low': 461.0,
#   'close': 466.85,
#   'volume': 1345,
#   'previousClose': 461.6,
#   'date': '2025-06-16'},
#  {'open': 460.7,
#   'high': 467.05,
#   'low': 459.6,
#   'close': 460.55,
#   'volume': 1243,
#   'previousClose': 466.85,
#   'date': '2025-06-17'},
#  {'open': 460.65,
#   'high': 465.65,
#   'low': 460.0,
#   'close': 463.9,
#   'volume': 1172,
#   'previousClose': 460.55,
#   'date': '2025-06-18'},
#  {'open': 457.6,
#   'high': 459.15,
#   'low': 450.9,
#   'close': 453.55,
#   'volume': 1856,
#   'previousClose': 463.9,
#   'date': '2025-06-19'},
#  {'open': 455.0,
#   'high': 456.25,
#   'low': 448.9,
#   'close': 449.25,
#   'volume': 1781,
#   'previousClose': 453.55,
#   'date': '2025-06-20'},
#  {'open': 445.9,
#   'high': 451.2,
#   'low': 444.0,
#   'close': 449.75,
#   'volume': 1409,
#   'previousClose': 449.25,
#   'date': '2025-06-23'},
#  {'open': 465.3,
#   'high': 466.1,
#   'low': 450.25,
#   'close': 453.75,
#   'volume': 1199,
#   'previousClose': 449.75,
#   'date': '2025-06-24'},
#  {'open': 456.0,
#   'high': 456.0,
#   'low': 444.0,
#   'close': 445.0,
#   'volume': 1419,
#   'previousClose': 453.75,
#   'date': '2025-06-25'},
#  {'open': 444.9,
#   'high': 449.95,
#   'low': 436.8,
#   'close': 437.5,
#   'volume': 2136,
#   'previousClose': 445.0,
#   'date': '2025-06-26'},
#  {'open': 441.95,
#   'high': 457.0,
#   'low': 440.3,
#   'close': 457.0,
#   'volume': 1271,
#   'previousClose': 437.5,
#   'date': '2025-06-27'},
#  {'open': 450.9,
#   'high': 453.0,
#   'low': 446.0,
#   'close': 447.9,
#   'volume': 1996,
#   'previousClose': 457.0,
#   'date': '2025-06-30'},
#  {'open': 447.9,
#   'high': 473.95,
#   'low': 446.9,
#   'close': 473.95,
#   'volume': 2525,
#   'previousClose': 447.9,
#   'date': '2025-07-01'},
#  {'open': 473.95,
#   'high': 492.65,
#   'low': 467.0,
#   'close': 489.6,
#   'volume': 7468,
#   'previousClose': 473.95,
#   'date': '2025-07-02'},
#  {'open': 494.95,
#   'high': 494.95,
#   'low': 485.3,
#   'close': 486.0,
#   'volume': 2772,
#   'previousClose': 489.6,
#   'date': '2025-07-03'},
#  {'open': 483.75,
#   'high': 483.75,
#   'low': 475.0,
#   'close': 477.7,
#   'volume': 1102,
#   'previousClose': 486.0,
#   'date': '2025-07-04'},
#  {'open': 480.0,
#   'high': 480.0,
#   'low': 472.2,
#   'close': 475.95,
#   'volume': 1322,
#   'previousClose': 477.7,
#   'date': '2025-07-07'},
#  {'open': 475.55,
#   'high': 484.6,
#   'low': 474.15,
#   'close': 482.7,
#   'volume': 1004,
#   'previousClose': 475.95,
#   'date': '2025-07-08'},
#  {'open': 485.0,
#   'high': 489.2,
#   'low': 479.9,
#   'close': 486.95,
#   'volume': 1638,
#   'previousClose': 482.7,
#   'date': '2025-07-09'},
#  {'open': 490.2,
#   'high': 503.2,
#   'low': 490.0,
#   'close': 501.1,
#   'volume': 3779,
#   'previousClose': 486.95,
#   'date': '2025-07-10'},
#  {'open': 500.2,
#   'high': 500.2,
#   'low': 488.15,
#   'close': 488.3,
#   'volume': 1552,
#   'previousClose': 501.1,
#   'date': '2025-07-11'},
#  {'open': 482.05,
#   'high': 483.65,
#   'low': 477.4,
#   'close': 478.5,
#   'volume': 1696,
#   'previousClose': 488.3,
#   'date': '2025-07-14'}]

# %% [markdown]
# Income Statement
#
# https://www.morningstar.com/stocks/pinx/lvmhf/financials

# %%
stock.incomeStatement()
# Out:
# {'_meta': {'companyId': '0C00000VOS',
#   'statementType': 'income-statement',
#   'periodReport': 'Success',
#   'latestReport': 'Success'},
#  'columnDefs': ['2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2022',
#   '2023',
#   '2024',
#   'TTM'],
#  'filingIdList': [None,
#   None,
#   None,
#   None,
#   None,
#   '328683655',
#   '384266622',
#   '437916148',
#   '502488388',
#   '577784039',
#   None],
#  'rows': [{'parentId': '',
#    'label': 'IncomeStatement',
#    'dataPointId': 'IFIS000000',
#    'order': 385,
#    'subLevel': [{'parentId': 'IFIS000000385',
#      'label': 'Gross Profit',
#      'dataPointId': 'IFIS000590',
#      'order': 386,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       28779.0,
#       43860.0,
#       54196.0,
#       59277.0,
#       56764.0,
#       56764.0],
#      'subLevel': [{'parentId': 'IFIS000590386',
#        'label': 'Total Revenue',
#        'dataPointId': 'IFIS001170',
#        'order': 387,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         44650.0,
#         64215.0,
#         79184.0,
#         86153.0,
#         84682.0,
#         84682.0],
#        'subLevel': [{'parentId': 'IFIS001170387',
#          'label': 'Business Revenue',
#          'dataPointId': 'IFIS001839',
#          'order': 388,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           44421.0,
#           63920.0,
#           79184.0,
#           85538.0,
#           84046.0,
#           84046.0]},
#         {'parentId': 'IFIS001170387',
#          'label': 'Other Revenue',
#          'dataPointId': 'IFIS002228',
#          'order': 391,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           229.0,
#           295.0,
#           None,
#           615.0,
#           636.0,
#           636.0]}]},
#       {'parentId': 'IFIS000590386',
#        'label': 'Cost of Revenue',
#        'dataPointId': 'IFIS000200',
#        'order': 392,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -15871.0,
#         -20355.0,
#         -24988.0,
#         -26876.0,
#         -27918.0,
#         -27918.0],
#        'subLevel': [{'parentId': 'IFIS000200392',
#          'label': 'Cost of Goods and Services',
#          'dataPointId': 'IFIS003118',
#          'order': 393,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -15871.0,
#           -20355.0,
#           -24988.0,
#           -26876.0,
#           -27918.0,
#           -27918.0]}]}]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Operating Income/Expenses',
#      'dataPointId': 'IFIS001220',
#      'order': 405,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       -20468.0,
#       -26738.0,
#       -33181.0,
#       -36496.0,
#       -37187.0,
#       -37187.0],
#      'subLevel': [{'parentId': 'IFIS001220405',
#        'label': 'Selling, General and Administrative Expenses',
#        'dataPointId': 'IFIS001700',
#        'order': 406,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -20433.0,
#         -26722.0,
#         -33178.0,
#         -36482.0,
#         -37222.0,
#         -37222.0],
#        'subLevel': [{'parentId': 'IFIS001700406',
#          'label': 'General and Administrative Expenses',
#          'dataPointId': 'IFIS000040',
#          'order': 414,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -3641.0,
#           -4414.0,
#           -5027.0,
#           -5714.0,
#           -6220.0,
#           -6220.0]},
#         {'parentId': 'IFIS001700406',
#          'label': 'Selling and Marketing Expenses',
#          'dataPointId': 'IFIS001690',
#          'order': 428,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -16792.0,
#           -22308.0,
#           -28151.0,
#           -30768.0,
#           -31002.0,
#           -31002.0]}]},
#       {'parentId': 'IFIS001220405',
#        'label': 'Other Income/Expense, Operating',
#        'dataPointId': 'IFIS101208',
#        'order': 442,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -35.0,
#         -16.0,
#         -3.0,
#         -14.0,
#         35.0,
#         35.0],
#        'subLevel': [{'parentId': 'IFIS101208442',
#          'label': 'Other Income, Operating',
#          'dataPointId': 'IFIS200030',
#          'order': 444,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           None,
#           None,
#           None,
#           None,
#           35.0,
#           35.0]},
#         {'parentId': 'IFIS101208442',
#          'label': 'Other Expenses, Operating',
#          'dataPointId': 'IFIS003104',
#          'order': 445,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -35.0,
#           -16.0,
#           -3.0,
#           -14.0,
#           None,
#           None]}]},
#       {'parentId': 'IFIS001220405',
#        'label': 'Depreciation, Amortization and Depletion',
#        'dataPointId': 'IFIS001855',
#        'order': 432,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None,
#         None],
#        'subLevel': [{'parentId': 'IFIS001855432',
#          'label': 'Depreciation and Amortization',
#          'dataPointId': 'IFIS000250',
#          'order': 433,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           None,
#           None,
#           None,
#           None,
#           None,
#           None]}]}]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Total Operating Profit/Loss',
#      'dataPointId': 'IFIS001230',
#      'order': 446,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       8311.0,
#       17122.0,
#       21015.0,
#       22781.0,
#       19577.0,
#       19577.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Non-Operating Income/Expense, Total',
#      'dataPointId': 'IFIS001917',
#      'order': 447,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       -948.0,
#       87.0,
#       -900.0,
#       -1154.0,
#       -1465.0,
#       -1465.0],
#      'subLevel': [{'parentId': 'IFIS001917447',
#        'label': 'Total Net Finance Income/Expense',
#        'dataPointId': 'IFIS000930',
#        'order': 448,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -404.0,
#         -287.0,
#         -424.0,
#         -1016.0,
#         -1234.0,
#         -1234.0],
#        'subLevel': [{'parentId': 'IFIS000930448',
#          'label': 'Net Interest Income/Expense',
#          'dataPointId': 'IFIS002367',
#          'order': 449,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -366.0,
#           -238.0,
#           -382.0,
#           -973.0,
#           -1186.0,
#           -1186.0],
#          'subLevel': [{'parentId': 'IFIS002367449',
#            'label': 'Interest Expense Net of Capitalized Interest',
#            'dataPointId': 'IFIS000800',
#            'order': 450,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -366.0,
#             -242.0,
#             -382.0,
#             -973.0,
#             -1186.0,
#             -1186.0]},
#           {'parentId': 'IFIS002367449',
#            'label': 'Interest Income',
#            'dataPointId': 'IFIS000910',
#            'order': 456,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             None,
#             4.0,
#             None,
#             None,
#             None,
#             None]}]},
#         {'parentId': 'IFIS000930448',
#          'label': 'Other Finance Income/Expenses',
#          'dataPointId': 'IFIS101192',
#          'order': 457,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -38.0,
#           -49.0,
#           -42.0,
#           -43.0,
#           -48.0,
#           -48.0],
#          'subLevel': [{'parentId': 'IFIS101192457',
#            'label': 'Other Finance Expenses',
#            'dataPointId': 'IFIS001924',
#            'order': 459,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -38.0,
#             -49.0,
#             -42.0,
#             -43.0,
#             -48.0,
#             -48.0]}]}]},
#       {'parentId': 'IFIS001917447',
#        'label': 'Net Investment Income',
#        'dataPointId': 'IFIS001915',
#        'order': 461,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -246.0,
#         472.0,
#         -194.0,
#         92.0,
#         470.0,
#         470.0],
#        'subLevel': [{'parentId': 'IFIS001915461',
#          'label': 'Dividend and Investment Income',
#          'dataPointId': 'IFIS003106',
#          'order': 462,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           12.0,
#           10.0,
#           58.0,
#           65.0,
#           9.0,
#           9.0]},
#         {'parentId': 'IFIS001915461',
#          'label': 'Gain/Loss on Investments and Other Financial Instruments',
#          'dataPointId': 'IFIS001885',
#          'order': 463,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           46.0,
#           40.0,
#           64.0,
#           153.0,
#           231.0,
#           231.0]},
#         {'parentId': 'IFIS001915461',
#          'label': 'Fair Value or Unrealized Gain/Loss on Financial Assets',
#          'dataPointId': 'IFIS001871',
#          'order': 464,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -4.0,
#           618.0,
#           7.0,
#           265.0,
#           482.0,
#           482.0]},
#         {'parentId': 'IFIS001915461',
#          'label': 'Income from Associates, JointVentures and Other Participating Interests',
#          'dataPointId': 'IFIS101191',
#          'order': 465,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -42.0,
#           13.0,
#           37.0,
#           7.0,
#           28.0,
#           28.0]},
#         {'parentId': 'IFIS001915461',
#          'label': 'Gain/Loss on Derivatives',
#          'dataPointId': 'IFIS002217',
#          'order': 475,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -258.0,
#           -209.0,
#           -360.0,
#           -398.0,
#           -280.0,
#           -280.0],
#          'subLevel': [{'parentId': 'IFIS002217475',
#            'label': 'Realized Gain/Loss on Derivatives',
#            'dataPointId': 'IFIS003179',
#            'order': 476,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -262.0,
#             -206.0,
#             -358.0,
#             -399.0,
#             -282.0,
#             -282.0]},
#           {'parentId': 'IFIS002217475',
#            'label': 'Unrealized Gain/Loss on Derivatives',
#            'dataPointId': 'IFIS003180',
#            'order': 477,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             4.0,
#             -3.0,
#             -2.0,
#             1.0,
#             2.0,
#             2.0]}]}]},
#       {'parentId': 'IFIS001917447',
#        'label': 'Irregular Income/Expense',
#        'dataPointId': 'IFIS101189',
#        'order': 480,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -298.0,
#         -98.0,
#         -282.0,
#         -230.0,
#         -701.0,
#         -701.0],
#        'subLevel': [{'parentId': 'IFIS101189480',
#          'label': 'Fixed Asset Disposals',
#          'dataPointId': 'IFIS001877',
#          'order': 483,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -22.0,
#           9.0,
#           -210.0,
#           -102.0,
#           -199.0,
#           -199.0]},
#         {'parentId': 'IFIS101189480',
#          'label': 'Impairment/Write Off/Write Down of Capital Assets',
#          'dataPointId': 'IFIS001892',
#          'order': 487,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -235.0,
#           -89.0,
#           -50.0,
#           -105.0,
#           -422.0,
#           -422.0]},
#         {'parentId': 'IFIS101189480',
#          'label': 'Merger and Acquisition Income/Expense',
#          'dataPointId': 'IFIS002098',
#          'order': 505,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -35.0,
#           -18.0,
#           -25.0,
#           -14.0,
#           -10.0,
#           -10.0]},
#         {'parentId': 'IFIS101189480',
#          'label': 'Restructuring and Reorganization Income/Expense',
#          'dataPointId': 'IFIS000680',
#          'order': 506,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -6.0,
#           None,
#           3.0,
#           -9.0,
#           -70.0,
#           -70.0]},
#         {'parentId': 'IFIS101189480',
#          'label': 'Gain/Loss on Extinguishment of Debt',
#          'dataPointId': 'IFIS002288',
#          'order': 500,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           None,
#           None,
#           None,
#           None,
#           None,
#           None]}]}]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Pretax Income',
#      'dataPointId': 'IFIS001490',
#      'order': 518,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       7363.0,
#       17209.0,
#       20115.0,
#       21627.0,
#       18112.0,
#       18112.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Provision for Income Tax',
#      'dataPointId': 'IFIS001560',
#      'order': 519,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       -2409.0,
#       -4510.0,
#       -5362.0,
#       -5673.0,
#       -5157.0,
#       -5157.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Net Income before Extraordinary Items and Discontinued Operations',
#      'dataPointId': 'IFIS001110',
#      'order': 529,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4955.0,
#       12698.0,
#       14751.0,
#       15952.0,
#       12958.0,
#       12958.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Net Income after Extraordinary Items and Discontinued Operations',
#      'dataPointId': 'IFIS001977',
#      'order': 535,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4955.0,
#       12698.0,
#       14751.0,
#       15952.0,
#       12958.0,
#       12958.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Non-Controlling/Minority Interests',
#      'dataPointId': 'IFIS001040',
#      'order': 536,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       -253.0,
#       -662.0,
#       -667.0,
#       -778.0,
#       -408.0,
#       -408.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Net Income after Non-Controlling/Minority Interests',
#      'dataPointId': 'IFIS001090',
#      'order': 537,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4702.0,
#       12036.0,
#       14084.0,
#       15174.0,
#       12550.0,
#       12550.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Net Income Available to Common Stockholders',
#      'dataPointId': 'IFIS001100',
#      'order': 543,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4702.0,
#       12036.0,
#       14084.0,
#       15174.0,
#       12550.0,
#       12550.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Diluted Net Income Available to Common Stockholders',
#      'dataPointId': 'IFIS002230',
#      'order': 545,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4702.0,
#       12036.0,
#       14084.0,
#       15174.0,
#       12550.0,
#       12550.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Income Statement Supplemental Section',
#      'dataPointId': 'IFIS002156',
#      'order': 560,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       None,
#       None,
#       None,
#       None,
#       None,
#       None],
#      'subLevel': [{'parentId': 'IFIS002156560',
#        'label': 'Reported Normalized and Operating Income/Expense Supplemental Section',
#        'dataPointId': 'IFIS003147',
#        'order': 561,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None,
#         None],
#        'subLevel': [{'parentId': 'IFIS003147561',
#          'label': 'Total Revenue as Reported, Supplemental',
#          'dataPointId': 'IFIS003203',
#          'order': 562,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           44651.0,
#           64215.0,
#           79184.0,
#           86153.0,
#           84683.0,
#           84683.0]},
#         {'parentId': 'IFIS003147561',
#          'label': 'Reported Total Operating Profit/Loss',
#          'dataPointId': 'IFIS003138',
#          'order': 564,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           7972.0,
#           17155.0,
#           21001.0,
#           22560.0,
#           18907.0,
#           18907.0]},
#         {'parentId': 'IFIS003147561',
#          'label': 'Reported Normalized Operating Profit',
#          'dataPointId': 'IFIS003202',
#          'order': 572,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           8305.0,
#           17151.0,
#           21055.0,
#           22802.0,
#           19571.0,
#           19571.0]},
#         {'parentId': 'IFIS003147561',
#          'label': 'Reported Effective Tax Rate',
#          'dataPointId': 'IFIS002303',
#          'order': 566,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           0.327,
#           0.262,
#           0.267,
#           0.262,
#           None,
#           None]}]},
#       {'parentId': 'IFIS002156560',
#        'label': 'Operating Income/Expense, Supplemental Section',
#        'dataPointId': 'IFIS001905',
#        'order': 575,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None,
#         None],
#        'subLevel': [{'parentId': 'IFIS001905575',
#          'label': 'Depreciation, Amortization and Depletion, Supplemental',
#          'dataPointId': 'IFIS200330',
#          'order': 589,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -4759.0,
#           -5107.0,
#           -5658.0,
#           -6450.0,
#           -6549.0,
#           -6549.0],
#          'subLevel': [{'parentId': 'IFIS200330589',
#            'label': 'Depreciation and Amortization, Supplemental',
#            'dataPointId': 'IFIS002143',
#            'order': 590,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -4759.0,
#             -5107.0,
#             -5658.0,
#             -6450.0,
#             -6549.0,
#             -6549.0],
#            'subLevel': [{'parentId': 'IFIS002143590',
#              'label': 'Depreciation, Supplemental',
#              'dataPointId': 'IFIS002144',
#              'order': 591,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -4274.0,
#               -4578.0,
#               -5054.0,
#               -5730.0,
#               -5735.0,
#               -5735.0]},
#             {'parentId': 'IFIS002143590',
#              'label': 'Amortization, Supplemental',
#              'dataPointId': 'IFIS002137',
#              'order': 592,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -485.0,
#               -529.0,
#               -604.0,
#               -720.0,
#               -814.0,
#               -814.0]}]}]},
#         {'parentId': 'IFIS001905575',
#          'label': 'Research and Development Expenses, Supplemental',
#          'dataPointId': 'IFIS002179',
#          'order': 588,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           None,
#           None,
#           None,
#           None,
#           None,
#           None]}]},
#       {'parentId': 'IFIS002156560',
#        'label': 'Employee Costs and Professional Fees, Supplemental Section',
#        'dataPointId': 'IFIS003148',
#        'order': 658,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None,
#         None]}]}]},
#   {'parentId': '',
#    'label': 'EpsAndWaso',
#    'dataPointId': 'IFES000000',
#    'order': 935,
#    'subLevel': [{'parentId': 'IFES000000935',
#      'label': 'Basic EPS',
#      'dataPointId': 'IFIS000100',
#      'order': 936,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       9.33,
#       23.9,
#       28.05,
#       30.34,
#       25.13,
#       25.13],
#      'subLevel': [{'parentId': 'IFIS000100936',
#        'label': 'Basic EPS from Continuing Operations',
#        'dataPointId': 'IFIS000120',
#        'order': 937,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         9.33,
#         23.9,
#         28.05,
#         30.34,
#         25.13,
#         25.13]}]},
#     {'parentId': 'IFES000000935',
#      'label': 'Diluted EPS',
#      'dataPointId': 'IFIS000280',
#      'order': 939,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       9.32,
#       23.89,
#       28.03,
#       30.33,
#       25.12,
#       25.12],
#      'subLevel': [{'parentId': 'IFIS000280939',
#        'label': 'Diluted EPS from Continuing Operations',
#        'dataPointId': 'IFIS000300',
#        'order': 940,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         9.32,
#         23.89,
#         28.03,
#         30.33,
#         25.12,
#         25.12]}]},
#     {'parentId': 'IFES000000935',
#      'label': 'Basic Weighted Average Shares Outstanding',
#      'dataPointId': 'IFIS000150',
#      'order': 942,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       503.68,
#       503.63,
#       502.12,
#       500.06,
#       499.41,
#       499.41]},
#     {'parentId': 'IFES000000935',
#      'label': 'Diluted Weighted Average Shares Outstanding',
#      'dataPointId': 'IFIS000330',
#      'order': 943,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       504.21,
#       503.9,
#       502.48,
#       500.3,
#       499.68,
#       499.68]},
#     {'parentId': 'IFES000000935',
#      'label': 'Total Dividend Per Share',
#      'dataPointId': 'ORISZ00026',
#      'order': 950,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4.6,
#       7.0,
#       12.0,
#       12.5,
#       13.0,
#       13.0],
#      'subLevel': [{'parentId': 'ORISZ00026950',
#        'label': 'Regular Dividend Per Share Calc',
#        'dataPointId': 'ORISZ00021',
#        'order': 951,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         4.6,
#         7.0,
#         12.0,
#         12.5,
#         13.0,
#         13.0]}]}]},
#   {'parentId': '',
#    'label': 'WasoAndEpsData',
#    'dataPointId': 'SAL0001000',
#    'collapsed': False,
#    'subLevel': [{'parentId': 'SAL0001000',
#      'label': 'Basic EPS',
#      'dataPointId': 'SAL0001001',
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       9.33,
#       23.9,
#       28.05,
#       30.34,
#       25.13,
#       25.13]},
#     {'parentId': 'SAL0001000',
#      'label': 'Diluted EPS',
#      'dataPointId': 'SAL0001002',
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       9.32,
#       23.89,
#       28.03,
#       30.33,
#       25.12,
#       25.12]},
#     {'parentId': 'SAL0001000',
#      'label': 'Basic WASO',
#      'dataPointId': 'SAL0001003',
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       503.68,
#       503.63,
#       502.12,
#       500.06,
#       499.41,
#       499.41]},
#     {'parentId': 'SAL0001000',
#      'label': 'Diluted WASO',
#      'dataPointId': 'SAL0001004',
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       504.21,
#       503.9,
#       502.48,
#       500.3,
#       499.68,
#       499.68]}]}],
#  'footer': {'currency': 'EUR',
#   'currencySymbol': '€',
#   'orderOfMagnitude': 'Million',
#   'fiscalYearEndDate': '12-31'},
#  'userType': 'Free'}

# %% [markdown]
# You can download the balance sheet in .xls format by setting the argument export = True

# %%
stock.incomeStatement(period="quarterly", reportType="original", export=True)
# Out:
# {'status': 200,
#  'mesage': 'File downloaded',
#  'filename': 'incomeStatement-0P0000G5GV-20250715162453.xls',
#  'folder': '.'}

# %% [markdown]
# Main institutional buyers
#
# Ownership - Buying - Institutions
#
# https://www.morningstar.com/stocks/pinx/lvmhf/ownership

# %%
stock.institutionBuyers()
# Out:
# {'isRestricted': False,
#  'userType': 'Free',
#  'country': 'ITA',
#  'rows': [{'secId': None,
#    'name': 'Aviva Investors Global Services Limited',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 2.189846494651685,
#    'totalAssets': 1.89844,
#    'currentShares': 10884088,
#    'changeAmount': 2955347,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'First Eagle Investment Management, LLC',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.23847082605826564,
#    'totalAssets': 9.65761,
#    'currentShares': 1185260,
#    'changeAmount': 476696,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'MFS Investment Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.5249985756254214,
#    'totalAssets': 28.81473,
#    'currentShares': 2609375,
#    'changeAmount': 351895,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'State Street Investment Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.2940305890914278,
#    'totalAssets': 9.20799,
#    'currentShares': 1461406,
#    'changeAmount': 148028,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BlackRock Advisors (UK) Limited',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.5294460366128991,
#    'totalAssets': 67.28449,
#    'currentShares': 2631480,
#    'changeAmount': 110306,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Deka Investment GmbH',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.10596566220497032,
#    'totalAssets': 20.69772,
#    'currentShares': 526676,
#    'changeAmount': 99081,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BlackRock Fund Advisors',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 1.0045644409814765,
#    'totalAssets': 24.43821,
#    'currentShares': 4992938,
#    'changeAmount': 80386,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Harris Associates L.P.',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.014991192860301853,
#    'totalAssets': 1.80093,
#    'currentShares': 74510,
#    'changeAmount': 73715,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'DWS Investment S.A. (ETF)',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.2262239610816642,
#    'totalAssets': 36.06116,
#    'currentShares': 1124390,
#    'changeAmount': 64021,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Vanguard Group Inc',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 1.44536727857144,
#    'totalAssets': 5.518,
#    'currentShares': 7183839,
#    'changeAmount': 48481,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Mitsubishi UFJ Asset Management Co.,Ltd',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.058799840470047195,
#    'totalAssets': 5.42359,
#    'currentShares': 292250,
#    'changeAmount': 48341,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Asset Management One Co., Ltd.',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.014651773421899904,
#    'totalAssets': 5.78688,
#    'currentShares': 72823,
#    'changeAmount': 45991,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BlackRock Institutional Trust Co NA',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.3209185640458063,
#    'totalAssets': 6.90763,
#    'currentShares': 1595046,
#    'changeAmount': 44395,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'LBP AM',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.12769937090387687,
#    'totalAssets': 50.03701,
#    'currentShares': 634698,
#    'changeAmount': 40261,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'ETHENEA Independent Investors (Schweiz) AG',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.008047882356892687,
#    'totalAssets': 0.97841,
#    'currentShares': 40000,
#    'changeAmount': 40000,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Golub Group',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.007842460159733,
#    'totalAssets': 3.93802,
#    'currentShares': 38979,
#    'changeAmount': 38979,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Northern Trust Asset Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.05462057516211282,
#    'totalAssets': 5.14261,
#    'currentShares': 271478,
#    'changeAmount': 38903,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Russell Investments Group, LLC',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.06403176879026312,
#    'totalAssets': 1.17184,
#    'currentShares': 318254,
#    'changeAmount': 38895,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Janus Henderson Investors',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.01298525818284635,
#    'totalAssets': 1.67592,
#    'currentShares': 64540,
#    'changeAmount': 36045,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Amundi Asset Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.34821738339450414,
#    'totalAssets': None,
#    'currentShares': 1730728,
#    'changeAmount': 27633,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': None,
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 7.591719934627534,
#    'totalAssets': None,
#    'currentShares': 37732758,
#    'changeAmount': 4807399,
#    'changePercentage': None,
#    'date': None,
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None}],
#  'columnDefs': [{'columnId': 'name', 'dataType': 'string'},
#   {'columnId': 'totalSharesHeld', 'dataType': 'number'},
#   {'columnId': 'totalAssets', 'dataType': 'number'},
#   {'columnId': 'trend', 'dataType': 'number'},
#   {'columnId': 'currentShares', 'dataType': 'number'},
#   {'columnId': 'changeAmount', 'dataType': 'number'},
#   {'columnId': 'changePercentage', 'dataType': 'number'},
#   {'columnId': 'date', 'dataType': 'string'}]}

# %% [markdown]
# Most concentrated institutionals
#
# Ownership - Concentrated - Institutions
#
# https://www.morningstar.com/stocks/pinx/lvmhf/ownership

# %%
stock.institutionConcentratedOwners()
# Out:
# {'isRestricted': False,
#  'userType': 'Free',
#  'country': 'ITA',
#  'rows': [{'secId': None,
#    'name': 'BlackRock Advisors (UK) Limited',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.5294460366128991,
#    'totalAssets': 67.28449,
#    'currentShares': 2631480,
#    'changeAmount': 110306,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Credit Mutuel Asset Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.0945286153905312,
#    'totalAssets': 66.76867,
#    'currentShares': 469831,
#    'changeAmount': -111217,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Federal Finance Gestion',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.028332569837440702,
#    'totalAssets': 64.95174,
#    'currentShares': 140820,
#    'changeAmount': -15455,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BlackRock Investment Management (UK) Ltd.',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.23446056627982603,
#    'totalAssets': 54.55108,
#    'currentShares': 1165328,
#    'changeAmount': -394894,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Massachusetts Financial Services Company',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.5920140967995025,
#    'totalAssets': 51.04599,
#    'currentShares': 2942459,
#    'changeAmount': -162856,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'LBP AM',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.12769937090387687,
#    'totalAssets': 50.03701,
#    'currentShares': 634698,
#    'changeAmount': 40261,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BNP PARIBAS ASSET MANAGEMENT Europe',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.05852138374049871,
#    'totalAssets': 45.88731,
#    'currentShares': 290866,
#    'changeAmount': -614,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Groupama Asset Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.02388490765290396,
#    'totalAssets': 44.49968,
#    'currentShares': 118714,
#    'changeAmount': -1709,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'HSBC Global Asset Management (France)',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.0237806875763822,
#    'totalAssets': 44.30788,
#    'currentShares': 118196,
#    'changeAmount': -3533,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Rothschild & Co Asset Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.08811183759032173,
#    'totalAssets': 41.31007,
#    'currentShares': 437938,
#    'changeAmount': 5676,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Lazard Frères Gestion',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.025925649421553024,
#    'totalAssets': 40.94865,
#    'currentShares': 128857,
#    'changeAmount': -7113,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Morgan Stanley Investment Management, Inc.',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.2024414627317517,
#    'totalAssets': 40.75256,
#    'currentShares': 1006185,
#    'changeAmount': -213724,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'AXA Investment Managers Paris S.A.',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.06184536035095431,
#    'totalAssets': 39.58536,
#    'currentShares': 307387,
#    'changeAmount': -56918,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Apicil Asset Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.0036529338017935904,
#    'totalAssets': 36.93606,
#    'currentShares': 18156,
#    'changeAmount': -8853,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'DWS Investment S.A. (ETF)',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.2262239610816642,
#    'totalAssets': 36.06116,
#    'currentShares': 1124390,
#    'changeAmount': 64021,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Abeille Asset Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.12880635712206745,
#    'totalAssets': 35.21278,
#    'currentShares': 640200,
#    'changeAmount': -9027,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'State Street Global Advisors Ltd',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.04954638533609198,
#    'totalAssets': 35.1906,
#    'currentShares': 246258,
#    'changeAmount': -21015456,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Morgan Stanley Investment Management Ltd',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.1895765203901409,
#    'totalAssets': 32.58742,
#    'currentShares': 942243,
#    'changeAmount': -62536,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Allianz Global Investors GmbH',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.062163654098169416,
#    'totalAssets': 32.05127,
#    'currentShares': 308969,
#    'changeAmount': -226832,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Santander Private Banking Gestión SGIIC',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.002080176392197837,
#    'totalAssets': 31.66013,
#    'currentShares': 10339,
#    'changeAmount': -18386,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': None,
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 2.7530425331105675,
#    'totalAssets': None,
#    'currentShares': 13683314,
#    'changeAmount': -22088859,
#    'changePercentage': None,
#    'date': None,
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None}],
#  'columnDefs': [{'columnId': 'name', 'dataType': 'string'},
#   {'columnId': 'totalSharesHeld', 'dataType': 'number'},
#   {'columnId': 'totalAssets', 'dataType': 'number'},
#   {'columnId': 'trend', 'dataType': 'number'},
#   {'columnId': 'currentShares', 'dataType': 'number'},
#   {'columnId': 'changeAmount', 'dataType': 'number'},
#   {'columnId': 'changePercentage', 'dataType': 'number'},
#   {'columnId': 'date', 'dataType': 'string'}]}

# %% [markdown]
# Main institutional owners
#
# Ownership - Major - Institutions
#
# https://www.morningstar.com/stocks/pinx/lvmhf/ownership

# %%
stock.institutionOwnership()
# Out:
# {'isRestricted': False,
#  'userType': 'Free',
#  'country': 'ITA',
#  'rows': [{'secId': None,
#    'name': 'Aviva Investors Global Services Limited',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 2.189846494651685,
#    'totalAssets': 1.89844,
#    'currentShares': 10884088,
#    'changeAmount': 2955347,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Vanguard Group Inc',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 1.44536727857144,
#    'totalAssets': 5.518,
#    'currentShares': 7183839,
#    'changeAmount': 48481,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Capital Research and Management Company',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 1.2430569963221056,
#    'totalAssets': 20.56944,
#    'currentShares': 6178306,
#    'changeAmount': -1905156,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BlackRock Fund Advisors',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 1.0045644409814765,
#    'totalAssets': 24.43821,
#    'currentShares': 4992938,
#    'changeAmount': 80386,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Capital Group',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.7712533134992736,
#    'totalAssets': 5.37917,
#    'currentShares': 3833323,
#    'changeAmount': -599359,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Fidelity Management & Research Company LLC',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.6559257509455889,
#    'totalAssets': 25.67695,
#    'currentShares': 3260116,
#    'changeAmount': -1560560,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Massachusetts Financial Services Company',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.5920140967995025,
#    'totalAssets': 51.04599,
#    'currentShares': 2942459,
#    'changeAmount': -162856,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BlackRock Advisors (UK) Limited',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.5294460366128991,
#    'totalAssets': 67.28449,
#    'currentShares': 2631480,
#    'changeAmount': 110306,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'MFS Investment Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.5249985756254214,
#    'totalAssets': 28.81473,
#    'currentShares': 2609375,
#    'changeAmount': 351895,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Vanguard Equity Investment Group',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.36706854183023063,
#    'totalAssets': 0.3886,
#    'currentShares': 1824423,
#    'changeAmount': 14575,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Amundi Asset Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.34821738339450414,
#    'totalAssets': None,
#    'currentShares': 1730728,
#    'changeAmount': 27633,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Fundsmith LLP',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.3215450916872904,
#    'totalAssets': 3.74901,
#    'currentShares': 1598160,
#    'changeAmount': 0,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BlackRock Institutional Trust Co NA',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.3209185640458063,
#    'totalAssets': 6.90763,
#    'currentShares': 1595046,
#    'changeAmount': 44395,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'State Street Investment Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.2940305890914278,
#    'totalAssets': 9.20799,
#    'currentShares': 1461406,
#    'changeAmount': 148028,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Northern Trust Investments Inc',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.25582366999619766,
#    'totalAssets': 11.18486,
#    'currentShares': 1271508,
#    'changeAmount': -44977,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Capital Guardian Trust Company',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.24427697078464589,
#    'totalAssets': 3.81592,
#    'currentShares': 1214118,
#    'changeAmount': -99480,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'First Eagle Investment Management, LLC',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.23847082605826564,
#    'totalAssets': 9.65761,
#    'currentShares': 1185260,
#    'changeAmount': 476696,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BlackRock Investment Management (UK) Ltd.',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.23446056627982603,
#    'totalAssets': 54.55108,
#    'currentShares': 1165328,
#    'changeAmount': -394894,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'DWS Investment S.A. (ETF)',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.2262239610816642,
#    'totalAssets': 36.06116,
#    'currentShares': 1124390,
#    'changeAmount': 64021,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Morgan Stanley Investment Management, Inc.',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.2024414627317517,
#    'totalAssets': 40.75256,
#    'currentShares': 1006185,
#    'changeAmount': -213724,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': None,
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 12.009950610991003,
#    'totalAssets': None,
#    'currentShares': 59692476,
#    'changeAmount': -659243,
#    'changePercentage': None,
#    'date': None,
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None}],
#  'columnDefs': [{'columnId': 'name', 'dataType': 'string'},
#   {'columnId': 'totalSharesHeld', 'dataType': 'number'},
#   {'columnId': 'totalAssets', 'dataType': 'number'},
#   {'columnId': 'trend', 'dataType': 'number'},
#   {'columnId': 'currentShares', 'dataType': 'number'},
#   {'columnId': 'changeAmount', 'dataType': 'number'},
#   {'columnId': 'changePercentage', 'dataType': 'number'},
#   {'columnId': 'date', 'dataType': 'string'}]}

# %% [markdown]
# Main institutional sellers
#
# Ownership - Selling - Institutions
#
# https://www.morningstar.com/stocks/pinx/lvmhf/ownership

# %%
stock.institutionSellers()
# Out:
# {'isRestricted': False,
#  'userType': 'Free',
#  'country': 'ITA',
#  'rows': [{'secId': None,
#    'name': 'State Street Global Advisors Ltd',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.04954638533609198,
#    'totalAssets': 35.1906,
#    'currentShares': 246258,
#    'changeAmount': -21015456,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Capital Research and Management Company',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 1.2430569963221056,
#    'totalAssets': 20.56944,
#    'currentShares': 6178306,
#    'changeAmount': -1905156,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Fidelity Management & Research Company LLC',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.6559257509455889,
#    'totalAssets': 25.67695,
#    'currentShares': 3260116,
#    'changeAmount': -1560560,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'WCM Investment Management',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -1138390,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Union Investment Privatfonds GmbH',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.023933798538222084,
#    'totalAssets': 10.42442,
#    'currentShares': 118957,
#    'changeAmount': -645111,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Capital Group',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.7712533134992736,
#    'totalAssets': 5.37917,
#    'currentShares': 3833323,
#    'changeAmount': -599359,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'JPMorgan Asset Management Inc',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.18527331769391037,
#    'totalAssets': 14.14008,
#    'currentShares': 920855,
#    'changeAmount': -493338,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Janus Capital Management LLC',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.014446954815916985,
#    'totalAssets': 4.44709,
#    'currentShares': 71805,
#    'changeAmount': -422807,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'BlackRock Investment Management (UK) Ltd.',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.23446056627982603,
#    'totalAssets': 54.55108,
#    'currentShares': 1165328,
#    'changeAmount': -394894,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Janus Henderson Investors UK Limited',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.004108645140252639,
#    'totalAssets': 4.25241,
#    'currentShares': 20421,
#    'changeAmount': -327933,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Swedbank Robur Fonder AB',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.007444492377184657,
#    'totalAssets': 1.12705,
#    'currentShares': 37001,
#    'changeAmount': -319999,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Janus Henderson',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.030481756820848895,
#    'totalAssets': 2.83499,
#    'currentShares': 151502,
#    'changeAmount': -291614,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Jennison Associates LLC',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.0024767357953337245,
#    'totalAssets': 9.19379,
#    'currentShares': 12310,
#    'changeAmount': -278048,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'PGIM Investments LLC',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.00040500967961062446,
#    'totalAssets': 0.89662,
#    'currentShares': 2013,
#    'changeAmount': -269737,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Templeton Global Advisors Limited',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.004206628107947807,
#    'totalAssets': 1.88464,
#    'currentShares': 20908,
#    'changeAmount': -255697,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'WisdomTree Asset Management Inc',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.029837523838179635,
#    'totalAssets': 18.44231,
#    'currentShares': 148300,
#    'changeAmount': -251689,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'AustralianSuper Pty Ltd',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.012503190029668479,
#    'totalAssets': 0.2355,
#    'currentShares': 62144,
#    'changeAmount': -241244,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Harbor Capital Advisors Inc',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.03372988214009078,
#    'totalAssets': 10.07394,
#    'currentShares': 167646,
#    'changeAmount': -228322,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Allianz Global Investors GmbH',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.062163654098169416,
#    'totalAssets': 32.05127,
#    'currentShares': 308969,
#    'changeAmount': -226832,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': 'Morgan Stanley Investment Management, Inc.',
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.2024414627317517,
#    'totalAssets': 40.75256,
#    'currentShares': 1006185,
#    'changeAmount': -213724,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None},
#   {'secId': None,
#    'name': None,
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 3.567696064189974,
#    'totalAssets': None,
#    'currentShares': 17732347,
#    'changeAmount': -31079910,
#    'changePercentage': None,
#    'date': None,
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None}],
#  'columnDefs': [{'columnId': 'name', 'dataType': 'string'},
#   {'columnId': 'totalSharesHeld', 'dataType': 'number'},
#   {'columnId': 'totalAssets', 'dataType': 'number'},
#   {'columnId': 'trend', 'dataType': 'number'},
#   {'columnId': 'currentShares', 'dataType': 'number'},
#   {'columnId': 'changeAmount', 'dataType': 'number'},
#   {'columnId': 'changePercentage', 'dataType': 'number'},
#   {'columnId': 'date', 'dataType': 'string'}]}

# %% [markdown]
# Key executives
#
# https://www.morningstar.com/stocks/pinx/lvmhf/executive

# %%
stock.keyExecutives()
# Out:
# {'rows': [{'type': 'person',
#    'personId': 'PS00007YG6',
#    'name': 'Bernard Arnault',
#    'title': 'Chairman of the Board and Chief Executive Officer',
#    'holding': None,
#    'memberSince': None,
#    'age': '76',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'salary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'bonus',
#      'name': 'Bonus',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'otherAnnualIncome',
#      'name': 'Annual Other Income',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'restrictedStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'securitiesOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'LTIP-Payout',
#      'name': 'LTIP Payout',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'non-EquityCompensation',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'otherCompensation',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]},
#   {'type': 'total',
#    'personId': 'totalKeyCompensation',
#    'name': 'Compensation for all Key Executives',
#    'totalCompensation': [None, None, None, None, None],
#    'compensation': [{'nameId': 'totalSalary',
#      'name': 'Salary',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalBonus',
#      'name': 'Bonus',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalOtherAnnualIncome',
#      'name': 'Annual Other Income',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalStockAward',
#      'name': 'Restricted Stock Award',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalOptions',
#      'name': 'Securities Options',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalLTIP-Payout',
#      'name': 'LTIP Payout',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalNon-Equity',
#      'name': 'Non-Equity Compensation',
#      'datum': [None, None, None, None, None]},
#     {'nameId': 'totalOther',
#      'name': 'Other Compensation',
#      'datum': [None, None, None, None, None]}]}],
#  'datesDef': ['2021', '2022', '2023', '2024', '2025'],
#  'currency': '',
#  'template': ''}

# %% [markdown]
# Financial Summary
#
# https://www.morningstar.com/stocks/pinx/lvmhf/key-metrics

# %%
stock.keyMetricsSummary()
# Out:
# {'currency': 'EUR',
#  'asOfDate': '2024-12-31T06:00:00.000',
#  'reportType': 'A',
#  'expectedFiscalYearEnd': '2025-12-31T06:00:00.000',
#  'template': 'GENERAL',
#  'incomeStatementList': {'dataList': [{'fiscalPeriodDate': '2015-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2015-12',
#     'revenue': 35.66,
#     'revenueGrowthPer': 16.4045,
#     'grossProfit': 23.11,
#     'grossProfitMarginPer': 64.802,
#     'operIncome': 6.5,
#     'operatingMarginPer': 18.2144,
#     'ebit': 6.08,
#     'ebitMarginPer': 17.0508,
#     'ebitda': 8.16,
#     'ebitdaMarginPer': 22.8858,
#     'netIncome': 3.57,
#     'netIncomeMarginPer': 11.218599999999999,
#     'basicEPS': 7.11,
#     'dilutedEPS': 7.08,
#     'normalizedEPS': None,
#     'dividentPerShare': 3.3},
#    {'fiscalPeriodDate': '2016-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2016-12',
#     'revenue': 37.6,
#     'revenueGrowthPer': 5.4284,
#     'grossProfit': 24.56,
#     'grossProfitMarginPer': 65.3218,
#     'operIncome': 6.86,
#     'operatingMarginPer': 18.25,
#     'ebit': 6.56,
#     'ebitMarginPer': 17.4574,
#     'ebitda': 8.71,
#     'ebitdaMarginPer': 23.1569,
#     'netIncome': 3.98,
#     'netIncomeMarginPer': 11.6037,
#     'basicEPS': 7.92,
#     'dilutedEPS': 7.89,
#     'normalizedEPS': None,
#     'dividentPerShare': 3.6},
#    {'fiscalPeriodDate': '2017-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2017-12',
#     'revenue': 42.64,
#     'revenueGrowthPer': 13.3936,
#     'grossProfit': 27.85,
#     'grossProfitMarginPer': 65.3274,
#     'operIncome': 8.3,
#     'operatingMarginPer': 19.4648,
#     'ebit': 8.04,
#     'ebitMarginPer': 18.8667,
#     'ebitda': 10.42,
#     'ebitdaMarginPer': 24.4371,
#     'netIncome': 5.13,
#     'netIncomeMarginPer': 13.172,
#     'basicEPS': 10.21,
#     'dilutedEPS': 10.18,
#     'normalizedEPS': None,
#     'dividentPerShare': 4.2},
#    {'fiscalPeriodDate': '2018-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2018-12',
#     'revenue': 46.83,
#     'revenueGrowthPer': 9.8248,
#     'grossProfit': 31.2,
#     'grossProfitMarginPer': 66.6318,
#     'operIncome': 9.99,
#     'operatingMarginPer': 21.323600000000003,
#     'ebit': 9.65,
#     'ebitMarginPer': 20.6018,
#     'ebitda': 11.95,
#     'ebitdaMarginPer': 25.517899999999997,
#     'netIncome': 6.35,
#     'netIncomeMarginPer': 14.9276,
#     'basicEPS': 12.64,
#     'dilutedEPS': 12.61,
#     'normalizedEPS': 12.625397,
#     'dividentPerShare': 5.4},
#    {'fiscalPeriodDate': '2019-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2019-12',
#     'revenue': 53.67,
#     'revenueGrowthPer': 14.6158,
#     'grossProfit': 35.55,
#     'grossProfitMarginPer': 66.2325,
#     'operIncome': 11.37,
#     'operatingMarginPer': 21.1887,
#     'ebit': 11.16,
#     'ebitMarginPer': 20.7919,
#     'ebitda': 16.27,
#     'ebitdaMarginPer': 30.3093,
#     'netIncome': 7.17,
#     'netIncomeMarginPer': 14.499699999999999,
#     'basicEPS': 14.25,
#     'dilutedEPS': 14.23,
#     'normalizedEPS': 14.250559,
#     'dividentPerShare': 6.2},
#    {'fiscalPeriodDate': '2020-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2020-12',
#     'revenue': 44.65,
#     'revenueGrowthPer': -16.8064,
#     'grossProfit': 28.78,
#     'grossProfitMarginPer': 64.4546,
#     'operIncome': 8.31,
#     'operatingMarginPer': 18.6137,
#     'ebit': 7.73,
#     'ebitMarginPer': 17.310200000000002,
#     'ebitda': 12.49,
#     'ebitdaMarginPer': 27.9686,
#     'netIncome': 4.7,
#     'netIncomeMarginPer': 11.0974,
#     'basicEPS': 9.33,
#     'dilutedEPS': 9.32,
#     'normalizedEPS': 10.1346,
#     'dividentPerShare': 9.2},
#    {'fiscalPeriodDate': '2021-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2021-12',
#     'revenue': 64.22,
#     'revenueGrowthPer': 43.8154,
#     'grossProfit': 43.86,
#     'grossProfitMarginPer': 68.3018,
#     'operIncome': 17.12,
#     'operatingMarginPer': 26.6636,
#     'ebit': 17.45,
#     'ebitMarginPer': 27.169700000000002,
#     'ebitda': 22.55,
#     'ebitdaMarginPer': 35.1226,
#     'netIncome': 12.04,
#     'netIncomeMarginPer': 19.7742,
#     'basicEPS': 23.9,
#     'dilutedEPS': 23.89,
#     'normalizedEPS': 23.728357,
#     'dividentPerShare': 7.0},
#    {'fiscalPeriodDate': '2022-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2022-12',
#     'revenue': 79.18,
#     'revenueGrowthPer': 23.3108,
#     'grossProfit': 54.2,
#     'grossProfitMarginPer': 68.4431,
#     'operIncome': 21.02,
#     'operatingMarginPer': 26.5395,
#     'ebit': 20.5,
#     'ebitMarginPer': 25.8853,
#     'ebitda': 26.16,
#     'ebitdaMarginPer': 33.0307,
#     'netIncome': 14.08,
#     'netIncomeMarginPer': 18.628800000000002,
#     'basicEPS': 28.05,
#     'dilutedEPS': 28.03,
#     'normalizedEPS': 28.709744,
#     'dividentPerShare': 12.0},
#    {'fiscalPeriodDate': '2023-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2023-12',
#     'revenue': 86.15,
#     'revenueGrowthPer': 8.8024,
#     'grossProfit': 59.28,
#     'grossProfitMarginPer': 68.8043,
#     'operIncome': 22.78,
#     'operatingMarginPer': 26.442500000000003,
#     'ebit': 22.6,
#     'ebitMarginPer': 26.2324,
#     'ebitda': 29.05,
#     'ebitdaMarginPer': 33.719100000000005,
#     'netIncome': 15.17,
#     'netIncomeMarginPer': 18.5159,
#     'basicEPS': 30.34,
#     'dilutedEPS': 30.33,
#     'normalizedEPS': 30.416745,
#     'dividentPerShare': 12.5},
#    {'fiscalPeriodDate': '2024-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2024-12',
#     'revenue': 84.68,
#     'revenueGrowthPer': -1.7073999999999998,
#     'grossProfit': 56.76,
#     'grossProfitMarginPer': 67.032,
#     'operIncome': 19.58,
#     'operatingMarginPer': 23.1183,
#     'ebit': 19.3,
#     'ebitMarginPer': 22.788800000000002,
#     'ebitda': 25.85,
#     'ebitdaMarginPer': 30.5224,
#     'netIncome': 12.55,
#     'netIncomeMarginPer': 15.302,
#     'basicEPS': 25.13,
#     'dilutedEPS': 25.12,
#     'normalizedEPS': 25.36971,
#     'dividentPerShare': 13.0},
#    {'fiscalPeriodDate': '2024-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': 'TTM',
#     'revenue': 84.68,
#     'revenueGrowthPer': -1.7073999999999998,
#     'grossProfit': 56.76,
#     'grossProfitMarginPer': 67.032,
#     'operIncome': 19.58,
#     'operatingMarginPer': 23.1183,
#     'ebit': 19.3,
#     'ebitMarginPer': 22.788800000000002,
#     'ebitda': 25.85,
#     'ebitdaMarginPer': 30.5224,
#     'netIncome': 12.55,
#     'netIncomeMarginPer': 15.302,
#     'basicEPS': 25.13,
#     'dilutedEPS': 25.12,
#     'normalizedEPS': 25.36971,
#     'dividentPerShare': 13.0}],
#   'footer': {'currency': 'EUR',
#    'orderOfMagnitude': 'Bil',
#    'fiscalYearEndDate': '2024-12-31T06:00:00.000'}},
#  'balanceSheetList': {'dataList': [{'fiscalPeriodDate': '2015-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2015-12',
#     'totalAssets': 57.6,
#     'totalLiabilities': 31.8,
#     'totalDebt': 8.28,
#     'totalEquity': 25.8,
#     'cashAndCashEquivalents': 3.59,
#     'workingCapital': 6.25,
#     'sharesOutstanding': 0.5,
#     'sharesOutstandingConverted': 502.8,
#     'bookValuePerShare': 48.406999,
#     'debtToEquity': 0.320943},
#    {'fiscalPeriodDate': '2016-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2016-12',
#     'totalAssets': 59.62,
#     'totalLiabilities': 31.72,
#     'totalDebt': 7.38,
#     'totalEquity': 27.9,
#     'cashAndCashEquivalents': 3.54,
#     'workingCapital': 6.59,
#     'sharesOutstanding': 0.5,
#     'sharesOutstandingConverted': 502.03,
#     'bookValuePerShare': 52.572664,
#     'debtToEquity': 0.264452},
#    {'fiscalPeriodDate': '2017-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2017-12',
#     'totalAssets': 68.55,
#     'totalLiabilities': 38.29,
#     'totalDebt': 11.58,
#     'totalEquity': 30.26,
#     'cashAndCashEquivalents': 3.74,
#     'workingCapital': 6.08,
#     'sharesOutstanding': None,
#     'sharesOutstandingConverted': None,
#     'bookValuePerShare': 57.387051,
#     'debtToEquity': 0.382551},
#    {'fiscalPeriodDate': '2018-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2018-12',
#     'totalAssets': 74.3,
#     'totalLiabilities': 40.34,
#     'totalDebt': 11.03,
#     'totalEquity': 33.96,
#     'cashAndCashEquivalents': 4.61,
#     'workingCapital': 6.72,
#     'sharesOutstanding': 0.5,
#     'sharesOutstandingConverted': 503.25,
#     'bookValuePerShare': 64.214316,
#     'debtToEquity': 0.324881},
#    {'fiscalPeriodDate': '2019-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2019-12',
#     'totalAssets': 96.51,
#     'totalLiabilities': 58.14,
#     'totalDebt': 25.26,
#     'totalEquity': 38.37,
#     'cashAndCashEquivalents': 5.67,
#     'workingCapital': 3.89,
#     'sharesOutstanding': None,
#     'sharesOutstandingConverted': None,
#     'bookValuePerShare': 72.641373,
#     'debtToEquity': 0.658334},
#    {'fiscalPeriodDate': '2020-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2020-12',
#     'totalAssets': 108.67,
#     'totalLiabilities': 69.84,
#     'totalDebt': 37.53,
#     'totalEquity': 38.83,
#     'cashAndCashEquivalents': 19.96,
#     'workingCapital': 14.66,
#     'sharesOutstanding': None,
#     'sharesOutstandingConverted': None,
#     'bookValuePerShare': 74.245496,
#     'debtToEquity': 0.966571},
#    {'fiscalPeriodDate': '2021-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2021-12',
#     'totalAssets': 125.31,
#     'totalLiabilities': 76.4,
#     'totalDebt': 36.29,
#     'totalEquity': 48.91,
#     'cashAndCashEquivalents': 8.02,
#     'workingCapital': 6.31,
#     'sharesOutstanding': None,
#     'sharesOutstandingConverted': None,
#     'bookValuePerShare': 93.582041,
#     'debtToEquity': 0.742072},
#    {'fiscalPeriodDate': '2022-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2022-12',
#     'totalAssets': 134.65,
#     'totalLiabilities': 78.04,
#     'totalDebt': 36.75,
#     'totalEquity': 56.6,
#     'cashAndCashEquivalents': 7.3,
#     'workingCapital': 8.2,
#     'sharesOutstanding': 0.5,
#     'sharesOutstandingConverted': 502.07,
#     'bookValuePerShare': 109.985105,
#     'debtToEquity': 0.649265},
#    {'fiscalPeriodDate': '2023-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2023-12',
#     'totalAssets': 143.69,
#     'totalLiabilities': 80.99,
#     'totalDebt': 38.88,
#     'totalEquity': 62.7,
#     'cashAndCashEquivalents': 7.77,
#     'workingCapital': 10.57,
#     'sharesOutstanding': None,
#     'sharesOutstandingConverted': None,
#     'bookValuePerShare': 122.152902,
#     'debtToEquity': 0.620022},
#    {'fiscalPeriodDate': '2024-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2024-12',
#     'totalAssets': 149.19,
#     'totalLiabilities': 79.9,
#     'totalDebt': 41.2,
#     'totalEquity': 69.29,
#     'cashAndCashEquivalents': 9.63,
#     'workingCapital': 13.78,
#     'sharesOutstanding': None,
#     'sharesOutstandingConverted': None,
#     'bookValuePerShare': 135.203595,
#     'debtToEquity': 0.594671},
#    {'fiscalPeriodDate': '2024-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': 'Last Quarter',
#     'totalAssets': 149.19,
#     'totalLiabilities': 79.9,
#     'totalDebt': 41.2,
#     'totalEquity': 69.29,
#     'cashAndCashEquivalents': 9.63,
#     'workingCapital': 13.78,
#     'sharesOutstanding': None,
#     'sharesOutstandingConverted': None,
#     'bookValuePerShare': 135.203595,
#     'debtToEquity': 0.594671}],
#   'footer': {'sharesOutstandingUnit': 'Mil',
#    'currency': 'EUR',
#    'orderOfMagnitude': 'Bil',
#    'fiscalYearEndDate': '2024-12-31T06:00:00.000'}},
#  'cashFlowList': {'dataList': [{'fiscalPeriodDate': '2015-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2015-12',
#     'cashFromOperActivities': 5.63,
#     'cashFromInvActivities': -2.47,
#     'cashFromFinActivities': -3.53,
#     'capitalExpenditures': 2.06,
#     'freeCashFlow': 4.01,
#     'changeInCash': -0.36},
#    {'fiscalPeriodDate': '2016-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2016-12',
#     'cashFromOperActivities': 6.24,
#     'cashFromInvActivities': -2.35,
#     'cashFromFinActivities': -3.9,
#     'capitalExpenditures': 2.59,
#     'freeCashFlow': 4.16,
#     'changeInCash': -0.01},
#    {'fiscalPeriodDate': '2017-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2017-12',
#     'cashFromOperActivities': 7.03,
#     'cashFromInvActivities': -8.61,
#     'cashFromFinActivities': 1.97,
#     'capitalExpenditures': 2.35,
#     'freeCashFlow': 5.2,
#     'changeInCash': 0.4},
#    {'fiscalPeriodDate': '2018-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2018-12',
#     'cashFromOperActivities': 8.49,
#     'cashFromInvActivities': -3.44,
#     'cashFromFinActivities': -4.32,
#     'capitalExpenditures': 3.14,
#     'freeCashFlow': 6.44,
#     'changeInCash': 0.73},
#    {'fiscalPeriodDate': '2019-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2019-12',
#     'cashFromOperActivities': 11.65,
#     'cashFromInvActivities': -5.87,
#     'cashFromFinActivities': -4.73,
#     'capitalExpenditures': 3.39,
#     'freeCashFlow': 9.41,
#     'changeInCash': 1.04},
#    {'fiscalPeriodDate': '2020-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2020-12',
#     'cashFromOperActivities': 10.9,
#     'cashFromInvActivities': -2.94,
#     'cashFromFinActivities': 7.4,
#     'capitalExpenditures': 2.47,
#     'freeCashFlow': 8.8,
#     'changeInCash': 15.36},
#    {'fiscalPeriodDate': '2021-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2021-12',
#     'cashFromOperActivities': 18.65,
#     'cashFromInvActivities': -15.98,
#     'cashFromFinActivities': -15.16,
#     'capitalExpenditures': 3.26,
#     'freeCashFlow': 14.97,
#     'changeInCash': -12.49},
#    {'fiscalPeriodDate': '2022-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2022-12',
#     'cashFromOperActivities': 17.84,
#     'cashFromInvActivities': -5.92,
#     'cashFromFinActivities': -12.69,
#     'capitalExpenditures': 5.08,
#     'freeCashFlow': 15.77,
#     'changeInCash': -0.77},
#    {'fiscalPeriodDate': '2023-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2023-12',
#     'cashFromOperActivities': 18.4,
#     'cashFromInvActivities': -8.31,
#     'cashFromFinActivities': -9.4,
#     'capitalExpenditures': 7.81,
#     'freeCashFlow': 15.17,
#     'changeInCash': 0.7},
#    {'fiscalPeriodDate': '2024-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': '2024-12',
#     'cashFromOperActivities': 18.93,
#     'cashFromInvActivities': -6.54,
#     'cashFromFinActivities': -10.72,
#     'capitalExpenditures': 5.55,
#     'freeCashFlow': 15.3,
#     'changeInCash': 1.67},
#    {'fiscalPeriodDate': '2024-12-31T06:00:00.000',
#     'fiscalPeriodYearMonth': 'TTM',
#     'cashFromOperActivities': 18.93,
#     'cashFromInvActivities': -6.54,
#     'cashFromFinActivities': -10.72,
#     'capitalExpenditures': 5.55,
#     'freeCashFlow': 15.3,
#     'changeInCash': 1.67}],
#   'footer': {'currency': 'EUR',
#    'orderOfMagnitude': 'Bil',
#    'fiscalYearEndDate': '2024-12-31T06:00:00.000'}},
#  'companyId': '0C00000VOS'}

# %% [markdown]
# Key ratio

# %%
stock.keyRatio()
# Out:
# {'valuationRatio': {},
#  'growthRatio': {},
#  'financialHealth': {},
#  'efficiencyRatio': {},
#  'profitabilityRatio': {},
#  'keyStatsQuoteJson': {'revenue3YearGrowth': {'stockValue': '9.6600',
#    'indAvg': '3.6200'},
#   'netIncome3YearGrowth': {'stockValue': '1.4000', 'indAvg': '12.5500'},
#   'operatingMarginTTM': {'stockValue': '23.1200', 'indAvg': '16.1700'},
#   'netMarginTTM': {'stockValue': '14.8200', 'indAvg': '12.5100'},
#   'roaTTM': {'stockValue': '8.5700', 'indAvg': '8.3300'},
#   'roeTTM': {'stockValue': '19.5300', 'indAvg': '39.2800'},
#   'debitToEquity': {'stockValue': '0.3992', 'indAvg': '0.4813'},
#   'freeCashFlow': {'cashFlowTTM': '13373000000',
#    'date': '2024-12-31T06:00:00.000'}}}

# %% [markdown]
# Main mutual funds buyers
#
# Ownership - Buying - Funds
#
# https://www.morningstar.com/stocks/pinx/lvmhf/ownership

# %%
stock.mutualFundBuyers()
# Out:
# {'isRestricted': False,
#  'userType': 'Free',
#  'country': 'ITA',
#  'rows': [{'secId': 'FOUSA08ZYU',
#    'name': 'MFS Growth Equity',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.10311007234768586,
#    'totalAssets': 0.76556,
#    'currentShares': 512483,
#    'changeAmount': 354459,
#    'changePercentage': 224.30706728091934,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00F8G',
#    'name': 'First Eagle Global A',
#    'securityType': 'FO',
#    'ticker': 'SGENX',
#    'totalSharesHeld': 0.1638943194098839,
#    'totalAssets': 0.77705,
#    'currentShares': 814596,
#    'changeAmount': 344131,
#    'changePercentage': 73.14699286875751,
#    'date': '2025-04-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'SAUSA0038A',
#    'name': 'SSgA MSCI EAFE Index Strategy',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.032468980171824625,
#    'totalAssets': 0.97864,
#    'currentShares': 161379,
#    'changeAmount': 153234,
#    'changePercentage': 1881.3259668508288,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00E5U',
#    'name': 'American Funds New Perspective A',
#    'securityType': 'FO',
#    'ticker': 'ANWPX',
#    'totalSharesHeld': 0.13075736500243715,
#    'totalAssets': 0.29516,
#    'currentShares': 649897,
#    'changeAmount': 117850,
#    'changePercentage': 22.150298751802,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000013FOQ',
#    'name': 'Capital Group New Perspective Comp',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.13075736500243715,
#    'totalAssets': 0.29516,
#    'currentShares': 649897,
#    'changeAmount': 117850,
#    'changePercentage': 22.150298751802,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00EHO',
#    'name': 'First Eagle Overseas A',
#    'securityType': 'FO',
#    'ticker': 'SGOVX',
#    'totalSharesHeld': 0.04360966371847117,
#    'totalAssets': 0.91726,
#    'currentShares': 216751,
#    'changeAmount': 115270,
#    'changePercentage': 113.58776519742612,
#    'date': '2025-04-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000MCMC',
#    'name': 'iShares Dev Wld Idx (IE) Flex Acc USD',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0189754982181405,
#    'totalAssets': 0.20691,
#    'currentShares': 94313,
#    'changeAmount': 94313,
#    'changePercentage': None,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'IRL'},
#   {'secId': 'F000013PKR',
#    'name': 'Capital Group Investment Co of Amer Comp',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.01767133888220604,
#    'totalAssets': 0.03717,
#    'currentShares': 87831,
#    'changeAmount': 87831,
#    'changePercentage': None,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00D77',
#    'name': 'American Funds Invmt Co of Amer A',
#    'securityType': 'FO',
#    'ticker': 'AIVSX',
#    'totalSharesHeld': 0.01767133888220604,
#    'totalAssets': 0.03717,
#    'currentShares': 87831,
#    'changeAmount': 87831,
#    'changePercentage': None,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000QF77',
#    'name': 'iShares Currency Hedged MSCI EAFE ETF',
#    'securityType': 'FE',
#    'ticker': 'HEFA',
#    'totalSharesHeld': 0.01687600690828612,
#    'totalAssets': 1.05088,
#    'currentShares': 83878,
#    'changeAmount': 83878,
#    'changePercentage': None,
#    'date': '2024-10-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000000EM3',
#    'name': 'Deka-GlobalChampions CF',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.03380110589894928,
#    'totalAssets': 1.00409,
#    'currentShares': 168000,
#    'changeAmount': 63000,
#    'changePercentage': 60.0,
#    'date': '2024-11-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'DEU'},
#   {'secId': 'FOUSA06YLG',
#    'name': 'American Funds Intl Gr and Inc F2',
#    'securityType': 'FO',
#    'ticker': 'IGFFX',
#    'totalSharesHeld': 0.03712387532705135,
#    'totalAssets': 0.7484,
#    'currentShares': 184515,
#    'changeAmount': 60981,
#    'changePercentage': 49.363737918305894,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000013PKT',
#    'name': 'Capital Group Intl Growth & Inc Comp',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.03712387532705135,
#    'totalAssets': 0.7484,
#    'currentShares': 184515,
#    'changeAmount': 60981,
#    'changePercentage': 49.363737918305894,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000002N40',
#    'name': 'AMOne Foreign Equity Passive Fund MF',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.009969917860777583,
#    'totalAssets': 0.26808,
#    'currentShares': 49553,
#    'changeAmount': 49553,
#    'changePercentage': None,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'JPN'},
#   {'secId': 'F00000J8T2',
#    'name': 'Deka-DividendenStrategie CF A (A)',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.025149632365289647,
#    'totalAssets': 0.38985,
#    'currentShares': 125000,
#    'changeAmount': 45000,
#    'changePercentage': 56.25,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'DEU'},
#   {'secId': 'F00000LL3B',
#    'name': 'American Funds Global Insight F-3',
#    'securityType': 'FO',
#    'ticker': 'AGVHX',
#    'totalSharesHeld': 0.027837423875432882,
#    'totalAssets': 0.56281,
#    'currentShares': 138359,
#    'changeAmount': 42109,
#    'changePercentage': 43.74961038961039,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA0604Z',
#    'name': 'Capital Group Global Insight Composite',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.027837423875432882,
#    'totalAssets': 0.56281,
#    'currentShares': 138359,
#    'changeAmount': 42109,
#    'changePercentage': 43.74961038961039,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F0GBR05Z9V',
#    'name': 'Ethna-AKTIV A',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.008047882356892687,
#    'totalAssets': 0.97841,
#    'currentShares': 40000,
#    'changeAmount': 40000,
#    'changePercentage': None,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'LUX'},
#   {'secId': 'F00001E8JL',
#    'name': 'Russell Personalized DI Core Equity',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.008664752539548511,
#    'totalAssets': 0.2807,
#    'currentShares': 43066,
#    'changeAmount': 38785,
#    'changePercentage': 905.9799112356926,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000VB2B',
#    'name': 'EAFE Equity Index Fund T',
#    'securityType': 'CZ',
#    'ticker': None,
#    'totalSharesHeld': 0.25950577737153496,
#    'totalAssets': 0.75991,
#    'currentShares': 1289809,
#    'changeAmount': 37704,
#    'changePercentage': 3.0112490565887047,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': None,
#    'name': None,
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 1.1508536153415396,
#    'totalAssets': None,
#    'currentShares': 5720032,
#    'changeAmount': 2036869,
#    'changePercentage': None,
#    'date': None,
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None}],
#  'columnDefs': [{'columnId': 'name', 'dataType': 'string'},
#   {'columnId': 'starRating', 'dataType': 'string'},
#   {'columnId': 'totalSharesHeld', 'dataType': 'number'},
#   {'columnId': 'totalAssets', 'dataType': 'number'},
#   {'columnId': 'trend', 'dataType': 'number'},
#   {'columnId': 'currentShares', 'dataType': 'number'},
#   {'columnId': 'changeAmount', 'dataType': 'number'},
#   {'columnId': 'changePercentage', 'dataType': 'number'},
#   {'columnId': 'date', 'dataType': 'string'}]}

# %% [markdown]
# Most concentrated mutual funds
#
# Ownership - Concentrated - Funds
#
# https://www.morningstar.com/stocks/pinx/lvmhf/ownership

# %%
stock.mutualFundConcentratedOwners()
# Out:
# {'isRestricted': False,
#  'userType': 'Free',
#  'country': 'ITA',
#  'rows': [{'secId': 'F000018SSE',
#    'name': 'Xtrackers MSCI Eur CDisc ESG Scr ETF 1C',
#    'securityType': 'FE',
#    'ticker': 'XZEC',
#    'totalSharesHeld': 0.000444041909041554,
#    'totalAssets': 16.04656,
#    'currentShares': 2207,
#    'changeAmount': 14,
#    'changePercentage': 0.6383948928408573,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'IRL'},
#   {'secId': 'F000016287',
#    'name': 'iShares MSCI Eurp Cnsmr Dscrtnry Sec ETF',
#    'securityType': 'FE',
#    'ticker': 'ESIC',
#    'totalSharesHeld': 0.022767056793531568,
#    'totalAssets': 14.09742,
#    'currentShares': 113158,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'IRL'},
#   {'secId': 'F00000V3AP',
#    'name': 'SPDR® MSCI Europe Consumer Discret ETF',
#    'securityType': 'FE',
#    'ticker': 'STR',
#    'totalSharesHeld': 0.0062250370030564935,
#    'totalAssets': 14.07022,
#    'currentShares': 30940,
#    'changeAmount': -7920,
#    'changePercentage': -20.38085434894493,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'IRL'},
#   {'secId': 'F0GBR04GC9',
#    'name': 'iShares STOXX Eurp 600 P & H Goods (DE)',
#    'securityType': 'FE',
#    'ticker': 'EXH7',
#    'totalSharesHeld': 0.00990794916662951,
#    'totalAssets': 13.60325,
#    'currentShares': 49245,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'DEU'},
#   {'secId': 'F00001EVLC',
#    'name': 'Nebraska Investment SICAV',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 9.154466180965431e-05,
#    'totalAssets': 10.96505,
#    'currentShares': 455,
#    'changeAmount': 55,
#    'changePercentage': 13.75,
#    'date': '2024-12-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'ESP'},
#   {'secId': 'F00001RNA2',
#    'name': 'Halley SICAV Stratum A EUR Inc',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0001289673147692053,
#    'totalAssets': 9.79851,
#    'currentShares': 641,
#    'changeAmount': 641,
#    'changePercentage': None,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'LUX'},
#   {'secId': 'F000015JXQ',
#    'name': 'Performance Monde Avenir Juin 2025 RC',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0027268237395741647,
#    'totalAssets': 9.2468,
#    'currentShares': 13553,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2025-04-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'FRA'},
#   {'secId': 'F00001MP52',
#    'name': 'MEGA 10 EURO-A',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 2.0119705892231716e-05,
#    'totalAssets': 9.07669,
#    'currentShares': 100,
#    'changeAmount': 1,
#    'changePercentage': 1.0101010101010102,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'THA'},
#   {'secId': 'F00001GEKU',
#    'name': 'KraneShares Global Luxury Index ETF',
#    'securityType': 'FE',
#    'ticker': 'KLXY',
#    'totalSharesHeld': 8.349677945276163e-05,
#    'totalAssets': 8.96986,
#    'currentShares': 415,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00001MP53',
#    'name': 'MEGA 10 EURO RMF',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 3.0179558838347576e-06,
#    'totalAssets': 8.82574,
#    'currentShares': 15,
#    'changeAmount': 6,
#    'changePercentage': 66.66666666666667,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'THA'},
#   {'secId': 'F0GBR04RCD',
#    'name': 'Stratégie France ISR',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0029938122367640795,
#    'totalAssets': 8.76877,
#    'currentShares': 14880,
#    'changeAmount': -245,
#    'changePercentage': -1.6198347107438018,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'FRA'},
#   {'secId': 'F000014ZQE',
#    'name': 'Huaan France CAC40 ETF (QDII)',
#    'securityType': 'FE',
#    'ticker': '513080',
#    'totalSharesHeld': 0.002204516174611829,
#    'totalAssets': 8.71306,
#    'currentShares': 10957,
#    'changeAmount': 3125,
#    'changePercentage': 39.900408580183864,
#    'date': '2024-12-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'CHN'},
#   {'secId': 'F00000W6E2',
#    'name': 'Stratégie Consommation - Luxe & Low Cost',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0005098333473091517,
#    'totalAssets': 8.55142,
#    'currentShares': 2534,
#    'changeAmount': -211,
#    'changePercentage': -7.686703096539162,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '2',
#    'domicileCountryId': 'FRA'},
#   {'secId': 'F00000PYRN',
#    'name': 'CPR Actions France Select PD',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.006342536085467127,
#    'totalAssets': 8.15101,
#    'currentShares': 31524,
#    'changeAmount': -1600,
#    'changePercentage': -4.830334500664171,
#    'date': '2025-02-28T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'FRA'},
#   {'secId': 'F00001G4NS',
#    'name': 'IAB Strategy Fund EUR',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0005231123531980246,
#    'totalAssets': 8.08921,
#    'currentShares': 2600,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'LIE'},
#   {'secId': 'F00000ZA48',
#    'name': 'ALM Actions France',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.014310543209967653,
#    'totalAssets': 8.08536,
#    'currentShares': 71127,
#    'changeAmount': 3116,
#    'changePercentage': 4.581611798091485,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'FRA'},
#   {'secId': 'F00000TP9D',
#    'name': 'ADN Dynamic C',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0012071823535339031,
#    'totalAssets': 7.91112,
#    'currentShares': 6000,
#    'changeAmount': -1000,
#    'changePercentage': -14.285714285714286,
#    'date': '2025-01-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'FRA'},
#   {'secId': 'F00000O6JM',
#    'name': 'E Fund S&P Global Luxury Idx Enh QDII A',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0010963227740677063,
#    'totalAssets': 7.73319,
#    'currentShares': 5449,
#    'changeAmount': 474,
#    'changePercentage': 9.527638190954773,
#    'date': '2024-12-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'CHN'},
#   {'secId': 'F0000176PS',
#    'name': 'Dynamique Europe 2027 RC',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0018304908420752415,
#    'totalAssets': 7.63328,
#    'currentShares': 9098,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2025-04-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'FRA'},
#   {'secId': 'F0000146L7',
#    'name': 'Felis Luxury Brands Fund EUR I',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.00019516114715464766,
#    'totalAssets': 7.37989,
#    'currentShares': 970,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2024-10-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'LIE'},
#   {'secId': None,
#    'name': None,
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.07361156555379034,
#    'totalAssets': None,
#    'currentShares': 365868,
#    'changeAmount': -3544,
#    'changePercentage': None,
#    'date': None,
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None}],
#  'columnDefs': [{'columnId': 'name', 'dataType': 'string'},
#   {'columnId': 'starRating', 'dataType': 'string'},
#   {'columnId': 'totalSharesHeld', 'dataType': 'number'},
#   {'columnId': 'totalAssets', 'dataType': 'number'},
#   {'columnId': 'trend', 'dataType': 'number'},
#   {'columnId': 'currentShares', 'dataType': 'number'},
#   {'columnId': 'changeAmount', 'dataType': 'number'},
#   {'columnId': 'changePercentage', 'dataType': 'number'},
#   {'columnId': 'date', 'dataType': 'string'}]}

# %% [markdown]
# Main mutual funds owner
#
# Ownership - Major - Funds
#
# https://www.morningstar.com/stocks/pinx/lvmhf/ownership

# %%
stock.mutualFundOwnership()
# Out:
# {'isRestricted': False,
#  'userType': 'Free',
#  'country': 'ITA',
#  'rows': [{'secId': 'FOUSA00KIR',
#    'name': 'Vanguard Total Intl Stock Index Inv',
#    'securityType': 'FO',
#    'ticker': 'VGTSX',
#    'totalSharesHeld': 0.7084045834154737,
#    'totalAssets': 0.38139,
#    'currentShares': 3520949,
#    'changeAmount': 19433,
#    'changePercentage': 0.5549881822616262,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00L5B',
#    'name': 'Vanguard Developed Markets Index Admiral',
#    'securityType': 'FO',
#    'ticker': 'VTMGX',
#    'totalSharesHeld': 0.4404453104162587,
#    'totalAssets': 0.52279,
#    'currentShares': 2189124,
#    'changeAmount': 13918,
#    'changePercentage': 0.6398474443340079,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000016DNK',
#    'name': 'Vanguard Instl Ttl Intl Stk Mkt Idx TrII',
#    'securityType': 'CZ',
#    'ticker': None,
#    'totalSharesHeld': 0.36706854183023063,
#    'totalAssets': 0.3886,
#    'currentShares': 1824423,
#    'changeAmount': 14575,
#    'changePercentage': 0.8053162475522806,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '2',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000OPP5',
#    'name': 'iShares Core MSCI EAFE ETF',
#    'securityType': 'FE',
#    'ticker': 'IEFA',
#    'totalSharesHeld': 0.3559330894071161,
#    'totalAssets': 0.6489,
#    'currentShares': 1769077,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000LK2Q',
#    'name': 'Fundsmith Equity I Acc',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.3215450916872904,
#    'totalAssets': 3.74901,
#    'currentShares': 1598160,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'GBR'},
#   {'secId': 'F00000VB2B',
#    'name': 'EAFE Equity Index Fund T',
#    'securityType': 'CZ',
#    'ticker': None,
#    'totalSharesHeld': 0.25950577737153496,
#    'totalAssets': 0.75991,
#    'currentShares': 1289809,
#    'changeAmount': 37704,
#    'changePercentage': 3.0112490565887047,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00BK7',
#    'name': 'American Funds Capital World Gr&Inc A',
#    'securityType': 'FO',
#    'ticker': 'CWGIX',
#    'totalSharesHeld': 0.23582206677755335,
#    'totalAssets': 0.59972,
#    'currentShares': 1172095,
#    'changeAmount': -101644,
#    'changePercentage': -7.979970778942939,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000013PKQ',
#    'name': 'Capital Group World Growth & Inc Cmp',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.23582206677755335,
#    'totalAssets': 0.59972,
#    'currentShares': 1172095,
#    'changeAmount': -101644,
#    'changePercentage': -7.979970778942939,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000013FOO',
#    'name': 'Capital Group EUPAC Composite',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.2005751588131883,
#    'totalAssets': 0.50108,
#    'currentShares': 996909,
#    'changeAmount': -401125,
#    'changePercentage': -28.692077588957066,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00CBJ',
#    'name': 'American Funds EUPAC A',
#    'securityType': 'FO',
#    'ticker': 'AEPGX',
#    'totalSharesHeld': 0.2005751588131883,
#    'totalAssets': 0.50108,
#    'currentShares': 996909,
#    'changeAmount': -401125,
#    'changePercentage': -28.692077588957066,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FEUSA0002W',
#    'name': 'iShares MSCI EAFE ETF',
#    'securityType': 'FE',
#    'ticker': 'EFA',
#    'totalSharesHeld': 0.1880782058923464,
#    'totalAssets': 0.7588,
#    'currentShares': 934796,
#    'changeAmount': 0,
#    'changePercentage': 0.0,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000MJRM',
#    'name': 'Fidelity International Index',
#    'securityType': 'FO',
#    'ticker': 'FSPSX',
#    'totalSharesHeld': 0.18110189907127397,
#    'totalAssets': 0.76228,
#    'currentShares': 900122,
#    'changeAmount': 6190,
#    'changePercentage': 0.6924464053194203,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F0000159G4',
#    'name': 'Stt Strt World Dev ex US Idx SL SF Cl I',
#    'securityType': 'CZ',
#    'ticker': None,
#    'totalSharesHeld': 0.17124123121349122,
#    'totalAssets': 0.6522,
#    'currentShares': 851112,
#    'changeAmount': 6464,
#    'changePercentage': 0.7652892092327218,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00F8G',
#    'name': 'First Eagle Global A',
#    'securityType': 'FO',
#    'ticker': 'SGENX',
#    'totalSharesHeld': 0.1638943194098839,
#    'totalAssets': 0.77705,
#    'currentShares': 814596,
#    'changeAmount': 344131,
#    'changePercentage': 73.14699286875751,
#    'date': '2025-04-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00D02',
#    'name': 'American Funds Growth Fund of Amer A',
#    'securityType': 'FO',
#    'ticker': 'AGTHX',
#    'totalSharesHeld': 0.14489789669761546,
#    'totalAssets': 0.16339,
#    'currentShares': 720179,
#    'changeAmount': -71876,
#    'changePercentage': -9.074622343145363,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000013FOP',
#    'name': 'Capital Group Growth Fnd of Amer Comp',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.14489789669761546,
#    'totalAssets': 0.16339,
#    'currentShares': 720179,
#    'changeAmount': -71876,
#    'changePercentage': -9.074622343145363,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F0000004JX',
#    'name': 'Xtrackers Euro Stoxx 50 ETF 1D',
#    'securityType': 'FE',
#    'ticker': 'XESX',
#    'totalSharesHeld': 0.134425187386591,
#    'totalAssets': 3.24401,
#    'currentShares': 668127,
#    'changeAmount': 7318,
#    'changePercentage': 1.1074304375394404,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'LUX'},
#   {'secId': 'FOUSA00JX9',
#    'name': 'MFS International Equity R6',
#    'securityType': 'FO',
#    'ticker': 'MIEIX',
#    'totalSharesHeld': 0.13428032550416694,
#    'totalAssets': 1.31236,
#    'currentShares': 667407,
#    'changeAmount': 4207,
#    'changePercentage': 0.6343486127864898,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00961',
#    'name': 'American Funds New World A',
#    'securityType': 'FO',
#    'ticker': 'NEWFX',
#    'totalSharesHeld': 0.13393507135105623,
#    'totalAssets': 0.67187,
#    'currentShares': 665691,
#    'changeAmount': -64105,
#    'changePercentage': -8.783961545418173,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00001LYPB',
#    'name': 'Capital Group New Geography Equity Comp',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.13393507135105623,
#    'totalAssets': 0.67187,
#    'currentShares': 665691,
#    'changeAmount': -64105,
#    'changePercentage': -8.783961545418173,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': None,
#    'name': None,
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 4.856383949884485,
#    'totalAssets': None,
#    'currentShares': 24137450,
#    'changeAmount': -823560,
#    'changePercentage': None,
#    'date': None,
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None}],
#  'columnDefs': [{'columnId': 'name', 'dataType': 'string'},
#   {'columnId': 'starRating', 'dataType': 'string'},
#   {'columnId': 'totalSharesHeld', 'dataType': 'number'},
#   {'columnId': 'totalAssets', 'dataType': 'number'},
#   {'columnId': 'trend', 'dataType': 'number'},
#   {'columnId': 'currentShares', 'dataType': 'number'},
#   {'columnId': 'changeAmount', 'dataType': 'number'},
#   {'columnId': 'changePercentage', 'dataType': 'number'},
#   {'columnId': 'date', 'dataType': 'string'}]}

# %% [markdown]
# Main mutual funds sellers
#
# Ownership - Selling - Funds
#
# https://www.morningstar.com/stocks/pinx/lvmhf/ownership

# %%
stock.mutualFundSellers()
# Out:
# {'isRestricted': False,
#  'userType': 'Free',
#  'country': 'ITA',
#  'rows': [{'secId': 'F0GBR06IRS',
#    'name': 'Stt Strt EUR Lqudty LVNAV I Stbl NAV',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -21000000,
#    'changePercentage': -100.0,
#    'date': '2024-10-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'IRL'},
#   {'secId': 'F00000MIHY',
#    'name': 'WCM Focused International Growth Instl',
#    'securityType': 'FO',
#    'ticker': 'WCMIX',
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -560461,
#    'changePercentage': -100.0,
#    'date': '2024-09-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA09GR6',
#    'name': 'WCM Inv Mgt Focused Growth Intl',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -560461,
#    'changePercentage': -100.0,
#    'date': '2024-09-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00B4J',
#    'name': 'American Funds American Balanced A',
#    'securityType': 'FO',
#    'ticker': 'ABALX',
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -534869,
#    'changePercentage': -100.0,
#    'date': '2024-09-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': 'SAUSA000CW',
#    'name': 'Janus Concentrated Growth CF',
#    'securityType': 'CZ',
#    'ticker': None,
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -424407,
#    'changePercentage': -100.0,
#    'date': '2024-09-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000013FOO',
#    'name': 'Capital Group EUPAC Composite',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.2005751588131883,
#    'totalAssets': 0.50108,
#    'currentShares': 996909,
#    'changeAmount': -401125,
#    'changePercentage': -28.692077588957066,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00CBJ',
#    'name': 'American Funds EUPAC A',
#    'securityType': 'FO',
#    'ticker': 'AEPGX',
#    'totalSharesHeld': 0.2005751588131883,
#    'totalAssets': 0.50108,
#    'currentShares': 996909,
#    'changeAmount': -401125,
#    'changePercentage': -28.692077588957066,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00001FYHG',
#    'name': 'Global Select - Canada Fund',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.001035158868155322,
#    'totalAssets': 3.21434,
#    'currentShares': 5145,
#    'changeAmount': -374323,
#    'changePercentage': -98.64415444780587,
#    'date': '2024-12-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '',
#    'domicileCountryId': 'CAN'},
#   {'secId': 'FOUSA00HVF',
#    'name': 'Fidelity Advisor Intl Cap App I',
#    'securityType': 'FO',
#    'ticker': 'FCPIX',
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -292821,
#    'changePercentage': -100.0,
#    'date': '2025-04-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F000013FUV',
#    'name': 'Fidelity Series Overseas',
#    'securityType': 'FO',
#    'ticker': 'FSOSX',
#    'totalSharesHeld': 0.01652069290222931,
#    'totalAssets': 0.28985,
#    'currentShares': 82112,
#    'changeAmount': -288325,
#    'changePercentage': -77.83374770878719,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000W8DF',
#    'name': 'UniGlobal Vorsorge',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -221601,
#    'changePercentage': -100.0,
#    'date': '2024-10-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'DEU'},
#   {'secId': 'FVUSA0002F',
#    'name': 'American Funds IS® Asset Allocation 1',
#    'securityType': 'FV',
#    'ticker': None,
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -202300,
#    'changePercentage': -100.0,
#    'date': '2024-09-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00D2I',
#    'name': 'Harbor Capital Appreciation Instl',
#    'securityType': 'FO',
#    'ticker': 'HACAX',
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -197068,
#    'changePercentage': -100.0,
#    'date': '2024-09-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F0GBR04PQD',
#    'name': 'UniGlobal',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -188342,
#    'changePercentage': -100.0,
#    'date': '2024-10-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'DEU'},
#   {'secId': 'F00000QKX9',
#    'name': 'WisdomTree Intl Hdgd Qual Div Gr ETF',
#    'securityType': 'FE',
#    'ticker': 'IHDG',
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -174606,
#    'changePercentage': -100.0,
#    'date': '2024-10-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00DP7',
#    'name': 'MFS Growth B',
#    'securityType': 'FO',
#    'ticker': 'MEGBX',
#    'totalSharesHeld': 0.07130906641148334,
#    'totalAssets': 0.42852,
#    'currentShares': 354424,
#    'changeAmount': -158059,
#    'changePercentage': -30.84180353299524,
#    'date': '2025-05-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '3',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00001HBGS',
#    'name': 'Vulcan Value Partners Focus',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -154982,
#    'changePercentage': -100.0,
#    'date': '2025-06-30T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'USA'},
#   {'secId': 'F00000VC0N',
#    'name': 'Eleva European Selection I EUR acc',
#    'securityType': 'FO',
#    'ticker': None,
#    'totalSharesHeld': 0.0,
#    'totalAssets': None,
#    'currentShares': 0,
#    'changeAmount': -149108,
#    'changePercentage': -100.0,
#    'date': '2025-02-28T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '5',
#    'domicileCountryId': 'LUX'},
#   {'secId': 'F000013PKZ',
#    'name': 'Capital Group New Economy Comp',
#    'securityType': 'SA',
#    'ticker': None,
#    'totalSharesHeld': 0.023622345491010336,
#    'totalAssets': 0.2191,
#    'currentShares': 117409,
#    'changeAmount': -142927,
#    'changePercentage': -54.90097412574519,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '2',
#    'domicileCountryId': 'USA'},
#   {'secId': 'FOUSA00E5P',
#    'name': 'American Funds New Economy A',
#    'securityType': 'FO',
#    'ticker': 'ANEFX',
#    'totalSharesHeld': 0.023622345491010336,
#    'totalAssets': 0.2191,
#    'currentShares': 117409,
#    'changeAmount': -142927,
#    'changePercentage': -54.90097412574519,
#    'date': '2025-03-31T00:00:00.000',
#    'trend': '_PO_',
#    'starRating': '4',
#    'domicileCountryId': 'USA'},
#   {'secId': None,
#    'name': None,
#    'securityType': None,
#    'ticker': None,
#    'totalSharesHeld': 0.5372599267902652,
#    'totalAssets': None,
#    'currentShares': 2670317,
#    'changeAmount': -26569837,
#    'changePercentage': None,
#    'date': None,
#    'trend': '_PO_',
#    'starRating': None,
#    'domicileCountryId': None}],
#  'columnDefs': [{'columnId': 'name', 'dataType': 'string'},
#   {'columnId': 'starRating', 'dataType': 'string'},
#   {'columnId': 'totalSharesHeld', 'dataType': 'number'},
#   {'columnId': 'totalAssets', 'dataType': 'number'},
#   {'columnId': 'trend', 'dataType': 'number'},
#   {'columnId': 'currentShares', 'dataType': 'number'},
#   {'columnId': 'changeAmount', 'dataType': 'number'},
#   {'columnId': 'changePercentage', 'dataType': 'number'},
#   {'columnId': 'date', 'dataType': 'string'}]}

# %% [markdown]
# Operating growth
#
# https://www.morningstar.com/stocks/pinx/lvmhf/key-metrics

# %%
stock.operatingGrowth()
# Out:
# {'currency': None,
#  'asOfDate': None,
#  'expectedFiscalYearEnd': '2025-12-31T06:00:00.000',
#  'dataList': [{'fiscalPeriodDate': '2015-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2015-12',
#    'revenuePer': {'yearOverYear': 16.400000000000002,
#     'threeYearAvg': 8.27,
#     'fiveYearAvg': 11.91,
#     'tenYearAvg': 9.87},
#    'operatingIncome': {'yearOverYear': 18.56,
#     'threeYearAvg': 4.01,
#     'fiveYearAvg': 9.28,
#     'tenYearAvg': 9.92},
#    'netIncomePer': {'yearOverYear': -36.74,
#     'threeYearAvg': 1.43,
#     'fiveYearAvg': 1.49,
#     'tenYearAvg': 7.920000000000001},
#    'epsPer': {'yearOverYear': -36.84,
#     'threeYearAvg': 1.26,
#     'fiveYearAvg': 2.3,
#     'tenYearAvg': 8.82}},
#   {'fiscalPeriodDate': '2016-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2016-12',
#    'revenuePer': {'yearOverYear': 5.43,
#     'threeYearAvg': 8.86,
#     'fiveYearAvg': 9.71,
#     'tenYearAvg': 9.4},
#    'operatingIncome': {'yearOverYear': 5.63,
#     'threeYearAvg': 4.99,
#     'fiveYearAvg': 5.89,
#     'tenYearAvg': 8.44},
#    'netIncomePer': {'yearOverYear': 11.42,
#     'threeYearAvg': 5.029999999999999,
#     'fiveYearAvg': 2.82,
#     'tenYearAvg': 6.3100000000000005},
#    'epsPer': {'yearOverYear': 11.44,
#     'threeYearAvg': 4.93,
#     'fiveYearAvg': 4.84,
#     'tenYearAvg': 7.19}},
#   {'fiscalPeriodDate': '2017-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2017-12',
#    'revenuePer': {'yearOverYear': 13.389999999999999,
#     'threeYearAvg': 11.64,
#     'fiveYearAvg': 8.690000000000001,
#     'tenYearAvg': 9.969999999999999},
#    'operatingIncome': {'yearOverYear': 20.94,
#     'threeYearAvg': 14.84,
#     'fiveYearAvg': 7.53,
#     'tenYearAvg': 9.24},
#    'netIncomePer': {'yearOverYear': 28.84,
#     'threeYearAvg': -3.16,
#     'fiveYearAvg': 8.42,
#     'tenYearAvg': 8.21},
#    'epsPer': {'yearOverYear': 29.020000000000003,
#     'threeYearAvg': -3.16,
#     'fiveYearAvg': 8.34,
#     'tenYearAvg': 9.21}},
#   {'fiscalPeriodDate': '2018-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2018-12',
#    'revenuePer': {'yearOverYear': 9.83,
#     'threeYearAvg': 9.5,
#     'fiveYearAvg': 9.94,
#     'tenYearAvg': 10.54},
#    'operatingIncome': {'yearOverYear': 20.32,
#     'threeYearAvg': 15.409999999999998,
#     'fiveYearAvg': 10.979999999999999,
#     'tenYearAvg': 11.1},
#    'netIncomePer': {'yearOverYear': 23.880000000000003,
#     'threeYearAvg': 21.15,
#     'fiveYearAvg': 13.08,
#     'tenYearAvg': 10.61},
#    'epsPer': {'yearOverYear': 23.87,
#     'threeYearAvg': 21.22,
#     'fiveYearAvg': 13.05,
#     'tenYearAvg': 11.459999999999999}},
#   {'fiscalPeriodDate': '2019-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2019-12',
#    'revenuePer': {'yearOverYear': 14.62,
#     'threeYearAvg': 12.590000000000002,
#     'fiveYearAvg': 11.87,
#     'tenYearAvg': 12.15},
#    'operatingIncome': {'yearOverYear': 13.889999999999999,
#     'threeYearAvg': 18.34,
#     'fiveYearAvg': 15.73,
#     'tenYearAvg': 13.66},
#    'netIncomePer': {'yearOverYear': 12.86,
#     'threeYearAvg': 21.67,
#     'fiveYearAvg': 4.89,
#     'tenYearAvg': 13.77},
#    'epsPer': {'yearOverYear': 12.85,
#     'threeYearAvg': 21.72,
#     'fiveYearAvg': 4.89,
#     'tenYearAvg': 14.42}},
#   {'fiscalPeriodDate': '2020-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2020-12',
#    'revenuePer': {'yearOverYear': -16.81,
#     'threeYearAvg': 1.55,
#     'fiveYearAvg': 4.6,
#     'tenYearAvg': 8.19},
#    'operatingIncome': {'yearOverYear': -26.919999999999998,
#     'threeYearAvg': 0.05,
#     'fiveYearAvg': 5.050000000000001,
#     'tenYearAvg': 7.140000000000001},
#    'netIncomePer': {'yearOverYear': -34.43,
#     'threeYearAvg': -2.86,
#     'fiveYearAvg': 5.65,
#     'tenYearAvg': 3.54},
#    'epsPer': {'yearOverYear': -34.5,
#     'threeYearAvg': -2.9000000000000004,
#     'fiveYearAvg': 5.65,
#     'tenYearAvg': 3.9600000000000004}},
#   {'fiscalPeriodDate': '2021-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2021-12',
#    'revenuePer': {'yearOverYear': 43.82,
#     'threeYearAvg': 11.1,
#     'fiveYearAvg': 11.3,
#     'tenYearAvg': 10.5},
#    'operatingIncome': {'yearOverYear': 106.02000000000001,
#     'threeYearAvg': 19.689999999999998,
#     'fiveYearAvg': 20.07,
#     'tenYearAvg': 12.76},
#    'netIncomePer': {'yearOverYear': 155.98000000000002,
#     'threeYearAvg': 23.73,
#     'fiveYearAvg': 24.77,
#     'tenYearAvg': 13.26},
#    'epsPer': {'yearOverYear': 156.32999999999998,
#     'threeYearAvg': 23.74,
#     'fiveYearAvg': 24.8,
#     'tenYearAvg': 14.39}},
#   {'fiscalPeriodDate': '2022-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2022-12',
#    'revenuePer': {'yearOverYear': 23.31,
#     'threeYearAvg': 13.84,
#     'fiveYearAvg': 13.18,
#     'tenYearAvg': 10.91},
#    'operatingIncome': {'yearOverYear': 22.74,
#     'threeYearAvg': 22.720000000000002,
#     'fiveYearAvg': 20.419999999999998,
#     'tenYearAvg': 13.79},
#    'netIncomePer': {'yearOverYear': 17.02,
#     'threeYearAvg': 25.230000000000004,
#     'fiveYearAvg': 22.39,
#     'tenYearAvg': 15.190000000000001},
#    'epsPer': {'yearOverYear': 17.330000000000002,
#     'threeYearAvg': 25.35,
#     'fiveYearAvg': 22.45,
#     'tenYearAvg': 15.18}},
#   {'fiscalPeriodDate': '2023-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2023-12',
#    'revenuePer': {'yearOverYear': 8.799999999999999,
#     'threeYearAvg': 24.490000000000002,
#     'fiveYearAvg': 12.97,
#     'tenYearAvg': 11.450000000000001},
#    'operatingIncome': {'yearOverYear': 8.4,
#     'threeYearAvg': 39.95,
#     'fiveYearAvg': 17.94,
#     'tenYearAvg': 14.41},
#    'netIncomePer': {'yearOverYear': 7.739999999999999,
#     'threeYearAvg': 47.78,
#     'fiveYearAvg': 19.02,
#     'tenYearAvg': 16.009999999999998},
#    'epsPer': {'yearOverYear': 8.21,
#     'threeYearAvg': 48.19,
#     'fiveYearAvg': 19.189999999999998,
#     'tenYearAvg': 16.08}},
#   {'fiscalPeriodDate': '2024-12-31T06:00:00.000',
#    'fiscalPeriodYearMonth': '2024-12',
#    'revenuePer': {'yearOverYear': -1.71,
#     'threeYearAvg': 9.66,
#     'fiveYearAvg': 9.55,
#     'tenYearAvg': 10.7},
#    'operatingIncome': {'yearOverYear': -14.06,
#     'threeYearAvg': 4.569999999999999,
#     'fiveYearAvg': 11.48,
#     'tenYearAvg': 13.58},
#    'netIncomePer': {'yearOverYear': -17.29,
#     'threeYearAvg': 1.4000000000000001,
#     'fiveYearAvg': 11.84,
#     'tenYearAvg': 8.309999999999999},
#    'epsPer': {'yearOverYear': -17.18,
#     'threeYearAvg': 1.69,
#     'fiveYearAvg': 12.04,
#     'tenYearAvg': 8.4}},
#   {'fiscalPeriodDate': None,
#    'fiscalPeriodYearMonth': 'Latest Qtr',
#    'revenuePer': {'yearOverYear': None,
#     'threeYearAvg': None,
#     'fiveYearAvg': None,
#     'tenYearAvg': None},
#    'operatingIncome': {'yearOverYear': None,
#     'threeYearAvg': None,
#     'fiveYearAvg': None,
#     'tenYearAvg': None},
#    'netIncomePer': {'yearOverYear': None,
#     'threeYearAvg': None,
#     'fiveYearAvg': None,
#     'tenYearAvg': None},
#    'epsPer': {'yearOverYear': None,
#     'threeYearAvg': None,
#     'fiveYearAvg': None,
#     'tenYearAvg': None}}]}

# %% [markdown]
# Overview of the stock

# %%
stock.overview()
# Out:
# {'userType': 'Free',
#  'secId': '0P0000G5GV',
#  'isREIT': 'no',
#  'isListedREIT': None,
#  'securityName': 'Lvmh Moet Hennessy Louis Vuitton SE',
#  'ticker': '1MC',
#  'starRating': '3',
#  'starRatingDate': '2025-07-15T04:36:24.000',
#  'bestRatingType': 'Quan',
#  'isMomentumFilterFlag': True,
#  'morningstarFundamentals': {'lastClose': '478.500000',
#   'lastCloseDate': '2025-07-14T05:00:00.000',
#   'fairValue': '_PO_',
#   'fairValueDate': '2025-07-15T04:35:30.000',
#   'uncertainty': '_PO_',
#   'oneStar': '_PO_',
#   'fiveStar': '_PO_',
#   'moat': '_PO_',
#   'stewardship': '_PO_',
#   'stewardshipDate': '',
#   'assessment': '_PO_',
#   'rpsCovered': False,
#   'lastCloseCurrency': 'EUR',
#   'fairValCurrency': 'EUR',
#   'priceFairValue': '0.7919402102'},
#  'sustainability': {'susEsgRiskGlobes': 4,
#   'comHighestControversyLevel': 2,
#   'comControversyLevelDescriptor': 'Moderate',
#   'comHighestControversyTopics': 'Operations, Product & Service, Business Ethics, Governance, Employee, Social Supply Chain, Customer',
#   'notableIssue1Name': 'Overall',
#   'notableIssue1': 'Human Capital',
#   'notableIssue2Name': 'Overall',
#   'notableIssue2': 'Data Privacy & Cybersecurity',
#   'notableIssue3Name': 'Supply Chain',
#   'notableIssue3': 'Human Rights',
#   'asOfDate': '2025-06-04T05:00:00.000'},
#  'investmentStyle': '2',
#  'sector': 'Consumer Cyclical',
#  'industry': 'Luxury Goods',
#  'dayRangeHigh': 486.2,
#  'dayRangeLow': 478.5,
#  'yearRangeHigh': 762.6,
#  'yearRangeLow': 436.8,
#  'marketCap': 238249009487.3,
#  'volume': 1528,
#  'avgVolume': 1854.746031746,
#  'priceSale': '2.823473',
#  'priceBook': '3.539107',
#  'priceEarnings': '19.048567',
#  'forwardDivYield': '0.027168',
#  'dividendYield': 0.027168,
#  'lastUpdateTime': '2025-07-15T16:09:27.000'}

# %% [markdown]
# Profitability
#
# https://www.morningstar.com/stocks/pinx/lvmhf/key-metrics

# %%
stock.profitability()
# Out:
# {'currency': None,
#  'asOfDate': '2024-12-31T06:00:00.000',
#  'expectedFiscalYearEnd': '2025-12-31T06:00:00.000',
#  'dataList': [{'fiscalPeriodYear': '2015',
#    'morningstarEndingDate': '2015-12-31T06:00:00.000',
#    'roa': 6.4399999999999995,
#    'roe': 15.5,
#    'roic': 11.469999999999999,
#    'daysInSales': 24.537,
#    'daysInInventory': 284.5302,
#    'daysInPayment': 109.9972,
#    'cashConversionCycle': 199.07,
#    'receivableTurnover': 14.8755,
#    'inventoryTurnover': 1.2828,
#    'fixedAssetsTurnover': 3.5051,
#    'assetsTurnover': 0.6428},
#   {'fiscalPeriodYear': '2016',
#    'morningstarEndingDate': '2016-12-31T06:00:00.000',
#    'roa': 6.79,
#    'roe': 15.690000000000001,
#    'roic': 12.18,
#    'daysInSales': 25.2685,
#    'daysInInventory': 288.9152,
#    'daysInPayment': 113.9873,
#    'cashConversionCycle': 200.1964,
#    'receivableTurnover': 14.4449,
#    'inventoryTurnover': 1.2633,
#    'fixedAssetsTurnover': 3.4371,
#    'assetsTurnover': 0.6415},
#   {'fiscalPeriodYear': '2017',
#    'morningstarEndingDate': '2017-12-31T06:00:00.000',
#    'roa': 8.0,
#    'roe': 18.57,
#    'roic': 14.030000000000001,
#    'daysInSales': 23.2084,
#    'daysInInventory': 264.8552,
#    'daysInPayment': 107.7001,
#    'cashConversionCycle': 180.3636,
#    'receivableTurnover': 15.727,
#    'inventoryTurnover': 1.3781,
#    'fixedAssetsTurnover': 3.5939,
#    'assetsTurnover': 0.6653},
#   {'fiscalPeriodYear': '2018',
#    'morningstarEndingDate': '2018-12-31T06:00:00.000',
#    'roa': 8.9,
#    'roe': 20.78,
#    'roic': 15.45,
#    'daysInSales': 23.2247,
#    'daysInInventory': 273.2302,
#    'daysInPayment': 115.0947,
#    'cashConversionCycle': 181.3602,
#    'receivableTurnover': 15.7161,
#    'inventoryTurnover': 1.3359,
#    'fixedAssetsTurnover': 3.4746,
#    'assetsTurnover': 0.6556},
#   {'fiscalPeriodYear': '2019',
#    'morningstarEndingDate': '2019-12-31T06:00:00.000',
#    'roa': 8.4,
#    'roe': 20.82,
#    'roic': 14.249999999999998,
#    'daysInSales': 22.6875,
#    'daysInInventory': 263.8562,
#    'daysInPayment': 112.0598,
#    'cashConversionCycle': 174.4839,
#    'receivableTurnover': 16.0881,
#    'inventoryTurnover': 1.3833,
#    'fixedAssetsTurnover': 2.3976,
#    'assetsTurnover': 0.6284},
#   {'fiscalPeriodYear': '2020',
#    'morningstarEndingDate': '2020-12-31T06:00:00.000',
#    'roa': 4.58,
#    'roe': 12.709999999999999,
#    'roic': 7.24,
#    'daysInSales': 25.3661,
#    'daysInInventory': 307.3902,
#    'daysInPayment': 125.4767,
#    'cashConversionCycle': 207.2796,
#    'receivableTurnover': 14.3893,
#    'inventoryTurnover': 1.1874,
#    'fixedAssetsTurnover': 1.479,
#    'assetsTurnover': 0.4352},
#   {'fiscalPeriodYear': '2021',
#    'morningstarEndingDate': '2021-12-31T06:00:00.000',
#    'roa': 10.290000000000001,
#    'roe': 28.48,
#    'roic': 15.42,
#    'daysInSales': 18.5953,
#    'daysInInventory': 265.0576,
#    'daysInPayment': 109.24,
#    'cashConversionCycle': 174.4129,
#    'receivableTurnover': 19.6286,
#    'inventoryTurnover': 1.3771,
#    'fixedAssetsTurnover': 2.0261,
#    'assetsTurnover': 0.5489},
#   {'fiscalPeriodYear': '2022',
#    'morningstarEndingDate': '2022-12-31T06:00:00.000',
#    'roa': 10.84,
#    'roe': 27.55,
#    'roic': 16.39,
#    'daysInSales': 18.5418,
#    'daysInInventory': 269.2583,
#    'daysInPayment': 115.9358,
#    'cashConversionCycle': 171.8643,
#    'receivableTurnover': 19.6853,
#    'inventoryTurnover': 1.3556,
#    'fixedAssetsTurnover': 2.2553,
#    'assetsTurnover': 0.6092},
#   {'fiscalPeriodYear': '2023',
#    'morningstarEndingDate': '2023-12-31T06:00:00.000',
#    'roa': 10.9,
#    'roe': 26.13,
#    'roic': 16.580000000000002,
#    'daysInSales': 19.0353,
#    'daysInInventory': 293.8293,
#    'daysInPayment': 121.1212,
#    'cashConversionCycle': 191.7434,
#    'receivableTurnover': 19.1749,
#    'inventoryTurnover': 1.2422,
#    'fixedAssetsTurnover': 2.1722,
#    'assetsTurnover': 0.619},
#   {'fiscalPeriodYear': '2024',
#    'morningstarEndingDate': '2024-12-31T06:00:00.000',
#    'roa': 8.57,
#    'roe': 19.53,
#    'roic': 12.85,
#    'daysInSales': 20.3853,
#    'daysInInventory': 304.7615,
#    'daysInPayment': 115.5676,
#    'cashConversionCycle': 209.5792,
#    'receivableTurnover': 17.9051,
#    'inventoryTurnover': 1.1977,
#    'fixedAssetsTurnover': 1.9188,
#    'assetsTurnover': 0.5783},
#   {'fiscalPeriodYear': 'Current',
#    'morningstarEndingDate': '2024-12-31T06:00:00.000',
#    'roa': 8.57,
#    'roe': 19.53,
#    'roic': 12.85,
#    'daysInSales': 20.3853,
#    'daysInInventory': 304.7615,
#    'daysInPayment': 115.5676,
#    'cashConversionCycle': 209.5792,
#    'receivableTurnover': 17.9051,
#    'inventoryTurnover': 1.1977,
#    'fixedAssetsTurnover': 1.9188,
#    'assetsTurnover': 0.5783},
#   {'fiscalPeriodYear': '5-Yr',
#    'morningstarEndingDate': None,
#    'roa': 7.706,
#    'roe': 18.272,
#    'roic': 13.476,
#    'daysInSales': 23.7852,
#    'daysInInventory': 275.0774,
#    'daysInPayment': 111.7678,
#    'cashConversionCycle': 187.0948,
#    'receivableTurnover': 15.3703,
#    'inventoryTurnover': 1.3287,
#    'fixedAssetsTurnover': 3.2817,
#    'assetsTurnover': 0.6467},
#   {'fiscalPeriodYear': 'Index',
#    'morningstarEndingDate': None,
#    'roa': None,
#    'roe': None,
#    'roic': None,
#    'daysInSales': None,
#    'daysInInventory': None,
#    'daysInPayment': None,
#    'cashConversionCycle': None,
#    'receivableTurnover': None,
#    'inventoryTurnover': None,
#    'fixedAssetsTurnover': None,
#    'assetsTurnover': None}]}

# %% [markdown]
# History of Splits
#
# https://www.morningstar.com/stocks/pinx/lvmhf/dividends

# %%
stock.split()
# Out:
# {'splitHistory': [], 'splitOffHistory': []}

# %% [markdown]
# Sustainability Risk Rating Breakdown
#
# https://www.morningstar.com/stocks/pinx/lvmhf/sustainability

# %%
stock.sustainability()
# Out:
# {'controllableRisk': 26.02,
#  'controlledRisk': 14.1608,
#  'companyExposureScore': 28.05,
#  'neglectedRisk': 11.8592,
#  'esgRiskScore': 13.8892,
#  'controlledRiskPer': 54.42,
#  'neglectedRiskPer': 45.58,
#  'uncontrollableRisk': 2.03,
#  'esgRiskCategory': 'Low',
#  'companyExposureCategory': 'Low',
#  'asOfDate': '2025-06-04T05:00:00.000',
#  'overallManagementScore': 54.4228,
#  'overallManagementCategory': 'Strong',
#  'companyName': 'Lvmh Moet Hennessy Louis Vuitton SE',
#  'subindustryExposureScore': 26.0,
#  'subindustryExposureCategory': 'Low',
#  'peers': [{'controllableRisk': 29.085,
#    'controlledRisk': 19.1596,
#    'companyExposureScore': 31.7,
#    'neglectedRisk': 9.9254,
#    'esgRiskScore': 12.5404,
#    'controlledRiskPer': 65.86999999999999,
#    'neglectedRiskPer': 34.13,
#    'uncontrollableRisk': 2.615,
#    'esgRiskCategory': 'Low',
#    'companyExposureCategory': 'Low',
#    'asOfDate': '2025-06-04 00:00:00.0',
#    'overallManagementScore': 65.8745,
#    'overallManagementCategory': 'Strong',
#    'companyName': 'Kering SA',
#    'subindustryExposureScore': 31.0,
#    'subindustryExposureCategory': 'Low',
#    'companyId': '0C00000VM2'},
#   {'controllableRisk': 28.6725,
#    'controlledRisk': 18.3636,
#    'companyExposureScore': 31.1,
#    'neglectedRisk': 10.3089,
#    'esgRiskScore': 12.7364,
#    'controlledRiskPer': 64.05,
#    'neglectedRiskPer': 35.949999999999996,
#    'uncontrollableRisk': 2.4275,
#    'esgRiskCategory': 'Low',
#    'companyExposureCategory': 'Low',
#    'asOfDate': '2025-06-04 00:00:00.0',
#    'overallManagementScore': 64.0462,
#    'overallManagementCategory': 'Strong',
#    'companyName': 'Hermes International SA',
#    'subindustryExposureScore': 31.0,
#    'subindustryExposureCategory': 'Low',
#    'companyId': '0C00000VUF'},
#   {'controllableRisk': 31.0475,
#    'controlledRisk': 17.9275,
#    'companyExposureScore': 33.9,
#    'neglectedRisk': 13.12,
#    'esgRiskScore': 15.9725,
#    'controlledRiskPer': 57.74,
#    'neglectedRiskPer': 42.26,
#    'uncontrollableRisk': 2.8525,
#    'esgRiskCategory': 'Low',
#    'companyExposureCategory': 'Low',
#    'asOfDate': '2025-06-04 00:00:00.0',
#    'overallManagementScore': 57.7422,
#    'overallManagementCategory': 'Strong',
#    'companyName': 'Compagnie Financiere Richemont SA',
#    'subindustryExposureScore': 31.0,
#    'subindustryExposureCategory': 'Low',
#    'companyId': '0C00003554'}]}

# %% [markdown]
# Last price
#
# https://www.morningstar.com/stocks/pinx/lvmhf/quote

# %%
stock.tradingInformation()
# Out:
# {'0P0000G5GV': {'netChange': {'value': 0.85,
#    'properties': {'date': {'value': '2025-07-15T16:09:28+02:00',
#      'properties': {}},
#     'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'date': {'value': '2025-07-15T16:09:28+02:00', 'properties': {}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'askPrice': {'value': 479.5,
#    'properties': {'date': {'value': '2025-07-15T16:10:02+02:00',
#      'properties': {}},
#     'size': {'value': 75, 'properties': {}},
#     'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'date': {'value': '2025-07-15T16:10:02+02:00', 'properties': {}},
#    'size': {'value': 75, 'properties': {}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'marketCap': {'value': 238249009487.3,
#    'properties': {'currency': {'value': 'EUR', 'properties': {}}},
#    'currency': {'value': 'EUR', 'properties': {}}},
#   'ticker': {'value': '1MC', 'properties': {}},
#   'adjustedClosePrice': {'value': 478.5,
#    'properties': {'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'tradedCurrency': {'value': 'EUR',
#    'properties': {'exchange': {'value': 'XMIL', 'properties': {}}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'openPrice': {'value': 478.5,
#    'properties': {'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'tradingStatus': {'value': 'Open',
#    'properties': {'exchange': {'value': 'XMIL', 'properties': {}}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'yearLowPrice': {'value': 436.8,
#    'properties': {'date': {'value': '2025-06-26', 'properties': {}},
#     'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'date': {'value': '2025-06-26', 'properties': {}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'bidPrice': {'value': 479.05,
#    'properties': {'date': {'value': '2025-07-15T16:10:03+02:00',
#      'properties': {}},
#     'size': {'value': 29, 'properties': {}},
#     'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'date': {'value': '2025-07-15T16:10:03+02:00', 'properties': {}},
#    'size': {'value': 29, 'properties': {}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'previousClosePrice': {'value': 478.5,
#    'properties': {'date': {'value': '2025-07-14', 'properties': {}},
#     'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'date': {'value': '2025-07-14', 'properties': {}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'volume': {'value': 1528,
#    'properties': {'date': {'value': '2025-07-15T16:09:28+02:00',
#      'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'date': {'value': '2025-07-15T16:09:28+02:00', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'performanceID': {'value': '0P0000G5GV', 'properties': {}},
#   'averageVolume': {'value': 1854.746031746,
#    'properties': {'exchange': {'value': 'XMIL', 'properties': {}}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'lowPrice': {'value': 478.5,
#    'properties': {'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'listedCurrency': {'value': 'EUR', 'properties': {}},
#   'highPrice': {'value': 486.2,
#    'properties': {'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'name': {'value': 'LVMH', 'properties': {}},
#   'exchange': {'value': 'XMIL', 'properties': {}},
#   'percentNetChange': {'value': 0.1776,
#    'properties': {'date': {'value': '2025-07-15T16:09:28+02:00',
#      'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'date': {'value': '2025-07-15T16:09:28+02:00', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'yearHighPrice': {'value': 762.6,
#    'properties': {'date': {'value': '2025-01-28', 'properties': {}},
#     'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'date': {'value': '2025-01-28', 'properties': {}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}},
#   'lastPrice': {'value': 479.35,
#    'properties': {'date': {'value': '2025-07-15T16:09:28+02:00',
#      'properties': {}},
#     'currency': {'value': 'EUR', 'properties': {}},
#     'exchange': {'value': 'XMIL', 'properties': {}}},
#    'date': {'value': '2025-07-15T16:09:28+02:00', 'properties': {}},
#    'currency': {'value': 'EUR', 'properties': {}},
#    'exchange': {'value': 'XMIL', 'properties': {}}}}}

# %% [markdown]
# Trainling returns of stock, industry and index
#
# https://www.morningstar.com/stocks/pinx/lvmhf/trailing-returns

# %%
stock.trailingTotalReturn()
# Out:
# {'returnDate': '2025-07-14T05:00:00.000',
#  'trailingTotalReturnsList': [{'name': '1MC',
#    'trailing1DayReturn': '-2.00696',
#    'trailing1WeekReturn': '0.53577',
#    'trailing1MonthReturn': '3.66118',
#    'trailing3MonthReturn': '-7.83235',
#    'trailing6MonthReturn': '-25.44869',
#    'trailingYearToDateReturn': '-22.70992',
#    'trailing1YearReturn': '-32.30028',
#    'trailing3YearReturn': '-5.18744',
#    'trailing5YearReturn': '5.68921',
#    'trailing10YearReturn': '13.23552',
#    'trailing15YearReturn': '13.11856'},
#   {'name': 'Luxury Goods',
#    'trailing1DayReturn': None,
#    'trailing1WeekReturn': None,
#    'trailing1MonthReturn': None,
#    'trailing3MonthReturn': None,
#    'trailing6MonthReturn': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'trailing10YearReturn': None,
#    'trailing15YearReturn': None},
#   {'name': 'Morningstar France GR EUR',
#    'trailing1DayReturn': '-0.26034',
#    'trailing1WeekReturn': '1.04869',
#    'trailing1MonthReturn': '1.87698',
#    'trailing3MonthReturn': '10.30050',
#    'trailing6MonthReturn': '8.89307',
#    'trailingYearToDateReturn': '9.51691',
#    'trailing1YearReturn': '5.68516',
#    'trailing3YearReturn': '12.53601',
#    'trailing5YearReturn': '11.77633',
#    'trailing10YearReturn': '7.67688',
#    'trailing15YearReturn': '9.20704'},
#   {'name': '+/-Luxury Goods',
#    'trailing1DayReturn': None,
#    'trailing1WeekReturn': None,
#    'trailing1MonthReturn': None,
#    'trailing3MonthReturn': None,
#    'trailing6MonthReturn': None,
#    'trailingYearToDateReturn': None,
#    'trailing1YearReturn': None,
#    'trailing3YearReturn': None,
#    'trailing5YearReturn': None,
#    'trailing10YearReturn': None,
#    'trailing15YearReturn': None},
#   {'name': '+/-Morningstar France GR EUR',
#    'trailing1DayReturn': '-1.74662',
#    'trailing1WeekReturn': '-0.51292',
#    'trailing1MonthReturn': '1.78420',
#    'trailing3MonthReturn': '-18.13285',
#    'trailing6MonthReturn': '-34.34176',
#    'trailingYearToDateReturn': '-32.22683',
#    'trailing1YearReturn': '-37.98544',
#    'trailing3YearReturn': '-17.72345',
#    'trailing5YearReturn': '-6.08712',
#    'trailing10YearReturn': '5.55864',
#    'trailing15YearReturn': '3.91152'}]}

# %% [markdown]
# Transaction history
#
# https://www.morningstar.com/stocks/pinx/lvmhf/executive

# %%
stock.transactionHistory()
# Out:
# []

# %% [markdown]
# Transaction summary
#
# https://www.morningstar.com/stocks/pinx/lvmhf/executive

# %%
stock.transactionSummary()
# Out:
# []

# %% [markdown]
# Valuation
#
# https://www.morningstar.com/stocks/pinx/lvmhf/valuation

# %%
stock.valuation()
# Out:
# {'Collapsed': {'rows': [{'label': 'Price/Sales',
#     'salDataId': 'price.sales.label',
#     'datum': ['2.2374',
#      '2.5036',
#      '3.1038',
#      '2.8512',
#      '4.1692',
#      '5.5209',
#      '6.6932',
#      '4.7471',
#      '4.3687',
#      '3.672',
#      '2.8235',
#      '4.6511',
#      '1.3646'],
#     'subLevel': ''},
#    {'label': 'Price/Earnings',
#     'salDataId': 'price.earnings.label',
#     'datum': ['13.0335',
#      '24.4142',
#      '28.3908',
#      '21.1642',
#      '31.5918',
#      '58.5779',
#      '38.8546',
#      '25.828',
#      '23.0841',
#      '22.5054',
#      '19.0486',
#      '28.9121',
#      '17.7022'],
#     'subLevel': ''},
#    {'label': 'Price/Cash Flow',
#     'salDataId': 'price.cash.flow.label',
#     'datum': ['13.2456',
#      '14.3866',
#      '16.8209',
#      '14.7556',
#      '18.7467',
#      '27.0324',
#      '21.7567',
#      '17.2487',
#      '16.8822',
#      '13.9375',
#      '11.4681',
#      '17.8486',
#      '8.9702'],
#     'subLevel': ''},
#    {'label': 'Price/Book',
#     'salDataId': 'price.book.label',
#     'datum': ['3.2109',
#      '3.6571',
#      '4.6241',
#      '4.2404',
#      '6.1998',
#      '7.2413',
#      '8.9214',
#      '6.7426',
#      '6.3882',
#      '4.8471',
#      '3.5391',
#      '6.2973',
#      '1.8498'],
#     'subLevel': ''}],
#   'columnDefs': ['Calendar',
#    '2015',
#    '2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    'Current',
#    '5-Yr',
#    'Index'],
#   'columnDefs_labels': ['tabular.data.label.column.year',
#    '2015',
#    '2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    'valuation.headers.current',
#    'valuation.headers.fiveyear',
#    'valuation.headers.index'],
#   'userType': None,
#   'footer': {'asOfLabel': 'As of',
#    'asOfDate': '2025-07-14T00:00:00.000',
#    'indexLabel': 'Index:',
#    'indexName': 'Morningstar France GR EUR',
#    'enterpriseValueCurrency': 'EUR'}},
#  'Expanded': {'rows': [{'label': 'Price/Forward Earnings',
#     'salDataId': 'price.forward.earnings.label',
#     'datum': [None,
#      None,
#      None,
#      None,
#      '25.3716',
#      '35.2189',
#      '30.5402',
#      '21.2734',
#      '21.7475',
#      '22.2939',
#      '20.7772',
#      '24.7725',
#      None],
#     'subLevel': ''},
#    {'label': 'PEG Ratio',
#     'salDataId': 'peg.ratio.label',
#     'datum': ['0.6319',
#      '17.181',
#      '5.8701',
#      '1.6813',
#      '2.1934',
#      '11.9875',
#      '1.8809',
#      '1.0624',
#      '1.1048',
#      '1.3804',
#      '1.5824',
#      '2.3647',
#      None],
#     'subLevel': ''},
#    {'label': 'Earnings Yield %',
#     'salDataId': 'earnings.yield.label',
#     'datum': ['7.67',
#      '4.1',
#      '3.52',
#      '4.73',
#      '3.17',
#      '1.71',
#      '2.57',
#      '3.87',
#      '4.33',
#      '4.44',
#      '5.25',
#      '3.03',
#      None],
#     'subLevel': ''},
#    {'label': 'Enterprise Value (Bil)',
#     'salDataId': 'enterprise.value.label',
#     'datum': ['80.21',
#      '98.22',
#      '128.93',
#      '138.73',
#      '232.17',
#      '283.11',
#      '398.61',
#      '371.29',
#      '397.59',
#      '348.68',
#      '267.73',
#      '338.96',
#      None],
#     'subLevel': '',
#     'orderOfMagnitude': 'Bil'},
#    {'label': 'Enterprise Value/EBIT',
#     'salDataId': 'enterprise.value.ebit.label',
#     'datum': ['9.2518',
#      '15.901',
#      '17.5372',
#      '15.2549',
#      '22.593',
#      '39.4854',
#      '28.0869',
#      '19.363',
#      '16.9388',
#      '16.5218',
#      '13.8737',
#      '21.0451',
#      None],
#     'subLevel': ''},
#    {'label': 'Enterprise Value/EBITDA',
#     'salDataId': 'enterprise.value.ebitda.label',
#     'datum': ['7.4895',
#      '11.9041',
#      '13.3444',
#      '12.0372',
#      '16.7315',
#      '22.0422',
#      '20.8369',
#      '15.1874',
#      '13.5858',
#      '12.5085',
#      '10.3584',
#      '15.6261',
#      None],
#     'subLevel': ''}],
#   'columnDefs': ['Calendar',
#    '2015',
#    '2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    'Current',
#    '5-Yr',
#    'Index'],
#   'columnDefs_labels': ['tabular.data.label.column.year',
#    '2015',
#    '2016',
#    '2017',
#    '2018',
#    '2019',
#    '2020',
#    '2021',
#    '2022',
#    '2023',
#    '2024',
#    'valuation.headers.current',
#    'valuation.headers.fiveyear',
#    'valuation.headers.index']}}
