# %% [markdown]
# # Installation
#
# You can install it **via pip** on the terminal by typing:
#
# ``` bash
# pip install mstarpy
# ```
#
# You can also install it **via git** on the terminal bu using :
#
# ``` bash
# pip install git+https://github.com/Mael-J/mstarpy.git@master
# ```

# %% [markdown]
# Import the package MStarpy as follow :

# %%
import mstarpy as ms

# %% [markdown]
# ## Fund analysis
#
# Initialize Funds to start you analysis

# %%
funds = ms.Funds("VTSAX")

# %% [markdown]
# Get historical nav and total return of the fund

# %%
import datetime
end_date = datetime.datetime.today()
start_date = end_date - datetime.timedelta(days=365)
funds.nav(start_date,end_date)
# Out:
# [{'nav': 134.11, 'totalReturn': 205.11715, 'date': '2024-07-12'},
#  {'nav': 134.65, 'totalReturn': 205.94306, 'date': '2024-07-15'},
#  {'nav': 135.84, 'totalReturn': 207.76313, 'date': '2024-07-16'},
#  {'nav': 133.92, 'totalReturn': 204.82655, 'date': '2024-07-17'},
#  {'nav': 132.74, 'totalReturn': 203.02178, 'date': '2024-07-18'},
#  {'nav': 131.88, 'totalReturn': 201.70643, 'date': '2024-07-19'},
#  {'nav': 133.34, 'totalReturn': 203.93946, 'date': '2024-07-22'},
#  {'nav': 133.26, 'totalReturn': 203.8171, 'date': '2024-07-23'},
#  {'nav': 130.16, 'totalReturn': 199.07575, 'date': '2024-07-24'},
#  {'nav': 129.75, 'totalReturn': 198.44866, 'date': '2024-07-25'},
#  {'nav': 131.27, 'totalReturn': 200.77346, 'date': '2024-07-26'},
#  {'nav': 131.28, 'totalReturn': 200.78875, 'date': '2024-07-29'},
#  {'nav': 130.73, 'totalReturn': 199.94754, 'date': '2024-07-30'},
#  {'nav': 132.63, 'totalReturn': 202.85353, 'date': '2024-07-31'},
#  {'nav': 130.65, 'totalReturn': 199.82519, 'date': '2024-08-01'},
#  {'nav': 128.02, 'totalReturn': 195.80268, 'date': '2024-08-02'},
#  {'nav': 124.21, 'totalReturn': 189.9754, 'date': '2024-08-05'},
#  {'nav': 125.5, 'totalReturn': 191.94842, 'date': '2024-08-06'},
#  {'nav': 124.5, 'totalReturn': 190.41895, 'date': '2024-08-07'},
#  {'nav': 127.4, 'totalReturn': 194.85441, 'date': '2024-08-08'},
#  {'nav': 127.97, 'totalReturn': 195.72621, 'date': '2024-08-09'},
#  {'nav': 127.86, 'totalReturn': 195.55797, 'date': '2024-08-12'},
#  {'nav': 130.01, 'totalReturn': 198.84632, 'date': '2024-08-13'},
#  {'nav': 130.44, 'totalReturn': 199.504, 'date': '2024-08-14'},
#  {'nav': 132.66, 'totalReturn': 202.89942, 'date': '2024-08-15'},
#  {'nav': 132.95, 'totalReturn': 203.34296, 'date': '2024-08-16'},
#  {'nav': 134.25, 'totalReturn': 205.33128, 'date': '2024-08-19'},
#  {'nav': 133.88, 'totalReturn': 204.76537, 'date': '2024-08-20'},
#  {'nav': 134.6, 'totalReturn': 205.86659, 'date': '2024-08-21'},
#  {'nav': 133.41, 'totalReturn': 204.04652, 'date': '2024-08-22'},
#  {'nav': 135.16, 'totalReturn': 206.72309, 'date': '2024-08-23'},
#  {'nav': 134.75, 'totalReturn': 206.09601, 'date': '2024-08-26'},
#  {'nav': 134.88, 'totalReturn': 206.29484, 'date': '2024-08-27'},
#  {'nav': 134.06, 'totalReturn': 205.04068, 'date': '2024-08-28'},
#  {'nav': 134.18, 'totalReturn': 205.22421, 'date': '2024-08-29'},
#  {'nav': 135.51, 'totalReturn': 207.25841, 'date': '2024-08-30'},
#  {'nav': 132.56, 'totalReturn': 202.74647, 'date': '2024-09-03'},
#  {'nav': 132.33, 'totalReturn': 202.39469, 'date': '2024-09-04'},
#  {'nav': 131.9, 'totalReturn': 201.73702, 'date': '2024-09-05'},
#  {'nav': 129.65, 'totalReturn': 198.29572, 'date': '2024-09-06'},
#  {'nav': 131.07, 'totalReturn': 200.46756, 'date': '2024-09-09'},
#  {'nav': 131.59, 'totalReturn': 201.26289, 'date': '2024-09-10'},
#  {'nav': 132.92, 'totalReturn': 203.29708, 'date': '2024-09-11'},
#  {'nav': 133.96, 'totalReturn': 204.88773, 'date': '2024-09-12'},
#  {'nav': 134.92, 'totalReturn': 206.35602, 'date': '2024-09-13'},
#  {'nav': 135.18, 'totalReturn': 206.75368, 'date': '2024-09-16'},
#  {'nav': 135.3, 'totalReturn': 206.93722, 'date': '2024-09-17'},
#  {'nav': 134.97, 'totalReturn': 206.43249, 'date': '2024-09-18'},
#  {'nav': 137.3, 'totalReturn': 209.99616, 'date': '2024-09-19'},
#  {'nav': 136.96, 'totalReturn': 209.47614, 'date': '2024-09-20'},
#  {'nav': 137.32, 'totalReturn': 210.02675, 'date': '2024-09-23'},
#  {'nav': 137.64, 'totalReturn': 210.51618, 'date': '2024-09-24'},
#  {'nav': 137.24, 'totalReturn': 209.90439, 'date': '2024-09-25'},
#  {'nav': 137.83, 'totalReturn': 210.80678, 'date': '2024-09-26'},
#  {'nav': 137.32, 'totalReturn': 210.67004, 'date': '2024-09-27'},
#  {'nav': 137.86, 'totalReturn': 211.49848, 'date': '2024-09-30'},
#  {'nav': 136.56, 'totalReturn': 209.50408, 'date': '2024-10-01'},
#  {'nav': 136.59, 'totalReturn': 209.55011, 'date': '2024-10-02'},
#  {'nav': 136.31, 'totalReturn': 209.12055, 'date': '2024-10-03'},
#  {'nav': 137.65, 'totalReturn': 211.17631, 'date': '2024-10-04'},
#  {'nav': 136.34, 'totalReturn': 209.16657, 'date': '2024-10-07'},
#  {'nav': 137.53, 'totalReturn': 210.99221, 'date': '2024-10-08'},
#  {'nav': 138.49, 'totalReturn': 212.465, 'date': '2024-10-09'},
#  {'nav': 138.21, 'totalReturn': 212.03544, 'date': '2024-10-10'},
#  {'nav': 139.27, 'totalReturn': 213.66164, 'date': '2024-10-11'},
#  {'nav': 140.3, 'totalReturn': 215.24182, 'date': '2024-10-14'},
#  {'nav': 139.37, 'totalReturn': 213.81506, 'date': '2024-10-15'},
#  {'nav': 140.13, 'totalReturn': 214.98101, 'date': '2024-10-16'},
#  {'nav': 140.09, 'totalReturn': 214.91965, 'date': '2024-10-17'},
#  {'nav': 140.61, 'totalReturn': 215.71741, 'date': '2024-10-18'},
#  {'nav': 140.17, 'totalReturn': 215.04238, 'date': '2024-10-21'},
#  {'nav': 140.03, 'totalReturn': 214.8276, 'date': '2024-10-22'},
#  {'nav': 138.78, 'totalReturn': 212.90991, 'date': '2024-10-23'},
#  {'nav': 139.1, 'totalReturn': 213.40084, 'date': '2024-10-24'},
#  {'nav': 138.98, 'totalReturn': 213.21674, 'date': '2024-10-25'},
#  {'nav': 139.51, 'totalReturn': 214.02984, 'date': '2024-10-28'},
#  {'nav': 139.73, 'totalReturn': 214.36735, 'date': '2024-10-29'},
#  {'nav': 139.31, 'totalReturn': 213.72301, 'date': '2024-10-30'},
#  {'nav': 136.82, 'totalReturn': 209.90296, 'date': '2024-10-31'},
#  {'nav': 137.39, 'totalReturn': 210.77743, 'date': '2024-11-01'},
#  {'nav': 137.08, 'totalReturn': 210.30184, 'date': '2024-11-04'},
#  {'nav': 138.85, 'totalReturn': 213.0173, 'date': '2024-11-05'},
#  {'nav': 142.74, 'totalReturn': 218.98516, 'date': '2024-11-06'},
#  {'nav': 143.73, 'totalReturn': 220.50397, 'date': '2024-11-07'},
#  {'nav': 144.36, 'totalReturn': 221.47049, 'date': '2024-11-08'},
#  {'nav': 144.79, 'totalReturn': 222.13017, 'date': '2024-11-11'},
#  {'nav': 144.23, 'totalReturn': 221.27105, 'date': '2024-11-12'},
#  {'nav': 144.14, 'totalReturn': 221.13297, 'date': '2024-11-13'},
#  {'nav': 143.16, 'totalReturn': 219.6295, 'date': '2024-11-14'},
#  {'nav': 141.29, 'totalReturn': 216.76063, 'date': '2024-11-15'},
#  {'nav': 141.88, 'totalReturn': 217.66578, 'date': '2024-11-18'},
#  {'nav': 142.54, 'totalReturn': 218.67833, 'date': '2024-11-19'},
#  {'nav': 142.62, 'totalReturn': 218.80106, 'date': '2024-11-20'},
#  {'nav': 143.61, 'totalReturn': 220.31987, 'date': '2024-11-21'},
#  {'nav': 144.38, 'totalReturn': 221.50117, 'date': '2024-11-22'},
#  {'nav': 145.01, 'totalReturn': 222.46769, 'date': '2024-11-25'},
#  {'nav': 145.63, 'totalReturn': 223.41886, 'date': '2024-11-26'},
#  {'nav': 145.14, 'totalReturn': 222.66713, 'date': '2024-11-27'},
#  {'nav': 145.89, 'totalReturn': 223.81774, 'date': '2024-11-29'},
#  {'nav': 146.21, 'totalReturn': 224.30867, 'date': '2024-12-02'},
#  {'nav': 146.23, 'totalReturn': 224.33935, 'date': '2024-12-03'},
#  {'nav': 147.23, 'totalReturn': 225.87351, 'date': '2024-12-04'},
#  {'nav': 146.8, 'totalReturn': 225.21382, 'date': '2024-12-05'},
#  {'nav': 147.26, 'totalReturn': 225.91953, 'date': '2024-12-06'},
#  {'nav': 146.25, 'totalReturn': 224.37004, 'date': '2024-12-09'},
#  {'nav': 145.69, 'totalReturn': 223.51091, 'date': '2024-12-10'},
#  {'nav': 146.9, 'totalReturn': 225.36724, 'date': '2024-12-11'},
#  {'nav': 146.03, 'totalReturn': 224.03252, 'date': '2024-12-12'},
#  {'nav': 145.97, 'totalReturn': 223.94047, 'date': '2024-12-13'},
#  {'nav': 146.59, 'totalReturn': 224.89165, 'date': '2024-12-16'},
#  {'nav': 145.87, 'totalReturn': 223.78706, 'date': '2024-12-17'},
#  {'nav': 141.29, 'totalReturn': 216.76063, 'date': '2024-12-18'},
#  {'nav': 141.12, 'totalReturn': 216.49983, 'date': '2024-12-19'},
#  {'nav': 142.69, 'totalReturn': 218.90845, 'date': '2024-12-20'},
#  {'nav': 143.11, 'totalReturn': 220.25068, 'date': '2024-12-23'},
#  {'nav': 144.66, 'totalReturn': 222.63618, 'date': '2024-12-24'},
#  {'nav': 144.71, 'totalReturn': 222.71313, 'date': '2024-12-26'},
#  {'nav': 143.08, 'totalReturn': 220.20451, 'date': '2024-12-27'},
#  {'nav': 141.57, 'totalReturn': 217.88057, 'date': '2024-12-30'},
#  {'nav': 141.03, 'totalReturn': 217.0495, 'date': '2024-12-31'},
#  {'nav': 140.8, 'totalReturn': 216.69552, 'date': '2025-01-02'},
#  {'nav': 142.66, 'totalReturn': 219.55812, 'date': '2025-01-03'},
#  {'nav': 143.42, 'totalReturn': 220.72778, 'date': '2025-01-06'},
#  {'nav': 141.84, 'totalReturn': 218.29611, 'date': '2025-01-07'},
#  {'nav': 142.02, 'totalReturn': 218.57314, 'date': '2025-01-08'},
#  {'nav': 139.84, 'totalReturn': 215.21805, 'date': '2025-01-10'},
#  {'nav': 140.09, 'totalReturn': 215.60281, 'date': '2025-01-13'},
#  {'nav': 140.41, 'totalReturn': 216.0953, 'date': '2025-01-14'},
#  {'nav': 142.98, 'totalReturn': 220.05061, 'date': '2025-01-15'},
#  {'nav': 142.84, 'totalReturn': 219.83514, 'date': '2025-01-16'},
#  {'nav': 144.19, 'totalReturn': 221.91283, 'date': '2025-01-17'},
#  {'nav': 145.6, 'totalReturn': 224.08287, 'date': '2025-01-21'},
#  {'nav': 146.32, 'totalReturn': 225.19097, 'date': '2025-01-22'},
#  {'nav': 147.07, 'totalReturn': 226.34524, 'date': '2025-01-23'},
#  {'nav': 146.7, 'totalReturn': 225.7758, 'date': '2025-01-24'},
#  {'nav': 144.6, 'totalReturn': 222.54384, 'date': '2025-01-27'},
#  {'nav': 145.88, 'totalReturn': 224.5138, 'date': '2025-01-28'},
#  {'nav': 145.25, 'totalReturn': 223.54421, 'date': '2025-01-29'},
#  {'nav': 146.13, 'totalReturn': 224.89855, 'date': '2025-01-30'},
#  {'nav': 145.39, 'totalReturn': 223.75967, 'date': '2025-01-31'},
#  {'nav': 144.26, 'totalReturn': 222.02057, 'date': '2025-02-03'},
#  {'nav': 145.32, 'totalReturn': 223.65194, 'date': '2025-02-04'},
#  {'nav': 145.98, 'totalReturn': 224.6677, 'date': '2025-02-05'},
#  {'nav': 146.41, 'totalReturn': 225.32948, 'date': '2025-02-06'},
#  {'nav': 145.03, 'totalReturn': 223.20562, 'date': '2025-02-07'},
#  {'nav': 145.97, 'totalReturn': 224.65231, 'date': '2025-02-10'},
#  {'nav': 145.86, 'totalReturn': 224.48301, 'date': '2025-02-11'},
#  {'nav': 145.42, 'totalReturn': 223.80584, 'date': '2025-02-12'},
#  {'nav': 146.94, 'totalReturn': 226.14517, 'date': '2025-02-13'},
#  {'nav': 146.95, 'totalReturn': 226.16056, 'date': '2025-02-14'},
#  {'nav': 147.36, 'totalReturn': 226.79156, 'date': '2025-02-18'},
#  {'nav': 147.54, 'totalReturn': 227.06859, 'date': '2025-02-19'},
#  {'nav': 146.76, 'totalReturn': 225.86814, 'date': '2025-02-20'},
#  {'nav': 144.03, 'totalReturn': 221.66659, 'date': '2025-02-21'},
#  {'nav': 143.29, 'totalReturn': 220.52771, 'date': '2025-02-24'},
#  {'nav': 142.57, 'totalReturn': 219.4196, 'date': '2025-02-25'},
#  {'nav': 142.63, 'totalReturn': 219.51195, 'date': '2025-02-26'},
#  {'nav': 140.42, 'totalReturn': 216.11069, 'date': '2025-02-27'},
#  {'nav': 142.61, 'totalReturn': 219.48117, 'date': '2025-02-28'},
#  {'nav': 139.99, 'totalReturn': 215.4489, 'date': '2025-03-03'},
#  {'nav': 138.29, 'totalReturn': 212.83255, 'date': '2025-03-04'},
#  {'nav': 139.88, 'totalReturn': 215.27961, 'date': '2025-03-05'},
#  {'nav': 137.24, 'totalReturn': 211.21657, 'date': '2025-03-06'},
#  {'nav': 137.97, 'totalReturn': 212.34006, 'date': '2025-03-07'},
#  {'nav': 134.15, 'totalReturn': 206.46097, 'date': '2025-03-10'},
#  {'nav': 133.29, 'totalReturn': 205.1374, 'date': '2025-03-11'},
#  {'nav': 133.91, 'totalReturn': 206.0916, 'date': '2025-03-12'},
#  {'nav': 131.95, 'totalReturn': 203.0751, 'date': '2025-03-13'},
#  {'nav': 134.88, 'totalReturn': 207.58446, 'date': '2025-03-14'},
#  {'nav': 135.9, 'totalReturn': 209.15427, 'date': '2025-03-17'},
#  {'nav': 134.45, 'totalReturn': 206.92267, 'date': '2025-03-18'},
#  {'nav': 136.0, 'totalReturn': 209.30817, 'date': '2025-03-19'},
#  {'nav': 135.67, 'totalReturn': 208.80029, 'date': '2025-03-20'},
#  {'nav': 135.74, 'totalReturn': 208.90802, 'date': '2025-03-21'},
#  {'nav': 138.31, 'totalReturn': 212.86333, 'date': '2025-03-24'},
#  {'nav': 138.45, 'totalReturn': 213.0788, 'date': '2025-03-25'},
#  {'nav': 136.88, 'totalReturn': 210.66252, 'date': '2025-03-26'},
#  {'nav': 135.84, 'totalReturn': 209.79435, 'date': '2025-03-27'},
#  {'nav': 133.14, 'totalReturn': 205.62441, 'date': '2025-03-28'},
#  {'nav': 133.75, 'totalReturn': 206.56651, 'date': '2025-03-31'},
#  {'nav': 134.28, 'totalReturn': 207.38505, 'date': '2025-04-01'},
#  {'nav': 135.36, 'totalReturn': 209.05303, 'date': '2025-04-02'},
#  {'nav': 128.49, 'totalReturn': 198.44285, 'date': '2025-04-03'},
#  {'nav': 120.94, 'totalReturn': 186.78246, 'date': '2025-04-04'},
#  {'nav': 120.57, 'totalReturn': 186.21102, 'date': '2025-04-07'},
#  {'nav': 118.56, 'totalReturn': 183.10673, 'date': '2025-04-08'},
#  {'nav': 129.87, 'totalReturn': 200.57415, 'date': '2025-04-09'},
#  {'nav': 125.27, 'totalReturn': 193.46981, 'date': '2025-04-10'},
#  {'nav': 127.49, 'totalReturn': 196.89842, 'date': '2025-04-11'},
#  {'nav': 128.54, 'totalReturn': 198.52007, 'date': '2025-04-14'},
#  {'nav': 128.38, 'totalReturn': 198.27296, 'date': '2025-04-15'},
#  {'nav': 125.68, 'totalReturn': 194.10302, 'date': '2025-04-16'},
#  {'nav': 125.97, 'totalReturn': 194.5509, 'date': '2025-04-17'},
#  {'nav': 123.01, 'totalReturn': 189.97941, 'date': '2025-04-21'},
#  {'nav': 126.14, 'totalReturn': 194.81345, 'date': '2025-04-22'},
#  {'nav': 128.27, 'totalReturn': 198.10307, 'date': '2025-04-23'},
#  {'nav': 130.93, 'totalReturn': 202.21124, 'date': '2025-04-24'},
#  {'nav': 131.81, 'totalReturn': 203.57033, 'date': '2025-04-25'},
#  {'nav': 131.96, 'totalReturn': 203.80199, 'date': '2025-04-28'},
#  {'nav': 132.74, 'totalReturn': 205.00664, 'date': '2025-04-29'},
#  {'nav': 132.85, 'totalReturn': 205.17653, 'date': '2025-04-30'},
#  {'nav': 133.67, 'totalReturn': 206.44296, 'date': '2025-05-01'},
#  {'nav': 135.75, 'totalReturn': 209.65535, 'date': '2025-05-02'},
#  {'nav': 134.93, 'totalReturn': 208.38893, 'date': '2025-05-05'},
#  {'nav': 133.86, 'totalReturn': 206.7364, 'date': '2025-05-06'},
#  {'nav': 134.42, 'totalReturn': 207.60127, 'date': '2025-05-07'},
#  {'nav': 135.4, 'totalReturn': 209.11481, 'date': '2025-05-08'},
#  {'nav': 135.32, 'totalReturn': 208.99125, 'date': '2025-05-09'},
#  {'nav': 139.8, 'totalReturn': 215.91027, 'date': '2025-05-12'},
#  {'nav': 140.83, 'totalReturn': 217.50102, 'date': '2025-05-13'},
#  {'nav': 140.88, 'totalReturn': 217.57824, 'date': '2025-05-14'},
#  {'nav': 141.43, 'totalReturn': 218.42767, 'date': '2025-05-15'},
#  {'nav': 142.5, 'totalReturn': 220.08021, 'date': '2025-05-16'},
#  {'nav': 142.59, 'totalReturn': 220.2192, 'date': '2025-05-19'},
#  {'nav': 142.08, 'totalReturn': 219.43155, 'date': '2025-05-20'},
#  {'nav': 139.61, 'totalReturn': 215.61682, 'date': '2025-05-21'},
#  {'nav': 139.59, 'totalReturn': 215.58594, 'date': '2025-05-22'},
#  {'nav': 138.71, 'totalReturn': 214.22684, 'date': '2025-05-23'},
#  {'nav': 141.6, 'totalReturn': 218.69023, 'date': '2025-05-27'},
#  {'nav': 140.75, 'totalReturn': 217.37747, 'date': '2025-05-28'},
#  {'nav': 141.28, 'totalReturn': 218.19601, 'date': '2025-05-29'},
#  {'nav': 141.28, 'totalReturn': 218.19601, 'date': '2025-05-30'},
#  {'nav': 141.83, 'totalReturn': 219.04544, 'date': '2025-06-02'},
#  {'nav': 142.78, 'totalReturn': 220.51264, 'date': '2025-06-03'},
#  {'nav': 142.8, 'totalReturn': 220.54353, 'date': '2025-06-04'},
#  {'nav': 142.15, 'totalReturn': 219.53966, 'date': '2025-06-05'},
#  {'nav': 143.67, 'totalReturn': 221.88718, 'date': '2025-06-06'},
#  {'nav': 143.81, 'totalReturn': 222.1034, 'date': '2025-06-09'},
#  {'nav': 144.54, 'totalReturn': 223.23083, 'date': '2025-06-10'},
#  {'nav': 144.15, 'totalReturn': 222.6285, 'date': '2025-06-11'},
#  {'nav': 144.6, 'totalReturn': 223.32349, 'date': '2025-06-12'},
#  {'nav': 142.91, 'totalReturn': 220.71342, 'date': '2025-06-13'},
#  {'nav': 144.31, 'totalReturn': 222.87561, 'date': '2025-06-16'},
#  {'nav': 143.11, 'totalReturn': 221.0223, 'date': '2025-06-17'},
#  {'nav': 143.17, 'totalReturn': 221.11497, 'date': '2025-06-18'},
#  {'nav': 142.87, 'totalReturn': 220.65164, 'date': '2025-06-20'},
#  {'nav': 144.22, 'totalReturn': 222.73661, 'date': '2025-06-23'},
#  {'nav': 145.88, 'totalReturn': 225.30035, 'date': '2025-06-24'},
#  {'nav': 145.69, 'totalReturn': 225.00691, 'date': '2025-06-25'},
#  {'nav': 146.97, 'totalReturn': 226.98377, 'date': '2025-06-26'},
#  {'nav': 147.67, 'totalReturn': 228.06487, 'date': '2025-06-27'},
#  {'nav': 148.01, 'totalReturn': 229.27106, 'date': '2025-06-30'},
#  {'nav': 147.93, 'totalReturn': 229.14714, 'date': '2025-07-01'},
#  {'nav': 148.73, 'totalReturn': 230.38636, 'date': '2025-07-02'},
#  {'nav': 150.01, 'totalReturn': 232.36911, 'date': '2025-07-03'},
#  {'nav': 148.8, 'totalReturn': 230.49479, 'date': '2025-07-07'},
#  {'nav': 148.74, 'totalReturn': 230.40185, 'date': '2025-07-08'},
#  {'nav': 149.69, 'totalReturn': 231.87342, 'date': '2025-07-09'},
#  {'nav': 150.1, 'totalReturn': 232.50852, 'date': '2025-07-10'},
#  {'nav': 149.48, 'totalReturn': 231.54813, 'date': '2025-07-11'}]

# %% [markdown]
# Holdings of the fund

# %%
funds.holdings()
# Out:
#                     securityName       secId performanceId holdingTypeId  \
# 0                 Microsoft Corp  0P000003MH    0P000003MH             E
# 1                    NVIDIA Corp  0P000003RE    0P000003RE             E
# 2                      Apple Inc  0P000000GY    0P000000GY             E
# 3                 Amazon.com Inc  0P000000B7    0P000000B7             E
# 4     Meta Platforms Inc Class A  0P0000W3KZ    0P0000W3KZ             E
# ...                          ...         ...           ...           ...
# 3556        Usd/Eur Fwd 20250530        None          None            CU
# 3557                        Euro        None          None            CH
# 3558          Btcs Incorporation  B10003UJJ6          None             P
# 3559        Eur/Usd Fwd 20250530        None          None            CU
# 3560                   Us Dollar        None          None            CH
#
#       weighting  numberOfShare   marketValue  shareChange        country  \
# 0       6.02457    238818012.0  1.099423e+11     282870.0  United States
# 1       5.51387    744635666.0  1.006226e+11     870143.0  United States
# 2       5.31119    482568559.0  9.692390e+10     565311.0  United States
# 3       3.44210    306398771.0  6.281481e+10     354439.0  United States
# 4       2.49597     70346890.0  4.554891e+10      80511.0  United States
# ...         ...            ...           ...          ...            ...
# 3556    0.00036      6518119.0  6.518119e+06    6518119.0           None
# 3557    0.00030      4885284.0  5.546996e+06    4885284.0           None
# 3558    0.00000       280193.0  3.000000e+00          0.0  United States
# 3559   -0.00036      5747394.0 -6.525878e+06    5747394.0           None
# 3560   -0.00103     18878765.0 -1.887876e+07   18878765.0           None
#
#      ticker  ...  susEsgRiskCategory  managementExpenseRatio qualRating  \
# 0      MSFT  ...                 Low                    None       None
# 1      NVDA  ...                 Low                    None       None
# 2      AAPL  ...                 Low                    None       None
# 3      AMZN  ...              Medium                    None       None
# 4      META  ...                High                    None       None
# ...     ...  ...                 ...                     ...        ...
# 3556   None  ...                None                    None       None
# 3557   None  ...                None                    None       None
# 3558   None  ...                None                    None       None
# 3559   None  ...                None                    None       None
# 3560   None  ...                None                    None       None
#
#      quantRating bestRatingType securityType domicileCountryId currencyName  \
# 0              3           Qual           ST               USA    US Dollar
# 1              2           Qual           ST               USA    US Dollar
# 2              2           Qual           ST               USA    US Dollar
# 3              3           Qual           ST               USA    US Dollar
# 4              3           Qual           ST               USA    US Dollar
# ...          ...            ...          ...               ...          ...
# 3556        None           None         None              None         None
# 3557        None           None         None              None         None
# 3558        None           None         None              None    US Dollar
# 3559        None           None         None              None         None
# 3560        None           None         None              None         None
#
#      originalMarketValue isMomentumFilterFlag
# 0           1.099423e+11                False
# 1           1.006226e+11                False
# 2           9.692390e+10                False
# 3           6.281481e+10                False
# 4           4.554891e+10                False
# ...                  ...                  ...
# 3556        6.518119e+06                 None
# 3557        5.546996e+06                 None
# 3558        3.000000e+00                 None
# 3559       -6.525878e+06                 None
# 3560       -1.887876e+07                 None
#
# [3561 rows x 57 columns]

# %% [markdown]
# You can access many other methods to retrieve detailed information about the fund.
#
# Examples are available in this notebook:
#
# <a href="https://github.com/Mael-J/mstarpy/blob/pre-release/examples/MStarpy%20-%20Funds%20example.ipynb">MStarpy - Funds example</a>

# %% [markdown]
# ## Stock analysis
#
# Initialize Stock to start you analysis

# %%
stock = ms.Stock("FR0000121014")

# %% [markdown]
# Get historical price of the stock

# %%
import datetime
end_date = datetime.datetime.today()
start_date = end_date - datetime.timedelta(days=365)
stock.historical(start_date, end_date)
# Out:
# [{'open': 722.7,
#   'high': 722.7,
#   'low': 722.4,
#   'close': 722.7,
#   'volume': 0,
#   'previousClose': 709.5,
#   'date': '2024-07-12'},
#  {'open': 722.5,
#   'high': 722.5,
#   'low': 705.7,
#   'close': 705.7,
#   'volume': 0,
#   'previousClose': 722.7,
#   'date': '2024-07-15'},
#  {'open': 698.1,
#   'high': 700.8,
#   'low': 696.8,
#   'close': 698.5,
#   'volume': 3,
#   'previousClose': 705.7,
#   'date': '2024-07-16'},
#  {'open': 693.8,
#   'high': 693.8,
#   'low': 690.1,
#   'close': 690.3,
#   'volume': 0,
#   'previousClose': 698.5,
#   'date': '2024-07-17'},
#  {'open': 696.1,
#   'high': 698.7,
#   'low': 695.9,
#   'close': 696.4,
#   'volume': 24,
#   'previousClose': 690.3,
#   'date': '2024-07-18'},
#  {'open': 690.1,
#   'high': 690.1,
#   'low': 680.8,
#   'close': 680.8,
#   'volume': 11,
#   'previousClose': 696.4,
#   'date': '2024-07-19'},
#  {'open': 686.9,
#   'high': 694.4,
#   'low': 686.9,
#   'close': 694.4,
#   'volume': 0,
#   'previousClose': 680.8,
#   'date': '2024-07-22'},
#  {'open': 704.8,
#   'high': 704.8,
#   'low': 694.3,
#   'close': 694.3,
#   'volume': 0,
#   'previousClose': 694.4,
#   'date': '2024-07-23'},
#  {'open': 660.2,
#   'high': 671.9,
#   'low': 660.2,
#   'close': 671.9,
#   'volume': 9,
#   'previousClose': 694.3,
#   'date': '2024-07-24'},
#  {'open': 654.1,
#   'high': 655.1,
#   'low': 651.0,
#   'close': 651.0,
#   'volume': 8,
#   'previousClose': 671.9,
#   'date': '2024-07-25'},
#  {'open': 653.5,
#   'high': 665.9,
#   'low': 653.5,
#   'close': 662.6,
#   'volume': 2,
#   'previousClose': 651.0,
#   'date': '2024-07-26'},
#  {'open': 669.0,
#   'high': 669.0,
#   'low': 652.0,
#   'close': 656.1,
#   'volume': 13,
#   'previousClose': 662.6,
#   'date': '2024-07-29'},
#  {'open': 657.5,
#   'high': 658.7,
#   'low': 657.0,
#   'close': 658.7,
#   'volume': 0,
#   'previousClose': 656.1,
#   'date': '2024-07-30'},
#  {'open': 654.0,
#   'high': 659.6,
#   'low': 654.0,
#   'close': 656.3,
#   'volume': 0,
#   'previousClose': 658.7,
#   'date': '2024-07-31'},
#  {'open': 646.8,
#   'high': 647.1,
#   'low': 642.3,
#   'close': 644.0,
#   'volume': 54,
#   'previousClose': 656.3,
#   'date': '2024-08-01'},
#  {'open': 639.8,
#   'high': 639.8,
#   'low': 632.2,
#   'close': 632.2,
#   'volume': 2,
#   'previousClose': 644.0,
#   'date': '2024-08-02'},
#  {'open': 620.0,
#   'high': 620.0,
#   'low': 614.3,
#   'close': 615.3,
#   'volume': 10,
#   'previousClose': 632.2,
#   'date': '2024-08-05'},
#  {'open': 622.6,
#   'high': 622.6,
#   'low': 617.3,
#   'close': 617.3,
#   'volume': 0,
#   'previousClose': 615.3,
#   'date': '2024-08-06'},
#  {'open': 623.0,
#   'high': 635.2,
#   'low': 623.0,
#   'close': 634.0,
#   'volume': 11,
#   'previousClose': 617.3,
#   'date': '2024-08-07'},
#  {'open': 627.0,
#   'high': 628.8,
#   'low': 623.8,
#   'close': 628.8,
#   'volume': 5,
#   'previousClose': 634.0,
#   'date': '2024-08-08'},
#  {'open': 635.7,
#   'high': 642.2,
#   'low': 634.4,
#   'close': 634.4,
#   'volume': 2,
#   'previousClose': 628.8,
#   'date': '2024-08-09'},
#  {'open': 640.1,
#   'high': 640.1,
#   'low': 636.3,
#   'close': 636.3,
#   'volume': 0,
#   'previousClose': 634.4,
#   'date': '2024-08-12'},
#  {'open': 638.4,
#   'high': 638.4,
#   'low': 626.4,
#   'close': 628.0,
#   'volume': 4,
#   'previousClose': 636.3,
#   'date': '2024-08-13'},
#  {'open': 640.1,
#   'high': 643.8,
#   'low': 640.1,
#   'close': 643.0,
#   'volume': 0,
#   'previousClose': 628.0,
#   'date': '2024-08-14'},
#  {'open': 644.9,
#   'high': 658.8,
#   'low': 643.6,
#   'close': 658.8,
#   'volume': 4,
#   'previousClose': 643.0,
#   'date': '2024-08-15'},
#  {'open': 660.0,
#   'high': 660.0,
#   'low': 658.4,
#   'close': 658.4,
#   'volume': 0,
#   'previousClose': 658.8,
#   'date': '2024-08-16'},
#  {'open': 661.3,
#   'high': 670.8,
#   'low': 661.3,
#   'close': 670.8,
#   'volume': 1,
#   'previousClose': 658.4,
#   'date': '2024-08-19'},
#  {'open': 676.3,
#   'high': 679.1,
#   'low': 676.3,
#   'close': 677.0,
#   'volume': 7,
#   'previousClose': 670.8,
#   'date': '2024-08-20'},
#  {'open': 678.5,
#   'high': 680.7,
#   'low': 676.7,
#   'close': 680.7,
#   'volume': 0,
#   'previousClose': 677.0,
#   'date': '2024-08-21'},
#  {'open': 680.2,
#   'high': 685.0,
#   'low': 680.2,
#   'close': 683.5,
#   'volume': 5,
#   'previousClose': 680.7,
#   'date': '2024-08-22'},
#  {'open': 678.9,
#   'high': 680.1,
#   'low': 676.0,
#   'close': 676.0,
#   'volume': 0,
#   'previousClose': 683.5,
#   'date': '2024-08-23'},
#  {'open': 682.1,
#   'high': 684.7,
#   'low': 682.1,
#   'close': 684.2,
#   'volume': 0,
#   'previousClose': 676.0,
#   'date': '2024-08-26'},
#  {'open': 685.1,
#   'high': 685.1,
#   'low': 668.0,
#   'close': 668.0,
#   'volume': 4,
#   'previousClose': 684.2,
#   'date': '2024-08-27'},
#  {'open': 671.3,
#   'high': 672.8,
#   'low': 671.3,
#   'close': 671.4,
#   'volume': 0,
#   'previousClose': 668.0,
#   'date': '2024-08-28'},
#  {'open': 670.0,
#   'high': 675.6,
#   'low': 670.0,
#   'close': 675.6,
#   'volume': 4,
#   'previousClose': 671.4,
#   'date': '2024-08-29'},
#  {'open': 680.7,
#   'high': 686.2,
#   'low': 677.9,
#   'close': 677.9,
#   'volume': 0,
#   'previousClose': 675.6,
#   'date': '2024-08-30'},
#  {'open': 667.2,
#   'high': 669.4,
#   'low': 665.3,
#   'close': 669.4,
#   'volume': 0,
#   'previousClose': 677.9,
#   'date': '2024-09-02'},
#  {'open': 677.3,
#   'high': 677.3,
#   'low': 675.2,
#   'close': 675.2,
#   'volume': 3,
#   'previousClose': 669.4,
#   'date': '2024-09-03'},
#  {'open': 653.3,
#   'high': 653.3,
#   'low': 642.1,
#   'close': 642.1,
#   'volume': 0,
#   'previousClose': 675.2,
#   'date': '2024-09-04'},
#  {'open': 637.7,
#   'high': 637.7,
#   'low': 618.9,
#   'close': 618.9,
#   'volume': 1,
#   'previousClose': 642.1,
#   'date': '2024-09-05'},
#  {'open': 621.8,
#   'high': 621.8,
#   'low': 616.6,
#   'close': 619.1,
#   'volume': 1,
#   'previousClose': 618.9,
#   'date': '2024-09-06'},
#  {'open': 610.7,
#   'high': 616.2,
#   'low': 610.7,
#   'close': 616.0,
#   'volume': 0,
#   'previousClose': 619.1,
#   'date': '2024-09-09'},
#  {'open': 615.6,
#   'high': 616.6,
#   'low': 612.9,
#   'close': 612.9,
#   'volume': 31,
#   'previousClose': 616.0,
#   'date': '2024-09-10'},
#  {'open': 613.9,
#   'high': 614.6,
#   'low': 610.8,
#   'close': 610.8,
#   'volume': 0,
#   'previousClose': 612.9,
#   'date': '2024-09-11'},
#  {'open': 615.0,
#   'high': 615.0,
#   'low': 603.8,
#   'close': 607.7,
#   'volume': 63,
#   'previousClose': 610.8,
#   'date': '2024-09-12'},
#  {'open': 609.3,
#   'high': 611.3,
#   'low': 608.8,
#   'close': 608.8,
#   'volume': 3,
#   'previousClose': 607.7,
#   'date': '2024-09-13'},
#  {'open': 609.7,
#   'high': 612.5,
#   'low': 605.7,
#   'close': 607.5,
#   'volume': 23,
#   'previousClose': 608.8,
#   'date': '2024-09-16'},
#  {'open': 605.4,
#   'high': 609.7,
#   'low': 605.4,
#   'close': 609.7,
#   'volume': 5,
#   'previousClose': 607.5,
#   'date': '2024-09-17'},
#  {'open': 607.7,
#   'high': 607.7,
#   'low': 601.2,
#   'close': 601.2,
#   'volume': 2,
#   'previousClose': 609.7,
#   'date': '2024-09-18'},
#  {'open': 606.5,
#   'high': 617.4,
#   'low': 606.5,
#   'close': 613.4,
#   'volume': 3,
#   'previousClose': 601.2,
#   'date': '2024-09-19'},
#  {'open': 605.8,
#   'high': 605.8,
#   'low': 593.9,
#   'close': 597.0,
#   'volume': 5,
#   'previousClose': 613.4,
#   'date': '2024-09-20'},
#  {'open': 585.5,
#   'high': 589.7,
#   'low': 583.5,
#   'close': 589.7,
#   'volume': 29,
#   'previousClose': 597.0,
#   'date': '2024-09-23'},
#  {'open': 621.9,
#   'high': 621.9,
#   'low': 613.0,
#   'close': 613.0,
#   'volume': 9,
#   'previousClose': 589.7,
#   'date': '2024-09-24'},
#  {'open': 612.4,
#   'high': 617.5,
#   'low': 612.4,
#   'close': 616.6,
#   'volume': 0,
#   'previousClose': 613.0,
#   'date': '2024-09-25'},
#  {'open': 624.5,
#   'high': 681.0,
#   'low': 624.5,
#   'close': 681.0,
#   'volume': 21,
#   'previousClose': 616.6,
#   'date': '2024-09-26'},
#  {'open': 700.5,
#   'high': 702.4,
#   'low': 685.3,
#   'close': 700.5,
#   'volume': 44,
#   'previousClose': 681.0,
#   'date': '2024-09-27'},
#  {'open': 701.8,
#   'high': 701.8,
#   'low': 693.1,
#   'close': 694.1,
#   'volume': 0,
#   'previousClose': 700.5,
#   'date': '2024-09-30'},
#  {'open': 683.1,
#   'high': 683.1,
#   'low': 678.4,
#   'close': 678.4,
#   'volume': 0,
#   'previousClose': 694.1,
#   'date': '2024-10-01'},
#  {'open': 669.7,
#   'high': 671.5,
#   'low': 656.5,
#   'close': 656.5,
#   'volume': 16,
#   'previousClose': 678.4,
#   'date': '2024-10-02'},
#  {'open': 663.9,
#   'high': 663.9,
#   'low': 656.5,
#   'close': 656.5,
#   'volume': 0,
#   'previousClose': 656.5,
#   'date': '2024-10-03'},
#  {'open': 660.4,
#   'high': 668.0,
#   'low': 646.5,
#   'close': 646.5,
#   'volume': 17,
#   'previousClose': 656.5,
#   'date': '2024-10-04'},
#  {'open': 671.2,
#   'high': 675.2,
#   'low': 670.7,
#   'close': 675.2,
#   'volume': 0,
#   'previousClose': 646.5,
#   'date': '2024-10-07'},
#  {'open': 655.9,
#   'high': 656.3,
#   'low': 655.5,
#   'close': 655.5,
#   'volume': 0,
#   'previousClose': 675.2,
#   'date': '2024-10-08'},
#  {'open': 664.0,
#   'high': 664.0,
#   'low': 650.8,
#   'close': 655.5,
#   'volume': 15,
#   'previousClose': 655.5,
#   'date': '2024-10-09'},
#  {'open': 652.9,
#   'high': 657.5,
#   'low': 652.9,
#   'close': 653.0,
#   'volume': 1,
#   'previousClose': 655.5,
#   'date': '2024-10-10'},
#  {'open': 653.0,
#   'high': 653.6,
#   'low': 651.2,
#   'close': 653.6,
#   'volume': 15,
#   'previousClose': 653.0,
#   'date': '2024-10-11'},
#  {'open': 644.8,
#   'high': 653.0,
#   'low': 633.9,
#   'close': 653.0,
#   'volume': 26,
#   'previousClose': 653.6,
#   'date': '2024-10-14'},
#  {'open': 627.6,
#   'high': 631.5,
#   'low': 627.6,
#   'close': 631.5,
#   'volume': 0,
#   'previousClose': 653.0,
#   'date': '2024-10-15'},
#  {'open': 621.0,
#   'high': 621.0,
#   'low': 596.4,
#   'close': 598.8,
#   'volume': 11,
#   'previousClose': 631.5,
#   'date': '2024-10-16'},
#  {'open': 599.7,
#   'high': 611.7,
#   'low': 599.7,
#   'close': 609.9,
#   'volume': 0,
#   'previousClose': 598.8,
#   'date': '2024-10-17'},
#  {'open': 627.0,
#   'high': 627.7,
#   'low': 623.1,
#   'close': 623.1,
#   'volume': 1,
#   'previousClose': 609.9,
#   'date': '2024-10-18'},
#  {'open': 622.1,
#   'high': 622.1,
#   'low': 610.3,
#   'close': 610.3,
#   'volume': 0,
#   'previousClose': 623.1,
#   'date': '2024-10-21'},
#  {'open': 613.1,
#   'high': 630.0,
#   'low': 611.5,
#   'close': 630.0,
#   'volume': 3,
#   'previousClose': 610.3,
#   'date': '2024-10-22'},
#  {'open': 611.9,
#   'high': 613.2,
#   'low': 610.1,
#   'close': 612.8,
#   'volume': 0,
#   'previousClose': 630.0,
#   'date': '2024-10-23'},
#  {'open': 612.2,
#   'high': 633.9,
#   'low': 612.2,
#   'close': 630.0,
#   'volume': 3,
#   'previousClose': 612.8,
#   'date': '2024-10-24'},
#  {'open': 627.5,
#   'high': 630.0,
#   'low': 622.8,
#   'close': 630.0,
#   'volume': 13,
#   'previousClose': 630.0,
#   'date': '2024-10-25'},
#  {'open': 632.6,
#   'high': 633.5,
#   'low': 629.1,
#   'close': 633.5,
#   'volume': 0,
#   'previousClose': 630.0,
#   'date': '2024-10-28'},
#  {'open': 633.0,
#   'high': 637.1,
#   'low': 631.2,
#   'close': 631.2,
#   'volume': 0,
#   'previousClose': 633.5,
#   'date': '2024-10-29'},
#  {'open': 635.3,
#   'high': 635.3,
#   'low': 609.2,
#   'close': 617.4,
#   'volume': 30,
#   'previousClose': 631.2,
#   'date': '2024-10-30'},
#  {'open': 610.9,
#   'high': 615.3,
#   'low': 609.3,
#   'close': 609.4,
#   'volume': 2,
#   'previousClose': 617.4,
#   'date': '2024-10-31'},
#  {'open': 611.7,
#   'high': 612.0,
#   'low': 608.7,
#   'close': 610.6,
#   'volume': 5,
#   'previousClose': 609.4,
#   'date': '2024-11-01'},
#  {'open': 612.0,
#   'high': 618.0,
#   'low': 607.8,
#   'close': 607.8,
#   'volume': 0,
#   'previousClose': 610.6,
#   'date': '2024-11-04'},
#  {'open': 607.8,
#   'high': 607.8,
#   'low': 601.0,
#   'close': 603.3,
#   'volume': 4,
#   'previousClose': 607.8,
#   'date': '2024-11-05'},
#  {'open': 605.1,
#   'high': 618.3,
#   'low': 600.0,
#   'close': 600.3,
#   'volume': 1,
#   'previousClose': 603.3,
#   'date': '2024-11-06'},
#  {'open': 599.1,
#   'high': 620.8,
#   'low': 599.1,
#   'close': 620.8,
#   'volume': 1,
#   'previousClose': 600.3,
#   'date': '2024-11-07'},
#  {'open': 614.1,
#   'high': 614.1,
#   'low': 597.3,
#   'close': 597.3,
#   'volume': 2,
#   'previousClose': 620.8,
#   'date': '2024-11-08'},
#  {'open': 602.0,
#   'high': 603.8,
#   'low': 597.8,
#   'close': 597.8,
#   'volume': 3,
#   'previousClose': 597.3,
#   'date': '2024-11-11'},
#  {'open': 594.5,
#   'high': 594.5,
#   'low': 569.2,
#   'close': 569.2,
#   'volume': 0,
#   'previousClose': 597.8,
#   'date': '2024-11-12'},
#  {'open': 573.3,
#   'high': 577.1,
#   'low': 571.0,
#   'close': 572.9,
#   'volume': 0,
#   'previousClose': 569.2,
#   'date': '2024-11-13'},
#  {'open': 568.5,
#   'high': 585.9,
#   'low': 568.5,
#   'close': 585.9,
#   'volume': 28,
#   'previousClose': 572.9,
#   'date': '2024-11-14'},
#  {'open': 584.5,
#   'high': 589.0,
#   'low': 584.5,
#   'close': 585.9,
#   'volume': 13,
#   'previousClose': 585.9,
#   'date': '2024-11-15'},
#  {'open': 591.3,
#   'high': 591.3,
#   'low': 583.9,
#   'close': 588.7,
#   'volume': 6,
#   'previousClose': 585.9,
#   'date': '2024-11-18'},
#  {'open': 589.3,
#   'high': 589.3,
#   'low': 570.1,
#   'close': 577.4,
#   'volume': 2,
#   'previousClose': 588.7,
#   'date': '2024-11-19'},
#  {'open': 581.6,
#   'high': 581.8,
#   'low': 576.6,
#   'close': 576.6,
#   'volume': 0,
#   'previousClose': 577.4,
#   'date': '2024-11-20'},
#  {'open': 569.2,
#   'high': 574.1,
#   'low': 569.2,
#   'close': 574.1,
#   'volume': 0,
#   'previousClose': 576.6,
#   'date': '2024-11-21'},
#  {'open': 580.0,
#   'high': 583.4,
#   'low': 575.9,
#   'close': 583.4,
#   'volume': 0,
#   'previousClose': 574.1,
#   'date': '2024-11-22'},
#  {'open': 596.1,
#   'high': 596.1,
#   'low': 591.6,
#   'close': 594.6,
#   'volume': 17,
#   'previousClose': 583.4,
#   'date': '2024-11-25'},
#  {'open': 590.7,
#   'high': 603.1,
#   'low': 590.7,
#   'close': 596.7,
#   'volume': 0,
#   'previousClose': 594.6,
#   'date': '2024-11-26'},
#  {'open': 590.5,
#   'high': 590.5,
#   'low': 587.4,
#   'close': 588.9,
#   'volume': 3,
#   'previousClose': 596.7,
#   'date': '2024-11-27'},
#  {'open': 592.8,
#   'high': 592.8,
#   'low': 586.7,
#   'close': 586.7,
#   'volume': 1,
#   'previousClose': 588.9,
#   'date': '2024-11-28'},
#  {'open': 585.9,
#   'high': 592.0,
#   'low': 585.9,
#   'close': 592.0,
#   'volume': 0,
#   'previousClose': 586.7,
#   'date': '2024-11-29'},
#  {'open': 587.5,
#   'high': 607.8,
#   'low': 586.7,
#   'close': 607.8,
#   'volume': 72,
#   'previousClose': 592.0,
#   'date': '2024-12-02'},
#  {'open': 610.4,
#   'high': 615.0,
#   'low': 606.9,
#   'close': 609.8,
#   'volume': 45,
#   'previousClose': 607.8,
#   'date': '2024-12-03'},
#  {'open': 611.7,
#   'high': 613.4,
#   'low': 608.0,
#   'close': 610.9,
#   'volume': 1,
#   'previousClose': 609.8,
#   'date': '2024-12-04'},
#  {'open': 609.2,
#   'high': 609.8,
#   'low': 605.9,
#   'close': 609.8,
#   'volume': 22,
#   'previousClose': 610.9,
#   'date': '2024-12-05'},
#  {'open': 603.8,
#   'high': 631.7,
#   'low': 603.8,
#   'close': 631.5,
#   'volume': 0,
#   'previousClose': 609.8,
#   'date': '2024-12-06'},
#  {'open': 647.9,
#   'high': 653.5,
#   'low': 641.4,
#   'close': 652.7,
#   'volume': 5,
#   'previousClose': 631.5,
#   'date': '2024-12-09'},
#  {'open': 643.1,
#   'high': 643.1,
#   'low': 634.9,
#   'close': 634.9,
#   'volume': 21,
#   'previousClose': 652.7,
#   'date': '2024-12-10'},
#  {'open': 631.5,
#   'high': 645.7,
#   'low': 631.5,
#   'close': 645.7,
#   'volume': 10,
#   'previousClose': 634.9,
#   'date': '2024-12-11'},
#  {'open': 641.0,
#   'high': 650.5,
#   'low': 637.3,
#   'close': 647.1,
#   'volume': 26,
#   'previousClose': 645.7,
#   'date': '2024-12-12'},
#  {'open': 639.6,
#   'high': 646.3,
#   'low': 637.8,
#   'close': 637.8,
#   'volume': 0,
#   'previousClose': 647.1,
#   'date': '2024-12-13'},
#  {'open': 632.2,
#   'high': 632.7,
#   'low': 629.1,
#   'close': 630.1,
#   'volume': 0,
#   'previousClose': 637.8,
#   'date': '2024-12-16'},
#  {'open': 626.9,
#   'high': 637.6,
#   'low': 626.9,
#   'close': 634.6,
#   'volume': 0,
#   'previousClose': 630.1,
#   'date': '2024-12-17'},
#  {'open': 635.2,
#   'high': 637.1,
#   'low': 633.2,
#   'close': 637.1,
#   'volume': 0,
#   'previousClose': 634.6,
#   'date': '2024-12-18'},
#  {'open': 627.3,
#   'high': 630.7,
#   'low': 615.0,
#   'close': 629.2,
#   'volume': 44,
#   'previousClose': 637.1,
#   'date': '2024-12-19'},
#  {'open': 625.7,
#   'high': 631.7,
#   'low': 619.1,
#   'close': 631.7,
#   'volume': 16,
#   'previousClose': 629.2,
#   'date': '2024-12-20'},
#  {'open': 627.1,
#   'high': 628.2,
#   'low': 624.4,
#   'close': 628.2,
#   'volume': 0,
#   'previousClose': 631.7,
#   'date': '2024-12-23'},
#  {'open': 630.6,
#   'high': 635.4,
#   'low': 630.6,
#   'close': 634.3,
#   'volume': 0,
#   'previousClose': 628.2,
#   'date': '2024-12-27'},
#  {'open': 632.8,
#   'high': 635.6,
#   'low': 632.4,
#   'close': 632.4,
#   'volume': 2,
#   'previousClose': 634.3,
#   'date': '2024-12-30'},
#  {'open': 636.6,
#   'high': 636.6,
#   'low': 623.3,
#   'close': 634.8,
#   'volume': 6,
#   'previousClose': 632.4,
#   'date': '2025-01-02'},
#  {'open': 625.4,
#   'high': 625.7,
#   'low': 610.6,
#   'close': 610.6,
#   'volume': 2,
#   'previousClose': 634.8,
#   'date': '2025-01-03'},
#  {'open': 616.2,
#   'high': 638.4,
#   'low': 616.2,
#   'close': 634.8,
#   'volume': 65,
#   'previousClose': 610.6,
#   'date': '2025-01-06'},
#  {'open': 634.5,
#   'high': 644.4,
#   'low': 634.5,
#   'close': 644.4,
#   'volume': 1,
#   'previousClose': 634.8,
#   'date': '2025-01-07'},
#  {'open': 643.5,
#   'high': 643.5,
#   'low': 635.2,
#   'close': 635.2,
#   'volume': 29,
#   'previousClose': 644.4,
#   'date': '2025-01-08'},
#  {'open': 630.9,
#   'high': 647.2,
#   'low': 630.9,
#   'close': 647.2,
#   'volume': 1,
#   'previousClose': 635.2,
#   'date': '2025-01-09'},
#  {'open': 647.0,
#   'high': 653.0,
#   'low': 644.1,
#   'close': 644.1,
#   'volume': 9,
#   'previousClose': 647.2,
#   'date': '2025-01-10'},
#  {'open': 645.5,
#   'high': 645.9,
#   'low': 640.8,
#   'close': 645.9,
#   'volume': 8,
#   'previousClose': 644.1,
#   'date': '2025-01-13'},
#  {'open': 657.5,
#   'high': 659.9,
#   'low': 651.5,
#   'close': 651.5,
#   'volume': 12,
#   'previousClose': 645.9,
#   'date': '2025-01-14'},
#  {'open': 640.7,
#   'high': 647.4,
#   'low': 639.8,
#   'close': 640.8,
#   'volume': 37,
#   'previousClose': 651.5,
#   'date': '2025-01-15'},
#  {'open': 685.9,
#   'high': 694.8,
#   'low': 680.1,
#   'close': 682.1,
#   'volume': 82,
#   'previousClose': 640.8,
#   'date': '2025-01-16'},
#  {'open': 692.2,
#   'high': 693.6,
#   'low': 689.9,
#   'close': 693.4,
#   'volume': 35,
#   'previousClose': 682.1,
#   'date': '2025-01-17'},
#  {'open': 686.8,
#   'high': 689.0,
#   'low': 681.8,
#   'close': 689.0,
#   'volume': 32,
#   'previousClose': 693.4,
#   'date': '2025-01-20'},
#  {'open': 686.3,
#   'high': 699.0,
#   'low': 686.3,
#   'close': 699.0,
#   'volume': 0,
#   'previousClose': 689.0,
#   'date': '2025-01-21'},
#  {'open': 698.9,
#   'high': 712.4,
#   'low': 698.9,
#   'close': 712.4,
#   'volume': 0,
#   'previousClose': 699.0,
#   'date': '2025-01-22'},
#  {'open': 712.9,
#   'high': 714.8,
#   'low': 712.9,
#   'close': 714.8,
#   'volume': 0,
#   'previousClose': 712.4,
#   'date': '2025-01-23'},
#  {'open': 742.8,
#   'high': 742.8,
#   'low': 730.2,
#   'close': 730.3,
#   'volume': 16,
#   'previousClose': 714.8,
#   'date': '2025-01-24'},
#  {'open': 735.8,
#   'high': 740.9,
#   'low': 734.8,
#   'close': 740.9,
#   'volume': 16,
#   'previousClose': 730.3,
#   'date': '2025-01-27'},
#  {'open': 754.1,
#   'high': 757.4,
#   'low': 751.6,
#   'close': 757.4,
#   'volume': 35,
#   'previousClose': 740.9,
#   'date': '2025-01-28'},
#  {'open': 706.4,
#   'high': 713.8,
#   'low': 706.4,
#   'close': 713.8,
#   'volume': 0,
#   'previousClose': 757.4,
#   'date': '2025-01-29'},
#  {'open': 715.8,
#   'high': 716.1,
#   'low': 712.8,
#   'close': 715.2,
#   'volume': 0,
#   'previousClose': 713.8,
#   'date': '2025-01-30'},
#  {'open': 714.2,
#   'high': 714.2,
#   'low': 703.3,
#   'close': 703.3,
#   'volume': 16,
#   'previousClose': 715.2,
#   'date': '2025-01-31'},
#  {'open': 685.9,
#   'high': 691.7,
#   'low': 685.2,
#   'close': 690.3,
#   'volume': 45,
#   'previousClose': 703.3,
#   'date': '2025-02-03'},
#  {'open': 692.3,
#   'high': 692.5,
#   'low': 690.3,
#   'close': 692.5,
#   'volume': 0,
#   'previousClose': 690.3,
#   'date': '2025-02-04'},
#  {'open': 687.4,
#   'high': 688.4,
#   'low': 681.2,
#   'close': 681.6,
#   'volume': 18,
#   'previousClose': 692.5,
#   'date': '2025-02-05'},
#  {'open': 682.5,
#   'high': 692.4,
#   'low': 682.5,
#   'close': 692.4,
#   'volume': 0,
#   'previousClose': 681.6,
#   'date': '2025-02-06'},
#  {'open': 691.3,
#   'high': 691.3,
#   'low': 684.3,
#   'close': 686.0,
#   'volume': 48,
#   'previousClose': 692.4,
#   'date': '2025-02-07'},
#  {'open': 684.7,
#   'high': 684.9,
#   'low': 679.7,
#   'close': 679.7,
#   'volume': 0,
#   'previousClose': 686.0,
#   'date': '2025-02-10'},
#  {'open': 679.5,
#   'high': 683.1,
#   'low': 679.5,
#   'close': 683.1,
#   'volume': 0,
#   'previousClose': 679.7,
#   'date': '2025-02-11'},
#  {'open': 688.4,
#   'high': 688.4,
#   'low': 673.7,
#   'close': 678.3,
#   'volume': 52,
#   'previousClose': 683.1,
#   'date': '2025-02-12'},
#  {'open': 699.5,
#   'high': 704.9,
#   'low': 699.5,
#   'close': 704.9,
#   'volume': 0,
#   'previousClose': 678.3,
#   'date': '2025-02-13'},
#  {'open': 719.1,
#   'high': 719.1,
#   'low': 712.5,
#   'close': 716.5,
#   'volume': 5,
#   'previousClose': 704.9,
#   'date': '2025-02-14'},
#  {'open': 702.7,
#   'high': 702.7,
#   'low': 698.9,
#   'close': 699.5,
#   'volume': 0,
#   'previousClose': 716.5,
#   'date': '2025-02-17'},
#  {'open': 706.0,
#   'high': 706.0,
#   'low': 700.1,
#   'close': 704.9,
#   'volume': 0,
#   'previousClose': 699.5,
#   'date': '2025-02-18'},
#  {'open': 701.1,
#   'high': 701.1,
#   'low': 690.2,
#   'close': 691.7,
#   'volume': 1,
#   'previousClose': 704.9,
#   'date': '2025-02-19'},
#  {'open': 697.7,
#   'high': 697.7,
#   'low': 694.6,
#   'close': 695.7,
#   'volume': 16,
#   'previousClose': 691.7,
#   'date': '2025-02-20'},
#  {'open': 698.5,
#   'high': 702.3,
#   'low': 698.5,
#   'close': 700.1,
#   'volume': 0,
#   'previousClose': 695.7,
#   'date': '2025-02-21'},
#  {'open': 696.7,
#   'high': 700.1,
#   'low': 694.6,
#   'close': 694.6,
#   'volume': 3,
#   'previousClose': 700.1,
#   'date': '2025-02-24'},
#  {'open': 690.1,
#   'high': 690.1,
#   'low': 687.3,
#   'close': 687.8,
#   'volume': 0,
#   'previousClose': 694.6,
#   'date': '2025-02-25'},
#  {'open': 695.7,
#   'high': 704.9,
#   'low': 695.7,
#   'close': 698.0,
#   'volume': 0,
#   'previousClose': 687.8,
#   'date': '2025-02-26'},
#  {'open': 691.2,
#   'high': 697.2,
#   'low': 691.2,
#   'close': 691.2,
#   'volume': 16,
#   'previousClose': 698.0,
#   'date': '2025-02-27'},
#  {'open': 681.6,
#   'high': 692.0,
#   'low': 681.6,
#   'close': 689.3,
#   'volume': 0,
#   'previousClose': 691.2,
#   'date': '2025-02-28'},
#  {'open': 692.5,
#   'high': 696.7,
#   'low': 690.8,
#   'close': 696.1,
#   'volume': 0,
#   'previousClose': 689.3,
#   'date': '2025-03-03'},
#  {'open': 674.5,
#   'high': 674.5,
#   'low': 669.0,
#   'close': 669.0,
#   'volume': 0,
#   'previousClose': 696.1,
#   'date': '2025-03-04'},
#  {'open': 668.7,
#   'high': 676.7,
#   'low': 668.7,
#   'close': 670.5,
#   'volume': 26,
#   'previousClose': 669.0,
#   'date': '2025-03-05'},
#  {'open': 668.0,
#   'high': 668.0,
#   'low': 649.8,
#   'close': 649.8,
#   'volume': 5,
#   'previousClose': 670.5,
#   'date': '2025-03-06'},
#  {'open': 646.6,
#   'high': 646.6,
#   'low': 630.5,
#   'close': 632.9,
#   'volume': 38,
#   'previousClose': 649.8,
#   'date': '2025-03-07'},
#  {'open': 633.4,
#   'high': 633.4,
#   'low': 625.0,
#   'close': 625.0,
#   'volume': 33,
#   'previousClose': 632.9,
#   'date': '2025-03-10'},
#  {'open': 628.6,
#   'high': 628.9,
#   'low': 620.5,
#   'close': 620.5,
#   'volume': 2,
#   'previousClose': 625.0,
#   'date': '2025-03-11'},
#  {'open': 622.5,
#   'high': 623.3,
#   'low': 611.1,
#   'close': 611.1,
#   'volume': 31,
#   'previousClose': 620.5,
#   'date': '2025-03-12'},
#  {'open': 606.7,
#   'high': 612.3,
#   'low': 606.2,
#   'close': 607.0,
#   'volume': 84,
#   'previousClose': 611.1,
#   'date': '2025-03-13'},
#  {'open': 603.6,
#   'high': 614.0,
#   'low': 602.2,
#   'close': 602.2,
#   'volume': 18,
#   'previousClose': 607.0,
#   'date': '2025-03-14'},
#  {'open': 602.3,
#   'high': 606.3,
#   'low': 602.3,
#   'close': 606.3,
#   'volume': 15,
#   'previousClose': 602.2,
#   'date': '2025-03-17'},
#  {'open': 611.1,
#   'high': 612.4,
#   'low': 610.9,
#   'close': 610.9,
#   'volume': 0,
#   'previousClose': 606.3,
#   'date': '2025-03-18'},
#  {'open': 607.2,
#   'high': 611.3,
#   'low': 606.5,
#   'close': 608.9,
#   'volume': 7,
#   'previousClose': 610.9,
#   'date': '2025-03-19'},
#  {'open': 602.8,
#   'high': 610.2,
#   'low': 602.8,
#   'close': 610.2,
#   'volume': 0,
#   'previousClose': 608.9,
#   'date': '2025-03-20'},
#  {'open': 596.8,
#   'high': 599.6,
#   'low': 594.8,
#   'close': 599.6,
#   'volume': 36,
#   'previousClose': 610.2,
#   'date': '2025-03-21'},
#  {'open': 608.9,
#   'high': 608.9,
#   'low': 599.8,
#   'close': 599.9,
#   'volume': 1,
#   'previousClose': 599.6,
#   'date': '2025-03-24'},
#  {'open': 600.3,
#   'high': 600.9,
#   'low': 598.4,
#   'close': 598.4,
#   'volume': 0,
#   'previousClose': 599.9,
#   'date': '2025-03-25'},
#  {'open': 598.1,
#   'high': 598.1,
#   'low': 592.9,
#   'close': 595.4,
#   'volume': 36,
#   'previousClose': 598.4,
#   'date': '2025-03-26'},
#  {'open': 597.5,
#   'high': 597.5,
#   'low': 587.3,
#   'close': 590.3,
#   'volume': 16,
#   'previousClose': 595.4,
#   'date': '2025-03-27'},
#  {'open': 582.9,
#   'high': 586.4,
#   'low': 582.9,
#   'close': 582.9,
#   'volume': 16,
#   'previousClose': 590.3,
#   'date': '2025-03-28'},
#  {'open': 578.1,
#   'high': 578.1,
#   'low': 568.5,
#   'close': 572.6,
#   'volume': 34,
#   'previousClose': 582.9,
#   'date': '2025-03-31'},
#  {'open': 575.0,
#   'high': 577.4,
#   'low': 574.3,
#   'close': 574.3,
#   'volume': 23,
#   'previousClose': 572.6,
#   'date': '2025-04-01'},
#  {'open': 575.4,
#   'high': 575.4,
#   'low': 574.4,
#   'close': 574.4,
#   'volume': 0,
#   'previousClose': 574.3,
#   'date': '2025-04-02'},
#  {'open': 568.0,
#   'high': 568.0,
#   'low': 543.3,
#   'close': 543.3,
#   'volume': 10,
#   'previousClose': 574.4,
#   'date': '2025-04-03'},
#  {'open': 541.8,
#   'high': 542.7,
#   'low': 527.0,
#   'close': 528.9,
#   'volume': 116,
#   'previousClose': 543.3,
#   'date': '2025-04-04'},
#  {'open': 525.0,
#   'high': 525.0,
#   'low': 493.65,
#   'close': 509.3,
#   'volume': 4,
#   'previousClose': 528.9,
#   'date': '2025-04-07'},
#  {'open': 514.2,
#   'high': 523.5,
#   'low': 504.5,
#   'close': 520.5,
#   'volume': 34,
#   'previousClose': 509.3,
#   'date': '2025-04-08'},
#  {'open': 510.5,
#   'high': 510.5,
#   'low': 494.4,
#   'close': 501.0,
#   'volume': 51,
#   'previousClose': 520.5,
#   'date': '2025-04-09'},
#  {'open': 526.1,
#   'high': 530.1,
#   'low': 523.4,
#   'close': 523.4,
#   'volume': 0,
#   'previousClose': 501.0,
#   'date': '2025-04-10'},
#  {'open': 527.8,
#   'high': 527.8,
#   'low': 517.4,
#   'close': 524.4,
#   'volume': 39,
#   'previousClose': 523.4,
#   'date': '2025-04-11'},
#  {'open': 532.5,
#   'high': 535.2,
#   'low': 527.3,
#   'close': 527.3,
#   'volume': 20,
#   'previousClose': 524.4,
#   'date': '2025-04-14'},
#  {'open': 494.15,
#   'high': 494.15,
#   'low': 485.75,
#   'close': 488.55,
#   'volume': 51,
#   'previousClose': 527.3,
#   'date': '2025-04-15'},
#  {'open': 483.65,
#   'high': 488.1,
#   'low': 483.65,
#   'close': 484.9,
#   'volume': 78,
#   'previousClose': 488.55,
#   'date': '2025-04-16'},
#  {'open': 482.85,
#   'high': 492.45,
#   'low': 482.85,
#   'close': 483.5,
#   'volume': 101,
#   'previousClose': 484.9,
#   'date': '2025-04-17'},
#  {'open': 484.7,
#   'high': 489.05,
#   'low': 474.65,
#   'close': 489.05,
#   'volume': 5,
#   'previousClose': 483.5,
#   'date': '2025-04-22'},
#  {'open': 506.7,
#   'high': 508.7,
#   'low': 503.6,
#   'close': 503.6,
#   'volume': 3,
#   'previousClose': 489.05,
#   'date': '2025-04-23'},
#  {'open': 486.35,
#   'high': 501.6,
#   'low': 486.35,
#   'close': 501.6,
#   'volume': 92,
#   'previousClose': 503.6,
#   'date': '2025-04-24'},
#  {'open': 502.8,
#   'high': 502.8,
#   'low': 498.7,
#   'close': 498.7,
#   'volume': 21,
#   'previousClose': 501.6,
#   'date': '2025-04-25'},
#  {'open': 503.6,
#   'high': 505.0,
#   'low': 502.6,
#   'close': 503.8,
#   'volume': 7,
#   'previousClose': 498.7,
#   'date': '2025-04-28'},
#  {'open': 499.2,
#   'high': 500.2,
#   'low': 491.85,
#   'close': 491.95,
#   'volume': 0,
#   'previousClose': 503.8,
#   'date': '2025-04-29'},
#  {'open': 490.55,
#   'high': 491.9,
#   'low': 486.25,
#   'close': 489.2,
#   'volume': 0,
#   'previousClose': 491.95,
#   'date': '2025-04-30'},
#  {'open': 489.95,
#   'high': 492.8,
#   'low': 489.95,
#   'close': 492.8,
#   'volume': 0,
#   'previousClose': 489.2,
#   'date': '2025-05-02'},
#  {'open': 488.05,
#   'high': 492.8,
#   'low': 488.05,
#   'close': 492.0,
#   'volume': 0,
#   'previousClose': 492.8,
#   'date': '2025-05-05'},
#  {'open': 488.15,
#   'high': 490.15,
#   'low': 488.15,
#   'close': 490.15,
#   'volume': 0,
#   'previousClose': 492.0,
#   'date': '2025-05-06'},
#  {'open': 489.8,
#   'high': 489.8,
#   'low': 484.0,
#   'close': 484.0,
#   'volume': 2,
#   'previousClose': 490.15,
#   'date': '2025-05-07'},
#  {'open': 485.3,
#   'high': 496.25,
#   'low': 485.3,
#   'close': 490.0,
#   'volume': 0,
#   'previousClose': 484.0,
#   'date': '2025-05-08'},
#  {'open': 494.3,
#   'high': 496.85,
#   'low': 492.65,
#   'close': 494.75,
#   'volume': 41,
#   'previousClose': 490.0,
#   'date': '2025-05-09'},
#  {'open': 527.4,
#   'high': 531.8,
#   'low': 526.3,
#   'close': 530.9,
#   'volume': 30,
#   'previousClose': 494.75,
#   'date': '2025-05-12'},
#  {'open': 531.0,
#   'high': 538.4,
#   'low': 531.0,
#   'close': 535.7,
#   'volume': 18,
#   'previousClose': 530.9,
#   'date': '2025-05-13'},
#  {'open': 533.7,
#   'high': 533.7,
#   'low': 523.1,
#   'close': 523.1,
#   'volume': 0,
#   'previousClose': 535.7,
#   'date': '2025-05-14'},
#  {'open': 519.9,
#   'high': 519.9,
#   'low': 508.5,
#   'close': 508.5,
#   'volume': 0,
#   'previousClose': 523.1,
#   'date': '2025-05-15'},
#  {'open': 508.1,
#   'high': 508.1,
#   'low': 502.3,
#   'close': 503.5,
#   'volume': 0,
#   'previousClose': 508.5,
#   'date': '2025-05-16'},
#  {'open': 503.8,
#   'high': 503.8,
#   'low': 492.6,
#   'close': 495.45,
#   'volume': 80,
#   'previousClose': 503.5,
#   'date': '2025-05-19'},
#  {'open': 498.8,
#   'high': 504.6,
#   'low': 495.45,
#   'close': 504.6,
#   'volume': 11,
#   'previousClose': 495.45,
#   'date': '2025-05-20'},
#  {'open': 495.3,
#   'high': 496.45,
#   'low': 494.8,
#   'close': 494.8,
#   'volume': 36,
#   'previousClose': 504.6,
#   'date': '2025-05-21'},
#  {'open': 490.3,
#   'high': 490.3,
#   'low': 478.5,
#   'close': 478.5,
#   'volume': 30,
#   'previousClose': 494.8,
#   'date': '2025-05-22'},
#  {'open': 488.6,
#   'high': 488.6,
#   'low': 470.9,
#   'close': 474.5,
#   'volume': 63,
#   'previousClose': 478.5,
#   'date': '2025-05-23'},
#  {'open': 486.7,
#   'high': 486.7,
#   'low': 481.5,
#   'close': 481.5,
#   'volume': 10,
#   'previousClose': 474.5,
#   'date': '2025-05-26'},
#  {'open': 477.75,
#   'high': 484.55,
#   'low': 477.75,
#   'close': 481.15,
#   'volume': 12,
#   'previousClose': 481.5,
#   'date': '2025-05-27'},
#  {'open': 484.55,
#   'high': 484.9,
#   'low': 482.85,
#   'close': 484.9,
#   'volume': 0,
#   'previousClose': 481.15,
#   'date': '2025-05-28'},
#  {'open': 491.1,
#   'high': 491.1,
#   'low': 484.95,
#   'close': 484.95,
#   'volume': 9,
#   'previousClose': 484.9,
#   'date': '2025-05-29'},
#  {'open': 479.65,
#   'high': 481.2,
#   'low': 479.65,
#   'close': 480.1,
#   'volume': 0,
#   'previousClose': 484.95,
#   'date': '2025-05-30'},
#  {'open': 471.75,
#   'high': 476.95,
#   'low': 470.65,
#   'close': 473.8,
#   'volume': 44,
#   'previousClose': 480.1,
#   'date': '2025-06-02'},
#  {'open': 476.65,
#   'high': 476.65,
#   'low': 466.95,
#   'close': 470.6,
#   'volume': 31,
#   'previousClose': 473.8,
#   'date': '2025-06-03'},
#  {'open': 474.45,
#   'high': 475.05,
#   'low': 473.9,
#   'close': 475.05,
#   'volume': 0,
#   'previousClose': 470.6,
#   'date': '2025-06-04'},
#  {'open': 482.3,
#   'high': 482.3,
#   'low': 469.9,
#   'close': 471.15,
#   'volume': 89,
#   'previousClose': 475.05,
#   'date': '2025-06-05'},
#  {'open': 470.75,
#   'high': 473.25,
#   'low': 470.7,
#   'close': 473.25,
#   'volume': 2,
#   'previousClose': 471.15,
#   'date': '2025-06-06'},
#  {'open': 476.25,
#   'high': 476.25,
#   'low': 471.25,
#   'close': 471.25,
#   'volume': 0,
#   'previousClose': 473.25,
#   'date': '2025-06-09'},
#  {'open': 469.65,
#   'high': 474.85,
#   'low': 469.65,
#   'close': 472.95,
#   'volume': 18,
#   'previousClose': 471.25,
#   'date': '2025-06-10'},
#  {'open': 478.9,
#   'high': 480.8,
#   'low': 476.95,
#   'close': 479.55,
#   'volume': 31,
#   'previousClose': 472.95,
#   'date': '2025-06-11'},
#  {'open': 468.1,
#   'high': 470.2,
#   'low': 464.0,
#   'close': 470.2,
#   'volume': 2,
#   'previousClose': 479.55,
#   'date': '2025-06-12'},
#  {'open': 460.0,
#   'high': 460.6,
#   'low': 458.55,
#   'close': 460.6,
#   'volume': 17,
#   'previousClose': 470.2,
#   'date': '2025-06-13'},
#  {'open': 465.7,
#   'high': 469.1,
#   'low': 464.1,
#   'close': 467.85,
#   'volume': 54,
#   'previousClose': 460.6,
#   'date': '2025-06-16'},
#  {'open': 466.65,
#   'high': 466.65,
#   'low': 460.95,
#   'close': 462.0,
#   'volume': 18,
#   'previousClose': 467.85,
#   'date': '2025-06-17'},
#  {'open': 462.3,
#   'high': 464.3,
#   'low': 460.5,
#   'close': 464.3,
#   'volume': 48,
#   'previousClose': 462.0,
#   'date': '2025-06-18'},
#  {'open': 457.95,
#   'high': 457.95,
#   'low': 452.4,
#   'close': 457.6,
#   'volume': 0,
#   'previousClose': 464.3,
#   'date': '2025-06-19'},
#  {'open': 453.1,
#   'high': 454.85,
#   'low': 450.25,
#   'close': 450.25,
#   'volume': 37,
#   'previousClose': 457.6,
#   'date': '2025-06-20'},
#  {'open': 445.0,
#   'high': 448.45,
#   'low': 445.0,
#   'close': 445.05,
#   'volume': 23,
#   'previousClose': 450.25,
#   'date': '2025-06-23'},
#  {'open': 447.5,
#   'high': 456.1,
#   'low': 447.5,
#   'close': 454.15,
#   'volume': 52,
#   'previousClose': 445.05,
#   'date': '2025-06-24'},
#  {'open': 453.4,
#   'high': 453.4,
#   'low': 447.35,
#   'close': 447.35,
#   'volume': 0,
#   'previousClose': 454.15,
#   'date': '2025-06-25'},
#  {'open': 447.25,
#   'high': 447.25,
#   'low': 439.55,
#   'close': 439.55,
#   'volume': 1,
#   'previousClose': 447.35,
#   'date': '2025-06-26'},
#  {'open': 436.4,
#   'high': 445.8,
#   'low': 436.4,
#   'close': 443.8,
#   'volume': 16,
#   'previousClose': 439.55,
#   'date': '2025-06-27'},
#  {'open': 449.45,
#   'high': 452.05,
#   'low': 448.65,
#   'close': 448.65,
#   'volume': 42,
#   'previousClose': 443.8,
#   'date': '2025-06-30'},
#  {'open': 448.8,
#   'high': 461.15,
#   'low': 448.8,
#   'close': 461.15,
#   'volume': 20,
#   'previousClose': 448.65,
#   'date': '2025-07-01'},
#  {'open': 465.5,
#   'high': 490.55,
#   'low': 465.5,
#   'close': 487.85,
#   'volume': 134,
#   'previousClose': 461.15,
#   'date': '2025-07-02'},
#  {'open': 493.45,
#   'high': 493.45,
#   'low': 486.8,
#   'close': 491.25,
#   'volume': 6,
#   'previousClose': 487.85,
#   'date': '2025-07-03'},
#  {'open': 479.35,
#   'high': 479.35,
#   'low': 476.45,
#   'close': 478.9,
#   'volume': 61,
#   'previousClose': 491.25,
#   'date': '2025-07-04'},
#  {'open': 477.4,
#   'high': 477.4,
#   'low': 474.0,
#   'close': 474.45,
#   'volume': 32,
#   'previousClose': 478.9,
#   'date': '2025-07-07'},
#  {'open': 475.6,
#   'high': 478.25,
#   'low': 475.3,
#   'close': 478.25,
#   'volume': 0,
#   'previousClose': 474.45,
#   'date': '2025-07-08'},
#  {'open': 480.3,
#   'high': 489.0,
#   'low': 480.3,
#   'close': 485.55,
#   'volume': 31,
#   'previousClose': 478.25,
#   'date': '2025-07-09'},
#  {'open': 490.5,
#   'high': 496.55,
#   'low': 490.5,
#   'close': 496.1,
#   'volume': 33,
#   'previousClose': 485.55,
#   'date': '2025-07-10'},
#  {'open': 495.5,
#   'high': 495.5,
#   'low': 491.15,
#   'close': 491.15,
#   'volume': 3,
#   'previousClose': 496.1,
#   'date': '2025-07-11'}]

# %% [markdown]
# Income statement

# %%
stock.incomeStatement()
# Out:
# {'_meta': {'companyId': '0C00000VOS',
#   'statementType': 'income-statement',
#   'periodReport': 'Success',
#   'latestReport': 'Success'},
#  'columnDefs': ['2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2022',
#   '2023',
#   '2024',
#   'TTM'],
#  'filingIdList': [None,
#   None,
#   None,
#   None,
#   None,
#   '328683655',
#   '384266622',
#   '437916148',
#   '502488388',
#   '577784039',
#   None],
#  'rows': [{'parentId': '',
#    'label': 'IncomeStatement',
#    'dataPointId': 'IFIS000000',
#    'order': 385,
#    'subLevel': [{'parentId': 'IFIS000000385',
#      'label': 'Gross Profit',
#      'dataPointId': 'IFIS000590',
#      'order': 386,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       28779.0,
#       43860.0,
#       54196.0,
#       59277.0,
#       56764.0,
#       56764.0],
#      'subLevel': [{'parentId': 'IFIS000590386',
#        'label': 'Total Revenue',
#        'dataPointId': 'IFIS001170',
#        'order': 387,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         44650.0,
#         64215.0,
#         79184.0,
#         86153.0,
#         84682.0,
#         84682.0],
#        'subLevel': [{'parentId': 'IFIS001170387',
#          'label': 'Business Revenue',
#          'dataPointId': 'IFIS001839',
#          'order': 388,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           44421.0,
#           63920.0,
#           79184.0,
#           85538.0,
#           84046.0,
#           84046.0]},
#         {'parentId': 'IFIS001170387',
#          'label': 'Other Revenue',
#          'dataPointId': 'IFIS002228',
#          'order': 391,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           229.0,
#           295.0,
#           None,
#           615.0,
#           636.0,
#           636.0]}]},
#       {'parentId': 'IFIS000590386',
#        'label': 'Cost of Revenue',
#        'dataPointId': 'IFIS000200',
#        'order': 392,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -15871.0,
#         -20355.0,
#         -24988.0,
#         -26876.0,
#         -27918.0,
#         -27918.0],
#        'subLevel': [{'parentId': 'IFIS000200392',
#          'label': 'Cost of Goods and Services',
#          'dataPointId': 'IFIS003118',
#          'order': 393,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -15871.0,
#           -20355.0,
#           -24988.0,
#           -26876.0,
#           -27918.0,
#           -27918.0]}]}]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Operating Income/Expenses',
#      'dataPointId': 'IFIS001220',
#      'order': 405,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       -20468.0,
#       -26738.0,
#       -33181.0,
#       -36496.0,
#       -37187.0,
#       -37187.0],
#      'subLevel': [{'parentId': 'IFIS001220405',
#        'label': 'Selling, General and Administrative Expenses',
#        'dataPointId': 'IFIS001700',
#        'order': 406,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -20433.0,
#         -26722.0,
#         -33178.0,
#         -36482.0,
#         -37222.0,
#         -37222.0],
#        'subLevel': [{'parentId': 'IFIS001700406',
#          'label': 'General and Administrative Expenses',
#          'dataPointId': 'IFIS000040',
#          'order': 414,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -3641.0,
#           -4414.0,
#           -5027.0,
#           -5714.0,
#           -6220.0,
#           -6220.0]},
#         {'parentId': 'IFIS001700406',
#          'label': 'Selling and Marketing Expenses',
#          'dataPointId': 'IFIS001690',
#          'order': 428,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -16792.0,
#           -22308.0,
#           -28151.0,
#           -30768.0,
#           -31002.0,
#           -31002.0]}]},
#       {'parentId': 'IFIS001220405',
#        'label': 'Other Income/Expense, Operating',
#        'dataPointId': 'IFIS101208',
#        'order': 442,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -35.0,
#         -16.0,
#         -3.0,
#         -14.0,
#         35.0,
#         35.0],
#        'subLevel': [{'parentId': 'IFIS101208442',
#          'label': 'Other Income, Operating',
#          'dataPointId': 'IFIS200030',
#          'order': 444,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           None,
#           None,
#           None,
#           None,
#           35.0,
#           35.0]},
#         {'parentId': 'IFIS101208442',
#          'label': 'Other Expenses, Operating',
#          'dataPointId': 'IFIS003104',
#          'order': 445,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -35.0,
#           -16.0,
#           -3.0,
#           -14.0,
#           None,
#           None]}]},
#       {'parentId': 'IFIS001220405',
#        'label': 'Depreciation, Amortization and Depletion',
#        'dataPointId': 'IFIS001855',
#        'order': 432,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None,
#         None],
#        'subLevel': [{'parentId': 'IFIS001855432',
#          'label': 'Depreciation and Amortization',
#          'dataPointId': 'IFIS000250',
#          'order': 433,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           None,
#           None,
#           None,
#           None,
#           None,
#           None]}]}]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Total Operating Profit/Loss',
#      'dataPointId': 'IFIS001230',
#      'order': 446,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       8311.0,
#       17122.0,
#       21015.0,
#       22781.0,
#       19577.0,
#       19577.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Non-Operating Income/Expense, Total',
#      'dataPointId': 'IFIS001917',
#      'order': 447,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       -948.0,
#       87.0,
#       -900.0,
#       -1154.0,
#       -1465.0,
#       -1465.0],
#      'subLevel': [{'parentId': 'IFIS001917447',
#        'label': 'Total Net Finance Income/Expense',
#        'dataPointId': 'IFIS000930',
#        'order': 448,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -404.0,
#         -287.0,
#         -424.0,
#         -1016.0,
#         -1234.0,
#         -1234.0],
#        'subLevel': [{'parentId': 'IFIS000930448',
#          'label': 'Net Interest Income/Expense',
#          'dataPointId': 'IFIS002367',
#          'order': 449,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -366.0,
#           -238.0,
#           -382.0,
#           -973.0,
#           -1186.0,
#           -1186.0],
#          'subLevel': [{'parentId': 'IFIS002367449',
#            'label': 'Interest Expense Net of Capitalized Interest',
#            'dataPointId': 'IFIS000800',
#            'order': 450,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -366.0,
#             -242.0,
#             -382.0,
#             -973.0,
#             -1186.0,
#             -1186.0]},
#           {'parentId': 'IFIS002367449',
#            'label': 'Interest Income',
#            'dataPointId': 'IFIS000910',
#            'order': 456,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             None,
#             4.0,
#             None,
#             None,
#             None,
#             None]}]},
#         {'parentId': 'IFIS000930448',
#          'label': 'Other Finance Income/Expenses',
#          'dataPointId': 'IFIS101192',
#          'order': 457,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -38.0,
#           -49.0,
#           -42.0,
#           -43.0,
#           -48.0,
#           -48.0],
#          'subLevel': [{'parentId': 'IFIS101192457',
#            'label': 'Other Finance Expenses',
#            'dataPointId': 'IFIS001924',
#            'order': 459,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -38.0,
#             -49.0,
#             -42.0,
#             -43.0,
#             -48.0,
#             -48.0]}]}]},
#       {'parentId': 'IFIS001917447',
#        'label': 'Net Investment Income',
#        'dataPointId': 'IFIS001915',
#        'order': 461,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -246.0,
#         472.0,
#         -194.0,
#         92.0,
#         470.0,
#         470.0],
#        'subLevel': [{'parentId': 'IFIS001915461',
#          'label': 'Dividend and Investment Income',
#          'dataPointId': 'IFIS003106',
#          'order': 462,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           12.0,
#           10.0,
#           58.0,
#           65.0,
#           9.0,
#           9.0]},
#         {'parentId': 'IFIS001915461',
#          'label': 'Gain/Loss on Investments and Other Financial Instruments',
#          'dataPointId': 'IFIS001885',
#          'order': 463,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           46.0,
#           40.0,
#           64.0,
#           153.0,
#           231.0,
#           231.0]},
#         {'parentId': 'IFIS001915461',
#          'label': 'Fair Value or Unrealized Gain/Loss on Financial Assets',
#          'dataPointId': 'IFIS001871',
#          'order': 464,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -4.0,
#           618.0,
#           7.0,
#           265.0,
#           482.0,
#           482.0]},
#         {'parentId': 'IFIS001915461',
#          'label': 'Income from Associates, JointVentures and Other Participating Interests',
#          'dataPointId': 'IFIS101191',
#          'order': 465,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -42.0,
#           13.0,
#           37.0,
#           7.0,
#           28.0,
#           28.0]},
#         {'parentId': 'IFIS001915461',
#          'label': 'Gain/Loss on Derivatives',
#          'dataPointId': 'IFIS002217',
#          'order': 475,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -258.0,
#           -209.0,
#           -360.0,
#           -398.0,
#           -280.0,
#           -280.0],
#          'subLevel': [{'parentId': 'IFIS002217475',
#            'label': 'Realized Gain/Loss on Derivatives',
#            'dataPointId': 'IFIS003179',
#            'order': 476,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -262.0,
#             -206.0,
#             -358.0,
#             -399.0,
#             -282.0,
#             -282.0]},
#           {'parentId': 'IFIS002217475',
#            'label': 'Unrealized Gain/Loss on Derivatives',
#            'dataPointId': 'IFIS003180',
#            'order': 477,
#            'collapsed': True,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             4.0,
#             -3.0,
#             -2.0,
#             1.0,
#             2.0,
#             2.0]}]}]},
#       {'parentId': 'IFIS001917447',
#        'label': 'Irregular Income/Expense',
#        'dataPointId': 'IFIS101189',
#        'order': 480,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         -298.0,
#         -98.0,
#         -282.0,
#         -230.0,
#         -701.0,
#         -701.0],
#        'subLevel': [{'parentId': 'IFIS101189480',
#          'label': 'Fixed Asset Disposals',
#          'dataPointId': 'IFIS001877',
#          'order': 483,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -22.0,
#           9.0,
#           -210.0,
#           -102.0,
#           -199.0,
#           -199.0]},
#         {'parentId': 'IFIS101189480',
#          'label': 'Impairment/Write Off/Write Down of Capital Assets',
#          'dataPointId': 'IFIS001892',
#          'order': 487,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -235.0,
#           -89.0,
#           -50.0,
#           -105.0,
#           -422.0,
#           -422.0]},
#         {'parentId': 'IFIS101189480',
#          'label': 'Merger and Acquisition Income/Expense',
#          'dataPointId': 'IFIS002098',
#          'order': 505,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -35.0,
#           -18.0,
#           -25.0,
#           -14.0,
#           -10.0,
#           -10.0]},
#         {'parentId': 'IFIS101189480',
#          'label': 'Restructuring and Reorganization Income/Expense',
#          'dataPointId': 'IFIS000680',
#          'order': 506,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -6.0,
#           None,
#           3.0,
#           -9.0,
#           -70.0,
#           -70.0]},
#         {'parentId': 'IFIS101189480',
#          'label': 'Gain/Loss on Extinguishment of Debt',
#          'dataPointId': 'IFIS002288',
#          'order': 500,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           None,
#           None,
#           None,
#           None,
#           None,
#           None]}]}]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Pretax Income',
#      'dataPointId': 'IFIS001490',
#      'order': 518,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       7363.0,
#       17209.0,
#       20115.0,
#       21627.0,
#       18112.0,
#       18112.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Provision for Income Tax',
#      'dataPointId': 'IFIS001560',
#      'order': 519,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       -2409.0,
#       -4510.0,
#       -5362.0,
#       -5673.0,
#       -5157.0,
#       -5157.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Net Income before Extraordinary Items and Discontinued Operations',
#      'dataPointId': 'IFIS001110',
#      'order': 529,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4955.0,
#       12698.0,
#       14751.0,
#       15952.0,
#       12958.0,
#       12958.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Net Income after Extraordinary Items and Discontinued Operations',
#      'dataPointId': 'IFIS001977',
#      'order': 535,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4955.0,
#       12698.0,
#       14751.0,
#       15952.0,
#       12958.0,
#       12958.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Non-Controlling/Minority Interests',
#      'dataPointId': 'IFIS001040',
#      'order': 536,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       -253.0,
#       -662.0,
#       -667.0,
#       -778.0,
#       -408.0,
#       -408.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Net Income after Non-Controlling/Minority Interests',
#      'dataPointId': 'IFIS001090',
#      'order': 537,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4702.0,
#       12036.0,
#       14084.0,
#       15174.0,
#       12550.0,
#       12550.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Net Income Available to Common Stockholders',
#      'dataPointId': 'IFIS001100',
#      'order': 543,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4702.0,
#       12036.0,
#       14084.0,
#       15174.0,
#       12550.0,
#       12550.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Diluted Net Income Available to Common Stockholders',
#      'dataPointId': 'IFIS002230',
#      'order': 545,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4702.0,
#       12036.0,
#       14084.0,
#       15174.0,
#       12550.0,
#       12550.0]},
#     {'parentId': 'IFIS000000385',
#      'label': 'Income Statement Supplemental Section',
#      'dataPointId': 'IFIS002156',
#      'order': 560,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       None,
#       None,
#       None,
#       None,
#       None,
#       None],
#      'subLevel': [{'parentId': 'IFIS002156560',
#        'label': 'Reported Normalized and Operating Income/Expense Supplemental Section',
#        'dataPointId': 'IFIS003147',
#        'order': 561,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None,
#         None],
#        'subLevel': [{'parentId': 'IFIS003147561',
#          'label': 'Total Revenue as Reported, Supplemental',
#          'dataPointId': 'IFIS003203',
#          'order': 562,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           44651.0,
#           64215.0,
#           79184.0,
#           86153.0,
#           84683.0,
#           84683.0]},
#         {'parentId': 'IFIS003147561',
#          'label': 'Reported Total Operating Profit/Loss',
#          'dataPointId': 'IFIS003138',
#          'order': 564,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           7972.0,
#           17155.0,
#           21001.0,
#           22560.0,
#           18907.0,
#           18907.0]},
#         {'parentId': 'IFIS003147561',
#          'label': 'Reported Normalized Operating Profit',
#          'dataPointId': 'IFIS003202',
#          'order': 572,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           8305.0,
#           17151.0,
#           21055.0,
#           22802.0,
#           19571.0,
#           19571.0]},
#         {'parentId': 'IFIS003147561',
#          'label': 'Reported Effective Tax Rate',
#          'dataPointId': 'IFIS002303',
#          'order': 566,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           0.327,
#           0.262,
#           0.267,
#           0.262,
#           None,
#           None]}]},
#       {'parentId': 'IFIS002156560',
#        'label': 'Operating Income/Expense, Supplemental Section',
#        'dataPointId': 'IFIS001905',
#        'order': 575,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None,
#         None],
#        'subLevel': [{'parentId': 'IFIS001905575',
#          'label': 'Depreciation, Amortization and Depletion, Supplemental',
#          'dataPointId': 'IFIS200330',
#          'order': 589,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           -4759.0,
#           -5107.0,
#           -5658.0,
#           -6450.0,
#           -6549.0,
#           -6549.0],
#          'subLevel': [{'parentId': 'IFIS200330589',
#            'label': 'Depreciation and Amortization, Supplemental',
#            'dataPointId': 'IFIS002143',
#            'order': 590,
#            'datum': ['_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             '_PO_',
#             -4759.0,
#             -5107.0,
#             -5658.0,
#             -6450.0,
#             -6549.0,
#             -6549.0],
#            'subLevel': [{'parentId': 'IFIS002143590',
#              'label': 'Depreciation, Supplemental',
#              'dataPointId': 'IFIS002144',
#              'order': 591,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -4274.0,
#               -4578.0,
#               -5054.0,
#               -5730.0,
#               -5735.0,
#               -5735.0]},
#             {'parentId': 'IFIS002143590',
#              'label': 'Amortization, Supplemental',
#              'dataPointId': 'IFIS002137',
#              'order': 592,
#              'collapsed': True,
#              'datum': ['_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               '_PO_',
#               -485.0,
#               -529.0,
#               -604.0,
#               -720.0,
#               -814.0,
#               -814.0]}]}]},
#         {'parentId': 'IFIS001905575',
#          'label': 'Research and Development Expenses, Supplemental',
#          'dataPointId': 'IFIS002179',
#          'order': 588,
#          'collapsed': True,
#          'datum': ['_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           '_PO_',
#           None,
#           None,
#           None,
#           None,
#           None,
#           None]}]},
#       {'parentId': 'IFIS002156560',
#        'label': 'Employee Costs and Professional Fees, Supplemental Section',
#        'dataPointId': 'IFIS003148',
#        'order': 658,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         None,
#         None,
#         None,
#         None,
#         None,
#         None]}]}]},
#   {'parentId': '',
#    'label': 'EpsAndWaso',
#    'dataPointId': 'IFES000000',
#    'order': 935,
#    'subLevel': [{'parentId': 'IFES000000935',
#      'label': 'Basic EPS',
#      'dataPointId': 'IFIS000100',
#      'order': 936,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       9.33,
#       23.9,
#       28.05,
#       30.34,
#       25.13,
#       25.13],
#      'subLevel': [{'parentId': 'IFIS000100936',
#        'label': 'Basic EPS from Continuing Operations',
#        'dataPointId': 'IFIS000120',
#        'order': 937,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         9.33,
#         23.9,
#         28.05,
#         30.34,
#         25.13,
#         25.13]}]},
#     {'parentId': 'IFES000000935',
#      'label': 'Diluted EPS',
#      'dataPointId': 'IFIS000280',
#      'order': 939,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       9.32,
#       23.89,
#       28.03,
#       30.33,
#       25.12,
#       25.12],
#      'subLevel': [{'parentId': 'IFIS000280939',
#        'label': 'Diluted EPS from Continuing Operations',
#        'dataPointId': 'IFIS000300',
#        'order': 940,
#        'collapsed': True,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         9.32,
#         23.89,
#         28.03,
#         30.33,
#         25.12,
#         25.12]}]},
#     {'parentId': 'IFES000000935',
#      'label': 'Basic Weighted Average Shares Outstanding',
#      'dataPointId': 'IFIS000150',
#      'order': 942,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       503.68,
#       503.63,
#       502.12,
#       500.06,
#       499.41,
#       499.41]},
#     {'parentId': 'IFES000000935',
#      'label': 'Diluted Weighted Average Shares Outstanding',
#      'dataPointId': 'IFIS000330',
#      'order': 943,
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       504.21,
#       503.9,
#       502.48,
#       500.3,
#       499.68,
#       499.68]},
#     {'parentId': 'IFES000000935',
#      'label': 'Total Dividend Per Share',
#      'dataPointId': 'ORISZ00026',
#      'order': 950,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       4.6,
#       7.0,
#       12.0,
#       12.5,
#       13.0,
#       13.0],
#      'subLevel': [{'parentId': 'ORISZ00026950',
#        'label': 'Regular Dividend Per Share Calc',
#        'dataPointId': 'ORISZ00021',
#        'order': 951,
#        'datum': ['_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         '_PO_',
#         4.6,
#         7.0,
#         12.0,
#         12.5,
#         13.0,
#         13.0]}]}]},
#   {'parentId': '',
#    'label': 'WasoAndEpsData',
#    'dataPointId': 'SAL0001000',
#    'collapsed': False,
#    'subLevel': [{'parentId': 'SAL0001000',
#      'label': 'Basic EPS',
#      'dataPointId': 'SAL0001001',
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       9.33,
#       23.9,
#       28.05,
#       30.34,
#       25.13,
#       25.13]},
#     {'parentId': 'SAL0001000',
#      'label': 'Diluted EPS',
#      'dataPointId': 'SAL0001002',
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       9.32,
#       23.89,
#       28.03,
#       30.33,
#       25.12,
#       25.12]},
#     {'parentId': 'SAL0001000',
#      'label': 'Basic WASO',
#      'dataPointId': 'SAL0001003',
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       503.68,
#       503.63,
#       502.12,
#       500.06,
#       499.41,
#       499.41]},
#     {'parentId': 'SAL0001000',
#      'label': 'Diluted WASO',
#      'dataPointId': 'SAL0001004',
#      'collapsed': True,
#      'datum': ['_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       '_PO_',
#       504.21,
#       503.9,
#       502.48,
#       500.3,
#       499.68,
#       499.68]}]}],
#  'footer': {'currency': 'EUR',
#   'currencySymbol': '€',
#   'orderOfMagnitude': 'Million',
#   'fiscalYearEndDate': '12-31'},
#  'userType': 'Free'}

# %% [markdown]
# You can access many other methods to retrieve detailed information about the stock.
#
# Examples are available in this notebook:
#
# <a href="https://github.com/Mael-J/mstarpy/blob/pre-release/examples/MStarpy%20-%20Stock%20example.ipynb">MStarpy - Stock example</a>

# %%
ms.screener_universe("a", 
                     ["name", "isin", "priceToEarnings"], 
                     )
# Out:
# [{'meta': {'securityID': 'F000013ODU',
#    'performanceID': '0P0001HOBX',
#    'fundID': 'FSUSA09R99',
#    'masterPortfolioID': '299210',
#    'universe': 'FO'},
#   'fields': {'name': {'value': '(LF) FoF Balanced Blnd Glbl Interamericn'},
#    'isin': {'value': 'LU1199652253'}}},
#  {'meta': {'securityID': 'F000014V7G',
#    'performanceID': '0P0001JC7T',
#    'fundID': 'FS0000FNN6',
#    'masterPortfolioID': '2222705',
#    'universe': 'FO'},
#   'fields': {'name': {'value': '(LF) High Yield A List Eurobank Cap'},
#    'isin': {'value': 'LU2047494005'}}},
#  {'meta': {'securityID': 'F000014B1Z',
#    'performanceID': '0P0001IKWX',
#    'fundID': 'FS0000FNN6',
#    'masterPortfolioID': '2222705',
#    'universe': 'FO'},
#   'fields': {'name': {'value': '(LF) High Yield A List Eurobank I'},
#    'isin': {'value': 'LU2047494187'}}},
#  {'meta': {'securityID': 'F000014B1Y',
#    'performanceID': '0P0001IKWW',
#    'fundID': 'FS0000FNN6',
#    'masterPortfolioID': '2222705',
#    'universe': 'FO'},
#   'fields': {'name': {'value': '(LF) High Yield A List Priv Banking'},
#    'isin': {'value': 'LU2047494260'}}},
#  {'meta': {'securityID': 'F000014L7Z',
#    'performanceID': '0P0001IXKX',
#    'fundID': 'FS0000FNN6',
#    'masterPortfolioID': '2222705',
#    'universe': 'FO'},
#   'fields': {'name': {'value': '(LF) High Yield A List Priv Banking DIS'},
#    'isin': {'value': 'LU2047494344'}}},
#  {'meta': {'securityID': 'F0000003X6',
#    'performanceID': '0P0000817A',
#    'fundID': 'FSUSA07YLP',
#    'masterPortfolioID': '260961',
#    'universe': 'FO',
#    'exchange': 'XMEX',
#    'ticker': '+CIBOLS A'},
#   'fields': {'name': {'value': '+CIBOLS A'},
#    'isin': {'value': 'MX52CI0L0008'}}},
#  {'meta': {'securityID': 'F00000YVRQ',
#    'performanceID': '0P0001AC1V',
#    'fundID': 'FS0000D7UR',
#    'masterPortfolioID': '1391199',
#    'universe': 'FO',
#    'exchange': 'XMEX',
#    'ticker': '+CIEQUS A'},
#   'fields': {'name': {'value': '+CIEQUS A'},
#    'isin': {'value': 'MX52CI150001'}}},
#  {'meta': {'securityID': 'F000010TBK',
#    'performanceID': '0P0001E05U',
#    'fundID': 'FS0000D7UR',
#    'masterPortfolioID': '1391199',
#    'universe': 'FO',
#    'exchange': 'XMEX',
#    'ticker': '+CIEQUS BF-1'},
#   'fields': {'name': {'value': '+CIEQUS BF-1'},
#    'isin': {'value': 'MX52CI1500A0'}}},
#  {'meta': {'securityID': 'F0000003X3',
#    'performanceID': '0P00008177',
#    'fundID': 'FSUSA07YLM',
#    'masterPortfolioID': '260768',
#    'universe': 'FO',
#    'exchange': 'XMEX',
#    'ticker': '+CIGUB A'},
#   'fields': {'name': {'value': '+CIGUB A'},
#    'isin': {'value': 'MX51CI0K0001'}}},
#  {'meta': {'securityID': 'F00000MOF5',
#    'performanceID': '0P0000TP44',
#    'fundID': 'FSUSA0A8IE',
#    'masterPortfolioID': '437134',
#    'universe': 'FO',
#    'exchange': 'XMEX',
#    'ticker': '+CIPLUS A'},
#   'fields': {'name': {'value': '+CIPLUS A'},
#    'isin': {'value': 'MX51CI0M0009'}}}]

# %%
ms.screener_universe("a", 
                     ["name", "isin", "priceToEarnings", "sector"], 
                     filters={"priceToEarnings[trailing]": ("<", 10),
                              "investmentType" : "EQ",
                              "sector": "Technology",
                              "domicile": "FRA"},
                     )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ms.screener_universe("q",
#       2                      ["name", "isin", "priceToEarnings", "sector"],
#       3                      filters={"priceToEarnings[trailing]": ("<", 10),
#       4                               "investmentType" : "EQ",
#       5                               "sector": "Technology",
#       6                               "domicile": "FRA"},
#       7                      )
#
# File c:\python\Lib\site-packages\mstarpy\search.py:167, in screener_universe(term, field, filters, pageSize, page, sortby, ascending, proxies)
#     164 if filters[f][0] not in ['<','<=','>=', '>']:
#     165      warnings.warn(f"""{f} is not a valid filter and will be ignored.
#     166                    The first argument of the tuple has to be one of this value {','.join(['<','<=','>=', '>'])}""")
# --> 167 if isinstance(filters[f][1,(int,float)]):
#     168     warnings.warn(f"""{f} is not a valid filter and will be ignored.
#     169                     The second argument of the tuple has be a number.
#     170                         """)
#     171 query_params += f" AND {f} {filters[f][0]} {filters[f][1]}"
#
# TypeError: tuple indices must be integers or slices, not tuple

# %% [markdown]
# ##
